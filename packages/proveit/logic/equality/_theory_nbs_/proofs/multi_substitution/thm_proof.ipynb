# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">equality</a>.<a class="ProveItLink" href="../../theorems.ipynb#multi_substitution">multi_substitution</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit.logic import And
from proveit import a, b, i, n, x, y
from proveit.core_expr_types.tuples import tuple_eq_via_elem_eq
from proveit.core_expr_types.operations  import operands_substitution
theory = proveit.Theory() # the theorem's theory

# %%
# %proving multi_substitution
# Out:
# multi_substitution: forall_{n in NaturalPos} [forall_{f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} (f(x_{1}, ..x_{_a}.., x_{n}) = f(y_{1}, ..y_{_a}.., y_{n}))]

# %%
defaults.assumptions = multi_substitution.all_conditions()
# Out:
# defaults.assumptions: (n in NaturalPos, x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n})

# %%
tuple_eq_via_elem_eq
# Out:
# |- forall_{i in NaturalPos} [forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{i} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{i} = b_{i}} ((a_{1}, ..a_{_a}.., a_{i}) = (b_{1}, ..b_{_a}.., b_{i}))]

# %%
tuple_eq_via_elem_eq.instantiate({i:n,a:x,b:y})
# Out:
# {n in NaturalPos, x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} |- (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})

# %%
operands_substitution
# Out:
# |- forall_{n in Natural} [forall_{f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})} (f(x_{1}, ..x_{_a}.., x_{n}) =  \\ f(y_{1}, ..y_{_a}.., y_{n}))]

# %%
operands_substitution.instantiate({y:y})
# Out:
# {n in NaturalPos, x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} |- f(x_{1}, ..x_{_a}.., x_{n}) = f(y_{1}, ..y_{_a}.., y_{n})

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{n in NaturalPos} [forall_{f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} (f(x_{1}, ..x_{_a}.., x_{n}) = f(y_{1}, ..y_{_a}.., y_{n}))]
# 1	instantiation	2, 3, 4	{n in NaturalPos, x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} |- f(x_{1}, ..x_{_a}.., x_{n}) = f(y_{1}, ..y_{_a}.., y_{n})
# 	n : n, f : f, x : x, y : y
# 2	axiom		|- forall_{n in Natural} [forall_{f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})} (f(x_{1}, ..x_{_a}.., x_{n}) =  \\ f(y_{1}, ..y_{_a}.., y_{n}))]
# 	proveit.core_expr_types.operations.operands_substitution
# 3	instantiation	5, 6, 8	{n in NaturalPos} |- n in Natural
# 	A : NaturalPos, B : Natural, x : n
# 4	instantiation	7, 8, 9	{n in NaturalPos, x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} |- (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})
# 	i : n, a : x, b : y
# 5	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 6	conjecture		|- NaturalPos proper_subset Natural
# 7	conjecture		|- forall_{i in NaturalPos} [forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{i} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{i} = b_{i}} ((a_{1}, ..a_{_a}.., a_{i}) = (b_{1}, ..b_{_a}.., b_{i}))]
# 8	assumption		{n in NaturalPos} |- n in NaturalPos
# 9	assumption		{x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} |- (x_{1} = y_{1}) and ..(x_{a} = y_{a}).. and (x_{n} = y_{n})
