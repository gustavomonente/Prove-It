# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#mult_sub_right_into">mult_sub_right_into</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.equality</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.equality import mult_sub_right_into

# %%
# check that the built expression is the same as the stored expression
assert mult_sub_right_into.expr == stored_expr
assert mult_sub_right_into.expr._style_id == stored_expr._style_id
print("Passed sanity check: mult_sub_right_into matches stored_expr")
# Out:
# Passed sanity check: mult_sub_right_into matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(mult_sub_right_into.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}}~\left[\forall_{P, x_{1}, \ldots, x_{n}, y_{1}, \ldots, y_{n}~|~P(x_{1}, \ldots, x_{n}), x_{1} = y_{1}, \ldots, x_{n} = y_{n}}~P(y_{1}, \ldots, y_{n})\right]

# %%
mult_sub_right_into.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
mult_sub_right_into.expr_info()
# Out:
# 0. forall_{n in Natural} [forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(x_{1}, ..x_{_a}.., x_{n}), x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} P(y_{1}, ..y_{_a}.., y_{n})]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (n -> {forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(x_{1}, ..x_{_a}.., x_{n}), x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} P(y_{1}, ..y_{_a}.., y_{n}) if n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(x_{1}, ..x_{_a}.., x_{n}), x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} P(y_{1}, ..y_{_a}.., y_{n}) if n in Natural.
#    core type: Lambda
#    parameter: 31
#    body: 3
# 3. {forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(x_{1}, ..x_{_a}.., x_{n}), x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} P(y_{1}, ..y_{_a}.., y_{n}) if n in Natural.
#    core type: Conditional
#    value: 4
# ...
