# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.equality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, P, Px, Py, x, y
from proveit.logic import And, Equals

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([P, x, y], Conditional(Py, And(Px, Equals(x, y)))))
# Out:
# expr: ((P, x, y) -> {P(y) if P(x) ,  x = y.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(P, x, y\right) \mapsto \left\{P(y) \textrm{ if } P(x) ,  x = y\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((P, x, y) -> {P(y) if P(x) ,  x = y.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (P, x, y) -> {P(y) if P(x) ,  x = y.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (P, x, y)
#    core type: ExprTuple
#    sub-expressions: 11, 15, 16
# 3. {P(y) if P(x) ,  x = y.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. P(y)
#    core type: Operation
#    operator: 11
#    operand: 16
# 5. P(x) and (x = y)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (y)
#    core type: ExprTuple
#    sub-expressions: 16
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (P(x), x = y)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. P(x)
#    core type: Operation
#    operator: 11
#    operand: 15
# 10. x = y
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. P
#     core type: Variable
#     sub-expressions:
# 12. (x)
#     core type: ExprTuple
#     sub-expressions: 15
# 13. =
#     core type: Literal
#     sub-expressions:
# 14. (x, y)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. x
#     core type: Variable
#     sub-expressions:
# 16. y
#     core type: Variable
#     sub-expressions:
