# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.equality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import f, n
from proveit.core_expr_types import f__x_1_to_n, f__y_1_to_n, x_1_to_n, y_1_to_n
from proveit.logic import Equals, Forall
from proveit.logic.equality import elementwise_equality
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Forall([n], Forall([f, x_1_to_n, y_1_to_n], Equals(f__x_1_to_n, f__y_1_to_n), condition = elementwise_equality), domains = [NaturalPos])
# Out:
# expr: forall_{n in NaturalPos} [forall_{f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} (f(x_{1}, ..x_{_a}.., x_{n}) = f(y_{1}, ..y_{_a}.., y_{n}))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\forall_{f, x_{1}, \ldots, x_{n}, y_{1}, \ldots, y_{n}~|~x_{1} = y_{1}, \ldots, x_{n} = y_{n}}~\left(f(x_{1}, \ldots, x_{n}) = f(y_{1}, \ldots, y_{n})\right)\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} (f(x_{1}, ..x_{_a}.., x_{n}) = f(y_{1}, ..y_{_a}.., y_{n}))]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (n -> {forall_{f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} (f(x_{1}, ..x_{_a}.., x_{n}) = f(y_{1}, ..y_{_a}.., y_{n})) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} (f(x_{1}, ..x_{_a}.., x_{n}) = f(y_{1}, ..y_{_a}.., y_{n})) if n in NaturalPos.
#    core type: Lambda
#    parameter: 32
#    body: 3
# 3. {forall_{f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} (f(x_{1}, ..x_{_a}.., x_{n}) = f(y_{1}, ..y_{_a}.., y_{n})) if n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} (f(x_{1}, ..x_{_a}.., x_{n}) = f(y_{1}, ..y_{_a}.., y_{n}))
#    core type: Operation
#    operator: 6
#    operand: 10
# 5. n in NaturalPos
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n}) -> {f(x_{1}, ..x_{_a}.., x_{n}) = f(y_{1}, ..y_{_a}.., y_{n}) if (x_{1} = y_{1}) and ..(x_{a} = y_{a}).. and (x_{n} = y_{n}).)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 32, 11
# 10. (f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n}) -> {f(x_{1}, ..x_{_a}.., x_{n}) = f(y_{1}, ..y_{_a}.., y_{n}) if (x_{1} = y_{1}) and ..(x_{a} = y_{a}).. and (x_{n} = y_{n}).
#     core type: Lambda
#     parameters: 12\n    body: 13
# 11. NaturalPos
#     core type: Literal
#     sub-expressions:
# 12. (f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 23, 26, 27
# 13. {f(x_{1}, ..x_{_a}.., x_{n}) = f(y_{1}, ..y_{_a}.., y_{n}) if (x_{1} = y_{1}) and ..(x_{a} = y_{a}).. and (x_{n} = y_{n}).
#     core type: Conditional
#     value: 14
#     condition: 15
# 14. f(x_{1}, ..x_{_a}.., x_{n}) = f(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 33
#     operands: 16
# 15. (x_{1} = y_{1}) and ..(x_{a} = y_{a}).. and (x_{n} = y_{n})
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. (f(x_{1}, ..x_{_a}.., x_{n}), f(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. and
#     core type: Literal
#     sub-expressions:
# 18. (x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n})
#     core type: ExprTuple
#     sub-expressions: 21
# 19. f(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 23
#     operands: 22
# 20. f(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. (x_{1} = y_{1}), ..(x_{a} = y_{a}).., (x_{n} = y_{n})
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 31
#     end_index: 32
# 22. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 26
# 23. f
#     core type: Variable
#     sub-expressions:
# 24. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 27
# 25. a -> (x_{a} = y_{a})
#     core type: Lambda
#     parameter: 44
#     body: 28
# 26. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 31
#     end_index: 32
# 27. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 31
#     end_index: 32
# 28. x_{a} = y_{a}
#     core type: Operation
#     operator: 33
#     operands: 34
# 29. _a -> x_{_a}
#     core type: Lambda
#     parameter: 43
#     body: 35
# 30. _a -> y_{_a}
#     core type: Lambda
#     parameter: 43
#     body: 36
# 31. 1
#     core type: Literal
#     sub-expressions:
# 32. n
#     core type: Variable
#     sub-expressions:
# 33. =
#     core type: Literal
#     sub-expressions:
# 34. (x_{a}, y_{a})
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 35. x_{_a}
#     core type: IndexedVar
# variable: 40
# index: 43
# 36. y_{_a}
#     core type: IndexedVar
# variable: 41
# index: 43
# 37. x_{a}
#     core type: IndexedVar
# variable: 40
# index: 44
# 38. y_{a}
#     core type: IndexedVar
# variable: 41
# index: 44
# 39. (_a)
#     core type: ExprTuple
#     sub-expressions: 43
# 40. x
#     core type: Variable
#     sub-expressions:
# 41. y
#     core type: Variable
#     sub-expressions:
# 42. (a)
#     core type: ExprTuple
#     sub-expressions: 44
# 43. _a
#     core type: Variable
#     sub-expressions:
# 44. a
#     core type: Variable
#     sub-expressions:
