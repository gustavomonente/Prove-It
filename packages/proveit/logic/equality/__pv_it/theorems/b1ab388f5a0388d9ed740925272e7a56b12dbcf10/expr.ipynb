# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.equality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, P
from proveit.core_expr_types import P__x_1_to_n, P__y_1_to_n, x_1_to_n, y_1_to_n
from proveit.logic import And, Equals

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([P, x_1_to_n, y_1_to_n], Conditional(P__y_1_to_n, And(P__x_1_to_n, Equals([x_1_to_n], [y_1_to_n])))))
# Out:
# expr: ((P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if P(x_{1}, ..x_{_a}.., x_{n}) ,  (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}).)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(P, x_{1}, \ldots, x_{n}, y_{1}, \ldots, y_{n}\right) \mapsto \left\{P(y_{1}, \ldots, y_{n}) \textrm{ if } P(x_{1}, \ldots, x_{n}) ,  \left(x_{1}, \ldots, x_{n}\right) = \left(y_{1}, \ldots, y_{n}\right)\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if P(x_{1}, ..x_{_a}.., x_{n}) ,  (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if P(x_{1}, ..x_{_a}.., x_{n}) ,  (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}).
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n})
#    core type: ExprTuple
#    sub-expressions: 10, 15, 16
# 3. {P(y_{1}, ..y_{_a}.., y_{n}) if P(x_{1}, ..x_{_a}.., x_{n}) ,  (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. P(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 10
#    operands: 14
# 5. P(x_{1}, ..x_{_a}.., x_{n}) and ((x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}))
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (P(x_{1}, ..x_{_a}.., x_{n}), (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 10
#    operands: 13
# 9. (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. P
#     core type: Variable
#     sub-expressions:
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. ((x_{1}, ..x_{_a}.., x_{n}), (y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 15
# 14. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 16
# 15. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 19
#     end_index: 20
# 16. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 19
#     end_index: 20
# 17. _a -> x_{_a}
#     core type: Lambda
#     parameter: 26
#     body: 21
# 18. _a -> y_{_a}
#     core type: Lambda
#     parameter: 26
#     body: 22
# 19. 1
#     core type: Literal
#     sub-expressions:
# 20. n
#     core type: Variable
#     sub-expressions:
# 21. x_{_a}
#     core type: IndexedVar
# variable: 23
# index: 26
# 22. y_{_a}
#     core type: IndexedVar
# variable: 24
# index: 26
# 23. x
#     core type: Variable
#     sub-expressions:
# 24. y
#     core type: Variable
#     sub-expressions:
# 25. (_a)
#     core type: ExprTuple
#     sub-expressions: 26
# 26. _a
#     core type: Variable
#     sub-expressions:
