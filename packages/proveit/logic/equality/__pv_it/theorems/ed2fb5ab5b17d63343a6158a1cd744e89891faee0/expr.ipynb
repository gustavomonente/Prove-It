# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.equality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import P
from proveit.core_expr_types import P__x_1_to_n, P__y_1_to_n, x_1_to_n, y_1_to_n
from proveit.logic import Forall
from proveit.logic.equality import elementwise_equality

# %%
# build up the expression from sub-expressions
expr = Forall([P, x_1_to_n, y_1_to_n], P__y_1_to_n, conditions = [P__x_1_to_n, elementwise_equality])
# Out:
# expr: forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(x_{1}, ..x_{_a}.., x_{n}), x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} P(y_{1}, ..y_{_a}.., y_{n})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{P, x_{1}, \ldots, x_{n}, y_{1}, \ldots, y_{n}~|~P(x_{1}, \ldots, x_{n}), x_{1} = y_{1}, \ldots, x_{n} = y_{n}}~P(y_{1}, \ldots, y_{n})

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(x_{1}, ..x_{_a}.., x_{n}), x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} P(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if P(x_{1}, ..x_{_a}.., x_{n}) ,  x_{1} = y_{1} ,  ..x_{a} = y_{a}.. ,  x_{n} = y_{n}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if P(x_{1}, ..x_{_a}.., x_{n}) ,  x_{1} = y_{1} ,  ..x_{a} = y_{a}.. ,  x_{n} = y_{n}.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n})
#    core type: ExprTuple
#    sub-expressions: 15, 19, 11
# 5. {P(y_{1}, ..y_{_a}.., y_{n}) if P(x_{1}, ..x_{_a}.., x_{n}) ,  x_{1} = y_{1} ,  ..x_{a} = y_{a}.. ,  x_{n} = y_{n}.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. P(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 15
#    operands: 8
# 7. P(x_{1}, ..x_{_a}.., x_{n}) and (x_{1} = y_{1}) and ..(x_{a} = y_{a}).. and (x_{n} = y_{n})
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (y_{1}, ..y_{_a}.., y_{n})
#    core type: ExprTuple
#    sub-expressions: 11
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (P(x_{1}, ..x_{_a}.., x_{n}), x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n})
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 22
#     end_index: 23
# 12. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. (x_{1} = y_{1}), ..(x_{a} = y_{a}).., (x_{n} = y_{n})
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 22
#     end_index: 23
# 14. _a -> y_{_a}
#     core type: Lambda
#     parameter: 33
#     body: 18
# 15. P
#     core type: Variable
#     sub-expressions:
# 16. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 19
# 17. a -> (x_{a} = y_{a})
#     core type: Lambda
#     parameter: 34
#     body: 20
# 18. y_{_a}
#     core type: IndexedVar
# variable: 31
# index: 33
# 19. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 22
#     end_index: 23
# 20. x_{a} = y_{a}
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. _a -> x_{_a}
#     core type: Lambda
#     parameter: 33
#     body: 26
# 22. 1
#     core type: Literal
#     sub-expressions:
# 23. n
#     core type: Variable
#     sub-expressions:
# 24. =
#     core type: Literal
#     sub-expressions:
# 25. (x_{a}, y_{a})
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 26. x_{_a}
#     core type: IndexedVar
# variable: 30
# index: 33
# 27. x_{a}
#     core type: IndexedVar
# variable: 30
# index: 34
# 28. y_{a}
#     core type: IndexedVar
# variable: 31
# index: 34
# 29. (_a)
#     core type: ExprTuple
#     sub-expressions: 33
# 30. x
#     core type: Variable
#     sub-expressions:
# 31. y
#     core type: Variable
#     sub-expressions:
# 32. (a)
#     core type: ExprTuple
#     sub-expressions: 34
# 33. _a
#     core type: Variable
#     sub-expressions:
# 34. a
#     core type: Variable
#     sub-expressions:
