# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.equality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, P
from proveit.core_expr_types import P__x_1_to_n, P__y_1_to_n, x_1_to_n, y_1_to_n
from proveit.logic import And
from proveit.logic.equality import elementwise_equality

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([P, x_1_to_n, y_1_to_n], Conditional(P__x_1_to_n, And(P__y_1_to_n, elementwise_equality))))
# Out:
# expr: ((P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) if P(y_{1}, ..y_{_a}.., y_{n}) ,  x_{1} = y_{1} ,  ..x_{a} = y_{a}.. ,  x_{n} = y_{n}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(P, x_{1}, \ldots, x_{n}, y_{1}, \ldots, y_{n}\right) \mapsto \left\{P(x_{1}, \ldots, x_{n}) \textrm{ if } P(y_{1}, \ldots, y_{n}) ,  x_{1} = y_{1} ,  \ldots ,  x_{n} = y_{n}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) if P(y_{1}, ..y_{_a}.., y_{n}) ,  x_{1} = y_{1} ,  ..x_{a} = y_{a}.. ,  x_{n} = y_{n}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) if P(y_{1}, ..y_{_a}.., y_{n}) ,  x_{1} = y_{1} ,  ..x_{a} = y_{a}.. ,  x_{n} = y_{n}.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n})
#    core type: ExprTuple
#    sub-expressions: 13, 9, 17
# 3. {P(x_{1}, ..x_{_a}.., x_{n}) if P(y_{1}, ..y_{_a}.., y_{n}) ,  x_{1} = y_{1} ,  ..x_{a} = y_{a}.. ,  x_{n} = y_{n}.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 13
#    operands: 6
# 5. P(y_{1}, ..y_{_a}.., y_{n}) and (x_{1} = y_{1}) and ..(x_{a} = y_{a}).. and (x_{n} = y_{n})
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (x_{1}, ..x_{_a}.., x_{n})
#    core type: ExprTuple
#    sub-expressions: 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (P(y_{1}, ..y_{_a}.., y_{n}), x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. x_{1}, ..x_{_a}.., x_{n}
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 20
#    end_index: 21
# 10. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. (x_{1} = y_{1}), ..(x_{a} = y_{a}).., (x_{n} = y_{n})
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 20
#     end_index: 21
# 12. _a -> x_{_a}
#     core type: Lambda
#     parameter: 31
#     body: 16
# 13. P
#     core type: Variable
#     sub-expressions:
# 14. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 17
# 15. a -> (x_{a} = y_{a})
#     core type: Lambda
#     parameter: 32
#     body: 18
# 16. x_{_a}
#     core type: IndexedVar
# variable: 28
# index: 31
# 17. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 20
#     end_index: 21
# 18. x_{a} = y_{a}
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. _a -> y_{_a}
#     core type: Lambda
#     parameter: 31
#     body: 24
# 20. 1
#     core type: Literal
#     sub-expressions:
# 21. n
#     core type: Variable
#     sub-expressions:
# 22. =
#     core type: Literal
#     sub-expressions:
# 23. (x_{a}, y_{a})
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 24. y_{_a}
#     core type: IndexedVar
# variable: 29
# index: 31
# 25. x_{a}
#     core type: IndexedVar
# variable: 28
# index: 32
# 26. y_{a}
#     core type: IndexedVar
# variable: 29
# index: 32
# 27. (_a)
#     core type: ExprTuple
#     sub-expressions: 31
# 28. x
#     core type: Variable
#     sub-expressions:
# 29. y
#     core type: Variable
#     sub-expressions:
# 30. (a)
#     core type: ExprTuple
#     sub-expressions: 32
# 31. _a
#     core type: Variable
#     sub-expressions:
# 32. a
#     core type: Variable
#     sub-expressions:
