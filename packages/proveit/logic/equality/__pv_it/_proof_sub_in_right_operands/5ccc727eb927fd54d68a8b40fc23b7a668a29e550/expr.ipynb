# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.equality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, n
from proveit.core_expr_types import P__x_1_to_n, x_1_to_n, y_1_to_n
from proveit.logic import Equals, InSet
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(n, Natural), P__x_1_to_n, Equals([x_1_to_n], [y_1_to_n]))
# Out:
# expr: (n in Natural, P(x_{1}, ..x_{_a}.., x_{n}), (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(n \in \mathbb{N}, P(x_{1}, \ldots, x_{n}), \left(x_{1}, \ldots, x_{n}\right) = \left(y_{1}, \ldots, y_{n}\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (n in Natural, P(x_{1}, ..x_{_a}.., x_{n}), (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}))
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. n in Natural
#    core type: Operation
#    operator: 4
#    operands: 5
# 2. P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 6
#    operands: 10
# 3. (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 7
#    operands: 8
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (n, Natural)
#    core type: ExprTuple
#    sub-expressions: 17, 9
# 6. P
#    core type: Variable
#    sub-expressions:
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. ((x_{1}, ..x_{_a}.., x_{n}), (y_{1}, ..y_{_a}.., y_{n}))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. Natural
#    core type: Literal
#    sub-expressions:
# 10. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 12
# 11. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 13
# 12. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 16
#     end_index: 17
# 13. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 16
#     end_index: 17
# 14. _a -> x_{_a}
#     core type: Lambda
#     parameter: 23
#     body: 18
# 15. _a -> y_{_a}
#     core type: Lambda
#     parameter: 23
#     body: 19
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. n
#     core type: Variable
#     sub-expressions:
# 18. x_{_a}
#     core type: IndexedVar
# variable: 20
# index: 23
# 19. y_{_a}
#     core type: IndexedVar
# variable: 21
# index: 23
# 20. x
#     core type: Variable
#     sub-expressions:
# 21. y
#     core type: Variable
#     sub-expressions:
# 22. (_a)
#     core type: ExprTuple
#     sub-expressions: 23
# 23. _a
#     core type: Variable
#     sub-expressions:
