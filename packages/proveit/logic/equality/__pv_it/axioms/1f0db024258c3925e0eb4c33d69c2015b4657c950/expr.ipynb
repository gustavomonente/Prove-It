# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.equality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda, x, y
from proveit.logic import Boolean, Equals, InSet

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([x, y], InSet(Equals(x, y), Boolean)))
# Out:
# expr: ((x, y) -> ((x = y) in BOOLEAN))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(x, y\right) \mapsto \left(\left(x = y\right) \in \mathbb{B}\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((x, y) -> ((x = y) in BOOLEAN))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (x, y) -> ((x = y) in BOOLEAN)
#    core type: Lambda
#    parameters: 8\n   body: 2
# 2. (x = y) in BOOLEAN
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. in
#    core type: Literal
#    sub-expressions:
# 4. (x = y, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. x = y
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (x, y)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. x
#    core type: Variable
#    sub-expressions:
# 10. y
#     core type: Variable
#     sub-expressions:
