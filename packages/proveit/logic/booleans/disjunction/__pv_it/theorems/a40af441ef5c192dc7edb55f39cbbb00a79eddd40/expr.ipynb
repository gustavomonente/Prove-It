# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import m
from proveit.core_expr_types import A_1_to_m
from proveit.logic import Equals, FALSE, Forall, Or, Set
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Forall([m], Forall([A_1_to_m], Equals(Or(A_1_to_m), FALSE), domains = [Set(FALSE)]), domains = [Natural])
# Out:
# expr: forall_{m in Natural} [forall_{A_{1}, ..A_{_a}.., A_{m} in {FALSE}} ((A_{1} or ..A_{_a}.. or A_{m}) = FALSE)]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{m \in \mathbb{N}}~\left[\forall_{A_{1}, \ldots, A_{m} \in \left\{\bot\right\}}~\left(\left(A_{1} \lor \ldots \lor A_{m}\right) = \bot\right)\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{m in Natural} [forall_{A_{1}, ..A_{_a}.., A_{m} in {FALSE}} ((A_{1} or ..A_{_a}.. or A_{m}) = FALSE)]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (m -> {forall_{A_{1}, ..A_{_a}.., A_{m} in {FALSE}} ((A_{1} or ..A_{_a}.. or A_{m}) = FALSE) if m in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. m -> {forall_{A_{1}, ..A_{_a}.., A_{m} in {FALSE}} ((A_{1} or ..A_{_a}.. or A_{m}) = FALSE) if m in Natural.
#    core type: Lambda
#    parameter: 27
#    body: 3
# 3. {forall_{A_{1}, ..A_{_a}.., A_{m} in {FALSE}} ((A_{1} or ..A_{_a}.. or A_{m}) = FALSE) if m in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{A_{1}, ..A_{_a}.., A_{m} in {FALSE}} ((A_{1} or ..A_{_a}.. or A_{m}) = FALSE)
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. m in Natural
#    core type: Operation
#    operator: 28
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((A_{1}, ..A_{_a}.., A_{m}) -> {(A_{1} or ..A_{_a}.. or A_{m}) = FALSE if (A_{1} in {FALSE}) and ..(A_{_a} in {FALSE}).. and (A_{m} in {FALSE}).)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (m, Natural)
#    core type: ExprTuple
#    sub-expressions: 27, 10
# 9. (A_{1}, ..A_{_a}.., A_{m}) -> {(A_{1} or ..A_{_a}.. or A_{m}) = FALSE if (A_{1} in {FALSE}) and ..(A_{_a} in {FALSE}).. and (A_{m} in {FALSE}).
#    core type: Lambda
#    parameters: 21\n   body: 11
# 10. Natural
#     core type: Literal
#     sub-expressions:
# 11. {(A_{1} or ..A_{_a}.. or A_{m}) = FALSE if (A_{1} in {FALSE}) and ..(A_{_a} in {FALSE}).. and (A_{m} in {FALSE}).
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. (A_{1} or ..A_{_a}.. or A_{m}) = FALSE
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (A_{1} in {FALSE}) and ..(A_{_a} in {FALSE}).. and (A_{m} in {FALSE})
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. =
#     core type: Literal
#     sub-expressions:
# 15. (A_{1} or ..A_{_a}.. or A_{m}, FALSE)
#     core type: ExprTuple
#     sub-expressions: 18, 37
# 16. and
#     core type: Literal
#     sub-expressions:
# 17. (A_{1} in {FALSE}, ..A_{_a} in {FALSE}.., A_{m} in {FALSE})
#     core type: ExprTuple
#     sub-expressions: 19
# 18. A_{1} or ..A_{_a}.. or A_{m}
#     core type: Operation
#     operator: 20
#     operands: 21
# 19. (A_{1} in {FALSE}), ..(A_{_a} in {FALSE}).., (A_{m} in {FALSE})
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 26
#     end_index: 27
# 20. or
#     core type: Literal
#     sub-expressions:
# 21. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 23
# 22. _a -> (A_{_a} in {FALSE})
#     core type: Lambda
#     parameter: 36
#     body: 24
# 23. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 26
#     end_index: 27
# 24. A_{_a} in {FALSE}
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. _a -> A_{_a}
#     core type: Lambda
#     parameter: 36
#     body: 30
# 26. 1
#     core type: Literal
#     sub-expressions:
# 27. m
#     core type: Variable
#     sub-expressions:
# 28. in
#     core type: Literal
#     sub-expressions:
# 29. (A_{_a}, {FALSE})
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 30. A_{_a}
#     core type: IndexedVar
# variable: 32
# index: 36
# 31. {FALSE}
#     core type: Operation
#     operator: 34
#     operand: 37
# 32. A
#     core type: Variable
#     sub-expressions:
# 33. (_a)
#     core type: ExprTuple
#     sub-expressions: 36
# 34. Set
#     core type: Literal
#     sub-expressions:
# 35. (FALSE)
#     core type: ExprTuple
#     sub-expressions: 37
# 36. _a
#     core type: Variable
#     sub-expressions:
# 37. FALSE
#     core type: Literal
#     sub-expressions:
