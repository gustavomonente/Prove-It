# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, ExprTuple, Lambda
from proveit.logic import Not, Or

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([A, B], Conditional(Not(A), Not(Or(A, B)))))
# Out:
# expr: ((A, B) -> {not(A) if not(A or B).)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(A, B\right) \mapsto \left\{\lnot A \textrm{ if } \lnot \left(A \lor B\right)\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((A, B) -> {not(A) if not(A or B).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (A, B) -> {not(A) if not(A or B).
#    core type: Lambda
#    parameters: 10\n   body: 2
# 2. {not(A) if not(A or B).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. not(A)
#    core type: Operation
#    operator: 6
#    operand: 11
# 4. not(A or B)
#    core type: Operation
#    operator: 6
#    operand: 8
# 5. (A)
#    core type: ExprTuple
#    sub-expressions: 11
# 6. not
#    core type: Literal
#    sub-expressions:
# 7. (A or B)
#    core type: ExprTuple
#    sub-expressions: 8
# 8. A or B
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. or
#    core type: Literal
#    sub-expressions:
# 10. (A, B)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. A
#     core type: Variable
#     sub-expressions:
# 12. B
#     core type: Variable
#     sub-expressions:
