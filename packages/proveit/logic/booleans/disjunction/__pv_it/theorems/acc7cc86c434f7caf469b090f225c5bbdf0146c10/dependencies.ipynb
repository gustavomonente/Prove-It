# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#not_right_if_neither">not_right_if_neither</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/not_right_if_neither/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.logic.booleans.disjunction import not_right_if_neither

# %%
# %dependencies not_right_if_neither
# Out:
# <h3>Unproven conjectures required (directly or indirectly) to prove not_right_if_neither</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../../../sets/enumeration/_theory_nbs_/proofs/fold/thm_proof.ipynb">proveit.logic.sets.enumeration.fold</a></dt><dd><a class="ProveItLink" href="../../../../../sets/enumeration/__pv_it/theorems/22e34c6090b35d0e995aaf11b862758af5d969170/expr.ipynb"><img src="../../../../../sets/enumeration/__pv_it/theorems/22e34c6090b35d0e995aaf11b862758af5d969170/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# ...
