# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.core_expr_types import A_1_to_l, B_1_to_m, C_1_to_n
from proveit.logic import Forall, Or

# %%
# build up the expression from sub-expressions
expr = Forall([A_1_to_l, B_1_to_m, C_1_to_n], Or(A_1_to_l, Or(B_1_to_m), C_1_to_n), condition = Or(A_1_to_l, B_1_to_m, C_1_to_n))
# Out:
# expr: forall_{A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n} | A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n}} (A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A_{1}, \ldots, A_{l}, B_{1}, \ldots, B_{m}, C_{1}, \ldots, C_{n}~|~A_{1} \lor \ldots \lor A_{l} \lor B_{1} \lor \ldots \lor B_{m} \lor C_{1} \lor \ldots \lor C_{n}}~\left(A_{1} \lor \ldots \lor A_{l} \lor \left(B_{1} \lor \ldots \lor B_{m}\right) \lor C_{1} \lor \ldots \lor C_{n}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n} | A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n}} (A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n})
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n}) -> {A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n} if A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n}) -> {A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n} if A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n}.
#    core type: Lambda
#    parameters: 8\n   body: 4
# 4. {A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n} if A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n}.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n}
#    core type: Operation
#    operator: 12
#    operands: 7
# 6. A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n}
#    core type: Operation
#    operator: 12
#    operands: 8
# 7. (A_{1}, ..A_{_a}.., A_{l}, B_{1} or ..B_{_a}.. or B_{m}, C_{1}, ..C_{_a}.., C_{n})
#    core type: ExprTuple
#    sub-expressions: 10, 9, 11
# 8. (A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n})
#    core type: ExprTuple
#    sub-expressions: 10, 18, 11
# 9. B_{1} or ..B_{_a}.. or B_{m}
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. A_{1}, ..A_{_a}.., A_{l}
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 22
#     end_index: 15
# 11. C_{1}, ..C_{_a}.., C_{n}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 22
#     end_index: 17
# 12. or
#     core type: Literal
#     sub-expressions:
# 13. (B_{1}, ..B_{_a}.., B_{m})
#     core type: ExprTuple
#     sub-expressions: 18
# 14. _a -> A_{_a}
#     core type: Lambda
#     parameter: 29
#     body: 19
# 15. l
#     core type: Variable
#     sub-expressions:
# 16. _a -> C_{_a}
#     core type: Lambda
#     parameter: 29
#     body: 20
# 17. n
#     core type: Variable
#     sub-expressions:
# 18. B_{1}, ..B_{_a}.., B_{m}
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 22
#     end_index: 23
# 19. A_{_a}
#     core type: IndexedVar
# variable: 24
# index: 29
# 20. C_{_a}
#     core type: IndexedVar
# variable: 25
# index: 29
# 21. _a -> B_{_a}
#     core type: Lambda
#     parameter: 29
#     body: 26
# 22. 1
#     core type: Literal
#     sub-expressions:
# 23. m
#     core type: Variable
#     sub-expressions:
# 24. A
#     core type: Variable
#     sub-expressions:
# 25. C
#     core type: Variable
#     sub-expressions:
# 26. B_{_a}
#     core type: IndexedVar
# variable: 27
# index: 29
# 27. B
#     core type: Variable
#     sub-expressions:
# 28. (_a)
#     core type: ExprTuple
#     sub-expressions: 29
# 29. _a
#     core type: Variable
#     sub-expressions:
