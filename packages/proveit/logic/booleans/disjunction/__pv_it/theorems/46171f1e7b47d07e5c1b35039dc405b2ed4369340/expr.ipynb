# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B, Conditional, l, m, n
from proveit.core_expr_types import A_1_to_l, C_1_to_m, D_1_to_n
from proveit.logic import And, Forall, InSet, Or
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([A_1_to_l, B, C_1_to_m, D_1_to_n], Or(A_1_to_l, C_1_to_m, B, D_1_to_n), condition = Or(A_1_to_l, B, C_1_to_m, D_1_to_n)), And(InSet(l, Natural), InSet(m, Natural), InSet(n, Natural)))
# Out:
# expr: {forall_{A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n} | A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}} (A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n}) if l in Natural ,  m in Natural ,  n in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{A_{1}, \ldots, A_{l}, B, C_{1}, \ldots, C_{m}, D_{1}, \ldots, D_{n}~|~A_{1} \lor \ldots \lor A_{l} \lor B \lor C_{1} \lor \ldots \lor C_{m} \lor D_{1} \lor \ldots \lor D_{n}}~\left(A_{1} \lor \ldots \lor A_{l} \lor C_{1} \lor \ldots \lor C_{m} \lor B \lor D_{1} \lor \ldots \lor D_{n}\right) \textrm{ if } l \in \mathbb{N} ,  m \in \mathbb{N} ,  n \in \mathbb{N}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n} | A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}} (A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n}) if l in Natural ,  m in Natural ,  n in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n} | A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}} (A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n})
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. (l in Natural) and (m in Natural) and (n in Natural)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n}) -> {A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n} if A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (l in Natural, m in Natural, n in Natural)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 7. (A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n}) -> {A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n} if A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}.
#    core type: Lambda
#    parameters: 21\n   body: 11
# 8. l in Natural
#    core type: Operation
#    operator: 14
#    operands: 12
# 9. m in Natural
#    core type: Operation
#    operator: 14
#    operands: 13
# 10. n in Natural
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. {A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n} if A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}.
#     core type: Conditional
#     value: 16
#     condition: 17
# 12. (l, Natural)
#     core type: ExprTuple
#     sub-expressions: 27, 18
# 13. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 29, 18
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 32, 18
# 16. A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n}
#     core type: Operation
#     operator: 20
#     operands: 19
# 17. A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. Natural
#     core type: Literal
#     sub-expressions:
# 19. (A_{1}, ..A_{_a}.., A_{l}, C_{1}, ..C_{_a}.., C_{m}, B, D_{1}, ..D_{_a}.., D_{n})
#     core type: ExprTuple
#     sub-expressions: 22, 24, 23, 25
# 20. or
#     core type: Literal
#     sub-expressions:
# 21. (A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n})
#     core type: ExprTuple
#     sub-expressions: 22, 23, 24, 25
# 22. A_{1}, ..A_{_a}.., A_{l}
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 31
#     end_index: 27
# 23. B
#     core type: Variable
#     sub-expressions:
# 24. C_{1}, ..C_{_a}.., C_{m}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 31
#     end_index: 29
# 25. D_{1}, ..D_{_a}.., D_{n}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 31
#     end_index: 32
# 26. _a -> A_{_a}
#     core type: Lambda
#     parameter: 40
#     body: 33
# 27. l
#     core type: Variable
#     sub-expressions:
# 28. _a -> C_{_a}
#     core type: Lambda
#     parameter: 40
#     body: 34
# 29. m
#     core type: Variable
#     sub-expressions:
# 30. _a -> D_{_a}
#     core type: Lambda
#     parameter: 40
#     body: 35
# 31. 1
#     core type: Literal
#     sub-expressions:
# 32. n
#     core type: Variable
#     sub-expressions:
# 33. A_{_a}
#     core type: IndexedVar
# variable: 36
# index: 40
# 34. C_{_a}
#     core type: IndexedVar
# variable: 37
# index: 40
# 35. D_{_a}
#     core type: IndexedVar
# variable: 38
# index: 40
# 36. A
#     core type: Variable
#     sub-expressions:
# 37. C
#     core type: Variable
#     sub-expressions:
# 38. D
#     core type: Variable
#     sub-expressions:
# 39. (_a)
#     core type: ExprTuple
#     sub-expressions: 40
# 40. _a
#     core type: Variable
#     sub-expressions:
