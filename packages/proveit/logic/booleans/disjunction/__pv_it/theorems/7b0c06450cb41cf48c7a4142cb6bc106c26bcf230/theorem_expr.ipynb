# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#or_if_right">or_if_right</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.disjunction import or_if_right

# %%
# check that the built expression is the same as the stored expression
assert or_if_right.expr == stored_expr
assert or_if_right.expr._style_id == stored_expr._style_id
print("Passed sanity check: or_if_right matches stored_expr")
# Out:
# Passed sanity check: or_if_right matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(or_if_right.latex())
# Out:
# \vdash \forall_{A, B \in \mathbb{B}~|~B}~\left(A \lor B\right)

# %%
or_if_right.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
or_if_right.expr_info()
# Out:
# 0. forall_{A, B in BOOLEAN | B} (A or B)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((A, B) -> {A or B if A in BOOLEAN ,  B in BOOLEAN ,  B.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (A, B) -> {A or B if A in BOOLEAN ,  B in BOOLEAN ,  B.
#    core type: Lambda
#    parameters: 8\n   body: 4
# 4. {A or B if A in BOOLEAN ,  B in BOOLEAN ,  B.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. A or B
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (A in BOOLEAN) and (B in BOOLEAN) and B
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. or
#    core type: Literal
#    sub-expressions:
# 8. (A, B)
#    core type: ExprTuple
#    sub-expressions: 16, 17
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (A in BOOLEAN, B in BOOLEAN, B)
#     core type: ExprTuple
#     sub-expressions: 11, 12, 17
# 11. A in BOOLEAN
#     core type: Operation
# ...
