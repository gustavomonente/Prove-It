# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#unary_or_lemma">unary_or_lemma</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.disjunction import unary_or_lemma

# %%
# check that the built expression is the same as the stored expression
assert unary_or_lemma.expr == stored_expr
assert unary_or_lemma.expr._style_id == stored_expr._style_id
print("Passed sanity check: unary_or_lemma matches stored_expr")
# Out:
# Passed sanity check: unary_or_lemma matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(unary_or_lemma.latex())
# Out:
# \vdash \forall_{A \in \mathbb{B}}~\left(\lor(A) = \left(\bot \lor A\right)\right)

# %%
unary_or_lemma.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
unary_or_lemma.expr_info()
# Out:
# 0. forall_{A in BOOLEAN} (or(A) = (FALSE or A))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A -> {or(A) = (FALSE or A) if A in BOOLEAN.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. A -> {or(A) = (FALSE or A) if A in BOOLEAN.
#    core type: Lambda
#    parameter: 18
#    body: 4
# 4. {or(A) = (FALSE or A) if A in BOOLEAN.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. or(A) = (FALSE or A)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. A in BOOLEAN
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (or(A), FALSE or A)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (A, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 18, 13
# 11. or(A)
#     core type: Operation
#     operator: 15
#     operand: 18
# 12. FALSE or A
# ...
