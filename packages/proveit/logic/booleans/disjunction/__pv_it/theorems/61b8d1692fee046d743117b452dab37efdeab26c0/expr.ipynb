# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, ExprRange, ExprTuple, IndexedVar, Lambda, i, m
from proveit.core_expr_types import A_1_to_m
from proveit.logic import And, Not, Or
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([A_1_to_m], Conditional(Not(Or(A_1_to_m)), And(ExprRange(i, Not(IndexedVar(A, i)), one, m)))))
# Out:
# expr: ((A_{1}, ..A_{_a}.., A_{m}) -> {not(A_{1} or ..A_{_a}.. or A_{m}) if not(A_{1}) and ..not(A_{i}).. and not(A_{m}).)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(A_{1}, \ldots, A_{m}\right) \mapsto \left\{\lnot \left(A_{1} \lor \ldots \lor A_{m}\right) \textrm{ if } (\lnot A_{1}) \land \ldots \land (\lnot A_{m})\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((A_{1}, ..A_{_a}.., A_{m}) -> {not(A_{1} or ..A_{_a}.. or A_{m}) if not(A_{1}) and ..not(A_{i}).. and not(A_{m}).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (A_{1}, ..A_{_a}.., A_{m}) -> {not(A_{1} or ..A_{_a}.. or A_{m}) if not(A_{1}) and ..not(A_{i}).. and not(A_{m}).
#    core type: Lambda
#    parameters: 11\n   body: 2
# 2. {not(A_{1} or ..A_{_a}.. or A_{m}) if not(A_{1}) and ..not(A_{i}).. and not(A_{m}).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. not(A_{1} or ..A_{_a}.. or A_{m})
#    core type: Operation
#    operator: 18
#    operand: 8
# 4. not(A_{1}) and ..not(A_{i}).. and not(A_{m})
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (A_{1} or ..A_{_a}.. or A_{m})
#    core type: ExprTuple
#    sub-expressions: 8
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (not(A_{1}), ..not(A_{i}).., not(A_{m}))
#    core type: ExprTuple
#    sub-expressions: 9
# 8. A_{1} or ..A_{_a}.. or A_{m}
#    core type: Operation
# ...
