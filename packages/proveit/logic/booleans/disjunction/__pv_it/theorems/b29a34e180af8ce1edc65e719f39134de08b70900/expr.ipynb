# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, C, Conditional, ExprRange, IndexedVar, Variable, i, m
from proveit.core_expr_types import A_1_to_m
from proveit.logic import And, Boolean, Forall, Implies, InSet, Or
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Conditional(Forall([C], C, condition = ExprRange(i, Implies(IndexedVar(A, i), C), one, m)), And(ExprRange(sub_expr1, InSet(IndexedVar(A, sub_expr1), Boolean), one, m), Or(A_1_to_m)))
# Out:
# expr: {forall_{C | A_{1} => C, ..A_{i} => C.., A_{m} => C} C if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{m} in BOOLEAN ,  A_{1} or ..A_{_a}.. or A_{m}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{C~|~A_{1} \Rightarrow C, \ldots, A_{m} \Rightarrow C}~C \textrm{ if } A_{1} \in \mathbb{B} ,  \ldots ,  A_{m} \in \mathbb{B} ,  A_{1} \lor \ldots \lor A_{m}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{C | A_{1} => C, ..A_{i} => C.., A_{m} => C} C if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{m} in BOOLEAN ,  A_{1} or ..A_{_a}.. or A_{m}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{C | A_{1} => C, ..A_{i} => C.., A_{m} => C} C
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN) and (A_{1} or ..A_{_a}.. or A_{m})
#    core type: Operation
#    operator: 16
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (C -> {C if (A_{1} => C) and ..(A_{i} => C).. and (A_{m} => C).)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m} in BOOLEAN, A_{1} or ..A_{_a}.. or A_{m})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. C -> {C if (A_{1} => C) and ..(A_{i} => C).. and (A_{m} => C).
#    core type: Lambda
#    parameter: 33
#    body: 9
# 7. (A_{1} in BOOLEAN), ..(A_{_a} in BOOLEAN).., (A_{m} in BOOLEAN)
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 25
#    end_index: 26
# 8. A_{1} or ..A_{_a}.. or A_{m}
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. {C if (A_{1} => C) and ..(A_{i} => C).. and (A_{m} => C).
#    core type: Conditional
#    value: 33
#    condition: 13
# 10. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 29
#     body: 14
# 11. or
#     core type: Literal
#     sub-expressions:
# 12. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 15
# 13. (A_{1} => C) and ..(A_{i} => C).. and (A_{m} => C)
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 25
#     end_index: 26
# 16. and
#     core type: Literal
#     sub-expressions:
# 17. (A_{1} => C, ..A_{i} => C.., A_{m} => C)
#     core type: ExprTuple
#     sub-expressions: 21
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 23, 22
# 20. _a -> A_{_a}
#     core type: Lambda
#     parameter: 29
#     body: 23
# 21. (A_{1} => C), ..(A_{i} => C).., (A_{m} => C)
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 25
#     end_index: 26
# 22. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 23. A_{_a}
#     core type: IndexedVar
# variable: 34
# index: 29
# 24. i -> (A_{i} => C)
#     core type: Lambda
#     parameter: 36
#     body: 28
# 25. 1
#     core type: Literal
#     sub-expressions:
# 26. m
#     core type: Variable
#     sub-expressions:
# 27. (_a)
#     core type: ExprTuple
#     sub-expressions: 29
# 28. A_{i} => C
#     core type: Operation
#     operator: 30
#     operands: 31
# 29. _a
#     core type: Variable
#     sub-expressions:
# 30. =>
#     core type: Literal
#     sub-expressions:
# 31. (A_{i}, C)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 32. A_{i}
#     core type: IndexedVar
# variable: 34
# index: 36
# 33. C
#     core type: Variable
#     sub-expressions:
# 34. A
#     core type: Variable
#     sub-expressions:
# 35. (i)
#     core type: ExprTuple
#     sub-expressions: 36
# 36. i
#     core type: Variable
#     sub-expressions:
