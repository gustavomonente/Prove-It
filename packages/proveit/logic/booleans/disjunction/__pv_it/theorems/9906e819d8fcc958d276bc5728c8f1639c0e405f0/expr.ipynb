# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional
from proveit.logic import And, Boolean, InSet, Not, Or

# %%
# build up the expression from sub-expressions
expr = Conditional(Or(A, B), And(InSet(A, Boolean), InSet(B, Boolean), Not(And(Not(A), Not(B)))))
# Out:
# expr: {A or B if A in BOOLEAN ,  B in BOOLEAN ,  not(not(A) and not(B)).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{A \lor B \textrm{ if } A \in \mathbb{B} ,  B \in \mathbb{B} ,  \lnot \left((\lnot A) \land (\lnot B)\right)\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {A or B if A in BOOLEAN ,  B in BOOLEAN ,  not(not(A) and not(B)).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. A or B
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (A in BOOLEAN) and (B in BOOLEAN) and not(not(A) and not(B))
#    core type: Operation
#    operator: 15
#    operands: 5
# 3. or
#    core type: Literal
#    sub-expressions:
# 4. (A, B)
#    core type: ExprTuple
#    sub-expressions: 22, 23
# 5. (A in BOOLEAN, B in BOOLEAN, not(not(A) and not(B)))
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 6. A in BOOLEAN
#    core type: Operation
#    operator: 10
#    operands: 9
# 7. B in BOOLEAN
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. not(not(A) and not(B))
#    core type: Operation
#    operator: 20
#    operand: 14
# 9. (A, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 22, 13
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 23, 13
# 12. (not(A) and not(B))
#     core type: ExprTuple
#     sub-expressions: 14
# 13. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 14. not(A) and not(B)
#     core type: Operation
#     operator: 15
#     operands: 16
# 15. and
#     core type: Literal
#     sub-expressions:
# 16. (not(A), not(B))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. not(A)
#     core type: Operation
#     operator: 20
#     operand: 22
# 18. not(B)
#     core type: Operation
#     operator: 20
#     operand: 23
# 19. (A)
#     core type: ExprTuple
#     sub-expressions: 22
# 20. not
#     core type: Literal
#     sub-expressions:
# 21. (B)
#     core type: ExprTuple
#     sub-expressions: 23
# 22. A
#     core type: Variable
#     sub-expressions:
# 23. B
#     core type: Variable
#     sub-expressions:
