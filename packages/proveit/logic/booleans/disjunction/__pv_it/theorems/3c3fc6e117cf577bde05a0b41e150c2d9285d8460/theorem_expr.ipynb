# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#closure">closure</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.disjunction import closure

# %%
# check that the built expression is the same as the stored expression
assert closure.expr == stored_expr
assert closure.expr._style_id == stored_expr._style_id
print("Passed sanity check: closure matches stored_expr")
# Out:
# Passed sanity check: closure matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(closure.latex())
# Out:
# \vdash \forall_{m \in \mathbb{N}^+}~\left[\forall_{A_{1}, \ldots, A_{m} \in \mathbb{B}}~\left(\left(A_{1} \lor \ldots \lor A_{m}\right) \in \mathbb{B}\right)\right]

# %%
closure.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
closure.expr_info()
# Out:
# 0. forall_{m in NaturalPos} [forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN)]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (m -> {forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN) if m in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. m -> {forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN) if m in NaturalPos.
#    core type: Lambda
#    parameter: 26
#    body: 3
# 3. {forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN) if m in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN)
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. m in NaturalPos
#    core type: Operation
#    operator: 27
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((A_{1}, ..A_{_a}.., A_{m}) -> {(A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN if (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN).)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (m, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 26, 10
# 9. (A_{1}, ..A_{_a}.., A_{m}) -> {(A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN if (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN).
#    core type: Lambda
#    parameters: 20\n   body: 11
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. {(A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN if (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN).
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. (A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN
#     core type: Operation
#     operator: 27
#     operands: 14
# 13. (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN)
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (A_{1} or ..A_{_a}.. or A_{m}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 17, 30
# 15. and
#     core type: Literal
#     sub-expressions:
# 16. (A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m} in BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 18
# 17. A_{1} or ..A_{_a}.. or A_{m}
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. (A_{1} in BOOLEAN), ..(A_{_a} in BOOLEAN).., (A_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 25
#     end_index: 26
# 19. or
#     core type: Literal
#     sub-expressions:
# 20. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 22
# 21. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 33
#     body: 23
# 22. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 25
#     end_index: 26
# 23. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 27
#     operands: 28
# 24. _a -> A_{_a}
#     core type: Lambda
#     parameter: 33
#     body: 29
# 25. 1
#     core type: Literal
#     sub-expressions:
# 26. m
#     core type: Variable
#     sub-expressions:
# 27. in
#     core type: Literal
#     sub-expressions:
# 28. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 29. A_{_a}
#     core type: IndexedVar
# variable: 31
# index: 33
# 30. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 31. A
#     core type: Variable
#     sub-expressions:
# 32. (_a)
#     core type: ExprTuple
#     sub-expressions: 33
# 33. _a
#     core type: Variable
#     sub-expressions:
