# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, ExprRange, IndexedVar, Lambda, i, m
from proveit.core_expr_types import A_1_to_m
from proveit.logic import And, Forall, InSet, Not, Or
from proveit.numbers import Natural, one

# %%
# build up the expression from sub-expressions
expr = Lambda(m, Conditional(Forall([A_1_to_m], Or(A_1_to_m), condition = Not(And(ExprRange(i, Not(IndexedVar(A, i)), one, m)))), InSet(m, Natural)))
# Out:
# expr: m -> {forall_{A_{1}, ..A_{_a}.., A_{m} | not(not(A_{1}) and ..not(A_{i}).. and not(A_{m}))} (A_{1} or ..A_{_a}.. or A_{m}) if m in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# m \mapsto \left\{\forall_{A_{1}, \ldots, A_{m}~|~\lnot \left((\lnot A_{1}) \land \ldots \land (\lnot A_{m})\right)}~\left(A_{1} \lor \ldots \lor A_{m}\right) \textrm{ if } m \in \mathbb{N}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. m -> {forall_{A_{1}, ..A_{_a}.., A_{m} | not(not(A_{1}) and ..not(A_{i}).. and not(A_{m}))} (A_{1} or ..A_{_a}.. or A_{m}) if m in Natural.
#    core type: Lambda
#    parameter: 26
#    body: 1
# 1. {forall_{A_{1}, ..A_{_a}.., A_{m} | not(not(A_{1}) and ..not(A_{i}).. and not(A_{m}))} (A_{1} or ..A_{_a}.. or A_{m}) if m in Natural.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{A_{1}, ..A_{_a}.., A_{m} | not(not(A_{1}) and ..not(A_{i}).. and not(A_{m}))} (A_{1} or ..A_{_a}.. or A_{m})
#    core type: Operation
#    operator: 4
#    operand: 8
# 3. m in Natural
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. ((A_{1}, ..A_{_a}.., A_{m}) -> {A_{1} or ..A_{_a}.. or A_{m} if not(not(A_{1}) and ..not(A_{i}).. and not(A_{m})).)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (m, Natural)
#    core type: ExprTuple
# ...
