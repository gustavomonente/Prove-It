# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, ExprRange, IndexedVar, i, m
from proveit.core_expr_types import A_1_to_m, B_1_to_m
from proveit.logic import Boolean, Forall, Implies, Or
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
expr = Forall([A_1_to_m, B_1_to_m], Or(B_1_to_m), domains = [Boolean, Boolean], conditions = [Or(A_1_to_m), ExprRange(i, Implies(IndexedVar(A, i), IndexedVar(B, i)), one, m)])
# Out:
# expr: forall_{A_{1}, ..A_{_a}.., A_{m}, B_{1}, ..B_{_a}.., B_{m} in BOOLEAN | A_{1} or ..A_{_a}.. or A_{m}, A_{1} => B_{1}, ..A_{i} => B_{i}.., A_{m} => B_{m}} (B_{1} or ..B_{_a}.. or B_{m})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A_{1}, \ldots, A_{m}, B_{1}, \ldots, B_{m} \in \mathbb{B}~|~A_{1} \lor \ldots \lor A_{m}, A_{1} \Rightarrow B_{1}, \ldots, A_{m} \Rightarrow B_{m}}~\left(B_{1} \lor \ldots \lor B_{m}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{A_{1}, ..A_{_a}.., A_{m}, B_{1}, ..B_{_a}.., B_{m} in BOOLEAN | A_{1} or ..A_{_a}.. or A_{m}, A_{1} => B_{1}, ..A_{i} => B_{i}.., A_{m} => B_{m}} (B_{1} or ..B_{_a}.. or B_{m})
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((A_{1}, ..A_{_a}.., A_{m}, B_{1}, ..B_{_a}.., B_{m}) -> {B_{1} or ..B_{_a}.. or B_{m} if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{m} in BOOLEAN ,  B_{1} in BOOLEAN ,  ..B_{_a} in BOOLEAN.. ,  B_{m} in BOOLEAN ,  A_{1} or ..A_{_a}.. or A_{m} ,  A_{1} => B_{1} ,  ..A_{i} => B_{i}.. ,  A_{m} => B_{m}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (A_{1}, ..A_{_a}.., A_{m}, B_{1}, ..B_{_a}.., B_{m}) -> {B_{1} or ..B_{_a}.. or B_{m} if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{m} in BOOLEAN ,  B_{1} in BOOLEAN ,  ..B_{_a} in BOOLEAN.. ,  B_{m} in BOOLEAN ,  A_{1} or ..A_{_a}.. or A_{m} ,  A_{1} => B_{1} ,  ..A_{i} => B_{i}.. ,  A_{m} => B_{m}.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (A_{1}, ..A_{_a}.., A_{m}, B_{1}, ..B_{_a}.., B_{m})
#    core type: ExprTuple
#    sub-expressions: 24, 11
# 5. {B_{1} or ..B_{_a}.. or B_{m} if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{m} in BOOLEAN ,  B_{1} in BOOLEAN ,  ..B_{_a} in BOOLEAN.. ,  B_{m} in BOOLEAN ,  A_{1} or ..A_{_a}.. or A_{m} ,  A_{1} => B_{1} ,  ..A_{i} => B_{i}.. ,  A_{m} => B_{m}.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. B_{1} or ..B_{_a}.. or B_{m}
#    core type: Operation
#    operator: 19
#    operands: 8
# 7. (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN) and (B_{1} in BOOLEAN) and ..(B_{_a} in BOOLEAN).. and (B_{m} in BOOLEAN) and (A_{1} or ..A_{_a}.. or A_{m}) and (A_{1} => B_{1}) and ..(A_{i} => B_{i}).. and (A_{m} => B_{m})
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (B_{1}, ..B_{_a}.., B_{m})
#    core type: ExprTuple
#    sub-expressions: 11
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m} in BOOLEAN, B_{1} in BOOLEAN, ..B_{_a} in BOOLEAN.., B_{m} in BOOLEAN, A_{1} or ..A_{_a}.. or A_{m}, A_{1} => B_{1}, ..A_{i} => B_{i}.., A_{m} => B_{m})
#     core type: ExprTuple
#     sub-expressions: 12, 13, 14, 15
# 11. B_{1}, ..B_{_a}.., B_{m}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 30
#     end_index: 31
# 12. (A_{1} in BOOLEAN), ..(A_{_a} in BOOLEAN).., (A_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 30
#     end_index: 31
# 13. (B_{1} in BOOLEAN), ..(B_{_a} in BOOLEAN).., (B_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 30
#     end_index: 31
# 14. A_{1} or ..A_{_a}.. or A_{m}
#     core type: Operation
#     operator: 19
#     operands: 20
# 15. (A_{1} => B_{1}), ..(A_{i} => B_{i}).., (A_{m} => B_{m})
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 30
#     end_index: 31
# 16. _a -> B_{_a}
#     core type: Lambda
#     parameter: 43
#     body: 34
# 17. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 43
#     body: 22
# 18. _a -> (B_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 43
#     body: 23
# 19. or
#     core type: Literal
#     sub-expressions:
# 20. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 24
# 21. i -> (A_{i} => B_{i})
#     core type: Lambda
#     parameter: 44
#     body: 25
# 22. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 27
#     operands: 26
# 23. B_{_a} in BOOLEAN
#     core type: Operation
#     operator: 27
#     operands: 28
# 24. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 30
#     end_index: 31
# 25. A_{i} => B_{i}
#     core type: Operation
#     operator: 32
#     operands: 33
# 26. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 36, 35
# 27. in
#     core type: Literal
#     sub-expressions:
# 28. (B_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 29. _a -> A_{_a}
#     core type: Lambda
#     parameter: 43
#     body: 36
# 30. 1
#     core type: Literal
#     sub-expressions:
# 31. m
#     core type: Variable
#     sub-expressions:
# 32. =>
#     core type: Literal
#     sub-expressions:
# 33. (A_{i}, B_{i})
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 34. B_{_a}
#     core type: IndexedVar
# variable: 41
# index: 43
# 35. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 36. A_{_a}
#     core type: IndexedVar
# variable: 40
# index: 43
# 37. A_{i}
#     core type: IndexedVar
# variable: 40
# index: 44
# 38. B_{i}
#     core type: IndexedVar
# variable: 41
# index: 44
# 39. (_a)
#     core type: ExprTuple
#     sub-expressions: 43
# 40. A
#     core type: Variable
#     sub-expressions:
# 41. B
#     core type: Variable
#     sub-expressions:
# 42. (i)
#     core type: ExprTuple
#     sub-expressions: 44
# 43. _a
#     core type: Variable
#     sub-expressions:
# 44. i
#     core type: Variable
#     sub-expressions:
