# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, ExprRange, ExprTuple, IndexedVar, Lambda, Variable, m
from proveit.logic import And, Boolean, InSet, Or
from proveit.numbers import Add, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(A, sub_expr1)
sub_expr3 = Add(m, one)
sub_expr4 = ExprRange(sub_expr1, sub_expr2, one, sub_expr3)
expr = ExprTuple(Lambda([sub_expr4], Conditional(InSet(Or(sub_expr4), Boolean), And(ExprRange(sub_expr1, InSet(sub_expr2, Boolean), one, sub_expr3)))))
# Out:
# expr: ((A_{1}, ..A_{_a}.., A_{m + 1}) -> {(A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEAN if (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m + 1} in BOOLEAN).)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(A_{1}, \ldots, A_{m + 1}\right) \mapsto \left\{\left(A_{1} \lor \ldots \lor A_{m + 1}\right) \in \mathbb{B} \textrm{ if } \left(A_{1} \in \mathbb{B}\right) \land \ldots \land \left(A_{m + 1} \in \mathbb{B}\right)\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((A_{1}, ..A_{_a}.., A_{m + 1}) -> {(A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEAN if (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m + 1} in BOOLEAN).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (A_{1}, ..A_{_a}.., A_{m + 1}) -> {(A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEAN if (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m + 1} in BOOLEAN).
#    core type: Lambda
#    parameters: 11\n   body: 2
# 2. {(A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEAN if (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m + 1} in BOOLEAN).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEAN
#    core type: Operation
#    operator: 17
#    operands: 5
# 4. (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m + 1} in BOOLEAN)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (A_{1} or ..A_{_a}.. or A_{m + 1}, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 8, 22
# 6. and
# ...
