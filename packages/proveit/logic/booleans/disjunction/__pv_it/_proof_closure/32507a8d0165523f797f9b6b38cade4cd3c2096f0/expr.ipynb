# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, ExprRange, IndexedVar, Variable, m
from proveit.core_expr_types import A_1_to_m
from proveit.logic import And, Boolean, Forall, InSet, Or
from proveit.numbers import Add, NaturalPos, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [Boolean]
sub_expr3 = IndexedVar(A, one)
sub_expr4 = ExprRange(sub_expr1, IndexedVar(A, sub_expr1), one, Add(m, one))
expr = And(Forall([sub_expr3], InSet(sub_expr3, Boolean), domains = sub_expr2), Forall([m], Forall([sub_expr4], InSet(Or(sub_expr4), Boolean), domains = sub_expr2), domains = [NaturalPos], condition = Forall([A_1_to_m], InSet(Or(A_1_to_m), Boolean), domains = sub_expr2)))
# Out:
# expr: [forall_{A_{1} in BOOLEAN} (A_{1} in BOOLEAN)] and [forall_{m in NaturalPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEAN)]]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left[\forall_{A_{1} \in \mathbb{B}}~\left(A_{1} \in \mathbb{B}\right)\right] \land \left[\forall_{m \in \mathbb{N}^+~|~\forall_{A_{1}, \ldots, A_{m} \in \mathbb{B}}~\left(\left(A_{1} \lor \ldots \lor A_{m}\right) \in \mathbb{B}\right)}~\left[\forall_{A_{1}, \ldots, A_{m + 1} \in \mathbb{B}}~\left(\left(A_{1} \lor \ldots \lor A_{m + 1}\right) \in \mathbb{B}\right)\right]\right]

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. [forall_{A_{1} in BOOLEAN} (A_{1} in BOOLEAN)] and [forall_{m in NaturalPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEAN)]]
#    core type: Operation
#    operator: 38
#    operands: 1
# 1. (forall_{A_{1} in BOOLEAN} (A_{1} in BOOLEAN), forall_{m in NaturalPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEAN)])
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. forall_{A_{1} in BOOLEAN} (A_{1} in BOOLEAN)
#    core type: Operation
#    operator: 23
#    operand: 6
# 3. forall_{m in NaturalPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEAN)]
# ...
