# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional
from proveit.logic import And, Boolean, Forall, InSet, Not, Or

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([B], Or(A, B), domains = [Boolean], condition = Not(And(Not(A), Not(B)))), InSet(A, Boolean))
# Out:
# expr: {forall_{B in BOOLEAN | not(not(A) and not(B))} (A or B) if A in BOOLEAN.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{B \in \mathbb{B}~|~\lnot \left((\lnot A) \land (\lnot B)\right)}~\left(A \lor B\right) \textrm{ if } A \in \mathbb{B}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{B in BOOLEAN | not(not(A) and not(B))} (A or B) if A in BOOLEAN.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{B in BOOLEAN | not(not(A) and not(B))} (A or B)
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. A in BOOLEAN
#    core type: Operation
#    operator: 15
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (B -> {A or B if B in BOOLEAN ,  not(not(A) and not(B)).)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (A, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 27, 18
# 6. B -> {A or B if B in BOOLEAN ,  not(not(A) and not(B)).
#    core type: Lambda
#    parameter: 28
#    body: 7
# 7. {A or B if B in BOOLEAN ,  not(not(A) and not(B)).
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. A or B
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (B in BOOLEAN) and not(not(A) and not(B))
#    core type: Operation
#    operator: 20
#    operands: 12
# 10. or
#     core type: Literal
#     sub-expressions:
# 11. (A, B)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 12. (B in BOOLEAN, not(not(A) and not(B)))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. B in BOOLEAN
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. not(not(A) and not(B))
#     core type: Operation
#     operator: 25
#     operand: 19
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 28, 18
# 17. (not(A) and not(B))
#     core type: ExprTuple
#     sub-expressions: 19
# 18. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 19. not(A) and not(B)
#     core type: Operation
#     operator: 20
#     operands: 21
# 20. and
#     core type: Literal
#     sub-expressions:
# 21. (not(A), not(B))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 22. not(A)
#     core type: Operation
#     operator: 25
#     operand: 27
# 23. not(B)
#     core type: Operation
#     operator: 25
#     operand: 28
# 24. (A)
#     core type: ExprTuple
#     sub-expressions: 27
# 25. not
#     core type: Literal
#     sub-expressions:
# 26. (B)
#     core type: ExprTuple
#     sub-expressions: 28
# 27. A
#     core type: Variable
#     sub-expressions:
# 28. B
#     core type: Variable
#     sub-expressions:
