# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#binary_closure">binary_closure</a> theorem
# ========

# %%
import proveit
# we need to import false_or_false_negated to derive it's side-effects:
from proveit.logic.booleans.disjunction import \
    (true_or_true, false_or_true, true_or_false, false_or_false_negated)
theory = proveit.Theory() # the theorem's theory

# %%
# %proving binary_closure
# Out:
# binary_closure: forall_{A, B in BOOLEAN} ((A or B) in BOOLEAN)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{A, B in BOOLEAN} ((A or B) in BOOLEAN)
# 1	instantiation	3, 4, 5, 6	|- [forall_{A in BOOLEAN} [forall_{B in BOOLEAN} ((A or B) in BOOLEAN)]] => [forall_{A, B in BOOLEAN} ((A or B) in BOOLEAN)]
# 	m : 1, n : 1, P(A, B) : (A or B) in BOOLEAN, Q(A) : A in BOOLEAN, R(A, B) : B in BOOLEAN, (x_{1}, ..x_{_a}.., x_{1}) : (A), (y_{1}, ..y_{_a}.., y_{1}) : (B)
# 2	instantiation	12, 7, 8	|- forall_{A in BOOLEAN} [forall_{B in BOOLEAN} ((A or B) in BOOLEAN)]
# 	P(A) : forall_{B in BOOLEAN} ((A or B) in BOOLEAN), A : A
# 3	conjecture		|- forall_{m, n in NaturalPos} [forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]] \\  => [forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})])]
# 4	instantiation	9	|- |(A)| = |(1, ..k.., 1)|
# 	a : A
# 5	instantiation	9	|- |(B)| = |(1, ..k.., 1)|
# 	a : B
# 6	conjecture		|- 1 in NaturalPos
# 7	instantiation	12, 10, 11	|- forall_{B in BOOLEAN} ((TRUE or B) in BOOLEAN)
# 	P(B) : (TRUE or B) in BOOLEAN, A : B
# 8	instantiation	12, 13, 14	|- forall_{B in BOOLEAN} ((FALSE or B) in BOOLEAN)
# 	P(B) : (FALSE or B) in BOOLEAN, A : B
# 9	conjecture		|- forall_{a} (|(a)| = |(1, ..k.., 1)|)
# 10	instantiation	20, 21, 15	|- (TRUE or TRUE) in BOOLEAN
# 	P(_a) : _a in BOOLEAN, x : TRUE or TRUE
# 11	instantiation	20, 21, 16	|- (TRUE or FALSE) in BOOLEAN
# 	P(_a) : _a in BOOLEAN, x : TRUE or FALSE
# 12	conjecture		|- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEAN} P(A)]
# 13	instantiation	20, 21, 17	|- (FALSE or TRUE) in BOOLEAN
# 	P(_a) : _a in BOOLEAN, x : FALSE or TRUE
# 14	instantiation	18, 19	|- (FALSE or FALSE) in BOOLEAN
# 	A : FALSE or FALSE
# 15	theorem		|- TRUE or TRUE
# 	proveit.logic.booleans.disjunction.true_or_true
# 16	theorem		|- TRUE or FALSE
# 	proveit.logic.booleans.disjunction.true_or_false
# 17	theorem		|- FALSE or TRUE
# 	proveit.logic.booleans.disjunction.false_or_true
# 18	axiom		|- forall_{A | not(A) in BOOLEAN} (A in BOOLEAN)
# 	proveit.logic.booleans.negation.operand_is_bool
# 19	instantiation	20, 21, 22	|- not(FALSE or FALSE) in BOOLEAN
# 	P(_a) : _a in BOOLEAN, x : not(FALSE or FALSE)
# 20	conjecture		|- forall_{P, x | P(TRUE), x} P(x)
# 21	conjecture		|- TRUE in BOOLEAN
# 22	theorem		|- not(FALSE or FALSE)
# 	proveit.logic.booleans.disjunction.false_or_false_negated
