# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#demorgans_law_and_to_or_bin_explicit">demorgans_law_and_to_or_bin_explicit</a> theorem
# ========

# %%
import proveit
from proveit.logic.booleans import fold_forall_over_bool, fold_conditioned_forall_over_bool
theory = proveit.Theory() # the theorem's theory

# %%
# %proving demorgans_law_and_to_or_bin_explicit
# Out:
# demorgans_law_and_to_or_bin_explicit: forall_{A, B in BOOLEAN | not(not(A) and not(B))} (A or B)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{A, B in BOOLEAN | not(not(A) and not(B))} (A or B)
# 1	instantiation	3, 4, 5, 6, 7*	|- [forall_{A in BOOLEAN} [forall_{B in BOOLEAN | not(not(A) and not(B))} (A or B)]] => [forall_{A, B in BOOLEAN | not(not(A) and not(B))} (A or B)]
# 	m : 1, n : 1, P(A, B) : A or B, Q(A) : A in BOOLEAN, R(A, B) : (B in BOOLEAN) and not(not(A) and not(B)), (x_{1}, ..x_{_a}.., x_{1}) : (A), (y_{1}, ..y_{_a}.., y_{1}) : (B)
# 2	instantiation	8, 9, 10	|- forall_{A in BOOLEAN} [forall_{B in BOOLEAN | not(not(A) and not(B))} (A or B)]
# 	P(A) : forall_{B in BOOLEAN | not(not(A) and not(B))} (A or B), A : A
# 3	conjecture		|- forall_{m, n in NaturalPos} [forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]] \\  => [forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})])]
# 4	instantiation	11	|- |(A)| = |(1, ..k.., 1)|
# 	a : A
# 5	instantiation	11	|- |(B)| = |(1, ..k.., 1)|
# 	a : B
# 6	conjecture		|- 1 in NaturalPos
# 7	instantiation	12, 13, 14	|- {A or B if A in BOOLEAN ,  (B in BOOLEAN) and not(not(A) and not(B)). = {A or B if A in BOOLEAN ,  B in BOOLEAN ,  not(not(A) and not(B)).
# 	n : 2, a : A or B, Q : A in BOOLEAN, R : (B in BOOLEAN, not(not(A) and not(B)))
# 8	conjecture		|- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEAN} P(A)]
# 9	instantiation	17, 15, 16	|- forall_{B in BOOLEAN | not(not(TRUE) and not(B))} (TRUE or B)
# 	P(B) : TRUE or B, Q(B) : not(not(TRUE) and not(B)), A : B
# 10	instantiation	17, 18, 19	|- forall_{B in BOOLEAN | not(not(FALSE) and not(B))} (FALSE or B)
# 	P(B) : FALSE or B, Q(B) : not(not(FALSE) and not(B)), A : B
# 11	conjecture		|- forall_{a} (|(a)| = |(1, ..k.., 1)|)
# 12	conjecture		|- forall_{n in Natural} [forall_{a, Q, R_{1}, ..R_{_a}.., R_{n}} ({a if Q ,  R_{1} and ..R_{_a}.. and R_{n}. \\  = {a if Q ,  R_{1} ,  ..R_{_a}.. ,  R_{n}.)]
# 13	instantiation	20, 21, 22	|- 2 in Natural
# 	A : NaturalPos, B : Natural, x : 2
# 14	instantiation	23	|- |(B in BOOLEAN, not(not(A) and not(B)))| = |(1, ..k.., 2)|
# 	a : B in BOOLEAN, b : not(not(A) and not(B))
# 15	deduction	24	|- not(not(TRUE) and not(TRUE)) => (TRUE or TRUE)
# 16	deduction	25	|- not(not(TRUE) and not(FALSE)) => (TRUE or FALSE)
# 17	conjecture		|- forall_{P, Q | Q(TRUE) => P(TRUE), Q(FALSE) => P(FALSE)} [forall_{A in BOOLEAN | Q(A)} P(A)]
# 18	deduction	26	|- not(not(FALSE) and not(TRUE)) => (FALSE or TRUE)
# 19	instantiation	27, 28	|- not(not(FALSE) and not(FALSE)) => (FALSE or FALSE)
# 	A : not(not(FALSE) and not(FALSE)), B : FALSE or FALSE
# 20	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 21	conjecture		|- NaturalPos proper_subset Natural
# 22	conjecture		|- 2 in NaturalPos
# 23	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..k.., 2)|)
# 24	instantiation	31, 29	|- TRUE or TRUE
# 	A : TRUE or TRUE
# 25	instantiation	31, 30	|- TRUE or FALSE
# 	A : TRUE or FALSE
# 26	instantiation	31, 32	|- FALSE or TRUE
# 	A : FALSE or TRUE
# 27	theorem		|- forall_{A, B | not(A)} (A => B)
# 	proveit.logic.booleans.implication.falsified_antecedent_implication
# 28	instantiation	33, 34	|- not(not(not(FALSE) and not(FALSE)))
# 	A : not(FALSE) and not(FALSE)
# 29	axiom		|- (TRUE or TRUE) = TRUE
# 	proveit.logic.booleans.disjunction.or_t_t
# 30	axiom		|- (TRUE or FALSE) = TRUE
# 	proveit.logic.booleans.disjunction.or_t_f
# 31	axiom		|- forall_{A | A = TRUE} A
# 	proveit.logic.booleans.eq_true_elim
# 32	axiom		|- (FALSE or TRUE) = TRUE
# 	proveit.logic.booleans.disjunction.or_f_t
# 33	conjecture		|- forall_{A | A} not(not(A))
# 34	theorem		|- not(FALSE)
# 	proveit.logic.booleans.negation.not_false
