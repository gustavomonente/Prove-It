# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda
from proveit.core_expr_types import P__x_1_to_m_y_1_to_n, Q__x_1_to_m, R__x_1_to_m_y_1_to_n, x_1_to_m, y_1_to_n
from proveit.logic import And

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([x_1_to_m, y_1_to_n], Conditional(P__x_1_to_m_y_1_to_n, And(Q__x_1_to_m, R__x_1_to_m_y_1_to_n))))
# Out:
# expr: ((x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) -> {P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) if Q(x_{1}, ..x_{_a}.., x_{m}) ,  R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}).)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(x_{1}, \ldots, x_{m}, y_{1}, \ldots, y_{n}\right) \mapsto \left\{P(x_{1}, \ldots, x_{m}, y_{1}, \ldots, y_{n}) \textrm{ if } Q(x_{1}, \ldots, x_{m}) ,  R(x_{1}, \ldots, x_{m}, y_{1}, \ldots, y_{n})\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) -> {P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) if Q(x_{1}, ..x_{_a}.., x_{m}) ,  R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) -> {P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) if Q(x_{1}, ..x_{_a}.., x_{m}) ,  R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}).
#    core type: Lambda
#    parameters: 13\n   body: 2
# 2. {P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) if Q(x_{1}, ..x_{_a}.., x_{m}) ,  R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 5
#    operands: 13
# 4. Q(x_{1}, ..x_{_a}.., x_{m}) and R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. P
#    core type: Variable
#    sub-expressions:
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. Q(x_{1}, ..x_{_a}.., x_{m})
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. Q
#     core type: Variable
#     sub-expressions:
# 11. (x_{1}, ..x_{_a}.., x_{m})
#     core type: ExprTuple
#     sub-expressions: 14
# 12. R
#     core type: Variable
#     sub-expressions:
# 13. (x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. x_{1}, ..x_{_a}.., x_{m}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 19
#     end_index: 17
# 15. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 19
#     end_index: 20
# 16. _a -> x_{_a}
#     core type: Lambda
#     parameter: 26
#     body: 21
# 17. m
#     core type: Variable
#     sub-expressions:
# 18. _a -> y_{_a}
#     core type: Lambda
#     parameter: 26
#     body: 22
# 19. 1
#     core type: Literal
#     sub-expressions:
# 20. n
#     core type: Variable
#     sub-expressions:
# 21. x_{_a}
#     core type: IndexedVar
# variable: 23
# index: 26
# 22. y_{_a}
#     core type: IndexedVar
# variable: 24
# index: 26
# 23. x
#     core type: Variable
#     sub-expressions:
# 24. y
#     core type: Variable
#     sub-expressions:
# 25. (_a)
#     core type: ExprTuple
#     sub-expressions: 26
# 26. _a
#     core type: Variable
#     sub-expressions:
