# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#general_exists_Px_st_Qx">general_exists_Px_st_Qx</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Exists.html">Exists</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.quantification import general_exists_Px_st_Qx

# %%
# check that the built expression is the same as the stored expression
assert general_exists_Px_st_Qx == stored_expr
assert general_exists_Px_st_Qx._style_id == stored_expr._style_id
print("Passed sanity check: general_exists_Px_st_Qx matches stored_expr")
# Out:
# Passed sanity check: general_exists_Px_st_Qx matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(general_exists_Px_st_Qx.latex())
# Out:
# \exists_{x_{1}, \ldots, x_{n}~|~Q(x_{1}, \ldots, x_{n})}~P(x_{1}, \ldots, x_{n})

# %%
general_exists_Px_st_Qx.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
general_exists_Px_st_Qx.expr_info()
# Out:
# 0. exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. exists
#    core type: Literal
#    sub-expressions:
# 2. ((x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#    core type: Lambda
#    parameters: 9\n   body: 4
# 4. {P(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 7
#    operands: 9
# 6. Q(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. P
#    core type: Variable
#    sub-expressions:
# 8. Q
#    core type: Variable
#    sub-expressions:
# 9. (x_{1}, ..x_{_a}.., x_{n})
#    core type: ExprTuple
# ...
