# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#general_exists_in_B_Py">general_exists_in_B_Py</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Exists.html">Exists</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.quantification import general_exists_in_B_Py

# %%
# check that the built expression is the same as the stored expression
assert general_exists_in_B_Py == stored_expr
assert general_exists_in_B_Py._style_id == stored_expr._style_id
print("Passed sanity check: general_exists_in_B_Py matches stored_expr")
# Out:
# Passed sanity check: general_exists_in_B_Py matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(general_exists_in_B_Py.latex())
# Out:
# \exists_{y_{1}, \ldots, y_{n} \in B}~P(y_{1}, \ldots, y_{n})

# %%
general_exists_in_B_Py.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
general_exists_in_B_Py.expr_info()
# Out:
# 0. exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. exists
#    core type: Literal
#    sub-expressions:
# 2. ((y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if (y_{1} in B) and ..(y_{_a} in B).. and (y_{n} in B).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if (y_{1} in B) and ..(y_{_a} in B).. and (y_{n} in B).
#    core type: Lambda
#    parameters: 8\n   body: 4
# 4. {P(y_{1}, ..y_{_a}.., y_{n}) if (y_{1} in B) and ..(y_{_a} in B).. and (y_{n} in B).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. P(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (y_{1} in B) and ..(y_{_a} in B).. and (y_{n} in B)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. P
#    core type: Variable
#    sub-expressions:
# 8. (y_{1}, ..y_{_a}.., y_{n})
# ...
