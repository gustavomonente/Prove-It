# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.universality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda, P
from proveit.logic import Boolean, InSet
from proveit.logic.booleans.quantification import general_forall_Px

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(P, InSet(general_forall_Px, Boolean)))
# Out:
# expr: (P -> ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(P \mapsto \left(\left[\forall_{x_{1}, \ldots, x_{n}}~P(x_{1}, \ldots, x_{n})\right] \in \mathbb{B}\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (P -> ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. P -> ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN)
#    core type: Lambda
#    parameter: 11
#    body: 2
# 2. [forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. in
#    core type: Literal
#    sub-expressions:
# 4. (forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n}), BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 7
#    operand: 9
# 6. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((x_{1}, ..x_{_a}.., x_{n}) -> P(x_{1}, ..x_{_a}.., x_{n}))
#    core type: ExprTuple
#    sub-expressions: 9
# 9. (x_{1}, ..x_{_a}.., x_{n}) -> P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Lambda
#    parameters: 12\n   body: 10
# 10. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. P
#     core type: Variable
#     sub-expressions:
# 12. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 13
# 13. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 15
#     end_index: 16
# 14. _a -> x_{_a}
#     core type: Lambda
#     parameter: 20
#     body: 17
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. n
#     core type: Variable
#     sub-expressions:
# 17. x_{_a}
#     core type: IndexedVar
# variable: 18
# index: 20
# 18. x
#     core type: Variable
#     sub-expressions:
# 19. (_a)
#     core type: ExprTuple
#     sub-expressions: 20
# 20. _a
#     core type: Variable
#     sub-expressions:
