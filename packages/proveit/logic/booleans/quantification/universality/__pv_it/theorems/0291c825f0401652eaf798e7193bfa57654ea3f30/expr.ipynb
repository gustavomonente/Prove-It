# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.universality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Function, P, n
from proveit.core_expr_types import P__x_1_to_n, P__x_1_to_np1, x_1_to_n, x_1_to_np1
from proveit.logic import And, Forall, Implies
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = And(Function(P, []), Forall([n], Implies(Forall([x_1_to_n], P__x_1_to_n), Forall([x_1_to_np1], P__x_1_to_np1)).with_wrapping_at(2), domains = [Natural]))
# Out:
# expr: P() and [forall_{n in Natural} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})])]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# P() \land \left[\forall_{n \in \mathbb{N}}~\left(\begin{array}{c} \begin{array}{l} \left[\forall_{x_{1}, \ldots, x_{n}}~P(x_{1}, \ldots, x_{n})\right] \Rightarrow  \\ \left[\forall_{x_{1}, \ldots, x_{n + 1}}~P(x_{1}, \ldots, x_{n + 1})\right] \end{array} \end{array}\right)\right]

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. P() and [forall_{n in Natural} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})])]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (P(), forall_{n in Natural} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})]))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. P()
#    core type: Operation
#    operator: 26
#    operands: 5
# 4. forall_{n in Natural} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})])
#    core type: Operation
#    operator: 19
#    operand: 7
# 5. ()
#    core type: ExprTuple
#    sub-expressions:
# 6. (n -> {[forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})] if n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 7
# 7. n -> {[forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})] if n in Natural.
#    core type: Lambda
#    parameter: 37
#    body: 8
# 8. {[forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})] if n in Natural.
#    core type: Conditional
#    value: 9
#    condition: 10
# 9. [forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})]
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. n in Natural
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. =>
#     core type: Literal
#     sub-expressions:
# 12. (forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n}), forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1}))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 37, 17
# 15. forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 19
#     operand: 21
# 16. forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})
#     core type: Operation
#     operator: 19
#     operand: 22
# 17. Natural
#     core type: Literal
#     sub-expressions:
# 18. ((x_{1}, ..x_{_a}.., x_{n}) -> P(x_{1}, ..x_{_a}.., x_{n}))
#     core type: ExprTuple
#     sub-expressions: 21
# 19. forall
#     core type: Literal
#     sub-expressions:
# 20. ((x_{1}, ..x_{_a}.., x_{n + 1}) -> P(x_{1}, ..x_{_a}.., x_{n + 1}))
#     core type: ExprTuple
#     sub-expressions: 22
# 21. (x_{1}, ..x_{_a}.., x_{n}) -> P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Lambda
#     parameters: 25\n    body: 23
# 22. (x_{1}, ..x_{_a}.., x_{n + 1}) -> P(x_{1}, ..x_{_a}.., x_{n + 1})
#     core type: Lambda
#     parameters: 27\n    body: 24
# 23. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 26
#     operands: 25
# 24. P(x_{1}, ..x_{_a}.., x_{n + 1})
#     core type: Operation
#     operator: 26
#     operands: 27
# 25. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 28
# 26. P
#     core type: Variable
#     sub-expressions:
# 27. (x_{1}, ..x_{_a}.., x_{n + 1})
#     core type: ExprTuple
#     sub-expressions: 29
# 28. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 38
#     end_index: 37
# 29. x_{1}, ..x_{_a}.., x_{n + 1}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 38
#     end_index: 31
# 30. _a -> x_{_a}
#     core type: Lambda
#     parameter: 39
#     body: 32
# 31. n + 1
#     core type: Operation
#     operator: 33
#     operands: 34
# 32. x_{_a}
#     core type: IndexedVar
# variable: 35
# index: 39
# 33. +
#     core type: Literal
#     sub-expressions:
# 34. (n, 1)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 35. x
#     core type: Variable
#     sub-expressions:
# 36. (_a)
#     core type: ExprTuple
#     sub-expressions: 39
# 37. n
#     core type: Variable
#     sub-expressions:
# 38. 1
#     core type: Literal
#     sub-expressions:
# 39. _a
#     core type: Variable
#     sub-expressions:
