# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.universality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Function, P, n
from proveit.core_expr_types import P__x_1_to_n, P__x_1_to_np1, x_1_to_n, x_1_to_np1
from proveit.logic import And, Forall, Implies
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
sub_expr1 = [n]
sub_expr2 = [Natural]
sub_expr3 = Forall([x_1_to_n], P__x_1_to_n)
expr = ExprTuple(And(Function(P, []), Forall(sub_expr1, Implies(sub_expr3, Forall([x_1_to_np1], P__x_1_to_np1)).with_wrapping_at(2), domains = sub_expr2)), Forall(sub_expr1, sub_expr3, domains = sub_expr2))
# Out:
# expr: (P() and [forall_{n in Natural} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})])], forall_{n in Natural} [forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})])

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(P() \land \left[\forall_{n \in \mathbb{N}}~\left(\begin{array}{c} \begin{array}{l} \left[\forall_{x_{1}, \ldots, x_{n}}~P(x_{1}, \ldots, x_{n})\right] \Rightarrow  \\ \left[\forall_{x_{1}, \ldots, x_{n + 1}}~P(x_{1}, \ldots, x_{n + 1})\right] \end{array} \end{array}\right)\right], \forall_{n \in \mathbb{N}}~\left[\forall_{x_{1}, \ldots, x_{n}}~P(x_{1}, \ldots, x_{n})\right]\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (P() and [forall_{n in Natural} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})])], forall_{n in Natural} [forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})])
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. P() and [forall_{n in Natural} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})])]
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. forall_{n in Natural} [forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})]
#    core type: Operation
#    operator: 24
#    operand: 8
# 3. and
#    core type: Literal
#    sub-expressions:
# 4. (P(), forall_{n in Natural} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})]))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (n -> {forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n}) if n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. P()
#    core type: Operation
#    operator: 31
#    operands: 9
# 7. forall_{n in Natural} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})])
#    core type: Operation
#    operator: 24
#    operand: 12
# 8. n -> {forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n}) if n in Natural.
#    core type: Lambda
#    parameter: 42
#    body: 11
# 9. ()
#    core type: ExprTuple
#    sub-expressions:
# 10. (n -> {[forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})] if n in Natural.)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. {forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n}) if n in Natural.
#     core type: Conditional
#     value: 20
#     condition: 15
# 12. n -> {[forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})] if n in Natural.
#     core type: Lambda
#     parameter: 42
#     body: 13
# 13. {[forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})] if n in Natural.
#     core type: Conditional
#     value: 14
#     condition: 15
# 14. [forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})]
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. n in Natural
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. =>
#     core type: Literal
#     sub-expressions:
# 17. (forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n}), forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1}))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 42, 22
# 20. forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 24
#     operand: 26
# 21. forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})
#     core type: Operation
#     operator: 24
#     operand: 27
# 22. Natural
#     core type: Literal
#     sub-expressions:
# 23. ((x_{1}, ..x_{_a}.., x_{n}) -> P(x_{1}, ..x_{_a}.., x_{n}))
#     core type: ExprTuple
#     sub-expressions: 26
# 24. forall
#     core type: Literal
#     sub-expressions:
# 25. ((x_{1}, ..x_{_a}.., x_{n + 1}) -> P(x_{1}, ..x_{_a}.., x_{n + 1}))
#     core type: ExprTuple
#     sub-expressions: 27
# 26. (x_{1}, ..x_{_a}.., x_{n}) -> P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Lambda
#     parameters: 30\n    body: 28
# 27. (x_{1}, ..x_{_a}.., x_{n + 1}) -> P(x_{1}, ..x_{_a}.., x_{n + 1})
#     core type: Lambda
#     parameters: 32\n    body: 29
# 28. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 31
#     operands: 30
# 29. P(x_{1}, ..x_{_a}.., x_{n + 1})
#     core type: Operation
#     operator: 31
#     operands: 32
# 30. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 33
# 31. P
#     core type: Variable
#     sub-expressions:
# 32. (x_{1}, ..x_{_a}.., x_{n + 1})
#     core type: ExprTuple
#     sub-expressions: 34
# 33. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 43
#     end_index: 42
# 34. x_{1}, ..x_{_a}.., x_{n + 1}
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 43
#     end_index: 36
# 35. _a -> x_{_a}
#     core type: Lambda
#     parameter: 44
#     body: 37
# 36. n + 1
#     core type: Operation
#     operator: 38
#     operands: 39
# 37. x_{_a}
#     core type: IndexedVar
# variable: 40
# index: 44
# 38. +
#     core type: Literal
#     sub-expressions:
# 39. (n, 1)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 40. x
#     core type: Variable
#     sub-expressions:
# 41. (_a)
#     core type: ExprTuple
#     sub-expressions: 44
# 42. n
#     core type: Variable
#     sub-expressions:
# 43. 1
#     core type: Literal
#     sub-expressions:
# 44. _a
#     core type: Variable
#     sub-expressions:
