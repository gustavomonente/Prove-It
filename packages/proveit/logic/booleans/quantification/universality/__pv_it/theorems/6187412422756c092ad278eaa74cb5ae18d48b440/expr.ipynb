# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.universality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import P, Q
from proveit.logic import Boolean, Forall, InSet
from proveit.logic.booleans.quantification import general_forall_Px_if_Qx

# %%
# build up the expression from sub-expressions
expr = Forall([P, Q], InSet(general_forall_Px_if_Qx, Boolean))
# Out:
# expr: forall_{P, Q} ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{P, Q}~\left(\left[\forall_{x_{1}, \ldots, x_{n}~|~Q(x_{1}, \ldots, x_{n})}~P(x_{1}, \ldots, x_{n})\right] \in \mathbb{B}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{P, Q} ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN)
#    core type: Operation
#    operator: 9
#    operand: 2
# 1. ((P, Q) -> ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN))
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (P, Q) -> ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN)
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (P, Q)
#    core type: ExprTuple
#    sub-expressions: 15, 16
# 4. [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n}), BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 9
#    operand: 11
# 8. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. ((x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).)
#     core type: ExprTuple
#     sub-expressions: 11
# 11. (x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#     core type: Lambda
#     parameters: 17\n    body: 12
# 12. {P(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#     core type: Conditional
#     value: 13
#     condition: 14
# 13. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 15
#     operands: 17
# 14. Q(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. P
#     core type: Variable
#     sub-expressions:
# 16. Q
#     core type: Variable
#     sub-expressions:
# 17. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 18
# 18. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 20
#     end_index: 21
# 19. _a -> x_{_a}
#     core type: Lambda
#     parameter: 25
#     body: 22
# 20. 1
#     core type: Literal
#     sub-expressions:
# 21. n
#     core type: Variable
#     sub-expressions:
# 22. x_{_a}
#     core type: IndexedVar
# variable: 23
# index: 25
# 23. x
#     core type: Variable
#     sub-expressions:
# 24. (_a)
#     core type: ExprTuple
#     sub-expressions: 25
# 25. _a
#     core type: Variable
#     sub-expressions:
