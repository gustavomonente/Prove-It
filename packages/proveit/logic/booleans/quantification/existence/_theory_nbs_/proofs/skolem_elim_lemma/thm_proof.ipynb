# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantification</a>.<a class="ProveItLink" href="../../theory.ipynb">existence</a>.<a class="ProveItLink" href="../../theorems.ipynb#skolem_elim_lemma">skolem_elim_lemma</a> theorem
# ========

# %%
import proveit
from proveit import alpha
from proveit.core_expr_types import x_1_to_n, Q__x_1_to_n, P__x_1_to_n
from proveit.logic import Not, Equals, TRUE, NotEquals
from proveit import defaults
theory = proveit.Theory() # the theorem's theory

# %%
# %proving skolem_elim_lemma
# Out:
# skolem_elim_lemma: forall_{n in NaturalPos, alpha in BOOLEAN} [forall_{P, Q} (([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha)]

# %%
antecedent = skolem_elim_lemma.instance_expr.instance_expr.antecedent
# Out:
# antecedent: [exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]

# %%
main_assumptions = (*skolem_elim_lemma.conditions.entries, antecedent)
# Out:
# main_assumptions: (n in NaturalPos, alpha in BOOLEAN, [exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)])

# %% [markdown]
# ### This is be a proof by contradiction

# %%
defaults.assumptions = (*main_assumptions, Not(alpha))
# Out:
# defaults.assumptions: (n in NaturalPos, alpha in BOOLEAN, [exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)], not(alpha))

# %%
existential, universal = antecedent.derive_left(), antecedent.derive_right()
# Out:
# existential: {[exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]} |- exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})
# universal: {[exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]} |- forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)

# %%
unfolded_existential = existential.unfold()
# Out:
# unfolded_existential: {[exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)], n in NaturalPos} |- not(forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE))

# %%
alpha_under_assumptions = universal.instantiate(assumptions=[Q__x_1_to_n]).derive_consequent(
    assumptions=[Equals(P__x_1_to_n, TRUE)])
# Out:
# alpha_under_assumptions: {P(x_{1}, ..x_{_a}.., x_{n}) = TRUE, [exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)], Q(x_{1}, ..x_{_a}.., x_{n})} |- alpha

# %%
contradiction = Not(alpha).derive_contradiction([*defaults.assumptions, Q__x_1_to_n, Equals(P__x_1_to_n, TRUE)])
# Out:
# contradiction: {P(x_{1}, ..x_{_a}.., x_{n}) = TRUE, [exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)], Q(x_{1}, ..x_{_a}.., x_{n}), not(alpha)} |- FALSE

# %%
contradiction.deny_assumption(Equals(P__x_1_to_n, TRUE))
# Out:
# {[exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)], Q(x_{1}, ..x_{_a}.., x_{n}), not(alpha)} |- not(P(x_{1}, ..x_{_a}.., x_{n}) = TRUE)

# %%
P_neq_T = NotEquals(P__x_1_to_n, TRUE).prove([*defaults.assumptions, Q__x_1_to_n])
# Out:
# P_neq_T: {[exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)], Q(x_{1}, ..x_{_a}.., x_{n}), not(alpha)} |- P(x_{1}, ..x_{_a}.., x_{n}) != TRUE

# %%
P_neq_T.generalize(x_1_to_n, conditions=[Q__x_1_to_n])
# Out:
# {[exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)], not(alpha)} |- forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) != TRUE)

# %%
unfolded_existential.affirm_via_contradiction(alpha, assumptions=main_assumptions)
# Out:
# {alpha in BOOLEAN, [exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)], n in NaturalPos} |- alpha

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{n in NaturalPos, alpha in BOOLEAN} [forall_{P, Q} (([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha)]
# 1	deduction	2	{alpha in BOOLEAN, n in NaturalPos} |- ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha
# 2	instantiation	3, 4, 5	{alpha in BOOLEAN, [exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)], n in NaturalPos} |- alpha
# 	A : alpha
# 3	axiom		|- forall_{A in BOOLEAN | not(A) => FALSE} A
# 	proveit.logic.booleans.implication.affirmation_via_contradiction
# 4	assumption		{alpha in BOOLEAN} |- alpha in BOOLEAN
# 5	deduction	6	{[exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)], n in NaturalPos} |- not(alpha) => FALSE
# 6	instantiation	29, 7, 8	{[exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)], not(alpha), n in NaturalPos} |- FALSE
# 	A : forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE)
# 7	generalizaton	9	{[exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)], not(alpha)} |- forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) != TRUE)
# 8	modus ponens	10, 11	{[exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)], n in NaturalPos} |- not(forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE))
# 9	instantiation	12, 13	{[exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)], Q(x_{1}, ..x_{_a}.., x_{n}), not(alpha)} |- P(x_{1}, ..x_{_a}.., x_{n}) != TRUE
# 	x : P(x_{1}, ..x_{_a}.., x_{n}), y : TRUE
# 10	instantiation	14, 28, 15, 16	{n in NaturalPos} |- [exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ not(forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE))
# 	n : n, P(y_{1}, ..y_{_a}.., y_{n}) : P(y_{1}, ..y_{_a}.., y_{n}), Q(y_{1}, ..y_{_a}.., y_{n}) : Q(y_{1}, ..y_{_a}.., y_{n})
# 11	instantiation	17, 39	{[exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]} |- exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})
# 	A : exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n}), B : forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)
# 12	conjecture		|- forall_{x, y | not(x = y)} (x != y)
# 13	instantiation	18, 19, 20, 21	{[exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)], Q(x_{1}, ..x_{_a}.., x_{n}), not(alpha)} |- not(P(x_{1}, ..x_{_a}.., x_{n}) = TRUE)
# 	A : P(x_{1}, ..x_{_a}.., x_{n}) = TRUE, B : FALSE
# 14	conjecture		|- forall_{n in NaturalPos} [forall_{P, Q} ([exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ not(forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE)))]
# 15	instantiation	22, 23	{n in NaturalPos} |- |(x_{1}, ..x_{a}.., x_{n})| = |(1, ..k.., n)|
# 	i : n, f(_a) : x_{_a}
# 16	instantiation	22, 23	{n in NaturalPos} |- |(y_{1}, ..y_{a}.., y_{n})| = |(1, ..k.., n)|
# 	i : n, f(_a) : y_{_a}
# 17	theorem		|- forall_{A, B | A, B} A
# 	proveit.logic.booleans.conjunction.left_from_and
# 18	theorem		|- forall_{A in BOOLEAN} [forall_{B | A => B, not(B)} not(A)]
# 	proveit.logic.booleans.implication.modus_tollens_denial
# 19	instantiation	24	|- (P(x_{1}, ..x_{_a}.., x_{n}) = TRUE) in BOOLEAN
# 	x : P(x_{1}, ..x_{_a}.., x_{n}), y : TRUE
# 20	deduction	25	{[exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)], Q(x_{1}, ..x_{_a}.., x_{n}), not(alpha)} |- (P(x_{1}, ..x_{_a}.., x_{n}) = TRUE) => FALSE
# 21	theorem		|- not(FALSE)
# 	proveit.logic.booleans.negation.not_false
# 22	conjecture		|- forall_{i in Natural} [forall_{f} (|(f(1), ..f(a).., f(i))| = |(1, ..k.., i)|)]
# 23	instantiation	26, 27, 28	{n in NaturalPos} |- n in Natural
# 	A : NaturalPos, B : Natural, x : n
# 24	axiom		|- forall_{x, y} ((x = y) in BOOLEAN)
# 	proveit.logic.equality.equality_in_bool
# 25	instantiation	29, 30, 31	{P(x_{1}, ..x_{_a}.., x_{n}) = TRUE, [exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)], Q(x_{1}, ..x_{_a}.., x_{n}), not(alpha)} |- FALSE
# 	A : alpha
# 26	conjecture		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 27	conjecture		|- NaturalPos proper_subset Natural
# 28	assumption		{n in NaturalPos} |- n in NaturalPos
# 29	theorem		|- forall_{A | A, not(A)} FALSE
# 	proveit.logic.booleans.negation.negation_contradiction
# 30	modus ponens	32, 33	{P(x_{1}, ..x_{_a}.., x_{n}) = TRUE, [exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)], Q(x_{1}, ..x_{_a}.., x_{n})} |- alpha
# 31	assumption		{not(alpha)} |- not(alpha)
# 32	instantiation	34, 35	{[exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)], Q(x_{1}, ..x_{_a}.., x_{n})} |- P(x_{1}, ..x_{_a}.., x_{n}) => alpha
# 	x : x
# 33	instantiation	36, 37	{P(x_{1}, ..x_{_a}.., x_{n}) = TRUE} |- P(x_{1}, ..x_{_a}.., x_{n})
# 	A : P(x_{1}, ..x_{_a}.., x_{n})
# 34	instantiation	38, 39	{[exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]} |- forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)
# 	A : exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n}), B : forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)
# 35	assumption		{Q(x_{1}, ..x_{_a}.., x_{n})} |- Q(x_{1}, ..x_{_a}.., x_{n})
# 36	axiom		|- forall_{A | A = TRUE} A
# 	proveit.logic.booleans.eq_true_elim
# 37	assumption		{P(x_{1}, ..x_{_a}.., x_{n}) = TRUE} |- P(x_{1}, ..x_{_a}.., x_{n}) = TRUE
# 38	theorem		|- forall_{A, B | A, B} B
# 	proveit.logic.booleans.conjunction.right_from_and
# 39	assumption		{[exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]} |- [exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]
