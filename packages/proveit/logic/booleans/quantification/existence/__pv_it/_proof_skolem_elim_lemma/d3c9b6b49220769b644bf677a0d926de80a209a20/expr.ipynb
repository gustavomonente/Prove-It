# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.core_expr_types import P__x_1_to_n, Q__x_1_to_n, x_1_to_n
from proveit.logic import Forall, NotEquals, TRUE

# %%
# build up the expression from sub-expressions
expr = Forall([x_1_to_n], NotEquals(P__x_1_to_n, TRUE), condition = Q__x_1_to_n)
# Out:
# expr: forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) != TRUE)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x_{1}, \ldots, x_{n}~|~Q(x_{1}, \ldots, x_{n})}~\left(P(x_{1}, \ldots, x_{n}) \neq \top\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) != TRUE)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) != TRUE if Q(x_{1}, ..x_{_a}.., x_{n}).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) != TRUE if Q(x_{1}, ..x_{_a}.., x_{n}).
#    core type: Lambda
#    parameters: 13\n   body: 4
# 4. {P(x_{1}, ..x_{_a}.., x_{n}) != TRUE if Q(x_{1}, ..x_{_a}.., x_{n}).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. P(x_{1}, ..x_{_a}.., x_{n}) != TRUE
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. Q(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 9
#    operands: 13
# 7. !=
#    core type: Literal
#    sub-expressions:
# 8. (P(x_{1}, ..x_{_a}.., x_{n}), TRUE)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. Q
#    core type: Variable
#    sub-expressions:
# 10. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. TRUE
#     core type: Literal
#     sub-expressions:
# 12. P
#     core type: Variable
#     sub-expressions:
# 13. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 14
# 14. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 16
#     end_index: 17
# 15. _a -> x_{_a}
#     core type: Lambda
#     parameter: 21
#     body: 18
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. n
#     core type: Variable
#     sub-expressions:
# 18. x_{_a}
#     core type: IndexedVar
# variable: 19
# index: 21
# 19. x
#     core type: Variable
#     sub-expressions:
# 20. (_a)
#     core type: ExprTuple
#     sub-expressions: 21
# 21. _a
#     core type: Variable
#     sub-expressions:
