# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda
from proveit.core_expr_types import P__x_1_to_n, Q__x_1_to_n, x_1_to_n
from proveit.logic import NotEquals, TRUE

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([x_1_to_n], Conditional(NotEquals(P__x_1_to_n, TRUE), Q__x_1_to_n)))
# Out:
# expr: ((x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) != TRUE if Q(x_{1}, ..x_{_a}.., x_{n}).)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(x_{1}, \ldots, x_{n}\right) \mapsto \left\{P(x_{1}, \ldots, x_{n}) \neq \top \textrm{ if } Q(x_{1}, \ldots, x_{n})\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) != TRUE if Q(x_{1}, ..x_{_a}.., x_{n}).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) != TRUE if Q(x_{1}, ..x_{_a}.., x_{n}).
#    core type: Lambda
#    parameters: 11\n   body: 2
# 2. {P(x_{1}, ..x_{_a}.., x_{n}) != TRUE if Q(x_{1}, ..x_{_a}.., x_{n}).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. P(x_{1}, ..x_{_a}.., x_{n}) != TRUE
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. Q(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 7
#    operands: 11
# 5. !=
#    core type: Literal
#    sub-expressions:
# 6. (P(x_{1}, ..x_{_a}.., x_{n}), TRUE)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. Q
#    core type: Variable
#    sub-expressions:
# 8. P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. TRUE
#    core type: Literal
#    sub-expressions:
# 10. P
#     core type: Variable
#     sub-expressions:
# 11. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 12
# 12. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 14
#     end_index: 15
# 13. _a -> x_{_a}
#     core type: Lambda
#     parameter: 19
#     body: 16
# 14. 1
#     core type: Literal
#     sub-expressions:
# 15. n
#     core type: Variable
#     sub-expressions:
# 16. x_{_a}
#     core type: IndexedVar
# variable: 17
# index: 19
# 17. x
#     core type: Variable
#     sub-expressions:
# 18. (_a)
#     core type: ExprTuple
#     sub-expressions: 19
# 19. _a
#     core type: Variable
#     sub-expressions:
