# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import P, n
from proveit.logic import Forall, Implies, Not
from proveit.logic.booleans.quantification import general_exists_Px, general_notexists_Py
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Forall([n], Forall([P], Implies(Not(general_exists_Px), general_notexists_Py).with_wrapping_at(2)), domains = [NaturalPos])
# Out:
# expr: forall_{n in NaturalPos} [forall_{P} (not(exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})) =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})])]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\forall_{P}~\left(\begin{array}{c} \begin{array}{l} (\lnot \left[\exists_{x_{1}, \ldots, x_{n}}~P(x_{1}, \ldots, x_{n})\right]) \Rightarrow  \\ \left[\nexists_{y_{1}, \ldots, y_{n}}~P(y_{1}, \ldots, y_{n})\right] \end{array} \end{array}\right)\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{P} (not(exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})) =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})])]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (n -> {forall_{P} (not(exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})) =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})]) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{P} (not(exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})) =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})]) if n in NaturalPos.
#    core type: Lambda
#    parameter: 35
#    body: 3
# 3. {forall_{P} (not(exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})) =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})]) if n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{P} (not(exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})) =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})])
#    core type: Operation
#    operator: 6
#    operand: 10
# 5. n in NaturalPos
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (P -> (not(exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})) =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})]))
#    core type: ExprTuple
#    sub-expressions: 10
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 35, 11
# 10. P -> (not(exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})) =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})])
#     core type: Lambda
#     parameter: 28
#     body: 12
# 11. NaturalPos
#     core type: Literal
#     sub-expressions:
# 12. not(exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})) =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})]
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. =>
#     core type: Literal
#     sub-expressions:
# 14. (not(exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})), notexists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. not(exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n}))
#     core type: Operation
#     operator: 17
#     operand: 20
# 16. notexists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 19
#     operand: 24
# 17. not
#     core type: Literal
#     sub-expressions:
# 18. (exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n}))
#     core type: ExprTuple
#     sub-expressions: 20
# 19. notexists
#     core type: Literal
#     sub-expressions:
# 20. exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 21
#     operand: 24
# 21. exists
#     core type: Literal
#     sub-expressions:
# 22. ((x_{1}, ..x_{_a}.., x_{n}) -> P(x_{1}, ..x_{_a}.., x_{n}))
#     core type: ExprTuple
#     sub-expressions: 24
# 23. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 28
#     operands: 25
# 24. (x_{1}, ..x_{_a}.., x_{n}) -> P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Lambda
#     parameters: 29\n    body: 26
# 25. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 27
# 26. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 28
#     operands: 29
# 27. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 34
#     end_index: 35
# 28. P
#     core type: Variable
#     sub-expressions:
# 29. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 31
# 30. _a -> y_{_a}
#     core type: Lambda
#     parameter: 40
#     body: 32
# 31. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 34
#     end_index: 35
# 32. y_{_a}
#     core type: IndexedVar
# variable: 36
# index: 40
# 33. _a -> x_{_a}
#     core type: Lambda
#     parameter: 40
#     body: 37
# 34. 1
#     core type: Literal
#     sub-expressions:
# 35. n
#     core type: Variable
#     sub-expressions:
# 36. y
#     core type: Variable
#     sub-expressions:
# 37. x_{_a}
#     core type: IndexedVar
# variable: 38
# index: 40
# 38. x
#     core type: Variable
#     sub-expressions:
# 39. (_a)
#     core type: ExprTuple
#     sub-expressions: 40
# 40. _a
#     core type: Variable
#     sub-expressions:
