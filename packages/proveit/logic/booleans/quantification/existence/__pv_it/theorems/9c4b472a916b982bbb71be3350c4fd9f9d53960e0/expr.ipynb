# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.logic.Not.html">Not</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.logic import Not
from proveit.logic.booleans.quantification import general_forall__Py_not_T__st_Qy

# %%
# build up the expression from sub-expressions
expr = Not(general_forall__Py_not_T__st_Qy)
# Out:
# expr: not(forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \lnot \left[\forall_{y_{1}, \ldots, y_{n}~|~Q(y_{1}, \ldots, y_{n})}~\left(P(y_{1}, \ldots, y_{n}) \neq \top\right)\right]

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: function
# current value: function
# related methods: ()

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. not(forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. not
#    core type: Literal
#    sub-expressions:
# 2. (forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE)
#    core type: Operation
#    operator: 4
#    operand: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. ((y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) != TRUE if Q(y_{1}, ..y_{_a}.., y_{n}).)
#    core type: ExprTuple
#    sub-expressions: 6
# 6. (y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) != TRUE if Q(y_{1}, ..y_{_a}.., y_{n}).
#    core type: Lambda
#    parameters: 16\n   body: 7
# 7. {P(y_{1}, ..y_{_a}.., y_{n}) != TRUE if Q(y_{1}, ..y_{_a}.., y_{n}).
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. P(y_{1}, ..y_{_a}.., y_{n}) != TRUE
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. Q(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 12
#    operands: 16
# 10. !=
#     core type: Literal
#     sub-expressions:
# 11. (P(y_{1}, ..y_{_a}.., y_{n}), TRUE)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. Q
#     core type: Variable
#     sub-expressions:
# 13. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. TRUE
#     core type: Literal
#     sub-expressions:
# 15. P
#     core type: Variable
#     sub-expressions:
# 16. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 17
# 17. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 19
#     end_index: 20
# 18. _a -> y_{_a}
#     core type: Lambda
#     parameter: 24
#     body: 21
# 19. 1
#     core type: Literal
#     sub-expressions:
# 20. n
#     core type: Variable
#     sub-expressions:
# 21. y_{_a}
#     core type: IndexedVar
# variable: 22
# index: 24
# 22. y
#     core type: Variable
#     sub-expressions:
# 23. (_a)
#     core type: ExprTuple
#     sub-expressions: 24
# 24. _a
#     core type: Variable
#     sub-expressions:
