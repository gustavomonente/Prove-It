# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, P, Q, alpha
from proveit.core_expr_types import P__x_1_to_n, Q__x_1_to_n, x_1_to_n
from proveit.logic import And, Forall, Implies
from proveit.logic.booleans.quantification import general_exists_Py_st_Qy

# %%
# build up the expression from sub-expressions
expr = Lambda([P, Q, alpha], Implies(And(general_exists_Py_st_Qy, Forall([x_1_to_n], Implies(P__x_1_to_n, alpha), condition = Q__x_1_to_n)), alpha))
# Out:
# expr: (P, Q, alpha) -> (([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(P, Q, \alpha\right) \mapsto \left(\left(\left[\exists_{y_{1}, \ldots, y_{n}~|~Q(y_{1}, \ldots, y_{n})}~P(y_{1}, \ldots, y_{n})\right] \land \left[\forall_{x_{1}, \ldots, x_{n}~|~Q(x_{1}, \ldots, x_{n})}~\left(P(x_{1}, \ldots, x_{n}) \Rightarrow \alpha\right)\right]\right) \Rightarrow \alpha\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (P, Q, alpha) -> (([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha)
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (P, Q, alpha)
#    core type: ExprTuple
#    sub-expressions: 29, 24, 27
# 2. ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha
#    core type: Operation
#    operator: 22
#    operands: 3
# 3. ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)], alpha)
#    core type: ExprTuple
#    sub-expressions: 4, 27
# 4. [exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n}), forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 9
#    operand: 13
# 8. forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)
#    core type: Operation
#    operator: 11
#    operand: 14
# 9. exists
#    core type: Literal
#    sub-expressions:
# 10. ((y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if Q(y_{1}, ..y_{_a}.., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 13
# 11. forall
#     core type: Literal
#     sub-expressions:
# 12. ((x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) => alpha if Q(x_{1}, ..x_{_a}.., x_{n}).)
#     core type: ExprTuple
#     sub-expressions: 14
# 13. (y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 21\n    body: 15
# 14. (x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) => alpha if Q(x_{1}, ..x_{_a}.., x_{n}).
#     core type: Lambda
#     parameters: 30\n    body: 16
# 15. {P(y_{1}, ..y_{_a}.., y_{n}) if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 17
#     condition: 18
# 16. {P(x_{1}, ..x_{_a}.., x_{n}) => alpha if Q(x_{1}, ..x_{_a}.., x_{n}).
#     core type: Conditional
#     value: 19
#     condition: 20
# 17. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 29
#     operands: 21
# 18. Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 24
#     operands: 21
# 19. P(x_{1}, ..x_{_a}.., x_{n}) => alpha
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. Q(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 24
#     operands: 30
# 21. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 25
# 22. =>
#     core type: Literal
#     sub-expressions:
# 23. (P(x_{1}, ..x_{_a}.., x_{n}), alpha)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. Q
#     core type: Variable
#     sub-expressions:
# 25. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 35
#     end_index: 36
# 26. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 29
#     operands: 30
# 27. alpha
#     core type: Variable
#     sub-expressions:
# 28. _a -> y_{_a}
#     core type: Lambda
#     parameter: 40
#     body: 31
# 29. P
#     core type: Variable
#     sub-expressions:
# 30. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 32
# 31. y_{_a}
#     core type: IndexedVar
# variable: 33
# index: 40
# 32. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 35
#     end_index: 36
# 33. y
#     core type: Variable
#     sub-expressions:
# 34. _a -> x_{_a}
#     core type: Lambda
#     parameter: 40
#     body: 37
# 35. 1
#     core type: Literal
#     sub-expressions:
# 36. n
#     core type: Variable
#     sub-expressions:
# 37. x_{_a}
#     core type: IndexedVar
# variable: 38
# index: 40
# 38. x
#     core type: Variable
#     sub-expressions:
# 39. (_a)
#     core type: ExprTuple
#     sub-expressions: 40
# 40. _a
#     core type: Variable
#     sub-expressions:
