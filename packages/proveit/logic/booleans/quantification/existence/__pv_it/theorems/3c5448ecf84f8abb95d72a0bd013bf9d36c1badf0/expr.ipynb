# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit.logic import Not
from proveit.logic.booleans.quantification import general_exists_Px_st_Qx, general_forall__Py_not_T__st_Qy

# %%
# build up the expression from sub-expressions
expr = Conditional(general_exists_Px_st_Qx, Not(general_forall__Py_not_T__st_Qy))
# Out:
# expr: {exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n}) if not(forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE)).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\exists_{x_{1}, \ldots, x_{n}~|~Q(x_{1}, \ldots, x_{n})}~P(x_{1}, \ldots, x_{n}) \textrm{ if } \lnot \left[\forall_{y_{1}, \ldots, y_{n}~|~Q(y_{1}, \ldots, y_{n})}~\left(P(y_{1}, \ldots, y_{n}) \neq \top\right)\right]\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n}) if not(forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE)).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. not(forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE))
#    core type: Operation
#    operator: 5
#    operand: 8
# 3. exists
#    core type: Literal
#    sub-expressions:
# 4. ((x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. not
#    core type: Literal
#    sub-expressions:
# 6. (forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE))
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#    core type: Lambda
#    parameters: 15\n   body: 9
# 8. forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE)
#    core type: Operation
#    operator: 10
#    operand: 14
# 9. {P(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. forall
#     core type: Literal
#     sub-expressions:
# 11. ((y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) != TRUE if Q(y_{1}, ..y_{_a}.., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 14
# 12. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 28
#     operands: 15
# 13. Q(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 23
#     operands: 15
# 14. (y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) != TRUE if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 29\n    body: 16
# 15. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 17
# 16. {P(y_{1}, ..y_{_a}.., y_{n}) != TRUE if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 18
#     condition: 19
# 17. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 32
#     end_index: 33
# 18. P(y_{1}, ..y_{_a}.., y_{n}) != TRUE
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 23
#     operands: 29
# 20. _a -> x_{_a}
#     core type: Lambda
#     parameter: 37
#     body: 24
# 21. !=
#     core type: Literal
#     sub-expressions:
# 22. (P(y_{1}, ..y_{_a}.., y_{n}), TRUE)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. Q
#     core type: Variable
#     sub-expressions:
# 24. x_{_a}
#     core type: IndexedVar
# variable: 27
# index: 37
# 25. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 28
#     operands: 29
# 26. TRUE
#     core type: Literal
#     sub-expressions:
# 27. x
#     core type: Variable
#     sub-expressions:
# 28. P
#     core type: Variable
#     sub-expressions:
# 29. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 30
# 30. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 32
#     end_index: 33
# 31. _a -> y_{_a}
#     core type: Lambda
#     parameter: 37
#     body: 34
# 32. 1
#     core type: Literal
#     sub-expressions:
# 33. n
#     core type: Variable
#     sub-expressions:
# 34. y_{_a}
#     core type: IndexedVar
# variable: 35
# index: 37
# 35. y
#     core type: Variable
#     sub-expressions:
# 36. (_a)
#     core type: ExprTuple
#     sub-expressions: 37
# 37. _a
#     core type: Variable
#     sub-expressions:
