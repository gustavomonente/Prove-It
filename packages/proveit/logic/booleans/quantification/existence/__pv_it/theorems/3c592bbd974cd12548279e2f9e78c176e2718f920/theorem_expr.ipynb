# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#exists_in_superset">exists_in_superset</a> of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.quantification.existence import exists_in_superset

# %%
# check that the built expression is the same as the stored expression
assert exists_in_superset.expr == stored_expr
assert exists_in_superset.expr._style_id == stored_expr._style_id
print("Passed sanity check: exists_in_superset matches stored_expr")
# Out:
# Passed sanity check: exists_in_superset matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(exists_in_superset.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{P, A, B~|~A \subseteq B}~\left(\begin{array}{c} \begin{array}{l} \left[\exists_{x_{1}, \ldots, x_{n} \in A}~P(x_{1}, \ldots, x_{n})\right] \Rightarrow  \\ \left[\exists_{y_{1}, \ldots, y_{n} \in B}~P(y_{1}, \ldots, y_{n})\right] \end{array} \end{array}\right)\right]

# %%
exists_in_superset.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
exists_in_superset.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{P, A, B | A subset_eq B} ([exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})])]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (n -> {forall_{P, A, B | A subset_eq B} ([exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})]) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{P, A, B | A subset_eq B} ([exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})]) if n in NaturalPos.
#    core type: Lambda
#    parameter: 47
#    body: 3
# 3. {forall_{P, A, B | A subset_eq B} ([exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})]) if n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{P, A, B | A subset_eq B} ([exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})])
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. n in NaturalPos
#    core type: Operation
#    operator: 51
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((P, A, B) -> {[exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})] if A subset_eq B.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 47, 10
# 9. (P, A, B) -> {[exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})] if A subset_eq B.
#    core type: Lambda
#    parameters: 11\n   body: 12
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. (P, A, B)
#     core type: ExprTuple
#     sub-expressions: 34, 54, 56
# 12. {[exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})] if A subset_eq B.
#     core type: Conditional
#     value: 13
#     condition: 14
# 13. [exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})]
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. A subset_eq B
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. =>
#     core type: Literal
#     sub-expressions:
# 16. (exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n}), exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. subset_eq
#     core type: Literal
#     sub-expressions:
# 18. (A, B)
#     core type: ExprTuple
#     sub-expressions: 54, 56
# 19. exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 22
#     operand: 24
# 20. exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 22
#     operand: 25
# 21. ((x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) if (x_{1} in A) and ..(x_{_a} in A).. and (x_{n} in A).)
#     core type: ExprTuple
#     sub-expressions: 24
# 22. exists
#     core type: Literal
#     sub-expressions:
# 23. ((y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if (y_{1} in B) and ..(y_{_a} in B).. and (y_{n} in B).)
#     core type: ExprTuple
#     sub-expressions: 25
# 24. (x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) if (x_{1} in A) and ..(x_{_a} in A).. and (x_{n} in A).
#     core type: Lambda
#     parameters: 32\n    body: 26
# 25. (y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if (y_{1} in B) and ..(y_{_a} in B).. and (y_{n} in B).
#     core type: Lambda
#     parameters: 35\n    body: 27
# 26. {P(x_{1}, ..x_{_a}.., x_{n}) if (x_{1} in A) and ..(x_{_a} in A).. and (x_{n} in A).
#     core type: Conditional
#     value: 28
#     condition: 29
# 27. {P(y_{1}, ..y_{_a}.., y_{n}) if (y_{1} in B) and ..(y_{_a} in B).. and (y_{n} in B).
#     core type: Conditional
#     value: 30
#     condition: 31
# 28. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 34
#     operands: 32
# 29. (x_{1} in A) and ..(x_{_a} in A).. and (x_{n} in A)
#     core type: Operation
#     operator: 36
#     operands: 33
# 30. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 34
#     operands: 35
# 31. (y_{1} in B) and ..(y_{_a} in B).. and (y_{n} in B)
#     core type: Operation
#     operator: 36
#     operands: 37
# 32. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 38
# 33. (x_{1} in A, ..x_{_a} in A.., x_{n} in A)
#     core type: ExprTuple
#     sub-expressions: 39
# 34. P
#     core type: Variable
#     sub-expressions:
# 35. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 40
# 36. and
#     core type: Literal
#     sub-expressions:
# 37. (y_{1} in B, ..y_{_a} in B.., y_{n} in B)
#     core type: ExprTuple
#     sub-expressions: 41
# 38. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 46
#     end_index: 47
# 39. (x_{1} in A), ..(x_{_a} in A).., (x_{n} in A)
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 46
#     end_index: 47
# 40. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 46
#     end_index: 47
# 41. (y_{1} in B), ..(y_{_a} in B).., (y_{n} in B)
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 46
#     end_index: 47
# 42. _a -> x_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 53
# 43. _a -> (x_{_a} in A)
#     core type: Lambda
#     parameter: 60
#     body: 48
# 44. _a -> y_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 55
# 45. _a -> (y_{_a} in B)
#     core type: Lambda
#     parameter: 60
#     body: 49
# 46. 1
#     core type: Literal
#     sub-expressions:
# 47. n
#     core type: Variable
#     sub-expressions:
# 48. x_{_a} in A
#     core type: Operation
#     operator: 51
#     operands: 50
# 49. y_{_a} in B
#     core type: Operation
#     operator: 51
#     operands: 52
# 50. (x_{_a}, A)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 51. in
#     core type: Literal
#     sub-expressions:
# 52. (y_{_a}, B)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 53. x_{_a}
#     core type: IndexedVar
# variable: 57
# index: 60
# 54. A
#     core type: Variable
#     sub-expressions:
# 55. y_{_a}
#     core type: IndexedVar
# variable: 58
# index: 60
# 56. B
#     core type: Variable
#     sub-expressions:
# 57. x
#     core type: Variable
#     sub-expressions:
# 58. y
#     core type: Variable
#     sub-expressions:
# 59. (_a)
#     core type: ExprTuple
#     sub-expressions: 60
# 60. _a
#     core type: Variable
#     sub-expressions:
