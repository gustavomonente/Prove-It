# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, P, Q, alpha, n
from proveit.core_expr_types import P__x_1_to_n, Q__x_1_to_n, x_1_to_n
from proveit.logic import And, Boolean, Forall, Implies, InSet
from proveit.logic.booleans.quantification import general_exists_Py_st_Qy
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Lambda([n, alpha], Conditional(Forall([P, Q], Implies(And(general_exists_Py_st_Qy, Forall([x_1_to_n], Implies(P__x_1_to_n, alpha), condition = Q__x_1_to_n)), alpha)), And(InSet(n, NaturalPos), InSet(alpha, Boolean))))
# Out:
# expr: (n, alpha) -> {forall_{P, Q} (([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha) if n in NaturalPos ,  alpha in BOOLEAN.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(n, \alpha\right) \mapsto \left\{\forall_{P, Q}~\left(\left(\left[\exists_{y_{1}, \ldots, y_{n}~|~Q(y_{1}, \ldots, y_{n})}~P(y_{1}, \ldots, y_{n})\right] \land \left[\forall_{x_{1}, \ldots, x_{n}~|~Q(x_{1}, \ldots, x_{n})}~\left(P(x_{1}, \ldots, x_{n}) \Rightarrow \alpha\right)\right]\right) \Rightarrow \alpha\right) \textrm{ if } n \in \mathbb{N}^+ ,  \alpha \in \mathbb{B}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (n, alpha) -> {forall_{P, Q} (([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha) if n in NaturalPos ,  alpha in BOOLEAN.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (n, alpha)
#    core type: ExprTuple
#    sub-expressions: 50, 41
# 2. {forall_{P, Q} (([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha) if n in NaturalPos ,  alpha in BOOLEAN.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{P, Q} (([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha)
#    core type: Operation
#    operator: 25
#    operand: 7
# 4. (n in NaturalPos) and (alpha in BOOLEAN)
#    core type: Operation
#    operator: 19
#    operands: 6
# 5. ((P, Q) -> (([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (n in NaturalPos, alpha in BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (P, Q) -> (([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha)
#    core type: Lambda
#    parameters: 10\n   body: 11
# 8. n in NaturalPos
#    core type: Operation
#    operator: 13
#    operands: 12
# 9. alpha in BOOLEAN
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. (P, Q)
#     core type: ExprTuple
#     sub-expressions: 43, 38
# 11. ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha
#     core type: Operation
#     operator: 36
#     operands: 15
# 12. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 50, 16
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (alpha, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 41, 17
# 15. ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)], alpha)
#     core type: ExprTuple
#     sub-expressions: 18, 41
# 16. NaturalPos
#     core type: Literal
#     sub-expressions:
# 17. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 18. [exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]
#     core type: Operation
#     operator: 19
#     operands: 20
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. (exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n}), forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 21. exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 23
#     operand: 27
# 22. forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)
#     core type: Operation
#     operator: 25
#     operand: 28
# 23. exists
#     core type: Literal
#     sub-expressions:
# 24. ((y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if Q(y_{1}, ..y_{_a}.., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 27
# 25. forall
#     core type: Literal
#     sub-expressions:
# 26. ((x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) => alpha if Q(x_{1}, ..x_{_a}.., x_{n}).)
#     core type: ExprTuple
#     sub-expressions: 28
# 27. (y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 35\n    body: 29
# 28. (x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) => alpha if Q(x_{1}, ..x_{_a}.., x_{n}).
#     core type: Lambda
#     parameters: 44\n    body: 30
# 29. {P(y_{1}, ..y_{_a}.., y_{n}) if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 31
#     condition: 32
# 30. {P(x_{1}, ..x_{_a}.., x_{n}) => alpha if Q(x_{1}, ..x_{_a}.., x_{n}).
#     core type: Conditional
#     value: 33
#     condition: 34
# 31. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 43
#     operands: 35
# 32. Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 38
#     operands: 35
# 33. P(x_{1}, ..x_{_a}.., x_{n}) => alpha
#     core type: Operation
#     operator: 36
#     operands: 37
# 34. Q(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 38
#     operands: 44
# 35. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 39
# 36. =>
#     core type: Literal
#     sub-expressions:
# 37. (P(x_{1}, ..x_{_a}.., x_{n}), alpha)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 38. Q
#     core type: Variable
#     sub-expressions:
# 39. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 49
#     end_index: 50
# 40. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 43
#     operands: 44
# 41. alpha
#     core type: Variable
#     sub-expressions:
# 42. _a -> y_{_a}
#     core type: Lambda
#     parameter: 54
#     body: 45
# 43. P
#     core type: Variable
#     sub-expressions:
# 44. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 46
# 45. y_{_a}
#     core type: IndexedVar
# variable: 47
# index: 54
# 46. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 49
#     end_index: 50
# 47. y
#     core type: Variable
#     sub-expressions:
# 48. _a -> x_{_a}
#     core type: Lambda
#     parameter: 54
#     body: 51
# 49. 1
#     core type: Literal
#     sub-expressions:
# 50. n
#     core type: Variable
#     sub-expressions:
# 51. x_{_a}
#     core type: IndexedVar
# variable: 52
# index: 54
# 52. x
#     core type: Variable
#     sub-expressions:
# 53. (_a)
#     core type: ExprTuple
#     sub-expressions: 54
# 54. _a
#     core type: Variable
#     sub-expressions:
