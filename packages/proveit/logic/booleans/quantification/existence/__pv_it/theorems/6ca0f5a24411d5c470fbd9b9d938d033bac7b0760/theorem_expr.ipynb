# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#forall_implies_not_exists_not">forall_implies_not_exists_not</a> of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.quantification.existence import forall_implies_not_exists_not

# %%
# check that the built expression is the same as the stored expression
assert forall_implies_not_exists_not.expr == stored_expr
assert forall_implies_not_exists_not.expr._style_id == stored_expr._style_id
print("Passed sanity check: forall_implies_not_exists_not matches stored_expr")
# Out:
# Passed sanity check: forall_implies_not_exists_not matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(forall_implies_not_exists_not.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{P}~\left(\begin{array}{c} \begin{array}{l} \left[\forall_{x_{1}, \ldots, x_{n}}~P(x_{1}, \ldots, x_{n})\right] \Rightarrow  \\ \left[\nexists_{y_{1}, \ldots, y_{n}}~(\lnot P(y_{1}, \ldots, y_{n}))\right] \end{array} \end{array}\right)\right]

# %%
forall_implies_not_exists_not.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
forall_implies_not_exists_not.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{P} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} not(P(y_{1}, ..y_{_a}.., y_{n}))])]
#    core type: Operation
#    operator: 16
#    operand: 2
# 1. (n -> {forall_{P} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} not(P(y_{1}, ..y_{_a}.., y_{n}))]) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{P} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} not(P(y_{1}, ..y_{_a}.., y_{n}))]) if n in NaturalPos.
#    core type: Lambda
#    parameter: 37
#    body: 3
# 3. {forall_{P} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} not(P(y_{1}, ..y_{_a}.., y_{n}))]) if n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{P} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} not(P(y_{1}, ..y_{_a}.., y_{n}))])
#    core type: Operation
#    operator: 16
#    operand: 9
# 5. n in NaturalPos
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (P -> ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} not(P(y_{1}, ..y_{_a}.., y_{n}))]))
#    core type: ExprTuple
#    sub-expressions: 9
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 37, 10
# 9. P -> ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} not(P(y_{1}, ..y_{_a}.., y_{n}))])
#    core type: Lambda
#    parameter: 30
#    body: 11
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. [forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} not(P(y_{1}, ..y_{_a}.., y_{n}))]
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. =>
#     core type: Literal
#     sub-expressions:
# 13. (forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n}), notexists_{y_{1}, ..y_{_a}.., y_{n}} not(P(y_{1}, ..y_{_a}.., y_{n})))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 16
#     operand: 20
# 15. notexists_{y_{1}, ..y_{_a}.., y_{n}} not(P(y_{1}, ..y_{_a}.., y_{n}))
#     core type: Operation
#     operator: 18
#     operand: 21
# 16. forall
#     core type: Literal
#     sub-expressions:
# 17. ((x_{1}, ..x_{_a}.., x_{n}) -> P(x_{1}, ..x_{_a}.., x_{n}))
#     core type: ExprTuple
#     sub-expressions: 20
# 18. notexists
#     core type: Literal
#     sub-expressions:
# 19. ((y_{1}, ..y_{_a}.., y_{n}) -> not(P(y_{1}, ..y_{_a}.., y_{n})))
#     core type: ExprTuple
#     sub-expressions: 21
# 20. (x_{1}, ..x_{_a}.., x_{n}) -> P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Lambda
#     parameters: 24\n    body: 22
# 21. (y_{1}, ..y_{_a}.., y_{n}) -> not(P(y_{1}, ..y_{_a}.., y_{n}))
#     core type: Lambda
#     parameters: 31\n    body: 23
# 22. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 30
#     operands: 24
# 23. not(P(y_{1}, ..y_{_a}.., y_{n}))
#     core type: Operation
#     operator: 25
#     operand: 28
# 24. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 27
# 25. not
#     core type: Literal
#     sub-expressions:
# 26. (P(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 28
# 27. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 36
#     end_index: 37
# 28. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 30
#     operands: 31
# 29. _a -> x_{_a}
#     core type: Lambda
#     parameter: 41
#     body: 32
# 30. P
#     core type: Variable
#     sub-expressions:
# 31. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 33
# 32. x_{_a}
#     core type: IndexedVar
# variable: 34
# index: 41
# 33. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 36
#     end_index: 37
# 34. x
#     core type: Variable
#     sub-expressions:
# 35. _a -> y_{_a}
#     core type: Lambda
#     parameter: 41
#     body: 38
# 36. 1
#     core type: Literal
#     sub-expressions:
# 37. n
#     core type: Variable
#     sub-expressions:
# 38. y_{_a}
#     core type: IndexedVar
# variable: 39
# index: 41
# 39. y
#     core type: Variable
#     sub-expressions:
# 40. (_a)
#     core type: ExprTuple
#     sub-expressions: 41
# 41. _a
#     core type: Variable
#     sub-expressions:
