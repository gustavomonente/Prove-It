# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional
from proveit.logic import Implies, SubsetEq
from proveit.logic.booleans.quantification import general_exists_in_A_Px, general_exists_in_B_Py

# %%
# build up the expression from sub-expressions
expr = Conditional(Implies(general_exists_in_A_Px, general_exists_in_B_Py).with_wrapping_at(2), SubsetEq(A, B))
# Out:
# expr: {[exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})] if A subset_eq B.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\begin{array}{c} \begin{array}{l} \left[\exists_{x_{1}, \ldots, x_{n} \in A}~P(x_{1}, \ldots, x_{n})\right] \Rightarrow  \\ \left[\exists_{y_{1}, \ldots, y_{n} \in B}~P(y_{1}, \ldots, y_{n})\right] \end{array} \end{array} \textrm{ if } A \subseteq B\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {[exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})] if A subset_eq B.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. [exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})]
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. A subset_eq B
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =>
#    core type: Literal
#    sub-expressions:
# 4. (exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n}), exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n}))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. subset_eq
#    core type: Literal
#    sub-expressions:
# 6. (A, B)
#    core type: ExprTuple
#    sub-expressions: 42, 44
# 7. exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 10
#    operand: 12
# 8. exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 10
#    operand: 13
# 9. ((x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) if (x_{1} in A) and ..(x_{_a} in A).. and (x_{n} in A).)
#    core type: ExprTuple
#    sub-expressions: 12
# 10. exists
#     core type: Literal
#     sub-expressions:
# 11. ((y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if (y_{1} in B) and ..(y_{_a} in B).. and (y_{n} in B).)
#     core type: ExprTuple
#     sub-expressions: 13
# 12. (x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) if (x_{1} in A) and ..(x_{_a} in A).. and (x_{n} in A).
#     core type: Lambda
#     parameters: 20\n    body: 14
# 13. (y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if (y_{1} in B) and ..(y_{_a} in B).. and (y_{n} in B).
#     core type: Lambda
#     parameters: 23\n    body: 15
# 14. {P(x_{1}, ..x_{_a}.., x_{n}) if (x_{1} in A) and ..(x_{_a} in A).. and (x_{n} in A).
#     core type: Conditional
#     value: 16
#     condition: 17
# 15. {P(y_{1}, ..y_{_a}.., y_{n}) if (y_{1} in B) and ..(y_{_a} in B).. and (y_{n} in B).
#     core type: Conditional
#     value: 18
#     condition: 19
# 16. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 22
#     operands: 20
# 17. (x_{1} in A) and ..(x_{_a} in A).. and (x_{n} in A)
#     core type: Operation
#     operator: 24
#     operands: 21
# 18. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. (y_{1} in B) and ..(y_{_a} in B).. and (y_{n} in B)
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 26
# 21. (x_{1} in A, ..x_{_a} in A.., x_{n} in A)
#     core type: ExprTuple
#     sub-expressions: 27
# 22. P
#     core type: Variable
#     sub-expressions:
# 23. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 28
# 24. and
#     core type: Literal
#     sub-expressions:
# 25. (y_{1} in B, ..y_{_a} in B.., y_{n} in B)
#     core type: ExprTuple
#     sub-expressions: 29
# 26. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 34
#     end_index: 35
# 27. (x_{1} in A), ..(x_{_a} in A).., (x_{n} in A)
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 34
#     end_index: 35
# 28. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 34
#     end_index: 35
# 29. (y_{1} in B), ..(y_{_a} in B).., (y_{n} in B)
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 34
#     end_index: 35
# 30. _a -> x_{_a}
#     core type: Lambda
#     parameter: 48
#     body: 41
# 31. _a -> (x_{_a} in A)
#     core type: Lambda
#     parameter: 48
#     body: 36
# 32. _a -> y_{_a}
#     core type: Lambda
#     parameter: 48
#     body: 43
# 33. _a -> (y_{_a} in B)
#     core type: Lambda
#     parameter: 48
#     body: 37
# 34. 1
#     core type: Literal
#     sub-expressions:
# 35. n
#     core type: Variable
#     sub-expressions:
# 36. x_{_a} in A
#     core type: Operation
#     operator: 39
#     operands: 38
# 37. y_{_a} in B
#     core type: Operation
#     operator: 39
#     operands: 40
# 38. (x_{_a}, A)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 39. in
#     core type: Literal
#     sub-expressions:
# 40. (y_{_a}, B)
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 41. x_{_a}
#     core type: IndexedVar
# variable: 45
# index: 48
# 42. A
#     core type: Variable
#     sub-expressions:
# 43. y_{_a}
#     core type: IndexedVar
# variable: 46
# index: 48
# 44. B
#     core type: Variable
#     sub-expressions:
# 45. x
#     core type: Variable
#     sub-expressions:
# 46. y
#     core type: Variable
#     sub-expressions:
# 47. (_a)
#     core type: ExprTuple
#     sub-expressions: 48
# 48. _a
#     core type: Variable
#     sub-expressions:
