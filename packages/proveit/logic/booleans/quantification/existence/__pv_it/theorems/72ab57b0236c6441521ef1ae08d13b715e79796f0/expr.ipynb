# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import P, Q, alpha, n
from proveit.core_expr_types import P__x_1_to_n, Q__x_1_to_n, x_1_to_n
from proveit.logic import And, Forall, Implies
from proveit.logic.booleans.quantification import general_exists_Py_st_Qy
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Forall([n], Forall([P, Q, alpha], Implies(And(general_exists_Py_st_Qy, Forall([x_1_to_n], Implies(P__x_1_to_n, alpha), condition = Q__x_1_to_n)), alpha)), domains = [NaturalPos])
# Out:
# expr: forall_{n in NaturalPos} [forall_{P, Q, alpha} (([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha)]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\forall_{P, Q, \alpha}~\left(\left(\left[\exists_{y_{1}, \ldots, y_{n}~|~Q(y_{1}, \ldots, y_{n})}~P(y_{1}, \ldots, y_{n})\right] \land \left[\forall_{x_{1}, \ldots, x_{n}~|~Q(x_{1}, \ldots, x_{n})}~\left(P(x_{1}, \ldots, x_{n}) \Rightarrow \alpha\right)\right]\right) \Rightarrow \alpha\right)\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{P, Q, alpha} (([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha)]
#    core type: Operation
#    operator: 21
#    operand: 2
# 1. (n -> {forall_{P, Q, alpha} (([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{P, Q, alpha} (([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha) if n in NaturalPos.
#    core type: Lambda
#    parameter: 46
#    body: 3
# 3. {forall_{P, Q, alpha} (([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha) if n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{P, Q, alpha} (([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha)
#    core type: Operation
#    operator: 21
#    operand: 9
# 5. n in NaturalPos
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. ((P, Q, alpha) -> (([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha))
#    core type: ExprTuple
#    sub-expressions: 9
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 46, 10
# 9. (P, Q, alpha) -> (([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha)
#    core type: Lambda
#    parameters: 11\n   body: 12
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. (P, Q, alpha)
#     core type: ExprTuple
#     sub-expressions: 39, 34, 37
# 12. ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha
#     core type: Operation
#     operator: 32
#     operands: 13
# 13. ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)], alpha)
#     core type: ExprTuple
#     sub-expressions: 14, 37
# 14. [exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]
#     core type: Operation
#     operator: 15
#     operands: 16
# 15. and
#     core type: Literal
#     sub-expressions:
# 16. (exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n}), forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 19
#     operand: 23
# 18. forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)
#     core type: Operation
#     operator: 21
#     operand: 24
# 19. exists
#     core type: Literal
#     sub-expressions:
# 20. ((y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if Q(y_{1}, ..y_{_a}.., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 23
# 21. forall
#     core type: Literal
#     sub-expressions:
# 22. ((x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) => alpha if Q(x_{1}, ..x_{_a}.., x_{n}).)
#     core type: ExprTuple
#     sub-expressions: 24
# 23. (y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 31\n    body: 25
# 24. (x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) => alpha if Q(x_{1}, ..x_{_a}.., x_{n}).
#     core type: Lambda
#     parameters: 40\n    body: 26
# 25. {P(y_{1}, ..y_{_a}.., y_{n}) if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 27
#     condition: 28
# 26. {P(x_{1}, ..x_{_a}.., x_{n}) => alpha if Q(x_{1}, ..x_{_a}.., x_{n}).
#     core type: Conditional
#     value: 29
#     condition: 30
# 27. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 39
#     operands: 31
# 28. Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 34
#     operands: 31
# 29. P(x_{1}, ..x_{_a}.., x_{n}) => alpha
#     core type: Operation
#     operator: 32
#     operands: 33
# 30. Q(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 34
#     operands: 40
# 31. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 35
# 32. =>
#     core type: Literal
#     sub-expressions:
# 33. (P(x_{1}, ..x_{_a}.., x_{n}), alpha)
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 34. Q
#     core type: Variable
#     sub-expressions:
# 35. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 45
#     end_index: 46
# 36. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 39
#     operands: 40
# 37. alpha
#     core type: Variable
#     sub-expressions:
# 38. _a -> y_{_a}
#     core type: Lambda
#     parameter: 50
#     body: 41
# 39. P
#     core type: Variable
#     sub-expressions:
# 40. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 42
# 41. y_{_a}
#     core type: IndexedVar
# variable: 43
# index: 50
# 42. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 45
#     end_index: 46
# 43. y
#     core type: Variable
#     sub-expressions:
# 44. _a -> x_{_a}
#     core type: Lambda
#     parameter: 50
#     body: 47
# 45. 1
#     core type: Literal
#     sub-expressions:
# 46. n
#     core type: Variable
#     sub-expressions:
# 47. x_{_a}
#     core type: IndexedVar
# variable: 48
# index: 50
# 48. x
#     core type: Variable
#     sub-expressions:
# 49. (_a)
#     core type: ExprTuple
#     sub-expressions: 50
# 50. _a
#     core type: Variable
#     sub-expressions:
