# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#not_exists_def">not_exists_def</a> of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.quantification.existence import not_exists_def

# %%
# check that the built expression is the same as the stored expression
assert not_exists_def.expr == stored_expr
assert not_exists_def.expr._style_id == stored_expr._style_id
print("Passed sanity check: not_exists_def matches stored_expr")
# Out:
# Passed sanity check: not_exists_def matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(not_exists_def.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{P, Q}~\left(\begin{array}{c} \begin{array}{l} \left[\nexists_{x_{1}, \ldots, x_{n}~|~Q(x_{1}, \ldots, x_{n})}~P(x_{1}, \ldots, x_{n})\right] =  \\ (\lnot \left[\exists_{y_{1}, \ldots, y_{n}~|~Q(y_{1}, \ldots, y_{n})}~P(y_{1}, \ldots, y_{n})\right]) \end{array} \end{array}\right)\right]

# %%
not_exists_def.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
not_exists_def.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{P, Q} ([notexists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ not(exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})))]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (n -> {forall_{P, Q} ([notexists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ not(exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n}))) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{P, Q} ([notexists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ not(exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n}))) if n in NaturalPos.
#    core type: Lambda
#    parameter: 42
#    body: 3
# ...
