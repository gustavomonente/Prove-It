# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, ExprTuple, Lambda, P, PofA, Q, QofA
from proveit.logic import And, Boolean, Forall, Implies, QimplPofFalse, QimplPofTrue

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([P, Q], Conditional(Forall([A], Implies(QofA, PofA), domains = [Boolean]), And(QimplPofTrue, QimplPofFalse))))
# Out:
# expr: ((P, Q) -> {forall_{A in BOOLEAN} (Q(A) => P(A)) if Q(TRUE) => P(TRUE) ,  Q(FALSE) => P(FALSE).)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(P, Q\right) \mapsto \left\{\forall_{A \in \mathbb{B}}~\left(Q(A) \Rightarrow P(A)\right) \textrm{ if } Q(\top) \Rightarrow P(\top) ,  Q(\bot) \Rightarrow P(\bot)\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((P, Q) -> {forall_{A in BOOLEAN} (Q(A) => P(A)) if Q(TRUE) => P(TRUE) ,  Q(FALSE) => P(FALSE).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (P, Q) -> {forall_{A in BOOLEAN} (Q(A) => P(A)) if Q(TRUE) => P(TRUE) ,  Q(FALSE) => P(FALSE).
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (P, Q)
#    core type: ExprTuple
#    sub-expressions: 34, 33
# 3. {forall_{A in BOOLEAN} (Q(A) => P(A)) if Q(TRUE) => P(TRUE) ,  Q(FALSE) => P(FALSE).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{A in BOOLEAN} (Q(A) => P(A))
#    core type: Operation
#    operator: 6
#    operand: 10
# 5. (Q(TRUE) => P(TRUE)) and (Q(FALSE) => P(FALSE))
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (A -> {Q(A) => P(A) if A in BOOLEAN.)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (Q(TRUE) => P(TRUE), Q(FALSE) => P(FALSE))
# ...
