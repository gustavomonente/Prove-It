# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, ExprTuple, Lambda, P, PofA
from proveit.logic import And, Boolean, Equals, Forall, PofFalse, PofTrue, TRUE

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(P, Conditional(Equals(Forall([A], PofA, domains = [Boolean]), TRUE), And(Equals(PofTrue, TRUE), Equals(PofFalse, TRUE)))))
# Out:
# expr: (P -> {[forall_{A in BOOLEAN} P(A)] = TRUE if P(TRUE) = TRUE ,  P(FALSE) = TRUE.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(P \mapsto \left\{\left[\forall_{A \in \mathbb{B}}~P(A)\right] = \top \textrm{ if } P(\top) = \top ,  P(\bot) = \top\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (P -> {[forall_{A in BOOLEAN} P(A)] = TRUE if P(TRUE) = TRUE ,  P(FALSE) = TRUE.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. P -> {[forall_{A in BOOLEAN} P(A)] = TRUE if P(TRUE) = TRUE ,  P(FALSE) = TRUE.
#    core type: Lambda
#    parameter: 26
#    body: 2
# 2. {[forall_{A in BOOLEAN} P(A)] = TRUE if P(TRUE) = TRUE ,  P(FALSE) = TRUE.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. [forall_{A in BOOLEAN} P(A)] = TRUE
#    core type: Operation
#    operator: 14
#    operands: 5
# 4. (P(TRUE) = TRUE) and (P(FALSE) = TRUE)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (forall_{A in BOOLEAN} P(A), TRUE)
#    core type: ExprTuple
#    sub-expressions: 8, 24
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (P(TRUE) = TRUE, P(FALSE) = TRUE)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. forall_{A in BOOLEAN} P(A)
#    core type: Operation
#    operator: 11
#    operand: 16
# 9. P(TRUE) = TRUE
# ...
