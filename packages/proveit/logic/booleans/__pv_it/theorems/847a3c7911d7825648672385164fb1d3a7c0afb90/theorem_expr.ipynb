# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#true_is_bool">true_is_bool</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans import true_is_bool

# %%
# check that the built expression is the same as the stored expression
assert true_is_bool.expr == stored_expr
assert true_is_bool.expr._style_id == stored_expr._style_id
print("Passed sanity check: true_is_bool matches stored_expr")
# Out:
# Passed sanity check: true_is_bool matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(true_is_bool.latex())
# Out:
# \vdash \top \in \mathbb{B}

# %%
true_is_bool.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
true_is_bool.expr_info()
# Out:
# 0. TRUE in BOOLEAN
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (TRUE, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. TRUE
#    core type: Literal
#    sub-expressions:
# 4. BOOLEAN
#    core type: Literal
#    sub-expressions:
