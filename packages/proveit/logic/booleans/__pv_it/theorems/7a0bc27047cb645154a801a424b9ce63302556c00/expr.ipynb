# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, ExprTuple, Lambda, P, PofA
from proveit.logic import And, Boolean, Forall, PofFalse, PofTrue

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(P, Conditional(Forall([A], PofA, domains = [Boolean]), And(PofTrue, PofFalse))))
# Out:
# expr: (P -> {forall_{A in BOOLEAN} P(A) if P(TRUE) ,  P(FALSE).)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(P \mapsto \left\{\forall_{A \in \mathbb{B}}~P(A) \textrm{ if } P(\top) ,  P(\bot)\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (P -> {forall_{A in BOOLEAN} P(A) if P(TRUE) ,  P(FALSE).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. P -> {forall_{A in BOOLEAN} P(A) if P(TRUE) ,  P(FALSE).
#    core type: Lambda
#    parameter: 19
#    body: 2
# 2. {forall_{A in BOOLEAN} P(A) if P(TRUE) ,  P(FALSE).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{A in BOOLEAN} P(A)
#    core type: Operation
#    operator: 5
#    operand: 9
# 4. P(TRUE) and P(FALSE)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (A -> {P(A) if A in BOOLEAN.)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (P(TRUE), P(FALSE))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. A -> {P(A) if A in BOOLEAN.
#    core type: Lambda
#    parameter: 23
#    body: 12
# 10. P(TRUE)
#     core type: Operation
#     operator: 19
#     operand: 17
# 11. P(FALSE)
#     core type: Operation
#     operator: 19
#     operand: 18
# 12. {P(A) if A in BOOLEAN.
#     core type: Conditional
#     value: 15
#     condition: 16
# 13. (TRUE)
#     core type: ExprTuple
#     sub-expressions: 17
# 14. (FALSE)
#     core type: ExprTuple
#     sub-expressions: 18
# 15. P(A)
#     core type: Operation
#     operator: 19
#     operand: 23
# 16. A in BOOLEAN
#     core type: Operation
#     operator: 21
#     operands: 22
# 17. TRUE
#     core type: Literal
#     sub-expressions:
# 18. FALSE
#     core type: Literal
#     sub-expressions:
# 19. P
#     core type: Variable
#     sub-expressions:
# 20. (A)
#     core type: ExprTuple
#     sub-expressions: 23
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (A, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 23. A
#     core type: Variable
#     sub-expressions:
# 24. BOOLEAN
#     core type: Literal
#     sub-expressions:
