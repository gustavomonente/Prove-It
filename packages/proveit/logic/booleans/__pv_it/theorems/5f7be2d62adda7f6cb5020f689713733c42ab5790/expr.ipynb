# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, ExprTuple, Lambda
from proveit.logic import Boolean, Equals, FALSE, InSet, Or, TRUE

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(A, Conditional(InSet(A, Boolean), Or(Equals(A, TRUE), Equals(A, FALSE)))))
# Out:
# expr: (A -> {A in BOOLEAN if (A = TRUE) or (A = FALSE).)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A \mapsto \left\{A \in \mathbb{B} \textrm{ if } \left(A = \top\right) \lor \left(A = \bot\right)\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A -> {A in BOOLEAN if (A = TRUE) or (A = FALSE).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. A -> {A in BOOLEAN if (A = TRUE) or (A = FALSE).
#    core type: Lambda
#    parameter: 16
#    body: 2
# 2. {A in BOOLEAN if (A = TRUE) or (A = FALSE).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. A in BOOLEAN
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (A = TRUE) or (A = FALSE)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (A, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 16, 9
# 7. or
#    core type: Literal
#    sub-expressions:
# 8. (A = TRUE, A = FALSE)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 10. A = TRUE
#     core type: Operation
#     operator: 13
#     operands: 12
# 11. A = FALSE
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (A, TRUE)
#     core type: ExprTuple
#     sub-expressions: 16, 15
# 13. =
#     core type: Literal
#     sub-expressions:
# 14. (A, FALSE)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. TRUE
#     core type: Literal
#     sub-expressions:
# 16. A
#     core type: Variable
#     sub-expressions:
# 17. FALSE
#     core type: Literal
#     sub-expressions:
