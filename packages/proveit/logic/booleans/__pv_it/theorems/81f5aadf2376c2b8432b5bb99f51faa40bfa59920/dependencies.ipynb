# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#false_is_bool">false_is_bool</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/false_is_bool/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.logic.booleans import false_is_bool

# %%
# %dependencies false_is_bool
# Out:
# <h3>Unproven conjectures required (directly or indirectly) to prove false_is_bool</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../../sets/enumeration/_theory_nbs_/proofs/fold/thm_proof.ipynb">proveit.logic.sets.enumeration.fold</a></dt><dd><a class="ProveItLink" href="../../../../sets/enumeration/__pv_it/theorems/22e34c6090b35d0e995aaf11b862758af5d969170/expr.ipynb"><img src="../../../../sets/enumeration/__pv_it/theorems/22e34c6090b35d0e995aaf11b862758af5d969170/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# ...
