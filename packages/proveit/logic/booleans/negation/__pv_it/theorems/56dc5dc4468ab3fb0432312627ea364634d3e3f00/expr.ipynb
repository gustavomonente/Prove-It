# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.negation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A
from proveit.logic import Boolean, Forall, Not

# %%
# build up the expression from sub-expressions
expr = Forall([A], A, domains = [Boolean], condition = Not(Not(A)))
# Out:
# expr: forall_{A in BOOLEAN | not(not(A))} A

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A \in \mathbb{B}~|~\lnot (\lnot A)}~A

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{A in BOOLEAN | not(not(A))} A
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A -> {A if A in BOOLEAN ,  not(not(A)).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. A -> {A if A in BOOLEAN ,  not(not(A)).
#    core type: Lambda
#    parameter: 17
#    body: 4
# 4. {A if A in BOOLEAN ,  not(not(A)).
#    core type: Conditional
#    value: 17
#    condition: 5
# 5. (A in BOOLEAN) and not(not(A))
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (A in BOOLEAN, not(not(A)))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. A in BOOLEAN
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. not(not(A))
#    core type: Operation
#    operator: 15
#    operand: 14
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (A, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 17, 13
# 12. (not(A))
#     core type: ExprTuple
#     sub-expressions: 14
# 13. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 14. not(A)
#     core type: Operation
#     operator: 15
#     operand: 17
# 15. not
#     core type: Literal
#     sub-expressions:
# 16. (A)
#     core type: ExprTuple
#     sub-expressions: 17
# 17. A
#     core type: Variable
#     sub-expressions:
