# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#iff_closure">iff_closure</a> theorem
# ========

# %%
import proveit
# we need to import true_iff_false_negated and false_iff_true_negated
# to derive their side-effects:
from proveit.logic.booleans.implication import true_iff_true, true_iff_false_negated
from proveit.logic.booleans.implication import false_iff_false, false_iff_true_negated
theory = proveit.Theory() # the theorem's theory

# %%
# %proving iff_closure
# Out:
# iff_closure: forall_{A, B in BOOLEAN} ((A <=> B) in BOOLEAN)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{A, B in BOOLEAN} ((A <=> B) in BOOLEAN)
# 1	instantiation	3, 4, 5, 6	|- [forall_{A in BOOLEAN} [forall_{B in BOOLEAN} ((A <=> B) in BOOLEAN)]] => [forall_{A, B in BOOLEAN} ((A <=> B) in BOOLEAN)]
# 	m : 1, n : 1, P(A, B) : (A <=> B) in BOOLEAN, Q(A) : A in BOOLEAN, R(A, B) : B in BOOLEAN, (x_{1}, ..x_{_a}.., x_{1}) : (A), (y_{1}, ..y_{_a}.., y_{1}) : (B)
# 2	instantiation	12, 7, 8	|- forall_{A in BOOLEAN} [forall_{B in BOOLEAN} ((A <=> B) in BOOLEAN)]
# 	P(A) : forall_{B in BOOLEAN} ((A <=> B) in BOOLEAN), A : A
# 3	conjecture		|- forall_{m, n in NaturalPos} [forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]] \\  => [forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})])]
# 4	instantiation	9	|- |(A)| = |(1, ..k.., 1)|
# 	a : A
# 5	instantiation	9	|- |(B)| = |(1, ..k.., 1)|
# 	a : B
# 6	conjecture		|- 1 in NaturalPos
# 7	instantiation	12, 10, 11	|- forall_{B in BOOLEAN} ((TRUE <=> B) in BOOLEAN)
# 	P(B) : (TRUE <=> B) in BOOLEAN, A : B
# 8	instantiation	12, 13, 14	|- forall_{B in BOOLEAN} ((FALSE <=> B) in BOOLEAN)
# 	P(B) : (FALSE <=> B) in BOOLEAN, A : B
# 9	conjecture		|- forall_{a} (|(a)| = |(1, ..k.., 1)|)
# 10	instantiation	21, 22, 15	|- (TRUE <=> TRUE) in BOOLEAN
# 	P(_a) : _a in BOOLEAN, x : TRUE <=> TRUE
# 11	instantiation	17, 16	|- (TRUE <=> FALSE) in BOOLEAN
# 	A : TRUE <=> FALSE
# 12	conjecture		|- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEAN} P(A)]
# 13	instantiation	17, 18	|- (FALSE <=> TRUE) in BOOLEAN
# 	A : FALSE <=> TRUE
# 14	instantiation	21, 22, 19	|- (FALSE <=> FALSE) in BOOLEAN
# 	P(_a) : _a in BOOLEAN, x : FALSE <=> FALSE
# 15	theorem		|- TRUE <=> TRUE
# 	proveit.logic.booleans.implication.true_iff_true
# 16	instantiation	21, 22, 20	|- not(TRUE <=> FALSE) in BOOLEAN
# 	P(_a) : _a in BOOLEAN, x : not(TRUE <=> FALSE)
# 17	axiom		|- forall_{A | not(A) in BOOLEAN} (A in BOOLEAN)
# 	proveit.logic.booleans.negation.operand_is_bool
# 18	instantiation	21, 22, 23	|- not(FALSE <=> TRUE) in BOOLEAN
# 	P(_a) : _a in BOOLEAN, x : not(FALSE <=> TRUE)
# 19	theorem		|- FALSE <=> FALSE
# 	proveit.logic.booleans.implication.false_iff_false
# 20	theorem		|- not(TRUE <=> FALSE)
# 	proveit.logic.booleans.implication.true_iff_false_negated
# 21	theorem		|- forall_{P, x | P(TRUE), x} P(x)
# 	proveit.logic.equality.substitute_truth
# 22	conjecture		|- TRUE in BOOLEAN
# 23	theorem		|- not(FALSE <=> TRUE)
# 	proveit.logic.booleans.implication.false_iff_true_negated
