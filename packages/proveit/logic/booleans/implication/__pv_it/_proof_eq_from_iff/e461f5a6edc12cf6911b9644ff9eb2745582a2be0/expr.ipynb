# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, ExprRange, k
from proveit.core_expr_types import Len
from proveit.logic import Boolean, Equals, Iff, InSet
from proveit.numbers import one, two

# %%
# build up the expression from sub-expressions
expr = Equals(Len([InSet(B, Boolean), Iff(A, B)]), Len([ExprRange(k, k, one, two)]))
# Out:
# expr: |(B in BOOLEAN, A <=> B)| = |(1, ..k.., 2)|

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(B \in \mathbb{B}, A \Leftrightarrow B\right)| = |\left(1, \ldots, 2\right)|

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |(B in BOOLEAN, A <=> B)| = |(1, ..k.., 2)|
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|(B in BOOLEAN, A <=> B)|, |(1, ..k.., 2)|)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |(B in BOOLEAN, A <=> B)|
#    core type: Operation
#    operator: 6
#    operand: 8
# 4. |(1, ..k.., 2)|
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. ((B in BOOLEAN, A <=> B))
#    core type: ExprTuple
#    sub-expressions: 8
# 6. length
#    core type: Literal
#    sub-expressions:
# 7. ((1, ..k.., 2))
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (B in BOOLEAN, A <=> B)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. (1, ..k.., 2)
#    core type: ExprTuple
#    sub-expressions: 12
# 10. B in BOOLEAN
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. A <=> B
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. 1, ..k.., 2
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 18
#     end_index: 19
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 22, 20
# 15. <=>
#     core type: Literal
#     sub-expressions:
# 16. (A, B)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 17. k -> k
#     core type: Lambda
#     parameter: 23
#     body: 23
# 18. 1
#     core type: Literal
#     sub-expressions:
# 19. 2
#     core type: Literal
#     sub-expressions:
# 20. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 21. A
#     core type: Variable
#     sub-expressions:
# 22. B
#     core type: Variable
#     sub-expressions:
# 23. k
#     core type: Variable
#     sub-expressions:
