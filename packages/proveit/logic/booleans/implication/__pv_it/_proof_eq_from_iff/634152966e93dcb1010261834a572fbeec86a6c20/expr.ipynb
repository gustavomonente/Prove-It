# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, ExprTuple, Lambda
from proveit.logic import Boolean, Equals, Forall, Iff, InSet

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(A, Conditional(Forall([B], Equals(A, B), domains = [Boolean], condition = Iff(A, B)), InSet(A, Boolean))))
# Out:
# expr: (A -> {forall_{B in BOOLEAN | A <=> B} (A = B) if A in BOOLEAN.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A \mapsto \left\{\forall_{B \in \mathbb{B}~|~A \Leftrightarrow B}~\left(A = B\right) \textrm{ if } A \in \mathbb{B}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A -> {forall_{B in BOOLEAN | A <=> B} (A = B) if A in BOOLEAN.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. A -> {forall_{B in BOOLEAN | A <=> B} (A = B) if A in BOOLEAN.
#    core type: Lambda
#    parameter: 22
#    body: 2
# 2. {forall_{B in BOOLEAN | A <=> B} (A = B) if A in BOOLEAN.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{B in BOOLEAN | A <=> B} (A = B)
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. A in BOOLEAN
#    core type: Operation
#    operator: 17
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (B -> {A = B if B in BOOLEAN ,  A <=> B.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (A, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 22, 21
# 8. B -> {A = B if B in BOOLEAN ,  A <=> B.
#    core type: Lambda
#    parameter: 23
#    body: 9
# 9. {A = B if B in BOOLEAN ,  A <=> B.
#    core type: Conditional
#    value: 10
#    condition: 11
# 10. A = B
#     core type: Operation
#     operator: 12
#     operands: 20
# 11. (B in BOOLEAN) and (A <=> B)
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. =
#     core type: Literal
#     sub-expressions:
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. (B in BOOLEAN, A <=> B)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. B in BOOLEAN
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. A <=> B
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 23, 21
# 19. <=>
#     core type: Literal
#     sub-expressions:
# 20. (A, B)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 21. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 22. A
#     core type: Variable
#     sub-expressions:
# 23. B
#     core type: Variable
#     sub-expressions:
