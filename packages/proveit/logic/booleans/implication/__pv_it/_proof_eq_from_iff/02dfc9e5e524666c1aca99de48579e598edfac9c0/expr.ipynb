# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B, Conditional, ExprTuple, Lambda
from proveit.logic import And, Boolean, Equals, Iff, InSet, TRUE

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(B, Conditional(Equals(TRUE, B), And(InSet(B, Boolean), Iff(TRUE, B)))))
# Out:
# expr: (B -> {TRUE = B if B in BOOLEAN ,  TRUE <=> B.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(B \mapsto \left\{\top = B \textrm{ if } B \in \mathbb{B} ,  \top \Leftrightarrow B\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (B -> {TRUE = B if B in BOOLEAN ,  TRUE <=> B.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. B -> {TRUE = B if B in BOOLEAN ,  TRUE <=> B.
#    core type: Lambda
#    parameter: 16
#    body: 2
# 2. {TRUE = B if B in BOOLEAN ,  TRUE <=> B.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. TRUE = B
#    core type: Operation
#    operator: 5
#    operands: 13
# 4. (B in BOOLEAN) and (TRUE <=> B)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (B in BOOLEAN, TRUE <=> B)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. B in BOOLEAN
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. TRUE <=> B
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 16, 14
# 12. <=>
#     core type: Literal
#     sub-expressions:
# 13. (TRUE, B)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 15. TRUE
#     core type: Literal
#     sub-expressions:
# 16. B
#     core type: Variable
#     sub-expressions:
