# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, ExprTuple, Lambda
from proveit.logic import Boolean, FALSE, Implies, InSet

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(A, Conditional(Implies(FALSE, A), InSet(A, Boolean))))
# Out:
# expr: (A -> {FALSE => A if A in BOOLEAN.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A \mapsto \left\{\bot \Rightarrow A \textrm{ if } A \in \mathbb{B}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A -> {FALSE => A if A in BOOLEAN.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. A -> {FALSE => A if A in BOOLEAN.
#    core type: Lambda
#    parameter: 10
#    body: 2
# 2. {FALSE => A if A in BOOLEAN.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. FALSE => A
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. A in BOOLEAN
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =>
#    core type: Literal
#    sub-expressions:
# 6. (FALSE, A)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (A, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. FALSE
#    core type: Literal
#    sub-expressions:
# 10. A
#     core type: Variable
#     sub-expressions:
# 11. BOOLEAN
#     core type: Literal
#     sub-expressions:
