# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B
from proveit.logic import Boolean, Forall, Implies, InSet, Not

# %%
# build up the expression from sub-expressions
expr = Forall([A, B], Implies(A, B), conditions = [Implies(Not(B), Not(A)), InSet(B, Boolean)])
# Out:
# expr: forall_{A, B | not(B) => not(A), B in BOOLEAN} (A => B)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A, B~|~(\lnot B) \Rightarrow (\lnot A), B \in \mathbb{B}}~\left(A \Rightarrow B\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{A, B | not(B) => not(A), B in BOOLEAN} (A => B)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((A, B) -> {A => B if not(B) => not(A) ,  B in BOOLEAN.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (A, B) -> {A => B if not(B) => not(A) ,  B in BOOLEAN.
#    core type: Lambda
#    parameters: 7\n   body: 4
# 4. {A => B if not(B) => not(A) ,  B in BOOLEAN.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. A => B
#    core type: Operation
#    operator: 12
#    operands: 7
# 6. (not(B) => not(A)) and (B in BOOLEAN)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (A, B)
#    core type: ExprTuple
#    sub-expressions: 23, 22
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (not(B) => not(A), B in BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. not(B) => not(A)
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. B in BOOLEAN
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. =>
#     core type: Literal
#     sub-expressions:
# 13. (not(B), not(A))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 22, 18
# 16. not(B)
#     core type: Operation
#     operator: 20
#     operand: 22
# 17. not(A)
#     core type: Operation
#     operator: 20
#     operand: 23
# 18. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 19. (B)
#     core type: ExprTuple
#     sub-expressions: 22
# 20. not
#     core type: Literal
#     sub-expressions:
# 21. (A)
#     core type: ExprTuple
#     sub-expressions: 23
# 22. B
#     core type: Variable
#     sub-expressions:
# 23. A
#     core type: Variable
#     sub-expressions:
