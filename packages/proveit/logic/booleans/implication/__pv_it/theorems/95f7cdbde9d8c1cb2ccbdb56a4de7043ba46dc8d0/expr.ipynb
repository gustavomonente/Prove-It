# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, Conditional, ExprTuple, Lambda
from proveit.logic import And, Implies

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([A, B, C], Conditional(Implies(A, C), And(Implies(A, B), Implies(B, C)))))
# Out:
# expr: ((A, B, C) -> {A => C if A => B ,  B => C.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(A, B, C\right) \mapsto \left\{A \Rightarrow C \textrm{ if } A \Rightarrow B ,  B \Rightarrow C\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((A, B, C) -> {A => C if A => B ,  B => C.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (A, B, C) -> {A => C if A => B ,  B => C.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (A, B, C)
#    core type: ExprTuple
#    sub-expressions: 14, 15, 16
# 3. {A => C if A => B ,  B => C.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. A => C
#    core type: Operation
#    operator: 12
#    operands: 6
# 5. (A => B) and (B => C)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (A, C)
#    core type: ExprTuple
#    sub-expressions: 14, 16
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (A => B, B => C)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. A => B
#    core type: Operation
#    operator: 12
#    operands: 11
# 10. B => C
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (A, B)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. =>
#     core type: Literal
#     sub-expressions:
# 13. (B, C)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. A
#     core type: Variable
#     sub-expressions:
# 15. B
#     core type: Variable
#     sub-expressions:
# 16. C
#     core type: Variable
#     sub-expressions:
