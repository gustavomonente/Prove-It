# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#implication_closure">implication_closure</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.implication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.implication import implication_closure

# %%
# check that the built expression is the same as the stored expression
assert implication_closure.expr == stored_expr
assert implication_closure.expr._style_id == stored_expr._style_id
print("Passed sanity check: implication_closure matches stored_expr")
# Out:
# Passed sanity check: implication_closure matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(implication_closure.latex())
# Out:
# \vdash \forall_{A, B \in \mathbb{B}}~\left(\left(A \Rightarrow B\right) \in \mathbb{B}\right)

# %%
implication_closure.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
implication_closure.expr_info()
# Out:
# 0. forall_{A, B in BOOLEAN} ((A => B) in BOOLEAN)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((A, B) -> {(A => B) in BOOLEAN if A in BOOLEAN ,  B in BOOLEAN.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (A, B) -> {(A => B) in BOOLEAN if A in BOOLEAN ,  B in BOOLEAN.
#    core type: Lambda
#    parameters: 14\n   body: 4
# 4. {(A => B) in BOOLEAN if A in BOOLEAN ,  B in BOOLEAN.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (A => B) in BOOLEAN
#    core type: Operation
#    operator: 16
#    operands: 7
# 6. (A in BOOLEAN) and (B in BOOLEAN)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (A => B, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 10, 20
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (A in BOOLEAN, B in BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. A => B
#     core type: Operation
#     operator: 13
# ...
