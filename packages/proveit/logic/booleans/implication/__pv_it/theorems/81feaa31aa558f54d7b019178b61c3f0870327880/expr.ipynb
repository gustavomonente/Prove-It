# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional
from proveit.logic import Iff, Implies, Not

# %%
# build up the expression from sub-expressions
expr = Conditional(Not(Iff(A, B)), Not(Implies(A, B)))
# Out:
# expr: {not(A <=> B) if not(A => B).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\lnot \left(A \Leftrightarrow B\right) \textrm{ if } \lnot \left(A \Rightarrow B\right)\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {not(A <=> B) if not(A => B).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. not(A <=> B)
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. not(A => B)
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. (A <=> B)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. not
#    core type: Literal
#    sub-expressions:
# 5. (A => B)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. A <=> B
#    core type: Operation
#    operator: 8
#    operands: 10
# 7. A => B
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. <=>
#    core type: Literal
#    sub-expressions:
# 9. =>
#    core type: Literal
#    sub-expressions:
# 10. (A, B)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. A
#     core type: Variable
#     sub-expressions:
# 12. B
#     core type: Variable
#     sub-expressions:
