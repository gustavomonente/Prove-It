# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, ExprTuple, Lambda
from proveit.logic import Boolean, Iff, InSet

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(B, Conditional(InSet(Iff(A, B), Boolean), InSet(B, Boolean))))
# Out:
# expr: (B -> {(A <=> B) in BOOLEAN if B in BOOLEAN.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(B \mapsto \left\{\left(A \Leftrightarrow B\right) \in \mathbb{B} \textrm{ if } B \in \mathbb{B}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (B -> {(A <=> B) in BOOLEAN if B in BOOLEAN.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. B -> {(A <=> B) in BOOLEAN if B in BOOLEAN.
#    core type: Lambda
#    parameter: 13
#    body: 2
# 2. {(A <=> B) in BOOLEAN if B in BOOLEAN.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (A <=> B) in BOOLEAN
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. B in BOOLEAN
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (A <=> B, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (B, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 13, 9
# 8. A <=> B
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 10. <=>
#     core type: Literal
#     sub-expressions:
# 11. (A, B)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. A
#     core type: Variable
#     sub-expressions:
# 13. B
#     core type: Variable
#     sub-expressions:
