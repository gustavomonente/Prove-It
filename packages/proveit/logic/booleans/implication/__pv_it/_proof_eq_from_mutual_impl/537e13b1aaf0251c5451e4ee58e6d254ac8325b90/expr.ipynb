# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, Lambda
from proveit.logic import Boolean, Equals, Forall, Implies, InSet

# %%
# build up the expression from sub-expressions
expr = Lambda(A, Conditional(Forall([B], Equals(A, B), domains = [Boolean], conditions = [Implies(A, B), Implies(B, A)]), InSet(A, Boolean)))
# Out:
# expr: A -> {forall_{B in BOOLEAN | A => B, B => A} (A = B) if A in BOOLEAN.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# A \mapsto \left\{\forall_{B \in \mathbb{B}~|~A \Rightarrow B, B \Rightarrow A}~\left(A = B\right) \textrm{ if } A \in \mathbb{B}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. A -> {forall_{B in BOOLEAN | A => B, B => A} (A = B) if A in BOOLEAN.
#    core type: Lambda
#    parameter: 24
#    body: 1
# 1. {forall_{B in BOOLEAN | A => B, B => A} (A = B) if A in BOOLEAN.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{B in BOOLEAN | A => B, B => A} (A = B)
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. A in BOOLEAN
#    core type: Operation
#    operator: 17
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (B -> {A = B if B in BOOLEAN ,  A => B ,  B => A.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (A, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 24, 22
# 7. B -> {A = B if B in BOOLEAN ,  A => B ,  B => A.
#    core type: Lambda
#    parameter: 23
#    body: 8
# 8. {A = B if B in BOOLEAN ,  A => B ,  B => A.
#    core type: Conditional
#    value: 9
#    condition: 10
# 9. A = B
#    core type: Operation
#    operator: 11
#    operands: 19
# 10. (B in BOOLEAN) and (A => B) and (B => A)
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. and
#     core type: Literal
#     sub-expressions:
# 13. (B in BOOLEAN, A => B, B => A)
#     core type: ExprTuple
#     sub-expressions: 14, 15, 16
# 14. B in BOOLEAN
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. A => B
#     core type: Operation
#     operator: 20
#     operands: 19
# 16. B => A
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 23, 22
# 19. (A, B)
#     core type: ExprTuple
#     sub-expressions: 24, 23
# 20. =>
#     core type: Literal
#     sub-expressions:
# 21. (B, A)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 22. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 23. B
#     core type: Variable
#     sub-expressions:
# 24. A
#     core type: Variable
#     sub-expressions:
