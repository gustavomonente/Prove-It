# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B, Conditional, ExprTuple
from proveit.logic import And, Boolean, Equals, Implies, InSet, TRUE

# %%
# build up the expression from sub-expressions
sub_expr1 = Equals(TRUE, B)
sub_expr2 = InSet(B, Boolean)
sub_expr3 = Implies(TRUE, B)
sub_expr4 = Implies(B, TRUE)
expr = ExprTuple(Conditional(sub_expr1, And(sub_expr2, And(sub_expr3, sub_expr4))), Conditional(sub_expr1, And(sub_expr2, sub_expr3, sub_expr4)))
# Out:
# expr: (TRUE = B if B in BOOLEAN ,  (TRUE => B) and (B => TRUE), TRUE = B if B in BOOLEAN ,  TRUE => B ,  B => TRUE)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\top = B \textrm{ if } B \in \mathbb{B} ,  \left(\top \Rightarrow B\right) \land \left(B \Rightarrow \top\right), \top = B \textrm{ if } B \in \mathbb{B} ,  \top \Rightarrow B ,  B \Rightarrow \top\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (TRUE = B if B in BOOLEAN ,  (TRUE => B) and (B => TRUE), TRUE = B if B in BOOLEAN ,  TRUE => B ,  B => TRUE)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. {TRUE = B if B in BOOLEAN ,  (TRUE => B) and (B => TRUE).
#    core type: Conditional
#    value: 4
#    condition: 3
# 2. {TRUE = B if B in BOOLEAN ,  TRUE => B ,  B => TRUE.
#    core type: Conditional
#    value: 4
#    condition: 5
# 3. (B in BOOLEAN) and ((TRUE => B) and (B => TRUE))
#    core type: Operation
#    operator: 11
#    operands: 6
# 4. TRUE = B
#    core type: Operation
#    operator: 7
#    operands: 18
# 5. (B in BOOLEAN) and (TRUE => B) and (B => TRUE)
#    core type: Operation
#    operator: 11
#    operands: 8
# 6. (B in BOOLEAN, (TRUE => B) and (B => TRUE))
#    core type: ExprTuple
#    sub-expressions: 10, 9
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (B in BOOLEAN, TRUE => B, B => TRUE)
#    core type: ExprTuple
#    sub-expressions: 10, 15, 16
# 9. (TRUE => B) and (B => TRUE)
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. B in BOOLEAN
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. and
#     core type: Literal
#     sub-expressions:
# 12. (TRUE => B, B => TRUE)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 21, 17
# 15. TRUE => B
#     core type: Operation
#     operator: 19
#     operands: 18
# 16. B => TRUE
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 18. (TRUE, B)
#     core type: ExprTuple
#     sub-expressions: 22, 21
# 19. =>
#     core type: Literal
#     sub-expressions:
# 20. (B, TRUE)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 21. B
#     core type: Variable
#     sub-expressions:
# 22. TRUE
#     core type: Literal
#     sub-expressions:
