# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B
from proveit.core_expr_types import A_1_to_m
from proveit.logic import And, Equals, Forall

# %%
# build up the expression from sub-expressions
expr = Forall([A_1_to_m, B], Equals(And(A_1_to_m, B), And(And(A_1_to_m), B)).with_wrapping_at(2))
# Out:
# expr: forall_{A_{1}, ..A_{_a}.., A_{m}, B} ((A_{1} and ..A_{_a}.. and A_{m} and B) =  \\ ((A_{1} and ..A_{_a}.. and A_{m}) and B))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A_{1}, \ldots, A_{m}, B}~\left(\begin{array}{c} \begin{array}{l} \left(A_{1} \land \ldots \land A_{m} \land B\right) =  \\ \left(\left(A_{1} \land \ldots \land A_{m}\right) \land B\right) \end{array} \end{array}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{A_{1}, ..A_{_a}.., A_{m}, B} ((A_{1} and ..A_{_a}.. and A_{m} and B) =  \\ ((A_{1} and ..A_{_a}.. and A_{m}) and B))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((A_{1}, ..A_{_a}.., A_{m}, B) -> ((A_{1} and ..A_{_a}.. and A_{m} and B) =  \\ ((A_{1} and ..A_{_a}.. and A_{m}) and B)))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (A_{1}, ..A_{_a}.., A_{m}, B) -> ((A_{1} and ..A_{_a}.. and A_{m} and B) =  \\ ((A_{1} and ..A_{_a}.. and A_{m}) and B))
#    core type: Lambda
#    parameters: 9\n   body: 4
# 4. (A_{1} and ..A_{_a}.. and A_{m} and B) =  \\ ((A_{1} and ..A_{_a}.. and A_{m}) and B)
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (A_{1} and ..A_{_a}.. and A_{m} and B, (A_{1} and ..A_{_a}.. and A_{m}) and B)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. A_{1} and ..A_{_a}.. and A_{m} and B
#    core type: Operation
#    operator: 13
#    operands: 9
# 8. (A_{1} and ..A_{_a}.. and A_{m}) and B
#    core type: Operation
#    operator: 13
#    operands: 10
# 9. (A_{1}, ..A_{_a}.., A_{m}, B)
#    core type: ExprTuple
#    sub-expressions: 15, 12
# 10. (A_{1} and ..A_{_a}.. and A_{m}, B)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. A_{1} and ..A_{_a}.. and A_{m}
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. B
#     core type: Variable
#     sub-expressions:
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 15
# 15. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 17
#     end_index: 18
# 16. _a -> A_{_a}
#     core type: Lambda
#     parameter: 22
#     body: 19
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. m
#     core type: Variable
#     sub-expressions:
# 19. A_{_a}
#     core type: IndexedVar
# variable: 20
# index: 22
# 20. A
#     core type: Variable
#     sub-expressions:
# 21. (_a)
#     core type: ExprTuple
#     sub-expressions: 22
# 22. _a
#     core type: Variable
#     sub-expressions:
