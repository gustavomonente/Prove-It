# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B, Lambda
from proveit.core_expr_types import A_1_to_m
from proveit.logic import And, Equals

# %%
# build up the expression from sub-expressions
expr = Lambda([A_1_to_m, B], Equals(And(A_1_to_m, B), And(And(A_1_to_m), B)).with_wrapping_at(2))
# Out:
# expr: (A_{1}, ..A_{_a}.., A_{m}, B) -> ((A_{1} and ..A_{_a}.. and A_{m} and B) =  \\ ((A_{1} and ..A_{_a}.. and A_{m}) and B))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{1}, \ldots, A_{m}, B\right) \mapsto \left(\begin{array}{c} \begin{array}{l} \left(A_{1} \land \ldots \land A_{m} \land B\right) =  \\ \left(\left(A_{1} \land \ldots \land A_{m}\right) \land B\right) \end{array} \end{array}\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A_{1}, ..A_{_a}.., A_{m}, B) -> ((A_{1} and ..A_{_a}.. and A_{m} and B) =  \\ ((A_{1} and ..A_{_a}.. and A_{m}) and B))
#    core type: Lambda
#    parameters: 6\n   body: 1
# 1. (A_{1} and ..A_{_a}.. and A_{m} and B) =  \\ ((A_{1} and ..A_{_a}.. and A_{m}) and B)
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. =
#    core type: Literal
#    sub-expressions:
# 3. (A_{1} and ..A_{_a}.. and A_{m} and B, (A_{1} and ..A_{_a}.. and A_{m}) and B)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. A_{1} and ..A_{_a}.. and A_{m} and B
#    core type: Operation
#    operator: 10
#    operands: 6
# 5. (A_{1} and ..A_{_a}.. and A_{m}) and B
#    core type: Operation
#    operator: 10
#    operands: 7
# 6. (A_{1}, ..A_{_a}.., A_{m}, B)
#    core type: ExprTuple
#    sub-expressions: 12, 9
# 7. (A_{1} and ..A_{_a}.. and A_{m}, B)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. A_{1} and ..A_{_a}.. and A_{m}
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. B
#    core type: Variable
#    sub-expressions:
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 12
# 12. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 14
#     end_index: 15
# 13. _a -> A_{_a}
#     core type: Lambda
#     parameter: 19
#     body: 16
# 14. 1
#     core type: Literal
#     sub-expressions:
# 15. m
#     core type: Variable
#     sub-expressions:
# 16. A_{_a}
#     core type: IndexedVar
# variable: 17
# index: 19
# 17. A
#     core type: Variable
#     sub-expressions:
# 18. (_a)
#     core type: ExprTuple
#     sub-expressions: 19
# 19. _a
#     core type: Variable
#     sub-expressions:
