# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#multi_conjunction_def">multi_conjunction_def</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.conjunction import multi_conjunction_def

# %%
# check that the built expression is the same as the stored expression
assert multi_conjunction_def.expr == stored_expr
assert multi_conjunction_def.expr._style_id == stored_expr._style_id
print("Passed sanity check: multi_conjunction_def matches stored_expr")
# Out:
# Passed sanity check: multi_conjunction_def matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(multi_conjunction_def.latex())
# Out:
# \vdash \forall_{m \in \mathbb{N}}~\left[\forall_{A_{1}, \ldots, A_{m}, B}~\left(\begin{array}{c} \begin{array}{l} \left(A_{1} \land \ldots \land A_{m} \land B\right) =  \\ \left(\left(A_{1} \land \ldots \land A_{m}\right) \land B\right) \end{array} \end{array}\right)\right]

# %%
multi_conjunction_def.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
multi_conjunction_def.expr_info()
# Out:
# 0. forall_{m in Natural} [forall_{A_{1}, ..A_{_a}.., A_{m}, B} ((A_{1} and ..A_{_a}.. and A_{m} and B) =  \\ ((A_{1} and ..A_{_a}.. and A_{m}) and B))]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (m -> {forall_{A_{1}, ..A_{_a}.., A_{m}, B} ((A_{1} and ..A_{_a}.. and A_{m} and B) =  \\ ((A_{1} and ..A_{_a}.. and A_{m}) and B)) if m in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. m -> {forall_{A_{1}, ..A_{_a}.., A_{m}, B} ((A_{1} and ..A_{_a}.. and A_{m} and B) =  \\ ((A_{1} and ..A_{_a}.. and A_{m}) and B)) if m in Natural.
#    core type: Lambda
#    parameter: 26
#    body: 3
# 3. {forall_{A_{1}, ..A_{_a}.., A_{m}, B} ((A_{1} and ..A_{_a}.. and A_{m} and B) =  \\ ((A_{1} and ..A_{_a}.. and A_{m}) and B)) if m in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{A_{1}, ..A_{_a}.., A_{m}, B} ((A_{1} and ..A_{_a}.. and A_{m} and B) =  \\ ((A_{1} and ..A_{_a}.. and A_{m}) and B))
#    core type: Operation
# ...
