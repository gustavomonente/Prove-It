# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, ExprRange, ExprTuple, IndexedVar, a, k, m
from proveit.core_expr_types import Len
from proveit.numbers import Add, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([ExprRange(a, IndexedVar(A, a), one, m), B]), Len([ExprRange(k, k, one, Add(m, one))]))
# Out:
# expr: (|(A_{1}, ..A_{a}.., A_{m}, B)|, |(1, ..k.., m + 1)|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(A_{1}, \ldots, A_{m}, B\right)|, |\left(1, \ldots, m + 1\right)|\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|(A_{1}, ..A_{a}.., A_{m}, B)|, |(1, ..k.., m + 1)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(A_{1}, ..A_{a}.., A_{m}, B)|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..k.., m + 1)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((A_{1}, ..A_{a}.., A_{m}, B))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..k.., m + 1))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (A_{1}, ..A_{a}.., A_{m}, B)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (1, ..k.., m + 1)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. A_{1}, ..A_{a}.., A_{m}
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 21
#    end_index: 20
# 9. B
#    core type: Variable
#    sub-expressions:
# 10. 1, ..k.., (m + 1)
#     core type: ExprRange
#     lambda_map: 12
#     start_index: 21
#     end_index: 13
# 11. a -> A_{a}
#     core type: Lambda
#     parameter: 22
#     body: 14
# 12. k -> k
#     core type: Lambda
#     parameter: 15
#     body: 15
# 13. m + 1
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. A_{a}
#     core type: IndexedVar
# variable: 18
# index: 22
# 15. k
#     core type: Variable
#     sub-expressions:
# 16. +
#     core type: Literal
#     sub-expressions:
# 17. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. A
#     core type: Variable
#     sub-expressions:
# 19. (a)
#     core type: ExprTuple
#     sub-expressions: 22
# 20. m
#     core type: Variable
#     sub-expressions:
# 21. 1
#     core type: Literal
#     sub-expressions:
# 22. a
#     core type: Variable
#     sub-expressions:
