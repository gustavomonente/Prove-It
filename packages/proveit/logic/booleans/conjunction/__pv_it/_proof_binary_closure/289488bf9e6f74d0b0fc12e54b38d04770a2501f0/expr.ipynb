# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional
from proveit.logic import And, Boolean, Forall, InSet

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([B], InSet(And(A, B), Boolean), domains = [Boolean]), InSet(A, Boolean))
# Out:
# expr: {forall_{B in BOOLEAN} ((A and B) in BOOLEAN) if A in BOOLEAN.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{B \in \mathbb{B}}~\left(\left(A \land B\right) \in \mathbb{B}\right) \textrm{ if } A \in \mathbb{B}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{B in BOOLEAN} ((A and B) in BOOLEAN) if A in BOOLEAN.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{B in BOOLEAN} ((A and B) in BOOLEAN)
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. A in BOOLEAN
#    core type: Operation
#    operator: 11
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (B -> {(A and B) in BOOLEAN if B in BOOLEAN.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (A, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 17, 14
# 6. B -> {(A and B) in BOOLEAN if B in BOOLEAN.
#    core type: Lambda
#    parameter: 18
#    body: 7
# 7. {(A and B) in BOOLEAN if B in BOOLEAN.
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. (A and B) in BOOLEAN
#    core type: Operation
#    operator: 11
#    operands: 10
# 9. B in BOOLEAN
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (A and B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 18, 14
# 13. A and B
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 15. and
#     core type: Literal
#     sub-expressions:
# 16. (A, B)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. A
#     core type: Variable
#     sub-expressions:
# 18. B
#     core type: Variable
#     sub-expressions:
