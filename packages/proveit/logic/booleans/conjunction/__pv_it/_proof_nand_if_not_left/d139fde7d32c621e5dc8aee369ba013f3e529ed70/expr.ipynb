# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B
from proveit.logic import And, Boolean, Forall, Implies, Not

# %%
# build up the expression from sub-expressions
sub_expr1 = [Boolean]
sub_expr2 = Not(A)
sub_expr3 = Not(And(A, B))
expr = Implies(Forall([A], Forall([B], sub_expr3, domains = sub_expr1, condition = sub_expr2), domains = sub_expr1), Forall([A, B], sub_expr3, domains = [Boolean, Boolean], condition = sub_expr2))
# Out:
# expr: [forall_{A in BOOLEAN} [forall_{B in BOOLEAN | not(A)} not(A and B)]] => [forall_{A, B in BOOLEAN | not(A)} not(A and B)]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left[\forall_{A \in \mathbb{B}}~\left[\forall_{B \in \mathbb{B}~|~\lnot A}~(\lnot \left(A \land B\right))\right]\right] \Rightarrow \left[\forall_{A, B \in \mathbb{B}~|~\lnot A}~(\lnot \left(A \land B\right))\right]

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. [forall_{A in BOOLEAN} [forall_{B in BOOLEAN | not(A)} not(A and B)]] => [forall_{A, B in BOOLEAN | not(A)} not(A and B)]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{A in BOOLEAN} [forall_{B in BOOLEAN | not(A)} not(A and B)], forall_{A, B in BOOLEAN | not(A)} not(A and B))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{A in BOOLEAN} [forall_{B in BOOLEAN | not(A)} not(A and B)]
#    core type: Operation
#    operator: 13
#    operand: 7
# 4. forall_{A, B in BOOLEAN | not(A)} not(A and B)
#    core type: Operation
#    operator: 13
#    operand: 8
# 5. (A -> {forall_{B in BOOLEAN | not(A)} not(A and B) if A in BOOLEAN.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. ((A, B) -> {not(A and B) if A in BOOLEAN ,  B in BOOLEAN ,  not(A).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. A -> {forall_{B in BOOLEAN | not(A)} not(A and B) if A in BOOLEAN.
#    core type: Lambda
#    parameter: 35
#    body: 9
# 8. (A, B) -> {not(A and B) if A in BOOLEAN ,  B in BOOLEAN ,  not(A).
#    core type: Lambda
#    parameters: 28\n   body: 10
# 9. {forall_{B in BOOLEAN | not(A)} not(A and B) if A in BOOLEAN.
#    core type: Conditional
#    value: 11
#    condition: 17
# 10. {not(A and B) if A in BOOLEAN ,  B in BOOLEAN ,  not(A).
#     core type: Conditional
#     value: 20
#     condition: 12
# 11. forall_{B in BOOLEAN | not(A)} not(A and B)
#     core type: Operation
#     operator: 13
#     operand: 16
# 12. (A in BOOLEAN) and (B in BOOLEAN) and not(A)
#     core type: Operation
#     operator: 27
#     operands: 15
# 13. forall
#     core type: Literal
#     sub-expressions:
# 14. (B -> {not(A and B) if B in BOOLEAN ,  not(A).)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. (A in BOOLEAN, B in BOOLEAN, not(A))
#     core type: ExprTuple
#     sub-expressions: 17, 25, 26
# 16. B -> {not(A and B) if B in BOOLEAN ,  not(A).
#     core type: Lambda
#     parameter: 33
#     body: 18
# 17. A in BOOLEAN
#     core type: Operation
#     operator: 29
#     operands: 19
# 18. {not(A and B) if B in BOOLEAN ,  not(A).
#     core type: Conditional
#     value: 20
#     condition: 21
# 19. (A, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 35, 34
# 20. not(A and B)
#     core type: Operation
#     operator: 31
#     operand: 24
# 21. (B in BOOLEAN) and not(A)
#     core type: Operation
#     operator: 27
#     operands: 23
# 22. (A and B)
#     core type: ExprTuple
#     sub-expressions: 24
# 23. (B in BOOLEAN, not(A))
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 24. A and B
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. B in BOOLEAN
#     core type: Operation
#     operator: 29
#     operands: 30
# 26. not(A)
#     core type: Operation
#     operator: 31
#     operand: 35
# 27. and
#     core type: Literal
#     sub-expressions:
# 28. (A, B)
#     core type: ExprTuple
#     sub-expressions: 35, 33
# 29. in
#     core type: Literal
#     sub-expressions:
# 30. (B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 31. not
#     core type: Literal
#     sub-expressions:
# 32. (A)
#     core type: ExprTuple
#     sub-expressions: 35
# 33. B
#     core type: Variable
#     sub-expressions:
# 34. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 35. A
#     core type: Variable
#     sub-expressions:
