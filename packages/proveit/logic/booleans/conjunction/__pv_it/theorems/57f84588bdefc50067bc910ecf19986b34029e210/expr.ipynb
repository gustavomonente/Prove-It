# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, l, m, n
from proveit.core_expr_types import A_1_to_l, B_1_to_m, C_1_to_n
from proveit.logic import And, Forall, InSet
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Lambda([l, m, n], Conditional(Forall([A_1_to_l, B_1_to_m, C_1_to_n], And(A_1_to_l, B_1_to_m, C_1_to_n), condition = And(A_1_to_l, And(B_1_to_m), C_1_to_n)), And(InSet(l, Natural), InSet(m, Natural), InSet(n, Natural))))
# Out:
# expr: (l, m, n) -> {forall_{A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n} | A_{1} and ..A_{_a}.. and A_{l} and (B_{1} and ..B_{_a}.. and B_{m}) and C_{1} and ..C_{_a}.. and C_{n}} (A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C_{1} and ..C_{_a}.. and C_{n}) if l in Natural ,  m in Natural ,  n in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(l, m, n\right) \mapsto \left\{\forall_{A_{1}, \ldots, A_{l}, B_{1}, \ldots, B_{m}, C_{1}, \ldots, C_{n}~|~A_{1} \land \ldots \land A_{l} \land \left(B_{1} \land \ldots \land B_{m}\right) \land C_{1} \land \ldots \land C_{n}}~\left(A_{1} \land \ldots \land A_{l} \land B_{1} \land \ldots \land B_{m} \land C_{1} \land \ldots \land C_{n}\right) \textrm{ if } l \in \mathbb{N} ,  m \in \mathbb{N} ,  n \in \mathbb{N}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (l, m, n) -> {forall_{A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n} | A_{1} and ..A_{_a}.. and A_{l} and (B_{1} and ..B_{_a}.. and B_{m}) and C_{1} and ..C_{_a}.. and C_{n}} (A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C_{1} and ..C_{_a}.. and C_{n}) if l in Natural ,  m in Natural ,  n in Natural.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (l, m, n)
#    core type: ExprTuple
#    sub-expressions: 26, 37, 30
# 2. {forall_{A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n} | A_{1} and ..A_{_a}.. and A_{l} and (B_{1} and ..B_{_a}.. and B_{m}) and C_{1} and ..C_{_a}.. and C_{n}} (A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C_{1} and ..C_{_a}.. and C_{n}) if l in Natural ,  m in Natural ,  n in Natural.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n} | A_{1} and ..A_{_a}.. and A_{l} and (B_{1} and ..B_{_a}.. and B_{m}) and C_{1} and ..C_{_a}.. and C_{n}} (A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C_{1} and ..C_{_a}.. and C_{n})
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. (l in Natural) and (m in Natural) and (n in Natural)
#    core type: Operation
#    operator: 27
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n}) -> {A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C_{1} and ..C_{_a}.. and C_{n} if A_{1} ,  ..A_{_a}.. ,  A_{l} ,  B_{1} and ..B_{_a}.. and B_{m} ,  C_{1} ,  ..C_{_a}.. ,  C_{n}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (l in Natural, m in Natural, n in Natural)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 8. (A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n}) -> {A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C_{1} and ..C_{_a}.. and C_{n} if A_{1} ,  ..A_{_a}.. ,  A_{l} ,  B_{1} and ..B_{_a}.. and B_{m} ,  C_{1} ,  ..C_{_a}.. ,  C_{n}.
#    core type: Lambda
#    parameters: 20\n   body: 12
# 9. l in Natural
#    core type: Operation
#    operator: 15
#    operands: 13
# 10. m in Natural
#     core type: Operation
#     operator: 15
#     operands: 14
# 11. n in Natural
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. {A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C_{1} and ..C_{_a}.. and C_{n} if A_{1} ,  ..A_{_a}.. ,  A_{l} ,  B_{1} and ..B_{_a}.. and B_{m} ,  C_{1} ,  ..C_{_a}.. ,  C_{n}.
#     core type: Conditional
#     value: 17
#     condition: 18
# 13. (l, Natural)
#     core type: ExprTuple
#     sub-expressions: 26, 19
# 14. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 37, 19
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 30, 19
# 17. A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C_{1} and ..C_{_a}.. and C_{n}
#     core type: Operation
#     operator: 27
#     operands: 20
# 18. A_{1} and ..A_{_a}.. and A_{l} and (B_{1} and ..B_{_a}.. and B_{m}) and C_{1} and ..C_{_a}.. and C_{n}
#     core type: Operation
#     operator: 27
#     operands: 21
# 19. Natural
#     core type: Literal
#     sub-expressions:
# 20. (A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n})
#     core type: ExprTuple
#     sub-expressions: 22, 32, 24
# 21. (A_{1}, ..A_{_a}.., A_{l}, B_{1} and ..B_{_a}.. and B_{m}, C_{1}, ..C_{_a}.., C_{n})
#     core type: ExprTuple
#     sub-expressions: 22, 23, 24
# 22. A_{1}, ..A_{_a}.., A_{l}
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 36
#     end_index: 26
# 23. B_{1} and ..B_{_a}.. and B_{m}
#     core type: Operation
#     operator: 27
#     operands: 28
# 24. C_{1}, ..C_{_a}.., C_{n}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 36
#     end_index: 30
# 25. _a -> A_{_a}
#     core type: Lambda
#     parameter: 42
#     body: 31
# 26. l
#     core type: Variable
#     sub-expressions:
# 27. and
#     core type: Literal
#     sub-expressions:
# 28. (B_{1}, ..B_{_a}.., B_{m})
#     core type: ExprTuple
#     sub-expressions: 32
# 29. _a -> C_{_a}
#     core type: Lambda
#     parameter: 42
#     body: 33
# 30. n
#     core type: Variable
#     sub-expressions:
# 31. A_{_a}
#     core type: IndexedVar
# variable: 34
# index: 42
# 32. B_{1}, ..B_{_a}.., B_{m}
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 36
#     end_index: 37
# 33. C_{_a}
#     core type: IndexedVar
# variable: 38
# index: 42
# 34. A
#     core type: Variable
#     sub-expressions:
# 35. _a -> B_{_a}
#     core type: Lambda
#     parameter: 42
#     body: 39
# 36. 1
#     core type: Literal
#     sub-expressions:
# 37. m
#     core type: Variable
#     sub-expressions:
# 38. C
#     core type: Variable
#     sub-expressions:
# 39. B_{_a}
#     core type: IndexedVar
# variable: 40
# index: 42
# 40. B
#     core type: Variable
#     sub-expressions:
# 41. (_a)
#     core type: ExprTuple
#     sub-expressions: 42
# 42. _a
#     core type: Variable
#     sub-expressions:
