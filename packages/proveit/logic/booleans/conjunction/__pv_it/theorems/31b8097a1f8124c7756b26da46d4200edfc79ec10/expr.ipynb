# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, ExprRange, IndexedVar, i, m
from proveit.core_expr_types import A_1_to_m
from proveit.logic import And, Not, Or
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
expr = Conditional(And(A_1_to_m), Not(Or(ExprRange(i, Not(IndexedVar(A, i)), one, m))))
# Out:
# expr: {A_{1} and ..A_{_a}.. and A_{m} if not(not(A_{1}) or ..not(A_{i}).. or not(A_{m})).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{A_{1} \land \ldots \land A_{m} \textrm{ if } \lnot \left((\lnot A_{1}) \lor \ldots \lor (\lnot A_{m})\right)\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {A_{1} and ..A_{_a}.. and A_{m} if not(not(A_{1}) or ..not(A_{i}).. or not(A_{m})).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. A_{1} and ..A_{_a}.. and A_{m}
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. not(not(A_{1}) or ..not(A_{i}).. or not(A_{m}))
#    core type: Operation
#    operator: 19
#    operand: 7
# 3. and
#    core type: Literal
#    sub-expressions:
# 4. (A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (not(A_{1}) or ..not(A_{i}).. or not(A_{m}))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. A_{1}, ..A_{_a}.., A_{m}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 15
#    end_index: 16
# 7. not(A_{1}) or ..not(A_{i}).. or not(A_{m})
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. _a -> A_{_a}
#    core type: Lambda
#    parameter: 17
#    body: 11
# 9. or
#    core type: Literal
#    sub-expressions:
# 10. (not(A_{1}), ..not(A_{i}).., not(A_{m}))
#     core type: ExprTuple
#     sub-expressions: 12
# 11. A_{_a}
#     core type: IndexedVar
# variable: 22
# index: 17
# 12. not(A_{1}), ..not(A_{i}).., not(A_{m})
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 15
#     end_index: 16
# 13. (_a)
#     core type: ExprTuple
#     sub-expressions: 17
# 14. i -> not(A_{i})
#     core type: Lambda
#     parameter: 24
#     body: 18
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. m
#     core type: Variable
#     sub-expressions:
# 17. _a
#     core type: Variable
#     sub-expressions:
# 18. not(A_{i})
#     core type: Operation
#     operator: 19
#     operand: 21
# 19. not
#     core type: Literal
#     sub-expressions:
# 20. (A_{i})
#     core type: ExprTuple
#     sub-expressions: 21
# 21. A_{i}
#     core type: IndexedVar
# variable: 22
# index: 24
# 22. A
#     core type: Variable
#     sub-expressions:
# 23. (i)
#     core type: ExprTuple
#     sub-expressions: 24
# 24. i
#     core type: Variable
#     sub-expressions:
