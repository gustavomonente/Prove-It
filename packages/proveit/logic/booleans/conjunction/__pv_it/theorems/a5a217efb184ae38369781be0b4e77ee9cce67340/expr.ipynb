# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, ExprTuple, Lambda
from proveit.logic import And, Not

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([A, B], Conditional(Not(And(A, B)), And(Not(A), Not(B)))))
# Out:
# expr: ((A, B) -> {not(A and B) if not(A) ,  not(B).)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(A, B\right) \mapsto \left\{\lnot \left(A \land B\right) \textrm{ if } \lnot A ,  \lnot B\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((A, B) -> {not(A and B) if not(A) ,  not(B).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (A, B) -> {not(A and B) if not(A) ,  not(B).
#    core type: Lambda
#    parameters: 11\n   body: 2
# 2. {not(A and B) if not(A) ,  not(B).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. not(A and B)
#    core type: Operation
#    operator: 13
#    operand: 7
# 4. not(A) and not(B)
#    core type: Operation
#    operator: 10
#    operands: 6
# 5. (A and B)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (not(A), not(B))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. A and B
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. not(A)
#    core type: Operation
#    operator: 13
#    operand: 15
# 9. not(B)
#    core type: Operation
#    operator: 13
#    operand: 16
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (A, B)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 12. (A)
#     core type: ExprTuple
#     sub-expressions: 15
# 13. not
#     core type: Literal
#     sub-expressions:
# 14. (B)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. B
#     core type: Variable
#     sub-expressions:
