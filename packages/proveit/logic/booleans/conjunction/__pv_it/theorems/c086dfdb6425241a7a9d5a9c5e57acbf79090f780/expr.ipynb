# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, Conditional, D, ExprRange, IndexedVar, Lambda, Variable, l, m, n
from proveit.core_expr_types import A_1_to_l, B_1_to_m, D_1_to_n
from proveit.logic import And, Boolean, Equals, InSet
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Lambda([A_1_to_l, B_1_to_m, C, D_1_to_n], Conditional(Equals(And(A_1_to_l, B_1_to_m, C, D_1_to_n), And(A_1_to_l, C, B_1_to_m, D_1_to_n)).with_wrapping_at(2), And(ExprRange(sub_expr1, InSet(IndexedVar(A, sub_expr1), Boolean), one, l), ExprRange(sub_expr1, InSet(IndexedVar(B, sub_expr1), Boolean), one, m), InSet(C, Boolean), ExprRange(sub_expr1, InSet(IndexedVar(D, sub_expr1), Boolean), one, n))))
# Out:
# expr: (A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C, D_{1}, ..D_{_a}.., D_{n}) -> {(A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}) =  \\ (A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n}) if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{l} in BOOLEAN ,  B_{1} in BOOLEAN ,  ..B_{_a} in BOOLEAN.. ,  B_{m} in BOOLEAN ,  C in BOOLEAN ,  D_{1} in BOOLEAN ,  ..D_{_a} in BOOLEAN.. ,  D_{n} in BOOLEAN.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{1}, \ldots, A_{l}, B_{1}, \ldots, B_{m}, C, D_{1}, \ldots, D_{n}\right) \mapsto \left\{\begin{array}{c} \begin{array}{l} \left(A_{1} \land \ldots \land A_{l} \land B_{1} \land \ldots \land B_{m} \land C \land D_{1} \land \ldots \land D_{n}\right) =  \\ \left(A_{1} \land \ldots \land A_{l} \land C \land B_{1} \land \ldots \land B_{m} \land D_{1} \land \ldots \land D_{n}\right) \end{array} \end{array} \textrm{ if } A_{1} \in \mathbb{B} ,  \ldots ,  A_{l} \in \mathbb{B} ,  B_{1} \in \mathbb{B} ,  \ldots ,  B_{m} \in \mathbb{B} ,  C \in \mathbb{B} ,  D_{1} \in \mathbb{B} ,  \ldots ,  D_{n} \in \mathbb{B}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C, D_{1}, ..D_{_a}.., D_{n}) -> {(A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}) =  \\ (A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n}) if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{l} in BOOLEAN ,  B_{1} in BOOLEAN ,  ..B_{_a} in BOOLEAN.. ,  B_{m} in BOOLEAN ,  C in BOOLEAN ,  D_{1} in BOOLEAN ,  ..D_{_a} in BOOLEAN.. ,  D_{n} in BOOLEAN.
#    core type: Lambda
#    parameters: 13\n   body: 1
# 1. {(A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}) =  \\ (A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n}) if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{l} in BOOLEAN ,  B_{1} in BOOLEAN ,  ..B_{_a} in BOOLEAN.. ,  B_{m} in BOOLEAN ,  C in BOOLEAN ,  D_{1} in BOOLEAN ,  ..D_{_a} in BOOLEAN.. ,  D_{n} in BOOLEAN.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}) =  \\ (A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n})
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{l} in BOOLEAN) and (B_{1} in BOOLEAN) and ..(B_{_a} in BOOLEAN).. and (B_{m} in BOOLEAN) and (C in BOOLEAN) and (D_{1} in BOOLEAN) and ..(D_{_a} in BOOLEAN).. and (D_{n} in BOOLEAN)
#    core type: Operation
#    operator: 14
#    operands: 6
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}, A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{l} in BOOLEAN, B_{1} in BOOLEAN, ..B_{_a} in BOOLEAN.., B_{m} in BOOLEAN, C in BOOLEAN, D_{1} in BOOLEAN, ..D_{_a} in BOOLEAN.., D_{n} in BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 12
# 7. A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}
#    core type: Operation
#    operator: 14
#    operands: 13
# 8. A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n}
#    core type: Operation
#    operator: 14
#    operands: 15
# 9. (A_{1} in BOOLEAN), ..(A_{_a} in BOOLEAN).., (A_{l} in BOOLEAN)
#    core type: ExprRange
#    lambda_map: 16
#    start_index: 32
#    end_index: 28
# 10. (B_{1} in BOOLEAN), ..(B_{_a} in BOOLEAN).., (B_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 32
#     end_index: 30
# 11. C in BOOLEAN
#     core type: Operation
#     operator: 36
#     operands: 18
# 12. (D_{1} in BOOLEAN), ..(D_{_a} in BOOLEAN).., (D_{n} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 32
#     end_index: 33
# 13. (A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C, D_{1}, ..D_{_a}.., D_{n})
#     core type: ExprTuple
#     sub-expressions: 20, 21, 25, 22
# 14. and
#     core type: Literal
#     sub-expressions:
# 15. (A_{1}, ..A_{_a}.., A_{l}, C, B_{1}, ..B_{_a}.., B_{m}, D_{1}, ..D_{_a}.., D_{n})
#     core type: ExprTuple
#     sub-expressions: 20, 25, 21, 22
# 16. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 46
#     body: 23
# 17. _a -> (B_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 46
#     body: 24
# 18. (C, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 25, 41
# 19. _a -> (D_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 46
#     body: 26
# 20. A_{1}, ..A_{_a}.., A_{l}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 32
#     end_index: 28
# 21. B_{1}, ..B_{_a}.., B_{m}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 32
#     end_index: 30
# 22. D_{1}, ..D_{_a}.., D_{n}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 32
#     end_index: 33
# 23. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 36
#     operands: 34
# 24. B_{_a} in BOOLEAN
#     core type: Operation
#     operator: 36
#     operands: 35
# 25. C
#     core type: Variable
#     sub-expressions:
# 26. D_{_a} in BOOLEAN
#     core type: Operation
#     operator: 36
#     operands: 37
# 27. _a -> A_{_a}
#     core type: Lambda
#     parameter: 46
#     body: 38
# 28. l
#     core type: Variable
#     sub-expressions:
# 29. _a -> B_{_a}
#     core type: Lambda
#     parameter: 46
#     body: 39
# 30. m
#     core type: Variable
#     sub-expressions:
# 31. _a -> D_{_a}
#     core type: Lambda
#     parameter: 46
#     body: 40
# 32. 1
#     core type: Literal
#     sub-expressions:
# 33. n
#     core type: Variable
#     sub-expressions:
# 34. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 38, 41
# 35. (B_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 39, 41
# 36. in
#     core type: Literal
#     sub-expressions:
# 37. (D_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 38. A_{_a}
#     core type: IndexedVar
# variable: 42
# index: 46
# 39. B_{_a}
#     core type: IndexedVar
# variable: 43
# index: 46
# 40. D_{_a}
#     core type: IndexedVar
# variable: 44
# index: 46
# 41. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 42. A
#     core type: Variable
#     sub-expressions:
# 43. B
#     core type: Variable
#     sub-expressions:
# 44. D
#     core type: Variable
#     sub-expressions:
# 45. (_a)
#     core type: ExprTuple
#     sub-expressions: 46
# 46. _a
#     core type: Variable
#     sub-expressions:
