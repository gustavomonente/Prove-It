# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, Lambda
from proveit.logic import And, Boolean, InSet, Not

# %%
# build up the expression from sub-expressions
expr = Lambda([A, B], Conditional(Not(And(A, B)), And(InSet(A, Boolean), InSet(B, Boolean), Not(B))))
# Out:
# expr: (A, B) -> {not(A and B) if A in BOOLEAN ,  B in BOOLEAN ,  not(B).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A, B\right) \mapsto \left\{\lnot \left(A \land B\right) \textrm{ if } A \in \mathbb{B} ,  B \in \mathbb{B} ,  \lnot B\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A, B) -> {not(A and B) if A in BOOLEAN ,  B in BOOLEAN ,  not(B).
#    core type: Lambda
#    parameters: 11\n   body: 1
# 1. {not(A and B) if A in BOOLEAN ,  B in BOOLEAN ,  not(B).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. not(A and B)
#    core type: Operation
#    operator: 15
#    operand: 6
# 3. (A in BOOLEAN) and (B in BOOLEAN) and not(B)
#    core type: Operation
#    operator: 10
#    operands: 5
# 4. (A and B)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (A in BOOLEAN, B in BOOLEAN, not(B))
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 6. A and B
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. A in BOOLEAN
#    core type: Operation
#    operator: 13
#    operands: 12
# 8. B in BOOLEAN
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. not(B)
#    core type: Operation
#    operator: 15
#    operand: 19
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (A, B)
#     core type: ExprTuple
#     sub-expressions: 17, 19
# 12. (A, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 19, 18
# 15. not
#     core type: Literal
#     sub-expressions:
# 16. (B)
#     core type: ExprTuple
#     sub-expressions: 19
# 17. A
#     core type: Variable
#     sub-expressions:
# 18. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 19. B
#     core type: Variable
#     sub-expressions:
