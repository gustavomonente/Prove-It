# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#nand_if_not_one">nand_if_not_one</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.conjunction import nand_if_not_one

# %%
# check that the built expression is the same as the stored expression
assert nand_if_not_one.expr == stored_expr
assert nand_if_not_one.expr._style_id == stored_expr._style_id
print("Passed sanity check: nand_if_not_one matches stored_expr")
# Out:
# Passed sanity check: nand_if_not_one matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(nand_if_not_one.latex())
# Out:
# \vdash \forall_{m, n \in \mathbb{N}}~\left[\forall_{A_{1}, \ldots, A_{m}, B, C_{1}, \ldots, C_{n}~|~\lnot B}~(\lnot \left(A_{1} \land \ldots \land A_{m} \land B \land C_{1} \land \ldots \land C_{n}\right))\right]

# %%
nand_if_not_one.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
nand_if_not_one.expr_info()
# Out:
# 0. forall_{m, n in Natural} [forall_{A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n} | not(B)} not(A_{1} and ..A_{_a}.. and A_{m} and B and C_{1} and ..C_{_a}.. and C_{n})]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((m, n) -> {forall_{A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n} | not(B)} not(A_{1} and ..A_{_a}.. and A_{m} and B and C_{1} and ..C_{_a}.. and C_{n}) if m in Natural ,  n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (m, n) -> {forall_{A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n} | not(B)} not(A_{1} and ..A_{_a}.. and A_{m} and B and C_{1} and ..C_{_a}.. and C_{n}) if m in Natural ,  n in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (m, n)
#    core type: ExprTuple
#    sub-expressions: 30, 33
# 4. {forall_{A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n} | not(B)} not(A_{1} and ..A_{_a}.. and A_{m} and B and C_{1} and ..C_{_a}.. and C_{n}) if m in Natural ,  n in Natural.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n} | not(B)} not(A_{1} and ..A_{_a}.. and A_{m} and B and C_{1} and ..C_{_a}.. and C_{n})
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. (m in Natural) and (n in Natural)
#    core type: Operation
#    operator: 24
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n}) -> {not(A_{1} and ..A_{_a}.. and A_{m} and B and C_{1} and ..C_{_a}.. and C_{n}) if not(B).)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (m in Natural, n in Natural)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. (A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n}) -> {not(A_{1} and ..A_{_a}.. and A_{m} and B and C_{1} and ..C_{_a}.. and C_{n}) if not(B).
#     core type: Lambda
#     parameters: 25\n    body: 13
# 11. m in Natural
#     core type: Operation
#     operator: 15
#     operands: 14
# 12. n in Natural
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. {not(A_{1} and ..A_{_a}.. and A_{m} and B and C_{1} and ..C_{_a}.. and C_{n}) if not(B).
#     core type: Conditional
#     value: 17
#     condition: 18
# 14. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 30, 19
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 33, 19
# 17. not(A_{1} and ..A_{_a}.. and A_{m} and B and C_{1} and ..C_{_a}.. and C_{n})
#     core type: Operation
#     operator: 21
#     operand: 23
# 18. not(B)
#     core type: Operation
#     operator: 21
#     operand: 27
# 19. Natural
#     core type: Literal
#     sub-expressions:
# 20. (A_{1} and ..A_{_a}.. and A_{m} and B and C_{1} and ..C_{_a}.. and C_{n})
#     core type: ExprTuple
#     sub-expressions: 23
# 21. not
#     core type: Literal
#     sub-expressions:
# 22. (B)
#     core type: ExprTuple
#     sub-expressions: 27
# 23. A_{1} and ..A_{_a}.. and A_{m} and B and C_{1} and ..C_{_a}.. and C_{n}
#     core type: Operation
#     operator: 24
#     operands: 25
# 24. and
#     core type: Literal
#     sub-expressions:
# 25. (A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n})
#     core type: ExprTuple
#     sub-expressions: 26, 27, 28
# 26. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 32
#     end_index: 30
# 27. B
#     core type: Variable
#     sub-expressions:
# 28. C_{1}, ..C_{_a}.., C_{n}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 32
#     end_index: 33
# 29. _a -> A_{_a}
#     core type: Lambda
#     parameter: 39
#     body: 34
# 30. m
#     core type: Variable
#     sub-expressions:
# 31. _a -> C_{_a}
#     core type: Lambda
#     parameter: 39
#     body: 35
# 32. 1
#     core type: Literal
#     sub-expressions:
# 33. n
#     core type: Variable
#     sub-expressions:
# 34. A_{_a}
#     core type: IndexedVar
# variable: 36
# index: 39
# 35. C_{_a}
#     core type: IndexedVar
# variable: 37
# index: 39
# 36. A
#     core type: Variable
#     sub-expressions:
# 37. C
#     core type: Variable
#     sub-expressions:
# 38. (_a)
#     core type: ExprTuple
#     sub-expressions: 39
# 39. _a
#     core type: Variable
#     sub-expressions:
