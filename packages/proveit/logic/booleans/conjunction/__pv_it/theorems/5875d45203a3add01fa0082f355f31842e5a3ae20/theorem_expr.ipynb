# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#closure">closure</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.conjunction import closure

# %%
# check that the built expression is the same as the stored expression
assert closure.expr == stored_expr
assert closure.expr._style_id == stored_expr._style_id
print("Passed sanity check: closure matches stored_expr")
# Out:
# Passed sanity check: closure matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(closure.latex())
# Out:
# \vdash \forall_{m \in \mathbb{N}}~\left[\forall_{A_{1}, \ldots, A_{m} \in \mathbb{B}}~\left(\left(A_{1} \land \ldots \land A_{m}\right) \in \mathbb{B}\right)\right]

# %%
closure.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
closure.expr_info()
# Out:
# 0. forall_{m in Natural} [forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} and ..A_{_a}.. and A_{m}) in BOOLEAN)]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (m -> {forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} and ..A_{_a}.. and A_{m}) in BOOLEAN) if m in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. m -> {forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} and ..A_{_a}.. and A_{m}) in BOOLEAN) if m in Natural.
#    core type: Lambda
#    parameter: 25
#    body: 3
# 3. {forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} and ..A_{_a}.. and A_{m}) in BOOLEAN) if m in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} and ..A_{_a}.. and A_{m}) in BOOLEAN)
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. m in Natural
#    core type: Operation
#    operator: 26
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((A_{1}, ..A_{_a}.., A_{m}) -> {(A_{1} and ..A_{_a}.. and A_{m}) in BOOLEAN if (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN).)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (m, Natural)
#    core type: ExprTuple
#    sub-expressions: 25, 10
# 9. (A_{1}, ..A_{_a}.., A_{m}) -> {(A_{1} and ..A_{_a}.. and A_{m}) in BOOLEAN if (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN).
#    core type: Lambda
#    parameters: 19\n   body: 11
# 10. Natural
#     core type: Literal
#     sub-expressions:
# 11. {(A_{1} and ..A_{_a}.. and A_{m}) in BOOLEAN if (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN).
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. (A_{1} and ..A_{_a}.. and A_{m}) in BOOLEAN
#     core type: Operation
#     operator: 26
#     operands: 14
# 13. (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN)
#     core type: Operation
#     operator: 18
#     operands: 15
# 14. (A_{1} and ..A_{_a}.. and A_{m}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 16, 29
# 15. (A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m} in BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 17
# 16. A_{1} and ..A_{_a}.. and A_{m}
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. (A_{1} in BOOLEAN), ..(A_{_a} in BOOLEAN).., (A_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 24
#     end_index: 25
# 18. and
#     core type: Literal
#     sub-expressions:
# 19. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 21
# 20. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 32
#     body: 22
# 21. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 24
#     end_index: 25
# 22. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. _a -> A_{_a}
#     core type: Lambda
#     parameter: 32
#     body: 28
# 24. 1
#     core type: Literal
#     sub-expressions:
# 25. m
#     core type: Variable
#     sub-expressions:
# 26. in
#     core type: Literal
#     sub-expressions:
# 27. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 28. A_{_a}
#     core type: IndexedVar
# variable: 30
# index: 32
# 29. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 30. A
#     core type: Variable
#     sub-expressions:
# 31. (_a)
#     core type: ExprTuple
#     sub-expressions: 32
# 32. _a
#     core type: Variable
#     sub-expressions:
