# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#and_if_all">and_if_all</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.conjunction import and_if_all

# %%
# check that the built expression is the same as the stored expression
assert and_if_all.expr == stored_expr
assert and_if_all.expr._style_id == stored_expr._style_id
print("Passed sanity check: and_if_all matches stored_expr")
# Out:
# Passed sanity check: and_if_all matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(and_if_all.latex())
# Out:
# \vdash \forall_{m \in \mathbb{N}}~\left[\forall_{A_{1}, \ldots, A_{m}~|~A_{1}, \ldots, A_{m}}~\left(A_{1} \land \ldots \land A_{m}\right)\right]

# %%
and_if_all.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
and_if_all.expr_info()
# Out:
# 0. forall_{m in Natural} [forall_{A_{1}, ..A_{_a}.., A_{m} | A_{1}, ..A_{_a}.., A_{m}} (A_{1} and ..A_{_a}.. and A_{m})]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (m -> {forall_{A_{1}, ..A_{_a}.., A_{m} | A_{1}, ..A_{_a}.., A_{m}} (A_{1} and ..A_{_a}.. and A_{m}) if m in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. m -> {forall_{A_{1}, ..A_{_a}.., A_{m} | A_{1}, ..A_{_a}.., A_{m}} (A_{1} and ..A_{_a}.. and A_{m}) if m in Natural.
#    core type: Lambda
#    parameter: 19
#    body: 3
# 3. {forall_{A_{1}, ..A_{_a}.., A_{m} | A_{1}, ..A_{_a}.., A_{m}} (A_{1} and ..A_{_a}.. and A_{m}) if m in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{A_{1}, ..A_{_a}.., A_{m} | A_{1}, ..A_{_a}.., A_{m}} (A_{1} and ..A_{_a}.. and A_{m})
#    core type: Operation
#    operator: 6
#    operand: 10
# 5. m in Natural
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((A_{1}, ..A_{_a}.., A_{m}) -> {A_{1} and ..A_{_a}.. and A_{m} if A_{1} and ..A_{_a}.. and A_{m}.)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (m, Natural)
#    core type: ExprTuple
#    sub-expressions: 19, 11
# 10. (A_{1}, ..A_{_a}.., A_{m}) -> {A_{1} and ..A_{_a}.. and A_{m} if A_{1} and ..A_{_a}.. and A_{m}.
#     core type: Lambda
#     parameters: 15\n    body: 12
# 11. Natural
#     core type: Literal
#     sub-expressions:
# 12. {A_{1} and ..A_{_a}.. and A_{m} if A_{1} and ..A_{_a}.. and A_{m}.
#     core type: Conditional
#     value: 13
#     condition: 13
# 13. A_{1} and ..A_{_a}.. and A_{m}
#     core type: Operation
#     operator: 14
#     operands: 15
# 14. and
#     core type: Literal
#     sub-expressions:
# 15. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 16
# 16. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 18
#     end_index: 19
# 17. _a -> A_{_a}
#     core type: Lambda
#     parameter: 23
#     body: 20
# 18. 1
#     core type: Literal
#     sub-expressions:
# 19. m
#     core type: Variable
#     sub-expressions:
# 20. A_{_a}
#     core type: IndexedVar
# variable: 21
# index: 23
# 21. A
#     core type: Variable
#     sub-expressions:
# 22. (_a)
#     core type: ExprTuple
#     sub-expressions: 23
# 23. _a
#     core type: Variable
#     sub-expressions:
