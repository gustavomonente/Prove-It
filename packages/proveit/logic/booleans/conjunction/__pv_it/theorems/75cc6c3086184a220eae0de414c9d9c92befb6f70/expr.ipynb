# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.core_expr_types import A_1_to_m
from proveit.logic import And, Boolean

# %%
# build up the expression from sub-expressions
expr = ExprTuple(And(A_1_to_m), Boolean)
# Out:
# expr: (A_{1} and ..A_{_a}.. and A_{m}, BOOLEAN)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{1} \land \ldots \land A_{m}, \mathbb{B}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A_{1} and ..A_{_a}.. and A_{m}, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. A_{1} and ..A_{_a}.. and A_{m}
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 3. and
#    core type: Literal
#    sub-expressions:
# 4. (A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 5
# 5. A_{1}, ..A_{_a}.., A_{m}
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 7
#    end_index: 8
# 6. _a -> A_{_a}
#    core type: Lambda
#    parameter: 12
#    body: 9
# 7. 1
#    core type: Literal
#    sub-expressions:
# 8. m
#    core type: Variable
#    sub-expressions:
# 9. A_{_a}
#    core type: IndexedVar
# variable: 10
# index: 12
# 10. A
#     core type: Variable
#     sub-expressions:
# 11. (_a)
#     core type: ExprTuple
#     sub-expressions: 12
# 12. _a
#     core type: Variable
#     sub-expressions:
