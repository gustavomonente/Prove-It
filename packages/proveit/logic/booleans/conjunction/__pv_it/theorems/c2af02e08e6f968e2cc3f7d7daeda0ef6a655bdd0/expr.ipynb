# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda
from proveit.core_expr_types import A_1_to_m
from proveit.logic import And

# %%
# build up the expression from sub-expressions
sub_expr1 = And(A_1_to_m)
expr = ExprTuple(Lambda([A_1_to_m], Conditional(sub_expr1, sub_expr1)))
# Out:
# expr: ((A_{1}, ..A_{_a}.., A_{m}) -> {A_{1} and ..A_{_a}.. and A_{m} if A_{1} and ..A_{_a}.. and A_{m}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(A_{1}, \ldots, A_{m}\right) \mapsto \left\{A_{1} \land \ldots \land A_{m} \textrm{ if } A_{1} \land \ldots \land A_{m}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((A_{1}, ..A_{_a}.., A_{m}) -> {A_{1} and ..A_{_a}.. and A_{m} if A_{1} and ..A_{_a}.. and A_{m}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (A_{1}, ..A_{_a}.., A_{m}) -> {A_{1} and ..A_{_a}.. and A_{m} if A_{1} and ..A_{_a}.. and A_{m}.
#    core type: Lambda
#    parameters: 5\n   body: 2
# 2. {A_{1} and ..A_{_a}.. and A_{m} if A_{1} and ..A_{_a}.. and A_{m}.
#    core type: Conditional
#    value: 3
#    condition: 3
# 3. A_{1} and ..A_{_a}.. and A_{m}
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 6
# 6. A_{1}, ..A_{_a}.., A_{m}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 8
#    end_index: 9
# 7. _a -> A_{_a}
#    core type: Lambda
#    parameter: 13
#    body: 10
# 8. 1
#    core type: Literal
#    sub-expressions:
# 9. m
#    core type: Variable
#    sub-expressions:
# 10. A_{_a}
#     core type: IndexedVar
# variable: 11
# index: 13
# 11. A
#     core type: Variable
#     sub-expressions:
# 12. (_a)
#     core type: ExprTuple
#     sub-expressions: 13
# 13. _a
#     core type: Variable
#     sub-expressions:
