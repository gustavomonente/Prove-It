# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#rightward_commute">rightward_commute</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.conjunction import rightward_commute

# %%
# check that the built expression is the same as the stored expression
assert rightward_commute.expr == stored_expr
assert rightward_commute.expr._style_id == stored_expr._style_id
print("Passed sanity check: rightward_commute matches stored_expr")
# Out:
# Passed sanity check: rightward_commute matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(rightward_commute.latex())
# Out:
# \vdash \forall_{l, m, n \in \mathbb{N}}~\left[\forall_{A_{1}, \ldots, A_{l}, B, C_{1}, \ldots, C_{m}, D_{1}, \ldots, D_{n}~|~A_{1}, \ldots, A_{l}, B, C_{1}, \ldots, C_{m}, D_{1}, \ldots, D_{n}}~\left(A_{1} \land \ldots \land A_{l} \land C_{1} \land \ldots \land C_{m} \land B \land D_{1} \land \ldots \land D_{n}\right)\right]

# %%
rightward_commute.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
rightward_commute.expr_info()
# Out:
# 0. forall_{l, m, n in Natural} [forall_{A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n} | A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n}} (A_{1} and ..A_{_a}.. and A_{l} and C_{1} and ..C_{_a}.. and C_{m} and B and D_{1} and ..D_{_a}.. and D_{n})]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((l, m, n) -> {forall_{A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n} | A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n}} (A_{1} and ..A_{_a}.. and A_{l} and C_{1} and ..C_{_a}.. and C_{m} and B and D_{1} and ..D_{_a}.. and D_{n}) if l in Natural ,  m in Natural ,  n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (l, m, n) -> {forall_{A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n} | A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n}} (A_{1} and ..A_{_a}.. and A_{l} and C_{1} and ..C_{_a}.. and C_{m} and B and D_{1} and ..D_{_a}.. and D_{n}) if l in Natural ,  m in Natural ,  n in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (l, m, n)
#    core type: ExprTuple
#    sub-expressions: 30, 32, 35
# 4. {forall_{A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n} | A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n}} (A_{1} and ..A_{_a}.. and A_{l} and C_{1} and ..C_{_a}.. and C_{m} and B and D_{1} and ..D_{_a}.. and D_{n}) if l in Natural ,  m in Natural ,  n in Natural.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n} | A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n}} (A_{1} and ..A_{_a}.. and A_{l} and C_{1} and ..C_{_a}.. and C_{m} and B and D_{1} and ..D_{_a}.. and D_{n})
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. (l in Natural) and (m in Natural) and (n in Natural)
#    core type: Operation
#    operator: 23
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n}) -> {A_{1} and ..A_{_a}.. and A_{l} and C_{1} and ..C_{_a}.. and C_{m} and B and D_{1} and ..D_{_a}.. and D_{n} if A_{1} ,  ..A_{_a}.. ,  A_{l} ,  B ,  C_{1} ,  ..C_{_a}.. ,  C_{m} ,  D_{1} ,  ..D_{_a}.. ,  D_{n}.)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (l in Natural, m in Natural, n in Natural)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 10. (A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n}) -> {A_{1} and ..A_{_a}.. and A_{l} and C_{1} and ..C_{_a}.. and C_{m} and B and D_{1} and ..D_{_a}.. and D_{n} if A_{1} ,  ..A_{_a}.. ,  A_{l} ,  B ,  C_{1} ,  ..C_{_a}.. ,  C_{m} ,  D_{1} ,  ..D_{_a}.. ,  D_{n}.
#     core type: Lambda
#     parameters: 24\n    body: 14
# 11. l in Natural
#     core type: Operation
#     operator: 17
#     operands: 15
# 12. m in Natural
#     core type: Operation
#     operator: 17
#     operands: 16
# 13. n in Natural
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. {A_{1} and ..A_{_a}.. and A_{l} and C_{1} and ..C_{_a}.. and C_{m} and B and D_{1} and ..D_{_a}.. and D_{n} if A_{1} ,  ..A_{_a}.. ,  A_{l} ,  B ,  C_{1} ,  ..C_{_a}.. ,  C_{m} ,  D_{1} ,  ..D_{_a}.. ,  D_{n}.
#     core type: Conditional
#     value: 19
#     condition: 20
# 15. (l, Natural)
#     core type: ExprTuple
#     sub-expressions: 30, 21
# 16. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 32, 21
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 35, 21
# 19. A_{1} and ..A_{_a}.. and A_{l} and C_{1} and ..C_{_a}.. and C_{m} and B and D_{1} and ..D_{_a}.. and D_{n}
#     core type: Operation
#     operator: 23
#     operands: 22
# 20. A_{1} and ..A_{_a}.. and A_{l} and B and C_{1} and ..C_{_a}.. and C_{m} and D_{1} and ..D_{_a}.. and D_{n}
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. Natural
#     core type: Literal
#     sub-expressions:
# 22. (A_{1}, ..A_{_a}.., A_{l}, C_{1}, ..C_{_a}.., C_{m}, B, D_{1}, ..D_{_a}.., D_{n})
#     core type: ExprTuple
#     sub-expressions: 25, 27, 26, 28
# 23. and
#     core type: Literal
#     sub-expressions:
# 24. (A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n})
#     core type: ExprTuple
#     sub-expressions: 25, 26, 27, 28
# 25. A_{1}, ..A_{_a}.., A_{l}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 34
#     end_index: 30
# 26. B
#     core type: Variable
#     sub-expressions:
# 27. C_{1}, ..C_{_a}.., C_{m}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 34
#     end_index: 32
# 28. D_{1}, ..D_{_a}.., D_{n}
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 34
#     end_index: 35
# 29. _a -> A_{_a}
#     core type: Lambda
#     parameter: 43
#     body: 36
# 30. l
#     core type: Variable
#     sub-expressions:
# 31. _a -> C_{_a}
#     core type: Lambda
#     parameter: 43
#     body: 37
# 32. m
#     core type: Variable
#     sub-expressions:
# 33. _a -> D_{_a}
#     core type: Lambda
#     parameter: 43
#     body: 38
# 34. 1
#     core type: Literal
#     sub-expressions:
# 35. n
#     core type: Variable
#     sub-expressions:
# 36. A_{_a}
#     core type: IndexedVar
# variable: 39
# index: 43
# 37. C_{_a}
#     core type: IndexedVar
# variable: 40
# index: 43
# 38. D_{_a}
#     core type: IndexedVar
# variable: 41
# index: 43
# 39. A
#     core type: Variable
#     sub-expressions:
# 40. C
#     core type: Variable
#     sub-expressions:
# 41. D
#     core type: Variable
#     sub-expressions:
# 42. (_a)
#     core type: ExprTuple
#     sub-expressions: 43
# 43. _a
#     core type: Variable
#     sub-expressions:
