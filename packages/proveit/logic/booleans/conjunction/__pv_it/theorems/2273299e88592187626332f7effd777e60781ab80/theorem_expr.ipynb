# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#false_and_false_negated">false_and_false_negated</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Not.html">Not</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.conjunction import false_and_false_negated

# %%
# check that the built expression is the same as the stored expression
assert false_and_false_negated.expr == stored_expr
assert false_and_false_negated.expr._style_id == stored_expr._style_id
print("Passed sanity check: false_and_false_negated matches stored_expr")
# Out:
# Passed sanity check: false_and_false_negated matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(false_and_false_negated.latex())
# Out:
# \vdash \lnot \left(\bot \land \bot\right)

# %%
false_and_false_negated.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: function
# current value: function
# related methods: ()

# %%
# display the expression information
false_and_false_negated.expr_info()
# Out:
# 0. not(FALSE and FALSE)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. not
#    core type: Literal
#    sub-expressions:
# 2. (FALSE and FALSE)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. FALSE and FALSE
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (FALSE, FALSE)
#    core type: ExprTuple
#    sub-expressions: 6, 6
# 6. FALSE
#    core type: Literal
#    sub-expressions:
