# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional
from proveit.logic import And, Not, Or

# %%
# build up the expression from sub-expressions
expr = Conditional(And(A, B), Not(Or(Not(A), Not(B))))
# Out:
# expr: {A and B if not(not(A) or not(B)).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{A \land B \textrm{ if } \lnot \left((\lnot A) \lor (\lnot B)\right)\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {A and B if not(not(A) or not(B)).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. A and B
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. not(not(A) or not(B))
#    core type: Operation
#    operator: 12
#    operand: 6
# 3. and
#    core type: Literal
#    sub-expressions:
# 4. (A, B)
#    core type: ExprTuple
#    sub-expressions: 14, 15
# 5. (not(A) or not(B))
#    core type: ExprTuple
#    sub-expressions: 6
# 6. not(A) or not(B)
#    core type: Operation
#    operator: 7
#    operands: 8
# 7. or
#    core type: Literal
#    sub-expressions:
# 8. (not(A), not(B))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. not(A)
#    core type: Operation
#    operator: 12
#    operand: 14
# 10. not(B)
#     core type: Operation
#     operator: 12
#     operand: 15
# 11. (A)
#     core type: ExprTuple
#     sub-expressions: 14
# 12. not
#     core type: Literal
#     sub-expressions:
# 13. (B)
#     core type: ExprTuple
#     sub-expressions: 15
# 14. A
#     core type: Variable
#     sub-expressions:
# 15. B
#     core type: Variable
#     sub-expressions:
