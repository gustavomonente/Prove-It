# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, ExprRange, IndexedVar, i, m
from proveit.core_expr_types import A_1_to_m
from proveit.logic import And, Forall, Not, Or
from proveit.numbers import Natural, one

# %%
# build up the expression from sub-expressions
expr = Forall([m], Forall([A_1_to_m], And(A_1_to_m), condition = Not(Or(ExprRange(i, Not(IndexedVar(A, i)), one, m)))), domains = [Natural])
# Out:
# expr: forall_{m in Natural} [forall_{A_{1}, ..A_{_a}.., A_{m} | not(not(A_{1}) or ..not(A_{i}).. or not(A_{m}))} (A_{1} and ..A_{_a}.. and A_{m})]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{m \in \mathbb{N}}~\left[\forall_{A_{1}, \ldots, A_{m}~|~\lnot \left((\lnot A_{1}) \lor \ldots \lor (\lnot A_{m})\right)}~\left(A_{1} \land \ldots \land A_{m}\right)\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{m in Natural} [forall_{A_{1}, ..A_{_a}.., A_{m} | not(not(A_{1}) or ..not(A_{i}).. or not(A_{m}))} (A_{1} and ..A_{_a}.. and A_{m})]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (m -> {forall_{A_{1}, ..A_{_a}.., A_{m} | not(not(A_{1}) or ..not(A_{i}).. or not(A_{m}))} (A_{1} and ..A_{_a}.. and A_{m}) if m in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. m -> {forall_{A_{1}, ..A_{_a}.., A_{m} | not(not(A_{1}) or ..not(A_{i}).. or not(A_{m}))} (A_{1} and ..A_{_a}.. and A_{m}) if m in Natural.
#    core type: Lambda
#    parameter: 28
#    body: 3
# 3. {forall_{A_{1}, ..A_{_a}.., A_{m} | not(not(A_{1}) or ..not(A_{i}).. or not(A_{m}))} (A_{1} and ..A_{_a}.. and A_{m}) if m in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{A_{1}, ..A_{_a}.., A_{m} | not(not(A_{1}) or ..not(A_{i}).. or not(A_{m}))} (A_{1} and ..A_{_a}.. and A_{m})
#    core type: Operation
#    operator: 6
#    operand: 10
# 5. m in Natural
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((A_{1}, ..A_{_a}.., A_{m}) -> {A_{1} and ..A_{_a}.. and A_{m} if not(not(A_{1}) or ..not(A_{i}).. or not(A_{m})).)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (m, Natural)
#    core type: ExprTuple
#    sub-expressions: 28, 11
# 10. (A_{1}, ..A_{_a}.., A_{m}) -> {A_{1} and ..A_{_a}.. and A_{m} if not(not(A_{1}) or ..not(A_{i}).. or not(A_{m})).
#     core type: Lambda
#     parameters: 16\n    body: 12
# 11. Natural
#     core type: Literal
#     sub-expressions:
# 12. {A_{1} and ..A_{_a}.. and A_{m} if not(not(A_{1}) or ..not(A_{i}).. or not(A_{m})).
#     core type: Conditional
#     value: 13
#     condition: 14
# 13. A_{1} and ..A_{_a}.. and A_{m}
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. not(not(A_{1}) or ..not(A_{i}).. or not(A_{m}))
#     core type: Operation
#     operator: 31
#     operand: 19
# 15. and
#     core type: Literal
#     sub-expressions:
# 16. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 18
# 17. (not(A_{1}) or ..not(A_{i}).. or not(A_{m}))
#     core type: ExprTuple
#     sub-expressions: 19
# 18. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 27
#     end_index: 28
# 19. not(A_{1}) or ..not(A_{i}).. or not(A_{m})
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. _a -> A_{_a}
#     core type: Lambda
#     parameter: 29
#     body: 23
# 21. or
#     core type: Literal
#     sub-expressions:
# 22. (not(A_{1}), ..not(A_{i}).., not(A_{m}))
#     core type: ExprTuple
#     sub-expressions: 24
# 23. A_{_a}
#     core type: IndexedVar
# variable: 34
# index: 29
# 24. not(A_{1}), ..not(A_{i}).., not(A_{m})
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 27
#     end_index: 28
# 25. (_a)
#     core type: ExprTuple
#     sub-expressions: 29
# 26. i -> not(A_{i})
#     core type: Lambda
#     parameter: 36
#     body: 30
# 27. 1
#     core type: Literal
#     sub-expressions:
# 28. m
#     core type: Variable
#     sub-expressions:
# 29. _a
#     core type: Variable
#     sub-expressions:
# 30. not(A_{i})
#     core type: Operation
#     operator: 31
#     operand: 33
# 31. not
#     core type: Literal
#     sub-expressions:
# 32. (A_{i})
#     core type: ExprTuple
#     sub-expressions: 33
# 33. A_{i}
#     core type: IndexedVar
# variable: 34
# index: 36
# 34. A
#     core type: Variable
#     sub-expressions:
# 35. (i)
#     core type: ExprTuple
#     sub-expressions: 36
# 36. i
#     core type: Variable
#     sub-expressions:
