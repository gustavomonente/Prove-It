# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">conjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#nand_if_not_right">nand_if_not_right</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import A, B
from proveit.logic.booleans import fold_forall_over_bool
from proveit.logic.booleans.conjunction import nand_if_left_but_not_right, nand_if_neither
from proveit.logic import Not, TRUE, FALSE
theory = proveit.Theory() # the theorem's theory

# %%
# %proving nand_if_not_right
# Out:
# nand_if_not_right: forall_{A, B in BOOLEAN | not(B)} not(A and B)

# %%
defaults.assumptions = nand_if_not_right.conditions
# Out:
# defaults.assumptions: (A in BOOLEAN, B in BOOLEAN, not(B))

# %%
nand_if_left_but_not_right.instantiate({A:TRUE})
# Out:
# {not(B)} |- not(TRUE and B)

# %%
nand_if_neither.instantiate({A:FALSE})
# Out:
# {not(B)} |- not(FALSE and B)

# %%
nand_if_left_but_not_right.instantiate({A:TRUE, B:B})
# Out:
# {not(B)} |- not(TRUE and B)

# %%
nand_if_neither.instantiate({A:FALSE, B:B})
# Out:
# {not(B)} |- not(FALSE and B)

# %%
nand_if_not_right.conclude_as_folded(nand_if_not_right.conditions)
# Out:
# nand_if_not_right has been proven.  Now simply execute "%qed".
# |- forall_{A, B in BOOLEAN | not(B)} not(A and B)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{A, B in BOOLEAN | not(B)} not(A and B)
# 1	instantiation	3, 4, 5, 6, 7*	|- [forall_{A in BOOLEAN} [forall_{B in BOOLEAN | not(B)} not(A and B)]] => [forall_{A, B in BOOLEAN | not(B)} not(A and B)]
# 	m : 1, n : 1, P(A, B) : not(A and B), Q(A) : A in BOOLEAN, R(A, B) : (B in BOOLEAN) and not(B), (x_{1}, ..x_{_a}.., x_{1}) : (A), (y_{1}, ..y_{_a}.., y_{1}) : (B)
# 2	instantiation	8, 9, 10	|- forall_{A in BOOLEAN} [forall_{B in BOOLEAN | not(B)} not(A and B)]
# 	P(A) : forall_{B in BOOLEAN | not(B)} not(A and B), A : A
# ...
