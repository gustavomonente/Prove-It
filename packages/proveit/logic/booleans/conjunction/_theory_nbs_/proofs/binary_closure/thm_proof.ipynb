# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">conjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#binary_closure">binary_closure</a> theorem
# ========

# %%
import proveit
from proveit.logic.booleans import fold_forall_over_bool
# we need to import these to derive their side-effects:
from proveit.logic.booleans.conjunction import \
    (true_and_true, false_and_true_negated, true_and_false_negated, false_and_false_negated)
theory = proveit.Theory() # the theorem's theory

# %%
# %proving binary_closure
# Out:
# binary_closure: forall_{A, B in BOOLEAN} ((A and B) in BOOLEAN)

# %%
# %qed # conclude_as_folded automatically
# Out:
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{A, B in BOOLEAN} ((A and B) in BOOLEAN)
# 1	instantiation	3, 4, 5, 6	|- [forall_{A in BOOLEAN} [forall_{B in BOOLEAN} ((A and B) in BOOLEAN)]] => [forall_{A, B in BOOLEAN} ((A and B) in BOOLEAN)]
# 	m : 1, n : 1, P(A, B) : (A and B) in BOOLEAN, Q(A) : A in BOOLEAN, R(A, B) : B in BOOLEAN, (x_{1}, ..x_{_a}.., x_{1}) : (A), (y_{1}, ..y_{_a}.., y_{1}) : (B)
# 2	instantiation	12, 7, 8	|- forall_{A in BOOLEAN} [forall_{B in BOOLEAN} ((A and B) in BOOLEAN)]
# 	P(A) : forall_{B in BOOLEAN} ((A and B) in BOOLEAN), A : A
# ...
