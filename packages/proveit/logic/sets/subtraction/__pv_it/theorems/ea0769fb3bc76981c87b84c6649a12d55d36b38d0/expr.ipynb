# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.subtraction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, ExprTuple, Lambda, x
from proveit.logic import And, Difference, InSet, NotInSet

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([x, A, B], Conditional(InSet(x, Difference(A, B)), And(InSet(x, A), NotInSet(x, B)))))
# Out:
# expr: ((x, A, B) -> {x in (A - B) if x in A ,  x not-in B.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(x, A, B\right) \mapsto \left\{x \in \left(A - B\right) \textrm{ if } x \in A ,  x \notin B\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((x, A, B) -> {x in (A - B) if x in A ,  x not-in B.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (x, A, B) -> {x in (A - B) if x in A ,  x not-in B.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (x, A, B)
#    core type: ExprTuple
#    sub-expressions: 19, 18, 20
# 3. {x in (A - B) if x in A ,  x not-in B.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. x in (A - B)
#    core type: Operation
#    operator: 14
#    operands: 6
# 5. (x in A) and (x not-in B)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (x, A - B)
#    core type: ExprTuple
#    sub-expressions: 19, 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (x in A, x not-in B)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. A - B
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. x in A
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. x not-in B
#     core type: Operation
#     operator: 16
#     operands: 17
# 12. -
#     core type: Literal
#     sub-expressions:
# 13. (A, B)
#     core type: ExprTuple
#     sub-expressions: 18, 20
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (x, A)
#     core type: ExprTuple
#     sub-expressions: 19, 18
# 16. not-in
#     core type: Literal
#     sub-expressions:
# 17. (x, B)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. A
#     core type: Variable
#     sub-expressions:
# 19. x
#     core type: Variable
#     sub-expressions:
# 20. B
#     core type: Variable
#     sub-expressions:
