# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Lambda, Variable, i, k, x, y
from proveit.logic import Equals, InSet, Or, Set
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = ExprRange(sub_expr1, IndexedVar(y, sub_expr1), one, k)
expr = Lambda([x, sub_expr2], Equals(InSet(x, Set(sub_expr2)), Or(ExprRange(i, Equals(x, IndexedVar(y, i)), one, k))))
# Out:
# expr: (x, y_{1}, ..y_{_a}.., y_{k}) -> ((x in {y_{1}, ..y_{_a}.., y_{k}}) = ((x = y_{1}) or ..(x = y_{i}).. or (x = y_{k})))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x, y_{1}, \ldots, y_{k}\right) \mapsto \left(\left(x \in \left\{y_{1}, \ldots, y_{k}\right\}\right) = \left(\left(x = y_{1}\right) \lor \ldots \lor \left(x = y_{k}\right)\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x, y_{1}, ..y_{_a}.., y_{k}) -> ((x in {y_{1}, ..y_{_a}.., y_{k}}) = ((x = y_{1}) or ..(x = y_{i}).. or (x = y_{k})))
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (x, y_{1}, ..y_{_a}.., y_{k})
#    core type: ExprTuple
#    sub-expressions: 23, 15
# 2. (x in {y_{1}, ..y_{_a}.., y_{k}}) = ((x = y_{1}) or ..(x = y_{i}).. or (x = y_{k}))
#    core type: Operation
#    operator: 20
#    operands: 3
# 3. (x in {y_{1}, ..y_{_a}.., y_{k}}, (x = y_{1}) or ..(x = y_{i}).. or (x = y_{k}))
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. x in {y_{1}, ..y_{_a}.., y_{k}}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (x = y_{1}) or ..(x = y_{i}).. or (x = y_{k})
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (x, {y_{1}, ..y_{_a}.., y_{k}})
#    core type: ExprTuple
#    sub-expressions: 23, 10
# 8. or
#    core type: Literal
#    sub-expressions:
# ...
