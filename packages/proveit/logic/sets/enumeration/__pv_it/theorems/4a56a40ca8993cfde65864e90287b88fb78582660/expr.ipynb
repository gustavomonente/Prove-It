# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda, P, Px, x
from proveit.core_expr_types import Pk_a1_to_an, a_1_to_n
from proveit.logic import Forall, Set

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([a_1_to_n], Forall([P], Forall([x], Px, domains = [Set(a_1_to_n)]), condition = Pk_a1_to_an)))
# Out:
# expr: ((a_{1}, ..a_{_a}.., a_{n}) -> [forall_{P | P(a_{1}), ..P(a_{k}).., P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)]])

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a_{1}, \ldots, a_{n}\right) \mapsto \left[\forall_{P~|~P(a_{1}), \ldots, P(a_{n})}~\left[\forall_{x \in \left\{a_{1}, \ldots, a_{n}\right\}}~P(x)\right]\right]\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a_{1}, ..a_{_a}.., a_{n}) -> [forall_{P | P(a_{1}), ..P(a_{k}).., P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)]])
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a_{1}, ..a_{_a}.., a_{n}) -> [forall_{P | P(a_{1}), ..P(a_{k}).., P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)]]
#    core type: Lambda
#    parameters: 28\n   body: 2
# 2. forall_{P | P(a_{1}), ..P(a_{k}).., P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)]
#    core type: Operation
#    operator: 8
#    operand: 4
# 3. (P -> {forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x) if P(a_{1}) and ..P(a_{k}).. and P(a_{n}).)
#    core type: ExprTuple
#    sub-expressions: 4
# 4. P -> {forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x) if P(a_{1}) and ..P(a_{k}).. and P(a_{n}).
#    core type: Lambda
#    parameter: 22
#    body: 5
# 5. {forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x) if P(a_{1}) and ..P(a_{k}).. and P(a_{n}).
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)
#    core type: Operation
#    operator: 8
#    operand: 12
# 7. P(a_{1}) and ..P(a_{k}).. and P(a_{n})
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. (x -> {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}}.)
#    core type: ExprTuple
#    sub-expressions: 12
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (P(a_{1}), ..P(a_{k}).., P(a_{n}))
#     core type: ExprTuple
#     sub-expressions: 13
# 12. x -> {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}}.
#     core type: Lambda
#     parameter: 24
#     body: 14
# 13. P(a_{1}), ..P(a_{k}).., P(a_{n})
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 33
#     end_index: 34
# 14. {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}}.
#     core type: Conditional
#     value: 16
#     condition: 17
# 15. k -> P(a_{k})
#     core type: Lambda
#     parameter: 31
#     body: 18
# 16. P(x)
#     core type: Operation
#     operator: 22
#     operand: 24
# 17. x in {a_{1}, ..a_{_a}.., a_{n}}
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. P(a_{k})
#     core type: Operation
#     operator: 22
#     operand: 26
# 19. (x)
#     core type: ExprTuple
#     sub-expressions: 24
# 20. in
#     core type: Literal
#     sub-expressions:
# 21. (x, {a_{1}, ..a_{_a}.., a_{n}})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. P
#     core type: Variable
#     sub-expressions:
# 23. (a_{k})
#     core type: ExprTuple
#     sub-expressions: 26
# 24. x
#     core type: Variable
#     sub-expressions:
# 25. {a_{1}, ..a_{_a}.., a_{n}}
#     core type: Operation
#     operator: 27
#     operands: 28
# 26. a_{k}
#     core type: IndexedVar
# variable: 36
# index: 31
# 27. Set
#     core type: Literal
#     sub-expressions:
# 28. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 30
# 29. (k)
#     core type: ExprTuple
#     sub-expressions: 31
# 30. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 33
#     end_index: 34
# 31. k
#     core type: Variable
#     sub-expressions:
# 32. _a -> a_{_a}
#     core type: Lambda
#     parameter: 38
#     body: 35
# 33. 1
#     core type: Literal
#     sub-expressions:
# 34. n
#     core type: Variable
#     sub-expressions:
# 35. a_{_a}
#     core type: IndexedVar
# variable: 36
# index: 38
# 36. a
#     core type: Variable
#     sub-expressions:
# 37. (_a)
#     core type: ExprTuple
#     sub-expressions: 38
# 38. _a
#     core type: Variable
#     sub-expressions:
