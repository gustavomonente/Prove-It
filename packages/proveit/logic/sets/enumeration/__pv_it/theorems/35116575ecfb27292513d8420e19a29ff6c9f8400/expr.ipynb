# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, P, Px, Q, Qx, n, x
from proveit.core_expr_types import Qk_implies_Pk_a1_to_an, a_1_to_n
from proveit.logic import Forall, InSet, Set
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(n, Conditional(Forall([a_1_to_n], Forall([P, Q], Forall([x], Px, domains = [Set(a_1_to_n)], condition = Qx), condition = Qk_implies_Pk_a1_to_an)), InSet(n, Natural))))
# Out:
# expr: (n -> {forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P, Q | Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)]] if n in Natural.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(n \mapsto \left\{\forall_{a_{1}, \ldots, a_{n}}~\left[\forall_{P, Q~|~Q(a_{1}) \Rightarrow P(a_{1}), \ldots, Q(a_{n}) \Rightarrow P(a_{n})}~\left[\forall_{x \in \left\{a_{1}, \ldots, a_{n}\right\}~|~Q(x)}~P(x)\right]\right] \textrm{ if } n \in \mathbb{N}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (n -> {forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P, Q | Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)]] if n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. n -> {forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P, Q | Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)]] if n in Natural.
#    core type: Lambda
#    parameter: 50
#    body: 2
# 2. {forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P, Q | Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)]] if n in Natural.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P, Q | Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)]]
#    core type: Operation
#    operator: 16
#    operand: 7
# 4. n in Natural
#    core type: Operation
#    operator: 34
#    operands: 6
# 5. ((a_{1}, ..a_{_a}.., a_{n}) -> [forall_{P, Q | Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)]])
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (n, Natural)
#    core type: ExprTuple
#    sub-expressions: 50, 8
# 7. (a_{1}, ..a_{_a}.., a_{n}) -> [forall_{P, Q | Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)]]
#    core type: Lambda
#    parameters: 44\n   body: 9
# 8. Natural
#    core type: Literal
#    sub-expressions:
# 9. forall_{P, Q | Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)]
#    core type: Operation
#    operator: 16
#    operand: 11
# 10. ((P, Q) -> {forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x) if (Q(a_{1}) => P(a_{1})) and ..(Q(a_{k}) => P(a_{k})).. and (Q(a_{n}) => P(a_{n})).)
#     core type: ExprTuple
#     sub-expressions: 11
# 11. (P, Q) -> {forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x) if (Q(a_{1}) => P(a_{1})) and ..(Q(a_{k}) => P(a_{k})).. and (Q(a_{n}) => P(a_{n})).
#     core type: Lambda
#     parameters: 12\n    body: 13
# 12. (P, Q)
#     core type: ExprTuple
#     sub-expressions: 38, 37
# 13. {forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x) if (Q(a_{1}) => P(a_{1})) and ..(Q(a_{k}) => P(a_{k})).. and (Q(a_{n}) => P(a_{n})).
#     core type: Conditional
#     value: 14
#     condition: 15
# 14. forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)
#     core type: Operation
#     operator: 16
#     operand: 19
# 15. (Q(a_{1}) => P(a_{1})) and ..(Q(a_{k}) => P(a_{k})).. and (Q(a_{n}) => P(a_{n}))
#     core type: Operation
#     operator: 26
#     operands: 18
# 16. forall
#     core type: Literal
#     sub-expressions:
# 17. (x -> {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}} ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 19
# 18. (Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n}))
#     core type: ExprTuple
#     sub-expressions: 20
# 19. x -> {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}} ,  Q(x).
#     core type: Lambda
#     parameter: 41
#     body: 21
# 20. (Q(a_{1}) => P(a_{1})), ..(Q(a_{k}) => P(a_{k})).., (Q(a_{n}) => P(a_{n}))
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 49
#     end_index: 50
# 21. {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}} ,  Q(x).
#     core type: Conditional
#     value: 23
#     condition: 24
# 22. k -> (Q(a_{k}) => P(a_{k}))
#     core type: Lambda
#     parameter: 47
#     body: 25
# 23. P(x)
#     core type: Operation
#     operator: 38
#     operand: 41
# 24. (x in {a_{1}, ..a_{_a}.., a_{n}}) and Q(x)
#     core type: Operation
#     operator: 26
#     operands: 27
# 25. Q(a_{k}) => P(a_{k})
#     core type: Operation
#     operator: 28
#     operands: 29
# 26. and
#     core type: Literal
#     sub-expressions:
# 27. (x in {a_{1}, ..a_{_a}.., a_{n}}, Q(x))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 28. =>
#     core type: Literal
#     sub-expressions:
# 29. (Q(a_{k}), P(a_{k}))
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 30. x in {a_{1}, ..a_{_a}.., a_{n}}
#     core type: Operation
#     operator: 34
#     operands: 35
# 31. Q(x)
#     core type: Operation
#     operator: 37
#     operand: 41
# 32. Q(a_{k})
#     core type: Operation
#     operator: 37
#     operand: 42
# 33. P(a_{k})
#     core type: Operation
#     operator: 38
#     operand: 42
# 34. in
#     core type: Literal
#     sub-expressions:
# 35. (x, {a_{1}, ..a_{_a}.., a_{n}})
#     core type: ExprTuple
#     sub-expressions: 41, 40
# 36. (x)
#     core type: ExprTuple
#     sub-expressions: 41
# 37. Q
#     core type: Variable
#     sub-expressions:
# 38. P
#     core type: Variable
#     sub-expressions:
# 39. (a_{k})
#     core type: ExprTuple
#     sub-expressions: 42
# 40. {a_{1}, ..a_{_a}.., a_{n}}
#     core type: Operation
#     operator: 43
#     operands: 44
# 41. x
#     core type: Variable
#     sub-expressions:
# 42. a_{k}
#     core type: IndexedVar
# variable: 52
# index: 47
# 43. Set
#     core type: Literal
#     sub-expressions:
# 44. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 46
# 45. (k)
#     core type: ExprTuple
#     sub-expressions: 47
# 46. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 49
#     end_index: 50
# 47. k
#     core type: Variable
#     sub-expressions:
# 48. _a -> a_{_a}
#     core type: Lambda
#     parameter: 54
#     body: 51
# 49. 1
#     core type: Literal
#     sub-expressions:
# 50. n
#     core type: Variable
#     sub-expressions:
# 51. a_{_a}
#     core type: IndexedVar
# variable: 52
# index: 54
# 52. a
#     core type: Variable
#     sub-expressions:
# 53. (_a)
#     core type: ExprTuple
#     sub-expressions: 54
# 54. _a
#     core type: Variable
#     sub-expressions:
