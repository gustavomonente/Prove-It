# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import i, j, k, x
from proveit.core_expr_types import a_1_to_i, b_1_to_j, c_1_to_k
from proveit.logic import Equals, Forall, Set
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Forall([i, j, k], Forall([a_1_to_i, x, b_1_to_j, c_1_to_k], Equals(Set(a_1_to_i, x, b_1_to_j, x, c_1_to_k), Set(a_1_to_i, b_1_to_j, x, c_1_to_k))), domains = [Natural, Natural, Natural])
# Out:
# expr: forall_{i, j, k in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k}} ({a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}} = {a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}})]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{i, j, k \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{i}, x, b_{1}, \ldots, b_{j}, c_{1}, \ldots, c_{k}}~\left(\left\{a_{1}, \ldots, a_{i}, x, b_{1}, \ldots, b_{j}, x, c_{1}, \ldots, c_{k}\right\} = \left\{a_{1}, \ldots, a_{i}, b_{1}, \ldots, b_{j}, x, c_{1}, \ldots, c_{k}\right\}\right)\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{i, j, k in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k}} ({a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}} = {a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}})]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((i, j, k) -> {forall_{a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k}} ({a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}} = {a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}}) if i in Natural ,  j in Natural ,  k in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (i, j, k) -> {forall_{a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k}} ({a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}} = {a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}}) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (i, j, k)
#    core type: ExprTuple
#    sub-expressions: 34, 36, 39
# 4. {forall_{a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k}} ({a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}} = {a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}}) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k}} ({a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}} = {a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}})
#    core type: Operation
#    operator: 7
#    operand: 11
# 6. (i in Natural) and (j in Natural) and (k in Natural)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k}) -> ({a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}} = {a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}}))
#    core type: ExprTuple
#    sub-expressions: 11
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (i in Natural, j in Natural, k in Natural)
#     core type: ExprTuple
#     sub-expressions: 12, 13, 14
# 11. (a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k}) -> ({a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}} = {a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}})
#     core type: Lambda
#     parameters: 15\n    body: 16
# 12. i in Natural
#     core type: Operation
#     operator: 19
#     operands: 17
# 13. j in Natural
#     core type: Operation
#     operator: 19
#     operands: 18
# 14. k in Natural
#     core type: Operation
#     operator: 19
#     operands: 20
# 15. (a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k})
#     core type: ExprTuple
#     sub-expressions: 29, 31, 30, 32
# 16. {a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}} = {a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}}
#     core type: Operation
#     operator: 21
#     operands: 22
# 17. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 34, 23
# 18. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 36, 23
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 39, 23
# 21. =
#     core type: Literal
#     sub-expressions:
# 22. ({a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}}, {a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 23. Natural
#     core type: Literal
#     sub-expressions:
# 24. {a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}}
#     core type: Operation
#     operator: 27
#     operands: 26
# 25. {a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}}
#     core type: Operation
#     operator: 27
#     operands: 28
# 26. (a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k})
#     core type: ExprTuple
#     sub-expressions: 29, 31, 30, 31, 32
# 27. Set
#     core type: Literal
#     sub-expressions:
# 28. (a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k})
#     core type: ExprTuple
#     sub-expressions: 29, 30, 31, 32
# 29. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 38
#     end_index: 34
# 30. b_{1}, ..b_{_a}.., b_{j}
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 38
#     end_index: 36
# 31. x
#     core type: Variable
#     sub-expressions:
# 32. c_{1}, ..c_{_a}.., c_{k}
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 38
#     end_index: 39
# 33. _a -> a_{_a}
#     core type: Lambda
#     parameter: 47
#     body: 40
# 34. i
#     core type: Variable
#     sub-expressions:
# 35. _a -> b_{_a}
#     core type: Lambda
#     parameter: 47
#     body: 41
# 36. j
#     core type: Variable
#     sub-expressions:
# 37. _a -> c_{_a}
#     core type: Lambda
#     parameter: 47
#     body: 42
# 38. 1
#     core type: Literal
#     sub-expressions:
# 39. k
#     core type: Variable
#     sub-expressions:
# 40. a_{_a}
#     core type: IndexedVar
# variable: 43
# index: 47
# 41. b_{_a}
#     core type: IndexedVar
# variable: 44
# index: 47
# 42. c_{_a}
#     core type: IndexedVar
# variable: 45
# index: 47
# 43. a
#     core type: Variable
#     sub-expressions:
# 44. b
#     core type: Variable
#     sub-expressions:
# 45. c
#     core type: Variable
#     sub-expressions:
# 46. (_a)
#     core type: ExprTuple
#     sub-expressions: 47
# 47. _a
#     core type: Variable
#     sub-expressions:
