# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import P, Px, Q, Qx, n, x
from proveit.core_expr_types import Qk_implies_Pk_a1_to_an, a_1_to_n
from proveit.logic import Forall, Set
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Forall([n], Forall([a_1_to_n], Forall([P, Q], Forall([x], Px, domains = [Set(a_1_to_n)], condition = Qx), condition = Qk_implies_Pk_a1_to_an)), domains = [Natural])
# Out:
# expr: forall_{n in Natural} [forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P, Q | Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)]]]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{n \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{n}}~\left[\forall_{P, Q~|~Q(a_{1}) \Rightarrow P(a_{1}), \ldots, Q(a_{n}) \Rightarrow P(a_{n})}~\left[\forall_{x \in \left\{a_{1}, \ldots, a_{n}\right\}~|~Q(x)}~P(x)\right]\right]\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{n in Natural} [forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P, Q | Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)]]]
#    core type: Operation
#    operator: 17
#    operand: 2
# 1. (n -> {forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P, Q | Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)]] if n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P, Q | Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)]] if n in Natural.
#    core type: Lambda
#    parameter: 51
#    body: 3
# 3. {forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P, Q | Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)]] if n in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P, Q | Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)]]
#    core type: Operation
#    operator: 17
#    operand: 8
# 5. n in Natural
#    core type: Operation
#    operator: 35
#    operands: 7
# 6. ((a_{1}, ..a_{_a}.., a_{n}) -> [forall_{P, Q | Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)]])
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (n, Natural)
#    core type: ExprTuple
#    sub-expressions: 51, 9
# 8. (a_{1}, ..a_{_a}.., a_{n}) -> [forall_{P, Q | Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)]]
#    core type: Lambda
#    parameters: 45\n   body: 10
# 9. Natural
#    core type: Literal
#    sub-expressions:
# 10. forall_{P, Q | Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)]
#     core type: Operation
#     operator: 17
#     operand: 12
# 11. ((P, Q) -> {forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x) if (Q(a_{1}) => P(a_{1})) and ..(Q(a_{k}) => P(a_{k})).. and (Q(a_{n}) => P(a_{n})).)
#     core type: ExprTuple
#     sub-expressions: 12
# 12. (P, Q) -> {forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x) if (Q(a_{1}) => P(a_{1})) and ..(Q(a_{k}) => P(a_{k})).. and (Q(a_{n}) => P(a_{n})).
#     core type: Lambda
#     parameters: 13\n    body: 14
# 13. (P, Q)
#     core type: ExprTuple
#     sub-expressions: 39, 38
# 14. {forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x) if (Q(a_{1}) => P(a_{1})) and ..(Q(a_{k}) => P(a_{k})).. and (Q(a_{n}) => P(a_{n})).
#     core type: Conditional
#     value: 15
#     condition: 16
# 15. forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)
#     core type: Operation
#     operator: 17
#     operand: 20
# 16. (Q(a_{1}) => P(a_{1})) and ..(Q(a_{k}) => P(a_{k})).. and (Q(a_{n}) => P(a_{n}))
#     core type: Operation
#     operator: 27
#     operands: 19
# 17. forall
#     core type: Literal
#     sub-expressions:
# 18. (x -> {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}} ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 20
# 19. (Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n}))
#     core type: ExprTuple
#     sub-expressions: 21
# 20. x -> {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}} ,  Q(x).
#     core type: Lambda
#     parameter: 42
#     body: 22
# 21. (Q(a_{1}) => P(a_{1})), ..(Q(a_{k}) => P(a_{k})).., (Q(a_{n}) => P(a_{n}))
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 50
#     end_index: 51
# 22. {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}} ,  Q(x).
#     core type: Conditional
#     value: 24
#     condition: 25
# 23. k -> (Q(a_{k}) => P(a_{k}))
#     core type: Lambda
#     parameter: 48
#     body: 26
# 24. P(x)
#     core type: Operation
#     operator: 39
#     operand: 42
# 25. (x in {a_{1}, ..a_{_a}.., a_{n}}) and Q(x)
#     core type: Operation
#     operator: 27
#     operands: 28
# 26. Q(a_{k}) => P(a_{k})
#     core type: Operation
#     operator: 29
#     operands: 30
# 27. and
#     core type: Literal
#     sub-expressions:
# 28. (x in {a_{1}, ..a_{_a}.., a_{n}}, Q(x))
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. =>
#     core type: Literal
#     sub-expressions:
# 30. (Q(a_{k}), P(a_{k}))
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 31. x in {a_{1}, ..a_{_a}.., a_{n}}
#     core type: Operation
#     operator: 35
#     operands: 36
# 32. Q(x)
#     core type: Operation
#     operator: 38
#     operand: 42
# 33. Q(a_{k})
#     core type: Operation
#     operator: 38
#     operand: 43
# 34. P(a_{k})
#     core type: Operation
#     operator: 39
#     operand: 43
# 35. in
#     core type: Literal
#     sub-expressions:
# 36. (x, {a_{1}, ..a_{_a}.., a_{n}})
#     core type: ExprTuple
#     sub-expressions: 42, 41
# 37. (x)
#     core type: ExprTuple
#     sub-expressions: 42
# 38. Q
#     core type: Variable
#     sub-expressions:
# 39. P
#     core type: Variable
#     sub-expressions:
# 40. (a_{k})
#     core type: ExprTuple
#     sub-expressions: 43
# 41. {a_{1}, ..a_{_a}.., a_{n}}
#     core type: Operation
#     operator: 44
#     operands: 45
# 42. x
#     core type: Variable
#     sub-expressions:
# 43. a_{k}
#     core type: IndexedVar
# variable: 53
# index: 48
# 44. Set
#     core type: Literal
#     sub-expressions:
# 45. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 47
# 46. (k)
#     core type: ExprTuple
#     sub-expressions: 48
# 47. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 50
#     end_index: 51
# 48. k
#     core type: Variable
#     sub-expressions:
# 49. _a -> a_{_a}
#     core type: Lambda
#     parameter: 55
#     body: 52
# 50. 1
#     core type: Literal
#     sub-expressions:
# 51. n
#     core type: Variable
#     sub-expressions:
# 52. a_{_a}
#     core type: IndexedVar
# variable: 53
# index: 55
# 53. a
#     core type: Variable
#     sub-expressions:
# 54. (_a)
#     core type: ExprTuple
#     sub-expressions: 55
# 55. _a
#     core type: Variable
#     sub-expressions:
