# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#equal_element_equality">equal_element_equality</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.enumeration import equal_element_equality

# %%
# check that the built expression is the same as the stored expression
assert equal_element_equality.expr == stored_expr
assert equal_element_equality.expr._style_id == stored_expr._style_id
print("Passed sanity check: equal_element_equality matches stored_expr")
# Out:
# Passed sanity check: equal_element_equality matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(equal_element_equality.latex())
# Out:
# \vdash \forall_{m, n \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{m}, b, c_{1}, \ldots, c_{n}, d~|~b = d}~\left(\left\{a_{1}, \ldots, a_{m}, b, c_{1}, \ldots, c_{n}\right\} = \left\{a_{1}, \ldots, a_{m}, d, c_{1}, \ldots, c_{n}\right\}\right)\right]

# %%
equal_element_equality.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
equal_element_equality.expr_info()
# Out:
# 0. forall_{m, n in Natural} [forall_{a_{1}, ..a_{_a}.., a_{m}, b, c_{1}, ..c_{_a}.., c_{n}, d | b = d} ({a_{1}, ..a_{_a}.., a_{m}, b, c_{1}, ..c_{_a}.., c_{n}} = {a_{1}, ..a_{_a}.., a_{m}, d, c_{1}, ..c_{_a}.., c_{n}})]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((m, n) -> {forall_{a_{1}, ..a_{_a}.., a_{m}, b, c_{1}, ..c_{_a}.., c_{n}, d | b = d} ({a_{1}, ..a_{_a}.., a_{m}, b, c_{1}, ..c_{_a}.., c_{n}} = {a_{1}, ..a_{_a}.., a_{m}, d, c_{1}, ..c_{_a}.., c_{n}}) if m in Natural ,  n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (m, n) -> {forall_{a_{1}, ..a_{_a}.., a_{m}, b, c_{1}, ..c_{_a}.., c_{n}, d | b = d} ({a_{1}, ..a_{_a}.., a_{m}, b, c_{1}, ..c_{_a}.., c_{n}} = {a_{1}, ..a_{_a}.., a_{m}, d, c_{1}, ..c_{_a}.., c_{n}}) if m in Natural ,  n in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (m, n)
#    core type: ExprTuple
#    sub-expressions: 35, 38
# ...
