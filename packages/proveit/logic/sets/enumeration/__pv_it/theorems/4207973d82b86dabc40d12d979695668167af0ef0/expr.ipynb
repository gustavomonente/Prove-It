# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import P, Px, x
from proveit.core_expr_types import Pk_a1_to_an, a_1_to_n
from proveit.logic import Forall, Set

# %%
# build up the expression from sub-expressions
expr = Forall([P], Forall([x], Px, domains = [Set(a_1_to_n)]), condition = Pk_a1_to_an)
# Out:
# expr: forall_{P | P(a_{1}), ..P(a_{k}).., P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{P~|~P(a_{1}), \ldots, P(a_{n})}~\left[\forall_{x \in \left\{a_{1}, \ldots, a_{n}\right\}}~P(x)\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{P | P(a_{1}), ..P(a_{k}).., P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (P -> {forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x) if P(a_{1}) and ..P(a_{k}).. and P(a_{n}).)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. P -> {forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x) if P(a_{1}) and ..P(a_{k}).. and P(a_{n}).
#    core type: Lambda
#    parameter: 20
#    body: 3
# 3. {forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x) if P(a_{1}) and ..P(a_{k}).. and P(a_{n}).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)
#    core type: Operation
#    operator: 6
#    operand: 10
# 5. P(a_{1}) and ..P(a_{k}).. and P(a_{n})
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (x -> {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}}.)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (P(a_{1}), ..P(a_{k}).., P(a_{n}))
#    core type: ExprTuple
#    sub-expressions: 11
# 10. x -> {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}}.
#     core type: Lambda
#     parameter: 22
#     body: 12
# 11. P(a_{1}), ..P(a_{k}).., P(a_{n})
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 31
#     end_index: 32
# 12. {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}}.
#     core type: Conditional
#     value: 14
#     condition: 15
# 13. k -> P(a_{k})
#     core type: Lambda
#     parameter: 29
#     body: 16
# 14. P(x)
#     core type: Operation
#     operator: 20
#     operand: 22
# 15. x in {a_{1}, ..a_{_a}.., a_{n}}
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. P(a_{k})
#     core type: Operation
#     operator: 20
#     operand: 24
# 17. (x)
#     core type: ExprTuple
#     sub-expressions: 22
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (x, {a_{1}, ..a_{_a}.., a_{n}})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. P
#     core type: Variable
#     sub-expressions:
# 21. (a_{k})
#     core type: ExprTuple
#     sub-expressions: 24
# 22. x
#     core type: Variable
#     sub-expressions:
# 23. {a_{1}, ..a_{_a}.., a_{n}}
#     core type: Operation
#     operator: 25
#     operands: 26
# 24. a_{k}
#     core type: IndexedVar
# variable: 34
# index: 29
# 25. Set
#     core type: Literal
#     sub-expressions:
# 26. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 28
# 27. (k)
#     core type: ExprTuple
#     sub-expressions: 29
# 28. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 31
#     end_index: 32
# 29. k
#     core type: Variable
#     sub-expressions:
# 30. _a -> a_{_a}
#     core type: Lambda
#     parameter: 36
#     body: 33
# 31. 1
#     core type: Literal
#     sub-expressions:
# 32. n
#     core type: Variable
#     sub-expressions:
# 33. a_{_a}
#     core type: IndexedVar
# variable: 34
# index: 36
# 34. a
#     core type: Variable
#     sub-expressions:
# 35. (_a)
#     core type: ExprTuple
#     sub-expressions: 36
# 36. _a
#     core type: Variable
#     sub-expressions:
