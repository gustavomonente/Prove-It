# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, x
from proveit.core_expr_types import a_1_to_i, b_1_to_j, c_1_to_k
from proveit.logic import Set

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Set(a_1_to_i, x, b_1_to_j, x, c_1_to_k), Set(a_1_to_i, x, b_1_to_j, c_1_to_k))
# Out:
# expr: ({a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}}, {a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k}})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left\{a_{1}, \ldots, a_{i}, x, b_{1}, \ldots, b_{j}, x, c_{1}, \ldots, c_{k}\right\}, \left\{a_{1}, \ldots, a_{i}, x, b_{1}, \ldots, b_{j}, c_{1}, \ldots, c_{k}\right\}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ({a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}}, {a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k}})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. {a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}}
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. {a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k}}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k})
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 7, 9
# 4. Set
#    core type: Literal
#    sub-expressions:
# 5. (a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k})
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 9
# 6. a_{1}, ..a_{_a}.., a_{i}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 15
#    end_index: 11
# 7. x
#    core type: Variable
#    sub-expressions:
# 8. b_{1}, ..b_{_a}.., b_{j}
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 15
#    end_index: 13
# 9. c_{1}, ..c_{_a}.., c_{k}
#    core type: ExprRange
#    lambda_map: 14
#    start_index: 15
#    end_index: 16
# 10. _a -> a_{_a}
#     core type: Lambda
#     parameter: 24
#     body: 17
# 11. i
#     core type: Variable
#     sub-expressions:
# 12. _a -> b_{_a}
#     core type: Lambda
#     parameter: 24
#     body: 18
# 13. j
#     core type: Variable
#     sub-expressions:
# 14. _a -> c_{_a}
#     core type: Lambda
#     parameter: 24
#     body: 19
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. k
#     core type: Variable
#     sub-expressions:
# 17. a_{_a}
#     core type: IndexedVar
# variable: 20
# index: 24
# 18. b_{_a}
#     core type: IndexedVar
# variable: 21
# index: 24
# 19. c_{_a}
#     core type: IndexedVar
# variable: 22
# index: 24
# 20. a
#     core type: Variable
#     sub-expressions:
# 21. b
#     core type: Variable
#     sub-expressions:
# 22. c
#     core type: Variable
#     sub-expressions:
# 23. (_a)
#     core type: ExprTuple
#     sub-expressions: 24
# 24. _a
#     core type: Variable
#     sub-expressions:
