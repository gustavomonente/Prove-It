# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, x
from proveit.core_expr_types import y_1_to_n
from proveit.logic import NotInSet, Set
from proveit.logic.sets import x_notequals_all_y

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([x, y_1_to_n], Conditional(x_notequals_all_y, NotInSet(x, Set(y_1_to_n)))))
# Out:
# expr: ((x, y_{1}, ..y_{_a}.., y_{n}) -> {(x != y_{1}) and ..(x != y_{i}).. and (x != y_{n}) if x not-in {y_{1}, ..y_{_a}.., y_{n}}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(x, y_{1}, \ldots, y_{n}\right) \mapsto \left\{\left(x \neq y_{1}\right) \land \ldots \land \left(x \neq y_{n}\right) \textrm{ if } x \notin \left\{y_{1}, \ldots, y_{n}\right\}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((x, y_{1}, ..y_{_a}.., y_{n}) -> {(x != y_{1}) and ..(x != y_{i}).. and (x != y_{n}) if x not-in {y_{1}, ..y_{_a}.., y_{n}}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (x, y_{1}, ..y_{_a}.., y_{n}) -> {(x != y_{1}) and ..(x != y_{i}).. and (x != y_{n}) if x not-in {y_{1}, ..y_{_a}.., y_{n}}.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (x, y_{1}, ..y_{_a}.., y_{n})
#    core type: ExprTuple
#    sub-expressions: 22, 16
# 3. {(x != y_{1}) and ..(x != y_{i}).. and (x != y_{n}) if x not-in {y_{1}, ..y_{_a}.., y_{n}}.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (x != y_{1}) and ..(x != y_{i}).. and (x != y_{n})
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. x not-in {y_{1}, ..y_{_a}.., y_{n}}
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (x != y_{1}, ..x != y_{i}.., x != y_{n})
#    core type: ExprTuple
#    sub-expressions: 10
# 8. not-in
#    core type: Literal
#    sub-expressions:
# 9. (x, {y_{1}, ..y_{_a}.., y_{n}})
#    core type: ExprTuple
#    sub-expressions: 22, 11
# 10. (x != y_{1}), ..(x != y_{i}).., (x != y_{n})
#     core type: ExprRange
#     lambda_map: 12
#     start_index: 20
#     end_index: 21
# 11. {y_{1}, ..y_{_a}.., y_{n}}
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. i -> (x != y_{i})
#     core type: Lambda
#     parameter: 28
#     body: 15
# 13. Set
#     core type: Literal
#     sub-expressions:
# 14. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 16
# 15. x != y_{i}
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 20
#     end_index: 21
# 17. !=
#     core type: Literal
#     sub-expressions:
# 18. (x, y_{i})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 19. _a -> y_{_a}
#     core type: Lambda
#     parameter: 29
#     body: 24
# 20. 1
#     core type: Literal
#     sub-expressions:
# 21. n
#     core type: Variable
#     sub-expressions:
# 22. x
#     core type: Variable
#     sub-expressions:
# 23. y_{i}
#     core type: IndexedVar
# variable: 26
# index: 28
# 24. y_{_a}
#     core type: IndexedVar
# variable: 26
# index: 29
# 25. (i)
#     core type: ExprTuple
#     sub-expressions: 28
# 26. y
#     core type: Variable
#     sub-expressions:
# 27. (_a)
#     core type: ExprTuple
#     sub-expressions: 29
# 28. i
#     core type: Variable
#     sub-expressions:
# 29. _a
#     core type: Variable
#     sub-expressions:
