# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, m, n
from proveit.core_expr_types import a_1_to_m, b_1_to_n
from proveit.logic import And, Forall, InSet, Set, SubsetEq
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([a_1_to_m, b_1_to_n], SubsetEq(Set(a_1_to_m), Set(a_1_to_m, b_1_to_n))), And(InSet(m, Natural), InSet(n, Natural)))
# Out:
# expr: {forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}} ({a_{1}, ..a_{_a}.., a_{m}} subset_eq {a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}}) if m in Natural ,  n in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{a_{1}, \ldots, a_{m}, b_{1}, \ldots, b_{n}}~\left(\left\{a_{1}, \ldots, a_{m}\right\} \subseteq \left\{a_{1}, \ldots, a_{m}, b_{1}, \ldots, b_{n}\right\}\right) \textrm{ if } m \in \mathbb{N} ,  n \in \mathbb{N}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}} ({a_{1}, ..a_{_a}.., a_{m}} subset_eq {a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}}) if m in Natural ,  n in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}} ({a_{1}, ..a_{_a}.., a_{m}} subset_eq {a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}})
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. (m in Natural) and (n in Natural)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}) -> ({a_{1}, ..a_{_a}.., a_{m}} subset_eq {a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}}))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (m in Natural, n in Natural)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}) -> ({a_{1}, ..a_{_a}.., a_{m}} subset_eq {a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}})
#    core type: Lambda
#    parameters: 21\n   body: 10
# 8. m in Natural
#    core type: Operation
#    operator: 12
#    operands: 11
# 9. n in Natural
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. {a_{1}, ..a_{_a}.., a_{m}} subset_eq {a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}}
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 25, 16
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 28, 16
# 14. subset_eq
#     core type: Literal
#     sub-expressions:
# 15. ({a_{1}, ..a_{_a}.., a_{m}}, {a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}})
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. Natural
#     core type: Literal
#     sub-expressions:
# 17. {a_{1}, ..a_{_a}.., a_{m}}
#     core type: Operation
#     operator: 20
#     operands: 19
# 18. {a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}}
#     core type: Operation
#     operator: 20
#     operands: 21
# 19. (a_{1}, ..a_{_a}.., a_{m})
#     core type: ExprTuple
#     sub-expressions: 22
# 20. Set
#     core type: Literal
#     sub-expressions:
# 21. (a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 22. a_{1}, ..a_{_a}.., a_{m}
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 27
#     end_index: 25
# 23. b_{1}, ..b_{_a}.., b_{n}
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 27
#     end_index: 28
# 24. _a -> a_{_a}
#     core type: Lambda
#     parameter: 34
#     body: 29
# 25. m
#     core type: Variable
#     sub-expressions:
# 26. _a -> b_{_a}
#     core type: Lambda
#     parameter: 34
#     body: 30
# 27. 1
#     core type: Literal
#     sub-expressions:
# 28. n
#     core type: Variable
#     sub-expressions:
# 29. a_{_a}
#     core type: IndexedVar
# variable: 31
# index: 34
# 30. b_{_a}
#     core type: IndexedVar
# variable: 32
# index: 34
# 31. a
#     core type: Variable
#     sub-expressions:
# 32. b
#     core type: Variable
#     sub-expressions:
# 33. (_a)
#     core type: ExprTuple
#     sub-expressions: 34
# 34. _a
#     core type: Variable
#     sub-expressions:
