# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import c
from proveit.core_expr_types import a_1_to_i, b_1_to_j, d_1_to_k
from proveit.logic import Equals, Forall, Set

# %%
# build up the expression from sub-expressions
expr = Forall([a_1_to_i, b_1_to_j, c, d_1_to_k], Equals(Set(a_1_to_i, b_1_to_j, c, d_1_to_k), Set(a_1_to_i, c, b_1_to_j, d_1_to_k)))
# Out:
# expr: forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c, d_{1}, ..d_{_a}.., d_{k}} ({a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c, d_{1}, ..d_{_a}.., d_{k}} = {a_{1}, ..a_{_a}.., a_{i}, c, b_{1}, ..b_{_a}.., b_{j}, d_{1}, ..d_{_a}.., d_{k}})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a_{1}, \ldots, a_{i}, b_{1}, \ldots, b_{j}, c, d_{1}, \ldots, d_{k}}~\left(\left\{a_{1}, \ldots, a_{i}, b_{1}, \ldots, b_{j}, c, d_{1}, \ldots, d_{k}\right\} = \left\{a_{1}, \ldots, a_{i}, c, b_{1}, \ldots, b_{j}, d_{1}, \ldots, d_{k}\right\}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c, d_{1}, ..d_{_a}.., d_{k}} ({a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c, d_{1}, ..d_{_a}.., d_{k}} = {a_{1}, ..a_{_a}.., a_{i}, c, b_{1}, ..b_{_a}.., b_{j}, d_{1}, ..d_{_a}.., d_{k}})
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c, d_{1}, ..d_{_a}.., d_{k}) -> ({a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c, d_{1}, ..d_{_a}.., d_{k}} = {a_{1}, ..a_{_a}.., a_{i}, c, b_{1}, ..b_{_a}.., b_{j}, d_{1}, ..d_{_a}.., d_{k}}))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c, d_{1}, ..d_{_a}.., d_{k}) -> ({a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c, d_{1}, ..d_{_a}.., d_{k}} = {a_{1}, ..a_{_a}.., a_{i}, c, b_{1}, ..b_{_a}.., b_{j}, d_{1}, ..d_{_a}.., d_{k}})
#    core type: Lambda
#    parameters: 9\n   body: 4
# 4. {a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c, d_{1}, ..d_{_a}.., d_{k}} = {a_{1}, ..a_{_a}.., a_{i}, c, b_{1}, ..b_{_a}.., b_{j}, d_{1}, ..d_{_a}.., d_{k}}
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. ({a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c, d_{1}, ..d_{_a}.., d_{k}}, {a_{1}, ..a_{_a}.., a_{i}, c, b_{1}, ..b_{_a}.., b_{j}, d_{1}, ..d_{_a}.., d_{k}})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. {a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c, d_{1}, ..d_{_a}.., d_{k}}
#    core type: Operation
#    operator: 10
#    operands: 9
# 8. {a_{1}, ..a_{_a}.., a_{i}, c, b_{1}, ..b_{_a}.., b_{j}, d_{1}, ..d_{_a}.., d_{k}}
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c, d_{1}, ..d_{_a}.., d_{k})
#    core type: ExprTuple
#    sub-expressions: 12, 14, 13, 15
# 10. Set
#     core type: Literal
#     sub-expressions:
# 11. (a_{1}, ..a_{_a}.., a_{i}, c, b_{1}, ..b_{_a}.., b_{j}, d_{1}, ..d_{_a}.., d_{k})
#     core type: ExprTuple
#     sub-expressions: 12, 13, 14, 15
# 12. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 21
#     end_index: 17
# 13. c
#     core type: Variable
#     sub-expressions:
# 14. b_{1}, ..b_{_a}.., b_{j}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 21
#     end_index: 19
# 15. d_{1}, ..d_{_a}.., d_{k}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 21
#     end_index: 22
# 16. _a -> a_{_a}
#     core type: Lambda
#     parameter: 30
#     body: 23
# 17. i
#     core type: Variable
#     sub-expressions:
# 18. _a -> b_{_a}
#     core type: Lambda
#     parameter: 30
#     body: 24
# 19. j
#     core type: Variable
#     sub-expressions:
# 20. _a -> d_{_a}
#     core type: Lambda
#     parameter: 30
#     body: 25
# 21. 1
#     core type: Literal
#     sub-expressions:
# 22. k
#     core type: Variable
#     sub-expressions:
# 23. a_{_a}
#     core type: IndexedVar
# variable: 26
# index: 30
# 24. b_{_a}
#     core type: IndexedVar
# variable: 27
# index: 30
# 25. d_{_a}
#     core type: IndexedVar
# variable: 28
# index: 30
# 26. a
#     core type: Variable
#     sub-expressions:
# 27. b
#     core type: Variable
#     sub-expressions:
# 28. d
#     core type: Variable
#     sub-expressions:
# 29. (_a)
#     core type: ExprTuple
#     sub-expressions: 30
# 30. _a
#     core type: Variable
#     sub-expressions:
