# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda
from proveit.core_expr_types import a_1_to_m, b_1_to_n
from proveit.logic import Set, SubsetEq

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([a_1_to_m, b_1_to_n], SubsetEq(Set(a_1_to_m), Set(a_1_to_m, b_1_to_n))))
# Out:
# expr: ((a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}) -> ({a_{1}, ..a_{_a}.., a_{m}} subset_eq {a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a_{1}, \ldots, a_{m}, b_{1}, \ldots, b_{n}\right) \mapsto \left(\left\{a_{1}, \ldots, a_{m}\right\} \subseteq \left\{a_{1}, \ldots, a_{m}, b_{1}, \ldots, b_{n}\right\}\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}) -> ({a_{1}, ..a_{_a}.., a_{m}} subset_eq {a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}}))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}) -> ({a_{1}, ..a_{_a}.., a_{m}} subset_eq {a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}})
#    core type: Lambda
#    parameters: 9\n   body: 2
# 2. {a_{1}, ..a_{_a}.., a_{m}} subset_eq {a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}}
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. subset_eq
#    core type: Literal
#    sub-expressions:
# 4. ({a_{1}, ..a_{_a}.., a_{m}}, {a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}})
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. {a_{1}, ..a_{_a}.., a_{m}}
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. {a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a_{1}, ..a_{_a}.., a_{m})
#    core type: ExprTuple
#    sub-expressions: 10
# 8. Set
#    core type: Literal
#    sub-expressions:
# 9. (a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. a_{1}, ..a_{_a}.., a_{m}
#     core type: ExprRange
#     lambda_map: 12
#     start_index: 15
#     end_index: 13
# 11. b_{1}, ..b_{_a}.., b_{n}
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 15
#     end_index: 16
# 12. _a -> a_{_a}
#     core type: Lambda
#     parameter: 22
#     body: 17
# 13. m
#     core type: Variable
#     sub-expressions:
# 14. _a -> b_{_a}
#     core type: Lambda
#     parameter: 22
#     body: 18
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. n
#     core type: Variable
#     sub-expressions:
# 17. a_{_a}
#     core type: IndexedVar
# variable: 19
# index: 22
# 18. b_{_a}
#     core type: IndexedVar
# variable: 20
# index: 22
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. b
#     core type: Variable
#     sub-expressions:
# 21. (_a)
#     core type: ExprTuple
#     sub-expressions: 22
# 22. _a
#     core type: Variable
#     sub-expressions:
