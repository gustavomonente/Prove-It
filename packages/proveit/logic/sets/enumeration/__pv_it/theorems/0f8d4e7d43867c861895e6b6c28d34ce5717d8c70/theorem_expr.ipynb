# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#true_for_all_then_true_for_each">true_for_all_then_true_for_each</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.enumeration import true_for_all_then_true_for_each

# %%
# check that the built expression is the same as the stored expression
assert true_for_all_then_true_for_each.expr == stored_expr
assert true_for_all_then_true_for_each.expr._style_id == stored_expr._style_id
print("Passed sanity check: true_for_all_then_true_for_each matches stored_expr")
# Out:
# Passed sanity check: true_for_all_then_true_for_each matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(true_for_all_then_true_for_each.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{n}}~\left[\forall_{P~|~\forall_{x \in \left\{a_{1}, \ldots, a_{n}\right\}}~P(x)}~\left(P(a_{1}) \land \ldots \land P(a_{n})\right)\right]\right]

# %%
true_for_all_then_true_for_each.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
true_for_all_then_true_for_each.expr_info()
# Out:
# 0. forall_{n in Natural} [forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P | forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)} (P(a_{1}) and ..P(a_{k}).. and P(a_{n}))]]
#    core type: Operation
#    operator: 18
#    operand: 2
# 1. (n -> {forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P | forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)} (P(a_{1}) and ..P(a_{k}).. and P(a_{n}))] if n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P | forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)} (P(a_{1}) and ..P(a_{k}).. and P(a_{n}))] if n in Natural.
#    core type: Lambda
#    parameter: 42
#    body: 3
# 3. {forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P | forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)} (P(a_{1}) and ..P(a_{k}).. and P(a_{n}))] if n in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# ...
