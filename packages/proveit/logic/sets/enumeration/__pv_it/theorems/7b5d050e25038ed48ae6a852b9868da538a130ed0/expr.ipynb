# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, P, Px, x
from proveit.core_expr_types import Pk_a1_to_an, a_1_to_n
from proveit.logic import And, Forall, Set

# %%
# build up the expression from sub-expressions
expr = Lambda([a_1_to_n], Forall([P], And(Pk_a1_to_an), condition = Forall([x], Px, domains = [Set(a_1_to_n)])))
# Out:
# expr: (a_{1}, ..a_{_a}.., a_{n}) -> [forall_{P | forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)} (P(a_{1}) and ..P(a_{k}).. and P(a_{n}))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1}, \ldots, a_{n}\right) \mapsto \left[\forall_{P~|~\forall_{x \in \left\{a_{1}, \ldots, a_{n}\right\}}~P(x)}~\left(P(a_{1}) \land \ldots \land P(a_{n})\right)\right]

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1}, ..a_{_a}.., a_{n}) -> [forall_{P | forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)} (P(a_{1}) and ..P(a_{k}).. and P(a_{n}))]
#    core type: Lambda
#    parameters: 28\n   body: 1
# 1. forall_{P | forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)} (P(a_{1}) and ..P(a_{k}).. and P(a_{n}))
#    core type: Operation
#    operator: 9
#    operand: 3
# 2. (P -> {P(a_{1}) and ..P(a_{k}).. and P(a_{n}) if forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. P -> {P(a_{1}) and ..P(a_{k}).. and P(a_{n}) if forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x).
#    core type: Lambda
#    parameter: 19
#    body: 4
# 4. {P(a_{1}) and ..P(a_{k}).. and P(a_{n}) if forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. P(a_{1}) and ..P(a_{k}).. and P(a_{n})
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)
#    core type: Operation
#    operator: 9
#    operand: 12
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (P(a_{1}), ..P(a_{k}).., P(a_{n}))
#    core type: ExprTuple
#    sub-expressions: 11
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. (x -> {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}}.)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. P(a_{1}), ..P(a_{k}).., P(a_{n})
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 32
#     end_index: 33
# 12. x -> {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}}.
#     core type: Lambda
#     parameter: 24
#     body: 14
# 13. k -> P(a_{k})
#     core type: Lambda
#     parameter: 29
#     body: 15
# 14. {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}}.
#     core type: Conditional
#     value: 16
#     condition: 17
# 15. P(a_{k})
#     core type: Operation
#     operator: 19
#     operand: 23
# 16. P(x)
#     core type: Operation
#     operator: 19
#     operand: 24
# 17. x in {a_{1}, ..a_{_a}.., a_{n}}
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. (a_{k})
#     core type: ExprTuple
#     sub-expressions: 23
# 19. P
#     core type: Variable
#     sub-expressions:
# 20. (x)
#     core type: ExprTuple
#     sub-expressions: 24
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (x, {a_{1}, ..a_{_a}.., a_{n}})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 23. a_{k}
#     core type: IndexedVar
# variable: 35
# index: 29
# 24. x
#     core type: Variable
#     sub-expressions:
# 25. {a_{1}, ..a_{_a}.., a_{n}}
#     core type: Operation
#     operator: 27
#     operands: 28
# 26. (k)
#     core type: ExprTuple
#     sub-expressions: 29
# 27. Set
#     core type: Literal
#     sub-expressions:
# 28. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 30
# 29. k
#     core type: Variable
#     sub-expressions:
# 30. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 32
#     end_index: 33
# 31. _a -> a_{_a}
#     core type: Lambda
#     parameter: 37
#     body: 34
# 32. 1
#     core type: Literal
#     sub-expressions:
# 33. n
#     core type: Variable
#     sub-expressions:
# 34. a_{_a}
#     core type: IndexedVar
# variable: 35
# index: 37
# 35. a
#     core type: Variable
#     sub-expressions:
# 36. (_a)
#     core type: ExprTuple
#     sub-expressions: 37
# 37. _a
#     core type: Variable
#     sub-expressions:
