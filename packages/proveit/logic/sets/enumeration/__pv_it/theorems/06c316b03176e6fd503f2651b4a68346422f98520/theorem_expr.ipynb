# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#nonmembership_fold">nonmembership_fold</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.enumeration import nonmembership_fold

# %%
# check that the built expression is the same as the stored expression
assert nonmembership_fold.expr == stored_expr
assert nonmembership_fold.expr._style_id == stored_expr._style_id
print("Passed sanity check: nonmembership_fold matches stored_expr")
# Out:
# Passed sanity check: nonmembership_fold matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(nonmembership_fold.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}}~\left[\forall_{x, y_{1}, \ldots, y_{n}~|~x \neq y_{1}, \ldots, x \neq y_{n}}~\left(x \notin \left\{y_{1}, \ldots, y_{n}\right\}\right)\right]

# %%
nonmembership_fold.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
nonmembership_fold.expr_info()
# Out:
# 0. forall_{n in Natural} [forall_{x, y_{1}, ..y_{_a}.., y_{n} | x != y_{1}, ..x != y_{i}.., x != y_{n}} (x not-in {y_{1}, ..y_{_a}.., y_{n}})]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (n -> {forall_{x, y_{1}, ..y_{_a}.., y_{n} | x != y_{1}, ..x != y_{i}.., x != y_{n}} (x not-in {y_{1}, ..y_{_a}.., y_{n}}) if n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{x, y_{1}, ..y_{_a}.., y_{n} | x != y_{1}, ..x != y_{i}.., x != y_{n}} (x not-in {y_{1}, ..y_{_a}.., y_{n}}) if n in Natural.
#    core type: Lambda
#    parameter: 29
#    body: 3
# 3. {forall_{x, y_{1}, ..y_{_a}.., y_{n} | x != y_{1}, ..x != y_{i}.., x != y_{n}} (x not-in {y_{1}, ..y_{_a}.., y_{n}}) if n in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{x, y_{1}, ..y_{_a}.., y_{n} | x != y_{1}, ..x != y_{i}.., x != y_{n}} (x not-in {y_{1}, ..y_{_a}.., y_{n}})
#    core type: Operation
#    operator: 6
#    operand: 10
# 5. n in Natural
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((x, y_{1}, ..y_{_a}.., y_{n}) -> {x not-in {y_{1}, ..y_{_a}.., y_{n}} if (x != y_{1}) and ..(x != y_{i}).. and (x != y_{n}).)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (n, Natural)
#    core type: ExprTuple
#    sub-expressions: 29, 11
# 10. (x, y_{1}, ..y_{_a}.., y_{n}) -> {x not-in {y_{1}, ..y_{_a}.., y_{n}} if (x != y_{1}) and ..(x != y_{i}).. and (x != y_{n}).
#     core type: Lambda
#     parameters: 12\n    body: 13
# 11. Natural
#     core type: Literal
#     sub-expressions:
# 12. (x, y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 33, 25
# 13. {x not-in {y_{1}, ..y_{_a}.., y_{n}} if (x != y_{1}) and ..(x != y_{i}).. and (x != y_{n}).
#     core type: Conditional
#     value: 14
#     condition: 15
# 14. x not-in {y_{1}, ..y_{_a}.., y_{n}}
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. (x != y_{1}) and ..(x != y_{i}).. and (x != y_{n})
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. not-in
#     core type: Literal
#     sub-expressions:
# 17. (x, {y_{1}, ..y_{_a}.., y_{n}})
#     core type: ExprTuple
#     sub-expressions: 33, 20
# 18. and
#     core type: Literal
#     sub-expressions:
# 19. (x != y_{1}, ..x != y_{i}.., x != y_{n})
#     core type: ExprTuple
#     sub-expressions: 21
# 20. {y_{1}, ..y_{_a}.., y_{n}}
#     core type: Operation
#     operator: 22
#     operands: 23
# 21. (x != y_{1}), ..(x != y_{i}).., (x != y_{n})
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 28
#     end_index: 29
# 22. Set
#     core type: Literal
#     sub-expressions:
# 23. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 25
# 24. i -> (x != y_{i})
#     core type: Lambda
#     parameter: 39
#     body: 26
# 25. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 28
#     end_index: 29
# 26. x != y_{i}
#     core type: Operation
#     operator: 30
#     operands: 31
# 27. _a -> y_{_a}
#     core type: Lambda
#     parameter: 38
#     body: 32
# 28. 1
#     core type: Literal
#     sub-expressions:
# 29. n
#     core type: Variable
#     sub-expressions:
# 30. !=
#     core type: Literal
#     sub-expressions:
# 31. (x, y_{i})
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 32. y_{_a}
#     core type: IndexedVar
# variable: 36
# index: 38
# 33. x
#     core type: Variable
#     sub-expressions:
# 34. y_{i}
#     core type: IndexedVar
# variable: 36
# index: 39
# 35. (_a)
#     core type: ExprTuple
#     sub-expressions: 38
# 36. y
#     core type: Variable
#     sub-expressions:
# 37. (i)
#     core type: ExprTuple
#     sub-expressions: 39
# 38. _a
#     core type: Variable
#     sub-expressions:
# 39. i
#     core type: Variable
#     sub-expressions:
