# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#fold">fold</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.enumeration import fold

# %%
# check that the built expression is the same as the stored expression
assert fold.expr == stored_expr
assert fold.expr._style_id == stored_expr._style_id
print("Passed sanity check: fold matches stored_expr")
# Out:
# Passed sanity check: fold matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(fold.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}}~\left[\forall_{x, y_{1}, \ldots, y_{n}~|~\left(x = y_{1}\right) \lor \ldots \lor \left(x = y_{n}\right)}~\left(x \in \left\{y_{1}, \ldots, y_{n}\right\}\right)\right]

# %%
fold.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
fold.expr_info()
# Out:
# 0. forall_{n in Natural} [forall_{x, y_{1}, ..y_{_a}.., y_{n} | (x = y_{1}) or ..(x = y_{i}).. or (x = y_{n})} (x in {y_{1}, ..y_{_a}.., y_{n}})]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (n -> {forall_{x, y_{1}, ..y_{_a}.., y_{n} | (x = y_{1}) or ..(x = y_{i}).. or (x = y_{n})} (x in {y_{1}, ..y_{_a}.., y_{n}}) if n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{x, y_{1}, ..y_{_a}.., y_{n} | (x = y_{1}) or ..(x = y_{i}).. or (x = y_{n})} (x in {y_{1}, ..y_{_a}.., y_{n}}) if n in Natural.
#    core type: Lambda
#    parameter: 28
#    body: 3
# 3. {forall_{x, y_{1}, ..y_{_a}.., y_{n} | (x = y_{1}) or ..(x = y_{i}).. or (x = y_{n})} (x in {y_{1}, ..y_{_a}.., y_{n}}) if n in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{x, y_{1}, ..y_{_a}.., y_{n} | (x = y_{1}) or ..(x = y_{i}).. or (x = y_{n})} (x in {y_{1}, ..y_{_a}.., y_{n}})
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. n in Natural
#    core type: Operation
#    operator: 15
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((x, y_{1}, ..y_{_a}.., y_{n}) -> {x in {y_{1}, ..y_{_a}.., y_{n}} if (x = y_{1}) or ..(x = y_{i}).. or (x = y_{n}).)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (n, Natural)
#    core type: ExprTuple
#    sub-expressions: 28, 10
# 9. (x, y_{1}, ..y_{_a}.., y_{n}) -> {x in {y_{1}, ..y_{_a}.., y_{n}} if (x = y_{1}) or ..(x = y_{i}).. or (x = y_{n}).
#    core type: Lambda
#    parameters: 11\n   body: 12
# 10. Natural
#     core type: Literal
#     sub-expressions:
# 11. (x, y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 32, 24
# 12. {x in {y_{1}, ..y_{_a}.., y_{n}} if (x = y_{1}) or ..(x = y_{i}).. or (x = y_{n}).
#     core type: Conditional
#     value: 13
#     condition: 14
# 13. x in {y_{1}, ..y_{_a}.., y_{n}}
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (x = y_{1}) or ..(x = y_{i}).. or (x = y_{n})
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (x, {y_{1}, ..y_{_a}.., y_{n}})
#     core type: ExprTuple
#     sub-expressions: 32, 19
# 17. or
#     core type: Literal
#     sub-expressions:
# 18. (x = y_{1}, ..x = y_{i}.., x = y_{n})
#     core type: ExprTuple
#     sub-expressions: 20
# 19. {y_{1}, ..y_{_a}.., y_{n}}
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. (x = y_{1}), ..(x = y_{i}).., (x = y_{n})
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 27
#     end_index: 28
# 21. Set
#     core type: Literal
#     sub-expressions:
# 22. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 24
# 23. i -> (x = y_{i})
#     core type: Lambda
#     parameter: 38
#     body: 25
# 24. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 27
#     end_index: 28
# 25. x = y_{i}
#     core type: Operation
#     operator: 29
#     operands: 30
# 26. _a -> y_{_a}
#     core type: Lambda
#     parameter: 37
#     body: 31
# 27. 1
#     core type: Literal
#     sub-expressions:
# 28. n
#     core type: Variable
#     sub-expressions:
# 29. =
#     core type: Literal
#     sub-expressions:
# 30. (x, y_{i})
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 31. y_{_a}
#     core type: IndexedVar
# variable: 35
# index: 37
# 32. x
#     core type: Variable
#     sub-expressions:
# 33. y_{i}
#     core type: IndexedVar
# variable: 35
# index: 38
# 34. (_a)
#     core type: ExprTuple
#     sub-expressions: 37
# 35. y
#     core type: Variable
#     sub-expressions:
# 36. (i)
#     core type: ExprTuple
#     sub-expressions: 38
# 37. _a
#     core type: Variable
#     sub-expressions:
# 38. i
#     core type: Variable
#     sub-expressions:
