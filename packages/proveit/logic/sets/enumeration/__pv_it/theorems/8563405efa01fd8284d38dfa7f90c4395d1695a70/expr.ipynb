# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, P, Px, n, x
from proveit.core_expr_types import Pk_a1_to_an, a_1_to_n
from proveit.logic import And, Forall, InSet, Set
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Forall([a_1_to_n], Forall([P], And(Pk_a1_to_an), condition = Forall([x], Px, domains = [Set(a_1_to_n)]))), InSet(n, Natural)))
# Out:
# expr: n -> {forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P | forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)} (P(a_{1}) and ..P(a_{k}).. and P(a_{n}))] if n in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\forall_{a_{1}, \ldots, a_{n}}~\left[\forall_{P~|~\forall_{x \in \left\{a_{1}, \ldots, a_{n}\right\}}~P(x)}~\left(P(a_{1}) \land \ldots \land P(a_{n})\right)\right] \textrm{ if } n \in \mathbb{N}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. n -> {forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P | forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)} (P(a_{1}) and ..P(a_{k}).. and P(a_{n}))] if n in Natural.
#    core type: Lambda
#    parameter: 40
#    body: 1
# 1. {forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P | forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)} (P(a_{1}) and ..P(a_{k}).. and P(a_{n}))] if n in Natural.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P | forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)} (P(a_{1}) and ..P(a_{k}).. and P(a_{n}))]
#    core type: Operation
#    operator: 16
#    operand: 6
# 3. n in Natural
#    core type: Operation
#    operator: 28
#    operands: 5
# 4. ((a_{1}, ..a_{_a}.., a_{n}) -> [forall_{P | forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)} (P(a_{1}) and ..P(a_{k}).. and P(a_{n}))])
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (n, Natural)
#    core type: ExprTuple
#    sub-expressions: 40, 7
# 6. (a_{1}, ..a_{_a}.., a_{n}) -> [forall_{P | forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)} (P(a_{1}) and ..P(a_{k}).. and P(a_{n}))]
#    core type: Lambda
#    parameters: 35\n   body: 8
# 7. Natural
#    core type: Literal
#    sub-expressions:
# 8. forall_{P | forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)} (P(a_{1}) and ..P(a_{k}).. and P(a_{n}))
#    core type: Operation
#    operator: 16
#    operand: 10
# 9. (P -> {P(a_{1}) and ..P(a_{k}).. and P(a_{n}) if forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x).)
#    core type: ExprTuple
#    sub-expressions: 10
# 10. P -> {P(a_{1}) and ..P(a_{k}).. and P(a_{n}) if forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x).
#     core type: Lambda
#     parameter: 26
#     body: 11
# 11. {P(a_{1}) and ..P(a_{k}).. and P(a_{n}) if forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x).
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. P(a_{1}) and ..P(a_{k}).. and P(a_{n})
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)
#     core type: Operation
#     operator: 16
#     operand: 19
# 14. and
#     core type: Literal
#     sub-expressions:
# 15. (P(a_{1}), ..P(a_{k}).., P(a_{n}))
#     core type: ExprTuple
#     sub-expressions: 18
# 16. forall
#     core type: Literal
#     sub-expressions:
# 17. (x -> {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}}.)
#     core type: ExprTuple
#     sub-expressions: 19
# 18. P(a_{1}), ..P(a_{k}).., P(a_{n})
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 39
#     end_index: 40
# 19. x -> {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}}.
#     core type: Lambda
#     parameter: 31
#     body: 21
# 20. k -> P(a_{k})
#     core type: Lambda
#     parameter: 36
#     body: 22
# 21. {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}}.
#     core type: Conditional
#     value: 23
#     condition: 24
# 22. P(a_{k})
#     core type: Operation
#     operator: 26
#     operand: 30
# 23. P(x)
#     core type: Operation
#     operator: 26
#     operand: 31
# 24. x in {a_{1}, ..a_{_a}.., a_{n}}
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. (a_{k})
#     core type: ExprTuple
#     sub-expressions: 30
# 26. P
#     core type: Variable
#     sub-expressions:
# 27. (x)
#     core type: ExprTuple
#     sub-expressions: 31
# 28. in
#     core type: Literal
#     sub-expressions:
# 29. (x, {a_{1}, ..a_{_a}.., a_{n}})
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 30. a_{k}
#     core type: IndexedVar
# variable: 42
# index: 36
# 31. x
#     core type: Variable
#     sub-expressions:
# 32. {a_{1}, ..a_{_a}.., a_{n}}
#     core type: Operation
#     operator: 34
#     operands: 35
# 33. (k)
#     core type: ExprTuple
#     sub-expressions: 36
# 34. Set
#     core type: Literal
#     sub-expressions:
# 35. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 37
# 36. k
#     core type: Variable
#     sub-expressions:
# 37. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 39
#     end_index: 40
# 38. _a -> a_{_a}
#     core type: Lambda
#     parameter: 44
#     body: 41
# 39. 1
#     core type: Literal
#     sub-expressions:
# 40. n
#     core type: Variable
#     sub-expressions:
# 41. a_{_a}
#     core type: IndexedVar
# variable: 42
# index: 44
# 42. a
#     core type: Variable
#     sub-expressions:
# 43. (_a)
#     core type: ExprTuple
#     sub-expressions: 44
# 44. _a
#     core type: Variable
#     sub-expressions:
