# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, Function, IndexedVar, P, Px, a, k, n, x
from proveit.core_expr_types import a_1_to_n
from proveit.logic import Equals, FALSE, Forall, Or, Set
from proveit.numbers import Natural, one

# %%
# build up the expression from sub-expressions
expr = Forall([n], Forall([a_1_to_n], Forall([P], Equals(Or(ExprRange(k, Equals(Function(P, [IndexedVar(a, k)]), FALSE), one, n)), Equals(Forall([x], Px, domains = [Set(a_1_to_n)]), FALSE)))), domains = [Natural])
# Out:
# expr: forall_{n in Natural} [forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P} (((P(a_{1}) = FALSE) or ..(P(a_{k}) = FALSE).. or (P(a_{n}) = FALSE)) = ([forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)] = FALSE))]]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{n \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{n}}~\left[\forall_{P}~\left(\left(\left(P(a_{1}) = \bot\right) \lor \ldots \lor \left(P(a_{n}) = \bot\right)\right) = \left(\left[\forall_{x \in \left\{a_{1}, \ldots, a_{n}\right\}}~P(x)\right] = \bot\right)\right)\right]\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{n in Natural} [forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P} (((P(a_{1}) = FALSE) or ..(P(a_{k}) = FALSE).. or (P(a_{n}) = FALSE)) = ([forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)] = FALSE))]]
#    core type: Operation
#    operator: 23
#    operand: 2
# 1. (n -> {forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P} (((P(a_{1}) = FALSE) or ..(P(a_{k}) = FALSE).. or (P(a_{n}) = FALSE)) = ([forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)] = FALSE))] if n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P} (((P(a_{1}) = FALSE) or ..(P(a_{k}) = FALSE).. or (P(a_{n}) = FALSE)) = ([forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)] = FALSE))] if n in Natural.
#    core type: Lambda
#    parameter: 49
#    body: 3
# 3. {forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P} (((P(a_{1}) = FALSE) or ..(P(a_{k}) = FALSE).. or (P(a_{n}) = FALSE)) = ([forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)] = FALSE))] if n in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P} (((P(a_{1}) = FALSE) or ..(P(a_{k}) = FALSE).. or (P(a_{n}) = FALSE)) = ([forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)] = FALSE))]
#    core type: Operation
#    operator: 23
#    operand: 8
# 5. n in Natural
#    core type: Operation
#    operator: 37
#    operands: 7
# 6. ((a_{1}, ..a_{_a}.., a_{n}) -> [forall_{P} (((P(a_{1}) = FALSE) or ..(P(a_{k}) = FALSE).. or (P(a_{n}) = FALSE)) = ([forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)] = FALSE))])
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (n, Natural)
#    core type: ExprTuple
#    sub-expressions: 49, 9
# 8. (a_{1}, ..a_{_a}.., a_{n}) -> [forall_{P} (((P(a_{1}) = FALSE) or ..(P(a_{k}) = FALSE).. or (P(a_{n}) = FALSE)) = ([forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)] = FALSE))]
#    core type: Lambda
#    parameters: 44\n   body: 10
# 9. Natural
#    core type: Literal
#    sub-expressions:
# 10. forall_{P} (((P(a_{1}) = FALSE) or ..(P(a_{k}) = FALSE).. or (P(a_{n}) = FALSE)) = ([forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)] = FALSE))
#     core type: Operation
#     operator: 23
#     operand: 12
# 11. (P -> (((P(a_{1}) = FALSE) or ..(P(a_{k}) = FALSE).. or (P(a_{n}) = FALSE)) = ([forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)] = FALSE)))
#     core type: ExprTuple
#     sub-expressions: 12
# 12. P -> (((P(a_{1}) = FALSE) or ..(P(a_{k}) = FALSE).. or (P(a_{n}) = FALSE)) = ([forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)] = FALSE))
#     core type: Lambda
#     parameter: 35
#     body: 13
# 13. ((P(a_{1}) = FALSE) or ..(P(a_{k}) = FALSE).. or (P(a_{n}) = FALSE)) = ([forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)] = FALSE)
#     core type: Operation
#     operator: 27
#     operands: 14
# 14. ((P(a_{1}) = FALSE) or ..(P(a_{k}) = FALSE).. or (P(a_{n}) = FALSE), [forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)] = FALSE)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. (P(a_{1}) = FALSE) or ..(P(a_{k}) = FALSE).. or (P(a_{n}) = FALSE)
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. [forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)] = FALSE
#     core type: Operation
#     operator: 27
#     operands: 19
# 17. or
#     core type: Literal
#     sub-expressions:
# 18. (P(a_{1}) = FALSE, ..P(a_{k}) = FALSE.., P(a_{n}) = FALSE)
#     core type: ExprTuple
#     sub-expressions: 20
# 19. (forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x), FALSE)
#     core type: ExprTuple
#     sub-expressions: 21, 31
# 20. (P(a_{1}) = FALSE), ..(P(a_{k}) = FALSE).., (P(a_{n}) = FALSE)
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 48
#     end_index: 49
# 21. forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)
#     core type: Operation
#     operator: 23
#     operand: 26
# 22. k -> (P(a_{k}) = FALSE)
#     core type: Lambda
#     parameter: 45
#     body: 25
# 23. forall
#     core type: Literal
#     sub-expressions:
# 24. (x -> {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}}.)
#     core type: ExprTuple
#     sub-expressions: 26
# 25. P(a_{k}) = FALSE
#     core type: Operation
#     operator: 27
#     operands: 28
# 26. x -> {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}}.
#     core type: Lambda
#     parameter: 40
#     body: 29
# 27. =
#     core type: Literal
#     sub-expressions:
# 28. (P(a_{k}), FALSE)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 29. {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}}.
#     core type: Conditional
#     value: 32
#     condition: 33
# 30. P(a_{k})
#     core type: Operation
#     operator: 35
#     operand: 39
# 31. FALSE
#     core type: Literal
#     sub-expressions:
# 32. P(x)
#     core type: Operation
#     operator: 35
#     operand: 40
# 33. x in {a_{1}, ..a_{_a}.., a_{n}}
#     core type: Operation
#     operator: 37
#     operands: 38
# 34. (a_{k})
#     core type: ExprTuple
#     sub-expressions: 39
# 35. P
#     core type: Variable
#     sub-expressions:
# 36. (x)
#     core type: ExprTuple
#     sub-expressions: 40
# 37. in
#     core type: Literal
#     sub-expressions:
# 38. (x, {a_{1}, ..a_{_a}.., a_{n}})
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 39. a_{k}
#     core type: IndexedVar
# variable: 51
# index: 45
# 40. x
#     core type: Variable
#     sub-expressions:
# 41. {a_{1}, ..a_{_a}.., a_{n}}
#     core type: Operation
#     operator: 43
#     operands: 44
# 42. (k)
#     core type: ExprTuple
#     sub-expressions: 45
# 43. Set
#     core type: Literal
#     sub-expressions:
# 44. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 46
# 45. k
#     core type: Variable
#     sub-expressions:
# 46. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 48
#     end_index: 49
# 47. _a -> a_{_a}
#     core type: Lambda
#     parameter: 53
#     body: 50
# 48. 1
#     core type: Literal
#     sub-expressions:
# 49. n
#     core type: Variable
#     sub-expressions:
# 50. a_{_a}
#     core type: IndexedVar
# variable: 51
# index: 53
# 51. a
#     core type: Variable
#     sub-expressions:
# 52. (_a)
#     core type: ExprTuple
#     sub-expressions: 53
# 53. _a
#     core type: Variable
#     sub-expressions:
