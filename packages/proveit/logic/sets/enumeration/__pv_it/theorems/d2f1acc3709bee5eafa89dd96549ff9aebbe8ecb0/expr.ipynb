# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Px, x
from proveit.core_expr_types import Pk_a1_to_an, a_1_to_n
from proveit.logic import And, Forall, Set

# %%
# build up the expression from sub-expressions
expr = Conditional(And(Pk_a1_to_an), Forall([x], Px, domains = [Set(a_1_to_n)]))
# Out:
# expr: {P(a_{1}) and ..P(a_{k}).. and P(a_{n}) if forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{P(a_{1}) \land \ldots \land P(a_{n}) \textrm{ if } \forall_{x \in \left\{a_{1}, \ldots, a_{n}\right\}}~P(x)\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {P(a_{1}) and ..P(a_{k}).. and P(a_{n}) if forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. P(a_{1}) and ..P(a_{k}).. and P(a_{n})
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)
#    core type: Operation
#    operator: 5
#    operand: 8
# 3. and
#    core type: Literal
#    sub-expressions:
# 4. (P(a_{1}), ..P(a_{k}).., P(a_{n}))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (x -> {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. P(a_{1}), ..P(a_{k}).., P(a_{n})
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 28
#    end_index: 29
# 8. x -> {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}}.
#    core type: Lambda
#    parameter: 20
#    body: 10
# 9. k -> P(a_{k})
#    core type: Lambda
#    parameter: 25
#    body: 11
# 10. {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}}.
#     core type: Conditional
#     value: 12
#     condition: 13
# 11. P(a_{k})
#     core type: Operation
#     operator: 15
#     operand: 19
# 12. P(x)
#     core type: Operation
#     operator: 15
#     operand: 20
# 13. x in {a_{1}, ..a_{_a}.., a_{n}}
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. (a_{k})
#     core type: ExprTuple
#     sub-expressions: 19
# 15. P
#     core type: Variable
#     sub-expressions:
# 16. (x)
#     core type: ExprTuple
#     sub-expressions: 20
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (x, {a_{1}, ..a_{_a}.., a_{n}})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. a_{k}
#     core type: IndexedVar
# variable: 31
# index: 25
# 20. x
#     core type: Variable
#     sub-expressions:
# 21. {a_{1}, ..a_{_a}.., a_{n}}
#     core type: Operation
#     operator: 23
#     operands: 24
# 22. (k)
#     core type: ExprTuple
#     sub-expressions: 25
# 23. Set
#     core type: Literal
#     sub-expressions:
# 24. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 26
# 25. k
#     core type: Variable
#     sub-expressions:
# 26. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 28
#     end_index: 29
# 27. _a -> a_{_a}
#     core type: Lambda
#     parameter: 33
#     body: 30
# 28. 1
#     core type: Literal
#     sub-expressions:
# 29. n
#     core type: Variable
#     sub-expressions:
# 30. a_{_a}
#     core type: IndexedVar
# variable: 31
# index: 33
# 31. a
#     core type: Variable
#     sub-expressions:
# 32. (_a)
#     core type: ExprTuple
#     sub-expressions: 33
# 33. _a
#     core type: Variable
#     sub-expressions:
