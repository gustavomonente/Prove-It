# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, x, y
from proveit.logic import Equals, InSet, Set

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([x, y], Conditional(InSet(x, Set(y)), Equals(x, y))))
# Out:
# expr: ((x, y) -> {x in {y} if x = y.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(x, y\right) \mapsto \left\{x \in \left\{y\right\} \textrm{ if } x = y\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((x, y) -> {x in {y} if x = y.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (x, y) -> {x in {y} if x = y.
#    core type: Lambda
#    parameters: 8\n   body: 2
# 2. {x in {y} if x = y.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. x in {y}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. x = y
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (x, {y})
#    core type: ExprTuple
#    sub-expressions: 10, 9
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (x, y)
#    core type: ExprTuple
#    sub-expressions: 10, 13
# 9. {y}
#    core type: Operation
#    operator: 11
#    operand: 13
# 10. x
#     core type: Variable
#     sub-expressions:
# 11. Set
#     core type: Literal
#     sub-expressions:
# 12. (y)
#     core type: ExprTuple
#     sub-expressions: 13
# 13. y
#     core type: Variable
#     sub-expressions:
