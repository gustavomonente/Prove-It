# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, n, x
from proveit.core_expr_types import y_1_to_n
from proveit.logic import Forall, InSet, NotInSet, Set
from proveit.logic.sets import x_notequals_all_y
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Forall([x, y_1_to_n], NotInSet(x, Set(y_1_to_n)), condition = x_notequals_all_y), InSet(n, Natural)))
# Out:
# expr: n -> {forall_{x, y_{1}, ..y_{_a}.., y_{n} | (x != y_{1}) and ..(x != y_{i}).. and (x != y_{n})} (x not-in {y_{1}, ..y_{_a}.., y_{n}}) if n in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\forall_{x, y_{1}, \ldots, y_{n}~|~\left(x \neq y_{1}\right) \land \ldots \land \left(x \neq y_{n}\right)}~\left(x \notin \left\{y_{1}, \ldots, y_{n}\right\}\right) \textrm{ if } n \in \mathbb{N}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. n -> {forall_{x, y_{1}, ..y_{_a}.., y_{n} | (x != y_{1}) and ..(x != y_{i}).. and (x != y_{n})} (x not-in {y_{1}, ..y_{_a}.., y_{n}}) if n in Natural.
#    core type: Lambda
#    parameter: 27
#    body: 1
# 1. {forall_{x, y_{1}, ..y_{_a}.., y_{n} | (x != y_{1}) and ..(x != y_{i}).. and (x != y_{n})} (x not-in {y_{1}, ..y_{_a}.., y_{n}}) if n in Natural.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{x, y_{1}, ..y_{_a}.., y_{n} | (x != y_{1}) and ..(x != y_{i}).. and (x != y_{n})} (x not-in {y_{1}, ..y_{_a}.., y_{n}})
#    core type: Operation
#    operator: 4
#    operand: 8
# 3. n in Natural
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. ((x, y_{1}, ..y_{_a}.., y_{n}) -> {x not-in {y_{1}, ..y_{_a}.., y_{n}} if (x != y_{1}) and ..(x != y_{i}).. and (x != y_{n}).)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (n, Natural)
#    core type: ExprTuple
#    sub-expressions: 27, 9
# 8. (x, y_{1}, ..y_{_a}.., y_{n}) -> {x not-in {y_{1}, ..y_{_a}.., y_{n}} if (x != y_{1}) and ..(x != y_{i}).. and (x != y_{n}).
#    core type: Lambda
#    parameters: 10\n   body: 11
# 9. Natural
#    core type: Literal
#    sub-expressions:
# 10. (x, y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 31, 23
# 11. {x not-in {y_{1}, ..y_{_a}.., y_{n}} if (x != y_{1}) and ..(x != y_{i}).. and (x != y_{n}).
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. x not-in {y_{1}, ..y_{_a}.., y_{n}}
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (x != y_{1}) and ..(x != y_{i}).. and (x != y_{n})
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. not-in
#     core type: Literal
#     sub-expressions:
# 15. (x, {y_{1}, ..y_{_a}.., y_{n}})
#     core type: ExprTuple
#     sub-expressions: 31, 18
# 16. and
#     core type: Literal
#     sub-expressions:
# 17. (x != y_{1}, ..x != y_{i}.., x != y_{n})
#     core type: ExprTuple
#     sub-expressions: 19
# 18. {y_{1}, ..y_{_a}.., y_{n}}
#     core type: Operation
#     operator: 20
#     operands: 21
# 19. (x != y_{1}), ..(x != y_{i}).., (x != y_{n})
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 26
#     end_index: 27
# 20. Set
#     core type: Literal
#     sub-expressions:
# 21. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 23
# 22. i -> (x != y_{i})
#     core type: Lambda
#     parameter: 37
#     body: 24
# 23. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 26
#     end_index: 27
# 24. x != y_{i}
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. _a -> y_{_a}
#     core type: Lambda
#     parameter: 36
#     body: 30
# 26. 1
#     core type: Literal
#     sub-expressions:
# 27. n
#     core type: Variable
#     sub-expressions:
# 28. !=
#     core type: Literal
#     sub-expressions:
# 29. (x, y_{i})
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 30. y_{_a}
#     core type: IndexedVar
# variable: 34
# index: 36
# 31. x
#     core type: Variable
#     sub-expressions:
# 32. y_{i}
#     core type: IndexedVar
# variable: 34
# index: 37
# 33. (_a)
#     core type: ExprTuple
#     sub-expressions: 36
# 34. y
#     core type: Variable
#     sub-expressions:
# 35. (i)
#     core type: ExprTuple
#     sub-expressions: 37
# 36. _a
#     core type: Variable
#     sub-expressions:
# 37. i
#     core type: Variable
#     sub-expressions:
