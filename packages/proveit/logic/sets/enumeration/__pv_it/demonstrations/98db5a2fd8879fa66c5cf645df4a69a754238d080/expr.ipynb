# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, k
from proveit.core_expr_types import Len
from proveit.numbers import five, four, one, seven, six, three, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([two, three, four, five, six, seven]), Len([ExprRange(k, k, one, six)]))
# Out:
# expr: (|(2, 3, 4, 5, 6, 7)|, |(1, ..k.., 6)|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(2, 3, 4, 5, 6, 7\right)|, |\left(1, \ldots, 6\right)|\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|(2, 3, 4, 5, 6, 7)|, |(1, ..k.., 6)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(2, 3, 4, 5, 6, 7)|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..k.., 6)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((2, 3, 4, 5, 6, 7))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..k.., 6))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (2, 3, 4, 5, 6, 7)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11, 16, 12
# 7. (1, ..k.., 6)
#    core type: ExprTuple
#    sub-expressions: 13
# 8. 2
#    core type: Literal
#    sub-expressions:
# 9. 3
#    core type: Literal
#    sub-expressions:
# 10. 4
#     core type: Literal
#     sub-expressions:
# 11. 5
#     core type: Literal
#     sub-expressions:
# 12. 7
#     core type: Literal
#     sub-expressions:
# 13. 1, ..k.., 6
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 15
#     end_index: 16
# 14. k -> k
#     core type: Lambda
#     parameter: 17
#     body: 17
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. 6
#     core type: Literal
#     sub-expressions:
# 17. k
#     core type: Variable
#     sub-expressions:
