# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b
from proveit.logic import Set

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(a)
sub_expr2 = Set(b)
expr = ExprTuple(Set(sub_expr1, sub_expr2), Set(Set(), sub_expr1, sub_expr2, Set(a, b)))
# Out:
# expr: ({{a}, {b}}, {{}, {a}, {b}, {a, b}})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left\{\left\{a\right\}, \left\{b\right\}\right\}, \left\{\left\{\right\}, \left\{a\right\}, \left\{b\right\}, \left\{a, b\right\}\right\}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ({{a}, {b}}, {{}, {a}, {b}, {a, b}})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. {{a}, {b}}
#    core type: Operation
#    operator: 12
#    operands: 3
# 2. {{}, {a}, {b}, {a, b}}
#    core type: Operation
#    operator: 12
#    operands: 4
# 3. ({a}, {b})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. ({}, {a}, {b}, {a, b})
#    core type: ExprTuple
#    sub-expressions: 5, 6, 7, 8
# 5. {}
#    core type: Operation
#    operator: 12
#    operands: 9
# 6. {a}
#    core type: Operation
#    operator: 12
#    operand: 14
# 7. {b}
#    core type: Operation
#    operator: 12
#    operand: 15
# 8. {a, b}
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. ()
#    core type: ExprTuple
#    sub-expressions:
# 10. (a)
#     core type: ExprTuple
#     sub-expressions: 14
# 11. (b)
#     core type: ExprTuple
#     sub-expressions: 15
# 12. Set
#     core type: Literal
#     sub-expressions:
# 13. (a, b)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. b
#     core type: Variable
#     sub-expressions:
