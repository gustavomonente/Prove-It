# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.equivalence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, Lambda, x
from proveit.logic import Equals, Forall, InSet, SetEquiv

# %%
# build up the expression from sub-expressions
expr = Lambda([A, B], Conditional(Forall([x], Equals(InSet(x, A), InSet(x, B))), SetEquiv(A, B)))
# Out:
# expr: (A, B) -> {forall_{x} ((x in A) = (x in B)) if A equiv B.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A, B\right) \mapsto \left\{\forall_{x}~\left(\left(x \in A\right) = \left(x \in B\right)\right) \textrm{ if } A \cong B\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A, B) -> {forall_{x} ((x in A) = (x in B)) if A equiv B.
#    core type: Lambda
#    parameters: 7\n   body: 1
# 1. {forall_{x} ((x in A) = (x in B)) if A equiv B.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{x} ((x in A) = (x in B))
#    core type: Operation
#    operator: 4
#    operand: 8
# 3. A equiv B
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (x -> ((x in A) = (x in B)))
#    core type: ExprTuple
#    sub-expressions: 8
# 6. equiv
#    core type: Literal
#    sub-expressions:
# 7. (A, B)
#    core type: ExprTuple
#    sub-expressions: 17, 19
# 8. x -> ((x in A) = (x in B))
#    core type: Lambda
#    parameter: 18
#    body: 9
# 9. (x in A) = (x in B)
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. (x in A, x in B)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. x in A
#     core type: Operation
#     operator: 15
#     operands: 14
# 13. x in B
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (x, A)
#     core type: ExprTuple
#     sub-expressions: 18, 17
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (x, B)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. A
#     core type: Variable
#     sub-expressions:
# 18. x
#     core type: Variable
#     sub-expressions:
# 19. B
#     core type: Variable
#     sub-expressions:
