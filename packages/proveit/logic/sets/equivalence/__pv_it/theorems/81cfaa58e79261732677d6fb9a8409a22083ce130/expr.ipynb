# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.equivalence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, Lambda
from proveit.logic import Not, SetEquiv, SetNotEquiv

# %%
# build up the expression from sub-expressions
expr = Lambda([A, B], Conditional(SetNotEquiv(A, B), Not(SetEquiv(A, B))))
# Out:
# expr: (A, B) -> {A not_equiv B if not(A equiv B).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A, B\right) \mapsto \left\{A \ncong B \textrm{ if } \lnot \left(A \cong B\right)\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A, B) -> {A not_equiv B if not(A equiv B).
#    core type: Lambda
#    parameters: 9\n   body: 1
# 1. {A not_equiv B if not(A equiv B).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. A not_equiv B
#    core type: Operation
#    operator: 4
#    operands: 9
# 3. not(A equiv B)
#    core type: Operation
#    operator: 5
#    operand: 7
# 4. not_equiv
#    core type: Literal
#    sub-expressions:
# 5. not
#    core type: Literal
#    sub-expressions:
# 6. (A equiv B)
#    core type: ExprTuple
#    sub-expressions: 7
# 7. A equiv B
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. equiv
#    core type: Literal
#    sub-expressions:
# 9. (A, B)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. A
#     core type: Variable
#     sub-expressions:
# 11. B
#     core type: Variable
#     sub-expressions:
