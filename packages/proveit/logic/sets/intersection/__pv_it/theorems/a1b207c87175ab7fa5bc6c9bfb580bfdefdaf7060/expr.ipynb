# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.intersection</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, x
from proveit.core_expr_types import A_1_to_m
from proveit.logic import Intersect, NotInSet
from proveit.logic.sets import x_notin_some_A

# %%
# build up the expression from sub-expressions
expr = ExprTuple(NotInSet(x, Intersect(A_1_to_m)), x_notin_some_A)
# Out:
# expr: (x not-in (A_{1} intersect ..A_{_a}.. intersect A_{m}), (x not-in A_{1}) or ..(x not-in A_{i}).. or (x not-in A_{m}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \notin \left(A_{1} \cap \ldots \cap A_{m}\right), \left(x \notin A_{1}\right) \lor \ldots \lor \left(x \notin A_{m}\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x not-in (A_{1} intersect ..A_{_a}.. intersect A_{m}), (x not-in A_{1}) or ..(x not-in A_{i}).. or (x not-in A_{m}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. x not-in (A_{1} intersect ..A_{_a}.. intersect A_{m})
#    core type: Operation
#    operator: 16
#    operands: 3
# 2. (x not-in A_{1}) or ..(x not-in A_{i}).. or (x not-in A_{m})
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (x, A_{1} intersect ..A_{_a}.. intersect A_{m})
#    core type: ExprTuple
#    sub-expressions: 19, 6
# 4. or
#    core type: Literal
#    sub-expressions:
# 5. (x not-in A_{1}, ..x not-in A_{i}.., x not-in A_{m})
#    core type: ExprTuple
#    sub-expressions: 7
# 6. A_{1} intersect ..A_{_a}.. intersect A_{m}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (x not-in A_{1}), ..(x not-in A_{i}).., (x not-in A_{m})
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 14
#    end_index: 15
# 8. intersect
#    core type: Literal
#    sub-expressions:
# 9. (A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 11
# 10. i -> (x not-in A_{i})
#     core type: Lambda
#     parameter: 25
#     body: 12
# 11. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 14
#     end_index: 15
# 12. x not-in A_{i}
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. _a -> A_{_a}
#     core type: Lambda
#     parameter: 24
#     body: 18
# 14. 1
#     core type: Literal
#     sub-expressions:
# 15. m
#     core type: Variable
#     sub-expressions:
# 16. not-in
#     core type: Literal
#     sub-expressions:
# 17. (x, A_{i})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. A_{_a}
#     core type: IndexedVar
# variable: 22
# index: 24
# 19. x
#     core type: Variable
#     sub-expressions:
# 20. A_{i}
#     core type: IndexedVar
# variable: 22
# index: 25
# 21. (_a)
#     core type: ExprTuple
#     sub-expressions: 24
# 22. A
#     core type: Variable
#     sub-expressions:
# 23. (i)
#     core type: ExprTuple
#     sub-expressions: 25
# 24. _a
#     core type: Variable
#     sub-expressions:
# 25. i
#     core type: Variable
#     sub-expressions:
