# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.intersection</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, m, x
from proveit.core_expr_types import A_1_to_m
from proveit.logic import Forall, InSet, Intersect, NotInSet
from proveit.logic.sets import x_notin_some_A
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([x, A_1_to_m], NotInSet(x, Intersect(A_1_to_m)), condition = x_notin_some_A), InSet(m, NaturalPos))
# Out:
# expr: {forall_{x, A_{1}, ..A_{_a}.., A_{m} | (x not-in A_{1}) or ..(x not-in A_{i}).. or (x not-in A_{m})} (x not-in (A_{1} intersect ..A_{_a}.. intersect A_{m})) if m in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{x, A_{1}, \ldots, A_{m}~|~\left(x \notin A_{1}\right) \lor \ldots \lor \left(x \notin A_{m}\right)}~\left(x \notin \left(A_{1} \cap \ldots \cap A_{m}\right)\right) \textrm{ if } m \in \mathbb{N}^+\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{x, A_{1}, ..A_{_a}.., A_{m} | (x not-in A_{1}) or ..(x not-in A_{i}).. or (x not-in A_{m})} (x not-in (A_{1} intersect ..A_{_a}.. intersect A_{m})) if m in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{x, A_{1}, ..A_{_a}.., A_{m} | (x not-in A_{1}) or ..(x not-in A_{i}).. or (x not-in A_{m})} (x not-in (A_{1} intersect ..A_{_a}.. intersect A_{m}))
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. m in NaturalPos
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((x, A_{1}, ..A_{_a}.., A_{m}) -> {x not-in (A_{1} intersect ..A_{_a}.. intersect A_{m}) if (x not-in A_{1}) or ..(x not-in A_{i}).. or (x not-in A_{m}).)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (m, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 25, 8
# 7. (x, A_{1}, ..A_{_a}.., A_{m}) -> {x not-in (A_{1} intersect ..A_{_a}.. intersect A_{m}) if (x not-in A_{1}) or ..(x not-in A_{i}).. or (x not-in A_{m}).
#    core type: Lambda
#    parameters: 9\n   body: 10
# 8. NaturalPos
#    core type: Literal
#    sub-expressions:
# 9. (x, A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 29, 21
# 10. {x not-in (A_{1} intersect ..A_{_a}.. intersect A_{m}) if (x not-in A_{1}) or ..(x not-in A_{i}).. or (x not-in A_{m}).
#     core type: Conditional
#     value: 11
#     condition: 12
# 11. x not-in (A_{1} intersect ..A_{_a}.. intersect A_{m})
#     core type: Operation
#     operator: 26
#     operands: 13
# 12. (x not-in A_{1}) or ..(x not-in A_{i}).. or (x not-in A_{m})
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (x, A_{1} intersect ..A_{_a}.. intersect A_{m})
#     core type: ExprTuple
#     sub-expressions: 29, 16
# 14. or
#     core type: Literal
#     sub-expressions:
# 15. (x not-in A_{1}, ..x not-in A_{i}.., x not-in A_{m})
#     core type: ExprTuple
#     sub-expressions: 17
# 16. A_{1} intersect ..A_{_a}.. intersect A_{m}
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. (x not-in A_{1}), ..(x not-in A_{i}).., (x not-in A_{m})
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 24
#     end_index: 25
# 18. intersect
#     core type: Literal
#     sub-expressions:
# 19. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 21
# 20. i -> (x not-in A_{i})
#     core type: Lambda
#     parameter: 35
#     body: 22
# 21. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 24
#     end_index: 25
# 22. x not-in A_{i}
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. _a -> A_{_a}
#     core type: Lambda
#     parameter: 34
#     body: 28
# 24. 1
#     core type: Literal
#     sub-expressions:
# 25. m
#     core type: Variable
#     sub-expressions:
# 26. not-in
#     core type: Literal
#     sub-expressions:
# 27. (x, A_{i})
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 28. A_{_a}
#     core type: IndexedVar
# variable: 32
# index: 34
# 29. x
#     core type: Variable
#     sub-expressions:
# 30. A_{i}
#     core type: IndexedVar
# variable: 32
# index: 35
# 31. (_a)
#     core type: ExprTuple
#     sub-expressions: 34
# 32. A
#     core type: Variable
#     sub-expressions:
# 33. (i)
#     core type: ExprTuple
#     sub-expressions: 35
# 34. _a
#     core type: Variable
#     sub-expressions:
# 35. i
#     core type: Variable
#     sub-expressions:
