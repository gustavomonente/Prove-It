# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.intersection</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, x
from proveit.core_expr_types import A_1_to_m
from proveit.logic import InSet, Intersect
from proveit.logic.sets import x_in_every_A

# %%
# build up the expression from sub-expressions
expr = Conditional(x_in_every_A, InSet(x, Intersect(A_1_to_m)))
# Out:
# expr: {(x in A_{1}) and ..(x in A_{i}).. and (x in A_{m}) if x in (A_{1} intersect ..A_{_a}.. intersect A_{m}).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(x \in A_{1}\right) \land \ldots \land \left(x \in A_{m}\right) \textrm{ if } x \in \left(A_{1} \cap \ldots \cap A_{m}\right)\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(x in A_{1}) and ..(x in A_{i}).. and (x in A_{m}) if x in (A_{1} intersect ..A_{_a}.. intersect A_{m}).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (x in A_{1}) and ..(x in A_{i}).. and (x in A_{m})
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. x in (A_{1} intersect ..A_{_a}.. intersect A_{m})
#    core type: Operation
#    operator: 13
#    operands: 5
# 3. and
#    core type: Literal
#    sub-expressions:
# 4. (x in A_{1}, ..x in A_{i}.., x in A_{m})
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (x, A_{1} intersect ..A_{_a}.. intersect A_{m})
#    core type: ExprTuple
#    sub-expressions: 18, 7
# 6. (x in A_{1}), ..(x in A_{i}).., (x in A_{m})
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 16
#    end_index: 17
# 7. A_{1} intersect ..A_{_a}.. intersect A_{m}
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. i -> (x in A_{i})
#    core type: Lambda
#    parameter: 24
#    body: 11
# 9. intersect
#    core type: Literal
#    sub-expressions:
# 10. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 12
# 11. x in A_{i}
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 16
#     end_index: 17
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (x, A_{i})
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. _a -> A_{_a}
#     core type: Lambda
#     parameter: 25
#     body: 20
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. m
#     core type: Variable
#     sub-expressions:
# 18. x
#     core type: Variable
#     sub-expressions:
# 19. A_{i}
#     core type: IndexedVar
# variable: 22
# index: 24
# 20. A_{_a}
#     core type: IndexedVar
# variable: 22
# index: 25
# 21. (i)
#     core type: ExprTuple
#     sub-expressions: 24
# 22. A
#     core type: Variable
#     sub-expressions:
# 23. (_a)
#     core type: ExprTuple
#     sub-expressions: 25
# 24. i
#     core type: Variable
#     sub-expressions:
# 25. _a
#     core type: Variable
#     sub-expressions:
