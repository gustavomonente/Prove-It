# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.intersection</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import x
from proveit.core_expr_types import A_1_to_m
from proveit.logic import Forall, Intersect, NotInSet
from proveit.logic.sets import x_notin_some_A

# %%
# build up the expression from sub-expressions
expr = Forall([x, A_1_to_m], NotInSet(x, Intersect(A_1_to_m)), condition = x_notin_some_A)
# Out:
# expr: forall_{x, A_{1}, ..A_{_a}.., A_{m} | (x not-in A_{1}) or ..(x not-in A_{i}).. or (x not-in A_{m})} (x not-in (A_{1} intersect ..A_{_a}.. intersect A_{m}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x, A_{1}, \ldots, A_{m}~|~\left(x \notin A_{1}\right) \lor \ldots \lor \left(x \notin A_{m}\right)}~\left(x \notin \left(A_{1} \cap \ldots \cap A_{m}\right)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{x, A_{1}, ..A_{_a}.., A_{m} | (x not-in A_{1}) or ..(x not-in A_{i}).. or (x not-in A_{m})} (x not-in (A_{1} intersect ..A_{_a}.. intersect A_{m}))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((x, A_{1}, ..A_{_a}.., A_{m}) -> {x not-in (A_{1} intersect ..A_{_a}.. intersect A_{m}) if (x not-in A_{1}) or ..(x not-in A_{i}).. or (x not-in A_{m}).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (x, A_{1}, ..A_{_a}.., A_{m}) -> {x not-in (A_{1} intersect ..A_{_a}.. intersect A_{m}) if (x not-in A_{1}) or ..(x not-in A_{i}).. or (x not-in A_{m}).
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (x, A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 24, 16
# 5. {x not-in (A_{1} intersect ..A_{_a}.. intersect A_{m}) if (x not-in A_{1}) or ..(x not-in A_{i}).. or (x not-in A_{m}).
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. x not-in (A_{1} intersect ..A_{_a}.. intersect A_{m})
#    core type: Operation
#    operator: 21
#    operands: 8
# 7. (x not-in A_{1}) or ..(x not-in A_{i}).. or (x not-in A_{m})
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (x, A_{1} intersect ..A_{_a}.. intersect A_{m})
#    core type: ExprTuple
#    sub-expressions: 24, 11
# 9. or
#    core type: Literal
#    sub-expressions:
# 10. (x not-in A_{1}, ..x not-in A_{i}.., x not-in A_{m})
#     core type: ExprTuple
#     sub-expressions: 12
# 11. A_{1} intersect ..A_{_a}.. intersect A_{m}
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (x not-in A_{1}), ..(x not-in A_{i}).., (x not-in A_{m})
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 19
#     end_index: 20
# 13. intersect
#     core type: Literal
#     sub-expressions:
# 14. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 16
# 15. i -> (x not-in A_{i})
#     core type: Lambda
#     parameter: 30
#     body: 17
# 16. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 19
#     end_index: 20
# 17. x not-in A_{i}
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. _a -> A_{_a}
#     core type: Lambda
#     parameter: 29
#     body: 23
# 19. 1
#     core type: Literal
#     sub-expressions:
# 20. m
#     core type: Variable
#     sub-expressions:
# 21. not-in
#     core type: Literal
#     sub-expressions:
# 22. (x, A_{i})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 23. A_{_a}
#     core type: IndexedVar
# variable: 27
# index: 29
# 24. x
#     core type: Variable
#     sub-expressions:
# 25. A_{i}
#     core type: IndexedVar
# variable: 27
# index: 30
# 26. (_a)
#     core type: ExprTuple
#     sub-expressions: 29
# 27. A
#     core type: Variable
#     sub-expressions:
# 28. (i)
#     core type: ExprTuple
#     sub-expressions: 30
# 29. _a
#     core type: Variable
#     sub-expressions:
# 30. i
#     core type: Variable
#     sub-expressions:
