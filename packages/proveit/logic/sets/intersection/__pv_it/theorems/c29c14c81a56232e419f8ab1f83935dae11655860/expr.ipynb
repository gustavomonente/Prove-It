# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.intersection</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, x
from proveit.core_expr_types import A_1_to_m
from proveit.logic import InSet, Intersect
from proveit.logic.sets import x_in_every_A

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([x, A_1_to_m], Conditional(InSet(x, Intersect(A_1_to_m)), x_in_every_A)))
# Out:
# expr: ((x, A_{1}, ..A_{_a}.., A_{m}) -> {x in (A_{1} intersect ..A_{_a}.. intersect A_{m}) if (x in A_{1}) and ..(x in A_{i}).. and (x in A_{m}).)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(x, A_{1}, \ldots, A_{m}\right) \mapsto \left\{x \in \left(A_{1} \cap \ldots \cap A_{m}\right) \textrm{ if } \left(x \in A_{1}\right) \land \ldots \land \left(x \in A_{m}\right)\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((x, A_{1}, ..A_{_a}.., A_{m}) -> {x in (A_{1} intersect ..A_{_a}.. intersect A_{m}) if (x in A_{1}) and ..(x in A_{i}).. and (x in A_{m}).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (x, A_{1}, ..A_{_a}.., A_{m}) -> {x in (A_{1} intersect ..A_{_a}.. intersect A_{m}) if (x in A_{1}) and ..(x in A_{i}).. and (x in A_{m}).
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (x, A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 22, 14
# 3. {x in (A_{1} intersect ..A_{_a}.. intersect A_{m}) if (x in A_{1}) and ..(x in A_{i}).. and (x in A_{m}).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. x in (A_{1} intersect ..A_{_a}.. intersect A_{m})
#    core type: Operation
#    operator: 19
#    operands: 6
# 5. (x in A_{1}) and ..(x in A_{i}).. and (x in A_{m})
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (x, A_{1} intersect ..A_{_a}.. intersect A_{m})
#    core type: ExprTuple
#    sub-expressions: 22, 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (x in A_{1}, ..x in A_{i}.., x in A_{m})
#    core type: ExprTuple
#    sub-expressions: 10
# 9. A_{1} intersect ..A_{_a}.. intersect A_{m}
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (x in A_{1}), ..(x in A_{i}).., (x in A_{m})
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 17
#     end_index: 18
# 11. intersect
#     core type: Literal
#     sub-expressions:
# 12. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 14
# 13. i -> (x in A_{i})
#     core type: Lambda
#     parameter: 28
#     body: 15
# 14. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 17
#     end_index: 18
# 15. x in A_{i}
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. _a -> A_{_a}
#     core type: Lambda
#     parameter: 27
#     body: 21
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. m
#     core type: Variable
#     sub-expressions:
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (x, A_{i})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 21. A_{_a}
#     core type: IndexedVar
# variable: 25
# index: 27
# 22. x
#     core type: Variable
#     sub-expressions:
# 23. A_{i}
#     core type: IndexedVar
# variable: 25
# index: 28
# 24. (_a)
#     core type: ExprTuple
#     sub-expressions: 27
# 25. A
#     core type: Variable
#     sub-expressions:
# 26. (i)
#     core type: ExprTuple
#     sub-expressions: 28
# 27. _a
#     core type: Variable
#     sub-expressions:
# 28. i
#     core type: Variable
#     sub-expressions:
