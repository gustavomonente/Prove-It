# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#intersect_all_def">intersect_all_def</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.intersection</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.intersection import intersect_all_def

# %%
# check that the built expression is the same as the stored expression
assert intersect_all_def.expr == stored_expr
assert intersect_all_def.expr._style_id == stored_expr._style_id
print("Passed sanity check: intersect_all_def matches stored_expr")
# Out:
# Passed sanity check: intersect_all_def matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(intersect_all_def.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{S_{1}, \ldots, S_{n}, Q, R, x~|~\exists_{y_{1} \in S_{1}, \ldots, y_{n} \in S_{n}}~Q(y_{1}, \ldots, y_{n})}~\left(\begin{array}{c} \begin{array}{l} \left(x \in \left[\bigcap_{y_{1} \in S_{1}, \ldots, y_{n} \in S_{n}~|~Q(y_{1}, \ldots, y_{n})}~R(y_{1}, \ldots, y_{n})\right]\right) \\  = \left[\forall_{y_{1} \in S_{1}, \ldots, y_{n} \in S_{n}~|~Q(y_{1}, \ldots, y_{n})}~\left(x \in R(y_{1}, \ldots, y_{n})\right)\right] \end{array} \end{array}\right)\right]

# %%
intersect_all_def.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
intersect_all_def.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{S_{1}, ..S_{_a}.., S_{n}, Q, R, x | exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}} Q(y_{1}, ..y_{_a}.., y_{n})} ((x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))])]
#    core type: Operation
#    operator: 24
#    operand: 2
# 1. (n -> {forall_{S_{1}, ..S_{_a}.., S_{n}, Q, R, x | exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}} Q(y_{1}, ..y_{_a}.., y_{n})} ((x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))]) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{S_{1}, ..S_{_a}.., S_{n}, Q, R, x | exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}} Q(y_{1}, ..y_{_a}.., y_{n})} ((x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))]) if n in NaturalPos.
#    core type: Lambda
#    parameter: 55
#    body: 3
# 3. {forall_{S_{1}, ..S_{_a}.., S_{n}, Q, R, x | exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}} Q(y_{1}, ..y_{_a}.., y_{n})} ((x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))]) if n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{S_{1}, ..S_{_a}.., S_{n}, Q, R, x | exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}} Q(y_{1}, ..y_{_a}.., y_{n})} ((x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))])
#    core type: Operation
#    operator: 24
#    operand: 8
# 5. n in NaturalPos
#    core type: Operation
#    operator: 51
#    operands: 7
# 6. ((S_{1}, ..S_{_a}.., S_{n}, Q, R, x) -> {(x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))] if exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}} Q(y_{1}, ..y_{_a}.., y_{n}).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 55, 9
# 8. (S_{1}, ..S_{_a}.., S_{n}, Q, R, x) -> {(x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))] if exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}} Q(y_{1}, ..y_{_a}.., y_{n}).
#    core type: Lambda
#    parameters: 10\n   body: 11
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. (S_{1}, ..S_{_a}.., S_{n}, Q, R, x)
#     core type: ExprTuple
#     sub-expressions: 12, 47, 43, 39
# 11. {(x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))] if exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}} Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 13
#     condition: 14
# 12. S_{1}, ..S_{_a}.., S_{n}
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 54
#     end_index: 55
# 13. (x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))]
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}} Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 18
#     operand: 22
# 15. _a -> S_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 56
# 16. =
#     core type: Literal
#     sub-expressions:
# 17. (x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})], forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n})))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. exists
#     core type: Literal
#     sub-expressions:
# 19. ((y_{1}, ..y_{_a}.., y_{n}) -> {Q(y_{1}, ..y_{_a}.., y_{n}) if (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n}).)
#     core type: ExprTuple
#     sub-expressions: 22
# 20. x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]
#     core type: Operation
#     operator: 51
#     operands: 23
# 21. forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))
#     core type: Operation
#     operator: 24
#     operand: 28
# 22. (y_{1}, ..y_{_a}.., y_{n}) -> {Q(y_{1}, ..y_{_a}.., y_{n}) if (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n}).
#     core type: Lambda
#     parameters: 48\n    body: 26
# 23. (x, intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 39, 27
# 24. forall
#     core type: Literal
#     sub-expressions:
# 25. ((y_{1}, ..y_{_a}.., y_{n}) -> {x in R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 28
# 26. {Q(y_{1}, ..y_{_a}.., y_{n}) if (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n}).
#     core type: Conditional
#     value: 45
#     condition: 29
# 27. intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 30
#     operand: 34
# 28. (y_{1}, ..y_{_a}.., y_{n}) -> {x in R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 48\n    body: 32
# 29. (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n})
#     core type: Operation
#     operator: 41
#     operands: 33
# 30. intersect_all
#     core type: Literal
#     sub-expressions:
# 31. ((y_{1}, ..y_{_a}.., y_{n}) -> {R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 34
# 32. {x in R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 35
#     condition: 38
# 33. (y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n})
#     core type: ExprTuple
#     sub-expressions: 44
# 34. (y_{1}, ..y_{_a}.., y_{n}) -> {R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 48\n    body: 36
# 35. x in R(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 51
#     operands: 37
# 36. {R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 40
#     condition: 38
# 37. (x, R(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 38. (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n}) and Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 41
#     operands: 42
# 39. x
#     core type: Variable
#     sub-expressions:
# 40. R(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 43
#     operands: 48
# 41. and
#     core type: Literal
#     sub-expressions:
# 42. (y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}, Q(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 43. R
#     core type: Variable
#     sub-expressions:
# 44. (y_{1} in S_{1}), ..(y_{_a} in S_{_a}).., (y_{n} in S_{n})
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 54
#     end_index: 55
# 45. Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 47
#     operands: 48
# 46. _a -> (y_{_a} in S_{_a})
#     core type: Lambda
#     parameter: 61
#     body: 49
# 47. Q
#     core type: Variable
#     sub-expressions:
# 48. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 50
# 49. y_{_a} in S_{_a}
#     core type: Operation
#     operator: 51
#     operands: 52
# 50. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 53
#     start_index: 54
#     end_index: 55
# 51. in
#     core type: Literal
#     sub-expressions:
# 52. (y_{_a}, S_{_a})
#     core type: ExprTuple
#     sub-expressions: 57, 56
# 53. _a -> y_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 57
# 54. 1
#     core type: Literal
#     sub-expressions:
# 55. n
#     core type: Variable
#     sub-expressions:
# 56. S_{_a}
#     core type: IndexedVar
# variable: 58
# index: 61
# 57. y_{_a}
#     core type: IndexedVar
# variable: 59
# index: 61
# 58. S
#     core type: Variable
#     sub-expressions:
# 59. y
#     core type: Variable
#     sub-expressions:
# 60. (_a)
#     core type: ExprTuple
#     sub-expressions: 61
# 61. _a
#     core type: Variable
#     sub-expressions:
