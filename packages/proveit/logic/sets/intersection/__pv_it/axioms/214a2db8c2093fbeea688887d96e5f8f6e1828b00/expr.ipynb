# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.intersection</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, Q, R, x
from proveit.core_expr_types import Q__y_1_to_n, R__y_1_to_n, S_1_to_n, y_1_to_n
from proveit.logic import Equals, Exists, Forall, InSet
from proveit.logic.sets import general_intersectall_Ryn

# %%
# build up the expression from sub-expressions
sub_expr1 = [y_1_to_n]
sub_expr2 = [S_1_to_n]
expr = Lambda([S_1_to_n, Q, R, x], Conditional(Equals(InSet(x, general_intersectall_Ryn), Forall(sub_expr1, InSet(x, R__y_1_to_n), domains = sub_expr2, condition = Q__y_1_to_n)).with_wrapping_at(1), Exists(sub_expr1, Q__y_1_to_n, domains = sub_expr2)))
# Out:
# expr: (S_{1}, ..S_{_a}.., S_{n}, Q, R, x) -> {(x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))] if exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}} Q(y_{1}, ..y_{_a}.., y_{n}).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(S_{1}, \ldots, S_{n}, Q, R, x\right) \mapsto \left\{\begin{array}{c} \begin{array}{l} \left(x \in \left[\bigcap_{y_{1} \in S_{1}, \ldots, y_{n} \in S_{n}~|~Q(y_{1}, \ldots, y_{n})}~R(y_{1}, \ldots, y_{n})\right]\right) \\  = \left[\forall_{y_{1} \in S_{1}, \ldots, y_{n} \in S_{n}~|~Q(y_{1}, \ldots, y_{n})}~\left(x \in R(y_{1}, \ldots, y_{n})\right)\right] \end{array} \end{array} \textrm{ if } \exists_{y_{1} \in S_{1}, \ldots, y_{n} \in S_{n}}~Q(y_{1}, \ldots, y_{n})\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (S_{1}, ..S_{_a}.., S_{n}, Q, R, x) -> {(x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))] if exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}} Q(y_{1}, ..y_{_a}.., y_{n}).
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (S_{1}, ..S_{_a}.., S_{n}, Q, R, x)
#    core type: ExprTuple
#    sub-expressions: 3, 38, 34, 30
# 2. {(x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))] if exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}} Q(y_{1}, ..y_{_a}.., y_{n}).
#    core type: Conditional
#    value: 4
#    condition: 5
# 3. S_{1}, ..S_{_a}.., S_{n}
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 45
#    end_index: 46
# 4. (x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))]
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}} Q(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 9
#    operand: 13
# 6. _a -> S_{_a}
#    core type: Lambda
#    parameter: 52
#    body: 47
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})], forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n})))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. exists
#    core type: Literal
#    sub-expressions:
# 10. ((y_{1}, ..y_{_a}.., y_{n}) -> {Q(y_{1}, ..y_{_a}.., y_{n}) if (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n}).)
#     core type: ExprTuple
#     sub-expressions: 13
# 11. x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]
#     core type: Operation
#     operator: 42
#     operands: 14
# 12. forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))
#     core type: Operation
#     operator: 15
#     operand: 19
# 13. (y_{1}, ..y_{_a}.., y_{n}) -> {Q(y_{1}, ..y_{_a}.., y_{n}) if (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n}).
#     core type: Lambda
#     parameters: 39\n    body: 17
# 14. (x, intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 30, 18
# 15. forall
#     core type: Literal
#     sub-expressions:
# 16. ((y_{1}, ..y_{_a}.., y_{n}) -> {x in R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 19
# 17. {Q(y_{1}, ..y_{_a}.., y_{n}) if (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n}).
#     core type: Conditional
#     value: 36
#     condition: 20
# 18. intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 21
#     operand: 25
# 19. (y_{1}, ..y_{_a}.., y_{n}) -> {x in R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 39\n    body: 23
# 20. (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n})
#     core type: Operation
#     operator: 32
#     operands: 24
# 21. intersect_all
#     core type: Literal
#     sub-expressions:
# 22. ((y_{1}, ..y_{_a}.., y_{n}) -> {R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 25
# 23. {x in R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 26
#     condition: 29
# 24. (y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n})
#     core type: ExprTuple
#     sub-expressions: 35
# 25. (y_{1}, ..y_{_a}.., y_{n}) -> {R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 39\n    body: 27
# 26. x in R(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 42
#     operands: 28
# 27. {R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 31
#     condition: 29
# 28. (x, R(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 29. (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n}) and Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 32
#     operands: 33
# 30. x
#     core type: Variable
#     sub-expressions:
# 31. R(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 34
#     operands: 39
# 32. and
#     core type: Literal
#     sub-expressions:
# 33. (y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}, Q(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 34. R
#     core type: Variable
#     sub-expressions:
# 35. (y_{1} in S_{1}), ..(y_{_a} in S_{_a}).., (y_{n} in S_{n})
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 45
#     end_index: 46
# 36. Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 38
#     operands: 39
# 37. _a -> (y_{_a} in S_{_a})
#     core type: Lambda
#     parameter: 52
#     body: 40
# 38. Q
#     core type: Variable
#     sub-expressions:
# 39. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 41
# 40. y_{_a} in S_{_a}
#     core type: Operation
#     operator: 42
#     operands: 43
# 41. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 45
#     end_index: 46
# 42. in
#     core type: Literal
#     sub-expressions:
# 43. (y_{_a}, S_{_a})
#     core type: ExprTuple
#     sub-expressions: 48, 47
# 44. _a -> y_{_a}
#     core type: Lambda
#     parameter: 52
#     body: 48
# 45. 1
#     core type: Literal
#     sub-expressions:
# 46. n
#     core type: Variable
#     sub-expressions:
# 47. S_{_a}
#     core type: IndexedVar
# variable: 49
# index: 52
# 48. y_{_a}
#     core type: IndexedVar
# variable: 50
# index: 52
# 49. S
#     core type: Variable
#     sub-expressions:
# 50. y
#     core type: Variable
#     sub-expressions:
# 51. (_a)
#     core type: ExprTuple
#     sub-expressions: 52
# 52. _a
#     core type: Variable
#     sub-expressions:
