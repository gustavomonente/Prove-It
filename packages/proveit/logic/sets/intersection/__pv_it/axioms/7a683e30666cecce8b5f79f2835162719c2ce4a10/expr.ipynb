# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.intersection</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, S, Variable, n, y
from proveit.logic import InSet
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(ExprRange(sub_expr1, InSet(IndexedVar(y, sub_expr1), IndexedVar(S, sub_expr1)), one, n))
# Out:
# expr: (y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(y_{1} \in S_{1}, \ldots, y_{n} \in S_{n}\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n})
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (y_{1} in S_{1}), ..(y_{_a} in S_{_a}).., (y_{n} in S_{n})
#    core type: ExprRange
#    lambda_map: 2
#    start_index: 3
#    end_index: 4
# 2. _a -> (y_{_a} in S_{_a})
#    core type: Lambda
#    parameter: 13
#    body: 5
# 3. 1
#    core type: Literal
#    sub-expressions:
# 4. n
#    core type: Variable
#    sub-expressions:
# 5. y_{_a} in S_{_a}
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (y_{_a}, S_{_a})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. y_{_a}
#    core type: IndexedVar
# variable: 10
# index: 13
# 9. S_{_a}
#    core type: IndexedVar
# variable: 11
# index: 13
# 10. y
#     core type: Variable
#     sub-expressions:
# 11. S
#     core type: Variable
#     sub-expressions:
# 12. (_a)
#     core type: ExprTuple
#     sub-expressions: 13
# 13. _a
#     core type: Variable
#     sub-expressions:
