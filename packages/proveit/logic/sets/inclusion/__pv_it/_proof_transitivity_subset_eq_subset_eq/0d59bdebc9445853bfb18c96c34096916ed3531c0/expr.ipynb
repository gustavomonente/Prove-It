# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B, C, Conditional, ExprTuple, Lambda, x
from proveit.logic import InSet

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(x, Conditional(InSet(x, C), InSet(x, B))))
# Out:
# expr: (x -> {x in C if x in B.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \mapsto \left\{x \in C \textrm{ if } x \in B\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x -> {x in C if x in B.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. x -> {x in C if x in B.
#    core type: Lambda
#    parameter: 9
#    body: 2
# 2. {x in C if x in B.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. x in C
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. x in B
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (x, C)
#    core type: ExprTuple
#    sub-expressions: 9, 8
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (x, B)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. C
#    core type: Variable
#    sub-expressions:
# 9. x
#    core type: Variable
#    sub-expressions:
# 10. B
#     core type: Variable
#     sub-expressions:
