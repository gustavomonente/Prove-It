# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, ExprTuple, Lambda
from proveit.logic import SetEquiv, SubsetEq

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([A, B], Conditional(SubsetEq(A, B), SetEquiv(A, B))))
# Out:
# expr: ((A, B) -> {A subset_eq B if A equiv B.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(A, B\right) \mapsto \left\{A \subseteq B \textrm{ if } A \cong B\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((A, B) -> {A subset_eq B if A equiv B.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (A, B) -> {A subset_eq B if A equiv B.
#    core type: Lambda
#    parameters: 7\n   body: 2
# 2. {A subset_eq B if A equiv B.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. A subset_eq B
#    core type: Operation
#    operator: 5
#    operands: 7
# 4. A equiv B
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. subset_eq
#    core type: Literal
#    sub-expressions:
# 6. equiv
#    core type: Literal
#    sub-expressions:
# 7. (A, B)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. A
#    core type: Variable
#    sub-expressions:
# 9. B
#    core type: Variable
#    sub-expressions:
