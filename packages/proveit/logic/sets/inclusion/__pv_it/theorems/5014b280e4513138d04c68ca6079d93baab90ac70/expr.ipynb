# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, Px, Py, x, y
from proveit.logic import Exists, Implies, SubsetEq

# %%
# build up the expression from sub-expressions
expr = Conditional(Implies(Exists([x], Px, domains = [A]), Exists([y], Py, domains = [B])), SubsetEq(A, B))
# Out:
# expr: {[exists_{x in A} P(x)] => [exists_{y in B} P(y)] if A subset_eq B.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left[\exists_{x \in A}~P(x)\right] \Rightarrow \left[\exists_{y \in B}~P(y)\right] \textrm{ if } A \subseteq B\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {[exists_{x in A} P(x)] => [exists_{y in B} P(y)] if A subset_eq B.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. [exists_{x in A} P(x)] => [exists_{y in B} P(y)]
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. A subset_eq B
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =>
#    core type: Literal
#    sub-expressions:
# 4. (exists_{x in A} P(x), exists_{y in B} P(y))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. subset_eq
#    core type: Literal
#    sub-expressions:
# 6. (A, B)
#    core type: ExprTuple
#    sub-expressions: 27, 29
# 7. exists_{x in A} P(x)
#    core type: Operation
#    operator: 10
#    operand: 12
# 8. exists_{y in B} P(y)
#    core type: Operation
#    operator: 10
#    operand: 13
# 9. (x -> {P(x) if x in A.)
#    core type: ExprTuple
#    sub-expressions: 12
# 10. exists
#     core type: Literal
#     sub-expressions:
# 11. (y -> {P(y) if y in B.)
#     core type: ExprTuple
#     sub-expressions: 13
# 12. x -> {P(x) if x in A.
#     core type: Lambda
#     parameter: 26
#     body: 14
# 13. y -> {P(y) if y in B.
#     core type: Lambda
#     parameter: 28
#     body: 15
# 14. {P(x) if x in A.
#     core type: Conditional
#     value: 16
#     condition: 17
# 15. {P(y) if y in B.
#     core type: Conditional
#     value: 18
#     condition: 19
# 16. P(x)
#     core type: Operation
#     operator: 22
#     operand: 26
# 17. x in A
#     core type: Operation
#     operator: 24
#     operands: 21
# 18. P(y)
#     core type: Operation
#     operator: 22
#     operand: 28
# 19. y in B
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. (x)
#     core type: ExprTuple
#     sub-expressions: 26
# 21. (x, A)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 22. P
#     core type: Variable
#     sub-expressions:
# 23. (y)
#     core type: ExprTuple
#     sub-expressions: 28
# 24. in
#     core type: Literal
#     sub-expressions:
# 25. (y, B)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 26. x
#     core type: Variable
#     sub-expressions:
# 27. A
#     core type: Variable
#     sub-expressions:
# 28. y
#     core type: Variable
#     sub-expressions:
# 29. B
#     core type: Variable
#     sub-expressions:
