# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#fold_subset_eq">fold_subset_eq</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.inclusion import fold_subset_eq

# %%
# check that the built expression is the same as the stored expression
assert fold_subset_eq.expr == stored_expr
assert fold_subset_eq.expr._style_id == stored_expr._style_id
print("Passed sanity check: fold_subset_eq matches stored_expr")
# Out:
# Passed sanity check: fold_subset_eq matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(fold_subset_eq.latex())
# Out:
# \vdash \forall_{A, B~|~\forall_{x \in A}~\left(x \in B\right)}~\left(A \subseteq B\right)

# %%
fold_subset_eq.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
fold_subset_eq.expr_info()
# Out:
# 0. forall_{A, B | forall_{x in A} (x in B)} (A subset_eq B)
#    core type: Operation
#    operator: 8
#    operand: 2
# 1. ((A, B) -> {A subset_eq B if forall_{x in A} (x in B).)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (A, B) -> {A subset_eq B if forall_{x in A} (x in B).
#    core type: Lambda
#    parameters: 7\n   body: 3
# 3. {A subset_eq B if forall_{x in A} (x in B).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. A subset_eq B
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. forall_{x in A} (x in B)
#    core type: Operation
#    operator: 8
#    operand: 10
# 6. subset_eq
#    core type: Literal
#    sub-expressions:
# 7. (A, B)
#    core type: ExprTuple
#    sub-expressions: 19, 17
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. (x -> {x in B if x in A.)
#    core type: ExprTuple
#    sub-expressions: 10
# 10. x -> {x in B if x in A.
#     core type: Lambda
#     parameter: 18
#     body: 11
# ...
