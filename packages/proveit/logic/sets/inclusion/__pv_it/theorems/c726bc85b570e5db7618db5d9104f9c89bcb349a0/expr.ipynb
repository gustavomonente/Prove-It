# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, ExprTuple, Lambda
from proveit.logic import Boolean, InSet, ProperSubset

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([A, B], InSet(ProperSubset(A, B), Boolean)))
# Out:
# expr: ((A, B) -> ((A proper_subset B) in BOOLEAN))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(A, B\right) \mapsto \left(\left(A \subset B\right) \in \mathbb{B}\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((A, B) -> ((A proper_subset B) in BOOLEAN))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (A, B) -> ((A proper_subset B) in BOOLEAN)
#    core type: Lambda
#    parameters: 8\n   body: 2
# 2. (A proper_subset B) in BOOLEAN
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. in
#    core type: Literal
#    sub-expressions:
# 4. (A proper_subset B, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. A proper_subset B
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 7. proper_subset
#    core type: Literal
#    sub-expressions:
# 8. (A, B)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. A
#    core type: Variable
#    sub-expressions:
# 10. B
#     core type: Variable
#     sub-expressions:
