# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#refined_nonmembership">refined_nonmembership</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.inclusion import refined_nonmembership

# %%
# check that the built expression is the same as the stored expression
assert refined_nonmembership.expr == stored_expr
assert refined_nonmembership.expr._style_id == stored_expr._style_id
print("Passed sanity check: refined_nonmembership matches stored_expr")
# Out:
# Passed sanity check: refined_nonmembership matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(refined_nonmembership.latex())
# Out:
# \vdash \forall_{A, B, x~|~A \subseteq B, x \notin B}~\left(x \notin A\right)

# %%
refined_nonmembership.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
refined_nonmembership.expr_info()
# Out:
# 0. forall_{A, B, x | A subset_eq B, x not-in B} (x not-in A)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((A, B, x) -> {x not-in A if A subset_eq B ,  x not-in B.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (A, B, x) -> {x not-in A if A subset_eq B ,  x not-in B.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (A, B, x)
#    core type: ExprTuple
#    sub-expressions: 17, 19, 18
# 5. {x not-in A if A subset_eq B ,  x not-in B.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. x not-in A
#    core type: Operation
#    operator: 15
#    operands: 8
# 7. (A subset_eq B) and (x not-in B)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (x, A)
#    core type: ExprTuple
#    sub-expressions: 18, 17
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (A subset_eq B, x not-in B)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. A subset_eq B
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. x not-in B
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. subset_eq
#     core type: Literal
#     sub-expressions:
# 14. (A, B)
#     core type: ExprTuple
#     sub-expressions: 17, 19
# 15. not-in
#     core type: Literal
#     sub-expressions:
# 16. (x, B)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. A
#     core type: Variable
#     sub-expressions:
# 18. x
#     core type: Variable
#     sub-expressions:
# 19. B
#     core type: Variable
#     sub-expressions:
