# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B
from proveit.logic import Forall, Not, NotProperSubset, ProperSubset

# %%
# build up the expression from sub-expressions
expr = Forall([A, B], Not(ProperSubset(A, B)), condition = NotProperSubset(A, B))
# Out:
# expr: forall_{A, B | A not_proper_subset B} not(A proper_subset B)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A, B~|~A \not\subset B}~(\lnot \left(A \subset B\right))

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{A, B | A not_proper_subset B} not(A proper_subset B)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((A, B) -> {not(A proper_subset B) if A not_proper_subset B.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (A, B) -> {not(A proper_subset B) if A not_proper_subset B.
#    core type: Lambda
#    parameters: 12\n   body: 4
# 4. {not(A proper_subset B) if A not_proper_subset B.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. not(A proper_subset B)
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. A not_proper_subset B
#    core type: Operation
#    operator: 9
#    operands: 12
# 7. not
#    core type: Literal
#    sub-expressions:
# 8. (A proper_subset B)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. not_proper_subset
#    core type: Literal
#    sub-expressions:
# 10. A proper_subset B
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. proper_subset
#     core type: Literal
#     sub-expressions:
# 12. (A, B)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. A
#     core type: Variable
#     sub-expressions:
# 14. B
#     core type: Variable
#     sub-expressions:
