# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#fold_proper_subset">fold_proper_subset</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.inclusion import fold_proper_subset

# %%
# check that the built expression is the same as the stored expression
assert fold_proper_subset.expr == stored_expr
assert fold_proper_subset.expr._style_id == stored_expr._style_id
print("Passed sanity check: fold_proper_subset matches stored_expr")
# Out:
# Passed sanity check: fold_proper_subset matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(fold_proper_subset.latex())
# Out:
# \vdash \forall_{A, B~|~A \subseteq B, B \ncong A}~\left(A \subset B\right)

# %%
fold_proper_subset.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
fold_proper_subset.expr_info()
# Out:
# 0. forall_{A, B | A subset_eq B, B not_equiv A} (A proper_subset B)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((A, B) -> {A proper_subset B if A subset_eq B ,  B not_equiv A.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (A, B) -> {A proper_subset B if A subset_eq B ,  B not_equiv A.
#    core type: Lambda
#    parameters: 13\n   body: 4
# 4. {A proper_subset B if A subset_eq B ,  B not_equiv A.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. A proper_subset B
#    core type: Operation
#    operator: 7
#    operands: 13
# 6. (A subset_eq B) and (B not_equiv A)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. proper_subset
#    core type: Literal
#    sub-expressions:
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (A subset_eq B, B not_equiv A)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. A subset_eq B
#     core type: Operation
# ...
