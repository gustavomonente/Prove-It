# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#transitivity_subset_subset">transitivity_subset_subset</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.inclusion import transitivity_subset_subset

# %%
# check that the built expression is the same as the stored expression
assert transitivity_subset_subset.expr == stored_expr
assert transitivity_subset_subset.expr._style_id == stored_expr._style_id
print("Passed sanity check: transitivity_subset_subset matches stored_expr")
# Out:
# Passed sanity check: transitivity_subset_subset matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(transitivity_subset_subset.latex())
# Out:
# \vdash \forall_{A, B, C~|~A \subset B, B \subset C}~\left(A \subset C\right)

# %%
transitivity_subset_subset.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
transitivity_subset_subset.expr_info()
# Out:
# 0. forall_{A, B, C | A proper_subset B, B proper_subset C} (A proper_subset C)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((A, B, C) -> {A proper_subset C if A proper_subset B ,  B proper_subset C.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (A, B, C) -> {A proper_subset C if A proper_subset B ,  B proper_subset C.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (A, B, C)
#    core type: ExprTuple
#    sub-expressions: 16, 17, 18
# 5. {A proper_subset C if A proper_subset B ,  B proper_subset C.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. A proper_subset C
#    core type: Operation
#    operator: 14
#    operands: 8
# 7. (A proper_subset B) and (B proper_subset C)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (A, C)
#    core type: ExprTuple
#    sub-expressions: 16, 18
# 9. and
#    core type: Literal
#    sub-expressions:
# ...
