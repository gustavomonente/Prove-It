# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, x
from proveit.logic import Forall, InSet, ProperSubset

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([x], InSet(x, B), domains = [A]), ProperSubset(A, B))
# Out:
# expr: {forall_{x in A} (x in B) if A proper_subset B.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{x \in A}~\left(x \in B\right) \textrm{ if } A \subset B\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{x in A} (x in B) if A proper_subset B.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{x in A} (x in B)
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. A proper_subset B
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (x -> {x in B if x in A.)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. proper_subset
#    core type: Literal
#    sub-expressions:
# 6. (A, B)
#    core type: ExprTuple
#    sub-expressions: 16, 14
# 7. x -> {x in B if x in A.
#    core type: Lambda
#    parameter: 15
#    body: 8
# 8. {x in B if x in A.
#    core type: Conditional
#    value: 9
#    condition: 10
# 9. x in B
#    core type: Operation
#    operator: 12
#    operands: 11
# 10. x in A
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (x, B)
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (x, A)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. B
#     core type: Variable
#     sub-expressions:
# 15. x
#     core type: Variable
#     sub-expressions:
# 16. A
#     core type: Variable
#     sub-expressions:
