# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, x
from proveit.logic import And, NotInSet, SubsetEq

# %%
# build up the expression from sub-expressions
expr = Conditional(NotInSet(x, A), And(SubsetEq(A, B), NotInSet(x, B)))
# Out:
# expr: {x not-in A if A subset_eq B ,  x not-in B.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{x \notin A \textrm{ if } A \subseteq B ,  x \notin B\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {x not-in A if A subset_eq B ,  x not-in B.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. x not-in A
#    core type: Operation
#    operator: 10
#    operands: 3
# 2. (A subset_eq B) and (x not-in B)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (x, A)
#    core type: ExprTuple
#    sub-expressions: 13, 12
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (A subset_eq B, x not-in B)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. A subset_eq B
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. x not-in B
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. subset_eq
#    core type: Literal
#    sub-expressions:
# 9. (A, B)
#    core type: ExprTuple
#    sub-expressions: 12, 14
# 10. not-in
#     core type: Literal
#     sub-expressions:
# 11. (x, B)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. A
#     core type: Variable
#     sub-expressions:
# 13. x
#     core type: Variable
#     sub-expressions:
# 14. B
#     core type: Variable
#     sub-expressions:
