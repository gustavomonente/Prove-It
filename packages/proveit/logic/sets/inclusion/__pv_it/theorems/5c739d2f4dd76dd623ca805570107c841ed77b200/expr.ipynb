# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, ExprTuple, Lambda, P, Px, Py, x, y
from proveit.logic import Exists, Implies, SubsetEq

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([A, B, P], Conditional(Implies(Exists([x], Px, domains = [A]), Exists([y], Py, domains = [B])), SubsetEq(A, B))))
# Out:
# expr: ((A, B, P) -> {[exists_{x in A} P(x)] => [exists_{y in B} P(y)] if A subset_eq B.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(A, B, P\right) \mapsto \left\{\left[\exists_{x \in A}~P(x)\right] \Rightarrow \left[\exists_{y \in B}~P(y)\right] \textrm{ if } A \subseteq B\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((A, B, P) -> {[exists_{x in A} P(x)] => [exists_{y in B} P(y)] if A subset_eq B.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (A, B, P) -> {[exists_{x in A} P(x)] => [exists_{y in B} P(y)] if A subset_eq B.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (A, B, P)
#    core type: ExprTuple
#    sub-expressions: 30, 32, 25
# 3. {[exists_{x in A} P(x)] => [exists_{y in B} P(y)] if A subset_eq B.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. [exists_{x in A} P(x)] => [exists_{y in B} P(y)]
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. A subset_eq B
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =>
#    core type: Literal
#    sub-expressions:
# 7. (exists_{x in A} P(x), exists_{y in B} P(y))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. subset_eq
#    core type: Literal
#    sub-expressions:
# 9. (A, B)
#    core type: ExprTuple
#    sub-expressions: 30, 32
# 10. exists_{x in A} P(x)
# ...
