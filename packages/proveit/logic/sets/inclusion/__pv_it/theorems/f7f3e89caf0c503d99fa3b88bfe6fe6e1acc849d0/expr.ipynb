# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, Lambda
from proveit.logic import ProperSubset, SubsetEq

# %%
# build up the expression from sub-expressions
expr = Lambda([A, B], Conditional(SubsetEq(A, B), ProperSubset(A, B)))
# Out:
# expr: (A, B) -> {A subset_eq B if A proper_subset B.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A, B\right) \mapsto \left\{A \subseteq B \textrm{ if } A \subset B\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A, B) -> {A subset_eq B if A proper_subset B.
#    core type: Lambda
#    parameters: 6\n   body: 1
# 1. {A subset_eq B if A proper_subset B.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. A subset_eq B
#    core type: Operation
#    operator: 4
#    operands: 6
# 3. A proper_subset B
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. subset_eq
#    core type: Literal
#    sub-expressions:
# 5. proper_subset
#    core type: Literal
#    sub-expressions:
# 6. (A, B)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. A
#    core type: Variable
#    sub-expressions:
# 8. B
#    core type: Variable
#    sub-expressions:
