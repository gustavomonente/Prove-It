# %% [markdown]
# Show the Proof
# ========

# %%
import proveit
# Automation is not needed when only showing a stored proof:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %show_proof
# Out:
# <table><tr><th>&nbsp;</th><th>step type</th><th>requirements</th><th>statement</th></tr>
# <tr><td><a name="proveit.logic.sets.inclusion._proof_unfold_subset_eq.04bce948fafe927f67380dabdf114154422d5d7d0_step0">0</a></td><td>assumption</td><td></td><td><span style="font-size:20px;"><a class="ProveItLink" href="../../axioms/e95a006f2b74a09b90987eb3cf94c9d5b15f5eda0/expr.ipynb"><img src="../../axioms/e95a006f2b74a09b90987eb3cf94c9d5b15f5eda0/expr.png" style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../axioms/e95a006f2b74a09b90987eb3cf94c9d5b15f5eda0/expr.ipynb"><img src="../../axioms/e95a006f2b74a09b90987eb3cf94c9d5b15f5eda0/expr.png" style="display:inline;vertical-align:middle;" /></a></span></td></tr>
# </table>
