# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Variable
from proveit.logic import InSet, Set
from proveit.numbers import four, one, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Conditional(InSet(sub_expr1, Set(one, two, three, four)), InSet(sub_expr1, Set(one, three)))
# Out:
# expr: {_a in {1, 2, 3, 4} if _a in {1, 3}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{{_{-}a} \in \left\{1, 2, 3, 4\right\} \textrm{ if } {_{-}a} \in \left\{1, 3\right\}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {_a in {1, 2, 3, 4} if _a in {1, 3}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. _a in {1, 2, 3, 4}
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. _a in {1, 3}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (_a, {1, 2, 3, 4})
#    core type: ExprTuple
#    sub-expressions: 7, 6
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (_a, {1, 3})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. {1, 2, 3, 4}
#    core type: Operation
#    operator: 10
#    operands: 9
# 7. _a
#    core type: Variable
#    sub-expressions:
# 8. {1, 3}
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (1, 2, 3, 4)
#    core type: ExprTuple
#    sub-expressions: 14, 12, 15, 13
# 10. Set
#     core type: Literal
#     sub-expressions:
# 11. (1, 3)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. 2
#     core type: Literal
#     sub-expressions:
# 13. 4
#     core type: Literal
#     sub-expressions:
# 14. 1
#     core type: Literal
#     sub-expressions:
# 15. 3
#     core type: Literal
#     sub-expressions:
