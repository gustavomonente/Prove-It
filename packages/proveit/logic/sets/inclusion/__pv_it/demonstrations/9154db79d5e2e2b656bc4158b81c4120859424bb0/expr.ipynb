# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Or.html">Or</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import x
from proveit.logic import Equals, Or
from proveit.numbers import five, four, one, three, two

# %%
# build up the expression from sub-expressions
expr = Or(Or(Equals(x, one), Equals(x, three), Equals(x, five)), Or(Equals(x, four), Equals(x, two)))
# Out:
# expr: ((x = 1) or (x = 3) or (x = 5)) or ((x = 4) or (x = 2))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(x = 1\right) \lor \left(x = 3\right) \lor \left(x = 5\right)\right) \lor \left(\left(x = 4\right) \lor \left(x = 2\right)\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((x = 1) or (x = 3) or (x = 5)) or ((x = 4) or (x = 2))
#    core type: Operation
#    operator: 5
#    operands: 1
# 1. ((x = 1) or (x = 3) or (x = 5), (x = 4) or (x = 2))
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. (x = 1) or (x = 3) or (x = 5)
#    core type: Operation
#    operator: 5
#    operands: 4
# 3. (x = 4) or (x = 2)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (x = 1, x = 3, x = 5)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 5. or
#    core type: Literal
#    sub-expressions:
# 6. (x = 4, x = 2)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 7. x = 1
#    core type: Operation
#    operator: 16
#    operands: 12
# 8. x = 3
#    core type: Operation
#    operator: 16
#    operands: 13
# 9. x = 5
#    core type: Operation
#    operator: 16
#    operands: 14
# 10. x = 4
#     core type: Operation
#     operator: 16
#     operands: 15
# 11. x = 2
#     core type: Operation
#     operator: 16
#     operands: 17
# 12. (x, 1)
#     core type: ExprTuple
#     sub-expressions: 22, 18
# 13. (x, 3)
#     core type: ExprTuple
#     sub-expressions: 22, 19
# 14. (x, 5)
#     core type: ExprTuple
#     sub-expressions: 22, 20
# 15. (x, 4)
#     core type: ExprTuple
#     sub-expressions: 22, 21
# 16. =
#     core type: Literal
#     sub-expressions:
# 17. (x, 2)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 18. 1
#     core type: Literal
#     sub-expressions:
# 19. 3
#     core type: Literal
#     sub-expressions:
# 20. 5
#     core type: Literal
#     sub-expressions:
# 21. 4
#     core type: Literal
#     sub-expressions:
# 22. x
#     core type: Variable
#     sub-expressions:
# 23. 2
#     core type: Literal
#     sub-expressions:
