# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, x
from proveit.logic import InSet, Set
from proveit.numbers import five, four, one, three, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(x, Conditional(InSet(x, Set(one, two, three, four, five)), InSet(x, Set(one, two, three)))))
# Out:
# expr: (x -> {x in {1, 2, 3, 4, 5} if x in {1, 2, 3}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \mapsto \left\{x \in \left\{1, 2, 3, 4, 5\right\} \textrm{ if } x \in \left\{1, 2, 3\right\}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x -> {x in {1, 2, 3, 4, 5} if x in {1, 2, 3}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. x -> {x in {1, 2, 3, 4, 5} if x in {1, 2, 3}.
#    core type: Lambda
#    parameter: 9
#    body: 2
# 2. {x in {1, 2, 3, 4, 5} if x in {1, 2, 3}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. x in {1, 2, 3, 4, 5}
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. x in {1, 2, 3}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (x, {1, 2, 3, 4, 5})
#    core type: ExprTuple
#    sub-expressions: 9, 8
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (x, {1, 2, 3})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. {1, 2, 3, 4, 5}
#    core type: Operation
#    operator: 12
#    operands: 11
# 9. x
#    core type: Variable
#    sub-expressions:
# 10. {1, 2, 3}
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (1, 2, 3, 4, 5)
#     core type: ExprTuple
#     sub-expressions: 16, 17, 18, 14, 15
# 12. Set
#     core type: Literal
#     sub-expressions:
# 13. (1, 2, 3)
#     core type: ExprTuple
#     sub-expressions: 16, 17, 18
# 14. 4
#     core type: Literal
#     sub-expressions:
# 15. 5
#     core type: Literal
#     sub-expressions:
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. 2
#     core type: Literal
#     sub-expressions:
# 18. 3
#     core type: Literal
#     sub-expressions:
