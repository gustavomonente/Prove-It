# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, x
from proveit.logic import InSet, Set
from proveit.numbers import five, four, one, three, two

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Conditional(InSet(x, Set(one, two, three, four, five)), InSet(x, Set(one, three, five))))
# Out:
# expr: x -> {x in {1, 2, 3, 4, 5} if x in {1, 3, 5}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# x \mapsto \left\{x \in \left\{1, 2, 3, 4, 5\right\} \textrm{ if } x \in \left\{1, 3, 5\right\}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. x -> {x in {1, 2, 3, 4, 5} if x in {1, 3, 5}.
#    core type: Lambda
#    parameter: 8
#    body: 1
# 1. {x in {1, 2, 3, 4, 5} if x in {1, 3, 5}.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. x in {1, 2, 3, 4, 5}
#    core type: Operation
#    operator: 5
#    operands: 4
# 3. x in {1, 3, 5}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (x, {1, 2, 3, 4, 5})
#    core type: ExprTuple
#    sub-expressions: 8, 7
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (x, {1, 3, 5})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. {1, 2, 3, 4, 5}
#    core type: Operation
#    operator: 11
#    operands: 10
# 8. x
#    core type: Variable
#    sub-expressions:
# 9. {1, 3, 5}
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (1, 2, 3, 4, 5)
#     core type: ExprTuple
#     sub-expressions: 15, 13, 16, 14, 17
# 11. Set
#     core type: Literal
#     sub-expressions:
# 12. (1, 3, 5)
#     core type: ExprTuple
#     sub-expressions: 15, 16, 17
# 13. 2
#     core type: Literal
#     sub-expressions:
# 14. 4
#     core type: Literal
#     sub-expressions:
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. 3
#     core type: Literal
#     sub-expressions:
# 17. 5
#     core type: Literal
#     sub-expressions:
