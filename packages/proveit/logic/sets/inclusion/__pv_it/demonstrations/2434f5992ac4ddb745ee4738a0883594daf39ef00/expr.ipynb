# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Variable, b, c, f
from proveit.logic import InSet, Set

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Conditional(InSet(sub_expr1, Set(b, c, f)), InSet(sub_expr1, Set(b, c)))
# Out:
# expr: {_a in {b, c, f} if _a in {b, c}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{{_{-}a} \in \left\{b, c, f\right\} \textrm{ if } {_{-}a} \in \left\{b, c\right\}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {_a in {b, c, f} if _a in {b, c}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. _a in {b, c, f}
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. _a in {b, c}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (_a, {b, c, f})
#    core type: ExprTuple
#    sub-expressions: 7, 6
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (_a, {b, c})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. {b, c, f}
#    core type: Operation
#    operator: 10
#    operands: 9
# 7. _a
#    core type: Variable
#    sub-expressions:
# 8. {b, c}
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (b, c, f)
#    core type: ExprTuple
#    sub-expressions: 13, 14, 12
# 10. Set
#     core type: Literal
#     sub-expressions:
# 11. (b, c)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. f
#     core type: Variable
#     sub-expressions:
# 13. b
#     core type: Variable
#     sub-expressions:
# 14. c
#     core type: Variable
#     sub-expressions:
