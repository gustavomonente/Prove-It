# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.unification</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Q, R, n, x
from proveit.core_expr_types import Q__y_1_to_n, R__y_1_to_n, S_1_to_n, y_1_to_n
from proveit.logic import Equals, Exists, Forall, InSet
from proveit.logic.sets import general_unionall_Ryn
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([S_1_to_n, Q, R, x], Equals(InSet(x, general_unionall_Ryn), Exists([y_1_to_n], InSet(x, R__y_1_to_n), domains = [S_1_to_n], condition = Q__y_1_to_n)).with_wrapping_at(1)), InSet(n, NaturalPos))
# Out:
# expr: {forall_{S_{1}, ..S_{_a}.., S_{n}, Q, R, x} ((x in [union_of_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))]) if n in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{S_{1}, \ldots, S_{n}, Q, R, x}~\left(\begin{array}{c} \begin{array}{l} \left(x \in \left[\bigcup_{y_{1} \in S_{1}, \ldots, y_{n} \in S_{n}~|~Q(y_{1}, \ldots, y_{n})}~R(y_{1}, \ldots, y_{n})\right]\right) \\  = \left[\exists_{y_{1} \in S_{1}, \ldots, y_{n} \in S_{n}~|~Q(y_{1}, \ldots, y_{n})}~\left(x \in R(y_{1}, \ldots, y_{n})\right)\right] \end{array} \end{array}\right) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{S_{1}, ..S_{_a}.., S_{n}, Q, R, x} ((x in [union_of_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))]) if n in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{S_{1}, ..S_{_a}.., S_{n}, Q, R, x} ((x in [union_of_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))])
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. n in NaturalPos
#    core type: Operation
#    operator: 41
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((S_{1}, ..S_{_a}.., S_{n}, Q, R, x) -> ((x in [union_of_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))]))
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 45, 7
# 6. (S_{1}, ..S_{_a}.., S_{n}, Q, R, x) -> ((x in [union_of_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))])
#    core type: Lambda
#    parameters: 8\n   body: 9
# 7. NaturalPos
#    core type: Literal
#    sub-expressions:
# 8. (S_{1}, ..S_{_a}.., S_{n}, Q, R, x)
#    core type: ExprTuple
#    sub-expressions: 10, 37, 33, 29
# 9. (x in [union_of_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))]
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. S_{1}, ..S_{_a}.., S_{n}
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 44
#     end_index: 45
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (x in [union_of_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})], exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n})))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. _a -> S_{_a}
#     core type: Lambda
#     parameter: 51
#     body: 46
# 14. x in [union_of_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]
#     core type: Operation
#     operator: 41
#     operands: 16
# 15. exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))
#     core type: Operation
#     operator: 17
#     operand: 20
# 16. (x, union_of_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 29, 19
# 17. exists
#     core type: Literal
#     sub-expressions:
# 18. ((y_{1}, ..y_{_a}.., y_{n}) -> {x in R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 20
# 19. union_of_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 21
#     operand: 24
# 20. (y_{1}, ..y_{_a}.., y_{n}) -> {x in R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 38\n    body: 23
# 21. union_of_all
#     core type: Literal
#     sub-expressions:
# 22. ((y_{1}, ..y_{_a}.., y_{n}) -> {R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 24
# 23. {x in R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 25
#     condition: 28
# 24. (y_{1}, ..y_{_a}.., y_{n}) -> {R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 38\n    body: 26
# 25. x in R(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 41
#     operands: 27
# 26. {R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 30
#     condition: 28
# 27. (x, R(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 28. (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n}) and Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 31
#     operands: 32
# 29. x
#     core type: Variable
#     sub-expressions:
# 30. R(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 33
#     operands: 38
# 31. and
#     core type: Literal
#     sub-expressions:
# 32. (y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}, Q(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 33. R
#     core type: Variable
#     sub-expressions:
# 34. (y_{1} in S_{1}), ..(y_{_a} in S_{_a}).., (y_{n} in S_{n})
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 44
#     end_index: 45
# 35. Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 37
#     operands: 38
# 36. _a -> (y_{_a} in S_{_a})
#     core type: Lambda
#     parameter: 51
#     body: 39
# 37. Q
#     core type: Variable
#     sub-expressions:
# 38. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 40
# 39. y_{_a} in S_{_a}
#     core type: Operation
#     operator: 41
#     operands: 42
# 40. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 44
#     end_index: 45
# 41. in
#     core type: Literal
#     sub-expressions:
# 42. (y_{_a}, S_{_a})
#     core type: ExprTuple
#     sub-expressions: 47, 46
# 43. _a -> y_{_a}
#     core type: Lambda
#     parameter: 51
#     body: 47
# 44. 1
#     core type: Literal
#     sub-expressions:
# 45. n
#     core type: Variable
#     sub-expressions:
# 46. S_{_a}
#     core type: IndexedVar
# variable: 48
# index: 51
# 47. y_{_a}
#     core type: IndexedVar
# variable: 49
# index: 51
# 48. S
#     core type: Variable
#     sub-expressions:
# 49. y
#     core type: Variable
#     sub-expressions:
# 50. (_a)
#     core type: ExprTuple
#     sub-expressions: 51
# 51. _a
#     core type: Variable
#     sub-expressions:
