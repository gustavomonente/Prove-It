# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.unification</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Q, R, x
from proveit.core_expr_types import Q__y_1_to_n, R__y_1_to_n, S_1_to_n, y_1_to_n
from proveit.logic import Equals, Exists, Forall, InSet
from proveit.logic.sets import general_unionall_Ryn

# %%
# build up the expression from sub-expressions
expr = Forall([S_1_to_n, Q, R, x], Equals(InSet(x, general_unionall_Ryn), Exists([y_1_to_n], InSet(x, R__y_1_to_n), domains = [S_1_to_n], condition = Q__y_1_to_n)).with_wrapping_at(1))
# Out:
# expr: forall_{S_{1}, ..S_{_a}.., S_{n}, Q, R, x} ((x in [union_of_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))])

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{S_{1}, \ldots, S_{n}, Q, R, x}~\left(\begin{array}{c} \begin{array}{l} \left(x \in \left[\bigcup_{y_{1} \in S_{1}, \ldots, y_{n} \in S_{n}~|~Q(y_{1}, \ldots, y_{n})}~R(y_{1}, \ldots, y_{n})\right]\right) \\  = \left[\exists_{y_{1} \in S_{1}, \ldots, y_{n} \in S_{n}~|~Q(y_{1}, \ldots, y_{n})}~\left(x \in R(y_{1}, \ldots, y_{n})\right)\right] \end{array} \end{array}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{S_{1}, ..S_{_a}.., S_{n}, Q, R, x} ((x in [union_of_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))])
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((S_{1}, ..S_{_a}.., S_{n}, Q, R, x) -> ((x in [union_of_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))]))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (S_{1}, ..S_{_a}.., S_{n}, Q, R, x) -> ((x in [union_of_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))])
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (S_{1}, ..S_{_a}.., S_{n}, Q, R, x)
#    core type: ExprTuple
#    sub-expressions: 6, 33, 29, 25
# 5. (x in [union_of_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))]
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. S_{1}, ..S_{_a}.., S_{n}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 40
#    end_index: 41
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (x in [union_of_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})], exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n})))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. _a -> S_{_a}
#    core type: Lambda
#    parameter: 47
#    body: 42
# 10. x in [union_of_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]
#     core type: Operation
#     operator: 37
#     operands: 12
# 11. exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))
#     core type: Operation
#     operator: 13
#     operand: 16
# 12. (x, union_of_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 25, 15
# 13. exists
#     core type: Literal
#     sub-expressions:
# 14. ((y_{1}, ..y_{_a}.., y_{n}) -> {x in R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. union_of_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 17
#     operand: 20
# 16. (y_{1}, ..y_{_a}.., y_{n}) -> {x in R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 34\n    body: 19
# 17. union_of_all
#     core type: Literal
#     sub-expressions:
# 18. ((y_{1}, ..y_{_a}.., y_{n}) -> {R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 20
# 19. {x in R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 21
#     condition: 24
# 20. (y_{1}, ..y_{_a}.., y_{n}) -> {R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 34\n    body: 22
# 21. x in R(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 37
#     operands: 23
# 22. {R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 26
#     condition: 24
# 23. (x, R(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 24. (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n}) and Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. x
#     core type: Variable
#     sub-expressions:
# 26. R(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 29
#     operands: 34
# 27. and
#     core type: Literal
#     sub-expressions:
# 28. (y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}, Q(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 29. R
#     core type: Variable
#     sub-expressions:
# 30. (y_{1} in S_{1}), ..(y_{_a} in S_{_a}).., (y_{n} in S_{n})
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 40
#     end_index: 41
# 31. Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 33
#     operands: 34
# 32. _a -> (y_{_a} in S_{_a})
#     core type: Lambda
#     parameter: 47
#     body: 35
# 33. Q
#     core type: Variable
#     sub-expressions:
# 34. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 36
# 35. y_{_a} in S_{_a}
#     core type: Operation
#     operator: 37
#     operands: 38
# 36. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 40
#     end_index: 41
# 37. in
#     core type: Literal
#     sub-expressions:
# 38. (y_{_a}, S_{_a})
#     core type: ExprTuple
#     sub-expressions: 43, 42
# 39. _a -> y_{_a}
#     core type: Lambda
#     parameter: 47
#     body: 43
# 40. 1
#     core type: Literal
#     sub-expressions:
# 41. n
#     core type: Variable
#     sub-expressions:
# 42. S_{_a}
#     core type: IndexedVar
# variable: 44
# index: 47
# 43. y_{_a}
#     core type: IndexedVar
# variable: 45
# index: 47
# 44. S
#     core type: Variable
#     sub-expressions:
# 45. y
#     core type: Variable
#     sub-expressions:
# 46. (_a)
#     core type: ExprTuple
#     sub-expressions: 47
# 47. _a
#     core type: Variable
#     sub-expressions:
