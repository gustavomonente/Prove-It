# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.unification</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda, x
from proveit.core_expr_types import A_1_to_m
from proveit.logic import Equals, InSet, Union
from proveit.logic.sets import x_in_any_A

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([x, A_1_to_m], Equals(InSet(x, Union(A_1_to_m)), x_in_any_A).with_wrapping_at(2)))
# Out:
# expr: ((x, A_{1}, ..A_{_a}.., A_{m}) -> ((x in (A_{1} union ..A_{_a}.. union A_{m})) =  \\ ((x in A_{1}) or ..(x in A_{i}).. or (x in A_{m}))))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(x, A_{1}, \ldots, A_{m}\right) \mapsto \left(\begin{array}{c} \begin{array}{l} \left(x \in \left(A_{1} \cup \ldots \cup A_{m}\right)\right) =  \\ \left(\left(x \in A_{1}\right) \lor \ldots \lor \left(x \in A_{m}\right)\right) \end{array} \end{array}\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((x, A_{1}, ..A_{_a}.., A_{m}) -> ((x in (A_{1} union ..A_{_a}.. union A_{m})) =  \\ ((x in A_{1}) or ..(x in A_{i}).. or (x in A_{m}))))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (x, A_{1}, ..A_{_a}.., A_{m}) -> ((x in (A_{1} union ..A_{_a}.. union A_{m})) =  \\ ((x in A_{1}) or ..(x in A_{i}).. or (x in A_{m})))
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (x, A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 24, 16
# 3. (x in (A_{1} union ..A_{_a}.. union A_{m})) =  \\ ((x in A_{1}) or ..(x in A_{i}).. or (x in A_{m}))
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (x in (A_{1} union ..A_{_a}.. union A_{m}), (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m}))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. x in (A_{1} union ..A_{_a}.. union A_{m})
#    core type: Operation
#    operator: 21
#    operands: 8
# 7. (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m})
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (x, A_{1} union ..A_{_a}.. union A_{m})
#    core type: ExprTuple
#    sub-expressions: 24, 11
# 9. or
#    core type: Literal
#    sub-expressions:
# 10. (x in A_{1}, ..x in A_{i}.., x in A_{m})
#     core type: ExprTuple
#     sub-expressions: 12
# 11. A_{1} union ..A_{_a}.. union A_{m}
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (x in A_{1}), ..(x in A_{i}).., (x in A_{m})
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 19
#     end_index: 20
# 13. union
#     core type: Literal
#     sub-expressions:
# 14. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 16
# 15. i -> (x in A_{i})
#     core type: Lambda
#     parameter: 30
#     body: 17
# 16. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 19
#     end_index: 20
# 17. x in A_{i}
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. _a -> A_{_a}
#     core type: Lambda
#     parameter: 29
#     body: 23
# 19. 1
#     core type: Literal
#     sub-expressions:
# 20. m
#     core type: Variable
#     sub-expressions:
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (x, A_{i})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 23. A_{_a}
#     core type: IndexedVar
# variable: 27
# index: 29
# 24. x
#     core type: Variable
#     sub-expressions:
# 25. A_{i}
#     core type: IndexedVar
# variable: 27
# index: 30
# 26. (_a)
#     core type: ExprTuple
#     sub-expressions: 29
# 27. A
#     core type: Variable
#     sub-expressions:
# 28. (i)
#     core type: ExprTuple
#     sub-expressions: 30
# 29. _a
#     core type: Variable
#     sub-expressions:
# 30. i
#     core type: Variable
#     sub-expressions:
