# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.unification</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import x
from proveit.core_expr_types import A_1_to_m
from proveit.logic import Equals, Forall, InSet, Union
from proveit.logic.sets import x_in_any_A

# %%
# build up the expression from sub-expressions
expr = Forall([x, A_1_to_m], Equals(InSet(x, Union(A_1_to_m)), x_in_any_A).with_wrapping_at(2))
# Out:
# expr: forall_{x, A_{1}, ..A_{_a}.., A_{m}} ((x in (A_{1} union ..A_{_a}.. union A_{m})) =  \\ ((x in A_{1}) or ..(x in A_{i}).. or (x in A_{m})))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x, A_{1}, \ldots, A_{m}}~\left(\begin{array}{c} \begin{array}{l} \left(x \in \left(A_{1} \cup \ldots \cup A_{m}\right)\right) =  \\ \left(\left(x \in A_{1}\right) \lor \ldots \lor \left(x \in A_{m}\right)\right) \end{array} \end{array}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{x, A_{1}, ..A_{_a}.., A_{m}} ((x in (A_{1} union ..A_{_a}.. union A_{m})) =  \\ ((x in A_{1}) or ..(x in A_{i}).. or (x in A_{m})))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((x, A_{1}, ..A_{_a}.., A_{m}) -> ((x in (A_{1} union ..A_{_a}.. union A_{m})) =  \\ ((x in A_{1}) or ..(x in A_{i}).. or (x in A_{m}))))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (x, A_{1}, ..A_{_a}.., A_{m}) -> ((x in (A_{1} union ..A_{_a}.. union A_{m})) =  \\ ((x in A_{1}) or ..(x in A_{i}).. or (x in A_{m})))
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (x, A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 26, 18
# 5. (x in (A_{1} union ..A_{_a}.. union A_{m})) =  \\ ((x in A_{1}) or ..(x in A_{i}).. or (x in A_{m}))
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (x in (A_{1} union ..A_{_a}.. union A_{m}), (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m}))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. x in (A_{1} union ..A_{_a}.. union A_{m})
#    core type: Operation
#    operator: 23
#    operands: 10
# 9. (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m})
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (x, A_{1} union ..A_{_a}.. union A_{m})
#     core type: ExprTuple
#     sub-expressions: 26, 13
# 11. or
#     core type: Literal
#     sub-expressions:
# 12. (x in A_{1}, ..x in A_{i}.., x in A_{m})
#     core type: ExprTuple
#     sub-expressions: 14
# 13. A_{1} union ..A_{_a}.. union A_{m}
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (x in A_{1}), ..(x in A_{i}).., (x in A_{m})
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 21
#     end_index: 22
# 15. union
#     core type: Literal
#     sub-expressions:
# 16. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 18
# 17. i -> (x in A_{i})
#     core type: Lambda
#     parameter: 32
#     body: 19
# 18. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 21
#     end_index: 22
# 19. x in A_{i}
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. _a -> A_{_a}
#     core type: Lambda
#     parameter: 31
#     body: 25
# 21. 1
#     core type: Literal
#     sub-expressions:
# 22. m
#     core type: Variable
#     sub-expressions:
# 23. in
#     core type: Literal
#     sub-expressions:
# 24. (x, A_{i})
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 25. A_{_a}
#     core type: IndexedVar
# variable: 29
# index: 31
# 26. x
#     core type: Variable
#     sub-expressions:
# 27. A_{i}
#     core type: IndexedVar
# variable: 29
# index: 32
# 28. (_a)
#     core type: ExprTuple
#     sub-expressions: 31
# 29. A
#     core type: Variable
#     sub-expressions:
# 30. (i)
#     core type: ExprTuple
#     sub-expressions: 32
# 31. _a
#     core type: Variable
#     sub-expressions:
# 32. i
#     core type: Variable
#     sub-expressions:
