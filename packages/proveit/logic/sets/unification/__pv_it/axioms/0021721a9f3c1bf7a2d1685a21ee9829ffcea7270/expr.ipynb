# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.unification</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, ExprTuple, IndexedVar, Lambda, S, Variable, n, x, y
from proveit.core_expr_types import Q__y_1_to_n, R__y_1_to_n, y_1_to_n
from proveit.logic import And, InSet
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(Lambda([y_1_to_n], Conditional(InSet(x, R__y_1_to_n), And(ExprRange(sub_expr1, InSet(IndexedVar(y, sub_expr1), IndexedVar(S, sub_expr1)), one, n), Q__y_1_to_n))))
# Out:
# expr: ((y_{1}, ..y_{_a}.., y_{n}) -> {x in R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(y_{1}, \ldots, y_{n}\right) \mapsto \left\{x \in R(y_{1}, \ldots, y_{n}) \textrm{ if } y_{1} \in S_{1} ,  \ldots ,  y_{n} \in S_{n} ,  Q(y_{1}, \ldots, y_{n})\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((y_{1}, ..y_{_a}.., y_{n}) -> {x in R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (y_{1}, ..y_{_a}.., y_{n}) -> {x in R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#    core type: Lambda
#    parameters: 15\n   body: 2
# 2. {x in R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. x in R(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 18
#    operands: 5
# 4. (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n}) and Q(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (x, R(y_{1}, ..y_{_a}.., y_{n}))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}, Q(y_{1}, ..y_{_a}.., y_{n}))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. x
#    core type: Variable
#    sub-expressions:
# 9. R(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 12
#    operands: 15
# 10. (y_{1} in S_{1}), ..(y_{_a} in S_{_a}).., (y_{n} in S_{n})
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 21
#     end_index: 22
# 11. Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. R
#     core type: Variable
#     sub-expressions:
# 13. _a -> (y_{_a} in S_{_a})
#     core type: Lambda
#     parameter: 28
#     body: 16
# 14. Q
#     core type: Variable
#     sub-expressions:
# 15. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 17
# 16. y_{_a} in S_{_a}
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 21
#     end_index: 22
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (y_{_a}, S_{_a})
#     core type: ExprTuple
#     sub-expressions: 24, 23
# 20. _a -> y_{_a}
#     core type: Lambda
#     parameter: 28
#     body: 24
# 21. 1
#     core type: Literal
#     sub-expressions:
# 22. n
#     core type: Variable
#     sub-expressions:
# 23. S_{_a}
#     core type: IndexedVar
# variable: 25
# index: 28
# 24. y_{_a}
#     core type: IndexedVar
# variable: 26
# index: 28
# 25. S
#     core type: Variable
#     sub-expressions:
# 26. y
#     core type: Variable
#     sub-expressions:
# 27. (_a)
#     core type: ExprTuple
#     sub-expressions: 28
# 28. _a
#     core type: Variable
#     sub-expressions:
