# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#intersect_all_def">intersect_all_def</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.unification</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.unification import intersect_all_def

# %%
# check that the built expression is the same as the stored expression
assert intersect_all_def.expr == stored_expr
assert intersect_all_def.expr._style_id == stored_expr._style_id
print("Passed sanity check: intersect_all_def matches stored_expr")
# Out:
# Passed sanity check: intersect_all_def matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(intersect_all_def.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{S_{1}, \ldots, S_{n}, Q, R, x}~\left(\begin{array}{c} \begin{array}{l} \left(x \in \left[\bigcup_{y_{1} \in S_{1}, \ldots, y_{n} \in S_{n}~|~Q(y_{1}, \ldots, y_{n})}~R(y_{1}, \ldots, y_{n})\right]\right) \\  = \left[\exists_{y_{1} \in S_{1}, \ldots, y_{n} \in S_{n}~|~Q(y_{1}, \ldots, y_{n})}~\left(x \in R(y_{1}, \ldots, y_{n})\right)\right] \end{array} \end{array}\right)\right]

# %%
intersect_all_def.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
intersect_all_def.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{S_{1}, ..S_{_a}.., S_{n}, Q, R, x} ((x in [union_of_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))])]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (n -> {forall_{S_{1}, ..S_{_a}.., S_{n}, Q, R, x} ((x in [union_of_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))]) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# ...
