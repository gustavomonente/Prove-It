# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.unification</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, m, x
from proveit.core_expr_types import A_1_to_m
from proveit.logic import Forall, InSet, Union
from proveit.logic.sets import x_in_any_A
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(m, Conditional(Forall([x, A_1_to_m], InSet(x, Union(A_1_to_m)), condition = x_in_any_A), InSet(m, NaturalPos))))
# Out:
# expr: (m -> {forall_{x, A_{1}, ..A_{_a}.., A_{m} | (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m})} (x in (A_{1} union ..A_{_a}.. union A_{m})) if m in NaturalPos.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(m \mapsto \left\{\forall_{x, A_{1}, \ldots, A_{m}~|~\left(x \in A_{1}\right) \lor \ldots \lor \left(x \in A_{m}\right)}~\left(x \in \left(A_{1} \cup \ldots \cup A_{m}\right)\right) \textrm{ if } m \in \mathbb{N}^+\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (m -> {forall_{x, A_{1}, ..A_{_a}.., A_{m} | (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m})} (x in (A_{1} union ..A_{_a}.. union A_{m})) if m in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. m -> {forall_{x, A_{1}, ..A_{_a}.., A_{m} | (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m})} (x in (A_{1} union ..A_{_a}.. union A_{m})) if m in NaturalPos.
#    core type: Lambda
#    parameter: 26
#    body: 2
# 2. {forall_{x, A_{1}, ..A_{_a}.., A_{m} | (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m})} (x in (A_{1} union ..A_{_a}.. union A_{m})) if m in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{x, A_{1}, ..A_{_a}.., A_{m} | (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m})} (x in (A_{1} union ..A_{_a}.. union A_{m}))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. m in NaturalPos
#    core type: Operation
#    operator: 27
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((x, A_{1}, ..A_{_a}.., A_{m}) -> {x in (A_{1} union ..A_{_a}.. union A_{m}) if (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m}).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (m, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 26, 9
# 8. (x, A_{1}, ..A_{_a}.., A_{m}) -> {x in (A_{1} union ..A_{_a}.. union A_{m}) if (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m}).
#    core type: Lambda
#    parameters: 10\n   body: 11
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. (x, A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 30, 22
# 11. {x in (A_{1} union ..A_{_a}.. union A_{m}) if (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m}).
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. x in (A_{1} union ..A_{_a}.. union A_{m})
#     core type: Operation
#     operator: 27
#     operands: 14
# 13. (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m})
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (x, A_{1} union ..A_{_a}.. union A_{m})
#     core type: ExprTuple
#     sub-expressions: 30, 17
# 15. or
#     core type: Literal
#     sub-expressions:
# 16. (x in A_{1}, ..x in A_{i}.., x in A_{m})
#     core type: ExprTuple
#     sub-expressions: 18
# 17. A_{1} union ..A_{_a}.. union A_{m}
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. (x in A_{1}), ..(x in A_{i}).., (x in A_{m})
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 25
#     end_index: 26
# 19. union
#     core type: Literal
#     sub-expressions:
# 20. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 22
# 21. i -> (x in A_{i})
#     core type: Lambda
#     parameter: 36
#     body: 23
# 22. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 25
#     end_index: 26
# 23. x in A_{i}
#     core type: Operation
#     operator: 27
#     operands: 28
# 24. _a -> A_{_a}
#     core type: Lambda
#     parameter: 35
#     body: 29
# 25. 1
#     core type: Literal
#     sub-expressions:
# 26. m
#     core type: Variable
#     sub-expressions:
# 27. in
#     core type: Literal
#     sub-expressions:
# 28. (x, A_{i})
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 29. A_{_a}
#     core type: IndexedVar
# variable: 33
# index: 35
# 30. x
#     core type: Variable
#     sub-expressions:
# 31. A_{i}
#     core type: IndexedVar
# variable: 33
# index: 36
# 32. (_a)
#     core type: ExprTuple
#     sub-expressions: 35
# 33. A
#     core type: Variable
#     sub-expressions:
# 34. (i)
#     core type: ExprTuple
#     sub-expressions: 36
# 35. _a
#     core type: Variable
#     sub-expressions:
# 36. i
#     core type: Variable
#     sub-expressions:
