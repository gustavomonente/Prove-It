# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.NotInSet.html">NotInSet</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.unification</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import x
from proveit.core_expr_types import A_1_to_m
from proveit.logic import NotInSet, Union

# %%
# build up the expression from sub-expressions
expr = NotInSet(x, Union(A_1_to_m))
# Out:
# expr: x not-in (A_{1} union ..A_{_a}.. union A_{m})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# x \notin \left(A_{1} \cup \ldots \cup A_{m}\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. x not-in (A_{1} union ..A_{_a}.. union A_{m})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. not-in
#    core type: Literal
#    sub-expressions:
# 2. (x, A_{1} union ..A_{_a}.. union A_{m})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. x
#    core type: Variable
#    sub-expressions:
# 4. A_{1} union ..A_{_a}.. union A_{m}
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. union
#    core type: Literal
#    sub-expressions:
# 6. (A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 7
# 7. A_{1}, ..A_{_a}.., A_{m}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 10
# 8. _a -> A_{_a}
#    core type: Lambda
#    parameter: 14
#    body: 11
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. m
#     core type: Variable
#     sub-expressions:
# 11. A_{_a}
#     core type: IndexedVar
# variable: 12
# index: 14
# 12. A
#     core type: Variable
#     sub-expressions:
# 13. (_a)
#     core type: ExprTuple
#     sub-expressions: 14
# 14. _a
#     core type: Variable
#     sub-expressions:
