# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.membership</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda, S, x
from proveit.logic import Equals, InSet, Not, NotInSet

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([x, S], Equals(NotInSet(x, S), Not(InSet(x, S)))))
# Out:
# expr: ((x, S) -> ((x not-in S) = not(x in S)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(x, S\right) \mapsto \left(\left(x \notin S\right) = (\lnot \left(x \in S\right))\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((x, S) -> ((x not-in S) = not(x in S)))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (x, S) -> ((x not-in S) = not(x in S))
#    core type: Lambda
#    parameters: 12\n   body: 2
# 2. (x not-in S) = not(x in S)
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (x not-in S, not(x in S))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. x not-in S
#    core type: Operation
#    operator: 7
#    operands: 12
# 6. not(x in S)
#    core type: Operation
#    operator: 8
#    operand: 10
# 7. not-in
#    core type: Literal
#    sub-expressions:
# 8. not
#    core type: Literal
#    sub-expressions:
# 9. (x in S)
#    core type: ExprTuple
#    sub-expressions: 10
# 10. x in S
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (x, S)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. x
#     core type: Variable
#     sub-expressions:
# 14. S
#     core type: Variable
#     sub-expressions:
