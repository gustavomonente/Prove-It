# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#general_intersectall_Ryn">general_intersectall_Ryn</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.IntersectAll.html">IntersectAll</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.logic.sets import general_intersectall_Ryn

# %%
# check that the built expression is the same as the stored expression
assert general_intersectall_Ryn == stored_expr
assert general_intersectall_Ryn._style_id == stored_expr._style_id
print("Passed sanity check: general_intersectall_Ryn matches stored_expr")
# Out:
# Passed sanity check: general_intersectall_Ryn matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(general_intersectall_Ryn.latex())
# Out:
# \bigcap_{y_{1} \in S_{1}, \ldots, y_{n} \in S_{n}~|~Q(y_{1}, \ldots, y_{n})}~R(y_{1}, \ldots, y_{n})

# %%
general_intersectall_Ryn.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
general_intersectall_Ryn.expr_info()
# Out:
# 0. intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. intersect_all
#    core type: Literal
#    sub-expressions:
# 2. ((y_{1}, ..y_{_a}.., y_{n}) -> {R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (y_{1}, ..y_{_a}.., y_{n}) -> {R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#    core type: Lambda
#    parameters: 14\n   body: 4
# 4. {R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. R(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 7
#    operands: 14
# ...
