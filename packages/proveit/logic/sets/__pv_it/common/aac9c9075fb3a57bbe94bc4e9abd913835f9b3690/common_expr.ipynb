# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#x_singletons_range">x_singletons_range</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.logic.sets import x_singletons_range

# %%
# check that the built expression is the same as the stored expression
assert x_singletons_range == stored_expr
assert x_singletons_range._style_id == stored_expr._style_id
print("Passed sanity check: x_singletons_range matches stored_expr")
# Out:
# Passed sanity check: x_singletons_range matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(x_singletons_range.latex())
# Out:
# \left\{x_{1}\right\}, \ldots, \left\{x_{n}\right\}

# %%
x_singletons_range.style_options()
# Out:
# style name: parameterization
# description: 'implicit' (default for LaTeX formatting) hides the parameter the ExprRange so the parameterization may be ambiguous (e.g., x_{1+1}, ..., x_{n+1}); 'explicit' (default for string formatting) reveals the parameterization (e.g. x_{1+1}, ..x_{k+1}.., x_{n+1}).
# default: None
# current value: None/False
# related methods: ('with_explicit_parameterization', 'with_implicit_parameterization', 'with_default_parameterization_style')

# %%
# display the expression information
x_singletons_range.expr_info()
# Out:
# 0. {x_{1}}, ..{x_{i}}.., {x_{n}}
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. i -> {x_{i}}
#    core type: Lambda
#    parameter: 10
#    body: 4
# 2. 1
#    core type: Literal
#    sub-expressions:
# 3. n
#    core type: Variable
#    sub-expressions:
# 4. {x_{i}}
#    core type: Operation
#    operator: 5
#    operand: 7
# 5. Set
#    core type: Literal
#    sub-expressions:
# 6. (x_{i})
#    core type: ExprTuple
#    sub-expressions: 7
# 7. x_{i}
#    core type: IndexedVar
# variable: 8
# index: 10
# 8. x
#    core type: Variable
#    sub-expressions:
# 9. (i)
#    core type: ExprTuple
#    sub-expressions: 10
# 10. i
#     core type: Variable
#     sub-expressions:
