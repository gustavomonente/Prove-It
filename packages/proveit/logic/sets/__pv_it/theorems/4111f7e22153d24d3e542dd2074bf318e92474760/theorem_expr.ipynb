# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#union_with_superset_is_superset">union_with_superset_is_superset</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.sets import union_with_superset_is_superset

# %%
# check that the built expression is the same as the stored expression
assert union_with_superset_is_superset.expr == stored_expr
assert union_with_superset_is_superset.expr._style_id == stored_expr._style_id
print("Passed sanity check: union_with_superset_is_superset matches stored_expr")
# Out:
# Passed sanity check: union_with_superset_is_superset matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(union_with_superset_is_superset.latex())
# Out:
# \vdash \forall_{A, S~|~A \subseteq S}~\left(\left(A \cup S\right) \cong S\right)

# %%
union_with_superset_is_superset.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
union_with_superset_is_superset.expr_info()
# Out:
# 0. forall_{A, S | A subset_eq S} ((A union S) equiv S)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((A, S) -> {(A union S) equiv S if A subset_eq S.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (A, S) -> {(A union S) equiv S if A subset_eq S.
#    core type: Lambda
#    parameters: 12\n   body: 4
# 4. {(A union S) equiv S if A subset_eq S.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (A union S) equiv S
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. A subset_eq S
#    core type: Operation
#    operator: 9
#    operands: 12
# 7. equiv
#    core type: Literal
#    sub-expressions:
# 8. (A union S, S)
#    core type: ExprTuple
#    sub-expressions: 10, 14
# 9. subset_eq
#    core type: Literal
#    sub-expressions:
# 10. A union S
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. union
#     core type: Literal
#     sub-expressions:
# ...
