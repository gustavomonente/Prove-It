# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, ExprTuple, Lambda, x
from proveit.logic import Boolean, Forall, InSet, SubsetEq, Union

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([A, B], Conditional(SubsetEq(A, Union(A, B)), Forall([x], InSet(InSet(x, B), Boolean)))))
# Out:
# expr: ((A, B) -> {A subset_eq (A union B) if forall_{x} ((x in B) in BOOLEAN).)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(A, B\right) \mapsto \left\{A \subseteq \left(A \cup B\right) \textrm{ if } \forall_{x}~\left(\left(x \in B\right) \in \mathbb{B}\right)\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((A, B) -> {A subset_eq (A union B) if forall_{x} ((x in B) in BOOLEAN).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (A, B) -> {A subset_eq (A union B) if forall_{x} ((x in B) in BOOLEAN).
#    core type: Lambda
#    parameters: 12\n   body: 2
# 2. {A subset_eq (A union B) if forall_{x} ((x in B) in BOOLEAN).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. A subset_eq (A union B)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. forall_{x} ((x in B) in BOOLEAN)
#    core type: Operation
#    operator: 7
#    operand: 10
# 5. subset_eq
#    core type: Literal
#    sub-expressions:
# 6. (A, A union B)
#    core type: ExprTuple
#    sub-expressions: 14, 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. (x -> ((x in B) in BOOLEAN))
#    core type: ExprTuple
#    sub-expressions: 10
# 9. A union B
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. x -> ((x in B) in BOOLEAN)
#     core type: Lambda
#     parameter: 20
#     body: 13
# 11. union
#     core type: Literal
#     sub-expressions:
# 12. (A, B)
#     core type: ExprTuple
#     sub-expressions: 14, 21
# 13. (x in B) in BOOLEAN
#     core type: Operation
#     operator: 18
#     operands: 15
# 14. A
#     core type: Variable
#     sub-expressions:
# 15. (x in B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. x in B
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (x, B)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 20. x
#     core type: Variable
#     sub-expressions:
# 21. B
#     core type: Variable
#     sub-expressions:
