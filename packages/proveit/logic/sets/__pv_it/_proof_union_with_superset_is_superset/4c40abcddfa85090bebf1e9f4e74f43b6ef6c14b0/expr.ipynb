# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, ExprTuple, Lambda, S, x
from proveit.logic import InSet, Union

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(x, Conditional(InSet(x, Union(A, S)), InSet(x, S))))
# Out:
# expr: (x -> {x in (A union S) if x in S.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \mapsto \left\{x \in \left(A \cup S\right) \textrm{ if } x \in S\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x -> {x in (A union S) if x in S.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. x -> {x in (A union S) if x in S.
#    core type: Lambda
#    parameter: 9
#    body: 2
# 2. {x in (A union S) if x in S.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. x in (A union S)
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. x in S
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (x, A union S)
#    core type: ExprTuple
#    sub-expressions: 9, 8
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (x, S)
#    core type: ExprTuple
#    sub-expressions: 9, 13
# 8. A union S
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. x
#    core type: Variable
#    sub-expressions:
# 10. union
#     core type: Literal
#     sub-expressions:
# 11. (A, S)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. A
#     core type: Variable
#     sub-expressions:
# 13. S
#     core type: Variable
#     sub-expressions:
