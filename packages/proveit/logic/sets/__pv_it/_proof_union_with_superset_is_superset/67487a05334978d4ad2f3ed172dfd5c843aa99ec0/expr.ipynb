# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, S, x
from proveit.logic import InSet, Union

# %%
# build up the expression from sub-expressions
expr = Conditional(InSet(x, S), InSet(x, Union(A, S)))
# Out:
# expr: {x in S if x in (A union S).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{x \in S \textrm{ if } x \in \left(A \cup S\right)\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {x in S if x in (A union S).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. x in S
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. x in (A union S)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (x, S)
#    core type: ExprTuple
#    sub-expressions: 6, 11
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (x, A union S)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. x
#    core type: Variable
#    sub-expressions:
# 7. A union S
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. union
#    core type: Literal
#    sub-expressions:
# 9. (A, S)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. A
#     core type: Variable
#     sub-expressions:
# 11. S
#     core type: Variable
#     sub-expressions:
