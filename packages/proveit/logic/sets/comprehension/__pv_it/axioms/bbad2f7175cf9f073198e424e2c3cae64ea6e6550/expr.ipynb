# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.comprehension</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import x
from proveit.logic import InSet
from proveit.logic.sets import general_comprehension_fyn

# %%
# build up the expression from sub-expressions
expr = InSet(x, general_comprehension_fyn)
# Out:
# expr: x in {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# x \in \left\{f(y_{1}, \ldots, y_{n})~|~Q(y_{1}, \ldots, y_{n})\right\}_{y_{1} \in S_{1}, \ldots, y_{n} \in S_{n}}

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. x in {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}
#    core type: Operation
#    operator: 20
#    operands: 1
# 1. (x, {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}})
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. x
#    core type: Variable
#    sub-expressions:
# 3. {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}
#    core type: Operation
#    operator: 4
#    operand: 6
# 4. SetOfAll
#    core type: Literal
#    sub-expressions:
# 5. ((y_{1}, ..y_{_a}.., y_{n}) -> {f(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).)
#    core type: ExprTuple
#    sub-expressions: 6
# 6. (y_{1}, ..y_{_a}.., y_{n}) -> {f(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#    core type: Lambda
#    parameters: 17\n   body: 7
# 7. {f(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. f(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 10
#    operands: 17
# 9. (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n}) and Q(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. f
#     core type: Variable
#     sub-expressions:
# 11. and
#     core type: Literal
#     sub-expressions:
# 12. (y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}, Q(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. (y_{1} in S_{1}), ..(y_{_a} in S_{_a}).., (y_{n} in S_{n})
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 23
#     end_index: 24
# 14. Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. _a -> (y_{_a} in S_{_a})
#     core type: Lambda
#     parameter: 30
#     body: 18
# 16. Q
#     core type: Variable
#     sub-expressions:
# 17. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 19
# 18. y_{_a} in S_{_a}
#     core type: Operation
#     operator: 20
#     operands: 21
# 19. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 23
#     end_index: 24
# 20. in
#     core type: Literal
#     sub-expressions:
# 21. (y_{_a}, S_{_a})
#     core type: ExprTuple
#     sub-expressions: 26, 25
# 22. _a -> y_{_a}
#     core type: Lambda
#     parameter: 30
#     body: 26
# 23. 1
#     core type: Literal
#     sub-expressions:
# 24. n
#     core type: Variable
#     sub-expressions:
# 25. S_{_a}
#     core type: IndexedVar
# variable: 27
# index: 30
# 26. y_{_a}
#     core type: IndexedVar
# variable: 28
# index: 30
# 27. S
#     core type: Variable
#     sub-expressions:
# 28. y
#     core type: Variable
#     sub-expressions:
# 29. (_a)
#     core type: ExprTuple
#     sub-expressions: 30
# 30. _a
#     core type: Variable
#     sub-expressions:
