# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.comprehension</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, Q, f, x
from proveit.core_expr_types import Q__y_1_to_n, S_1_to_n, f__y_1_to_n, y_1_to_n
from proveit.logic import Equals, Exists, InSet
from proveit.logic.sets import general_comprehension_fyn

# %%
# build up the expression from sub-expressions
expr = Lambda([S_1_to_n, Q, f, x], Equals(InSet(x, general_comprehension_fyn), Exists([y_1_to_n], Equals(x, f__y_1_to_n), domains = [S_1_to_n], condition = Q__y_1_to_n)).with_wrapping_at(1))
# Out:
# expr: (S_{1}, ..S_{_a}.., S_{n}, Q, f, x) -> ((x in {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x = f(y_{1}, ..y_{_a}.., y_{n}))])

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(S_{1}, \ldots, S_{n}, Q, f, x\right) \mapsto \left(\begin{array}{c} \begin{array}{l} \left(x \in \left\{f(y_{1}, \ldots, y_{n})~|~Q(y_{1}, \ldots, y_{n})\right\}_{y_{1} \in S_{1}, \ldots, y_{n} \in S_{n}}\right) \\  = \left[\exists_{y_{1} \in S_{1}, \ldots, y_{n} \in S_{n}~|~Q(y_{1}, \ldots, y_{n})}~\left(x = f(y_{1}, \ldots, y_{n})\right)\right] \end{array} \end{array}\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (S_{1}, ..S_{_a}.., S_{n}, Q, f, x) -> ((x in {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x = f(y_{1}, ..y_{_a}.., y_{n}))])
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (S_{1}, ..S_{_a}.., S_{n}, Q, f, x)
#    core type: ExprTuple
#    sub-expressions: 3, 30, 26, 22
# 2. (x in {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x = f(y_{1}, ..y_{_a}.., y_{n}))]
#    core type: Operation
#    operator: 19
#    operands: 4
# 3. S_{1}, ..S_{_a}.., S_{n}
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 37
#    end_index: 38
# 4. (x in {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}, exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x = f(y_{1}, ..y_{_a}.., y_{n})))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. _a -> S_{_a}
#    core type: Lambda
#    parameter: 44
#    body: 39
# 6. x in {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}
#    core type: Operation
#    operator: 34
#    operands: 8
# 7. exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x = f(y_{1}, ..y_{_a}.., y_{n}))
#    core type: Operation
#    operator: 9
#    operand: 12
# 8. (x, {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}})
#    core type: ExprTuple
#    sub-expressions: 22, 11
# 9. exists
#    core type: Literal
#    sub-expressions:
# 10. ((y_{1}, ..y_{_a}.., y_{n}) -> {x = f(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}
#     core type: Operation
#     operator: 13
#     operand: 16
# 12. (y_{1}, ..y_{_a}.., y_{n}) -> {x = f(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 31\n    body: 15
# 13. SetOfAll
#     core type: Literal
#     sub-expressions:
# 14. ((y_{1}, ..y_{_a}.., y_{n}) -> {f(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. {x = f(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 17
#     condition: 21
# 16. (y_{1}, ..y_{_a}.., y_{n}) -> {f(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 31\n    body: 18
# 17. x = f(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. {f(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 23
#     condition: 21
# 19. =
#     core type: Literal
#     sub-expressions:
# 20. (x, f(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 21. (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n}) and Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 24
#     operands: 25
# 22. x
#     core type: Variable
#     sub-expressions:
# 23. f(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 26
#     operands: 31
# 24. and
#     core type: Literal
#     sub-expressions:
# 25. (y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}, Q(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 26. f
#     core type: Variable
#     sub-expressions:
# 27. (y_{1} in S_{1}), ..(y_{_a} in S_{_a}).., (y_{n} in S_{n})
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 37
#     end_index: 38
# 28. Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 30
#     operands: 31
# 29. _a -> (y_{_a} in S_{_a})
#     core type: Lambda
#     parameter: 44
#     body: 32
# 30. Q
#     core type: Variable
#     sub-expressions:
# 31. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 33
# 32. y_{_a} in S_{_a}
#     core type: Operation
#     operator: 34
#     operands: 35
# 33. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 37
#     end_index: 38
# 34. in
#     core type: Literal
#     sub-expressions:
# 35. (y_{_a}, S_{_a})
#     core type: ExprTuple
#     sub-expressions: 40, 39
# 36. _a -> y_{_a}
#     core type: Lambda
#     parameter: 44
#     body: 40
# 37. 1
#     core type: Literal
#     sub-expressions:
# 38. n
#     core type: Variable
#     sub-expressions:
# 39. S_{_a}
#     core type: IndexedVar
# variable: 41
# index: 44
# 40. y_{_a}
#     core type: IndexedVar
# variable: 42
# index: 44
# 41. S
#     core type: Variable
#     sub-expressions:
# 42. y
#     core type: Variable
#     sub-expressions:
# 43. (_a)
#     core type: ExprTuple
#     sub-expressions: 44
# 44. _a
#     core type: Variable
#     sub-expressions:
