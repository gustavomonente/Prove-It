# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.comprehension</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, Q, f, n, x
from proveit.core_expr_types import Q__y_1_to_n, S_1_to_n, f__y_1_to_n, y_1_to_n
from proveit.logic import Equals, Exists, Forall, InSet
from proveit.logic.sets import general_comprehension_fyn
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(n, Conditional(Forall([S_1_to_n, Q, f, x], Equals(InSet(x, general_comprehension_fyn), Exists([y_1_to_n], Equals(x, f__y_1_to_n), domains = [S_1_to_n], condition = Q__y_1_to_n)).with_wrapping_at(1)), InSet(n, NaturalPos))))
# Out:
# expr: (n -> {forall_{S_{1}, ..S_{_a}.., S_{n}, Q, f, x} ((x in {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x = f(y_{1}, ..y_{_a}.., y_{n}))]) if n in NaturalPos.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(n \mapsto \left\{\forall_{S_{1}, \ldots, S_{n}, Q, f, x}~\left(\begin{array}{c} \begin{array}{l} \left(x \in \left\{f(y_{1}, \ldots, y_{n})~|~Q(y_{1}, \ldots, y_{n})\right\}_{y_{1} \in S_{1}, \ldots, y_{n} \in S_{n}}\right) \\  = \left[\exists_{y_{1} \in S_{1}, \ldots, y_{n} \in S_{n}~|~Q(y_{1}, \ldots, y_{n})}~\left(x = f(y_{1}, \ldots, y_{n})\right)\right] \end{array} \end{array}\right) \textrm{ if } n \in \mathbb{N}^+\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (n -> {forall_{S_{1}, ..S_{_a}.., S_{n}, Q, f, x} ((x in {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x = f(y_{1}, ..y_{_a}.., y_{n}))]) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. n -> {forall_{S_{1}, ..S_{_a}.., S_{n}, Q, f, x} ((x in {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x = f(y_{1}, ..y_{_a}.., y_{n}))]) if n in NaturalPos.
#    core type: Lambda
#    parameter: 47
#    body: 2
# 2. {forall_{S_{1}, ..S_{_a}.., S_{n}, Q, f, x} ((x in {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x = f(y_{1}, ..y_{_a}.., y_{n}))]) if n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{S_{1}, ..S_{_a}.., S_{n}, Q, f, x} ((x in {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x = f(y_{1}, ..y_{_a}.., y_{n}))])
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. n in NaturalPos
#    core type: Operation
#    operator: 43
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((S_{1}, ..S_{_a}.., S_{n}, Q, f, x) -> ((x in {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x = f(y_{1}, ..y_{_a}.., y_{n}))]))
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 47, 9
# 8. (S_{1}, ..S_{_a}.., S_{n}, Q, f, x) -> ((x in {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x = f(y_{1}, ..y_{_a}.., y_{n}))])
#    core type: Lambda
#    parameters: 10\n   body: 11
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. (S_{1}, ..S_{_a}.., S_{n}, Q, f, x)
#     core type: ExprTuple
#     sub-expressions: 12, 39, 35, 31
# 11. (x in {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x = f(y_{1}, ..y_{_a}.., y_{n}))]
#     core type: Operation
#     operator: 28
#     operands: 13
# 12. S_{1}, ..S_{_a}.., S_{n}
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 46
#     end_index: 47
# 13. (x in {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}, exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x = f(y_{1}, ..y_{_a}.., y_{n})))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. _a -> S_{_a}
#     core type: Lambda
#     parameter: 53
#     body: 48
# 15. x in {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}
#     core type: Operation
#     operator: 43
#     operands: 17
# 16. exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x = f(y_{1}, ..y_{_a}.., y_{n}))
#     core type: Operation
#     operator: 18
#     operand: 21
# 17. (x, {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}})
#     core type: ExprTuple
#     sub-expressions: 31, 20
# 18. exists
#     core type: Literal
#     sub-expressions:
# 19. ((y_{1}, ..y_{_a}.., y_{n}) -> {x = f(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 21
# 20. {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}
#     core type: Operation
#     operator: 22
#     operand: 25
# 21. (y_{1}, ..y_{_a}.., y_{n}) -> {x = f(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 40\n    body: 24
# 22. SetOfAll
#     core type: Literal
#     sub-expressions:
# 23. ((y_{1}, ..y_{_a}.., y_{n}) -> {f(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 25
# 24. {x = f(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 26
#     condition: 30
# 25. (y_{1}, ..y_{_a}.., y_{n}) -> {f(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 40\n    body: 27
# 26. x = f(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 28
#     operands: 29
# 27. {f(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 32
#     condition: 30
# 28. =
#     core type: Literal
#     sub-expressions:
# 29. (x, f(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 30. (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n}) and Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. x
#     core type: Variable
#     sub-expressions:
# 32. f(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 35
#     operands: 40
# 33. and
#     core type: Literal
#     sub-expressions:
# 34. (y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}, Q(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 35. f
#     core type: Variable
#     sub-expressions:
# 36. (y_{1} in S_{1}), ..(y_{_a} in S_{_a}).., (y_{n} in S_{n})
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 46
#     end_index: 47
# 37. Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 39
#     operands: 40
# 38. _a -> (y_{_a} in S_{_a})
#     core type: Lambda
#     parameter: 53
#     body: 41
# 39. Q
#     core type: Variable
#     sub-expressions:
# 40. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 42
# 41. y_{_a} in S_{_a}
#     core type: Operation
#     operator: 43
#     operands: 44
# 42. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 46
#     end_index: 47
# 43. in
#     core type: Literal
#     sub-expressions:
# 44. (y_{_a}, S_{_a})
#     core type: ExprTuple
#     sub-expressions: 49, 48
# 45. _a -> y_{_a}
#     core type: Lambda
#     parameter: 53
#     body: 49
# 46. 1
#     core type: Literal
#     sub-expressions:
# 47. n
#     core type: Variable
#     sub-expressions:
# 48. S_{_a}
#     core type: IndexedVar
# variable: 50
# index: 53
# 49. y_{_a}
#     core type: IndexedVar
# variable: 51
# index: 53
# 50. S
#     core type: Variable
#     sub-expressions:
# 51. y
#     core type: Variable
#     sub-expressions:
# 52. (_a)
#     core type: ExprTuple
#     sub-expressions: 53
# 53. _a
#     core type: Variable
#     sub-expressions:
