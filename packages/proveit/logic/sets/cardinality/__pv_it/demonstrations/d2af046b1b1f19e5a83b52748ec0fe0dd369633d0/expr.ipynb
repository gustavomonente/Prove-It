# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.cardinality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, N, S
from proveit.core_expr_types import Len, x_1_to_n
from proveit.logic import Card, Distinct, Equals, Exists
from proveit.numbers import LessEq

# %%
# build up the expression from sub-expressions
sub_expr1 = [x_1_to_n]
expr = Lambda([S, N], Conditional(Exists(sub_expr1, Distinct(x_1_to_n), domains = [S], condition = Equals(Len(sub_expr1), N)), LessEq(N, Card(S))))
# Out:
# expr: (S, N) -> {exists_{x_{1}, ..x_{_a}.., x_{n} in S | |(x_{1}, ..x_{_a}.., x_{n})| = N} distinct(x_{1}, ..x_{_a}.., x_{n}) if N <= |S|.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(S, N\right) \mapsto \left\{\exists_{x_{1}, \ldots, x_{n} \in S~|~|\left(x_{1}, \ldots, x_{n}\right)| = N}~\textrm{distinct}(x_{1}, \ldots, x_{n}) \textrm{ if } N \leq |S|\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (S, N) -> {exists_{x_{1}, ..x_{_a}.., x_{n} in S | |(x_{1}, ..x_{_a}.., x_{n})| = N} distinct(x_{1}, ..x_{_a}.., x_{n}) if N <= |S|.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (S, N)
#    core type: ExprTuple
#    sub-expressions: 31, 26
# 2. {exists_{x_{1}, ..x_{_a}.., x_{n} in S | |(x_{1}, ..x_{_a}.., x_{n})| = N} distinct(x_{1}, ..x_{_a}.., x_{n}) if N <= |S|.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. exists_{x_{1}, ..x_{_a}.., x_{n} in S | |(x_{1}, ..x_{_a}.., x_{n})| = N} distinct(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 5
#    operand: 9
# 4. N <= |S|
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. exists
#    core type: Literal
#    sub-expressions:
# 6. ((x_{1}, ..x_{_a}.., x_{n}) -> {distinct(x_{1}, ..x_{_a}.., x_{n}) if x_{1} in S ,  ..x_{_a} in S.. ,  x_{n} in S ,  |(x_{1}, ..x_{_a}.., x_{n})| = N.)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. <=
#    core type: Literal
# ...
