# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#QimplPofFalse">QimplPofFalse</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.logic import QimplPofFalse

# %%
# check that the built expression is the same as the stored expression
assert QimplPofFalse == stored_expr
assert QimplPofFalse._style_id == stored_expr._style_id
print("Passed sanity check: QimplPofFalse matches stored_expr")
# Out:
# Passed sanity check: QimplPofFalse matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(QimplPofFalse.latex())
# Out:
# Q(\bot) \Rightarrow P(\bot)

# %%
QimplPofFalse.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
QimplPofFalse.expr_info()
# Out:
# 0. Q(FALSE) => P(FALSE)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (Q(FALSE), P(FALSE))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. Q(FALSE)
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. P(FALSE)
#    core type: Operation
#    operator: 6
#    operand: 8
# 5. Q
#    core type: Variable
#    sub-expressions:
# 6. P
#    core type: Variable
#    sub-expressions:
# 7. (FALSE)
#    core type: ExprTuple
#    sub-expressions: 8
# 8. FALSE
#    core type: Literal
#    sub-expressions:
