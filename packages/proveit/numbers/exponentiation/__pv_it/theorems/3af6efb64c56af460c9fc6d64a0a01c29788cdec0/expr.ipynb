# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, m
from proveit.core_expr_types import b_1_to_m
from proveit.logic import Equals, Forall, InSet, NotEquals
from proveit.numbers import Add, Complex, Exp, NaturalPos, Real, zero
from proveit.numbers.exponentiation import prod_a_raise_bi__1_to_m

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([a, b_1_to_m], Equals(prod_a_raise_bi__1_to_m, Exp(a, Add(b_1_to_m))), domains = [Complex, Real], condition = NotEquals(a, zero)), InSet(m, NaturalPos))
# Out:
# expr: {forall_{a in Complex, b_{1} in Real, ..b_{_a} in Real.., b_{m} in Real | a != 0} ((a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}}) if m in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{a \in \mathbb{C}, b_{1} \in \mathbb{R}, \ldots, b_{m} \in \mathbb{R}~|~a \neq 0}~\left(\left(a^{b_{1}} \cdot \ldots \cdot a^{b_{m}}\right) = a^{b_{1} + \ldots + b_{m}}\right) \textrm{ if } m \in \mathbb{N}^+\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{a in Complex, b_{1} in Real, ..b_{_a} in Real.., b_{m} in Real | a != 0} ((a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}}) if m in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{a in Complex, b_{1} in Real, ..b_{_a} in Real.., b_{m} in Real | a != 0} ((a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}})
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. m in NaturalPos
#    core type: Operation
#    operator: 36
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((a, b_{1}, ..b_{_a}.., b_{m}) -> {(a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}} if a in Complex ,  b_{1} in Real ,  ..b_{_a} in Real.. ,  b_{m} in Real ,  a != 0.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (m, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 45, 7
# 6. (a, b_{1}, ..b_{_a}.., b_{m}) -> {(a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}} if a in Complex ,  b_{1} in Real ,  ..b_{_a} in Real.. ,  b_{m} in Real ,  a != 0.
#    core type: Lambda
#    parameters: 8\n   body: 9
# 7. NaturalPos
#    core type: Literal
#    sub-expressions:
# 8. (a, b_{1}, ..b_{_a}.., b_{m})
#    core type: ExprTuple
#    sub-expressions: 46, 39
# 9. {(a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}} if a in Complex ,  b_{1} in Real ,  ..b_{_a} in Real.. ,  b_{m} in Real ,  a != 0.
#    core type: Conditional
#    value: 10
#    condition: 11
# 10. (a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}}
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (a in Complex) and (b_{1} in Real) and ..(b_{_a} in Real).. and (b_{m} in Real) and (a != 0)
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. =
#     core type: Literal
#     sub-expressions:
# 13. (a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}, a^{b_{1} + ..b_{_a}.. + b_{m}})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. and
#     core type: Literal
#     sub-expressions:
# 15. (a in Complex, b_{1} in Real, ..b_{_a} in Real.., b_{m} in Real, a != 0)
#     core type: ExprTuple
#     sub-expressions: 18, 19, 20
# 16. a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}
#     core type: Operation
#     operator: 21
#     operands: 22
# 17. a^{b_{1} + ..b_{_a}.. + b_{m}}
#     core type: Operation
#     operator: 41
#     operands: 23
# 18. a in Complex
#     core type: Operation
#     operator: 36
#     operands: 24
# 19. (b_{1} in Real), ..(b_{_a} in Real).., (b_{m} in Real)
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 44
#     end_index: 45
# 20. a != 0
#     core type: Operation
#     operator: 26
#     operands: 27
# 21. *
#     core type: Literal
#     sub-expressions:
# 22. (a^{b_{1}}, ..a^{b_{i}}.., a^{b_{m}})
#     core type: ExprTuple
#     sub-expressions: 28
# 23. (a, b_{1} + ..b_{_a}.. + b_{m})
#     core type: ExprTuple
#     sub-expressions: 46, 29
# 24. (a, Complex)
#     core type: ExprTuple
#     sub-expressions: 46, 30
# 25. _a -> (b_{_a} in Real)
#     core type: Lambda
#     parameter: 53
#     body: 31
# 26. !=
#     core type: Literal
#     sub-expressions:
# 27. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 46, 32
# 28. a^{b_{1}}, ..a^{b_{i}}.., a^{b_{m}}
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 44
#     end_index: 45
# 29. b_{1} + ..b_{_a}.. + b_{m}
#     core type: Operation
#     operator: 34
#     operands: 35
# 30. Complex
#     core type: Literal
#     sub-expressions:
# 31. b_{_a} in Real
#     core type: Operation
#     operator: 36
#     operands: 37
# 32. 0
#     core type: Literal
#     sub-expressions:
# 33. i -> a^{b_{i}}
#     core type: Lambda
#     parameter: 52
#     body: 38
# 34. +
#     core type: Literal
#     sub-expressions:
# 35. (b_{1}, ..b_{_a}.., b_{m})
#     core type: ExprTuple
#     sub-expressions: 39
# 36. in
#     core type: Literal
#     sub-expressions:
# 37. (b_{_a}, Real)
#     core type: ExprTuple
#     sub-expressions: 48, 40
# 38. a^{b_{i}}
#     core type: Operation
#     operator: 41
#     operands: 42
# 39. b_{1}, ..b_{_a}.., b_{m}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 44
#     end_index: 45
# 40. Real
#     core type: Literal
#     sub-expressions:
# 41. Exp
#     core type: Literal
#     sub-expressions:
# 42. (a, b_{i})
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 43. _a -> b_{_a}
#     core type: Lambda
#     parameter: 53
#     body: 48
# 44. 1
#     core type: Literal
#     sub-expressions:
# 45. m
#     core type: Variable
#     sub-expressions:
# 46. a
#     core type: Variable
#     sub-expressions:
# 47. b_{i}
#     core type: IndexedVar
# variable: 50
# index: 52
# 48. b_{_a}
#     core type: IndexedVar
# variable: 50
# index: 53
# 49. (i)
#     core type: ExprTuple
#     sub-expressions: 52
# 50. b
#     core type: Variable
#     sub-expressions:
# 51. (_a)
#     core type: ExprTuple
#     sub-expressions: 53
# 52. i
#     core type: Variable
#     sub-expressions:
# 53. _a
#     core type: Variable
#     sub-expressions:
