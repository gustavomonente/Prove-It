# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#exp_nonpos_lesseq">exp_nonpos_lesseq</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.exponentiation import exp_nonpos_lesseq

# %%
# check that the built expression is the same as the stored expression
assert exp_nonpos_lesseq.expr == stored_expr
assert exp_nonpos_lesseq.expr._style_id == stored_expr._style_id
print("Passed sanity check: exp_nonpos_lesseq matches stored_expr")
# Out:
# Passed sanity check: exp_nonpos_lesseq matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(exp_nonpos_lesseq.latex())
# Out:
# \vdash \forall_{a, x, y \in \mathbb{R}~|~0 < x \leq y, a \leq 0}~\left(y^{a} \leq x^{a}\right)

# %%
exp_nonpos_lesseq.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
exp_nonpos_lesseq.expr_info()
# Out:
# 0. forall_{a, x, y in Real | 0 < x <= y, a <= 0} (y^{a} <= x^{a})
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, x, y) -> {y^{a} <= x^{a} if a in Real ,  x in Real ,  y in Real ,  0 < x <= y ,  a <= 0.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, x, y) -> {y^{a} <= x^{a} if a in Real ,  x in Real ,  y in Real ,  0 < x <= y ,  a <= 0.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a, x, y)
#    core type: ExprTuple
#    sub-expressions: 30, 36, 37
# 5. {y^{a} <= x^{a} if a in Real ,  x in Real ,  y in Real ,  0 < x <= y ,  a <= 0.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. y^{a} <= x^{a}
#    core type: Operation
#    operator: 33
#    operands: 8
# 7. (a in Real) and (x in Real) and (y in Real) and (0 < x <= y) and (a <= 0)
#    core type: Operation
#    operator: 24
#    operands: 9
# 8. (y^{a}, x^{a})
#    core type: ExprTuple
# ...
