# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#sqrt_of_prod">sqrt_of_prod</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.exponentiation import sqrt_of_prod

# %%
# check that the built expression is the same as the stored expression
assert sqrt_of_prod.expr == stored_expr
assert sqrt_of_prod.expr._style_id == stored_expr._style_id
print("Passed sanity check: sqrt_of_prod matches stored_expr")
# Out:
# Passed sanity check: sqrt_of_prod matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(sqrt_of_prod.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{a_{1}, \ldots, a_{n} \in \mathbb{C}}~\left(\sqrt{\left(a_{1} \cdot \ldots \cdot a_{n}\right)} = \left(\sqrt{\left(a_{1}\right)} \cdot \ldots \cdot \sqrt{\left(a_{n}\right)}\right)\right)\right]

# %%
sqrt_of_prod.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
sqrt_of_prod.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{a_{1}, ..a_{_a}.., a_{n} in Complex} (sqrt((a_{1} * ..a_{_a}.. * a_{n})) = (sqrt((a_{1})) * ..sqrt((a_{i})).. * sqrt((a_{n}))))]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (n -> {forall_{a_{1}, ..a_{_a}.., a_{n} in Complex} (sqrt((a_{1} * ..a_{_a}.. * a_{n})) = (sqrt((a_{1})) * ..sqrt((a_{i})).. * sqrt((a_{n})))) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{a_{1}, ..a_{_a}.., a_{n} in Complex} (sqrt((a_{1} * ..a_{_a}.. * a_{n})) = (sqrt((a_{1})) * ..sqrt((a_{i})).. * sqrt((a_{n})))) if n in NaturalPos.
#    core type: Lambda
#    parameter: 36
#    body: 3
# 3. {forall_{a_{1}, ..a_{_a}.., a_{n} in Complex} (sqrt((a_{1} * ..a_{_a}.. * a_{n})) = (sqrt((a_{1})) * ..sqrt((a_{i})).. * sqrt((a_{n})))) if n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{a_{1}, ..a_{_a}.., a_{n} in Complex} (sqrt((a_{1} * ..a_{_a}.. * a_{n})) = (sqrt((a_{1})) * ..sqrt((a_{i})).. * sqrt((a_{n}))))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. n in NaturalPos
#    core type: Operation
#    operator: 30
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((a_{1}, ..a_{_a}.., a_{n}) -> {sqrt((a_{1} * ..a_{_a}.. * a_{n})) = (sqrt((a_{1})) * ..sqrt((a_{i})).. * sqrt((a_{n}))) if (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{n} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 36, 10
# 9. (a_{1}, ..a_{_a}.., a_{n}) -> {sqrt((a_{1} * ..a_{_a}.. * a_{n})) = (sqrt((a_{1})) * ..sqrt((a_{i})).. * sqrt((a_{n}))) if (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{n} in Complex).
#    core type: Lambda
#    parameters: 28\n   body: 11
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. {sqrt((a_{1} * ..a_{_a}.. * a_{n})) = (sqrt((a_{1})) * ..sqrt((a_{i})).. * sqrt((a_{n}))) if (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{n} in Complex).
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. sqrt((a_{1} * ..a_{_a}.. * a_{n})) = (sqrt((a_{1})) * ..sqrt((a_{i})).. * sqrt((a_{n})))
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{n} in Complex)
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. =
#     core type: Literal
#     sub-expressions:
# 15. (sqrt((a_{1} * ..a_{_a}.. * a_{n})), sqrt((a_{1})) * ..sqrt((a_{i})).. * sqrt((a_{n})))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. and
#     core type: Literal
#     sub-expressions:
# 17. (a_{1} in Complex, ..a_{_a} in Complex.., a_{n} in Complex)
#     core type: ExprTuple
#     sub-expressions: 20
# 18. sqrt((a_{1} * ..a_{_a}.. * a_{n}))
#     core type: Operation
#     operator: 37
#     operands: 21
# 19. sqrt((a_{1})) * ..sqrt((a_{i})).. * sqrt((a_{n}))
#     core type: Operation
#     operator: 27
#     operands: 22
# 20. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 49
#     end_index: 36
# 21. (a_{1} * ..a_{_a}.. * a_{n}, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 24, 41
# 22. (sqrt((a_{1})), ..sqrt((a_{i})).., sqrt((a_{n})))
#     core type: ExprTuple
#     sub-expressions: 25
# 23. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 47
#     body: 26
# 24. a_{1} * ..a_{_a}.. * a_{n}
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. sqrt((a_{1})), ..sqrt((a_{i})).., sqrt((a_{n}))
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 49
#     end_index: 36
# 26. a_{_a} in Complex
#     core type: Operation
#     operator: 30
#     operands: 31
# 27. *
#     core type: Literal
#     sub-expressions:
# 28. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 32
# 29. i -> sqrt((a_{i}))
#     core type: Lambda
#     parameter: 48
#     body: 33
# 30. in
#     core type: Literal
#     sub-expressions:
# 31. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 39, 34
# 32. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 49
#     end_index: 36
# 33. sqrt((a_{i}))
#     core type: Operation
#     operator: 37
#     operands: 38
# 34. Complex
#     core type: Literal
#     sub-expressions:
# 35. _a -> a_{_a}
#     core type: Lambda
#     parameter: 47
#     body: 39
# 36. n
#     core type: Variable
#     sub-expressions:
# 37. Exp
#     core type: Literal
#     sub-expressions:
# 38. (a_{i}, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 39. a_{_a}
#     core type: IndexedVar
# variable: 43
# index: 47
# 40. a_{i}
#     core type: IndexedVar
# variable: 43
# index: 48
# 41. 1 / 2
#     core type: Operation
#     operator: 45
#     operands: 46
# 42. (_a)
#     core type: ExprTuple
#     sub-expressions: 47
# 43. a
#     core type: Variable
#     sub-expressions:
# 44. (i)
#     core type: ExprTuple
#     sub-expressions: 48
# 45. /
#     core type: Literal
#     sub-expressions:
# 46. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 47. _a
#     core type: Variable
#     sub-expressions:
# 48. i
#     core type: Variable
#     sub-expressions:
# 49. 1
#     core type: Literal
#     sub-expressions:
# 50. 2
#     core type: Literal
#     sub-expressions:
