# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#products_of_complex_powers">products_of_complex_powers</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.exponentiation import products_of_complex_powers

# %%
# check that the built expression is the same as the stored expression
assert products_of_complex_powers.expr == stored_expr
assert products_of_complex_powers.expr._style_id == stored_expr._style_id
print("Passed sanity check: products_of_complex_powers matches stored_expr")
# Out:
# Passed sanity check: products_of_complex_powers matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(products_of_complex_powers.latex())
# Out:
# \vdash \forall_{m \in \mathbb{N}^+}~\left[\forall_{a \in \mathbb{R}^+, b_{1} \in \mathbb{C}, \ldots, b_{m} \in \mathbb{C}}~\left(\left(a^{b_{1}} \cdot \ldots \cdot a^{b_{m}}\right) = a^{b_{1} + \ldots + b_{m}}\right)\right]

# %%
products_of_complex_powers.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
products_of_complex_powers.expr_info()
# Out:
# 0. forall_{m in NaturalPos} [forall_{a in RealPos, b_{1} in Complex, ..b_{_a} in Complex.., b_{m} in Complex} ((a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}})]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (m -> {forall_{a in RealPos, b_{1} in Complex, ..b_{_a} in Complex.., b_{m} in Complex} ((a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}}) if m in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. m -> {forall_{a in RealPos, b_{1} in Complex, ..b_{_a} in Complex.., b_{m} in Complex} ((a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}}) if m in NaturalPos.
#    core type: Lambda
#    parameter: 44
#    body: 3
# 3. {forall_{a in RealPos, b_{1} in Complex, ..b_{_a} in Complex.., b_{m} in Complex} ((a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}}) if m in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# ...
