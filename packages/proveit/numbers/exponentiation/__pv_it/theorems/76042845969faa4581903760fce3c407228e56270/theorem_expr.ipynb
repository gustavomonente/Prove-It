# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#exp_complex_closure">exp_complex_closure</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.exponentiation import exp_complex_closure

# %%
# check that the built expression is the same as the stored expression
assert exp_complex_closure.expr == stored_expr
assert exp_complex_closure.expr._style_id == stored_expr._style_id
print("Passed sanity check: exp_complex_closure matches stored_expr")
# Out:
# Passed sanity check: exp_complex_closure matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(exp_complex_closure.latex())
# Out:
# \vdash \forall_{a, b \in \mathbb{C}~|~\left(a \neq 0\right) \lor \left(b \neq 0\right)}~\left(a^{b} \in \mathbb{C}\right)

# %%
exp_complex_closure.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
exp_complex_closure.expr_info()
# Out:
# 0. forall_{a, b in Complex | (a != 0) or (b != 0)} (a^{b} in Complex)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b) -> {a^{b} in Complex if a in Complex ,  b in Complex ,  (a != 0) or (b != 0).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b) -> {a^{b} in Complex if a in Complex ,  b in Complex ,  (a != 0) or (b != 0).
#    core type: Lambda
#    parameters: 15\n   body: 4
# 4. {a^{b} in Complex if a in Complex ,  b in Complex ,  (a != 0) or (b != 0).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. a^{b} in Complex
#    core type: Operation
#    operator: 17
#    operands: 7
# 6. (a in Complex) and (b in Complex) and ((a != 0) or (b != 0))
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a^{b}, Complex)
#    core type: ExprTuple
#    sub-expressions: 10, 21
# 8. and
#    core type: Literal
#    sub-expressions:
# ...
