# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, x
from proveit.logic import Equals, InSet
from proveit.numbers import Exp, Real, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(x, Conditional(Equals(Exp(x, one), x), InSet(x, Real))))
# Out:
# expr: (x -> {x^{1} = x if x in Real.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \mapsto \left\{x^{1} = x \textrm{ if } x \in \mathbb{R}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x -> {x^{1} = x if x in Real.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. x -> {x^{1} = x if x in Real.
#    core type: Lambda
#    parameter: 13
#    body: 2
# 2. {x^{1} = x if x in Real.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. x^{1} = x
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. x in Real
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (x^{1}, x)
#    core type: ExprTuple
#    sub-expressions: 9, 13
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (x, Real)
#    core type: ExprTuple
#    sub-expressions: 13, 10
# 9. x^{1}
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. Real
#     core type: Literal
#     sub-expressions:
# 11. Exp
#     core type: Literal
#     sub-expressions:
# 12. (x, 1)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. x
#     core type: Variable
#     sub-expressions:
# 14. 1
#     core type: Literal
#     sub-expressions:
