# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#exp_not_eq_zero">exp_not_eq_zero</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.exponentiation import exp_not_eq_zero

# %%
# check that the built expression is the same as the stored expression
assert exp_not_eq_zero.expr == stored_expr
assert exp_not_eq_zero.expr._style_id == stored_expr._style_id
print("Passed sanity check: exp_not_eq_zero matches stored_expr")
# Out:
# Passed sanity check: exp_not_eq_zero matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(exp_not_eq_zero.latex())
# Out:
# \vdash \forall_{a, b \in \mathbb{C}~|~a \neq 0}~\left(a^{b} \neq 0\right)

# %%
exp_not_eq_zero.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
exp_not_eq_zero.expr_info()
# Out:
# 0. forall_{a, b in Complex | a != 0} (a^{b} != 0)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b) -> {a^{b} != 0 if a in Complex ,  b in Complex ,  a != 0.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b) -> {a^{b} != 0 if a in Complex ,  b in Complex ,  a != 0.
#    core type: Lambda
#    parameters: 15\n   body: 4
# 4. {a^{b} != 0 if a in Complex ,  b in Complex ,  a != 0.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. a^{b} != 0
#    core type: Operation
#    operator: 19
#    operands: 7
# 6. (a in Complex) and (b in Complex) and (a != 0)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a^{b}, 0)
#    core type: ExprTuple
#    sub-expressions: 10, 24
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Complex, b in Complex, a != 0)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 10. a^{b}
#     core type: Operation
# ...
