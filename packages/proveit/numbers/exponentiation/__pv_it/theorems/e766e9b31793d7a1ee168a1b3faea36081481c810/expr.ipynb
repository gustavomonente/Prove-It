# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, m, n
from proveit.logic import Equals, Forall, NotEquals
from proveit.numbers import Add, Complex, Exp, NaturalPos, Neg, frac, zero

# %%
# build up the expression from sub-expressions
expr = Forall([a, m, n], Equals(frac(Exp(a, m), Exp(a, n)), Exp(a, Add(m, Neg(n)))), domains = [Complex, NaturalPos, NaturalPos], condition = NotEquals(a, zero))
# Out:
# expr: forall_{a in Complex, m in NaturalPos, n in NaturalPos | a != 0} ((a^{m} / a^{n}) = a^{m - n})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a \in \mathbb{C}, m \in \mathbb{N}^+, n \in \mathbb{N}^+~|~a \neq 0}~\left(\frac{a^{m}}{a^{n}} = a^{m - n}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a in Complex, m in NaturalPos, n in NaturalPos | a != 0} ((a^{m} / a^{n}) = a^{m - n})
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, m, n) -> {(a^{m} / a^{n}) = a^{m - n} if a in Complex ,  m in NaturalPos ,  n in NaturalPos ,  a != 0.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, m, n) -> {(a^{m} / a^{n}) = a^{m - n} if a in Complex ,  m in NaturalPos ,  n in NaturalPos ,  a != 0.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a, m, n)
#    core type: ExprTuple
#    sub-expressions: 38, 39, 43
# 5. {(a^{m} / a^{n}) = a^{m - n} if a in Complex ,  m in NaturalPos ,  n in NaturalPos ,  a != 0.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (a^{m} / a^{n}) = a^{m - n}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a in Complex) and (m in NaturalPos) and (n in NaturalPos) and (a != 0)
#    core type: Operation
#    operator: 10
# ...
