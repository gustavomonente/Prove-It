# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, n, x
from proveit.logic import And, Equals, InSet
from proveit.numbers import Exp, NaturalPos, RealPos, frac, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([n, x], Conditional(Equals(Exp(Exp(x, frac(one, n)), n), x), And(InSet(n, NaturalPos), InSet(x, RealPos)))))
# Out:
# expr: ((n, x) -> {(x^{1 / n})^{n} = x if n in NaturalPos ,  x in RealPos.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(n, x\right) \mapsto \left\{(x^{\frac{1}{n}})^{n} = x \textrm{ if } n \in \mathbb{N}^+ ,  x \in \mathbb{R}^+\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((n, x) -> {(x^{1 / n})^{n} = x if n in NaturalPos ,  x in RealPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (n, x) -> {(x^{1 / n})^{n} = x if n in NaturalPos ,  x in RealPos.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (n, x)
#    core type: ExprTuple
#    sub-expressions: 27, 22
# 3. {(x^{1 / n})^{n} = x if n in NaturalPos ,  x in RealPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (x^{1 / n})^{n} = x
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (n in NaturalPos) and (x in RealPos)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. ((x^{1 / n})^{n}, x)
#    core type: ExprTuple
#    sub-expressions: 10, 22
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (n in NaturalPos, x in RealPos)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. (x^{1 / n})^{n}
#     core type: Operation
#     operator: 20
#     operands: 13
# ...
