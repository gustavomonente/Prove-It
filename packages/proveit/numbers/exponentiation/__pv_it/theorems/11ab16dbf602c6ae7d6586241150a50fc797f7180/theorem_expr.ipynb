# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#real_power_of_product">real_power_of_product</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.exponentiation import real_power_of_product

# %%
# check that the built expression is the same as the stored expression
assert real_power_of_product.expr == stored_expr
assert real_power_of_product.expr._style_id == stored_expr._style_id
print("Passed sanity check: real_power_of_product matches stored_expr")
# Out:
# Passed sanity check: real_power_of_product matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(real_power_of_product.latex())
# Out:
# \vdash \forall_{a \in \mathbb{C}, b \in \mathbb{C}, c \in \mathbb{R}~|~a \neq 0, b \neq 0}~\left(\left(a \cdot b\right)^{c} = \left(a^{c} \cdot b^{c}\right)\right)

# %%
real_power_of_product.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
real_power_of_product.expr_info()
# Out:
# 0. forall_{a in Complex, b in Complex, c in Real | a != 0, b != 0} ((a * b)^{c} = (a^{c} * b^{c}))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b, c) -> {(a * b)^{c} = (a^{c} * b^{c}) if a in Complex ,  b in Complex ,  c in Real ,  a != 0 ,  b != 0.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b, c) -> {(a * b)^{c} = (a^{c} * b^{c}) if a in Complex ,  b in Complex ,  c in Real ,  a != 0 ,  b != 0.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 39, 40, 41
# 5. {(a * b)^{c} = (a^{c} * b^{c}) if a in Complex ,  b in Complex ,  c in Real ,  a != 0 ,  b != 0.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (a * b)^{c} = (a^{c} * b^{c})
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a in Complex) and (b in Complex) and (c in Real) and (a != 0) and (b != 0)
#    core type: Operation
# ...
