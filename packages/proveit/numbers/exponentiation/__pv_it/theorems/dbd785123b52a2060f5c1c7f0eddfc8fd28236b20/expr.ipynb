# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a, b
from proveit.logic import And, InSet
from proveit.numbers import Exp, Natural, NaturalPos

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([a, b], Conditional(InSet(Exp(a, b), NaturalPos), And(InSet(a, NaturalPos), InSet(b, Natural)))))
# Out:
# expr: ((a, b) -> {a^{b} in NaturalPos if a in NaturalPos ,  b in Natural.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a, b\right) \mapsto \left\{a^{b} \in \mathbb{N}^+ \textrm{ if } a \in \mathbb{N}^+ ,  b \in \mathbb{N}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a, b) -> {a^{b} in NaturalPos if a in NaturalPos ,  b in Natural.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a, b) -> {a^{b} in NaturalPos if a in NaturalPos ,  b in Natural.
#    core type: Lambda
#    parameters: 12\n   body: 2
# 2. {a^{b} in NaturalPos if a in NaturalPos ,  b in Natural.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. a^{b} in NaturalPos
#    core type: Operation
#    operator: 14
#    operands: 5
# 4. (a in NaturalPos) and (b in Natural)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a^{b}, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 8, 17
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a in NaturalPos, b in Natural)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. a^{b}
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. a in NaturalPos
#    core type: Operation
#    operator: 14
#    operands: 13
# 10. b in Natural
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. Exp
#     core type: Literal
#     sub-expressions:
# 12. (a, b)
#     core type: ExprTuple
#     sub-expressions: 16, 18
# 13. (a, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (b, Natural)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. NaturalPos
#     core type: Literal
#     sub-expressions:
# 18. b
#     core type: Variable
#     sub-expressions:
# 19. Natural
#     core type: Literal
#     sub-expressions:
