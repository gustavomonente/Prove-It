# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c
from proveit.logic import Equals, Forall
from proveit.numbers import Complex, Exp, Mult, RealPos

# %%
# build up the expression from sub-expressions
expr = Forall([a, b, c], Equals(Exp(Exp(a, b), c), Exp(a, Mult(b, c))), domains = [RealPos, Complex, Complex])
# Out:
# expr: forall_{a in RealPos, b in Complex, c in Complex} ((a^{b})^{c} = a^{b * c})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a \in \mathbb{R}^+, b \in \mathbb{C}, c \in \mathbb{C}}~\left((a^{b})^{c} = a^{b \cdot c}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a in RealPos, b in Complex, c in Complex} ((a^{b})^{c} = a^{b * c})
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b, c) -> {(a^{b})^{c} = a^{b * c} if a in RealPos ,  b in Complex ,  c in Complex.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b, c) -> {(a^{b})^{c} = a^{b * c} if a in RealPos ,  b in Complex ,  c in Complex.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 31, 32, 33
# 5. {(a^{b})^{c} = a^{b * c} if a in RealPos ,  b in Complex ,  c in Complex.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (a^{b})^{c} = a^{b * c}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a in RealPos) and (b in Complex) and (c in Complex)
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. ((a^{b})^{c}, a^{b * c})
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (a in RealPos, b in Complex, c in Complex)
#     core type: ExprTuple
#     sub-expressions: 14, 15, 16
# 12. (a^{b})^{c}
#     core type: Operation
#     operator: 27
#     operands: 17
# 13. a^{b * c}
#     core type: Operation
#     operator: 27
#     operands: 18
# 14. a in RealPos
#     core type: Operation
#     operator: 21
#     operands: 19
# 15. b in Complex
#     core type: Operation
#     operator: 21
#     operands: 20
# 16. c in Complex
#     core type: Operation
#     operator: 21
#     operands: 22
# 17. (a^{b}, c)
#     core type: ExprTuple
#     sub-expressions: 23, 33
# 18. (a, b * c)
#     core type: ExprTuple
#     sub-expressions: 31, 24
# 19. (a, RealPos)
#     core type: ExprTuple
#     sub-expressions: 31, 25
# 20. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 32, 26
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (c, Complex)
#     core type: ExprTuple
#     sub-expressions: 33, 26
# 23. a^{b}
#     core type: Operation
#     operator: 27
#     operands: 28
# 24. b * c
#     core type: Operation
#     operator: 29
#     operands: 30
# 25. RealPos
#     core type: Literal
#     sub-expressions:
# 26. Complex
#     core type: Literal
#     sub-expressions:
# 27. Exp
#     core type: Literal
#     sub-expressions:
# 28. (a, b)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. *
#     core type: Literal
#     sub-expressions:
# 30. (b, c)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 31. a
#     core type: Variable
#     sub-expressions:
# 32. b
#     core type: Variable
#     sub-expressions:
# 33. c
#     core type: Variable
#     sub-expressions:
