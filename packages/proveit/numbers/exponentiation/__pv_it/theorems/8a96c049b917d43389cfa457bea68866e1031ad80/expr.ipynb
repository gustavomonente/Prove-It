# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a
from proveit.logic import And, Equals, InSet, NotEquals
from proveit.numbers import Complex, Exp, one, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(a, Conditional(Equals(Exp(a, zero), one), And(InSet(a, Complex), NotEquals(a, zero)))))
# Out:
# expr: (a -> {a^{0} = 1 if a in Complex ,  a != 0.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \mapsto \left\{a^{0} = 1 \textrm{ if } a \in \mathbb{C} ,  a \neq 0\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a -> {a^{0} = 1 if a in Complex ,  a != 0.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. a -> {a^{0} = 1 if a in Complex ,  a != 0.
#    core type: Lambda
#    parameter: 19
#    body: 2
# 2. {a^{0} = 1 if a in Complex ,  a != 0.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. a^{0} = 1
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a in Complex) and (a != 0)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (a^{0}, 1)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Complex, a != 0)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. a^{0}
#    core type: Operation
#    operator: 13
#    operands: 17
# 10. 1
#     core type: Literal
#     sub-expressions:
# 11. a in Complex
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. a != 0
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. Exp
#     core type: Literal
#     sub-expressions:
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (a, Complex)
#     core type: ExprTuple
#     sub-expressions: 19, 18
# 16. !=
#     core type: Literal
#     sub-expressions:
# 17. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. Complex
#     core type: Literal
#     sub-expressions:
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. 0
#     core type: Literal
#     sub-expressions:
