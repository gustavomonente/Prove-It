# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, x, y
from proveit.logic import And, InSet
from proveit.numbers import Exp, Less, LessEq, Real, greater_eq, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(LessEq(Exp(x, a), Exp(y, a)), And(InSet(a, Real), InSet(x, Real), InSet(y, Real), And(Less(zero, x), Less(x, y)).with_total_ordering_style(), greater_eq(a, zero)))
# Out:
# expr: {x^{a} <= y^{a} if a in Real ,  x in Real ,  y in Real ,  0 < x < y ,  a >= 0.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{x^{a} \leq y^{a} \textrm{ if } a \in \mathbb{R} ,  x \in \mathbb{R} ,  y \in \mathbb{R} ,  0 < x < y ,  a \geq 0\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {x^{a} <= y^{a} if a in Real ,  x in Real ,  y in Real ,  0 < x < y ,  a >= 0.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. x^{a} <= y^{a}
#    core type: Operation
#    operator: 21
#    operands: 3
# 2. (a in Real) and (x in Real) and (y in Real) and (0 < x < y) and (a >= 0)
#    core type: Operation
#    operator: 19
#    operands: 4
# 3. (x^{a}, y^{a})
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. (a in Real, x in Real, y in Real, 0 < x < y, a >= 0)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 10, 11
# 5. x^{a}
#    core type: Operation
#    operator: 13
#    operands: 12
# 6. y^{a}
#    core type: Operation
#    operator: 13
#    operands: 14
# 7. a in Real
#    core type: Operation
#    operator: 17
#    operands: 15
# 8. x in Real
#    core type: Operation
#    operator: 17
#    operands: 16
# 9. y in Real
#    core type: Operation
#    operator: 17
#    operands: 18
# 10. 0 < x < y
#     core type: Operation
#     operator: 19
# ...
