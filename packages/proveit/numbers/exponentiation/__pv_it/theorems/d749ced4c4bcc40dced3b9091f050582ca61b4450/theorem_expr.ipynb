# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#products_of_posnat_powers">products_of_posnat_powers</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.exponentiation import products_of_posnat_powers

# %%
# check that the built expression is the same as the stored expression
assert products_of_posnat_powers.expr == stored_expr
assert products_of_posnat_powers.expr._style_id == stored_expr._style_id
print("Passed sanity check: products_of_posnat_powers matches stored_expr")
# Out:
# Passed sanity check: products_of_posnat_powers matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(products_of_posnat_powers.latex())
# Out:
# \vdash \forall_{m \in \mathbb{N}^+}~\left[\forall_{a \in \mathbb{C}, k_{1} \in \mathbb{N}^+, \ldots, k_{m} \in \mathbb{N}^+}~\left(\left(a^{k_{1}} \cdot \ldots \cdot a^{k_{m}}\right) = a^{k_{1} + \ldots + k_{m}}\right)\right]

# %%
products_of_posnat_powers.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
products_of_posnat_powers.expr_info()
# Out:
# 0. forall_{m in NaturalPos} [forall_{a in Complex, k_{1} in NaturalPos, ..k_{_a} in NaturalPos.., k_{m} in NaturalPos} ((a^{k_{1}} * ..a^{k_{i}}.. * a^{k_{m}}) = a^{k_{1} + ..k_{_a}.. + k_{m}})]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (m -> {forall_{a in Complex, k_{1} in NaturalPos, ..k_{_a} in NaturalPos.., k_{m} in NaturalPos} ((a^{k_{1}} * ..a^{k_{i}}.. * a^{k_{m}}) = a^{k_{1} + ..k_{_a}.. + k_{m}}) if m in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. m -> {forall_{a in Complex, k_{1} in NaturalPos, ..k_{_a} in NaturalPos.., k_{m} in NaturalPos} ((a^{k_{1}} * ..a^{k_{i}}.. * a^{k_{m}}) = a^{k_{1} + ..k_{_a}.. + k_{m}}) if m in NaturalPos.
#    core type: Lambda
#    parameter: 43
#    body: 3
# 3. {forall_{a in Complex, k_{1} in NaturalPos, ..k_{_a} in NaturalPos.., k_{m} in NaturalPos} ((a^{k_{1}} * ..a^{k_{i}}.. * a^{k_{m}}) = a^{k_{1} + ..k_{_a}.. + k_{m}}) if m in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{a in Complex, k_{1} in NaturalPos, ..k_{_a} in NaturalPos.., k_{m} in NaturalPos} ((a^{k_{1}} * ..a^{k_{i}}.. * a^{k_{m}}) = a^{k_{1} + ..k_{_a}.. + k_{m}})
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. m in NaturalPos
#    core type: Operation
#    operator: 34
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((a, k_{1}, ..k_{_a}.., k_{m}) -> {(a^{k_{1}} * ..a^{k_{i}}.. * a^{k_{m}}) = a^{k_{1} + ..k_{_a}.. + k_{m}} if a in Complex ,  k_{1} in NaturalPos ,  ..k_{_a} in NaturalPos.. ,  k_{m} in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (m, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 43, 38
# 9. (a, k_{1}, ..k_{_a}.., k_{m}) -> {(a^{k_{1}} * ..a^{k_{i}}.. * a^{k_{m}}) = a^{k_{1} + ..k_{_a}.. + k_{m}} if a in Complex ,  k_{1} in NaturalPos ,  ..k_{_a} in NaturalPos.. ,  k_{m} in NaturalPos.
#    core type: Lambda
#    parameters: 10\n   body: 11
# 10. (a, k_{1}, ..k_{_a}.., k_{m})
#     core type: ExprTuple
#     sub-expressions: 44, 37
# 11. {(a^{k_{1}} * ..a^{k_{i}}.. * a^{k_{m}}) = a^{k_{1} + ..k_{_a}.. + k_{m}} if a in Complex ,  k_{1} in NaturalPos ,  ..k_{_a} in NaturalPos.. ,  k_{m} in NaturalPos.
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. (a^{k_{1}} * ..a^{k_{i}}.. * a^{k_{m}}) = a^{k_{1} + ..k_{_a}.. + k_{m}}
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (a in Complex) and (k_{1} in NaturalPos) and ..(k_{_a} in NaturalPos).. and (k_{m} in NaturalPos)
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. =
#     core type: Literal
#     sub-expressions:
# 15. (a^{k_{1}} * ..a^{k_{i}}.. * a^{k_{m}}, a^{k_{1} + ..k_{_a}.. + k_{m}})
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. and
#     core type: Literal
#     sub-expressions:
# 17. (a in Complex, k_{1} in NaturalPos, ..k_{_a} in NaturalPos.., k_{m} in NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. a^{k_{1}} * ..a^{k_{i}}.. * a^{k_{m}}
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. a^{k_{1} + ..k_{_a}.. + k_{m}}
#     core type: Operation
#     operator: 39
#     operands: 24
# 20. a in Complex
#     core type: Operation
#     operator: 34
#     operands: 25
# 21. (k_{1} in NaturalPos), ..(k_{_a} in NaturalPos).., (k_{m} in NaturalPos)
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 42
#     end_index: 43
# 22. *
#     core type: Literal
#     sub-expressions:
# 23. (a^{k_{1}}, ..a^{k_{i}}.., a^{k_{m}})
#     core type: ExprTuple
#     sub-expressions: 27
# 24. (a, k_{1} + ..k_{_a}.. + k_{m})
#     core type: ExprTuple
#     sub-expressions: 44, 28
# 25. (a, Complex)
#     core type: ExprTuple
#     sub-expressions: 44, 29
# 26. _a -> (k_{_a} in NaturalPos)
#     core type: Lambda
#     parameter: 51
#     body: 30
# 27. a^{k_{1}}, ..a^{k_{i}}.., a^{k_{m}}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 42
#     end_index: 43
# 28. k_{1} + ..k_{_a}.. + k_{m}
#     core type: Operation
#     operator: 32
#     operands: 33
# 29. Complex
#     core type: Literal
#     sub-expressions:
# 30. k_{_a} in NaturalPos
#     core type: Operation
#     operator: 34
#     operands: 35
# 31. i -> a^{k_{i}}
#     core type: Lambda
#     parameter: 50
#     body: 36
# 32. +
#     core type: Literal
#     sub-expressions:
# 33. (k_{1}, ..k_{_a}.., k_{m})
#     core type: ExprTuple
#     sub-expressions: 37
# 34. in
#     core type: Literal
#     sub-expressions:
# 35. (k_{_a}, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 46, 38
# 36. a^{k_{i}}
#     core type: Operation
#     operator: 39
#     operands: 40
# 37. k_{1}, ..k_{_a}.., k_{m}
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 42
#     end_index: 43
# 38. NaturalPos
#     core type: Literal
#     sub-expressions:
# 39. Exp
#     core type: Literal
#     sub-expressions:
# 40. (a, k_{i})
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 41. _a -> k_{_a}
#     core type: Lambda
#     parameter: 51
#     body: 46
# 42. 1
#     core type: Literal
#     sub-expressions:
# 43. m
#     core type: Variable
#     sub-expressions:
# 44. a
#     core type: Variable
#     sub-expressions:
# 45. k_{i}
#     core type: IndexedVar
# variable: 48
# index: 50
# 46. k_{_a}
#     core type: IndexedVar
# variable: 48
# index: 51
# 47. (i)
#     core type: ExprTuple
#     sub-expressions: 50
# 48. k
#     core type: Variable
#     sub-expressions:
# 49. (_a)
#     core type: ExprTuple
#     sub-expressions: 51
# 50. i
#     core type: Variable
#     sub-expressions:
# 51. _a
#     core type: Variable
#     sub-expressions:
