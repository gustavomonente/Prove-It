# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, b, m
from proveit.core_expr_types import a_1_to_m
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Complex, Exp, Mult, NaturalPos, RealPos
from proveit.numbers.exponentiation import prod_ai_raise_b__1_to_m

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(m, Conditional(Forall([a_1_to_m, b], Equals(Exp(Mult(a_1_to_m), b), prod_ai_raise_b__1_to_m), domains = [RealPos, Complex]), InSet(m, NaturalPos))))
# Out:
# expr: (m -> {forall_{a_{1} in RealPos, ..a_{_a} in RealPos.., a_{m} in RealPos, b in Complex} ((a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})) if m in NaturalPos.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(m \mapsto \left\{\forall_{a_{1} \in \mathbb{R}^+, \ldots, a_{m} \in \mathbb{R}^+, b \in \mathbb{C}}~\left(\left(a_{1} \cdot \ldots \cdot a_{m}\right)^{b} = \left(\left(a_{1}\right)^{b} \cdot \ldots \cdot \left(a_{m}\right)^{b}\right)\right) \textrm{ if } m \in \mathbb{N}^+\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (m -> {forall_{a_{1} in RealPos, ..a_{_a} in RealPos.., a_{m} in RealPos, b in Complex} ((a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})) if m in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. m -> {forall_{a_{1} in RealPos, ..a_{_a} in RealPos.., a_{m} in RealPos, b in Complex} ((a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})) if m in NaturalPos.
#    core type: Lambda
#    parameter: 40
#    body: 2
# 2. {forall_{a_{1} in RealPos, ..a_{_a} in RealPos.., a_{m} in RealPos, b in Complex} ((a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})) if m in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1} in RealPos, ..a_{_a} in RealPos.., a_{m} in RealPos, b in Complex} ((a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. m in NaturalPos
#    core type: Operation
#    operator: 33
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((a_{1}, ..a_{_a}.., a_{m}, b) -> {(a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}) if a_{1} in RealPos ,  ..a_{_a} in RealPos.. ,  a_{m} in RealPos ,  b in Complex.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (m, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 40, 9
# 8. (a_{1}, ..a_{_a}.., a_{m}, b) -> {(a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}) if a_{1} in RealPos ,  ..a_{_a} in RealPos.. ,  a_{m} in RealPos ,  b in Complex.
#    core type: Lambda
#    parameters: 10\n   body: 11
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. (a_{1}, ..a_{_a}.., a_{m}, b)
#     core type: ExprTuple
#     sub-expressions: 35, 45
# 11. {(a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}) if a_{1} in RealPos ,  ..a_{_a} in RealPos.. ,  a_{m} in RealPos ,  b in Complex.
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. (a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (a_{1} in RealPos) and ..(a_{_a} in RealPos).. and (a_{m} in RealPos) and (b in Complex)
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. =
#     core type: Literal
#     sub-expressions:
# 15. ((a_{1} * ..a_{_a}.. * a_{m})^{b}, (a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. and
#     core type: Literal
#     sub-expressions:
# 17. (a_{1} in RealPos, ..a_{_a} in RealPos.., a_{m} in RealPos, b in Complex)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. (a_{1} * ..a_{_a}.. * a_{m})^{b}
#     core type: Operation
#     operator: 41
#     operands: 22
# 19. (a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}
#     core type: Operation
#     operator: 30
#     operands: 23
# 20. (a_{1} in RealPos), ..(a_{_a} in RealPos).., (a_{m} in RealPos)
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 39
#     end_index: 40
# 21. b in Complex
#     core type: Operation
#     operator: 33
#     operands: 25
# 22. (a_{1} * ..a_{_a}.. * a_{m}, b)
#     core type: ExprTuple
#     sub-expressions: 26, 45
# 23. ((a_{1})^{b}, ..(a_{i})^{b}.., (a_{m})^{b})
#     core type: ExprTuple
#     sub-expressions: 27
# 24. _a -> (a_{_a} in RealPos)
#     core type: Lambda
#     parameter: 49
#     body: 28
# 25. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 45, 29
# 26. a_{1} * ..a_{_a}.. * a_{m}
#     core type: Operation
#     operator: 30
#     operands: 31
# 27. (a_{1})^{b}, ..(a_{i})^{b}.., (a_{m})^{b}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 39
#     end_index: 40
# 28. a_{_a} in RealPos
#     core type: Operation
#     operator: 33
#     operands: 34
# 29. Complex
#     core type: Literal
#     sub-expressions:
# 30. *
#     core type: Literal
#     sub-expressions:
# 31. (a_{1}, ..a_{_a}.., a_{m})
#     core type: ExprTuple
#     sub-expressions: 35
# 32. i -> (a_{i})^{b}
#     core type: Lambda
#     parameter: 50
#     body: 36
# 33. in
#     core type: Literal
#     sub-expressions:
# 34. (a_{_a}, RealPos)
#     core type: ExprTuple
#     sub-expressions: 43, 37
# 35. a_{1}, ..a_{_a}.., a_{m}
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 39
#     end_index: 40
# 36. (a_{i})^{b}
#     core type: Operation
#     operator: 41
#     operands: 42
# 37. RealPos
#     core type: Literal
#     sub-expressions:
# 38. _a -> a_{_a}
#     core type: Lambda
#     parameter: 49
#     body: 43
# 39. 1
#     core type: Literal
#     sub-expressions:
# 40. m
#     core type: Variable
#     sub-expressions:
# 41. Exp
#     core type: Literal
#     sub-expressions:
# 42. (a_{i}, b)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 43. a_{_a}
#     core type: IndexedVar
# variable: 47
# index: 49
# 44. a_{i}
#     core type: IndexedVar
# variable: 47
# index: 50
# 45. b
#     core type: Variable
#     sub-expressions:
# 46. (_a)
#     core type: ExprTuple
#     sub-expressions: 49
# 47. a
#     core type: Variable
#     sub-expressions:
# 48. (i)
#     core type: ExprTuple
#     sub-expressions: 50
# 49. _a
#     core type: Variable
#     sub-expressions:
# 50. i
#     core type: Variable
#     sub-expressions:
