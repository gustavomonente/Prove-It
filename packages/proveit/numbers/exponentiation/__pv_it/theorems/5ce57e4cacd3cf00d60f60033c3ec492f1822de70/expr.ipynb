# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Lambda, Variable, a, b, i, m
from proveit.core_expr_types import a_1_to_m
from proveit.logic import And, Equals, InSet, NotEquals
from proveit.numbers import Complex, Exp, Mult, RealPos, one, zero
from proveit.numbers.exponentiation import prod_ai_raise_b__1_to_m

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Lambda([a_1_to_m, b], Conditional(Equals(Exp(Mult(a_1_to_m), b), prod_ai_raise_b__1_to_m), And(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), Complex), one, m), InSet(b, RealPos), ExprRange(i, NotEquals(IndexedVar(a, i), zero), one, m))))
# Out:
# expr: (a_{1}, ..a_{_a}.., a_{m}, b) -> {(a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{m} in Complex ,  b in RealPos ,  a_{1} != 0 ,  ..a_{i} != 0.. ,  a_{m} != 0.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1}, \ldots, a_{m}, b\right) \mapsto \left\{\left(a_{1} \cdot \ldots \cdot a_{m}\right)^{b} = \left(\left(a_{1}\right)^{b} \cdot \ldots \cdot \left(a_{m}\right)^{b}\right) \textrm{ if } a_{1} \in \mathbb{C} ,  \ldots ,  a_{m} \in \mathbb{C} ,  b \in \mathbb{R}^+ ,  a_{1} \neq 0 ,  \ldots ,  a_{m} \neq 0\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1}, ..a_{_a}.., a_{m}, b) -> {(a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{m} in Complex ,  b in RealPos ,  a_{1} != 0 ,  ..a_{i} != 0.. ,  a_{m} != 0.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a_{1}, ..a_{_a}.., a_{m}, b)
#    core type: ExprTuple
#    sub-expressions: 31, 42
# 2. {(a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{m} in Complex ,  b in RealPos ,  a_{1} != 0 ,  ..a_{i} != 0.. ,  a_{m} != 0.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{m} in Complex) and (b in RealPos) and (a_{1} != 0) and ..(a_{i} != 0).. and (a_{m} != 0)
#    core type: Operation
# ...
