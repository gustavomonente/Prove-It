# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#complex_x_to_first_power_is_x">complex_x_to_first_power_is_x</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.exponentiation import complex_x_to_first_power_is_x

# %%
# check that the built expression is the same as the stored expression
assert complex_x_to_first_power_is_x.expr == stored_expr
assert complex_x_to_first_power_is_x.expr._style_id == stored_expr._style_id
print("Passed sanity check: complex_x_to_first_power_is_x matches stored_expr")
# Out:
# Passed sanity check: complex_x_to_first_power_is_x matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(complex_x_to_first_power_is_x.latex())
# Out:
# \vdash \forall_{x \in \mathbb{C}}~\left(x^{1} = x\right)

# %%
complex_x_to_first_power_is_x.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
complex_x_to_first_power_is_x.expr_info()
# Out:
# 0. forall_{x in Complex} (x^{1} = x)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x -> {x^{1} = x if x in Complex.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. x -> {x^{1} = x if x in Complex.
#    core type: Lambda
#    parameter: 15
#    body: 4
# 4. {x^{1} = x if x in Complex.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. x^{1} = x
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. x in Complex
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (x^{1}, x)
#    core type: ExprTuple
#    sub-expressions: 11, 15
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 15, 12
# 11. x^{1}
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. Complex
#     core type: Literal
#     sub-expressions:
# 13. Exp
# ...
