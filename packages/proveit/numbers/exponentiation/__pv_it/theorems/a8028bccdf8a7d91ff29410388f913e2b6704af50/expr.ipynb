# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c
from proveit.logic import And, InSet, NotEquals
from proveit.numbers import Complex, RealPos, zero

# %%
# build up the expression from sub-expressions
expr = And(InSet(a, Complex), InSet(b, Complex), InSet(c, RealPos), NotEquals(b, zero))
# Out:
# expr: (a in Complex) and (b in Complex) and (c in RealPos) and (b != 0)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{C}\right) \land \left(b \in \mathbb{C}\right) \land \left(c \in \mathbb{R}^+\right) \land \left(b \neq 0\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a in Complex) and (b in Complex) and (c in RealPos) and (b != 0)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (a in Complex, b in Complex, c in RealPos, b != 0)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6
# 3. a in Complex
#    core type: Operation
#    operator: 9
#    operands: 7
# 4. b in Complex
#    core type: Operation
#    operator: 9
#    operands: 8
# 5. c in RealPos
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. b != 0
#    core type: Operation
#    operator: 11
#    operands: 12
# 7. (a, Complex)
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 8. (b, Complex)
#    core type: ExprTuple
#    sub-expressions: 17, 14
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (c, RealPos)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 11. !=
#     core type: Literal
#     sub-expressions:
# 12. (b, 0)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 13. a
#     core type: Variable
#     sub-expressions:
# 14. Complex
#     core type: Literal
#     sub-expressions:
# 15. c
#     core type: Variable
#     sub-expressions:
# 16. RealPos
#     core type: Literal
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
# 18. 0
#     core type: Literal
#     sub-expressions:
