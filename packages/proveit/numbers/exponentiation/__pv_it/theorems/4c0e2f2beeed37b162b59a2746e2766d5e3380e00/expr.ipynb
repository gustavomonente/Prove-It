# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b
from proveit.logic import And, InSet, NotEquals, Or
from proveit.numbers import Exp, Real, greater, greater_eq, zero

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(InSet(Exp(a, b), Real), And(InSet(a, Real), InSet(b, Real), Or(greater(a, zero), And(greater_eq(a, zero), NotEquals(b, zero))))))
# Out:
# expr: (a, b) -> {a^{b} in Real if a in Real ,  b in Real ,  (a > 0) or ((a >= 0) and (b != 0)).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{a^{b} \in \mathbb{R} \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R} ,  \left(a > 0\right) \lor \left(\left(a \geq 0\right) \land \left(b \neq 0\right)\right)\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, b) -> {a^{b} in Real if a in Real ,  b in Real ,  (a > 0) or ((a >= 0) and (b != 0)).
#    core type: Lambda
#    parameters: 11\n   body: 1
# 1. {a^{b} in Real if a in Real ,  b in Real ,  (a > 0) or ((a >= 0) and (b != 0)).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. a^{b} in Real
#    core type: Operation
#    operator: 13
#    operands: 4
# 3. (a in Real) and (b in Real) and ((a > 0) or ((a >= 0) and (b != 0)))
#    core type: Operation
#    operator: 21
#    operands: 5
# 4. (a^{b}, Real)
#    core type: ExprTuple
#    sub-expressions: 6, 17
# 5. (a in Real, b in Real, (a > 0) or ((a >= 0) and (b != 0)))
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 6. a^{b}
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. a in Real
#    core type: Operation
#    operator: 13
#    operands: 12
# 8. b in Real
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. (a > 0) or ((a >= 0) and (b != 0))
#    core type: Operation
# ...
