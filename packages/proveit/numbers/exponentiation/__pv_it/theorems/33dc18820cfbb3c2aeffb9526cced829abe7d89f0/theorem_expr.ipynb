# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#pos_power_of_products">pos_power_of_products</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.exponentiation import pos_power_of_products

# %%
# check that the built expression is the same as the stored expression
assert pos_power_of_products.expr == stored_expr
assert pos_power_of_products.expr._style_id == stored_expr._style_id
print("Passed sanity check: pos_power_of_products matches stored_expr")
# Out:
# Passed sanity check: pos_power_of_products matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(pos_power_of_products.latex())
# Out:
# \vdash \forall_{m \in \mathbb{N}^+}~\left[\forall_{a_{1} \in \mathbb{C}, \ldots, a_{m} \in \mathbb{C}, b \in \mathbb{R}^+}~\left(\left(a_{1} \cdot \ldots \cdot a_{m}\right)^{b} = \left(\left(a_{1}\right)^{b} \cdot \ldots \cdot \left(a_{m}\right)^{b}\right)\right)\right]

# %%
pos_power_of_products.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
pos_power_of_products.expr_info()
# Out:
# 0. forall_{m in NaturalPos} [forall_{a_{1} in Complex, ..a_{_a} in Complex.., a_{m} in Complex, b in RealPos} ((a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}))]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (m -> {forall_{a_{1} in Complex, ..a_{_a} in Complex.., a_{m} in Complex, b in RealPos} ((a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})) if m in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. m -> {forall_{a_{1} in Complex, ..a_{_a} in Complex.., a_{m} in Complex, b in RealPos} ((a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})) if m in NaturalPos.
#    core type: Lambda
#    parameter: 41
#    body: 3
# 3. {forall_{a_{1} in Complex, ..a_{_a} in Complex.., a_{m} in Complex, b in RealPos} ((a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})) if m in NaturalPos.
#    core type: Conditional
#    value: 4
# ...
