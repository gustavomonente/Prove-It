# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#product_of_real_powers">product_of_real_powers</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.exponentiation import product_of_real_powers

# %%
# check that the built expression is the same as the stored expression
assert product_of_real_powers.expr == stored_expr
assert product_of_real_powers.expr._style_id == stored_expr._style_id
print("Passed sanity check: product_of_real_powers matches stored_expr")
# Out:
# Passed sanity check: product_of_real_powers matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(product_of_real_powers.latex())
# Out:
# \vdash \forall_{a \in \mathbb{C}, b \in \mathbb{R}, c \in \mathbb{R}~|~a \neq 0}~\left(\left(a^{b} \cdot a^{c}\right) = a^{b + c}\right)

# %%
product_of_real_powers.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
product_of_real_powers.expr_info()
# Out:
# 0. forall_{a in Complex, b in Real, c in Real | a != 0} ((a^{b} * a^{c}) = a^{b + c})
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b, c) -> {(a^{b} * a^{c}) = a^{b + c} if a in Complex ,  b in Real ,  c in Real ,  a != 0.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b, c) -> {(a^{b} * a^{c}) = a^{b + c} if a in Complex ,  b in Real ,  c in Real ,  a != 0.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 38, 39, 40
# 5. {(a^{b} * a^{c}) = a^{b + c} if a in Complex ,  b in Real ,  c in Real ,  a != 0.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (a^{b} * a^{c}) = a^{b + c}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a in Complex) and (b in Real) and (c in Real) and (a != 0)
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. =
#    core type: Literal
# ...
