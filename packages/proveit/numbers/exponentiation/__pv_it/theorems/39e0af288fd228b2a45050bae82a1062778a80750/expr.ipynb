# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Lambda, Variable, a, k, m
from proveit.core_expr_types import k_1_to_m
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Complex, Exp, NaturalPos, one
from proveit.numbers.exponentiation import prod_a_raise_ki__1_to_m

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Lambda([a, k_1_to_m], Conditional(Equals(prod_a_raise_ki__1_to_m, Exp(a, Add(k_1_to_m))), And(InSet(a, Complex), ExprRange(sub_expr1, InSet(IndexedVar(k, sub_expr1), NaturalPos), one, m))))
# Out:
# expr: (a, k_{1}, ..k_{_a}.., k_{m}) -> {(a^{k_{1}} * ..a^{k_{i}}.. * a^{k_{m}}) = a^{k_{1} + ..k_{_a}.. + k_{m}} if a in Complex ,  k_{1} in NaturalPos ,  ..k_{_a} in NaturalPos.. ,  k_{m} in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, k_{1}, \ldots, k_{m}\right) \mapsto \left\{\left(a^{k_{1}} \cdot \ldots \cdot a^{k_{m}}\right) = a^{k_{1} + \ldots + k_{m}} \textrm{ if } a \in \mathbb{C} ,  k_{1} \in \mathbb{N}^+ ,  \ldots ,  k_{m} \in \mathbb{N}^+\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, k_{1}, ..k_{_a}.., k_{m}) -> {(a^{k_{1}} * ..a^{k_{i}}.. * a^{k_{m}}) = a^{k_{1} + ..k_{_a}.. + k_{m}} if a in Complex ,  k_{1} in NaturalPos ,  ..k_{_a} in NaturalPos.. ,  k_{m} in NaturalPos.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a, k_{1}, ..k_{_a}.., k_{m})
#    core type: ExprTuple
#    sub-expressions: 35, 28
# 2. {(a^{k_{1}} * ..a^{k_{i}}.. * a^{k_{m}}) = a^{k_{1} + ..k_{_a}.. + k_{m}} if a in Complex ,  k_{1} in NaturalPos ,  ..k_{_a} in NaturalPos.. ,  k_{m} in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (a^{k_{1}} * ..a^{k_{i}}.. * a^{k_{m}}) = a^{k_{1} + ..k_{_a}.. + k_{m}}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a in Complex) and (k_{1} in NaturalPos) and ..(k_{_a} in NaturalPos).. and (k_{m} in NaturalPos)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (a^{k_{1}} * ..a^{k_{i}}.. * a^{k_{m}}, a^{k_{1} + ..k_{_a}.. + k_{m}})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Complex, k_{1} in NaturalPos, ..k_{_a} in NaturalPos.., k_{m} in NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. a^{k_{1}} * ..a^{k_{i}}.. * a^{k_{m}}
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. a^{k_{1} + ..k_{_a}.. + k_{m}}
#     core type: Operation
#     operator: 30
#     operands: 15
# 11. a in Complex
#     core type: Operation
#     operator: 25
#     operands: 16
# 12. (k_{1} in NaturalPos), ..(k_{_a} in NaturalPos).., (k_{m} in NaturalPos)
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 33
#     end_index: 34
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (a^{k_{1}}, ..a^{k_{i}}.., a^{k_{m}})
#     core type: ExprTuple
#     sub-expressions: 18
# 15. (a, k_{1} + ..k_{_a}.. + k_{m})
#     core type: ExprTuple
#     sub-expressions: 35, 19
# 16. (a, Complex)
#     core type: ExprTuple
#     sub-expressions: 35, 20
# 17. _a -> (k_{_a} in NaturalPos)
#     core type: Lambda
#     parameter: 42
#     body: 21
# 18. a^{k_{1}}, ..a^{k_{i}}.., a^{k_{m}}
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 33
#     end_index: 34
# 19. k_{1} + ..k_{_a}.. + k_{m}
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. Complex
#     core type: Literal
#     sub-expressions:
# 21. k_{_a} in NaturalPos
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. i -> a^{k_{i}}
#     core type: Lambda
#     parameter: 41
#     body: 27
# 23. +
#     core type: Literal
#     sub-expressions:
# 24. (k_{1}, ..k_{_a}.., k_{m})
#     core type: ExprTuple
#     sub-expressions: 28
# 25. in
#     core type: Literal
#     sub-expressions:
# 26. (k_{_a}, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 37, 29
# 27. a^{k_{i}}
#     core type: Operation
#     operator: 30
#     operands: 31
# 28. k_{1}, ..k_{_a}.., k_{m}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 33
#     end_index: 34
# 29. NaturalPos
#     core type: Literal
#     sub-expressions:
# 30. Exp
#     core type: Literal
#     sub-expressions:
# 31. (a, k_{i})
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 32. _a -> k_{_a}
#     core type: Lambda
#     parameter: 42
#     body: 37
# 33. 1
#     core type: Literal
#     sub-expressions:
# 34. m
#     core type: Variable
#     sub-expressions:
# 35. a
#     core type: Variable
#     sub-expressions:
# 36. k_{i}
#     core type: IndexedVar
# variable: 39
# index: 41
# 37. k_{_a}
#     core type: IndexedVar
# variable: 39
# index: 42
# 38. (i)
#     core type: ExprTuple
#     sub-expressions: 41
# 39. k
#     core type: Variable
#     sub-expressions:
# 40. (_a)
#     core type: ExprTuple
#     sub-expressions: 42
# 41. i
#     core type: Variable
#     sub-expressions:
# 42. _a
#     core type: Variable
#     sub-expressions:
