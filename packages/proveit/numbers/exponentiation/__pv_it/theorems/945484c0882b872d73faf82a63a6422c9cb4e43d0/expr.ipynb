# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b, c
from proveit.logic import And, Equals, InSet, NotEquals
from proveit.numbers import Add, Complex, Exp, Neg, RealPos, frac, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(frac(Exp(a, b), Exp(a, c)), Exp(a, Add(b, Neg(c)))), And(InSet(a, Complex), InSet(b, RealPos), InSet(c, RealPos), NotEquals(a, zero)))
# Out:
# expr: {(a^{b} / a^{c}) = a^{b - c} if a in Complex ,  b in RealPos ,  c in RealPos ,  a != 0.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\frac{a^{b}}{a^{c}} = a^{b - c} \textrm{ if } a \in \mathbb{C} ,  b \in \mathbb{R}^+ ,  c \in \mathbb{R}^+ ,  a \neq 0\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(a^{b} / a^{c}) = a^{b - c} if a in Complex ,  b in RealPos ,  c in RealPos ,  a != 0.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a^{b} / a^{c}) = a^{b - c}
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a in Complex) and (b in RealPos) and (c in RealPos) and (a != 0)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (a^{b} / a^{c}, a^{b - c})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in Complex, b in RealPos, c in RealPos, a != 0)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 12
# 7. a^{b} / a^{c}
#    core type: Operation
#    operator: 13
#    operands: 14
# 8. a^{b - c}
#    core type: Operation
#    operator: 29
#    operands: 15
# 9. a in Complex
#    core type: Operation
#    operator: 18
#    operands: 16
# 10. b in RealPos
#     core type: Operation
#     operator: 18
# ...
