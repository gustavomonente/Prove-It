# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#neg_int_exp_of_neg_exp">neg_int_exp_of_neg_exp</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.exponentiation import neg_int_exp_of_neg_exp

# %%
# check that the built expression is the same as the stored expression
assert neg_int_exp_of_neg_exp.expr == stored_expr
assert neg_int_exp_of_neg_exp.expr._style_id == stored_expr._style_id
print("Passed sanity check: neg_int_exp_of_neg_exp matches stored_expr")
# Out:
# Passed sanity check: neg_int_exp_of_neg_exp matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(neg_int_exp_of_neg_exp.latex())
# Out:
# \vdash \forall_{n \in \mathbb{Z}}~\left[\forall_{a, b \in \mathbb{C}~|~a \neq 0}~\left((a^{-b})^{-n} = a^{b \cdot n}\right)\right]

# %%
neg_int_exp_of_neg_exp.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
neg_int_exp_of_neg_exp.expr_info()
# Out:
# 0. forall_{n in Integer} [forall_{a, b in Complex | a != 0} ((a^{-b})^{-n} = a^{b * n})]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (n -> {forall_{a, b in Complex | a != 0} ((a^{-b})^{-n} = a^{b * n}) if n in Integer.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{a, b in Complex | a != 0} ((a^{-b})^{-n} = a^{b * n}) if n in Integer.
#    core type: Lambda
#    parameter: 43
#    body: 3
# 3. {forall_{a, b in Complex | a != 0} ((a^{-b})^{-n} = a^{b * n}) if n in Integer.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{a, b in Complex | a != 0} ((a^{-b})^{-n} = a^{b * n})
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. n in Integer
#    core type: Operation
#    operator: 27
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((a, b) -> {(a^{-b})^{-n} = a^{b * n} if a in Complex ,  b in Complex ,  a != 0.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (n, Integer)
# ...
