# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#exp_real_closure">exp_real_closure</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.exponentiation import exp_real_closure

# %%
# check that the built expression is the same as the stored expression
assert exp_real_closure.expr == stored_expr
assert exp_real_closure.expr._style_id == stored_expr._style_id
print("Passed sanity check: exp_real_closure matches stored_expr")
# Out:
# Passed sanity check: exp_real_closure matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(exp_real_closure.latex())
# Out:
# \vdash \forall_{a, b \in \mathbb{R}~|~\left(a > 0\right) \lor \left(\left(a \geq 0\right) \land \left(b \neq 0\right)\right)}~\left(a^{b} \in \mathbb{R}\right)

# %%
exp_real_closure.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
exp_real_closure.expr_info()
# Out:
# 0. forall_{a, b in Real | (a > 0) or ((a >= 0) and (b != 0))} (a^{b} in Real)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b) -> {a^{b} in Real if a in Real ,  b in Real ,  (a > 0) or ((a >= 0) and (b != 0)).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b) -> {a^{b} in Real if a in Real ,  b in Real ,  (a > 0) or ((a >= 0) and (b != 0)).
#    core type: Lambda
#    parameters: 14\n   body: 4
# 4. {a^{b} in Real if a in Real ,  b in Real ,  (a > 0) or ((a >= 0) and (b != 0)).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. a^{b} in Real
#    core type: Operation
#    operator: 16
#    operands: 7
# 6. (a in Real) and (b in Real) and ((a > 0) or ((a >= 0) and (b != 0)))
#    core type: Operation
#    operator: 24
#    operands: 8
# 7. (a^{b}, Real)
#    core type: ExprTuple
#    sub-expressions: 9, 20
# 8. (a in Real, b in Real, (a > 0) or ((a >= 0) and (b != 0)))
# ...
