# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c
from proveit.logic import And, InSet
from proveit.numbers import Complex, RealPos

# %%
# build up the expression from sub-expressions
expr = And(InSet(a, RealPos), InSet(b, Complex), InSet(c, Complex))
# Out:
# expr: (a in RealPos) and (b in Complex) and (c in Complex)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{R}^+\right) \land \left(b \in \mathbb{C}\right) \land \left(c \in \mathbb{C}\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a in RealPos) and (b in Complex) and (c in Complex)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (a in RealPos, b in Complex, c in Complex)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 3. a in RealPos
#    core type: Operation
#    operator: 8
#    operands: 6
# 4. b in Complex
#    core type: Operation
#    operator: 8
#    operands: 7
# 5. c in Complex
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. (a, RealPos)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 7. (b, Complex)
#    core type: ExprTuple
#    sub-expressions: 12, 14
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (c, Complex)
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 10. a
#     core type: Variable
#     sub-expressions:
# 11. RealPos
#     core type: Literal
#     sub-expressions:
# 12. b
#     core type: Variable
#     sub-expressions:
# 13. c
#     core type: Variable
#     sub-expressions:
# 14. Complex
#     core type: Literal
#     sub-expressions:
