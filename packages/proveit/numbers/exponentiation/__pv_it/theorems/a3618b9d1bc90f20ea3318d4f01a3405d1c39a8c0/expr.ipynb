# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b
from proveit.logic import And, InSet
from proveit.numbers import Exp, Natural, NaturalPos

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(InSet(Exp(a, b), NaturalPos), And(InSet(a, NaturalPos), InSet(b, Natural))))
# Out:
# expr: (a, b) -> {a^{b} in NaturalPos if a in NaturalPos ,  b in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{a^{b} \in \mathbb{N}^+ \textrm{ if } a \in \mathbb{N}^+ ,  b \in \mathbb{N}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, b) -> {a^{b} in NaturalPos if a in NaturalPos ,  b in Natural.
#    core type: Lambda
#    parameters: 11\n   body: 1
# 1. {a^{b} in NaturalPos if a in NaturalPos ,  b in Natural.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. a^{b} in NaturalPos
#    core type: Operation
#    operator: 13
#    operands: 4
# 3. (a in NaturalPos) and (b in Natural)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a^{b}, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 7, 16
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in NaturalPos, b in Natural)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. a^{b}
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. a in NaturalPos
#    core type: Operation
#    operator: 13
#    operands: 12
# 9. b in Natural
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. Exp
#     core type: Literal
#     sub-expressions:
# 11. (a, b)
#     core type: ExprTuple
#     sub-expressions: 15, 17
# 12. (a, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (b, Natural)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. NaturalPos
#     core type: Literal
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
# 18. Natural
#     core type: Literal
#     sub-expressions:
