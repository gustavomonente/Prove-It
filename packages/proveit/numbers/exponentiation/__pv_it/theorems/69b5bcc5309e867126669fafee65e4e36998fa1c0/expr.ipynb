# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, ExprTuple, IndexedVar, Lambda, Variable, a, b, m
from proveit.core_expr_types import b_1_to_m
from proveit.logic import And, Equals, InSet, NotEquals
from proveit.numbers import Add, Complex, Exp, Real, one, zero
from proveit.numbers.exponentiation import prod_a_raise_bi__1_to_m

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(Lambda([a, b_1_to_m], Conditional(Equals(prod_a_raise_bi__1_to_m, Exp(a, Add(b_1_to_m))), And(InSet(a, Complex), ExprRange(sub_expr1, InSet(IndexedVar(b, sub_expr1), Real), one, m), NotEquals(a, zero)))))
# Out:
# expr: ((a, b_{1}, ..b_{_a}.., b_{m}) -> {(a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}} if a in Complex ,  b_{1} in Real ,  ..b_{_a} in Real.. ,  b_{m} in Real ,  a != 0.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a, b_{1}, \ldots, b_{m}\right) \mapsto \left\{\left(a^{b_{1}} \cdot \ldots \cdot a^{b_{m}}\right) = a^{b_{1} + \ldots + b_{m}} \textrm{ if } a \in \mathbb{C} ,  b_{1} \in \mathbb{R} ,  \ldots ,  b_{m} \in \mathbb{R} ,  a \neq 0\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a, b_{1}, ..b_{_a}.., b_{m}) -> {(a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}} if a in Complex ,  b_{1} in Real ,  ..b_{_a} in Real.. ,  b_{m} in Real ,  a != 0.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a, b_{1}, ..b_{_a}.., b_{m}) -> {(a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}} if a in Complex ,  b_{1} in Real ,  ..b_{_a} in Real.. ,  b_{m} in Real ,  a != 0.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (a, b_{1}, ..b_{_a}.., b_{m})
#    core type: ExprTuple
#    sub-expressions: 40, 33
# 3. {(a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}} if a in Complex ,  b_{1} in Real ,  ..b_{_a} in Real.. ,  b_{m} in Real ,  a != 0.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a in Complex) and (b_{1} in Real) and ..(b_{_a} in Real).. and (b_{m} in Real) and (a != 0)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}, a^{b_{1} + ..b_{_a}.. + b_{m}})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Complex, b_{1} in Real, ..b_{_a} in Real.., b_{m} in Real, a != 0)
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14
# 10. a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. a^{b_{1} + ..b_{_a}.. + b_{m}}
#     core type: Operation
#     operator: 35
#     operands: 17
# 12. a in Complex
#     core type: Operation
#     operator: 30
#     operands: 18
# 13. (b_{1} in Real), ..(b_{_a} in Real).., (b_{m} in Real)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 38
#     end_index: 39
# 14. a != 0
#     core type: Operation
#     operator: 20
#     operands: 21
# 15. *
#     core type: Literal
#     sub-expressions:
# 16. (a^{b_{1}}, ..a^{b_{i}}.., a^{b_{m}})
#     core type: ExprTuple
#     sub-expressions: 22
# 17. (a, b_{1} + ..b_{_a}.. + b_{m})
#     core type: ExprTuple
#     sub-expressions: 40, 23
# 18. (a, Complex)
#     core type: ExprTuple
#     sub-expressions: 40, 24
# 19. _a -> (b_{_a} in Real)
#     core type: Lambda
#     parameter: 47
#     body: 25
# 20. !=
#     core type: Literal
#     sub-expressions:
# 21. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 40, 26
# 22. a^{b_{1}}, ..a^{b_{i}}.., a^{b_{m}}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 38
#     end_index: 39
# 23. b_{1} + ..b_{_a}.. + b_{m}
#     core type: Operation
#     operator: 28
#     operands: 29
# 24. Complex
#     core type: Literal
#     sub-expressions:
# 25. b_{_a} in Real
#     core type: Operation
#     operator: 30
#     operands: 31
# 26. 0
#     core type: Literal
#     sub-expressions:
# 27. i -> a^{b_{i}}
#     core type: Lambda
#     parameter: 46
#     body: 32
# 28. +
#     core type: Literal
#     sub-expressions:
# 29. (b_{1}, ..b_{_a}.., b_{m})
#     core type: ExprTuple
#     sub-expressions: 33
# 30. in
#     core type: Literal
#     sub-expressions:
# 31. (b_{_a}, Real)
#     core type: ExprTuple
#     sub-expressions: 42, 34
# 32. a^{b_{i}}
#     core type: Operation
#     operator: 35
#     operands: 36
# 33. b_{1}, ..b_{_a}.., b_{m}
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 38
#     end_index: 39
# 34. Real
#     core type: Literal
#     sub-expressions:
# 35. Exp
#     core type: Literal
#     sub-expressions:
# 36. (a, b_{i})
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 37. _a -> b_{_a}
#     core type: Lambda
#     parameter: 47
#     body: 42
# 38. 1
#     core type: Literal
#     sub-expressions:
# 39. m
#     core type: Variable
#     sub-expressions:
# 40. a
#     core type: Variable
#     sub-expressions:
# 41. b_{i}
#     core type: IndexedVar
# variable: 44
# index: 46
# 42. b_{_a}
#     core type: IndexedVar
# variable: 44
# index: 47
# 43. (i)
#     core type: ExprTuple
#     sub-expressions: 46
# 44. b
#     core type: Variable
#     sub-expressions:
# 45. (_a)
#     core type: ExprTuple
#     sub-expressions: 47
# 46. i
#     core type: Variable
#     sub-expressions:
# 47. _a
#     core type: Variable
#     sub-expressions:
