# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a
from proveit.core_expr_types import b_1_to_m
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Complex, Exp, RealPos
from proveit.numbers.exponentiation import prod_a_raise_bi__1_to_m

# %%
# build up the expression from sub-expressions
expr = Forall([a, b_1_to_m], Equals(prod_a_raise_bi__1_to_m, Exp(a, Add(b_1_to_m))), domains = [Complex, RealPos])
# Out:
# expr: forall_{a in Complex, b_{1} in RealPos, ..b_{_a} in RealPos.., b_{m} in RealPos} ((a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a \in \mathbb{C}, b_{1} \in \mathbb{R}^+, \ldots, b_{m} \in \mathbb{R}^+}~\left(\left(a^{b_{1}} \cdot \ldots \cdot a^{b_{m}}\right) = a^{b_{1} + \ldots + b_{m}}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a in Complex, b_{1} in RealPos, ..b_{_a} in RealPos.., b_{m} in RealPos} ((a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}})
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b_{1}, ..b_{_a}.., b_{m}) -> {(a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}} if a in Complex ,  b_{1} in RealPos ,  ..b_{_a} in RealPos.. ,  b_{m} in RealPos.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b_{1}, ..b_{_a}.., b_{m}) -> {(a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}} if a in Complex ,  b_{1} in RealPos ,  ..b_{_a} in RealPos.. ,  b_{m} in RealPos.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a, b_{1}, ..b_{_a}.., b_{m})
#    core type: ExprTuple
#    sub-expressions: 38, 31
# 5. {(a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}} if a in Complex ,  b_{1} in RealPos ,  ..b_{_a} in RealPos.. ,  b_{m} in RealPos.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a in Complex) and (b_{1} in RealPos) and ..(b_{_a} in RealPos).. and (b_{m} in RealPos)
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. (a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}, a^{b_{1} + ..b_{_a}.. + b_{m}})
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (a in Complex, b_{1} in RealPos, ..b_{_a} in RealPos.., b_{m} in RealPos)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. a^{b_{1} + ..b_{_a}.. + b_{m}}
#     core type: Operation
#     operator: 33
#     operands: 18
# 14. a in Complex
#     core type: Operation
#     operator: 28
#     operands: 19
# 15. (b_{1} in RealPos), ..(b_{_a} in RealPos).., (b_{m} in RealPos)
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 36
#     end_index: 37
# 16. *
#     core type: Literal
#     sub-expressions:
# 17. (a^{b_{1}}, ..a^{b_{i}}.., a^{b_{m}})
#     core type: ExprTuple
#     sub-expressions: 21
# 18. (a, b_{1} + ..b_{_a}.. + b_{m})
#     core type: ExprTuple
#     sub-expressions: 38, 22
# 19. (a, Complex)
#     core type: ExprTuple
#     sub-expressions: 38, 23
# 20. _a -> (b_{_a} in RealPos)
#     core type: Lambda
#     parameter: 45
#     body: 24
# 21. a^{b_{1}}, ..a^{b_{i}}.., a^{b_{m}}
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 36
#     end_index: 37
# 22. b_{1} + ..b_{_a}.. + b_{m}
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. Complex
#     core type: Literal
#     sub-expressions:
# 24. b_{_a} in RealPos
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. i -> a^{b_{i}}
#     core type: Lambda
#     parameter: 44
#     body: 30
# 26. +
#     core type: Literal
#     sub-expressions:
# 27. (b_{1}, ..b_{_a}.., b_{m})
#     core type: ExprTuple
#     sub-expressions: 31
# 28. in
#     core type: Literal
#     sub-expressions:
# 29. (b_{_a}, RealPos)
#     core type: ExprTuple
#     sub-expressions: 40, 32
# 30. a^{b_{i}}
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. b_{1}, ..b_{_a}.., b_{m}
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 36
#     end_index: 37
# 32. RealPos
#     core type: Literal
#     sub-expressions:
# 33. Exp
#     core type: Literal
#     sub-expressions:
# 34. (a, b_{i})
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 35. _a -> b_{_a}
#     core type: Lambda
#     parameter: 45
#     body: 40
# 36. 1
#     core type: Literal
#     sub-expressions:
# 37. m
#     core type: Variable
#     sub-expressions:
# 38. a
#     core type: Variable
#     sub-expressions:
# 39. b_{i}
#     core type: IndexedVar
# variable: 42
# index: 44
# 40. b_{_a}
#     core type: IndexedVar
# variable: 42
# index: 45
# 41. (i)
#     core type: ExprTuple
#     sub-expressions: 44
# 42. b
#     core type: Variable
#     sub-expressions:
# 43. (_a)
#     core type: ExprTuple
#     sub-expressions: 45
# 44. i
#     core type: Variable
#     sub-expressions:
# 45. _a
#     core type: Variable
#     sub-expressions:
