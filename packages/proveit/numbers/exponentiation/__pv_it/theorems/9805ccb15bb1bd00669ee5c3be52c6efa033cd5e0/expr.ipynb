# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, ExprTuple, IndexedVar, Lambda, Variable, a, b, m
from proveit.core_expr_types import b_1_to_m
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Complex, Exp, RealPos, one
from proveit.numbers.exponentiation import prod_a_raise_bi__1_to_m

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(Lambda([a, b_1_to_m], Conditional(Equals(prod_a_raise_bi__1_to_m, Exp(a, Add(b_1_to_m))), And(InSet(a, Complex), ExprRange(sub_expr1, InSet(IndexedVar(b, sub_expr1), RealPos), one, m)))))
# Out:
# expr: ((a, b_{1}, ..b_{_a}.., b_{m}) -> {(a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}} if a in Complex ,  b_{1} in RealPos ,  ..b_{_a} in RealPos.. ,  b_{m} in RealPos.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a, b_{1}, \ldots, b_{m}\right) \mapsto \left\{\left(a^{b_{1}} \cdot \ldots \cdot a^{b_{m}}\right) = a^{b_{1} + \ldots + b_{m}} \textrm{ if } a \in \mathbb{C} ,  b_{1} \in \mathbb{R}^+ ,  \ldots ,  b_{m} \in \mathbb{R}^+\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a, b_{1}, ..b_{_a}.., b_{m}) -> {(a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}} if a in Complex ,  b_{1} in RealPos ,  ..b_{_a} in RealPos.. ,  b_{m} in RealPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a, b_{1}, ..b_{_a}.., b_{m}) -> {(a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}} if a in Complex ,  b_{1} in RealPos ,  ..b_{_a} in RealPos.. ,  b_{m} in RealPos.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (a, b_{1}, ..b_{_a}.., b_{m})
#    core type: ExprTuple
#    sub-expressions: 36, 29
# 3. {(a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}} if a in Complex ,  b_{1} in RealPos ,  ..b_{_a} in RealPos.. ,  b_{m} in RealPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a in Complex) and (b_{1} in RealPos) and ..(b_{_a} in RealPos).. and (b_{m} in RealPos)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}, a^{b_{1} + ..b_{_a}.. + b_{m}})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Complex, b_{1} in RealPos, ..b_{_a} in RealPos.., b_{m} in RealPos)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. a^{b_{1} + ..b_{_a}.. + b_{m}}
#     core type: Operation
#     operator: 31
#     operands: 16
# 12. a in Complex
#     core type: Operation
#     operator: 26
#     operands: 17
# 13. (b_{1} in RealPos), ..(b_{_a} in RealPos).., (b_{m} in RealPos)
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 34
#     end_index: 35
# 14. *
#     core type: Literal
#     sub-expressions:
# 15. (a^{b_{1}}, ..a^{b_{i}}.., a^{b_{m}})
#     core type: ExprTuple
#     sub-expressions: 19
# 16. (a, b_{1} + ..b_{_a}.. + b_{m})
#     core type: ExprTuple
#     sub-expressions: 36, 20
# 17. (a, Complex)
#     core type: ExprTuple
#     sub-expressions: 36, 21
# 18. _a -> (b_{_a} in RealPos)
#     core type: Lambda
#     parameter: 43
#     body: 22
# 19. a^{b_{1}}, ..a^{b_{i}}.., a^{b_{m}}
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 34
#     end_index: 35
# 20. b_{1} + ..b_{_a}.. + b_{m}
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. Complex
#     core type: Literal
#     sub-expressions:
# 22. b_{_a} in RealPos
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. i -> a^{b_{i}}
#     core type: Lambda
#     parameter: 42
#     body: 28
# 24. +
#     core type: Literal
#     sub-expressions:
# 25. (b_{1}, ..b_{_a}.., b_{m})
#     core type: ExprTuple
#     sub-expressions: 29
# 26. in
#     core type: Literal
#     sub-expressions:
# 27. (b_{_a}, RealPos)
#     core type: ExprTuple
#     sub-expressions: 38, 30
# 28. a^{b_{i}}
#     core type: Operation
#     operator: 31
#     operands: 32
# 29. b_{1}, ..b_{_a}.., b_{m}
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 34
#     end_index: 35
# 30. RealPos
#     core type: Literal
#     sub-expressions:
# 31. Exp
#     core type: Literal
#     sub-expressions:
# 32. (a, b_{i})
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 33. _a -> b_{_a}
#     core type: Lambda
#     parameter: 43
#     body: 38
# 34. 1
#     core type: Literal
#     sub-expressions:
# 35. m
#     core type: Variable
#     sub-expressions:
# 36. a
#     core type: Variable
#     sub-expressions:
# 37. b_{i}
#     core type: IndexedVar
# variable: 40
# index: 42
# 38. b_{_a}
#     core type: IndexedVar
# variable: 40
# index: 43
# 39. (i)
#     core type: ExprTuple
#     sub-expressions: 42
# 40. b
#     core type: Variable
#     sub-expressions:
# 41. (_a)
#     core type: ExprTuple
#     sub-expressions: 43
# 42. i
#     core type: Variable
#     sub-expressions:
# 43. _a
#     core type: Variable
#     sub-expressions:
