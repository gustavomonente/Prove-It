# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Lambda, Variable, a, b, m
from proveit.core_expr_types import a_1_to_m
from proveit.logic import And, Equals, InSet
from proveit.numbers import Complex, Exp, Mult, RealPos, one
from proveit.numbers.exponentiation import prod_ai_raise_b__1_to_m

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Lambda([a_1_to_m, b], Conditional(Equals(Exp(Mult(a_1_to_m), b), prod_ai_raise_b__1_to_m), And(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), RealPos), one, m), InSet(b, Complex))))
# Out:
# expr: (a_{1}, ..a_{_a}.., a_{m}, b) -> {(a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}) if a_{1} in RealPos ,  ..a_{_a} in RealPos.. ,  a_{m} in RealPos ,  b in Complex.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1}, \ldots, a_{m}, b\right) \mapsto \left\{\left(a_{1} \cdot \ldots \cdot a_{m}\right)^{b} = \left(\left(a_{1}\right)^{b} \cdot \ldots \cdot \left(a_{m}\right)^{b}\right) \textrm{ if } a_{1} \in \mathbb{R}^+ ,  \ldots ,  a_{m} \in \mathbb{R}^+ ,  b \in \mathbb{C}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1}, ..a_{_a}.., a_{m}, b) -> {(a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}) if a_{1} in RealPos ,  ..a_{_a} in RealPos.. ,  a_{m} in RealPos ,  b in Complex.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a_{1}, ..a_{_a}.., a_{m}, b)
#    core type: ExprTuple
#    sub-expressions: 26, 36
# 2. {(a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}) if a_{1} in RealPos ,  ..a_{_a} in RealPos.. ,  a_{m} in RealPos ,  b in Complex.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a_{1} in RealPos) and ..(a_{_a} in RealPos).. and (a_{m} in RealPos) and (b in Complex)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. ((a_{1} * ..a_{_a}.. * a_{m})^{b}, (a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a_{1} in RealPos, ..a_{_a} in RealPos.., a_{m} in RealPos, b in Complex)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. (a_{1} * ..a_{_a}.. * a_{m})^{b}
#    core type: Operation
#    operator: 32
#    operands: 13
# 10. (a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}
#     core type: Operation
#     operator: 21
#     operands: 14
# 11. (a_{1} in RealPos), ..(a_{_a} in RealPos).., (a_{m} in RealPos)
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 30
#     end_index: 31
# 12. b in Complex
#     core type: Operation
#     operator: 24
#     operands: 16
# 13. (a_{1} * ..a_{_a}.. * a_{m}, b)
#     core type: ExprTuple
#     sub-expressions: 17, 36
# 14. ((a_{1})^{b}, ..(a_{i})^{b}.., (a_{m})^{b})
#     core type: ExprTuple
#     sub-expressions: 18
# 15. _a -> (a_{_a} in RealPos)
#     core type: Lambda
#     parameter: 40
#     body: 19
# 16. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 36, 20
# 17. a_{1} * ..a_{_a}.. * a_{m}
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. (a_{1})^{b}, ..(a_{i})^{b}.., (a_{m})^{b}
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 30
#     end_index: 31
# 19. a_{_a} in RealPos
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. Complex
#     core type: Literal
#     sub-expressions:
# 21. *
#     core type: Literal
#     sub-expressions:
# 22. (a_{1}, ..a_{_a}.., a_{m})
#     core type: ExprTuple
#     sub-expressions: 26
# 23. i -> (a_{i})^{b}
#     core type: Lambda
#     parameter: 41
#     body: 27
# 24. in
#     core type: Literal
#     sub-expressions:
# 25. (a_{_a}, RealPos)
#     core type: ExprTuple
#     sub-expressions: 34, 28
# 26. a_{1}, ..a_{_a}.., a_{m}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 30
#     end_index: 31
# 27. (a_{i})^{b}
#     core type: Operation
#     operator: 32
#     operands: 33
# 28. RealPos
#     core type: Literal
#     sub-expressions:
# 29. _a -> a_{_a}
#     core type: Lambda
#     parameter: 40
#     body: 34
# 30. 1
#     core type: Literal
#     sub-expressions:
# 31. m
#     core type: Variable
#     sub-expressions:
# 32. Exp
#     core type: Literal
#     sub-expressions:
# 33. (a_{i}, b)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 34. a_{_a}
#     core type: IndexedVar
# variable: 38
# index: 40
# 35. a_{i}
#     core type: IndexedVar
# variable: 38
# index: 41
# 36. b
#     core type: Variable
#     sub-expressions:
# 37. (_a)
#     core type: ExprTuple
#     sub-expressions: 40
# 38. a
#     core type: Variable
#     sub-expressions:
# 39. (i)
#     core type: ExprTuple
#     sub-expressions: 41
# 40. _a
#     core type: Variable
#     sub-expressions:
# 41. i
#     core type: Variable
#     sub-expressions:
