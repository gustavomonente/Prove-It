# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, a, i, m, n
from proveit.numbers import Exp, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(ExprRange(i, Exp(IndexedVar(a, i), n), one, m))
# Out:
# expr: ((a_{1})^{n}, ..(a_{i})^{n}.., (a_{m})^{n})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a_{1}\right)^{n}, \ldots, \left(a_{m}\right)^{n}\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a_{1})^{n}, ..(a_{i})^{n}.., (a_{m})^{n})
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a_{1})^{n}, ..(a_{i})^{n}.., (a_{m})^{n}
#    core type: ExprRange
#    lambda_map: 2
#    start_index: 3
#    end_index: 4
# 2. i -> (a_{i})^{n}
#    core type: Lambda
#    parameter: 12
#    body: 5
# 3. 1
#    core type: Literal
#    sub-expressions:
# 4. m
#    core type: Variable
#    sub-expressions:
# 5. (a_{i})^{n}
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. Exp
#    core type: Literal
#    sub-expressions:
# 7. (a_{i}, n)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. a_{i}
#    core type: IndexedVar
# variable: 10
# index: 12
# 9. n
#    core type: Variable
#    sub-expressions:
# 10. a
#     core type: Variable
#     sub-expressions:
# 11. (i)
#     core type: ExprTuple
#     sub-expressions: 12
# 12. i
#     core type: Variable
#     sub-expressions:
