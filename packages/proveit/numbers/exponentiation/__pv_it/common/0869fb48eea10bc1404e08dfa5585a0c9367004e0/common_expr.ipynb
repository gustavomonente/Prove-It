# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#prod_ai_raise_n__1_to_m">prod_ai_raise_n__1_to_m</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.numbers.Mult.html">Mult</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.numbers.exponentiation import prod_ai_raise_n__1_to_m

# %%
# check that the built expression is the same as the stored expression
assert prod_ai_raise_n__1_to_m == stored_expr
assert prod_ai_raise_n__1_to_m._style_id == stored_expr._style_id
print("Passed sanity check: prod_ai_raise_n__1_to_m matches stored_expr")
# Out:
# Passed sanity check: prod_ai_raise_n__1_to_m matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(prod_ai_raise_n__1_to_m.latex())
# Out:
# \left(a_{1}\right)^{n} \cdot \ldots \cdot \left(a_{m}\right)^{n}

# %%
prod_ai_raise_n__1_to_m.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
prod_ai_raise_n__1_to_m.expr_info()
# Out:
# 0. (a_{1})^{n} * ..(a_{i})^{n}.. * (a_{m})^{n}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. *
#    core type: Literal
#    sub-expressions:
# 2. ((a_{1})^{n}, ..(a_{i})^{n}.., (a_{m})^{n})
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a_{1})^{n}, ..(a_{i})^{n}.., (a_{m})^{n}
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 5
#    end_index: 6
# 4. i -> (a_{i})^{n}
#    core type: Lambda
#    parameter: 14
#    body: 7
# 5. 1
#    core type: Literal
#    sub-expressions:
# 6. m
#    core type: Variable
#    sub-expressions:
# 7. (a_{i})^{n}
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. Exp
#    core type: Literal
#    sub-expressions:
# 9. (a_{i}, n)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. a_{i}
#     core type: IndexedVar
# variable: 12
# index: 14
# 11. n
#     core type: Variable
#     sub-expressions:
# 12. a
#     core type: Variable
#     sub-expressions:
# 13. (i)
#     core type: ExprTuple
# ...
