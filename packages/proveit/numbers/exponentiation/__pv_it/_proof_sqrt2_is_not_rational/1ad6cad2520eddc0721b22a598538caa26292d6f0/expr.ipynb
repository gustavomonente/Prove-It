# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a_star, b_star
from proveit.logic import Equals
from proveit.numbers import Mult, frac, one

# %%
# build up the expression from sub-expressions
expr = Equals(Mult(frac(a_star, Mult(one, b_star)), frac(Mult(b_star, one), one)), Mult(frac(a_star, b_star), b_star))
# Out:
# expr: ((a_star / (1 * b_star)) * ((b_star * 1) / 1)) = ((a_star / b_star) * b_star)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\frac{a^*}{1 \cdot b^*} \cdot \frac{b^* \cdot 1}{1}\right) = \left(\frac{a^*}{b^*} \cdot b^*\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a_star / (1 * b_star)) * ((b_star * 1) / 1)) = ((a_star / b_star) * b_star)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((a_star / (1 * b_star)) * ((b_star * 1) / 1), (a_star / b_star) * b_star)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (a_star / (1 * b_star)) * ((b_star * 1) / 1)
#    core type: Operation
#    operator: 18
#    operands: 5
# 4. (a_star / b_star) * b_star
#    core type: Operation
#    operator: 18
#    operands: 6
# 5. (a_star / (1 * b_star), (b_star * 1) / 1)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (a_star / b_star, b_star)
#    core type: ExprTuple
#    sub-expressions: 9, 20
# 7. a_star / (1 * b_star)
#    core type: Operation
#    operator: 12
#    operands: 10
# 8. (b_star * 1) / 1
#    core type: Operation
#    operator: 12
#    operands: 11
# 9. a_star / b_star
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. (a_star, 1 * b_star)
#     core type: ExprTuple
#     sub-expressions: 16, 14
# 11. (b_star * 1, 1)
#     core type: ExprTuple
#     sub-expressions: 15, 21
# 12. /
#     core type: Literal
#     sub-expressions:
# 13. (a_star, b_star)
#     core type: ExprTuple
#     sub-expressions: 16, 20
# 14. 1 * b_star
#     core type: Operation
#     operator: 18
#     operands: 17
# 15. b_star * 1
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. a_star
#     core type: Variable
#     sub-expressions:
# 17. (1, b_star)
#     core type: ExprTuple
#     sub-expressions: 21, 20
# 18. *
#     core type: Literal
#     sub-expressions:
# 19. (b_star, 1)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 20. b_star
#     core type: Variable
#     sub-expressions:
# 21. 1
#     core type: Literal
#     sub-expressions:
