# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, a_star, b, b_star
from proveit.logic import And, Equals, Exists, FALSE, Forall, Implies
from proveit.numbers import Abs, GCD, NaturalPos, frac, one, sqrt, two

# %%
# build up the expression from sub-expressions
sub_expr1 = [NaturalPos, NaturalPos]
sub_expr2 = Abs(sqrt(two))
expr = Implies(And(Exists([a, b], And(Equals(sub_expr2, frac(a, b)), Equals(GCD(a, b), one)), domains = sub_expr1), Forall([a_star, b_star], Implies(And(Equals(sub_expr2, frac(a_star, b_star)), Equals(GCD(a_star, b_star), one)), FALSE), domains = sub_expr1)), FALSE)
# Out:
# expr: ([exists_{a, b in NaturalPos} ((|sqrt(2)| = (a / b)) and (gcd(a, b) = 1))] and [forall_{a_star, b_star in NaturalPos} (((|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)) => FALSE)]) => FALSE

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left[\exists_{a, b \in \mathbb{N}^+}~\left(\left(\left|\sqrt{2}\right| = \frac{a}{b}\right) \land \left(gcd(a, b) = 1\right)\right)\right] \land \left[\forall_{a^*, b^* \in \mathbb{N}^+}~\left(\left(\left(\left|\sqrt{2}\right| = \frac{a^*}{b^*}\right) \land \left(gcd(a^*, b^*) = 1\right)\right) \Rightarrow \bot\right)\right]\right) \Rightarrow \bot

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ([exists_{a, b in NaturalPos} ((|sqrt(2)| = (a / b)) and (gcd(a, b) = 1))] and [forall_{a_star, b_star in NaturalPos} (((|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)) => FALSE)]) => FALSE
#    core type: Operation
#    operator: 20
#    operands: 1
# 1. ([exists_{a, b in NaturalPos} ((|sqrt(2)| = (a / b)) and (gcd(a, b) = 1))] and [forall_{a_star, b_star in NaturalPos} (((|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)) => FALSE)], FALSE)
#    core type: ExprTuple
#    sub-expressions: 2, 28
# 2. [exists_{a, b in NaturalPos} ((|sqrt(2)| = (a / b)) and (gcd(a, b) = 1))] and [forall_{a_star, b_star in NaturalPos} (((|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)) => FALSE)]
#    core type: Operation
#    operator: 35
#    operands: 3
# 3. (exists_{a, b in NaturalPos} ((|sqrt(2)| = (a / b)) and (gcd(a, b) = 1)), forall_{a_star, b_star in NaturalPos} (((|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)) => FALSE))
# ...
