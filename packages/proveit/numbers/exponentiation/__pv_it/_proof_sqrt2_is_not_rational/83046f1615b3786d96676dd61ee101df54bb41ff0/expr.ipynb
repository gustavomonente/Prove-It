# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, a_star, b, b_star
from proveit.logic import And, Equals, Exists, FALSE, Forall, Implies
from proveit.numbers import Abs, GCD, NaturalPos, frac, one, sqrt, two

# %%
# build up the expression from sub-expressions
sub_expr1 = [NaturalPos, NaturalPos]
sub_expr2 = Abs(sqrt(two))
expr = ExprTuple(Exists([a, b], And(Equals(sub_expr2, frac(a, b)), Equals(GCD(a, b), one)), domains = sub_expr1), Forall([a_star, b_star], Implies(And(Equals(sub_expr2, frac(a_star, b_star)), Equals(GCD(a_star, b_star), one)), FALSE), domains = sub_expr1))
# Out:
# expr: (exists_{a, b in NaturalPos} ((|sqrt(2)| = (a / b)) and (gcd(a, b) = 1)), forall_{a_star, b_star in NaturalPos} (((|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)) => FALSE))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\exists_{a, b \in \mathbb{N}^+}~\left(\left(\left|\sqrt{2}\right| = \frac{a}{b}\right) \land \left(gcd(a, b) = 1\right)\right), \forall_{a^*, b^* \in \mathbb{N}^+}~\left(\left(\left(\left|\sqrt{2}\right| = \frac{a^*}{b^*}\right) \land \left(gcd(a^*, b^*) = 1\right)\right) \Rightarrow \bot\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (exists_{a, b in NaturalPos} ((|sqrt(2)| = (a / b)) and (gcd(a, b) = 1)), forall_{a_star, b_star in NaturalPos} (((|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)) => FALSE))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. exists_{a, b in NaturalPos} ((|sqrt(2)| = (a / b)) and (gcd(a, b) = 1))
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. forall_{a_star, b_star in NaturalPos} (((|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)) => FALSE)
#    core type: Operation
#    operator: 5
#    operand: 8
# 3. exists
#    core type: Literal
#    sub-expressions:
# 4. ((a, b) -> {(|sqrt(2)| = (a / b)) and (gcd(a, b) = 1) if a in NaturalPos ,  b in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((a_star, b_star) -> {((|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)) => FALSE if a_star in NaturalPos ,  b_star in NaturalPos.)
#    core type: ExprTuple
# ...
