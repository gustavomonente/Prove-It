# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#distribute_neg_through_sum">distribute_neg_through_sum</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.negation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.negation import distribute_neg_through_sum

# %%
# check that the built expression is the same as the stored expression
assert distribute_neg_through_sum.expr == stored_expr
assert distribute_neg_through_sum.expr._style_id == stored_expr._style_id
print("Passed sanity check: distribute_neg_through_sum matches stored_expr")
# Out:
# Passed sanity check: distribute_neg_through_sum matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(distribute_neg_through_sum.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{x_{1}, \ldots, x_{n} \in \mathbb{C}}~\left(\left(-\left(x_{1} + \ldots + x_{n}\right)\right) = \left(\left(-x_{1}\right) + \ldots + \left(-x_{n}\right)\right)\right)\right]

# %%
distribute_neg_through_sum.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
distribute_neg_through_sum.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{x_{1}, ..x_{_a}.., x_{n} in Complex} ((-(x_{1} + ..x_{_a}.. + x_{n})) = ((-x_{1}) + ..(-x_{k}).. + (-x_{n})))]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (n -> {forall_{x_{1}, ..x_{_a}.., x_{n} in Complex} ((-(x_{1} + ..x_{_a}.. + x_{n})) = ((-x_{1}) + ..(-x_{k}).. + (-x_{n}))) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{x_{1}, ..x_{_a}.., x_{n} in Complex} ((-(x_{1} + ..x_{_a}.. + x_{n})) = ((-x_{1}) + ..(-x_{k}).. + (-x_{n}))) if n in NaturalPos.
#    core type: Lambda
#    parameter: 37
#    body: 3
# 3. {forall_{x_{1}, ..x_{_a}.., x_{n} in Complex} ((-(x_{1} + ..x_{_a}.. + x_{n})) = ((-x_{1}) + ..(-x_{k}).. + (-x_{n}))) if n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{x_{1}, ..x_{_a}.., x_{n} in Complex} ((-(x_{1} + ..x_{_a}.. + x_{n})) = ((-x_{1}) + ..(-x_{k}).. + (-x_{n})))
#    core type: Operation
#    operator: 6
#    operand: 9
# ...
