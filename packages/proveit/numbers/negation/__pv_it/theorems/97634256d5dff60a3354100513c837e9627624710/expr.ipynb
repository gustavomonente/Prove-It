# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.negation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, x, y
from proveit.logic import And, Equals, InSet
from proveit.numbers import Complex, Mult, Neg

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([x, y], Conditional(Equals(Mult(Neg(x), Neg(y)), Mult(x, y)), And(InSet(x, Complex), InSet(y, Complex)))))
# Out:
# expr: ((x, y) -> {((-x) * (-y)) = (x * y) if x in Complex ,  y in Complex.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(x, y\right) \mapsto \left\{\left(\left(-x\right) \cdot \left(-y\right)\right) = \left(x \cdot y\right) \textrm{ if } x \in \mathbb{C} ,  y \in \mathbb{C}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((x, y) -> {((-x) * (-y)) = (x * y) if x in Complex ,  y in Complex.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (x, y) -> {((-x) * (-y)) = (x * y) if x in Complex ,  y in Complex.
#    core type: Lambda
#    parameters: 15\n   body: 2
# 2. {((-x) * (-y)) = (x * y) if x in Complex ,  y in Complex.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. ((-x) * (-y)) = (x * y)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (x in Complex) and (y in Complex)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. ((-x) * (-y), x * y)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (x in Complex, y in Complex)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. (-x) * (-y)
#    core type: Operation
#    operator: 14
#    operands: 13
# 10. x * y
#     core type: Operation
#     operator: 14
#     operands: 15
# ...
