# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.integers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b, n
from proveit.logic import And, InSet
from proveit.numbers import Integer, Interval, LessEq

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b, n], Conditional(InSet(n, Interval(a, b)), And(InSet(a, Integer), InSet(b, Integer), InSet(n, Integer), And(LessEq(a, n), LessEq(n, b)).with_total_ordering_style())))
# Out:
# expr: (a, b, n) -> {n in {a...b} if a in Integer ,  b in Integer ,  n in Integer ,  a <= n <= b.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b, n\right) \mapsto \left\{n \in \{a \ldots b\} \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  n \in \mathbb{Z} ,  a \leq n \leq b\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, b, n) -> {n in {a...b} if a in Integer ,  b in Integer ,  n in Integer ,  a <= n <= b.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a, b, n)
#    core type: ExprTuple
#    sub-expressions: 26, 28, 27
# 2. {n in {a...b} if a in Integer ,  b in Integer ,  n in Integer ,  a <= n <= b.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. n in {a...b}
#    core type: Operation
#    operator: 16
#    operands: 5
# 4. (a in Integer) and (b in Integer) and (n in Integer) and (a <= n <= b)
#    core type: Operation
#    operator: 18
#    operands: 6
# 5. (n, {a...b})
#    core type: ExprTuple
#    sub-expressions: 27, 7
# 6. (a in Integer, b in Integer, n in Integer, a <= n <= b)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 7. {a...b}
#    core type: Operation
#    operator: 12
#    operands: 13
# 8. a in Integer
#    core type: Operation
#    operator: 16
#    operands: 14
# 9. b in Integer
#    core type: Operation
#    operator: 16
# ...
