# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.integers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b, n
from proveit.logic import And, Forall, InSet
from proveit.numbers import Integer, Interval

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(Forall([n], InSet(n, Integer), domains = [Interval(a, b)]), And(InSet(a, Integer), InSet(b, Integer))))
# Out:
# expr: (a, b) -> {forall_{n in {a...b}} (n in Integer) if a in Integer ,  b in Integer.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{\forall_{n \in \{a \ldots b\}}~\left(n \in \mathbb{Z}\right) \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, b) -> {forall_{n in {a...b}} (n in Integer) if a in Integer ,  b in Integer.
#    core type: Lambda
#    parameters: 23\n   body: 1
# 1. {forall_{n in {a...b}} (n in Integer) if a in Integer ,  b in Integer.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{n in {a...b}} (n in Integer)
#    core type: Operation
#    operator: 4
#    operand: 8
# 3. (a in Integer) and (b in Integer)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (n -> {n in Integer if n in {a...b}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a in Integer, b in Integer)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. n -> {n in Integer if n in {a...b}.
#    core type: Lambda
#    parameter: 20
#    body: 11
# 9. a in Integer
#    core type: Operation
#    operator: 17
#    operands: 12
# 10. b in Integer
#     core type: Operation
#     operator: 17
#     operands: 13
# 11. {n in Integer if n in {a...b}.
#     core type: Conditional
#     value: 14
#     condition: 15
# 12. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 24, 19
# 13. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 25, 19
# 14. n in Integer
#     core type: Operation
#     operator: 17
#     operands: 16
# 15. n in {a...b}
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. (n, Integer)
#     core type: ExprTuple
#     sub-expressions: 20, 19
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (n, {a...b})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. Integer
#     core type: Literal
#     sub-expressions:
# 20. n
#     core type: Variable
#     sub-expressions:
# 21. {a...b}
#     core type: Operation
#     operator: 22
#     operands: 23
# 22. Interval
#     core type: Literal
#     sub-expressions:
# 23. (a, b)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. a
#     core type: Variable
#     sub-expressions:
# 25. b
#     core type: Variable
#     sub-expressions:
