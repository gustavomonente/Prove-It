# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.integers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b, n
from proveit.logic import And, Forall, InSet
from proveit.numbers import Integer, Interval, NaturalPos, greater, zero

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(Forall([n], InSet(n, NaturalPos), domains = [Interval(a, b)]), And(InSet(a, Integer), InSet(b, Integer), greater(a, zero))))
# Out:
# expr: (a, b) -> {forall_{n in {a...b}} (n in NaturalPos) if a in Integer ,  b in Integer ,  a > 0.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{\forall_{n \in \{a \ldots b\}}~\left(n \in \mathbb{N}^+\right) \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  a > 0\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, b) -> {forall_{n in {a...b}} (n in NaturalPos) if a in Integer ,  b in Integer ,  a > 0.
#    core type: Lambda
#    parameters: 28\n   body: 1
# 1. {forall_{n in {a...b}} (n in NaturalPos) if a in Integer ,  b in Integer ,  a > 0.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{n in {a...b}} (n in NaturalPos)
#    core type: Operation
#    operator: 4
#    operand: 8
# 3. (a in Integer) and (b in Integer) and (a > 0)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (n -> {n in NaturalPos if n in {a...b}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a in Integer, b in Integer, a > 0)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 8. n -> {n in NaturalPos if n in {a...b}.
#    core type: Lambda
#    parameter: 25
#    body: 12
# 9. a in Integer
#    core type: Operation
#    operator: 22
# ...
