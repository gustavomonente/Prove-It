# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.integers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a, b, n
from proveit.logic import InSet
from proveit.numbers import Interval, greater, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(n, Conditional(greater(n, zero), InSet(n, Interval(a, b)))))
# Out:
# expr: (n -> {n > 0 if n in {a...b}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(n \mapsto \left\{n > 0 \textrm{ if } n \in \{a \ldots b\}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (n -> {n > 0 if n in {a...b}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. n -> {n > 0 if n in {a...b}.
#    core type: Lambda
#    parameter: 10
#    body: 2
# 2. {n > 0 if n in {a...b}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. n > 0
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. n in {a...b}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. <
#    core type: Literal
#    sub-expressions:
# 6. (0, n)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (n, {a...b})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. 0
#    core type: Literal
#    sub-expressions:
# 10. n
#     core type: Variable
#     sub-expressions:
# 11. {a...b}
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. Interval
#     core type: Literal
#     sub-expressions:
# 13. (a, b)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. b
#     core type: Variable
#     sub-expressions:
