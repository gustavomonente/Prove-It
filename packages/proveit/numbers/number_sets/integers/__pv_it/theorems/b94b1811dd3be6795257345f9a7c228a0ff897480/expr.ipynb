# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.integers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b, c, d
from proveit.logic import And, InSet, ProperSubset
from proveit.numbers import Integer, Interval, Less, LessEq

# %%
# build up the expression from sub-expressions
expr = Conditional(ProperSubset(Interval(b, c), Interval(a, d)), And(InSet(a, Integer), InSet(b, Integer), InSet(c, Integer), InSet(d, Integer), And(Less(a, b), LessEq(b, c), Less(c, d)).with_total_ordering_style()))
# Out:
# expr: {{b...c} proper_subset {a...d} if a in Integer ,  b in Integer ,  c in Integer ,  d in Integer ,  a < b <= c < d.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\{b \ldots c\} \subset \{a \ldots d\} \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  c \in \mathbb{Z} ,  d \in \mathbb{Z} ,  a < b \leq c < d\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {{b...c} proper_subset {a...d} if a in Integer ,  b in Integer ,  c in Integer ,  d in Integer ,  a < b <= c < d.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. {b...c} proper_subset {a...d}
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a in Integer) and (b in Integer) and (c in Integer) and (d in Integer) and (a < b <= c < d)
#    core type: Operation
#    operator: 20
#    operands: 5
# 3. proper_subset
#    core type: Literal
#    sub-expressions:
# 4. ({b...c}, {a...d})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (a in Integer, b in Integer, c in Integer, d in Integer, a < b <= c < d)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11, 12
# 6. {b...c}
#    core type: Operation
#    operator: 13
#    operands: 28
# 7. {a...d}
#    core type: Operation
#    operator: 13
#    operands: 14
# 8. a in Integer
#    core type: Operation
#    operator: 18
#    operands: 15
# 9. b in Integer
#    core type: Operation
#    operator: 18
#    operands: 16
# 10. c in Integer
#     core type: Operation
#     operator: 18
#     operands: 17
# 11. d in Integer
#     core type: Operation
#     operator: 18
#     operands: 19
# 12. a < b <= c < d
#     core type: Operation
#     operator: 20
#     operands: 21
# 13. Interval
#     core type: Literal
#     sub-expressions:
# 14. (a, d)
#     core type: ExprTuple
#     sub-expressions: 31, 34
# 15. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 31, 22
# 16. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 32, 22
# 17. (c, Integer)
#     core type: ExprTuple
#     sub-expressions: 33, 22
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (d, Integer)
#     core type: ExprTuple
#     sub-expressions: 34, 22
# 20. and
#     core type: Literal
#     sub-expressions:
# 21. (a < b, b <= c, c < d)
#     core type: ExprTuple
#     sub-expressions: 23, 24, 25
# 22. Integer
#     core type: Literal
#     sub-expressions:
# 23. a < b
#     core type: Operation
#     operator: 29
#     operands: 26
# 24. b <= c
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. c < d
#     core type: Operation
#     operator: 29
#     operands: 30
# 26. (a, b)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 27. <=
#     core type: Literal
#     sub-expressions:
# 28. (b, c)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 29. <
#     core type: Literal
#     sub-expressions:
# 30. (c, d)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 31. a
#     core type: Variable
#     sub-expressions:
# 32. b
#     core type: Variable
#     sub-expressions:
# 33. c
#     core type: Variable
#     sub-expressions:
# 34. d
#     core type: Variable
#     sub-expressions:
