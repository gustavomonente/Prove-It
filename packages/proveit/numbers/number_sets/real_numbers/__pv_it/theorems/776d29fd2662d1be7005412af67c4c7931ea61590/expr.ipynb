# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a
from proveit.logic import Iff, InSet
from proveit.numbers import Less, Real, RealNeg, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(a, Conditional(Iff(InSet(a, RealNeg), Less(a, zero)), InSet(a, Real))))
# Out:
# expr: (a -> {(a in RealNeg) <=> (a < 0) if a in Real.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \mapsto \left\{\left(a \in \mathbb{R}^-\right) \Leftrightarrow \left(a < 0\right) \textrm{ if } a \in \mathbb{R}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a -> {(a in RealNeg) <=> (a < 0) if a in Real.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. a -> {(a in RealNeg) <=> (a < 0) if a in Real.
#    core type: Lambda
#    parameter: 16
#    body: 2
# 2. {(a in RealNeg) <=> (a < 0) if a in Real.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (a in RealNeg) <=> (a < 0)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. a in Real
#    core type: Operation
#    operator: 11
#    operands: 7
# 5. <=>
#    core type: Literal
#    sub-expressions:
# 6. (a in RealNeg, a < 0)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (a, Real)
#    core type: ExprTuple
#    sub-expressions: 16, 10
# 8. a in RealNeg
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. a < 0
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. Real
#     core type: Literal
#     sub-expressions:
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (a, RealNeg)
#     core type: ExprTuple
#     sub-expressions: 16, 15
# 13. <
#     core type: Literal
#     sub-expressions:
# 14. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. RealNeg
#     core type: Literal
#     sub-expressions:
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. 0
#     core type: Literal
#     sub-expressions:
