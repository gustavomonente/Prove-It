# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, n, x
from proveit.logic import Forall, InSet, NotInSet
from proveit.numbers import Add, Integer, IntervalOO, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(n, Conditional(Forall([x], NotInSet(x, Integer), domains = [IntervalOO(n, Add(n, one))]), InSet(n, Integer))))
# Out:
# expr: (n -> {forall_{x in (n,n + 1)} (x not-in Integer) if n in Integer.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(n \mapsto \left\{\forall_{x \in \left(n,n + 1\right)}~\left(x \notin \mathbb{Z}\right) \textrm{ if } n \in \mathbb{Z}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (n -> {forall_{x in (n,n + 1)} (x not-in Integer) if n in Integer.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. n -> {forall_{x in (n,n + 1)} (x not-in Integer) if n in Integer.
#    core type: Lambda
#    parameter: 24
#    body: 2
# 2. {forall_{x in (n,n + 1)} (x not-in Integer) if n in Integer.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{x in (n,n + 1)} (x not-in Integer)
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. n in Integer
#    core type: Operation
#    operator: 14
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (x -> {x not-in Integer if x in (n,n + 1).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (n, Integer)
#    core type: ExprTuple
#    sub-expressions: 24, 16
# 8. x -> {x not-in Integer if x in (n,n + 1).
#    core type: Lambda
#    parameter: 17
#    body: 9
# 9. {x not-in Integer if x in (n,n + 1).
#    core type: Conditional
#    value: 10
#    condition: 11
# 10. x not-in Integer
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. x in (n,n + 1)
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. not-in
#     core type: Literal
#     sub-expressions:
# 13. (x, Integer)
#     core type: ExprTuple
#     sub-expressions: 17, 16
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (x, (n,n + 1))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. Integer
#     core type: Literal
#     sub-expressions:
# 17. x
#     core type: Variable
#     sub-expressions:
# 18. (n,n + 1)
#     core type: Operation
#     operator: 19
#     operands: 20
# 19. IntervalOO
#     core type: Literal
#     sub-expressions:
# 20. (n, n + 1)
#     core type: ExprTuple
#     sub-expressions: 24, 21
# 21. n + 1
#     core type: Operation
#     operator: 22
#     operands: 23
# 22. +
#     core type: Literal
#     sub-expressions:
# 23. (n, 1)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. n
#     core type: Variable
#     sub-expressions:
# 25. 1
#     core type: Literal
#     sub-expressions:
