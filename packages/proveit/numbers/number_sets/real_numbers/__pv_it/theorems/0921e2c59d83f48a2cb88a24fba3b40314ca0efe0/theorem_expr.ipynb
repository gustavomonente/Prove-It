# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#in_real_pos_iff_positive">in_real_pos_iff_positive</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.real_numbers import in_real_pos_iff_positive

# %%
# check that the built expression is the same as the stored expression
assert in_real_pos_iff_positive.expr == stored_expr
assert in_real_pos_iff_positive.expr._style_id == stored_expr._style_id
print("Passed sanity check: in_real_pos_iff_positive matches stored_expr")
# Out:
# Passed sanity check: in_real_pos_iff_positive matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(in_real_pos_iff_positive.latex())
# Out:
# \vdash \forall_{a \in \mathbb{R}}~\left(\left(a \in \mathbb{R}^+\right) \Leftrightarrow \left(a > 0\right)\right)

# %%
in_real_pos_iff_positive.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
in_real_pos_iff_positive.expr_info()
# Out:
# 0. forall_{a in Real} ((a in RealPos) <=> (a > 0))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a -> {(a in RealPos) <=> (a > 0) if a in Real.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. a -> {(a in RealPos) <=> (a > 0) if a in Real.
#    core type: Lambda
#    parameter: 19
#    body: 4
# 4. {(a in RealPos) <=> (a > 0) if a in Real.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (a in RealPos) <=> (a > 0)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. a in Real
#    core type: Operation
#    operator: 13
#    operands: 9
# 7. <=>
#    core type: Literal
#    sub-expressions:
# 8. (a in RealPos, a > 0)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. (a, Real)
#    core type: ExprTuple
#    sub-expressions: 19, 12
# 10. a in RealPos
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. a > 0
#     core type: Operation
# ...
