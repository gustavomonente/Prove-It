# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b
from proveit.logic import And, InSet, ProperSubset
from proveit.numbers import IntervalCC, RealNonNeg

# %%
# build up the expression from sub-expressions
expr = Conditional(ProperSubset(IntervalCC(a, b), RealNonNeg), And(InSet(a, RealNonNeg), InSet(b, RealNonNeg)))
# Out:
# expr: {[a,b] proper_subset RealNonNeg if a in RealNonNeg ,  b in RealNonNeg.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left[a,b\right] \subset \mathbb{R}^{\ge 0} \textrm{ if } a \in \mathbb{R}^{\ge 0} ,  b \in \mathbb{R}^{\ge 0}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {[a,b] proper_subset RealNonNeg if a in RealNonNeg ,  b in RealNonNeg.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. [a,b] proper_subset RealNonNeg
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a in RealNonNeg) and (b in RealNonNeg)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. proper_subset
#    core type: Literal
#    sub-expressions:
# 4. ([a,b], RealNonNeg)
#    core type: ExprTuple
#    sub-expressions: 7, 17
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in RealNonNeg, b in RealNonNeg)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. [a,b]
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. a in RealNonNeg
#    core type: Operation
#    operator: 13
#    operands: 12
# 9. b in RealNonNeg
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. IntervalCC
#     core type: Literal
#     sub-expressions:
# 11. (a, b)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 12. (a, RealNonNeg)
#     core type: ExprTuple
#     sub-expressions: 15, 17
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (b, RealNonNeg)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
# 17. RealNonNeg
#     core type: Literal
#     sub-expressions:
