# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#relax_IntervalOC">relax_IntervalOC</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.real_numbers import relax_IntervalOC

# %%
# check that the built expression is the same as the stored expression
assert relax_IntervalOC.expr == stored_expr
assert relax_IntervalOC.expr._style_id == stored_expr._style_id
print("Passed sanity check: relax_IntervalOC matches stored_expr")
# Out:
# Passed sanity check: relax_IntervalOC matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(relax_IntervalOC.latex())
# Out:
# \vdash \forall_{a, b \in \mathbb{R}}~\left[\forall_{x \in \left(a,b\right]}~\left(x \in \left[a,b\right]\right)\right]

# %%
relax_IntervalOC.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
relax_IntervalOC.expr_info()
# Out:
# 0. forall_{a, b in Real} [forall_{x in (a,b]} (x in [a,b])]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. ((a, b) -> {forall_{x in (a,b]} (x in [a,b]) if a in Real ,  b in Real.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (a, b) -> {forall_{x in (a,b]} (x in [a,b]) if a in Real ,  b in Real.
#    core type: Lambda
#    parameters: 27\n   body: 3
# 3. {forall_{x in (a,b]} (x in [a,b]) if a in Real ,  b in Real.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{x in (a,b]} (x in [a,b])
#    core type: Operation
#    operator: 6
#    operand: 10
# 5. (a in Real) and (b in Real)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (x -> {x in [a,b] if x in (a,b].)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Real, b in Real)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# ...
