# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b, x
from proveit.logic import And, Forall, InSet
from proveit.numbers import IntervalOO, Less, Real

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([x], Less(a, x), domains = [IntervalOO(a, b)]), And(InSet(a, Real), InSet(b, Real)))
# Out:
# expr: {forall_{x in (a,b)} (a < x) if a in Real ,  b in Real.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{x \in \left(a,b\right)}~\left(a < x\right) \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{x in (a,b)} (a < x) if a in Real ,  b in Real.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{x in (a,b)} (a < x)
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. (a in Real) and (b in Real)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (x -> {a < x if x in (a,b).)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in Real, b in Real)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. x -> {a < x if x in (a,b).
#    core type: Lambda
#    parameter: 20
#    body: 10
# 8. a in Real
#    core type: Operation
#    operator: 18
#    operands: 11
# 9. b in Real
#    core type: Operation
#    operator: 18
#    operands: 12
# 10. {a < x if x in (a,b).
#     core type: Conditional
#     value: 13
#     condition: 14
# 11. (a, Real)
#     core type: ExprTuple
#     sub-expressions: 24, 15
# 12. (b, Real)
#     core type: ExprTuple
#     sub-expressions: 25, 15
# 13. a < x
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. x in (a,b)
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. Real
#     core type: Literal
#     sub-expressions:
# 16. <
#     core type: Literal
#     sub-expressions:
# 17. (a, x)
#     core type: ExprTuple
#     sub-expressions: 24, 20
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (x, (a,b))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 20. x
#     core type: Variable
#     sub-expressions:
# 21. (a,b)
#     core type: Operation
#     operator: 22
#     operands: 23
# 22. IntervalOO
#     core type: Literal
#     sub-expressions:
# 23. (a, b)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. a
#     core type: Variable
#     sub-expressions:
# 25. b
#     core type: Variable
#     sub-expressions:
