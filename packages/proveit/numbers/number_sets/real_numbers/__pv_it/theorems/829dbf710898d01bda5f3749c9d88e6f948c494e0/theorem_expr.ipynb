# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#real_pos_interval_c_c_is_subset_of_RealPos">real_pos_interval_c_c_is_subset_of_RealPos</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.real_numbers import real_pos_interval_c_c_is_subset_of_RealPos

# %%
# check that the built expression is the same as the stored expression
assert real_pos_interval_c_c_is_subset_of_RealPos.expr == stored_expr
assert real_pos_interval_c_c_is_subset_of_RealPos.expr._style_id == stored_expr._style_id
print("Passed sanity check: real_pos_interval_c_c_is_subset_of_RealPos matches stored_expr")
# Out:
# Passed sanity check: real_pos_interval_c_c_is_subset_of_RealPos matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(real_pos_interval_c_c_is_subset_of_RealPos.latex())
# Out:
# \vdash \forall_{a, b \in \mathbb{R}^+}~\left(\left[a,b\right] \subset \mathbb{R}^+\right)

# %%
real_pos_interval_c_c_is_subset_of_RealPos.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
real_pos_interval_c_c_is_subset_of_RealPos.expr_info()
# Out:
# 0. forall_{a, b in RealPos} ([a,b] proper_subset RealPos)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b) -> {[a,b] proper_subset RealPos if a in RealPos ,  b in RealPos.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b) -> {[a,b] proper_subset RealPos if a in RealPos ,  b in RealPos.
#    core type: Lambda
#    parameters: 15\n   body: 4
# 4. {[a,b] proper_subset RealPos if a in RealPos ,  b in RealPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. [a,b] proper_subset RealPos
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a in RealPos) and (b in RealPos)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. proper_subset
#    core type: Literal
#    sub-expressions:
# 8. ([a,b], RealPos)
#    core type: ExprTuple
#    sub-expressions: 11, 21
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (a in RealPos, b in RealPos)
# ...
