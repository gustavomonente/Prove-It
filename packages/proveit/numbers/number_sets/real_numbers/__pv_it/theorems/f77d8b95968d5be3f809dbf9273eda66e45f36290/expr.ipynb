# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a, b, x
from proveit.logic import InSet
from proveit.numbers import IntervalOO, Less

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(x, Conditional(Less(x, b), InSet(x, IntervalOO(a, b)))))
# Out:
# expr: (x -> {x < b if x in (a,b).)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \mapsto \left\{x < b \textrm{ if } x \in \left(a,b\right)\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x -> {x < b if x in (a,b).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. x -> {x < b if x in (a,b).
#    core type: Lambda
#    parameter: 9
#    body: 2
# 2. {x < b if x in (a,b).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. x < b
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. x in (a,b)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. <
#    core type: Literal
#    sub-expressions:
# 6. (x, b)
#    core type: ExprTuple
#    sub-expressions: 9, 14
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (x, (a,b))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. x
#    core type: Variable
#    sub-expressions:
# 10. (a,b)
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. IntervalOO
#     core type: Literal
#     sub-expressions:
# 12. (a, b)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. a
#     core type: Variable
#     sub-expressions:
# 14. b
#     core type: Variable
#     sub-expressions:
