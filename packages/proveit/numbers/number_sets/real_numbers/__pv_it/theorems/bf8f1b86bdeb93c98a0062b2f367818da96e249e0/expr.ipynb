# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, x
from proveit.logic import And, InSet
from proveit.numbers import LessEq, Real

# %%
# build up the expression from sub-expressions
expr = And(InSet(a, Real), InSet(b, Real), InSet(x, Real), LessEq(a, x), LessEq(x, b))
# Out:
# expr: (a in Real) and (b in Real) and (x in Real) and (a <= x) and (x <= b)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{R}\right) \land \left(b \in \mathbb{R}\right) \land \left(x \in \mathbb{R}\right) \land \left(a \leq x\right) \land \left(x \leq b\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a in Real) and (b in Real) and (x in Real) and (a <= x) and (x <= b)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (a in Real, b in Real, x in Real, a <= x, x <= b)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6, 7
# 3. a in Real
#    core type: Operation
#    operator: 10
#    operands: 8
# 4. b in Real
#    core type: Operation
#    operator: 10
#    operands: 9
# 5. x in Real
#    core type: Operation
#    operator: 10
#    operands: 11
# 6. a <= x
#    core type: Operation
#    operator: 13
#    operands: 12
# 7. x <= b
#    core type: Operation
#    operator: 13
#    operands: 14
# 8. (a, Real)
#    core type: ExprTuple
#    sub-expressions: 16, 15
# 9. (b, Real)
#    core type: ExprTuple
#    sub-expressions: 18, 15
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (x, Real)
#     core type: ExprTuple
#     sub-expressions: 17, 15
# 12. (a, x)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 13. <=
#     core type: Literal
#     sub-expressions:
# 14. (x, b)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. Real
#     core type: Literal
#     sub-expressions:
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. x
#     core type: Variable
#     sub-expressions:
# 18. b
#     core type: Variable
#     sub-expressions:
