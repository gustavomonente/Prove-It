# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#rationals_neg_def">rationals_neg_def</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.rational_numbers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.rational_numbers import rationals_neg_def

# %%
# check that the built expression is the same as the stored expression
assert rationals_neg_def.expr == stored_expr
assert rationals_neg_def.expr._style_id == stored_expr._style_id
print("Passed sanity check: rationals_neg_def matches stored_expr")
# Out:
# Passed sanity check: rationals_neg_def matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(rationals_neg_def.latex())
# Out:
# \vdash \mathbb{Q}^- = \left\{q~|~q < 0\right\}_{q \in \mathbb{Q}}

# %%
rationals_neg_def.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
rationals_neg_def.expr_info()
# Out:
# 0. RationalNeg = {q s.t. q < 0}_{q in Rational}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (RationalNeg, {q s.t. q < 0}_{q in Rational})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. RationalNeg
#    core type: Literal
#    sub-expressions:
# 4. {q s.t. q < 0}_{q in Rational}
#    core type: Operation
#    operator: 5
#    operand: 7
# 5. SetOfAll
#    core type: Literal
#    sub-expressions:
# 6. (q -> {q if q in Rational ,  q < 0.)
#    core type: ExprTuple
#    sub-expressions: 7
# 7. q -> {q if q in Rational ,  q < 0.
#    core type: Lambda
#    parameter: 19
#    body: 8
# 8. {q if q in Rational ,  q < 0.
#    core type: Conditional
#    value: 19
#    condition: 9
# 9. (q in Rational) and (q < 0)
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (q in Rational, q < 0)
#     core type: ExprTuple
# ...
