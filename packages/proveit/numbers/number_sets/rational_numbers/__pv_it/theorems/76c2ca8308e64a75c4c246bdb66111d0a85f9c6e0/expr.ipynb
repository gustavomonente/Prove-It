# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.rational_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, q
from proveit.logic import Iff, InSet
from proveit.numbers import Rational, RationalPos, greater, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(q, Conditional(Iff(InSet(q, RationalPos), greater(q, zero)), InSet(q, Rational))))
# Out:
# expr: (q -> {(q in RationalPos) <=> (q > 0) if q in Rational.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(q \mapsto \left\{\left(q \in \mathbb{Q}^+\right) \Leftrightarrow \left(q > 0\right) \textrm{ if } q \in \mathbb{Q}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (q -> {(q in RationalPos) <=> (q > 0) if q in Rational.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. q -> {(q in RationalPos) <=> (q > 0) if q in Rational.
#    core type: Lambda
#    parameter: 17
#    body: 2
# 2. {(q in RationalPos) <=> (q > 0) if q in Rational.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (q in RationalPos) <=> (q > 0)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. q in Rational
#    core type: Operation
#    operator: 11
#    operands: 7
# 5. <=>
#    core type: Literal
#    sub-expressions:
# 6. (q in RationalPos, q > 0)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (q, Rational)
#    core type: ExprTuple
#    sub-expressions: 17, 10
# 8. q in RationalPos
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. q > 0
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. Rational
#     core type: Literal
#     sub-expressions:
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (q, RationalPos)
#     core type: ExprTuple
#     sub-expressions: 17, 15
# 13. <
#     core type: Literal
#     sub-expressions:
# 14. (0, q)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. RationalPos
#     core type: Literal
#     sub-expressions:
# 16. 0
#     core type: Literal
#     sub-expressions:
# 17. q
#     core type: Variable
#     sub-expressions:
