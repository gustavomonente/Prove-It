# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.rational_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, q
from proveit.logic import And, Equals, Exists, Forall
from proveit.numbers import GCD, NaturalPos, RationalPos, frac, one

# %%
# build up the expression from sub-expressions
expr = Forall([q], Exists([a, b], And(Equals(q, frac(a, b)), Equals(GCD(a, b), one)), domains = [NaturalPos, NaturalPos]), domains = [RationalPos])
# Out:
# expr: forall_{q in RationalPos} [exists_{a, b in NaturalPos} ((q = (a / b)) and (gcd(a, b) = 1))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{q \in \mathbb{Q}^+}~\left[\exists_{a, b \in \mathbb{N}^+}~\left(\left(q = \frac{a}{b}\right) \land \left(gcd(a, b) = 1\right)\right)\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{q in RationalPos} [exists_{a, b in NaturalPos} ((q = (a / b)) and (gcd(a, b) = 1))]
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (q -> {exists_{a, b in NaturalPos} ((q = (a / b)) and (gcd(a, b) = 1)) if q in RationalPos.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. q -> {exists_{a, b in NaturalPos} ((q = (a / b)) and (gcd(a, b) = 1)) if q in RationalPos.
#    core type: Lambda
#    parameter: 28
#    body: 4
# 4. {exists_{a, b in NaturalPos} ((q = (a / b)) and (gcd(a, b) = 1)) if q in RationalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. exists_{a, b in NaturalPos} ((q = (a / b)) and (gcd(a, b) = 1))
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. q in RationalPos
#    core type: Operation
#    operator: 26
#    operands: 9
# 7. exists
#    core type: Literal
#    sub-expressions:
# ...
