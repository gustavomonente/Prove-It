# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#nat_pos_within_rational_non_neg">nat_pos_within_rational_non_neg</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.ProperSubset.html">ProperSubset</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.rational_numbers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.rational_numbers import nat_pos_within_rational_non_neg

# %%
# check that the built expression is the same as the stored expression
assert nat_pos_within_rational_non_neg.expr == stored_expr
assert nat_pos_within_rational_non_neg.expr._style_id == stored_expr._style_id
print("Passed sanity check: nat_pos_within_rational_non_neg matches stored_expr")
# Out:
# Passed sanity check: nat_pos_within_rational_non_neg matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(nat_pos_within_rational_non_neg.latex())
# Out:
# \vdash \mathbb{N}^+ \subset \mathbb{Q}^{\geq 0}

# %%
nat_pos_within_rational_non_neg.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
nat_pos_within_rational_non_neg.expr_info()
# Out:
# 0. NaturalPos proper_subset RationalNonNeg
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. proper_subset
#    core type: Literal
#    sub-expressions:
# 2. (NaturalPos, RationalNonNeg)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. NaturalPos
#    core type: Literal
#    sub-expressions:
# 4. RationalNonNeg
#    core type: Literal
#    sub-expressions:
