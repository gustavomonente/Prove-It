# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.rational_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda, x
from proveit.logic import Boolean, InSet
from proveit.numbers import Rational

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(x, InSet(InSet(x, Rational), Boolean)))
# Out:
# expr: (x -> ((x in Rational) in BOOLEAN))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \mapsto \left(\left(x \in \mathbb{Q}\right) \in \mathbb{B}\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x -> ((x in Rational) in BOOLEAN))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. x -> ((x in Rational) in BOOLEAN)
#    core type: Lambda
#    parameter: 8
#    body: 2
# 2. (x in Rational) in BOOLEAN
#    core type: Operation
#    operator: 6
#    operands: 3
# 3. (x in Rational, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. x in Rational
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (x, Rational)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. x
#    core type: Variable
#    sub-expressions:
# 9. Rational
#    core type: Literal
#    sub-expressions:
