# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.rational_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, q
from proveit.logic import And, InSet
from proveit.numbers import Rational, RationalNonNeg, greater_eq, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(q, Conditional(InSet(q, RationalNonNeg), And(InSet(q, Rational), greater_eq(q, zero)))))
# Out:
# expr: (q -> {q in RationalNonNeg if q in Rational ,  q >= 0.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(q \mapsto \left\{q \in \mathbb{Q}^{\geq 0} \textrm{ if } q \in \mathbb{Q} ,  q \geq 0\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (q -> {q in RationalNonNeg if q in Rational ,  q >= 0.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. q -> {q in RationalNonNeg if q in Rational ,  q >= 0.
#    core type: Lambda
#    parameter: 17
#    body: 2
# 2. {q in RationalNonNeg if q in Rational ,  q >= 0.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. q in RationalNonNeg
#    core type: Operation
#    operator: 11
#    operands: 5
# 4. (q in Rational) and (q >= 0)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (q, RationalNonNeg)
#    core type: ExprTuple
#    sub-expressions: 17, 8
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (q in Rational, q >= 0)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. RationalNonNeg
#    core type: Literal
#    sub-expressions:
# 9. q in Rational
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. q >= 0
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (q, Rational)
#     core type: ExprTuple
#     sub-expressions: 17, 15
# 13. <=
#     core type: Literal
#     sub-expressions:
# 14. (0, q)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. Rational
#     core type: Literal
#     sub-expressions:
# 16. 0
#     core type: Literal
#     sub-expressions:
# 17. q
#     core type: Variable
#     sub-expressions:
