# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.natural_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, x
from proveit.logic import Boolean, InSet
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Lambda(x, InSet(InSet(x, Natural), Boolean))
# Out:
# expr: x -> ((x in Natural) in BOOLEAN)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# x \mapsto \left(\left(x \in \mathbb{N}\right) \in \mathbb{B}\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. x -> ((x in Natural) in BOOLEAN)
#    core type: Lambda
#    parameter: 7
#    body: 1
# 1. (x in Natural) in BOOLEAN
#    core type: Operation
#    operator: 5
#    operands: 2
# 2. (x in Natural, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. x in Natural
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (x, Natural)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. x
#    core type: Variable
#    sub-expressions:
# 8. Natural
#    core type: Literal
#    sub-expressions:
