# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.natural_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, S, x
from proveit.logic import And, Forall, Implies, InSet, SetEquiv, SubsetEq
from proveit.numbers import Add, Natural, one, zero

# %%
# build up the expression from sub-expressions
expr = Lambda(S, Conditional(Implies(And(InSet(zero, S), Forall([x], InSet(Add(x, one), S), domains = [S])), SetEquiv(S, Natural)), SubsetEq(S, Natural)))
# Out:
# expr: S -> {((0 in S) and [forall_{x in S} ((x + 1) in S)]) => (S equiv Natural) if S subset_eq Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# S \mapsto \left\{\left(\left(0 \in S\right) \land \left[\forall_{x \in S}~\left(\left(x + 1\right) \in S\right)\right]\right) \Rightarrow \left(S \cong \mathbb{N}\right) \textrm{ if } S \subseteq \mathbb{N}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. S -> {((0 in S) and [forall_{x in S} ((x + 1) in S)]) => (S equiv Natural) if S subset_eq Natural.
#    core type: Lambda
#    parameter: 28
#    body: 1
# 1. {((0 in S) and [forall_{x in S} ((x + 1) in S)]) => (S equiv Natural) if S subset_eq Natural.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. ((0 in S) and [forall_{x in S} ((x + 1) in S)]) => (S equiv Natural)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. S subset_eq Natural
#    core type: Operation
#    operator: 6
#    operands: 12
# 4. =>
#    core type: Literal
#    sub-expressions:
# 5. ((0 in S) and [forall_{x in S} ((x + 1) in S)], S equiv Natural)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. subset_eq
#    core type: Literal
#    sub-expressions:
# 7. (0 in S) and [forall_{x in S} ((x + 1) in S)]
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. S equiv Natural
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (0 in S, forall_{x in S} ((x + 1) in S))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. equiv
#     core type: Literal
#     sub-expressions:
# 12. (S, Natural)
#     core type: ExprTuple
#     sub-expressions: 28, 15
# 13. 0 in S
#     core type: Operation
#     operator: 25
#     operands: 16
# 14. forall_{x in S} ((x + 1) in S)
#     core type: Operation
#     operator: 17
#     operand: 20
# 15. Natural
#     core type: Literal
#     sub-expressions:
# 16. (0, S)
#     core type: ExprTuple
#     sub-expressions: 19, 28
# 17. forall
#     core type: Literal
#     sub-expressions:
# 18. (x -> {(x + 1) in S if x in S.)
#     core type: ExprTuple
#     sub-expressions: 20
# 19. 0
#     core type: Literal
#     sub-expressions:
# 20. x -> {(x + 1) in S if x in S.
#     core type: Lambda
#     parameter: 31
#     body: 21
# 21. {(x + 1) in S if x in S.
#     core type: Conditional
#     value: 22
#     condition: 23
# 22. (x + 1) in S
#     core type: Operation
#     operator: 25
#     operands: 24
# 23. x in S
#     core type: Operation
#     operator: 25
#     operands: 26
# 24. (x + 1, S)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. in
#     core type: Literal
#     sub-expressions:
# 26. (x, S)
#     core type: ExprTuple
#     sub-expressions: 31, 28
# 27. x + 1
#     core type: Operation
#     operator: 29
#     operands: 30
# 28. S
#     core type: Variable
#     sub-expressions:
# 29. +
#     core type: Literal
#     sub-expressions:
# 30. (x, 1)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 31. x
#     core type: Variable
#     sub-expressions:
# 32. 1
#     core type: Literal
#     sub-expressions:
