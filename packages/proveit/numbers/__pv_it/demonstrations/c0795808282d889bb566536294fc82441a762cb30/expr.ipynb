# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b, c, x, y
from proveit.numbers import Add, Mult

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Mult(a, Add(x, b), c), Mult(Mult(a, Add(y, b)), c))
# Out:
# expr: (a * (x + b) * c, (a * (y + b)) * c)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \cdot \left(x + b\right) \cdot c, \left(a \cdot \left(y + b\right)\right) \cdot c\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a * (x + b) * c, (a * (y + b)) * c)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. a * (x + b) * c
#    core type: Operation
#    operator: 9
#    operands: 3
# 2. (a * (y + b)) * c
#    core type: Operation
#    operator: 9
#    operands: 4
# 3. (a, x + b, c)
#    core type: ExprTuple
#    sub-expressions: 12, 5, 7
# 4. (a * (y + b), c)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. x + b
#    core type: Operation
#    operator: 14
#    operands: 8
# 6. a * (y + b)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. c
#    core type: Variable
#    sub-expressions:
# 8. (x, b)
#    core type: ExprTuple
#    sub-expressions: 11, 17
# 9. *
#    core type: Literal
#    sub-expressions:
# 10. (a, y + b)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. x
#     core type: Variable
#     sub-expressions:
# 12. a
#     core type: Variable
#     sub-expressions:
# 13. y + b
#     core type: Operation
#     operator: 14
#     operands: 15
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (y, b)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. y
#     core type: Variable
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
