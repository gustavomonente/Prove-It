# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#P_nAddOne">P_nAddOne</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Function.html">Function</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.numbers import P_nAddOne

# %%
# check that the built expression is the same as the stored expression
assert P_nAddOne == stored_expr
assert P_nAddOne._style_id == stored_expr._style_id
print("Passed sanity check: P_nAddOne matches stored_expr")
# Out:
# Passed sanity check: P_nAddOne matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(P_nAddOne.latex())
# Out:
# P(n + 1)

# %%
P_nAddOne.style_options()
# Out:
# no style options

# %%
# display the expression information
P_nAddOne.expr_info()
# Out:
# 0. P(n + 1)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. P
#    core type: Variable
#    sub-expressions:
# 2. (n + 1)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. n + 1
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (n, 1)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. n
#    core type: Variable
#    sub-expressions:
# 7. 1
#    core type: Literal
#    sub-expressions:
