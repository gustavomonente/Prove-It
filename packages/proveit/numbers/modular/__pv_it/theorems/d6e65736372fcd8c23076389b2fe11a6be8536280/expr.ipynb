# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.modular</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, N, a, b, c, x
from proveit.logic import InSet
from proveit.numbers import Add, Interval, Mod

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(x, Conditional(Mod(Add(c, x), N), InSet(x, Interval(a, b)))))
# Out:
# expr: (x -> {(c + x) mod  N if x in {a...b}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \mapsto \left\{\left(c + x\right) ~\textup{mod}~ N \textrm{ if } x \in \{a \ldots b\}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x -> {(c + x) mod  N if x in {a...b}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. x -> {(c + x) mod  N if x in {a...b}.
#    core type: Lambda
#    parameter: 17
#    body: 2
# 2. {(c + x) mod  N if x in {a...b}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (c + x) mod  N
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. x in {a...b}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. mod
#    core type: Literal
#    sub-expressions:
# 6. (c + x, N)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (x, {a...b})
#    core type: ExprTuple
#    sub-expressions: 17, 11
# 9. c + x
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. N
#     core type: Variable
#     sub-expressions:
# 11. {a...b}
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (c, x)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. Interval
#     core type: Literal
#     sub-expressions:
# 15. (a, b)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. c
#     core type: Variable
#     sub-expressions:
# 17. x
#     core type: Variable
#     sub-expressions:
# 18. a
#     core type: Variable
#     sub-expressions:
# 19. b
#     core type: Variable
#     sub-expressions:
