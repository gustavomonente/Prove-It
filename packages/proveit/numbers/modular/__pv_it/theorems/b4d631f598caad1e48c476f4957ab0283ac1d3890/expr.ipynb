# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.modular</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, N, a, b, c, x
from proveit.logic import And, Equals, InSet, NotEquals, SetOfAll
from proveit.numbers import Add, Integer, Interval, Mod, Neg, one, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(N, Neg(one))
expr = Lambda([N, a, b, c], Conditional(Equals(SetOfAll([x], Mod(Add(x, c), N), domains = [Interval(a, b)]), Interval(zero, sub_expr1)), And(InSet(N, Integer), InSet(a, Integer), InSet(b, Integer), InSet(c, Integer), Equals(Add(b, Neg(a)), sub_expr1), NotEquals(N, zero))))
# Out:
# expr: (N, a, b, c) -> {{(x + c) mod  N}_{x in {a...b}} = {0...N - 1} if N in Integer ,  a in Integer ,  b in Integer ,  c in Integer ,  (b - a) = (N - 1) ,  N != 0.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(N, a, b, c\right) \mapsto \left\{\left\{\left(x + c\right) ~\textup{mod}~ N\right\}_{x \in \{a \ldots b\}} = \{0 \ldots N - 1\} \textrm{ if } N \in \mathbb{Z} ,  a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  c \in \mathbb{Z} ,  \left(b - a\right) = \left(N - 1\right) ,  N \neq 0\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (N, a, b, c) -> {{(x + c) mod  N}_{x in {a...b}} = {0...N - 1} if N in Integer ,  a in Integer ,  b in Integer ,  c in Integer ,  (b - a) = (N - 1) ,  N != 0.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (N, a, b, c)
#    core type: ExprTuple
#    sub-expressions: 47, 56, 57, 55
# 2. {{(x + c) mod  N}_{x in {a...b}} = {0...N - 1} if N in Integer ,  a in Integer ,  b in Integer ,  c in Integer ,  (b - a) = (N - 1) ,  N != 0.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. {(x + c) mod  N}_{x in {a...b}} = {0...N - 1}
#    core type: Operation
#    operator: 23
#    operands: 5
# 4. (N in Integer) and (a in Integer) and (b in Integer) and (c in Integer) and ((b - a) = (N - 1)) and (N != 0)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. ({(x + c) mod  N}_{x in {a...b}}, {0...N - 1})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# ...
