# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#full_modular_range_equiv_right_shift">full_modular_range_equiv_right_shift</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.modular</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.modular import full_modular_range_equiv_right_shift

# %%
# check that the built expression is the same as the stored expression
assert full_modular_range_equiv_right_shift.expr == stored_expr
assert full_modular_range_equiv_right_shift.expr._style_id == stored_expr._style_id
print("Passed sanity check: full_modular_range_equiv_right_shift matches stored_expr")
# Out:
# Passed sanity check: full_modular_range_equiv_right_shift matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(full_modular_range_equiv_right_shift.latex())
# Out:
# \vdash \forall_{N, a, b, c \in \mathbb{Z}~|~\left(b - a\right) = \left(N - 1\right), N \neq 0}~\left(\left\{\left(x + c\right) ~\textup{mod}~ N\right\}_{x \in \{a \ldots b\}} = \{0 \ldots N - 1\}\right)

# %%
full_modular_range_equiv_right_shift.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
full_modular_range_equiv_right_shift.expr_info()
# Out:
# 0. forall_{N, a, b, c in Integer | (b - a) = (N - 1), N != 0} ({(x + c) mod  N}_{x in {a...b}} = {0...N - 1})
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((N, a, b, c) -> {{(x + c) mod  N}_{x in {a...b}} = {0...N - 1} if N in Integer ,  a in Integer ,  b in Integer ,  c in Integer ,  (b - a) = (N - 1) ,  N != 0.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (N, a, b, c) -> {{(x + c) mod  N}_{x in {a...b}} = {0...N - 1} if N in Integer ,  a in Integer ,  b in Integer ,  c in Integer ,  (b - a) = (N - 1) ,  N != 0.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (N, a, b, c)
#    core type: ExprTuple
#    sub-expressions: 50, 59, 60, 58
# 5. {{(x + c) mod  N}_{x in {a...b}} = {0...N - 1} if N in Integer ,  a in Integer ,  b in Integer ,  c in Integer ,  (b - a) = (N - 1) ,  N != 0.
#    core type: Conditional
#    value: 6
#    condition: 7
# ...
