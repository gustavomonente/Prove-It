# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.modular</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a, b
from proveit.logic import And, InSet, NotEquals
from proveit.numbers import Abs, Add, Integer, Interval, Mod, Neg, one, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([a, b], Conditional(InSet(Mod(a, b), Interval(zero, Add(Abs(b), Neg(one)))), And(InSet(a, Integer), InSet(b, Integer), NotEquals(b, zero)))))
# Out:
# expr: ((a, b) -> {(a mod  b) in {0...|b| - 1} if a in Integer ,  b in Integer ,  b != 0.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a, b\right) \mapsto \left\{\left(a ~\textup{mod}~ b\right) \in \{0 \ldots \left|b\right| - 1\} \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  b \neq 0\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a, b) -> {(a mod  b) in {0...|b| - 1} if a in Integer ,  b in Integer ,  b != 0.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a, b) -> {(a mod  b) in {0...|b| - 1} if a in Integer ,  b in Integer ,  b != 0.
#    core type: Lambda
#    parameters: 14\n   body: 2
# 2. {(a mod  b) in {0...|b| - 1} if a in Integer ,  b in Integer ,  b != 0.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (a mod  b) in {0...|b| - 1}
#    core type: Operation
#    operator: 18
#    operands: 5
# 4. (a in Integer) and (b in Integer) and (b != 0)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a mod  b, {0...|b| - 1})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a in Integer, b in Integer, b != 0)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 8. a mod  b
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. {0...|b| - 1}
#    core type: Operation
# ...
