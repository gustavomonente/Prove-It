# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.divisibility</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, k, n
from proveit.logic import And, InSet
from proveit.numbers import Divides, Exp, Integer, NaturalPos

# %%
# build up the expression from sub-expressions
expr = Lambda([k, a, n], Conditional(Divides(Exp(k, n), Exp(a, n)), And(InSet(k, Integer), InSet(a, Integer), InSet(n, NaturalPos), Divides(k, a))))
# Out:
# expr: (k, a, n) -> {k^{n} | a^{n} if k in Integer ,  a in Integer ,  n in NaturalPos ,  k | a.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(k, a, n\right) \mapsto \left\{k^{n} \rvert a^{n} \textrm{ if } k \in \mathbb{Z} ,  a \in \mathbb{Z} ,  n \in \mathbb{N}^+ ,  k \rvert a\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (k, a, n) -> {k^{n} | a^{n} if k in Integer ,  a in Integer ,  n in NaturalPos ,  k | a.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (k, a, n)
#    core type: ExprTuple
#    sub-expressions: 26, 27, 24
# 2. {k^{n} | a^{n} if k in Integer ,  a in Integer ,  n in NaturalPos ,  k | a.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. k^{n} | a^{n}
#    core type: Operation
#    operator: 21
#    operands: 5
# 4. (k in Integer) and (a in Integer) and (n in NaturalPos) and (k | a)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (k^{n}, a^{n})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (k in Integer, a in Integer, n in NaturalPos, k | a)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12, 13
# 8. k^{n}
#    core type: Operation
#    operator: 15
#    operands: 14
# 9. a^{n}
#    core type: Operation
#    operator: 15
#    operands: 16
# 10. k in Integer
# ...
