# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.divisibility</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, x
from proveit.logic import And, InSet, NotEquals
from proveit.numbers import Complex, Divides, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(Divides(x, zero), And(InSet(x, Complex), NotEquals(x, zero)))
# Out:
# expr: {x | 0 if x in Complex ,  x != 0.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{x \rvert 0 \textrm{ if } x \in \mathbb{C} ,  x \neq 0\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {x | 0 if x in Complex ,  x != 0.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. x | 0
#    core type: Operation
#    operator: 3
#    operands: 11
# 2. (x in Complex) and (x != 0)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. |
#    core type: Literal
#    sub-expressions:
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (x in Complex, x != 0)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. x in Complex
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. x != 0
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (x, Complex)
#    core type: ExprTuple
#    sub-expressions: 13, 12
# 10. !=
#     core type: Literal
#     sub-expressions:
# 11. (x, 0)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. Complex
#     core type: Literal
#     sub-expressions:
# 13. x
#     core type: Variable
#     sub-expressions:
# 14. 0
#     core type: Literal
#     sub-expressions:
