# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">numbers</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">numerals</a>.<a class="ProveItLink" href="../../theory.ipynb">decimals</a>.<a class="ProveItLink" href="../../theorems.ipynb#tuple_len_5">tuple_len_5</a> theorem
# ========

# %%
import proveit
from proveit import a, b, e, i
from proveit.core_expr_types.tuples  import tuple_len_incr
from proveit.numbers.numerals.decimals import tuple_len_4, add_4_1
theory = proveit.Theory() # the theorem's theory

# %%
# %proving tuple_len_5
# Out:
# tuple_len_5: forall_{a, b, c, d, e} (|(a, b, c, d, e)| = 5)

# %%
one_spec = tuple_len_4.instantiate({a:a})
# Out:
# one_spec: |- |(a, b, c, d)| = 4

# %%
tuple_spec = tuple_len_incr.instantiate({i: one_spec.rhs, a: one_spec.lhs.operands[0], b: e})
# Out:
# tuple_spec: |- |(a, b, c, d, e)| = (4 + 1)

# %%
spec = tuple_spec.apply_transitivity(add_4_1)
# Out:
# spec: |- |(a, b, c, d, e)| = 5

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{a, b, c, d, e} (|(a, b, c, d, e)| = 5)
# 1	instantiation	2, 3, 4	|- |(a, b, c, d, e)| = 5
# 	x : |(a, b, c, d, e)|, y : 4 + 1, z : 5
# 2	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 3	instantiation	5, 6, 7	|- |(a, b, c, d, e)| = (4 + 1)
# 	i : 4, a : (a, b, c, d), b : e
# 4	conjecture		|- (4 + 1) = 5
# 5	axiom		|- forall_{i in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b} (|(a_{1}, ..a_{_a}.., a_{i}, b)| = (i + 1))]
# 	proveit.core_expr_types.tuples.tuple_len_incr
# 6	conjecture		|- 4 in Natural
# 7	instantiation	8	|- |(a, b, c, d)| = |(1, ..k.., 4)|
# 	a : a, b : b, c : c, d : d
# 8	conjecture		|- forall_{a, b, c, d} (|(a, b, c, d)| = |(1, ..k.., 4)|)
