# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#md_nine_add_one">md_nine_add_one</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.numerals.decimals import md_nine_add_one

# %%
# check that the built expression is the same as the stored expression
assert md_nine_add_one.expr == stored_expr
assert md_nine_add_one.expr._style_id == stored_expr._style_id
print("Passed sanity check: md_nine_add_one matches stored_expr")
# Out:
# Passed sanity check: md_nine_add_one matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(md_nine_add_one.latex())
# Out:
# \vdash \forall_{m, k \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{m}, b \in \mathbb{N}^{\leq 9}~|~b < 9}~\left(\left(\# (a_{1} ~ \ldots ~ a_{m} ~ b ~ 9 ~ ..k \textrm{ repeats}.. ~ 9) + 1\right) = \# (a_{1} ~ \ldots ~ a_{m} ~ \left(b + 1\right) ~ 0 ~ ..k \textrm{ repeats}.. ~ 0)\right)\right]

# %%
md_nine_add_one.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
md_nine_add_one.expr_info()
# Out:
# 0. forall_{m, k in Natural} [forall_{a_{1}, ..a_{_a}.., a_{m}, b in Digits | b < 9} ((\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ 9 ~ ..k repeats.. ~ 9) + 1) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b + 1) ~ 0 ~ ..k repeats.. ~ 0))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((m, k) -> {forall_{a_{1}, ..a_{_a}.., a_{m}, b in Digits | b < 9} ((\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ 9 ~ ..k repeats.. ~ 9) + 1) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b + 1) ~ 0 ~ ..k repeats.. ~ 0)) if m in Natural ,  k in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (m, k) -> {forall_{a_{1}, ..a_{_a}.., a_{m}, b in Digits | b < 9} ((\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ 9 ~ ..k repeats.. ~ 9) + 1) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b + 1) ~ 0 ~ ..k repeats.. ~ 0)) if m in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (m, k)
#    core type: ExprTuple
#    sub-expressions: 52, 55
# ...
