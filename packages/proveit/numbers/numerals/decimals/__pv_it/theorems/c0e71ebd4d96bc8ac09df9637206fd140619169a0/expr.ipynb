# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, ExprTuple, IndexedVar, Lambda, Variable, a, n
from proveit.core_expr_types import a_1_to_n
from proveit.logic import And, InSet
from proveit.numbers import DecimalSequence, NaturalPos, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(Lambda([a_1_to_n], Conditional(InSet(DecimalSequence(a_1_to_n), NaturalPos), And(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), NaturalPos), one, n)))))
# Out:
# expr: ((a_{1}, ..a_{_a}.., a_{n}) -> {\# (a_{1} ~ ..a_{_a}.. ~ a_{n}) in NaturalPos if (a_{1} in NaturalPos) and ..(a_{_a} in NaturalPos).. and (a_{n} in NaturalPos).)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a_{1}, \ldots, a_{n}\right) \mapsto \left\{\# (a_{1} ~ \ldots ~ a_{n}) \in \mathbb{N}^+ \textrm{ if } \left(a_{1} \in \mathbb{N}^+\right) \land \ldots \land \left(a_{n} \in \mathbb{N}^+\right)\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a_{1}, ..a_{_a}.., a_{n}) -> {\# (a_{1} ~ ..a_{_a}.. ~ a_{n}) in NaturalPos if (a_{1} in NaturalPos) and ..(a_{_a} in NaturalPos).. and (a_{n} in NaturalPos).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a_{1}, ..a_{_a}.., a_{n}) -> {\# (a_{1} ~ ..a_{_a}.. ~ a_{n}) in NaturalPos if (a_{1} in NaturalPos) and ..(a_{_a} in NaturalPos).. and (a_{n} in NaturalPos).
#    core type: Lambda
#    parameters: 11\n   body: 2
# 2. {\# (a_{1} ~ ..a_{_a}.. ~ a_{n}) in NaturalPos if (a_{1} in NaturalPos) and ..(a_{_a} in NaturalPos).. and (a_{n} in NaturalPos).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. \# (a_{1} ~ ..a_{_a}.. ~ a_{n}) in NaturalPos
#    core type: Operation
#    operator: 18
#    operands: 5
# 4. (a_{1} in NaturalPos) and ..(a_{_a} in NaturalPos).. and (a_{n} in NaturalPos)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (\# (a_{1} ~ ..a_{_a}.. ~ a_{n}), NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 8, 21
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a_{1} in NaturalPos, ..a_{_a} in NaturalPos.., a_{n} in NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. \# (a_{1} ~ ..a_{_a}.. ~ a_{n})
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (a_{1} in NaturalPos), ..(a_{_a} in NaturalPos).., (a_{n} in NaturalPos)
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 16
#    end_index: 17
# 10. Decimal
#     core type: Literal
#     sub-expressions:
# 11. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 13
# 12. _a -> (a_{_a} in NaturalPos)
#     core type: Lambda
#     parameter: 24
#     body: 14
# 13. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 16
#     end_index: 17
# 14. a_{_a} in NaturalPos
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. _a -> a_{_a}
#     core type: Lambda
#     parameter: 24
#     body: 20
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. n
#     core type: Variable
#     sub-expressions:
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (a_{_a}, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 20. a_{_a}
#     core type: IndexedVar
# variable: 22
# index: 24
# 21. NaturalPos
#     core type: Literal
#     sub-expressions:
# 22. a
#     core type: Variable
#     sub-expressions:
# 23. (_a)
#     core type: ExprTuple
#     sub-expressions: 24
# 24. _a
#     core type: Variable
#     sub-expressions:
