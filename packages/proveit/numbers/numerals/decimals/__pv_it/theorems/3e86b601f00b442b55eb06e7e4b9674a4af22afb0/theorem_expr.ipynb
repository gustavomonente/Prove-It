# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#mult_8_6">mult_8_6</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.numerals.decimals import mult_8_6

# %%
# check that the built expression is the same as the stored expression
assert mult_8_6.expr == stored_expr
assert mult_8_6.expr._style_id == stored_expr._style_id
print("Passed sanity check: mult_8_6 matches stored_expr")
# Out:
# Passed sanity check: mult_8_6 matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(mult_8_6.latex())
# Out:
# \vdash \left(8 \cdot 6\right) = 48

# %%
mult_8_6.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
mult_8_6.expr_info()
# Out:
# 0. (8 * 6) = 48
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (8 * 6, 48)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 8 * 6
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. 48
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. *
#    core type: Literal
#    sub-expressions:
# 6. (8, 6)
#    core type: ExprTuple
#    sub-expressions: 11, 9
# 7. Decimal
#    core type: Literal
#    sub-expressions:
# 8. (4, 8)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. 6
#    core type: Literal
#    sub-expressions:
# 10. 4
#     core type: Literal
#     sub-expressions:
# 11. 8
#     core type: Literal
#     sub-expressions:
