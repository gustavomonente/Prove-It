# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#digit2">digit2</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.numerals.decimals import digit2

# %%
# check that the built expression is the same as the stored expression
assert digit2.expr == stored_expr
assert digit2.expr._style_id == stored_expr._style_id
print("Passed sanity check: digit2 matches stored_expr")
# Out:
# Passed sanity check: digit2 matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(digit2.latex())
# Out:
# \vdash 2 \in \mathbb{N}^{\leq 9}

# %%
digit2.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
digit2.expr_info()
# Out:
# 0. 2 in Digits
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (2, Digits)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 2
#    core type: Literal
#    sub-expressions:
# 4. Digits
#    core type: Literal
#    sub-expressions:
