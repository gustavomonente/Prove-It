# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Lambda, a, b, c, d, e, f, g, h, k
from proveit.core_expr_types import Len
from proveit.logic import Equals
from proveit.numbers import eight, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [a, b, c, d, e, f, g, h]
expr = ExprTuple(Lambda(sub_expr1, Equals(Len(sub_expr1), Len([ExprRange(k, k, one, eight)]))))
# Out:
# expr: ((a, b, c, d, e, f, g, h) -> (|(a, b, c, d, e, f, g, h)| = |(1, ..k.., 8)|))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a, b, c, d, e, f, g, h\right) \mapsto \left(|\left(a, b, c, d, e, f, g, h\right)| = |\left(1, \ldots, 8\right)|\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a, b, c, d, e, f, g, h) -> (|(a, b, c, d, e, f, g, h)| = |(1, ..k.., 8)|))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a, b, c, d, e, f, g, h) -> (|(a, b, c, d, e, f, g, h)| = |(1, ..k.., 8)|)
#    core type: Lambda
#    parameters: 10\n   body: 2
# 2. |(a, b, c, d, e, f, g, h)| = |(1, ..k.., 8)|
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (|(a, b, c, d, e, f, g, h)|, |(1, ..k.., 8)|)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. |(a, b, c, d, e, f, g, h)|
#    core type: Operation
#    operator: 8
#    operand: 10
# 6. |(1, ..k.., 8)|
#    core type: Operation
#    operator: 8
#    operand: 11
# 7. ((a, b, c, d, e, f, g, h))
#    core type: ExprTuple
#    sub-expressions: 10
# 8. length
#    core type: Literal
#    sub-expressions:
# 9. ((1, ..k.., 8))
#    core type: ExprTuple
#    sub-expressions: 11
# 10. (a, b, c, d, e, f, g, h)
#     core type: ExprTuple
# ...
