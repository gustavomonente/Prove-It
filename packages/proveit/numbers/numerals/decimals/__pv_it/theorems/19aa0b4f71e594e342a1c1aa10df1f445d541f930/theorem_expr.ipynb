# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#add_9_0">add_9_0</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.numerals.decimals import add_9_0

# %%
# check that the built expression is the same as the stored expression
assert add_9_0.expr == stored_expr
assert add_9_0.expr._style_id == stored_expr._style_id
print("Passed sanity check: add_9_0 matches stored_expr")
# Out:
# Passed sanity check: add_9_0 matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(add_9_0.latex())
# Out:
# \vdash \left(9 + 0\right) = 9

# %%
add_9_0.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
add_9_0.expr_info()
# Out:
# 0. (9 + 0) = 9
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (9 + 0, 9)
#    core type: ExprTuple
#    sub-expressions: 3, 6
# 3. 9 + 0
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (9, 0)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. 9
#    core type: Literal
#    sub-expressions:
# 7. 0
#    core type: Literal
#    sub-expressions:
