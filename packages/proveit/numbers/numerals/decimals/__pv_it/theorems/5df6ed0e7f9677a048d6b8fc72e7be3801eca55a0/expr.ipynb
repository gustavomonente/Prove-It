# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, a, b, c, d, e, f, g, h, i
from proveit.core_expr_types import Len
from proveit.logic import Equals
from proveit.numbers import nine

# %%
# build up the expression from sub-expressions
sub_expr1 = [a, b, c, d, e, f, g, h, i]
expr = Lambda(sub_expr1, Equals(Len(sub_expr1), nine))
# Out:
# expr: (a, b, c, d, e, f, g, h, i) -> (|(a, b, c, d, e, f, g, h, i)| = 9)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b, c, d, e, f, g, h, i\right) \mapsto \left(|\left(a, b, c, d, e, f, g, h, i\right)| = 9\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, b, c, d, e, f, g, h, i) -> (|(a, b, c, d, e, f, g, h, i)| = 9)
#    core type: Lambda
#    parameters: 8\n   body: 1
# 1. |(a, b, c, d, e, f, g, h, i)| = 9
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. =
#    core type: Literal
#    sub-expressions:
# 3. (|(a, b, c, d, e, f, g, h, i)|, 9)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. |(a, b, c, d, e, f, g, h, i)|
#    core type: Operation
#    operator: 6
#    operand: 8
# 5. 9
#    core type: Literal
#    sub-expressions:
# 6. length
#    core type: Literal
#    sub-expressions:
# 7. ((a, b, c, d, e, f, g, h, i))
#    core type: ExprTuple
#    sub-expressions: 8
# 8. (a, b, c, d, e, f, g, h, i)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 12, 13, 14, 15, 16, 17
# 9. a
#    core type: Variable
#    sub-expressions:
# 10. b
#     core type: Variable
#     sub-expressions:
# 11. c
#     core type: Variable
#     sub-expressions:
# 12. d
#     core type: Variable
#     sub-expressions:
# 13. e
#     core type: Variable
#     sub-expressions:
# 14. f
#     core type: Variable
#     sub-expressions:
# 15. g
#     core type: Variable
#     sub-expressions:
# 16. h
#     core type: Variable
#     sub-expressions:
# 17. i
#     core type: Variable
#     sub-expressions:
