# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, ExprTuple, IndexedVar, Lambda, Variable, a, b, c, d, k, m, n
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Add, DecimalSequence, Digits, Natural, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = ExprRange(sub_expr1, IndexedVar(a, sub_expr1), one, m)
sub_expr3 = ExprRange(sub_expr1, IndexedVar(b, sub_expr1), one, n)
sub_expr4 = ExprRange(sub_expr1, IndexedVar(d, sub_expr1), one, k)
sub_expr5 = Add(sub_expr3)
expr = ExprTuple(Lambda([m, n, k], Conditional(Forall([sub_expr2, sub_expr3, c, sub_expr4], Equals(DecimalSequence(sub_expr2, sub_expr5, sub_expr4), DecimalSequence(sub_expr2, c, sub_expr4)), domains = [Digits, Digits, Digits, Digits], condition = Equals(sub_expr5, c)), And(InSet(m, Natural), InSet(n, Natural), InSet(k, Natural)))))
# Out:
# expr: ((m, n, k) -> {forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}, c, d_{1}, ..d_{_a}.., d_{k} in Digits | (b_{1} + ..b_{_a}.. + b_{n}) = c} (\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b_{1} + ..b_{_a}.. + b_{n}) ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c ~ d_{1} ~ ..d_{_a}.. ~ d_{k})) if m in Natural ,  n in Natural ,  k in Natural.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(m, n, k\right) \mapsto \left\{\forall_{a_{1}, \ldots, a_{m}, b_{1}, \ldots, b_{n}, c, d_{1}, \ldots, d_{k} \in \mathbb{N}^{\leq 9}~|~\left(b_{1} + \ldots + b_{n}\right) = c}~\left(\# (a_{1} ~ \ldots ~ a_{m} ~ \left(b_{1} + \ldots + b_{n}\right) ~ d_{1} ~ \ldots ~ d_{k}) = \# (a_{1} ~ \ldots ~ a_{m} ~ c ~ d_{1} ~ \ldots ~ d_{k})\right) \textrm{ if } m \in \mathbb{N} ,  n \in \mathbb{N} ,  k \in \mathbb{N}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((m, n, k) -> {forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}, c, d_{1}, ..d_{_a}.., d_{k} in Digits | (b_{1} + ..b_{_a}.. + b_{n}) = c} (\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b_{1} + ..b_{_a}.. + b_{n}) ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c ~ d_{1} ~ ..d_{_a}.. ~ d_{k})) if m in Natural ,  n in Natural ,  k in Natural.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (m, n, k) -> {forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}, c, d_{1}, ..d_{_a}.., d_{k} in Digits | (b_{1} + ..b_{_a}.. + b_{n}) = c} (\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b_{1} + ..b_{_a}.. + b_{n}) ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c ~ d_{1} ~ ..d_{_a}.. ~ d_{k})) if m in Natural ,  n in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (m, n, k)
#    core type: ExprTuple
#    sub-expressions: 48, 65, 50
# ...
