# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, a, b, c, d, e, f, g, h, i, k
from proveit.core_expr_types import Len
from proveit.logic import Equals, Forall
from proveit.numbers import nine, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [a, b, c, d, e, f, g, h, i]
expr = Forall(sub_expr1, Equals(Len(sub_expr1), Len([ExprRange(k, k, one, nine)])))
# Out:
# expr: forall_{a, b, c, d, e, f, g, h, i} (|(a, b, c, d, e, f, g, h, i)| = |(1, ..k.., 9)|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a, b, c, d, e, f, g, h, i}~\left(|\left(a, b, c, d, e, f, g, h, i\right)| = |\left(1, \ldots, 9\right)|\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a, b, c, d, e, f, g, h, i} (|(a, b, c, d, e, f, g, h, i)| = |(1, ..k.., 9)|)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b, c, d, e, f, g, h, i) -> (|(a, b, c, d, e, f, g, h, i)| = |(1, ..k.., 9)|))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b, c, d, e, f, g, h, i) -> (|(a, b, c, d, e, f, g, h, i)| = |(1, ..k.., 9)|)
#    core type: Lambda
#    parameters: 12\n   body: 4
# 4. |(a, b, c, d, e, f, g, h, i)| = |(1, ..k.., 9)|
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (|(a, b, c, d, e, f, g, h, i)|, |(1, ..k.., 9)|)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. |(a, b, c, d, e, f, g, h, i)|
#    core type: Operation
#    operator: 10
#    operand: 12
# 8. |(1, ..k.., 9)|
#    core type: Operation
#    operator: 10
#    operand: 13
# 9. ((a, b, c, d, e, f, g, h, i))
#    core type: ExprTuple
#    sub-expressions: 12
# 10. length
#     core type: Literal
#     sub-expressions:
# 11. ((1, ..k.., 9))
#     core type: ExprTuple
#     sub-expressions: 13
# 12. (a, b, c, d, e, f, g, h, i)
#     core type: ExprTuple
#     sub-expressions: 14, 15, 16, 17, 18, 19, 20, 21, 22
# 13. (1, ..k.., 9)
#     core type: ExprTuple
#     sub-expressions: 23
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. b
#     core type: Variable
#     sub-expressions:
# 16. c
#     core type: Variable
#     sub-expressions:
# 17. d
#     core type: Variable
#     sub-expressions:
# 18. e
#     core type: Variable
#     sub-expressions:
# 19. f
#     core type: Variable
#     sub-expressions:
# 20. g
#     core type: Variable
#     sub-expressions:
# 21. h
#     core type: Variable
#     sub-expressions:
# 22. i
#     core type: Variable
#     sub-expressions:
# 23. 1, ..k.., 9
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 25
#     end_index: 26
# 24. k -> k
#     core type: Lambda
#     parameter: 27
#     body: 27
# 25. 1
#     core type: Literal
#     sub-expressions:
# 26. 9
#     core type: Literal
#     sub-expressions:
# 27. k
#     core type: Variable
#     sub-expressions:
