# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Lambda, i, x
from proveit.logic import Equals
from proveit.numbers import five, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(x, Equals([ExprRange(i, x, one, five)], [x, x, x, x, x])))
# Out:
# expr: (x -> ((x, ..5 repeats.., x) = (x, x, x, x, x)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \mapsto \left(\left(x, ..5 \textrm{ repeats}.., x\right) = \left(x, x, x, x, x\right)\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x -> ((x, ..5 repeats.., x) = (x, x, x, x, x)))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. x -> ((x, ..5 repeats.., x) = (x, x, x, x, x))
#    core type: Lambda
#    parameter: 12
#    body: 2
# 2. (x, ..5 repeats.., x) = (x, x, x, x, x)
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. ((x, ..5 repeats.., x), (x, x, x, x, x))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. (x, ..5 repeats.., x)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (x, x, x, x, x)
#    core type: ExprTuple
#    sub-expressions: 12, 12, 12, 12, 12
# 7. x, ..5 repeats.., x
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 10
# 8. i -> x
#    core type: Lambda
#    parameter: 11
#    body: 12
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. 5
#     core type: Literal
#     sub-expressions:
# 11. i
#     core type: Variable
#     sub-expressions:
# 12. x
#     core type: Variable
#     sub-expressions:
