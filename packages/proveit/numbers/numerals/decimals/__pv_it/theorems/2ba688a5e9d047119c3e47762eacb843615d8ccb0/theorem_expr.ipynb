# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#tuple_len_8_typical_eq">tuple_len_8_typical_eq</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.numerals.decimals import tuple_len_8_typical_eq

# %%
# check that the built expression is the same as the stored expression
assert tuple_len_8_typical_eq.expr == stored_expr
assert tuple_len_8_typical_eq.expr._style_id == stored_expr._style_id
print("Passed sanity check: tuple_len_8_typical_eq matches stored_expr")
# Out:
# Passed sanity check: tuple_len_8_typical_eq matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(tuple_len_8_typical_eq.latex())
# Out:
# \vdash \forall_{a, b, c, d, e, f, g, h}~\left(|\left(a, b, c, d, e, f, g, h\right)| = |\left(1, \ldots, 8\right)|\right)

# %%
tuple_len_8_typical_eq.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
tuple_len_8_typical_eq.expr_info()
# Out:
# 0. forall_{a, b, c, d, e, f, g, h} (|(a, b, c, d, e, f, g, h)| = |(1, ..k.., 8)|)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b, c, d, e, f, g, h) -> (|(a, b, c, d, e, f, g, h)| = |(1, ..k.., 8)|))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b, c, d, e, f, g, h) -> (|(a, b, c, d, e, f, g, h)| = |(1, ..k.., 8)|)
#    core type: Lambda
#    parameters: 12\n   body: 4
# 4. |(a, b, c, d, e, f, g, h)| = |(1, ..k.., 8)|
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (|(a, b, c, d, e, f, g, h)|, |(1, ..k.., 8)|)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. |(a, b, c, d, e, f, g, h)|
#    core type: Operation
#    operator: 10
#    operand: 12
# 8. |(1, ..k.., 8)|
#    core type: Operation
#    operator: 10
#    operand: 13
# 9. ((a, b, c, d, e, f, g, h))
#    core type: ExprTuple
#    sub-expressions: 12
# ...
