# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Variable, a, b, c, d, i, k, m, n
from proveit.logic import And, Equals, InSet
from proveit.numbers import DecimalSequence, Digits, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(a, sub_expr1)
sub_expr3 = ExprRange(i, b, one, n)
sub_expr4 = IndexedVar(d, sub_expr1)
sub_expr5 = IndexedVar(c, sub_expr1)
sub_expr6 = ExprRange(sub_expr1, sub_expr2, one, m)
sub_expr7 = ExprRange(sub_expr1, sub_expr4, one, k)
sub_expr8 = ExprRange(sub_expr1, sub_expr5, one, n)
expr = Conditional(Equals(DecimalSequence(sub_expr6, sub_expr3, sub_expr7), DecimalSequence(sub_expr6, sub_expr8, sub_expr7)), And(ExprRange(sub_expr1, InSet(sub_expr2, Digits), one, m), InSet(b, Digits), ExprRange(sub_expr1, InSet(sub_expr5, Digits), one, n), ExprRange(sub_expr1, InSet(sub_expr4, Digits), one, k), Equals([sub_expr3], [sub_expr8])))
# Out:
# expr: {\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ ..n repeats.. ~ b ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c_{1} ~ ..c_{_a}.. ~ c_{n} ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) if a_{1} in Digits ,  ..a_{_a} in Digits.. ,  a_{m} in Digits ,  b in Digits ,  c_{1} in Digits ,  ..c_{_a} in Digits.. ,  c_{n} in Digits ,  d_{1} in Digits ,  ..d_{_a} in Digits.. ,  d_{k} in Digits ,  (b, ..n repeats.., b) = (c_{1}, ..c_{_a}.., c_{n}).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\# (a_{1} ~ \ldots ~ a_{m} ~ b ~ ..n \textrm{ repeats}.. ~ b ~ d_{1} ~ \ldots ~ d_{k}) = \# (a_{1} ~ \ldots ~ a_{m} ~ c_{1} ~ \ldots ~ c_{n} ~ d_{1} ~ \ldots ~ d_{k}) \textrm{ if } a_{1} \in \mathbb{N}^{\leq 9} ,  \ldots ,  a_{m} \in \mathbb{N}^{\leq 9} ,  b \in \mathbb{N}^{\leq 9} ,  c_{1} \in \mathbb{N}^{\leq 9} ,  \ldots ,  c_{n} \in \mathbb{N}^{\leq 9} ,  d_{1} \in \mathbb{N}^{\leq 9} ,  \ldots ,  d_{k} \in \mathbb{N}^{\leq 9} ,  \left(b, ..n \textrm{ repeats}.., b\right) = \left(c_{1}, \ldots, c_{n}\right)\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ ..n repeats.. ~ b ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c_{1} ~ ..c_{_a}.. ~ c_{n} ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) if a_{1} in Digits ,  ..a_{_a} in Digits.. ,  a_{m} in Digits ,  b in Digits ,  c_{1} in Digits ,  ..c_{_a} in Digits.. ,  c_{n} in Digits ,  d_{1} in Digits ,  ..d_{_a} in Digits.. ,  d_{k} in Digits ,  (b, ..n repeats.., b) = (c_{1}, ..c_{_a}.., c_{n}).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ ..n repeats.. ~ b ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c_{1} ~ ..c_{_a}.. ~ c_{n} ~ d_{1} ~ ..d_{_a}.. ~ d_{k})
#    core type: Operation
#    operator: 20
#    operands: 3
# ...
