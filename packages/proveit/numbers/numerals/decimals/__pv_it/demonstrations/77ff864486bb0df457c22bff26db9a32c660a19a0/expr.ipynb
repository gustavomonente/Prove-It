# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.numbers import Add, DecimalSequence, nine, one, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(DecimalSequence(nine, nine, nine, nine, nine), one), DecimalSequence(one, zero, zero, zero, zero, zero))
# Out:
# expr: (99999 + 1, 100000)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(99999 + 1, 100000\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (99999 + 1, 100000)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 99999 + 1
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. 100000
#    core type: Operation
#    operator: 9
#    operands: 5
# 3. +
#    core type: Literal
#    sub-expressions:
# 4. (99999, 1)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (1, 0, 0, 0, 0, 0)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 8, 8, 8, 8
# 6. 99999
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. 1
#    core type: Literal
#    sub-expressions:
# 8. 0
#    core type: Literal
#    sub-expressions:
# 9. Decimal
#    core type: Literal
#    sub-expressions:
# 10. (9, 9, 9, 9, 9)
#     core type: ExprTuple
#     sub-expressions: 11, 11, 11, 11, 11
# 11. 9
#     core type: Literal
#     sub-expressions:
