# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, Lambda, Variable, i, k
from proveit.core_expr_types import Len
from proveit.logic import Equals
from proveit.numbers import eight, five, four, nine, one, seven, six, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Lambda(sub_expr1, seven)
expr = Equals(Len([Lambda(sub_expr1, three), Lambda(sub_expr1, eight), Lambda(sub_expr1, six), sub_expr2, Lambda(sub_expr1, four), Lambda(i, nine), Lambda(sub_expr1, five), sub_expr2, Lambda(sub_expr1, two)]), Len([ExprRange(k, k, one, nine)]))
# Out:
# expr: |(_a -> 3, _a -> 8, _a -> 6, _a -> 7, _a -> 4, i -> 9, _a -> 5, _a -> 7, _a -> 2)| = |(1, ..k.., 9)|

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left({_{-}a} \mapsto 3, {_{-}a} \mapsto 8, {_{-}a} \mapsto 6, {_{-}a} \mapsto 7, {_{-}a} \mapsto 4, i \mapsto 9, {_{-}a} \mapsto 5, {_{-}a} \mapsto 7, {_{-}a} \mapsto 2\right)| = |\left(1, \ldots, 9\right)|

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |(_a -> 3, _a -> 8, _a -> 6, _a -> 7, _a -> 4, i -> 9, _a -> 5, _a -> 7, _a -> 2)| = |(1, ..k.., 9)|
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|(_a -> 3, _a -> 8, _a -> 6, _a -> 7, _a -> 4, i -> 9, _a -> 5, _a -> 7, _a -> 2)|, |(1, ..k.., 9)|)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |(_a -> 3, _a -> 8, _a -> 6, _a -> 7, _a -> 4, i -> 9, _a -> 5, _a -> 7, _a -> 2)|
#    core type: Operation
#    operator: 6
#    operand: 8
# 4. |(1, ..k.., 9)|
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. ((_a -> 3, _a -> 8, _a -> 6, _a -> 7, _a -> 4, i -> 9, _a -> 5, _a -> 7, _a -> 2))
#    core type: ExprTuple
#    sub-expressions: 8
# 6. length
#    core type: Literal
#    sub-expressions:
# 7. ((1, ..k.., 9))
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (_a -> 3, _a -> 8, _a -> 6, _a -> 7, _a -> 4, i -> 9, _a -> 5, _a -> 7, _a -> 2)
#    core type: ExprTuple
# ...
