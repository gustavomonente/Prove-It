# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda, Variable, i
from proveit.numbers import eight, five, four, nine, seven, six, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Lambda(sub_expr1, seven)
expr = ExprTuple([Lambda(sub_expr1, three), Lambda(sub_expr1, eight), Lambda(sub_expr1, six), sub_expr2, Lambda(sub_expr1, four), Lambda(i, nine), Lambda(sub_expr1, five), sub_expr2, Lambda(sub_expr1, two)])
# Out:
# expr: ((_a -> 3, _a -> 8, _a -> 6, _a -> 7, _a -> 4, i -> 9, _a -> 5, _a -> 7, _a -> 2))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left({_{-}a} \mapsto 3, {_{-}a} \mapsto 8, {_{-}a} \mapsto 6, {_{-}a} \mapsto 7, {_{-}a} \mapsto 4, i \mapsto 9, {_{-}a} \mapsto 5, {_{-}a} \mapsto 7, {_{-}a} \mapsto 2\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((_a -> 3, _a -> 8, _a -> 6, _a -> 7, _a -> 4, i -> 9, _a -> 5, _a -> 7, _a -> 2))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (_a -> 3, _a -> 8, _a -> 6, _a -> 7, _a -> 4, i -> 9, _a -> 5, _a -> 7, _a -> 2)
#    core type: ExprTuple
#    sub-expressions: 2, 3, 4, 8, 5, 6, 7, 8, 9
# 2. _a -> 3
#    core type: Lambda
#    parameter: 18
#    body: 10
# 3. _a -> 8
#    core type: Lambda
#    parameter: 18
#    body: 11
# 4. _a -> 6
#    core type: Lambda
#    parameter: 18
#    body: 12
# 5. _a -> 4
#    core type: Lambda
#    parameter: 18
#    body: 13
# 6. i -> 9
#    core type: Lambda
#    parameter: 14
#    body: 15
# 7. _a -> 5
#    core type: Lambda
#    parameter: 18
#    body: 16
# 8. _a -> 7
#    core type: Lambda
#    parameter: 18
#    body: 17
# 9. _a -> 2
#    core type: Lambda
#    parameter: 18
#    body: 19
# 10. 3
#     core type: Literal
#     sub-expressions:
# 11. 8
#     core type: Literal
#     sub-expressions:
# 12. 6
#     core type: Literal
#     sub-expressions:
# 13. 4
#     core type: Literal
#     sub-expressions:
# 14. i
#     core type: Variable
#     sub-expressions:
# 15. 9
#     core type: Literal
#     sub-expressions:
# 16. 5
#     core type: Literal
#     sub-expressions:
# 17. 7
#     core type: Literal
#     sub-expressions:
# 18. _a
#     core type: Variable
#     sub-expressions:
# 19. 2
#     core type: Literal
#     sub-expressions:
