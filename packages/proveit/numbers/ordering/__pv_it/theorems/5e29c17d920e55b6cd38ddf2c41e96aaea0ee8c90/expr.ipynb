# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b
from proveit.logic import And, InSet
from proveit.numbers import Add, Less, Real, RealPos

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(Less(a, Add(a, b)), And(InSet(a, Real), InSet(b, RealPos))))
# Out:
# expr: (a, b) -> {a < (a + b) if a in Real ,  b in RealPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{a < \left(a + b\right) \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R}^+\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, b) -> {a < (a + b) if a in Real ,  b in RealPos.
#    core type: Lambda
#    parameters: 12\n   body: 1
# 1. {a < (a + b) if a in Real ,  b in RealPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. a < (a + b)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a in Real) and (b in RealPos)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. <
#    core type: Literal
#    sub-expressions:
# 5. (a, a + b)
#    core type: ExprTuple
#    sub-expressions: 16, 8
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a in Real, b in RealPos)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. a + b
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. a in Real
#    core type: Operation
#    operator: 14
#    operands: 13
# 10. b in RealPos
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (a, b)
#     core type: ExprTuple
#     sub-expressions: 16, 18
# 13. (a, Real)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (b, RealPos)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. Real
#     core type: Literal
#     sub-expressions:
# 18. b
#     core type: Variable
#     sub-expressions:
# 19. RealPos
#     core type: Literal
#     sub-expressions:
