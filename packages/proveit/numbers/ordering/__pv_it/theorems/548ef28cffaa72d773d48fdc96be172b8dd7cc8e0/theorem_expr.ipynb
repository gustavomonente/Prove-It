# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#negative_if_real_neg">negative_if_real_neg</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.ordering import negative_if_real_neg

# %%
# check that the built expression is the same as the stored expression
assert negative_if_real_neg.expr == stored_expr
assert negative_if_real_neg.expr._style_id == stored_expr._style_id
print("Passed sanity check: negative_if_real_neg matches stored_expr")
# Out:
# Passed sanity check: negative_if_real_neg matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(negative_if_real_neg.latex())
# Out:
# \vdash \forall_{a \in \mathbb{R}^-}~\left(a < 0\right)

# %%
negative_if_real_neg.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
negative_if_real_neg.expr_info()
# Out:
# 0. forall_{a in RealNeg} (a < 0)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a -> {a < 0 if a in RealNeg.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. a -> {a < 0 if a in RealNeg.
#    core type: Lambda
#    parameter: 12
#    body: 4
# 4. {a < 0 if a in RealNeg.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. a < 0
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. a in RealNeg
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. <
#    core type: Literal
#    sub-expressions:
# 8. (a, 0)
#    core type: ExprTuple
#    sub-expressions: 12, 11
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (a, RealNeg)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. 0
#     core type: Literal
#     sub-expressions:
# 12. a
#     core type: Variable
#     sub-expressions:
# 13. RealNeg
#     core type: Literal
#     sub-expressions:
