# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a, b, c
from proveit.logic import And, InSet
from proveit.numbers import Add, Less, LessEq, Real, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([a, b, c], Conditional(Less(Add(a, c), b), And(InSet(a, Real), InSet(b, Real), InSet(c, Real), Less(a, b), LessEq(c, zero)))))
# Out:
# expr: ((a, b, c) -> {(a + c) < b if a in Real ,  b in Real ,  c in Real ,  a < b ,  c <= 0.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a, b, c\right) \mapsto \left\{\left(a + c\right) < b \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R} ,  c \in \mathbb{R} ,  a < b ,  c \leq 0\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a, b, c) -> {(a + c) < b if a in Real ,  b in Real ,  c in Real ,  a < b ,  c <= 0.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a, b, c) -> {(a + c) < b if a in Real ,  b in Real ,  c in Real ,  a < b ,  c <= 0.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 26, 27, 28
# 3. {(a + c) < b if a in Real ,  b in Real ,  c in Real ,  a < b ,  c <= 0.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (a + c) < b
#    core type: Operation
#    operator: 21
#    operands: 6
# 5. (a in Real) and (b in Real) and (c in Real) and (a < b) and (c <= 0)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a + c, b)
#    core type: ExprTuple
#    sub-expressions: 9, 27
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Real, b in Real, c in Real, a < b, c <= 0)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12, 13, 14
# 9. a + c
#    core type: Operation
#    operator: 15
#    operands: 16
# 10. a in Real
#     core type: Operation
#     operator: 19
#     operands: 17
# 11. b in Real
#     core type: Operation
#     operator: 19
#     operands: 18
# 12. c in Real
#     core type: Operation
#     operator: 19
#     operands: 20
# 13. a < b
#     core type: Operation
#     operator: 21
#     operands: 22
# 14. c <= 0
#     core type: Operation
#     operator: 23
#     operands: 24
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (a, c)
#     core type: ExprTuple
#     sub-expressions: 26, 28
# 17. (a, Real)
#     core type: ExprTuple
#     sub-expressions: 26, 25
# 18. (b, Real)
#     core type: ExprTuple
#     sub-expressions: 27, 25
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (c, Real)
#     core type: ExprTuple
#     sub-expressions: 28, 25
# 21. <
#     core type: Literal
#     sub-expressions:
# 22. (a, b)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 23. <=
#     core type: Literal
#     sub-expressions:
# 24. (c, 0)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 25. Real
#     core type: Literal
#     sub-expressions:
# 26. a
#     core type: Variable
#     sub-expressions:
# 27. b
#     core type: Variable
#     sub-expressions:
# 28. c
#     core type: Variable
#     sub-expressions:
# 29. 0
#     core type: Literal
#     sub-expressions:
