# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#relax_equal_to_less_eq">relax_equal_to_less_eq</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.ordering import relax_equal_to_less_eq

# %%
# check that the built expression is the same as the stored expression
assert relax_equal_to_less_eq.expr == stored_expr
assert relax_equal_to_less_eq.expr._style_id == stored_expr._style_id
print("Passed sanity check: relax_equal_to_less_eq matches stored_expr")
# Out:
# Passed sanity check: relax_equal_to_less_eq matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(relax_equal_to_less_eq.latex())
# Out:
# \vdash \forall_{x, y \in \mathbb{R}~|~x = y}~\left(x \leq y\right)

# %%
relax_equal_to_less_eq.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
relax_equal_to_less_eq.expr_info()
# Out:
# 0. forall_{x, y in Real | x = y} (x <= y)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((x, y) -> {x <= y if x in Real ,  y in Real ,  x = y.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (x, y) -> {x <= y if x in Real ,  y in Real ,  x = y.
#    core type: Lambda
#    parameters: 17\n   body: 4
# 4. {x <= y if x in Real ,  y in Real ,  x = y.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. x <= y
#    core type: Operation
#    operator: 7
#    operands: 17
# 6. (x in Real) and (y in Real) and (x = y)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. <=
#    core type: Literal
#    sub-expressions:
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (x in Real, y in Real, x = y)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 10. x in Real
#     core type: Operation
#     operator: 14
#     operands: 13
# 11. y in Real
#     core type: Operation
# ...
