# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#transitivity_less_eq_less_eq">transitivity_less_eq_less_eq</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.ordering import transitivity_less_eq_less_eq

# %%
# check that the built expression is the same as the stored expression
assert transitivity_less_eq_less_eq.expr == stored_expr
assert transitivity_less_eq_less_eq.expr._style_id == stored_expr._style_id
print("Passed sanity check: transitivity_less_eq_less_eq matches stored_expr")
# Out:
# Passed sanity check: transitivity_less_eq_less_eq matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(transitivity_less_eq_less_eq.latex())
# Out:
# \vdash \forall_{x, y, z~|~x \leq y, y \leq z}~\left(x \leq z\right)

# %%
transitivity_less_eq_less_eq.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
transitivity_less_eq_less_eq.expr_info()
# Out:
# 0. forall_{x, y, z | x <= y, y <= z} (x <= z)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((x, y, z) -> {x <= z if x <= y ,  y <= z.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (x, y, z) -> {x <= z if x <= y ,  y <= z.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (x, y, z)
#    core type: ExprTuple
#    sub-expressions: 16, 17, 18
# 5. {x <= z if x <= y ,  y <= z.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. x <= z
#    core type: Operation
#    operator: 14
#    operands: 8
# 7. (x <= y) and (y <= z)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (x, z)
#    core type: ExprTuple
#    sub-expressions: 16, 18
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (x <= y, y <= z)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. x <= y
#     core type: Operation
#     operator: 14
#     operands: 13
# 12. y <= z
# ...
