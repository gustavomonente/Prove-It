# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#less_than_an_increase">less_than_an_increase</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.ordering import less_than_an_increase

# %%
# check that the built expression is the same as the stored expression
assert less_than_an_increase.expr == stored_expr
assert less_than_an_increase.expr._style_id == stored_expr._style_id
print("Passed sanity check: less_than_an_increase matches stored_expr")
# Out:
# Passed sanity check: less_than_an_increase matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(less_than_an_increase.latex())
# Out:
# \vdash \forall_{a \in \mathbb{R}, b \in \mathbb{R}^+}~\left(a < \left(a + b\right)\right)

# %%
less_than_an_increase.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
less_than_an_increase.expr_info()
# Out:
# 0. forall_{a in Real, b in RealPos} (a < (a + b))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b) -> {a < (a + b) if a in Real ,  b in RealPos.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b) -> {a < (a + b) if a in Real ,  b in RealPos.
#    core type: Lambda
#    parameters: 15\n   body: 4
# 4. {a < (a + b) if a in Real ,  b in RealPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. a < (a + b)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a in Real) and (b in RealPos)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. <
#    core type: Literal
#    sub-expressions:
# 8. (a, a + b)
#    core type: ExprTuple
#    sub-expressions: 19, 11
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (a in Real, b in RealPos)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. a + b
#     core type: Operation
#     operator: 14
# ...
