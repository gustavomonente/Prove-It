# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a
from proveit.logic import InSet
from proveit.numbers import RealNonNeg, greater_eq, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(a, Conditional(greater_eq(a, zero), InSet(a, RealNonNeg))))
# Out:
# expr: (a -> {a >= 0 if a in RealNonNeg.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \mapsto \left\{a \geq 0 \textrm{ if } a \in \mathbb{R}^{\ge 0}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a -> {a >= 0 if a in RealNonNeg.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. a -> {a >= 0 if a in RealNonNeg.
#    core type: Lambda
#    parameter: 10
#    body: 2
# 2. {a >= 0 if a in RealNonNeg.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. a >= 0
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. a in RealNonNeg
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. <=
#    core type: Literal
#    sub-expressions:
# 6. (0, a)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (a, RealNonNeg)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. 0
#    core type: Literal
#    sub-expressions:
# 10. a
#     core type: Variable
#     sub-expressions:
# 11. RealNonNeg
#     core type: Literal
#     sub-expressions:
