# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#less_eq_shift_add_right">less_eq_shift_add_right</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.ordering import less_eq_shift_add_right

# %%
# check that the built expression is the same as the stored expression
assert less_eq_shift_add_right.expr == stored_expr
assert less_eq_shift_add_right.expr._style_id == stored_expr._style_id
print("Passed sanity check: less_eq_shift_add_right matches stored_expr")
# Out:
# Passed sanity check: less_eq_shift_add_right matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(less_eq_shift_add_right.latex())
# Out:
# \vdash \forall_{a, b, c \in \mathbb{R}~|~a \leq b}~\left(\left(a + c\right) \leq \left(b + c\right)\right)

# %%
less_eq_shift_add_right.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
less_eq_shift_add_right.expr_info()
# Out:
# 0. forall_{a, b, c in Real | a <= b} ((a + c) <= (b + c))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b, c) -> {(a + c) <= (b + c) if a in Real ,  b in Real ,  c in Real ,  a <= b.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b, c) -> {(a + c) <= (b + c) if a in Real ,  b in Real ,  c in Real ,  a <= b.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 28, 29, 26
# 5. {(a + c) <= (b + c) if a in Real ,  b in Real ,  c in Real ,  a <= b.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (a + c) <= (b + c)
#    core type: Operation
#    operator: 24
#    operands: 8
# 7. (a in Real) and (b in Real) and (c in Real) and (a <= b)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (a + c, b + c)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
# ...
