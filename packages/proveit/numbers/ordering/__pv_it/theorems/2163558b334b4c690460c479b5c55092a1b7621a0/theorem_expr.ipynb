# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#less_than_is_bool">less_than_is_bool</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.ordering import less_than_is_bool

# %%
# check that the built expression is the same as the stored expression
assert less_than_is_bool.expr == stored_expr
assert less_than_is_bool.expr._style_id == stored_expr._style_id
print("Passed sanity check: less_than_is_bool matches stored_expr")
# Out:
# Passed sanity check: less_than_is_bool matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(less_than_is_bool.latex())
# Out:
# \vdash \forall_{x, y \in \mathbb{R}}~\left(\left(x < y\right) \in \mathbb{B}\right)

# %%
less_than_is_bool.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
less_than_is_bool.expr_info()
# Out:
# 0. forall_{x, y in Real} ((x < y) in BOOLEAN)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((x, y) -> {(x < y) in BOOLEAN if x in Real ,  y in Real.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (x, y) -> {(x < y) in BOOLEAN if x in Real ,  y in Real.
#    core type: Lambda
#    parameters: 15\n   body: 4
# 4. {(x < y) in BOOLEAN if x in Real ,  y in Real.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (x < y) in BOOLEAN
#    core type: Operation
#    operator: 17
#    operands: 7
# 6. (x in Real) and (y in Real)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (x < y, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (x in Real, y in Real)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. x < y
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. BOOLEAN
# ...
