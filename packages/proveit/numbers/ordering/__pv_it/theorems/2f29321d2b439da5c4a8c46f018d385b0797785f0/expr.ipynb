# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b, c
from proveit.logic import And, InSet
from proveit.numbers import Add, LessEq, Real

# %%
# build up the expression from sub-expressions
expr = Conditional(LessEq(Add(a, c), Add(b, c)), And(InSet(a, Real), InSet(b, Real), InSet(c, Real), LessEq(a, b)))
# Out:
# expr: {(a + c) <= (b + c) if a in Real ,  b in Real ,  c in Real ,  a <= b.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a + c\right) \leq \left(b + c\right) \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R} ,  c \in \mathbb{R} ,  a \leq b\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(a + c) <= (b + c) if a in Real ,  b in Real ,  c in Real ,  a <= b.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a + c) <= (b + c)
#    core type: Operation
#    operator: 19
#    operands: 3
# 2. (a in Real) and (b in Real) and (c in Real) and (a <= b)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a + c, b + c)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (a in Real, b in Real, c in Real, a <= b)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 6. a + c
#    core type: Operation
#    operator: 13
#    operands: 12
# 7. b + c
#    core type: Operation
#    operator: 13
#    operands: 14
# 8. a in Real
#    core type: Operation
#    operator: 17
#    operands: 15
# 9. b in Real
#    core type: Operation
#    operator: 17
#    operands: 16
# 10. c in Real
#     core type: Operation
#     operator: 17
#     operands: 18
# 11. a <= b
#     core type: Operation
#     operator: 19
#     operands: 20
# 12. (a, c)
#     core type: ExprTuple
#     sub-expressions: 23, 21
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (b, c)
#     core type: ExprTuple
#     sub-expressions: 24, 21
# 15. (a, Real)
#     core type: ExprTuple
#     sub-expressions: 23, 22
# 16. (b, Real)
#     core type: ExprTuple
#     sub-expressions: 24, 22
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (c, Real)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. <=
#     core type: Literal
#     sub-expressions:
# 20. (a, b)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. c
#     core type: Variable
#     sub-expressions:
# 22. Real
#     core type: Literal
#     sub-expressions:
# 23. a
#     core type: Variable
#     sub-expressions:
# 24. b
#     core type: Variable
#     sub-expressions:
