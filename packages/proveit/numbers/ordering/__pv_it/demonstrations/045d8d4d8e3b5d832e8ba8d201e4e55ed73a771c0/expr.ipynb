# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, a, b, c, e, k
from proveit.core_expr_types import Len
from proveit.numbers import Less, LessEq, one, three

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([Less(b, a), LessEq(a, c), LessEq(c, e)]), Len([ExprRange(k, k, one, three)]))
# Out:
# expr: (|(b < a, a <= c, c <= e)|, |(1, ..k.., 3)|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(b < a, a \leq c, c \leq e\right)|, |\left(1, \ldots, 3\right)|\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|(b < a, a <= c, c <= e)|, |(1, ..k.., 3)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(b < a, a <= c, c <= e)|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..k.., 3)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((b < a, a <= c, c <= e))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..k.., 3))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (b < a, a <= c, c <= e)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 7. (1, ..k.., 3)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. b < a
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. a <= c
#    core type: Operation
#    operator: 15
#    operands: 14
# 10. c <= e
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. 1, ..k.., 3
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 18
#     end_index: 19
# 12. <
#     core type: Literal
#     sub-expressions:
# 13. (b, a)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 14. (a, c)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 15. <=
#     core type: Literal
#     sub-expressions:
# 16. (c, e)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 17. k -> k
#     core type: Lambda
#     parameter: 24
#     body: 24
# 18. 1
#     core type: Literal
#     sub-expressions:
# 19. 3
#     core type: Literal
#     sub-expressions:
# 20. b
#     core type: Variable
#     sub-expressions:
# 21. a
#     core type: Variable
#     sub-expressions:
# 22. c
#     core type: Variable
#     sub-expressions:
# 23. e
#     core type: Variable
#     sub-expressions:
# 24. k
#     core type: Variable
#     sub-expressions:
