# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, a, b, c, d, e, k
from proveit.core_expr_types import Len
from proveit.logic import Equals
from proveit.numbers import Less, LessEq, four, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([Less(b, a), LessEq(a, c), Equals(c, d), LessEq(d, e)]), Len([ExprRange(k, k, one, four)]))
# Out:
# expr: (|(b < a, a <= c, c = d, d <= e)|, |(1, ..k.., 4)|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(b < a, a \leq c, c = d, d \leq e\right)|, |\left(1, \ldots, 4\right)|\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|(b < a, a <= c, c = d, d <= e)|, |(1, ..k.., 4)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(b < a, a <= c, c = d, d <= e)|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..k.., 4)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((b < a, a <= c, c = d, d <= e))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..k.., 4))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (b < a, a <= c, c = d, d <= e)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 7. (1, ..k.., 4)
#    core type: ExprTuple
#    sub-expressions: 12
# 8. b < a
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. a <= c
#    core type: Operation
#    operator: 18
#    operands: 15
# 10. c = d
#     core type: Operation
#     operator: 16
#     operands: 17
# 11. d <= e
#     core type: Operation
#     operator: 18
#     operands: 19
# 12. 1, ..k.., 4
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 21
#     end_index: 22
# 13. <
#     core type: Literal
#     sub-expressions:
# 14. (b, a)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 15. (a, c)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 16. =
#     core type: Literal
#     sub-expressions:
# 17. (c, d)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 18. <=
#     core type: Literal
#     sub-expressions:
# 19. (d, e)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 20. k -> k
#     core type: Lambda
#     parameter: 28
#     body: 28
# 21. 1
#     core type: Literal
#     sub-expressions:
# 22. 4
#     core type: Literal
#     sub-expressions:
# 23. b
#     core type: Variable
#     sub-expressions:
# 24. a
#     core type: Variable
#     sub-expressions:
# 25. c
#     core type: Variable
#     sub-expressions:
# 26. d
#     core type: Variable
#     sub-expressions:
# 27. e
#     core type: Variable
#     sub-expressions:
# 28. k
#     core type: Variable
#     sub-expressions:
