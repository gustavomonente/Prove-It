# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a, x
from proveit.logic import Equals, InSet
from proveit.numbers import Integer, Interval, Sum

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(a, Conditional(Equals(Sum([x], x, domains = [Interval(a, a)]), a), InSet(a, Integer))))
# Out:
# expr: (a -> {(Sum_{x=a}^{a} x) = a if a in Integer.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \mapsto \left\{\left(\sum_{x=a}^{a} x\right) = a \textrm{ if } a \in \mathbb{Z}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a -> {(Sum_{x=a}^{a} x) = a if a in Integer.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. a -> {(Sum_{x=a}^{a} x) = a if a in Integer.
#    core type: Lambda
#    parameter: 21
#    body: 2
# 2. {(Sum_{x=a}^{a} x) = a if a in Integer.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (Sum_{x=a}^{a} x) = a
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. a in Integer
#    core type: Operation
#    operator: 15
#    operands: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (Sum_{x=a}^{a} x, a)
#    core type: ExprTuple
#    sub-expressions: 8, 21
# 7. (a, Integer)
#    core type: ExprTuple
#    sub-expressions: 21, 9
# 8. Sum_{x=a}^{a} x
#    core type: Operation
#    operator: 10
#    operand: 12
# 9. Integer
#    core type: Literal
#    sub-expressions:
# 10. Sum
#     core type: Literal
#     sub-expressions:
# 11. (x -> {x if x in {a...a}.)
#     core type: ExprTuple
#     sub-expressions: 12
# 12. x -> {x if x in {a...a}.
#     core type: Lambda
#     parameter: 17
#     body: 13
# 13. {x if x in {a...a}.
#     core type: Conditional
#     value: 17
#     condition: 14
# 14. x in {a...a}
#     core type: Operation
#     operator: 15
#     operands: 16
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (x, {a...a})
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. x
#     core type: Variable
#     sub-expressions:
# 18. {a...a}
#     core type: Operation
#     operator: 19
#     operands: 20
# 19. Interval
#     core type: Literal
#     sub-expressions:
# 20. (a, a)
#     core type: ExprTuple
#     sub-expressions: 21, 21
# 21. a
#     core type: Variable
#     sub-expressions:
