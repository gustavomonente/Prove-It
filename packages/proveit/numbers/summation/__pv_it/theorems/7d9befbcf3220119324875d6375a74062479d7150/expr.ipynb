# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import S, k, l
from proveit.logic import Forall, Implies
from proveit.numbers import Less, Sum
from proveit.numbers.summation import ak, al, bk, bl

# %%
# build up the expression from sub-expressions
sub_expr1 = [S]
sub_expr2 = [l]
expr = Implies(Forall([k], Less(ak, bk), domains = sub_expr1), Less(Sum(sub_expr2, al, domains = sub_expr1), Sum(sub_expr2, bl, domains = sub_expr1)))
# Out:
# expr: [forall_{k in S} (a(k) < b(k))] => (Sum_{l in S} a(l) < Sum_{l in S} b(l))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left[\forall_{k \in S}~\left(a(k) < b(k)\right)\right] \Rightarrow \left(\sum_{l \in S}~a(l) < \sum_{l \in S}~b(l)\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. [forall_{k in S} (a(k) < b(k))] => (Sum_{l in S} a(l) < Sum_{l in S} b(l))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{k in S} (a(k) < b(k)), Sum_{l in S} a(l) < Sum_{l in S} b(l))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{k in S} (a(k) < b(k))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. Sum_{l in S} a(l) < Sum_{l in S} b(l)
#    core type: Operation
#    operator: 19
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (k -> {a(k) < b(k) if k in S.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (Sum_{l in S} a(l), Sum_{l in S} b(l))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. k -> {a(k) < b(k) if k in S.
#    core type: Lambda
#    parameter: 35
#    body: 11
# 9. Sum_{l in S} a(l)
#    core type: Operation
#    operator: 13
#    operand: 17
# 10. Sum_{l in S} b(l)
#     core type: Operation
# ...
