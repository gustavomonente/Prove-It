# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, P, Px, Q, Qx, x
from proveit.logic import Forall, Implies, InSet
from proveit.numbers import Integer, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Lambda([P, Q], Implies(Forall(sub_expr1, InSet(Px, Integer), condition = Qx), InSet(Sum(sub_expr1, Px, condition = Qx), Integer)))
# Out:
# expr: (P, Q) -> ([forall_{x | Q(x)} (P(x) in Integer)] => (Sum_{x | Q(x)} P(x) in Integer))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(P, Q\right) \mapsto \left(\left[\forall_{x~|~Q(x)}~\left(P(x) \in \mathbb{Z}\right)\right] \Rightarrow \left(\sum_{x~|~Q(x)}~P(x) \in \mathbb{Z}\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (P, Q) -> ([forall_{x | Q(x)} (P(x) in Integer)] => (Sum_{x | Q(x)} P(x) in Integer))
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (P, Q)
#    core type: ExprTuple
#    sub-expressions: 23, 24
# 2. [forall_{x | Q(x)} (P(x) in Integer)] => (Sum_{x | Q(x)} P(x) in Integer)
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. =>
#    core type: Literal
#    sub-expressions:
# 4. (forall_{x | Q(x)} (P(x) in Integer), Sum_{x | Q(x)} P(x) in Integer)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. forall_{x | Q(x)} (P(x) in Integer)
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. Sum_{x | Q(x)} P(x) in Integer
#    core type: Operation
#    operator: 17
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. (x -> {P(x) in Integer if Q(x).)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (Sum_{x | Q(x)} P(x), Integer)
#    core type: ExprTuple
#    sub-expressions: 11, 20
# 10. x -> {P(x) in Integer if Q(x).
#     core type: Lambda
#     parameter: 26
#     body: 12
# 11. Sum_{x | Q(x)} P(x)
#     core type: Operation
#     operator: 13
#     operand: 16
# 12. {P(x) in Integer if Q(x).
#     core type: Conditional
#     value: 15
#     condition: 22
# 13. Sum
#     core type: Literal
#     sub-expressions:
# 14. (x -> {P(x) if Q(x).)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. P(x) in Integer
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. x -> {P(x) if Q(x).
#     core type: Lambda
#     parameter: 26
#     body: 19
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (P(x), Integer)
#     core type: ExprTuple
#     sub-expressions: 21, 20
# 19. {P(x) if Q(x).
#     core type: Conditional
#     value: 21
#     condition: 22
# 20. Integer
#     core type: Literal
#     sub-expressions:
# 21. P(x)
#     core type: Operation
#     operator: 23
#     operand: 26
# 22. Q(x)
#     core type: Operation
#     operator: 24
#     operand: 26
# 23. P
#     core type: Variable
#     sub-expressions:
# 24. Q
#     core type: Variable
#     sub-expressions:
# 25. (x)
#     core type: ExprTuple
#     sub-expressions: 26
# 26. x
#     core type: Variable
#     sub-expressions:
