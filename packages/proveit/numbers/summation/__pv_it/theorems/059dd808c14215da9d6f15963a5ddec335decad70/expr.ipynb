# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, Px, Qx, x
from proveit.logic import InSet
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(x, Conditional(InSet(Px, Natural), Qx)))
# Out:
# expr: (x -> {P(x) in Natural if Q(x).)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \mapsto \left\{P(x) \in \mathbb{N} \textrm{ if } Q(x)\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x -> {P(x) in Natural if Q(x).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. x -> {P(x) in Natural if Q(x).
#    core type: Lambda
#    parameter: 12
#    body: 2
# 2. {P(x) in Natural if Q(x).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. P(x) in Natural
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. Q(x)
#    core type: Operation
#    operator: 7
#    operand: 12
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (P(x), Natural)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. Q
#    core type: Variable
#    sub-expressions:
# 8. P(x)
#    core type: Operation
#    operator: 10
#    operand: 12
# 9. Natural
#    core type: Literal
#    sub-expressions:
# 10. P
#     core type: Variable
#     sub-expressions:
# 11. (x)
#     core type: ExprTuple
#     sub-expressions: 12
# 12. x
#     core type: Variable
#     sub-expressions:
