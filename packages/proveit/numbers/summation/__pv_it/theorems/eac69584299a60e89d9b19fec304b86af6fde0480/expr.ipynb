# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda, S, a, b, k, l
from proveit.logic import Forall, Implies
from proveit.numbers import LessEq, Sum
from proveit.numbers.summation import ak, al, bk, bl

# %%
# build up the expression from sub-expressions
sub_expr1 = [S]
sub_expr2 = [l]
expr = ExprTuple(Lambda([a, b, S], Implies(Forall([k], LessEq(ak, bk), domains = sub_expr1), LessEq(Sum(sub_expr2, al, domains = sub_expr1), Sum(sub_expr2, bl, domains = sub_expr1)))))
# Out:
# expr: ((a, b, S) -> ([forall_{k in S} (a(k) <= b(k))] => (Sum_{l in S} a(l) <= Sum_{l in S} b(l))))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a, b, S\right) \mapsto \left(\left[\forall_{k \in S}~\left(a(k) \leq b(k)\right)\right] \Rightarrow \left(\sum_{l \in S}~a(l) \leq \sum_{l \in S}~b(l)\right)\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a, b, S) -> ([forall_{k in S} (a(k) <= b(k))] => (Sum_{l in S} a(l) <= Sum_{l in S} b(l))))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a, b, S) -> ([forall_{k in S} (a(k) <= b(k))] => (Sum_{l in S} a(l) <= Sum_{l in S} b(l)))
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (a, b, S)
#    core type: ExprTuple
#    sub-expressions: 33, 34, 40
# 3. [forall_{k in S} (a(k) <= b(k))] => (Sum_{l in S} a(l) <= Sum_{l in S} b(l))
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =>
#    core type: Literal
#    sub-expressions:
# 5. (forall_{k in S} (a(k) <= b(k)), Sum_{l in S} a(l) <= Sum_{l in S} b(l))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. forall_{k in S} (a(k) <= b(k))
#    core type: Operation
#    operator: 8
#    operand: 11
# 7. Sum_{l in S} a(l) <= Sum_{l in S} b(l)
#    core type: Operation
#    operator: 22
#    operands: 10
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. (k -> {a(k) <= b(k) if k in S.)
# ...
