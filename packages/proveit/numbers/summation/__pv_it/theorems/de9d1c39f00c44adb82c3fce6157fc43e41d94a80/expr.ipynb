# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, m, x
from proveit.logic import Equals, InSet
from proveit.numbers import Add, Complex, Exp, Interval, Neg, Sum, frac, infinity, one, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(x, Conditional(Equals(Sum([m], Exp(x, m), domains = [Interval(zero, infinity)]), frac(one, Add(one, Neg(x)))), InSet(x, Complex))))
# Out:
# expr: (x -> {(Sum_{m=0}^{infinity} x^{m}) = (1 / (1 - x)) if x in Complex.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \mapsto \left\{\left(\sum_{m=0}^{\infty} x^{m}\right) = \frac{1}{1 - x} \textrm{ if } x \in \mathbb{C}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x -> {(Sum_{m=0}^{infinity} x^{m}) = (1 / (1 - x)) if x in Complex.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. x -> {(Sum_{m=0}^{infinity} x^{m}) = (1 / (1 - x)) if x in Complex.
#    core type: Lambda
#    parameter: 32
#    body: 2
# 2. {(Sum_{m=0}^{infinity} x^{m}) = (1 / (1 - x)) if x in Complex.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (Sum_{m=0}^{infinity} x^{m}) = (1 / (1 - x))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. x in Complex
#    core type: Operation
#    operator: 26
#    operands: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (Sum_{m=0}^{infinity} x^{m}, 1 / (1 - x))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (x, Complex)
#    core type: ExprTuple
#    sub-expressions: 32, 10
# 8. Sum_{m=0}^{infinity} x^{m}
#    core type: Operation
#    operator: 11
#    operand: 15
# 9. 1 / (1 - x)
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. Complex
# ...
