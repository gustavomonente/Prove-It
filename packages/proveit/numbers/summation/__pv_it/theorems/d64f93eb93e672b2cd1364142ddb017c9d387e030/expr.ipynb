# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import m, x
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Complex, Exp, Interval, Neg, Sum, frac, infinity, one, zero

# %%
# build up the expression from sub-expressions
expr = Forall([x], Equals(Sum([m], Exp(x, m), domains = [Interval(zero, infinity)]), frac(one, Add(one, Neg(x)))), domains = [Complex])
# Out:
# expr: forall_{x in Complex} ((Sum_{m=0}^{infinity} x^{m}) = (1 / (1 - x)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x \in \mathbb{C}}~\left(\left(\sum_{m=0}^{\infty} x^{m}\right) = \frac{1}{1 - x}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{x in Complex} ((Sum_{m=0}^{infinity} x^{m}) = (1 / (1 - x)))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x -> {(Sum_{m=0}^{infinity} x^{m}) = (1 / (1 - x)) if x in Complex.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. x -> {(Sum_{m=0}^{infinity} x^{m}) = (1 / (1 - x)) if x in Complex.
#    core type: Lambda
#    parameter: 34
#    body: 4
# 4. {(Sum_{m=0}^{infinity} x^{m}) = (1 / (1 - x)) if x in Complex.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (Sum_{m=0}^{infinity} x^{m}) = (1 / (1 - x))
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. x in Complex
#    core type: Operation
#    operator: 28
#    operands: 9
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (Sum_{m=0}^{infinity} x^{m}, 1 / (1 - x))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. (x, Complex)
#    core type: ExprTuple
#    sub-expressions: 34, 12
# 10. Sum_{m=0}^{infinity} x^{m}
#     core type: Operation
#     operator: 13
#     operand: 17
# 11. 1 / (1 - x)
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. Complex
#     core type: Literal
#     sub-expressions:
# 13. Sum
#     core type: Literal
#     sub-expressions:
# 14. (m -> {x^{m} if m in {0...infinity}.)
#     core type: ExprTuple
#     sub-expressions: 17
# 15. /
#     core type: Literal
#     sub-expressions:
# 16. (1, 1 - x)
#     core type: ExprTuple
#     sub-expressions: 24, 18
# 17. m -> {x^{m} if m in {0...infinity}.
#     core type: Lambda
#     parameter: 32
#     body: 19
# 18. 1 - x
#     core type: Operation
#     operator: 20
#     operands: 21
# 19. {x^{m} if m in {0...infinity}.
#     core type: Conditional
#     value: 22
#     condition: 23
# 20. +
#     core type: Literal
#     sub-expressions:
# 21. (1, -x)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. x^{m}
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. m in {0...infinity}
#     core type: Operation
#     operator: 28
#     operands: 29
# 24. 1
#     core type: Literal
#     sub-expressions:
# 25. -x
#     core type: Operation
#     operator: 30
#     operand: 34
# 26. Exp
#     core type: Literal
#     sub-expressions:
# 27. (x, m)
#     core type: ExprTuple
#     sub-expressions: 34, 32
# 28. in
#     core type: Literal
#     sub-expressions:
# 29. (m, {0...infinity})
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 30. -
#     core type: Literal
#     sub-expressions:
# 31. (x)
#     core type: ExprTuple
#     sub-expressions: 34
# 32. m
#     core type: Variable
#     sub-expressions:
# 33. {0...infinity}
#     core type: Operation
#     operator: 35
#     operands: 36
# 34. x
#     core type: Variable
#     sub-expressions:
# 35. Interval
#     core type: Literal
#     sub-expressions:
# 36. (0, infinity)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 37. 0
#     core type: Literal
#     sub-expressions:
# 38. infinity
#     core type: Literal
#     sub-expressions:
