# %% [markdown]
# Temporary notebook for <a class="ProveItLink" href="../../../_theorems_.ipynb#weak_summation_from_summands_bound">weak_summation_from_summands_bound</a> of type <a href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # a not-yet-official theorem from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import S, a, b, k, l
from proveit.logic import Forall, Implies
from proveit.numbers import LessEq, Sum
from proveit.numbers.summation import ak, al, bk, bl

# %%
# build up the expression from sub-expressions
sub_expr1 = [S]
sub_expr2 = [l]
expr = Forall([a, b, S], Implies(Forall([k], LessEq(ak, bk), domains = sub_expr1), LessEq(Sum(sub_expr2, al, domains = sub_expr1), Sum(sub_expr2, bl, domains = sub_expr1))))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: weak_summation_from_summands_bound matches stored_expr")

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())

# %%
expr.style_options()

# %%
# display the expression information
expr.expr_info()
