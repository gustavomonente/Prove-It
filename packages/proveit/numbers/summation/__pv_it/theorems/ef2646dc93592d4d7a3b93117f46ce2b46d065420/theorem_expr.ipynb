# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#summation_int_closure">summation_int_closure</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.summation import summation_int_closure

# %%
# check that the built expression is the same as the stored expression
assert summation_int_closure.expr == stored_expr
assert summation_int_closure.expr._style_id == stored_expr._style_id
print("Passed sanity check: summation_int_closure matches stored_expr")
# Out:
# Passed sanity check: summation_int_closure matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(summation_int_closure.latex())
# Out:
# \vdash \forall_{P, Q}~\left(\left[\forall_{x~|~Q(x)}~\left(P(x) \in \mathbb{Z}\right)\right] \Rightarrow \left(\sum_{x~|~Q(x)}~P(x) \in \mathbb{Z}\right)\right)

# %%
summation_int_closure.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
summation_int_closure.expr_info()
# Out:
# 0. forall_{P, Q} ([forall_{x | Q(x)} (P(x) in Integer)] => (Sum_{x | Q(x)} P(x) in Integer))
#    core type: Operation
#    operator: 9
#    operand: 2
# 1. ((P, Q) -> ([forall_{x | Q(x)} (P(x) in Integer)] => (Sum_{x | Q(x)} P(x) in Integer)))
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (P, Q) -> ([forall_{x | Q(x)} (P(x) in Integer)] => (Sum_{x | Q(x)} P(x) in Integer))
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (P, Q)
#    core type: ExprTuple
#    sub-expressions: 25, 26
# 4. [forall_{x | Q(x)} (P(x) in Integer)] => (Sum_{x | Q(x)} P(x) in Integer)
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =>
#    core type: Literal
#    sub-expressions:
# 6. (forall_{x | Q(x)} (P(x) in Integer), Sum_{x | Q(x)} P(x) in Integer)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. forall_{x | Q(x)} (P(x) in Integer)
#    core type: Operation
#    operator: 9
#    operand: 12
# 8. Sum_{x | Q(x)} P(x) in Integer
#    core type: Operation
# ...
