# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, l, m, n
from proveit.logic import Forall, Implies
from proveit.numbers import Interval, LessEq, Sum
from proveit.numbers.summation import ak, al, bk, bl

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = [Interval(m, n)]
expr = Implies(Forall([k], LessEq(ak, bk), domains = sub_expr2), LessEq(Sum(sub_expr1, al, domains = sub_expr2), Sum(sub_expr1, bl, domains = sub_expr2)))
# Out:
# expr: [forall_{k in {m...n}} (a(k) <= b(k))] => ((Sum_{l=m}^{n} a(l)) <= (Sum_{l=m}^{n} b(l)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left[\forall_{k \in \{m \ldots n\}}~\left(a(k) \leq b(k)\right)\right] \Rightarrow \left(\left(\sum_{l=m}^{n} a(l)\right) \leq \left(\sum_{l=m}^{n} b(l)\right)\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. [forall_{k in {m...n}} (a(k) <= b(k))] => ((Sum_{l=m}^{n} a(l)) <= (Sum_{l=m}^{n} b(l)))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{k in {m...n}} (a(k) <= b(k)), (Sum_{l=m}^{n} a(l)) <= (Sum_{l=m}^{n} b(l)))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{k in {m...n}} (a(k) <= b(k))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. (Sum_{l=m}^{n} a(l)) <= (Sum_{l=m}^{n} b(l))
#    core type: Operation
#    operator: 19
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (k -> {a(k) <= b(k) if k in {m...n}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (Sum_{l=m}^{n} a(l), Sum_{l=m}^{n} b(l))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. k -> {a(k) <= b(k) if k in {m...n}.
#    core type: Lambda
#    parameter: 35
#    body: 11
# 9. Sum_{l=m}^{n} a(l)
#    core type: Operation
#    operator: 13
#    operand: 17
# 10. Sum_{l=m}^{n} b(l)
#     core type: Operation
#     operator: 13
#     operand: 18
# 11. {a(k) <= b(k) if k in {m...n}.
#     core type: Conditional
#     value: 15
#     condition: 16
# 12. (l -> {a(l) if l in {m...n}.)
#     core type: ExprTuple
#     sub-expressions: 17
# 13. Sum
#     core type: Literal
#     sub-expressions:
# 14. (l -> {b(l) if l in {m...n}.)
#     core type: ExprTuple
#     sub-expressions: 18
# 15. a(k) <= b(k)
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. k in {m...n}
#     core type: Operation
#     operator: 33
#     operands: 21
# 17. l -> {a(l) if l in {m...n}.
#     core type: Lambda
#     parameter: 36
#     body: 22
# 18. l -> {b(l) if l in {m...n}.
#     core type: Lambda
#     parameter: 36
#     body: 23
# 19. <=
#     core type: Literal
#     sub-expressions:
# 20. (a(k), b(k))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 21. (k, {m...n})
#     core type: ExprTuple
#     sub-expressions: 35, 37
# 22. {a(l) if l in {m...n}.
#     core type: Conditional
#     value: 26
#     condition: 28
# 23. {b(l) if l in {m...n}.
#     core type: Conditional
#     value: 27
#     condition: 28
# 24. a(k)
#     core type: Operation
#     operator: 30
#     operand: 35
# 25. b(k)
#     core type: Operation
#     operator: 31
#     operand: 35
# 26. a(l)
#     core type: Operation
#     operator: 30
#     operand: 36
# 27. b(l)
#     core type: Operation
#     operator: 31
#     operand: 36
# 28. l in {m...n}
#     core type: Operation
#     operator: 33
#     operands: 34
# 29. (k)
#     core type: ExprTuple
#     sub-expressions: 35
# 30. a
#     core type: Variable
#     sub-expressions:
# 31. b
#     core type: Variable
#     sub-expressions:
# 32. (l)
#     core type: ExprTuple
#     sub-expressions: 36
# 33. in
#     core type: Literal
#     sub-expressions:
# 34. (l, {m...n})
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 35. k
#     core type: Variable
#     sub-expressions:
# 36. l
#     core type: Variable
#     sub-expressions:
# 37. {m...n}
#     core type: Operation
#     operator: 38
#     operands: 39
# 38. Interval
#     core type: Literal
#     sub-expressions:
# 39. (m, n)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 40. m
#     core type: Variable
#     sub-expressions:
# 41. n
#     core type: Variable
#     sub-expressions:
