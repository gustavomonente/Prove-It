# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import w, x, y, z
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Complex, Neg, frac

# %%
# build up the expression from sub-expressions
expr = Forall([w, x, y, z], Equals(frac(Add(w, Neg(x)), Add(y, Neg(z))), frac(Add(x, Neg(w)), Add(z, Neg(y)))), domains = [Complex, Complex, Complex, Complex])
# Out:
# expr: forall_{w, x, y, z in Complex} (((w - x) / (y - z)) = ((x - w) / (z - y)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{w, x, y, z \in \mathbb{C}}~\left(\frac{w - x}{y - z} = \frac{x - w}{z - y}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{w, x, y, z in Complex} (((w - x) / (y - z)) = ((x - w) / (z - y)))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((w, x, y, z) -> {((w - x) / (y - z)) = ((x - w) / (z - y)) if w in Complex ,  x in Complex ,  y in Complex ,  z in Complex.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (w, x, y, z) -> {((w - x) / (y - z)) = ((x - w) / (z - y)) if w in Complex ,  x in Complex ,  y in Complex ,  z in Complex.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (w, x, y, z)
#    core type: ExprTuple
#    sub-expressions: 47, 45, 48, 46
# 5. {((w - x) / (y - z)) = ((x - w) / (z - y)) if w in Complex ,  x in Complex ,  y in Complex ,  z in Complex.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. ((w - x) / (y - z)) = ((x - w) / (z - y))
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (w in Complex) and (x in Complex) and (y in Complex) and (z in Complex)
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. ((w - x) / (y - z), (x - w) / (z - y))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (w in Complex, x in Complex, y in Complex, z in Complex)
#     core type: ExprTuple
#     sub-expressions: 14, 15, 16, 17
# 12. (w - x) / (y - z)
#     core type: Operation
#     operator: 19
#     operands: 18
# 13. (x - w) / (z - y)
#     core type: Operation
#     operator: 19
#     operands: 20
# 14. w in Complex
#     core type: Operation
#     operator: 24
#     operands: 21
# 15. x in Complex
#     core type: Operation
#     operator: 24
#     operands: 22
# 16. y in Complex
#     core type: Operation
#     operator: 24
#     operands: 23
# 17. z in Complex
#     core type: Operation
#     operator: 24
#     operands: 25
# 18. (w - x, y - z)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 19. /
#     core type: Literal
#     sub-expressions:
# 20. (x - w, z - y)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 21. (w, Complex)
#     core type: ExprTuple
#     sub-expressions: 47, 30
# 22. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 45, 30
# 23. (y, Complex)
#     core type: ExprTuple
#     sub-expressions: 48, 30
# 24. in
#     core type: Literal
#     sub-expressions:
# 25. (z, Complex)
#     core type: ExprTuple
#     sub-expressions: 46, 30
# 26. w - x
#     core type: Operation
#     operator: 34
#     operands: 31
# 27. y - z
#     core type: Operation
#     operator: 34
#     operands: 32
# 28. x - w
#     core type: Operation
#     operator: 34
#     operands: 33
# 29. z - y
#     core type: Operation
#     operator: 34
#     operands: 35
# 30. Complex
#     core type: Literal
#     sub-expressions:
# 31. (w, -x)
#     core type: ExprTuple
#     sub-expressions: 47, 36
# 32. (y, -z)
#     core type: ExprTuple
#     sub-expressions: 48, 37
# 33. (x, -w)
#     core type: ExprTuple
#     sub-expressions: 45, 38
# 34. +
#     core type: Literal
#     sub-expressions:
# 35. (z, -y)
#     core type: ExprTuple
#     sub-expressions: 46, 39
# 36. -x
#     core type: Operation
#     operator: 43
#     operand: 45
# 37. -z
#     core type: Operation
#     operator: 43
#     operand: 46
# 38. -w
#     core type: Operation
#     operator: 43
#     operand: 47
# 39. -y
#     core type: Operation
#     operator: 43
#     operand: 48
# 40. (x)
#     core type: ExprTuple
#     sub-expressions: 45
# 41. (z)
#     core type: ExprTuple
#     sub-expressions: 46
# 42. (w)
#     core type: ExprTuple
#     sub-expressions: 47
# 43. -
#     core type: Literal
#     sub-expressions:
# 44. (y)
#     core type: ExprTuple
#     sub-expressions: 48
# 45. x
#     core type: Variable
#     sub-expressions:
# 46. z
#     core type: Variable
#     sub-expressions:
# 47. w
#     core type: Variable
#     sub-expressions:
# 48. y
#     core type: Variable
#     sub-expressions:
