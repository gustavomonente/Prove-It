# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b, c, d, e
from proveit.logic import And, Equals, InSet, NotEquals
from proveit.numbers import Complex, Mult, frac, zero

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b, c, d, e], Conditional(Equals(Mult(frac(a, Mult(b, c)), frac(Mult(c, d), e)), Mult(frac(a, b), frac(d, e))), And(InSet(a, Complex), InSet(b, Complex), InSet(c, Complex), InSet(d, Complex), InSet(e, Complex), NotEquals(c, zero))))
# Out:
# expr: (a, b, c, d, e) -> {((a / (b * c)) * ((c * d) / e)) = ((a / b) * (d / e)) if a in Complex ,  b in Complex ,  c in Complex ,  d in Complex ,  e in Complex ,  c != 0.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b, c, d, e\right) \mapsto \left\{\left(\frac{a}{b \cdot c} \cdot \frac{c \cdot d}{e}\right) = \left(\frac{a}{b} \cdot \frac{d}{e}\right) \textrm{ if } a \in \mathbb{C} ,  b \in \mathbb{C} ,  c \in \mathbb{C} ,  d \in \mathbb{C} ,  e \in \mathbb{C} ,  c \neq 0\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, b, c, d, e) -> {((a / (b * c)) * ((c * d) / e)) = ((a / b) * (d / e)) if a in Complex ,  b in Complex ,  c in Complex ,  d in Complex ,  e in Complex ,  c != 0.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a, b, c, d, e)
#    core type: ExprTuple
#    sub-expressions: 40, 45, 46, 47, 41
# 2. {((a / (b * c)) * ((c * d) / e)) = ((a / b) * (d / e)) if a in Complex ,  b in Complex ,  c in Complex ,  d in Complex ,  e in Complex ,  c != 0.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. ((a / (b * c)) * ((c * d) / e)) = ((a / b) * (d / e))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a in Complex) and (b in Complex) and (c in Complex) and (d in Complex) and (e in Complex) and (c != 0)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. ((a / (b * c)) * ((c * d) / e), (a / b) * (d / e))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
# ...
