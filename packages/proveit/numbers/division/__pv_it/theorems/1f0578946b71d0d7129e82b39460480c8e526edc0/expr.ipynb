# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import w, x, y, z
from proveit.logic import And, InSet
from proveit.numbers import Complex

# %%
# build up the expression from sub-expressions
expr = And(InSet(w, Complex), InSet(x, Complex), InSet(y, Complex), InSet(z, Complex))
# Out:
# expr: (w in Complex) and (x in Complex) and (y in Complex) and (z in Complex)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(w \in \mathbb{C}\right) \land \left(x \in \mathbb{C}\right) \land \left(y \in \mathbb{C}\right) \land \left(z \in \mathbb{C}\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (w in Complex) and (x in Complex) and (y in Complex) and (z in Complex)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (w in Complex, x in Complex, y in Complex, z in Complex)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6
# 3. w in Complex
#    core type: Operation
#    operator: 10
#    operands: 7
# 4. x in Complex
#    core type: Operation
#    operator: 10
#    operands: 8
# 5. y in Complex
#    core type: Operation
#    operator: 10
#    operands: 9
# 6. z in Complex
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. (w, Complex)
#    core type: ExprTuple
#    sub-expressions: 12, 16
# 8. (x, Complex)
#    core type: ExprTuple
#    sub-expressions: 13, 16
# 9. (y, Complex)
#    core type: ExprTuple
#    sub-expressions: 14, 16
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (z, Complex)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 12. w
#     core type: Variable
#     sub-expressions:
# 13. x
#     core type: Variable
#     sub-expressions:
# 14. y
#     core type: Variable
#     sub-expressions:
# 15. z
#     core type: Variable
#     sub-expressions:
# 16. Complex
#     core type: Literal
#     sub-expressions:
