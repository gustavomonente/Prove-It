# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b
from proveit.logic import Forall, InSet, NotEquals
from proveit.numbers import Real, frac, zero

# %%
# build up the expression from sub-expressions
expr = Forall([a, b], InSet(frac(a, b), Real), domains = [Real, Real], condition = NotEquals(b, zero))
# Out:
# expr: forall_{a, b in Real | b != 0} ((a / b) in Real)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a, b \in \mathbb{R}~|~b \neq 0}~\left(\frac{a}{b} \in \mathbb{R}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a, b in Real | b != 0} ((a / b) in Real)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b) -> {(a / b) in Real if a in Real ,  b in Real ,  b != 0.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b) -> {(a / b) in Real if a in Real ,  b in Real ,  b != 0.
#    core type: Lambda
#    parameters: 15\n   body: 4
# 4. {(a / b) in Real if a in Real ,  b in Real ,  b != 0.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (a / b) in Real
#    core type: Operation
#    operator: 17
#    operands: 7
# 6. (a in Real) and (b in Real) and (b != 0)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a / b, Real)
#    core type: ExprTuple
#    sub-expressions: 10, 22
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Real, b in Real, b != 0)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 10. a / b
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. a in Real
#     core type: Operation
#     operator: 17
#     operands: 16
# 12. b in Real
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. b != 0
#     core type: Operation
#     operator: 19
#     operands: 20
# 14. /
#     core type: Literal
#     sub-expressions:
# 15. (a, b)
#     core type: ExprTuple
#     sub-expressions: 21, 23
# 16. (a, Real)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (b, Real)
#     core type: ExprTuple
#     sub-expressions: 23, 22
# 19. !=
#     core type: Literal
#     sub-expressions:
# 20. (b, 0)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. a
#     core type: Variable
#     sub-expressions:
# 22. Real
#     core type: Literal
#     sub-expressions:
# 23. b
#     core type: Variable
#     sub-expressions:
# 24. 0
#     core type: Literal
#     sub-expressions:
