# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, x, y
from proveit.logic import And, InSet
from proveit.numbers import Less, LessEq, Real, zero

# %%
# build up the expression from sub-expressions
expr = And(InSet(a, Real), InSet(x, Real), InSet(y, Real), LessEq(x, y), Less(a, zero))
# Out:
# expr: (a in Real) and (x in Real) and (y in Real) and (x <= y) and (a < 0)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{R}\right) \land \left(x \in \mathbb{R}\right) \land \left(y \in \mathbb{R}\right) \land \left(x \leq y\right) \land \left(a < 0\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a in Real) and (x in Real) and (y in Real) and (x <= y) and (a < 0)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (a in Real, x in Real, y in Real, x <= y, a < 0)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6, 7
# 3. a in Real
#    core type: Operation
#    operator: 10
#    operands: 8
# 4. x in Real
#    core type: Operation
#    operator: 10
#    operands: 9
# 5. y in Real
#    core type: Operation
#    operator: 10
#    operands: 11
# 6. x <= y
#    core type: Operation
#    operator: 12
#    operands: 13
# 7. a < 0
#    core type: Operation
#    operator: 14
#    operands: 15
# 8. (a, Real)
#    core type: ExprTuple
#    sub-expressions: 19, 16
# 9. (x, Real)
#    core type: ExprTuple
#    sub-expressions: 17, 16
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (y, Real)
#     core type: ExprTuple
#     sub-expressions: 18, 16
# 12. <=
#     core type: Literal
#     sub-expressions:
# 13. (x, y)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 14. <
#     core type: Literal
#     sub-expressions:
# 15. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 16. Real
#     core type: Literal
#     sub-expressions:
# 17. x
#     core type: Variable
#     sub-expressions:
# 18. y
#     core type: Variable
#     sub-expressions:
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. 0
#     core type: Literal
#     sub-expressions:
