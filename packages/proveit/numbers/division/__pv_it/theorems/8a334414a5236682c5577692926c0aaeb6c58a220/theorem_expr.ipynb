# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#mult_frac_cancel_numer_left">mult_frac_cancel_numer_left</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.division import mult_frac_cancel_numer_left

# %%
# check that the built expression is the same as the stored expression
assert mult_frac_cancel_numer_left.expr == stored_expr
assert mult_frac_cancel_numer_left.expr._style_id == stored_expr._style_id
print("Passed sanity check: mult_frac_cancel_numer_left matches stored_expr")
# Out:
# Passed sanity check: mult_frac_cancel_numer_left matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(mult_frac_cancel_numer_left.latex())
# Out:
# \vdash \forall_{a, b, c, d, e \in \mathbb{C}~|~b \neq 0}~\left(\left(\frac{a \cdot b}{c} \cdot \frac{d}{b \cdot e}\right) = \left(\frac{a}{c} \cdot \frac{d}{e}\right)\right)

# %%
mult_frac_cancel_numer_left.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
mult_frac_cancel_numer_left.expr_info()
# Out:
# 0. forall_{a, b, c, d, e in Complex | b != 0} ((((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e)))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b, c, d, e) -> {(((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e)) if a in Complex ,  b in Complex ,  c in Complex ,  d in Complex ,  e in Complex ,  b != 0.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b, c, d, e) -> {(((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e)) if a in Complex ,  b in Complex ,  c in Complex ,  d in Complex ,  e in Complex ,  b != 0.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a, b, c, d, e)
#    core type: ExprTuple
#    sub-expressions: 48, 49, 43, 44, 50
# 5. {(((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e)) if a in Complex ,  b in Complex ,  c in Complex ,  d in Complex ,  e in Complex ,  b != 0.
#    core type: Conditional
#    value: 6
#    condition: 7
# ...
