# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import x, y, z
from proveit.logic import Equals, Forall, NotEquals
from proveit.numbers import Complex, Mult, frac, zero

# %%
# build up the expression from sub-expressions
expr = Forall([x, y, z], Equals(frac(Mult(x, y), Mult(x, z)), frac(y, z)), domains = [Complex, Complex, Complex], condition = NotEquals(x, zero))
# Out:
# expr: forall_{x, y, z in Complex | x != 0} (((x * y) / (x * z)) = (y / z))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x, y, z \in \mathbb{C}~|~x \neq 0}~\left(\frac{x \cdot y}{x \cdot z} = \frac{y}{z}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{x, y, z in Complex | x != 0} (((x * y) / (x * z)) = (y / z))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((x, y, z) -> {((x * y) / (x * z)) = (y / z) if x in Complex ,  y in Complex ,  z in Complex ,  x != 0.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (x, y, z) -> {((x * y) / (x * z)) = (y / z) if x in Complex ,  y in Complex ,  z in Complex ,  x != 0.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (x, y, z)
#    core type: ExprTuple
#    sub-expressions: 35, 34, 36
# 5. {((x * y) / (x * z)) = (y / z) if x in Complex ,  y in Complex ,  z in Complex ,  x != 0.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. ((x * y) / (x * z)) = (y / z)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (x in Complex) and (y in Complex) and (z in Complex) and (x != 0)
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. ((x * y) / (x * z), y / z)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (x in Complex, y in Complex, z in Complex, x != 0)
#     core type: ExprTuple
#     sub-expressions: 14, 15, 16, 17
# 12. (x * y) / (x * z)
#     core type: Operation
#     operator: 19
#     operands: 18
# 13. y / z
#     core type: Operation
#     operator: 19
#     operands: 20
# 14. x in Complex
#     core type: Operation
#     operator: 23
#     operands: 21
# 15. y in Complex
#     core type: Operation
#     operator: 23
#     operands: 22
# 16. z in Complex
#     core type: Operation
#     operator: 23
#     operands: 24
# 17. x != 0
#     core type: Operation
#     operator: 25
#     operands: 26
# 18. (x * y, x * z)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 19. /
#     core type: Literal
#     sub-expressions:
# 20. (y, z)
#     core type: ExprTuple
#     sub-expressions: 34, 36
# 21. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 35, 29
# 22. (y, Complex)
#     core type: ExprTuple
#     sub-expressions: 34, 29
# 23. in
#     core type: Literal
#     sub-expressions:
# 24. (z, Complex)
#     core type: ExprTuple
#     sub-expressions: 36, 29
# 25. !=
#     core type: Literal
#     sub-expressions:
# 26. (x, 0)
#     core type: ExprTuple
#     sub-expressions: 35, 30
# 27. x * y
#     core type: Operation
#     operator: 32
#     operands: 31
# 28. x * z
#     core type: Operation
#     operator: 32
#     operands: 33
# 29. Complex
#     core type: Literal
#     sub-expressions:
# 30. 0
#     core type: Literal
#     sub-expressions:
# 31. (x, y)
#     core type: ExprTuple
#     sub-expressions: 35, 34
# 32. *
#     core type: Literal
#     sub-expressions:
# 33. (x, z)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 34. y
#     core type: Variable
#     sub-expressions:
# 35. x
#     core type: Variable
#     sub-expressions:
# 36. z
#     core type: Variable
#     sub-expressions:
