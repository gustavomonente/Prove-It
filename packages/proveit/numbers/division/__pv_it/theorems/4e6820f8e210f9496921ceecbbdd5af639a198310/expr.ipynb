# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, x, y
from proveit.logic import And, InSet
from proveit.numbers import Less, LessEq, Real, frac, greater_eq, zero

# %%
# build up the expression from sub-expressions
expr = Lambda([a, x, y], Conditional(greater_eq(frac(x, a), frac(y, a)), And(InSet(a, Real), InSet(x, Real), InSet(y, Real), LessEq(x, y), Less(a, zero))))
# Out:
# expr: (a, x, y) -> {(x / a) >= (y / a) if a in Real ,  x in Real ,  y in Real ,  x <= y ,  a < 0.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, x, y\right) \mapsto \left\{\frac{x}{a} \geq \frac{y}{a} \textrm{ if } a \in \mathbb{R} ,  x \in \mathbb{R} ,  y \in \mathbb{R} ,  x \leq y ,  a < 0\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, x, y) -> {(x / a) >= (y / a) if a in Real ,  x in Real ,  y in Real ,  x <= y ,  a < 0.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a, x, y)
#    core type: ExprTuple
#    sub-expressions: 29, 27, 28
# 2. {(x / a) >= (y / a) if a in Real ,  x in Real ,  y in Real ,  x <= y ,  a < 0.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (x / a) >= (y / a)
#    core type: Operation
#    operator: 22
#    operands: 5
# 4. (a in Real) and (x in Real) and (y in Real) and (x <= y) and (a < 0)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (y / a, x / a)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a in Real, x in Real, y in Real, x <= y, a < 0)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12, 13, 14
# 8. y / a
#    core type: Operation
#    operator: 16
#    operands: 15
# 9. x / a
#    core type: Operation
#    operator: 16
#    operands: 17
# 10. a in Real
# ...
