# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, x
from proveit.logic import Equals, InSet
from proveit.numbers import Abs, Neg, RealNeg

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(x, Conditional(Equals(Abs(x), Neg(x)), InSet(x, RealNeg))))
# Out:
# expr: (x -> {|x| = (-x) if x in RealNeg.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \mapsto \left\{\left|x\right| = \left(-x\right) \textrm{ if } x \in \mathbb{R}^-\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x -> {|x| = (-x) if x in RealNeg.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. x -> {|x| = (-x) if x in RealNeg.
#    core type: Lambda
#    parameter: 15
#    body: 2
# 2. {|x| = (-x) if x in RealNeg.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. |x| = (-x)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. x in RealNeg
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (|x|, -x)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (x, RealNeg)
#    core type: ExprTuple
#    sub-expressions: 15, 11
# 9. |x|
#    core type: Operation
#    operator: 12
#    operand: 15
# 10. -x
#     core type: Operation
#     operator: 13
#     operand: 15
# 11. RealNeg
#     core type: Literal
#     sub-expressions:
# 12. Abs
#     core type: Literal
#     sub-expressions:
# 13. -
#     core type: Literal
#     sub-expressions:
# 14. (x)
#     core type: ExprTuple
#     sub-expressions: 15
# 15. x
#     core type: Variable
#     sub-expressions:
