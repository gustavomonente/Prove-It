# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a, b
from proveit.logic import And, InSet
from proveit.numbers import Abs, Add, Complex, LessEq

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([a, b], Conditional(LessEq(Abs(Add(a, b)), Add(Abs(a), Abs(b))), And(InSet(a, Complex), InSet(b, Complex)))))
# Out:
# expr: ((a, b) -> {|a + b| <= (|a| + |b|) if a in Complex ,  b in Complex.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a, b\right) \mapsto \left\{\left|a + b\right| \leq \left(\left|a\right| + \left|b\right|\right) \textrm{ if } a \in \mathbb{C} ,  b \in \mathbb{C}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a, b) -> {|a + b| <= (|a| + |b|) if a in Complex ,  b in Complex.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a, b) -> {|a + b| <= (|a| + |b|) if a in Complex ,  b in Complex.
#    core type: Lambda
#    parameters: 23\n   body: 2
# 2. {|a + b| <= (|a| + |b|) if a in Complex ,  b in Complex.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. |a + b| <= (|a| + |b|)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a in Complex) and (b in Complex)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. <=
#    core type: Literal
#    sub-expressions:
# 6. (|a + b|, |a| + |b|)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Complex, b in Complex)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. |a + b|
#    core type: Operation
#    operator: 25
#    operand: 18
# 10. |a| + |b|
#     core type: Operation
#     operator: 22
#     operands: 14
# 11. a in Complex
#     core type: Operation
#     operator: 16
#     operands: 15
# 12. b in Complex
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. (a + b)
#     core type: ExprTuple
#     sub-expressions: 18
# 14. (|a|, |b|)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 15. (a, Complex)
#     core type: ExprTuple
#     sub-expressions: 27, 21
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 28, 21
# 18. a + b
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. |a|
#     core type: Operation
#     operator: 25
#     operand: 27
# 20. |b|
#     core type: Operation
#     operator: 25
#     operand: 28
# 21. Complex
#     core type: Literal
#     sub-expressions:
# 22. +
#     core type: Literal
#     sub-expressions:
# 23. (a, b)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 24. (a)
#     core type: ExprTuple
#     sub-expressions: 27
# 25. Abs
#     core type: Literal
#     sub-expressions:
# 26. (b)
#     core type: ExprTuple
#     sub-expressions: 28
# 27. a
#     core type: Variable
#     sub-expressions:
# 28. b
#     core type: Variable
#     sub-expressions:
