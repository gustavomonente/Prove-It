# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a
from proveit.logic import InSet
from proveit.numbers import Abs, Complex, Real

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(a, Conditional(InSet(Abs(a), Real), InSet(a, Complex))))
# Out:
# expr: (a -> {|a| in Real if a in Complex.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \mapsto \left\{\left|a\right| \in \mathbb{R} \textrm{ if } a \in \mathbb{C}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a -> {|a| in Real if a in Complex.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. a -> {|a| in Real if a in Complex.
#    core type: Lambda
#    parameter: 13
#    body: 2
# 2. {|a| in Real if a in Complex.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. |a| in Real
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. a in Complex
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (|a|, Real)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (a, Complex)
#    core type: ExprTuple
#    sub-expressions: 13, 10
# 8. |a|
#    core type: Operation
#    operator: 11
#    operand: 13
# 9. Real
#    core type: Literal
#    sub-expressions:
# 10. Complex
#     core type: Literal
#     sub-expressions:
# 11. Abs
#     core type: Literal
#     sub-expressions:
# 12. (a)
#     core type: ExprTuple
#     sub-expressions: 13
# 13. a
#     core type: Variable
#     sub-expressions:
