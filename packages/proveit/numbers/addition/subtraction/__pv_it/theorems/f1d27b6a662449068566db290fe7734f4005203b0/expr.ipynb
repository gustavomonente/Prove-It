# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition.subtraction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, b, i, j, k
from proveit.core_expr_types import a_1_to_i, c_1_to_j, d_1_to_k
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Add, Complex, Natural, Neg

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([a_1_to_i, b, c_1_to_j, d_1_to_k], Equals(Add(a_1_to_i, Neg(b), c_1_to_j, b, d_1_to_k), Add(a_1_to_i, c_1_to_j, d_1_to_k)), domains = [Complex, Complex, Complex, Complex]), And(InSet(i, Natural), InSet(j, Natural), InSet(k, Natural)))
# Out:
# expr: {forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k} in Complex} ((a_{1} i repeats ..a_{_a}.. + a_{i} - b + c_{1} j repeats ..c_{_a}.. + c_{j} + b + d_{1} k repeats ..d_{_a}.. + d_{k}) = (a_{1} + ..a_{_a}.. + a_{i} + c_{1} + ..c_{_a}.. + c_{j} + d_{1} + ..d_{_a}.. + d_{k})) if i in Natural ,  j in Natural ,  k in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{a_{1}, \ldots, a_{i}, b, c_{1}, \ldots, c_{j}, d_{1}, \ldots, d_{k} \in \mathbb{C}}~\left(\left(a_{1} i \textrm{ repeats} \ldots + a_{i} - b + c_{1} j \textrm{ repeats} \ldots + c_{j} + b + d_{1} k \textrm{ repeats} \ldots + d_{k}\right) = \left(a_{1} + \ldots + a_{i} + c_{1} + \ldots + c_{j} + d_{1} + \ldots + d_{k}\right)\right) \textrm{ if } i \in \mathbb{N} ,  j \in \mathbb{N} ,  k \in \mathbb{N}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k} in Complex} ((a_{1} i repeats ..a_{_a}.. + a_{i} - b + c_{1} j repeats ..c_{_a}.. + c_{j} + b + d_{1} k repeats ..d_{_a}.. + d_{k}) = (a_{1} + ..a_{_a}.. + a_{i} + c_{1} + ..c_{_a}.. + c_{j} + d_{1} + ..d_{_a}.. + d_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k} in Complex} ((a_{1} i repeats ..a_{_a}.. + a_{i} - b + c_{1} j repeats ..c_{_a}.. + c_{j} + b + d_{1} k repeats ..d_{_a}.. + d_{k}) = (a_{1} + ..a_{_a}.. + a_{i} + c_{1} + ..c_{_a}.. + c_{j} + d_{1} + ..d_{_a}.. + d_{k}))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (i in Natural) and (j in Natural) and (k in Natural)
#    core type: Operation
#    operator: 20
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k}) -> {(a_{1} i repeats ..a_{_a}.. + a_{i} - b + c_{1} j repeats ..c_{_a}.. + c_{j} + b + d_{1} k repeats ..d_{_a}.. + d_{k}) = (a_{1} + ..a_{_a}.. + a_{i} + c_{1} + ..c_{_a}.. + c_{j} + d_{1} + ..d_{_a}.. + d_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{j} in Complex ,  d_{1} in Complex ,  ..d_{_a} in Complex.. ,  d_{k} in Complex.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (i in Natural, j in Natural, k in Natural)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 6. (a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k}) -> {(a_{1} i repeats ..a_{_a}.. + a_{i} - b + c_{1} j repeats ..c_{_a}.. + c_{j} + b + d_{1} k repeats ..d_{_a}.. + d_{k}) = (a_{1} + ..a_{_a}.. + a_{i} + c_{1} + ..c_{_a}.. + c_{j} + d_{1} + ..d_{_a}.. + d_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{j} in Complex ,  d_{1} in Complex ,  ..d_{_a} in Complex.. ,  d_{k} in Complex.
#    core type: Lambda
#    parameters: 10\n   body: 11
# 7. i in Natural
#    core type: Operation
#    operator: 53
#    operands: 12
# 8. j in Natural
#    core type: Operation
#    operator: 53
#    operands: 13
# 9. k in Natural
#    core type: Operation
#    operator: 53
#    operands: 14
# 10. (a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k})
#     core type: ExprTuple
#     sub-expressions: 36, 55, 37, 38
# 11. {(a_{1} i repeats ..a_{_a}.. + a_{i} - b + c_{1} j repeats ..c_{_a}.. + c_{j} + b + d_{1} k repeats ..d_{_a}.. + d_{k}) = (a_{1} + ..a_{_a}.. + a_{i} + c_{1} + ..c_{_a}.. + c_{j} + d_{1} + ..d_{_a}.. + d_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{j} in Complex ,  d_{1} in Complex ,  ..d_{_a} in Complex.. ,  d_{k} in Complex.
#     core type: Conditional
#     value: 15
#     condition: 16
# 12. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 45, 17
# 13. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 47, 17
# 14. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 50, 17
# 15. (a_{1} i repeats ..a_{_a}.. + a_{i} - b + c_{1} j repeats ..c_{_a}.. + c_{j} + b + d_{1} k repeats ..d_{_a}.. + d_{k}) = (a_{1} + ..a_{_a}.. + a_{i} + c_{1} + ..c_{_a}.. + c_{j} + d_{1} + ..d_{_a}.. + d_{k})
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{i} in Complex) and (b in Complex) and (c_{1} in Complex) and ..(c_{_a} in Complex).. and (c_{j} in Complex) and (d_{1} in Complex) and ..(d_{_a} in Complex).. and (d_{k} in Complex)
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. Natural
#     core type: Literal
#     sub-expressions:
# 18. =
#     core type: Literal
#     sub-expressions:
# 19. (a_{1} i repeats ..a_{_a}.. + a_{i} - b + c_{1} j repeats ..c_{_a}.. + c_{j} + b + d_{1} k repeats ..d_{_a}.. + d_{k}, a_{1} + ..a_{_a}.. + a_{i} + c_{1} + ..c_{_a}.. + c_{j} + d_{1} + ..d_{_a}.. + d_{k})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. and
#     core type: Literal
#     sub-expressions:
# 21. (a_{1} in Complex, ..a_{_a} in Complex.., a_{i} in Complex, b in Complex, c_{1} in Complex, ..c_{_a} in Complex.., c_{j} in Complex, d_{1} in Complex, ..d_{_a} in Complex.., d_{k} in Complex)
#     core type: ExprTuple
#     sub-expressions: 24, 25, 26, 27
# 22. a_{1} i repeats ..a_{_a}.. + a_{i} - b + c_{1} j repeats ..c_{_a}.. + c_{j} + b + d_{1} k repeats ..d_{_a}.. + d_{k}
#     core type: Operation
#     operator: 29
#     operands: 28
# 23. a_{1} + ..a_{_a}.. + a_{i} + c_{1} + ..c_{_a}.. + c_{j} + d_{1} + ..d_{_a}.. + d_{k}
#     core type: Operation
#     operator: 29
#     operands: 30
# 24. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 49
#     end_index: 45
# 25. b in Complex
#     core type: Operation
#     operator: 53
#     operands: 32
# 26. (c_{1} in Complex), ..(c_{_a} in Complex).., (c_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 49
#     end_index: 47
# 27. (d_{1} in Complex), ..(d_{_a} in Complex).., (d_{k} in Complex)
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 49
#     end_index: 50
# 28. (a_{1}, ..a_{_a}.., a_{i}, -b, c_{1}, ..c_{_a}.., c_{j}, b, d_{1}, ..d_{_a}.., d_{k})
#     core type: ExprTuple
#     sub-expressions: 36, 35, 37, 55, 38
# 29. +
#     core type: Literal
#     sub-expressions:
# 30. (a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k})
#     core type: ExprTuple
#     sub-expressions: 36, 37, 38
# 31. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 64
#     body: 39
# 32. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 55, 59
# 33. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 64
#     body: 40
# 34. _a -> (d_{_a} in Complex)
#     core type: Lambda
#     parameter: 64
#     body: 41
# 35. -b
#     core type: Operation
#     operator: 42
#     operand: 55
# 36. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 49
#     end_index: 45
# 37. c_{1}, ..c_{_a}.., c_{j}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 49
#     end_index: 47
# 38. d_{1}, ..d_{_a}.., d_{k}
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 49
#     end_index: 50
# 39. a_{_a} in Complex
#     core type: Operation
#     operator: 53
#     operands: 51
# 40. c_{_a} in Complex
#     core type: Operation
#     operator: 53
#     operands: 52
# 41. d_{_a} in Complex
#     core type: Operation
#     operator: 53
#     operands: 54
# 42. -
#     core type: Literal
#     sub-expressions:
# 43. (b)
#     core type: ExprTuple
#     sub-expressions: 55
# 44. _a -> a_{_a}
#     core type: Lambda
#     parameter: 64
#     body: 56
# 45. i
#     core type: Variable
#     sub-expressions:
# 46. _a -> c_{_a}
#     core type: Lambda
#     parameter: 64
#     body: 57
# 47. j
#     core type: Variable
#     sub-expressions:
# 48. _a -> d_{_a}
#     core type: Lambda
#     parameter: 64
#     body: 58
# 49. 1
#     core type: Literal
#     sub-expressions:
# 50. k
#     core type: Variable
#     sub-expressions:
# 51. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 56, 59
# 52. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 57, 59
# 53. in
#     core type: Literal
#     sub-expressions:
# 54. (d_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 55. b
#     core type: Variable
#     sub-expressions:
# 56. a_{_a}
#     core type: IndexedVar
# variable: 60
# index: 64
# 57. c_{_a}
#     core type: IndexedVar
# variable: 61
# index: 64
# 58. d_{_a}
#     core type: IndexedVar
# variable: 62
# index: 64
# 59. Complex
#     core type: Literal
#     sub-expressions:
# 60. a
#     core type: Variable
#     sub-expressions:
# 61. c
#     core type: Variable
#     sub-expressions:
# 62. d
#     core type: Variable
#     sub-expressions:
# 63. (_a)
#     core type: ExprTuple
#     sub-expressions: 64
# 64. _a
#     core type: Variable
#     sub-expressions:
