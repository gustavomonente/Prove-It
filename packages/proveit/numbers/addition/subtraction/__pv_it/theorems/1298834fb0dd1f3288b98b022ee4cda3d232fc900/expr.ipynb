# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition.subtraction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, ExprTuple, IndexedVar, Lambda, Variable, a, b, c, i, j, k
from proveit.core_expr_types import a_1_to_i, b_1_to_j, c_1_to_k
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Complex, Neg, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(Lambda([a_1_to_i, b_1_to_j, c_1_to_k], Conditional(Equals(Add(a_1_to_i, Neg(Add(b_1_to_j)), c_1_to_k), Add(a_1_to_i, ExprRange(a, Neg(IndexedVar(b, a)), one, j), c_1_to_k)).with_wrapping_at(2), And(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), Complex), one, i), ExprRange(sub_expr1, InSet(IndexedVar(b, sub_expr1), Complex), one, j), ExprRange(sub_expr1, InSet(IndexedVar(c, sub_expr1), Complex), one, k)))))
# Out:
# expr: ((a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k}) -> {(a_{1} i repeats ..a_{_a}.. + a_{i} - (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} k repeats ..c_{_a}.. + c_{k}) =  \\ (a_{1} i repeats ..a_{_a}.. + a_{i} - b_{1} j repeats ..b_{a}.. - b_{j} + c_{1} k repeats ..c_{_a}.. + c_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b_{1} in Complex ,  ..b_{_a} in Complex.. ,  b_{j} in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{k} in Complex.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a_{1}, \ldots, a_{i}, b_{1}, \ldots, b_{j}, c_{1}, \ldots, c_{k}\right) \mapsto \left\{\begin{array}{c} \begin{array}{l} \left(a_{1} i \textrm{ repeats} \ldots + a_{i} - \left(b_{1} + \ldots + b_{j}\right) + c_{1} k \textrm{ repeats} \ldots + c_{k}\right) =  \\ \left(a_{1} i \textrm{ repeats} \ldots + a_{i} - b_{1} j \textrm{ repeats} \ldots - b_{j} + c_{1} k \textrm{ repeats} \ldots + c_{k}\right) \end{array} \end{array} \textrm{ if } a_{1} \in \mathbb{C} ,  \ldots ,  a_{i} \in \mathbb{C} ,  b_{1} \in \mathbb{C} ,  \ldots ,  b_{j} \in \mathbb{C} ,  c_{1} \in \mathbb{C} ,  \ldots ,  c_{k} \in \mathbb{C}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k}) -> {(a_{1} i repeats ..a_{_a}.. + a_{i} - (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} k repeats ..c_{_a}.. + c_{k}) =  \\ (a_{1} i repeats ..a_{_a}.. + a_{i} - b_{1} j repeats ..b_{a}.. - b_{j} + c_{1} k repeats ..c_{_a}.. + c_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b_{1} in Complex ,  ..b_{_a} in Complex.. ,  b_{j} in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{k} in Complex.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k}) -> {(a_{1} i repeats ..a_{_a}.. + a_{i} - (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} k repeats ..c_{_a}.. + c_{k}) =  \\ (a_{1} i repeats ..a_{_a}.. + a_{i} - b_{1} j repeats ..b_{a}.. - b_{j} + c_{1} k repeats ..c_{_a}.. + c_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b_{1} in Complex ,  ..b_{_a} in Complex.. ,  b_{j} in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{k} in Complex.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k})
#    core type: ExprTuple
#    sub-expressions: 21, 47, 23
# 3. {(a_{1} i repeats ..a_{_a}.. + a_{i} - (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} k repeats ..c_{_a}.. + c_{k}) =  \\ (a_{1} i repeats ..a_{_a}.. + a_{i} - b_{1} j repeats ..b_{a}.. - b_{j} + c_{1} k repeats ..c_{_a}.. + c_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b_{1} in Complex ,  ..b_{_a} in Complex.. ,  b_{j} in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{k} in Complex.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (a_{1} i repeats ..a_{_a}.. + a_{i} - (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} k repeats ..c_{_a}.. + c_{k}) =  \\ (a_{1} i repeats ..a_{_a}.. + a_{i} - b_{1} j repeats ..b_{a}.. - b_{j} + c_{1} k repeats ..c_{_a}.. + c_{k})
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{i} in Complex) and (b_{1} in Complex) and ..(b_{_a} in Complex).. and (b_{j} in Complex) and (c_{1} in Complex) and ..(c_{_a} in Complex).. and (c_{k} in Complex)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (a_{1} i repeats ..a_{_a}.. + a_{i} - (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} k repeats ..c_{_a}.. + c_{k}, a_{1} i repeats ..a_{_a}.. + a_{i} - b_{1} j repeats ..b_{a}.. - b_{j} + c_{1} k repeats ..c_{_a}.. + c_{k})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a_{1} in Complex, ..a_{_a} in Complex.., a_{i} in Complex, b_{1} in Complex, ..b_{_a} in Complex.., b_{j} in Complex, c_{1} in Complex, ..c_{_a} in Complex.., c_{k} in Complex)
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14
# 10. a_{1} i repeats ..a_{_a}.. + a_{i} - (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} k repeats ..c_{_a}.. + c_{k}
#     core type: Operation
#     operator: 42
#     operands: 15
# 11. a_{1} i repeats ..a_{_a}.. + a_{i} - b_{1} j repeats ..b_{a}.. - b_{j} + c_{1} k repeats ..c_{_a}.. + c_{k}
#     core type: Operation
#     operator: 42
#     operands: 16
# 12. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 50
#     end_index: 29
# 13. (b_{1} in Complex), ..(b_{_a} in Complex).., (b_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 50
#     end_index: 51
# 14. (c_{1} in Complex), ..(c_{_a} in Complex).., (c_{k} in Complex)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 50
#     end_index: 32
# 15. (a_{1}, ..a_{_a}.., a_{i}, -(b_{1} + ..b_{_a}.. + b_{j}), c_{1}, ..c_{_a}.., c_{k})
#     core type: ExprTuple
#     sub-expressions: 21, 20, 23
# 16. (a_{1}, ..a_{_a}.., a_{i}, -b_{1}, ..-b_{a}.., -b_{j}, c_{1}, ..c_{_a}.., c_{k})
#     core type: ExprTuple
#     sub-expressions: 21, 22, 23
# 17. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 57
#     body: 24
# 18. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 57
#     body: 25
# 19. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 57
#     body: 26
# 20. -(b_{1} + ..b_{_a}.. + b_{j})
#     core type: Operation
#     operator: 44
#     operand: 37
# 21. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 50
#     end_index: 29
# 22. (-b_{1}), ..(-b_{a}).., (-b_{j})
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 50
#     end_index: 51
# 23. c_{1}, ..c_{_a}.., c_{k}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 50
#     end_index: 32
# 24. a_{_a} in Complex
#     core type: Operation
#     operator: 35
#     operands: 33
# 25. b_{_a} in Complex
#     core type: Operation
#     operator: 35
#     operands: 34
# 26. c_{_a} in Complex
#     core type: Operation
#     operator: 35
#     operands: 36
# 27. (b_{1} + ..b_{_a}.. + b_{j})
#     core type: ExprTuple
#     sub-expressions: 37
# 28. _a -> a_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 39
# 29. i
#     core type: Variable
#     sub-expressions:
# 30. a -> (-b_{a})
#     core type: Lambda
#     parameter: 54
#     body: 38
# 31. _a -> c_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 40
# 32. k
#     core type: Variable
#     sub-expressions:
# 33. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 39, 41
# 34. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 53, 41
# 35. in
#     core type: Literal
#     sub-expressions:
# 36. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 37. b_{1} + ..b_{_a}.. + b_{j}
#     core type: Operation
#     operator: 42
#     operands: 43
# 38. -b_{a}
#     core type: Operation
#     operator: 44
#     operand: 48
# 39. a_{_a}
#     core type: IndexedVar
# variable: 54
# index: 57
# 40. c_{_a}
#     core type: IndexedVar
# variable: 46
# index: 57
# 41. Complex
#     core type: Literal
#     sub-expressions:
# 42. +
#     core type: Literal
#     sub-expressions:
# 43. (b_{1}, ..b_{_a}.., b_{j})
#     core type: ExprTuple
#     sub-expressions: 47
# 44. -
#     core type: Literal
#     sub-expressions:
# 45. (b_{a})
#     core type: ExprTuple
#     sub-expressions: 48
# 46. c
#     core type: Variable
#     sub-expressions:
# 47. b_{1}, ..b_{_a}.., b_{j}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 50
#     end_index: 51
# 48. b_{a}
#     core type: IndexedVar
# variable: 55
# index: 54
# 49. _a -> b_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 53
# 50. 1
#     core type: Literal
#     sub-expressions:
# 51. j
#     core type: Variable
#     sub-expressions:
# 52. (a)
#     core type: ExprTuple
#     sub-expressions: 54
# 53. b_{_a}
#     core type: IndexedVar
# variable: 55
# index: 57
# 54. a
#     core type: Variable
#     sub-expressions:
# 55. b
#     core type: Variable
#     sub-expressions:
# 56. (_a)
#     core type: ExprTuple
#     sub-expressions: 57
# 57. _a
#     core type: Variable
#     sub-expressions:
