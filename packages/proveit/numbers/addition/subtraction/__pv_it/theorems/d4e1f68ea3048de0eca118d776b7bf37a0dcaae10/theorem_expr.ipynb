# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#add_cancel_triple_21">add_cancel_triple_21</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition.subtraction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.addition.subtraction import add_cancel_triple_21

# %%
# check that the built expression is the same as the stored expression
assert add_cancel_triple_21.expr == stored_expr
assert add_cancel_triple_21.expr._style_id == stored_expr._style_id
print("Passed sanity check: add_cancel_triple_21 matches stored_expr")
# Out:
# Passed sanity check: add_cancel_triple_21 matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(add_cancel_triple_21.latex())
# Out:
# \vdash \forall_{a, b \in \mathbb{C}}~\left(\left(-a + a + b\right) = b\right)

# %%
add_cancel_triple_21.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
add_cancel_triple_21.expr_info()
# Out:
# 0. forall_{a, b in Complex} ((-a + a + b) = b)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b) -> {(-a + a + b) = b if a in Complex ,  b in Complex.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b) -> {(-a + a + b) = b if a in Complex ,  b in Complex.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a, b)
#    core type: ExprTuple
#    sub-expressions: 25, 21
# 5. {(-a + a + b) = b if a in Complex ,  b in Complex.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (-a + a + b) = b
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a in Complex) and (b in Complex)
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. (-a + a + b, b)
#    core type: ExprTuple
#    sub-expressions: 12, 21
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (a in Complex, b in Complex)
# ...
