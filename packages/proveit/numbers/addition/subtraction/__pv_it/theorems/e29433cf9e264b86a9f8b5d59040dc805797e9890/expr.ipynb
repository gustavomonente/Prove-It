# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition.subtraction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable, a, b, c, i, j, k
from proveit.logic import InSet
from proveit.numbers import Complex, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), Complex), one, i), ExprRange(sub_expr1, InSet(IndexedVar(b, sub_expr1), Complex), one, j), ExprRange(sub_expr1, InSet(IndexedVar(c, sub_expr1), Complex), one, k))
# Out:
# expr: (a_{1} in Complex, ..a_{_a} in Complex.., a_{i} in Complex, b_{1} in Complex, ..b_{_a} in Complex.., b_{j} in Complex, c_{1} in Complex, ..c_{_a} in Complex.., c_{k} in Complex)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1} \in \mathbb{C}, \ldots, a_{i} \in \mathbb{C}, b_{1} \in \mathbb{C}, \ldots, b_{j} \in \mathbb{C}, c_{1} \in \mathbb{C}, \ldots, c_{k} \in \mathbb{C}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1} in Complex, ..a_{_a} in Complex.., a_{i} in Complex, b_{1} in Complex, ..b_{_a} in Complex.., b_{j} in Complex, c_{1} in Complex, ..c_{_a} in Complex.., c_{k} in Complex)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{i} in Complex)
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 9
#    end_index: 5
# 2. (b_{1} in Complex), ..(b_{_a} in Complex).., (b_{j} in Complex)
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 9
#    end_index: 7
# 3. (c_{1} in Complex), ..(c_{_a} in Complex).., (c_{k} in Complex)
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 10
# 4. _a -> (a_{_a} in Complex)
#    core type: Lambda
#    parameter: 26
#    body: 11
# 5. i
#    core type: Variable
#    sub-expressions:
# 6. _a -> (b_{_a} in Complex)
#    core type: Lambda
#    parameter: 26
#    body: 12
# 7. j
#    core type: Variable
#    sub-expressions:
# 8. _a -> (c_{_a} in Complex)
#    core type: Lambda
#    parameter: 26
#    body: 13
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. k
#     core type: Variable
#     sub-expressions:
# 11. a_{_a} in Complex
#     core type: Operation
#     operator: 16
#     operands: 14
# 12. b_{_a} in Complex
#     core type: Operation
#     operator: 16
#     operands: 15
# 13. c_{_a} in Complex
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 18, 21
# 15. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 19, 21
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. a_{_a}
#     core type: IndexedVar
# variable: 22
# index: 26
# 19. b_{_a}
#     core type: IndexedVar
# variable: 23
# index: 26
# 20. c_{_a}
#     core type: IndexedVar
# variable: 24
# index: 26
# 21. Complex
#     core type: Literal
#     sub-expressions:
# 22. a
#     core type: Variable
#     sub-expressions:
# 23. b
#     core type: Variable
#     sub-expressions:
# 24. c
#     core type: Variable
#     sub-expressions:
# 25. (_a)
#     core type: ExprTuple
#     sub-expressions: 26
# 26. _a
#     core type: Variable
#     sub-expressions:
