# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, b, m
from proveit.core_expr_types import a_1_to_m
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Add, Natural

# %%
# build up the expression from sub-expressions
expr = Lambda(m, Conditional(Forall([a_1_to_m, b], Equals(Add(a_1_to_m, b), Add(Add(a_1_to_m), b)).with_wrapping_at(2)), InSet(m, Natural)))
# Out:
# expr: m -> {forall_{a_{1}, ..a_{_a}.., a_{m}, b} ((a_{1} + ..a_{_a}.. + a_{m} + b) =  \\ ((a_{1} + ..a_{_a}.. + a_{m}) + b)) if m in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# m \mapsto \left\{\forall_{a_{1}, \ldots, a_{m}, b}~\left(\begin{array}{c} \begin{array}{l} \left(a_{1} + \ldots + a_{m} + b\right) =  \\ \left(\left(a_{1} + \ldots + a_{m}\right) + b\right) \end{array} \end{array}\right) \textrm{ if } m \in \mathbb{N}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. m -> {forall_{a_{1}, ..a_{_a}.., a_{m}, b} ((a_{1} + ..a_{_a}.. + a_{m} + b) =  \\ ((a_{1} + ..a_{_a}.. + a_{m}) + b)) if m in Natural.
#    core type: Lambda
#    parameter: 24
#    body: 1
# 1. {forall_{a_{1}, ..a_{_a}.., a_{m}, b} ((a_{1} + ..a_{_a}.. + a_{m} + b) =  \\ ((a_{1} + ..a_{_a}.. + a_{m}) + b)) if m in Natural.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{a_{1}, ..a_{_a}.., a_{m}, b} ((a_{1} + ..a_{_a}.. + a_{m} + b) =  \\ ((a_{1} + ..a_{_a}.. + a_{m}) + b))
#    core type: Operation
#    operator: 4
#    operand: 8
# 3. m in Natural
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. ((a_{1}, ..a_{_a}.., a_{m}, b) -> ((a_{1} + ..a_{_a}.. + a_{m} + b) =  \\ ((a_{1} + ..a_{_a}.. + a_{m}) + b)))
#    core type: ExprTuple
#    sub-expressions: 8
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (m, Natural)
#    core type: ExprTuple
#    sub-expressions: 24, 9
# 8. (a_{1}, ..a_{_a}.., a_{m}, b) -> ((a_{1} + ..a_{_a}.. + a_{m} + b) =  \\ ((a_{1} + ..a_{_a}.. + a_{m}) + b))
#    core type: Lambda
#    parameters: 15\n   body: 10
# 9. Natural
#    core type: Literal
#    sub-expressions:
# 10. (a_{1} + ..a_{_a}.. + a_{m} + b) =  \\ ((a_{1} + ..a_{_a}.. + a_{m}) + b)
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (a_{1} + ..a_{_a}.. + a_{m} + b, (a_{1} + ..a_{_a}.. + a_{m}) + b)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. a_{1} + ..a_{_a}.. + a_{m} + b
#     core type: Operation
#     operator: 19
#     operands: 15
# 14. (a_{1} + ..a_{_a}.. + a_{m}) + b
#     core type: Operation
#     operator: 19
#     operands: 16
# 15. (a_{1}, ..a_{_a}.., a_{m}, b)
#     core type: ExprTuple
#     sub-expressions: 21, 18
# 16. (a_{1} + ..a_{_a}.. + a_{m}, b)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. a_{1} + ..a_{_a}.. + a_{m}
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. b
#     core type: Variable
#     sub-expressions:
# 19. +
#     core type: Literal
#     sub-expressions:
# 20. (a_{1}, ..a_{_a}.., a_{m})
#     core type: ExprTuple
#     sub-expressions: 21
# 21. a_{1}, ..a_{_a}.., a_{m}
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 23
#     end_index: 24
# 22. _a -> a_{_a}
#     core type: Lambda
#     parameter: 28
#     body: 25
# 23. 1
#     core type: Literal
#     sub-expressions:
# 24. m
#     core type: Variable
#     sub-expressions:
# 25. a_{_a}
#     core type: IndexedVar
# variable: 26
# index: 28
# 26. a
#     core type: Variable
#     sub-expressions:
# 27. (_a)
#     core type: ExprTuple
#     sub-expressions: 28
# 28. _a
#     core type: Variable
#     sub-expressions:
