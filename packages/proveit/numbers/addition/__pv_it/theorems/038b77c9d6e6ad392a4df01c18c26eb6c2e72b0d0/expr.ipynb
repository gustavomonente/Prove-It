# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Variable, a, b, c, d, i, j, k
from proveit.core_expr_types import a_1_to_i, c_1_to_j, d_1_to_k
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Complex, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Conditional(Equals(Add(a_1_to_i, b, c_1_to_j, d_1_to_k), Add(a_1_to_i, c_1_to_j, b, d_1_to_k)).with_wrapping_at(2), And(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), Complex), one, i), InSet(b, Complex), ExprRange(sub_expr1, InSet(IndexedVar(c, sub_expr1), Complex), one, j), ExprRange(sub_expr1, InSet(IndexedVar(d, sub_expr1), Complex), one, k)))
# Out:
# expr: {(a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j} + d_{1} + ..d_{_a}.. + d_{k}) =  \\ (a_{1} + ..a_{_a}.. + a_{i} + c_{1} + ..c_{_a}.. + c_{j} + b + d_{1} + ..d_{_a}.. + d_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{j} in Complex ,  d_{1} in Complex ,  ..d_{_a} in Complex.. ,  d_{k} in Complex.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\begin{array}{c} \begin{array}{l} \left(a_{1} + \ldots + a_{i} + b + c_{1} + \ldots + c_{j} + d_{1} + \ldots + d_{k}\right) =  \\ \left(a_{1} + \ldots + a_{i} + c_{1} + \ldots + c_{j} + b + d_{1} + \ldots + d_{k}\right) \end{array} \end{array} \textrm{ if } a_{1} \in \mathbb{C} ,  \ldots ,  a_{i} \in \mathbb{C} ,  b \in \mathbb{C} ,  c_{1} \in \mathbb{C} ,  \ldots ,  c_{j} \in \mathbb{C} ,  d_{1} \in \mathbb{C} ,  \ldots ,  d_{k} \in \mathbb{C}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j} + d_{1} + ..d_{_a}.. + d_{k}) =  \\ (a_{1} + ..a_{_a}.. + a_{i} + c_{1} + ..c_{_a}.. + c_{j} + b + d_{1} + ..d_{_a}.. + d_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{j} in Complex ,  d_{1} in Complex ,  ..d_{_a} in Complex.. ,  d_{k} in Complex.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j} + d_{1} + ..d_{_a}.. + d_{k}) =  \\ (a_{1} + ..a_{_a}.. + a_{i} + c_{1} + ..c_{_a}.. + c_{j} + b + d_{1} + ..d_{_a}.. + d_{k})
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{i} in Complex) and (b in Complex) and (c_{1} in Complex) and ..(c_{_a} in Complex).. and (c_{j} in Complex) and (d_{1} in Complex) and ..(d_{_a} in Complex).. and (d_{k} in Complex)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j} + d_{1} + ..d_{_a}.. + d_{k}, a_{1} + ..a_{_a}.. + a_{i} + c_{1} + ..c_{_a}.. + c_{j} + b + d_{1} + ..d_{_a}.. + d_{k})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a_{1} in Complex, ..a_{_a} in Complex.., a_{i} in Complex, b in Complex, c_{1} in Complex, ..c_{_a} in Complex.., c_{j} in Complex, d_{1} in Complex, ..d_{_a} in Complex.., d_{k} in Complex)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 12
# 7. a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j} + d_{1} + ..d_{_a}.. + d_{k}
#    core type: Operation
#    operator: 14
#    operands: 13
# 8. a_{1} + ..a_{_a}.. + a_{i} + c_{1} + ..c_{_a}.. + c_{j} + b + d_{1} + ..d_{_a}.. + d_{k}
#    core type: Operation
#    operator: 14
#    operands: 15
# 9. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{i} in Complex)
#    core type: ExprRange
#    lambda_map: 16
#    start_index: 32
#    end_index: 28
# 10. b in Complex
#     core type: Operation
#     operator: 36
#     operands: 17
# 11. (c_{1} in Complex), ..(c_{_a} in Complex).., (c_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 32
#     end_index: 30
# 12. (d_{1} in Complex), ..(d_{_a} in Complex).., (d_{k} in Complex)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 32
#     end_index: 33
# 13. (a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k})
#     core type: ExprTuple
#     sub-expressions: 20, 24, 21, 22
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{j}, b, d_{1}, ..d_{_a}.., d_{k})
#     core type: ExprTuple
#     sub-expressions: 20, 21, 24, 22
# 16. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 46
#     body: 23
# 17. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 24, 41
# 18. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 46
#     body: 25
# 19. _a -> (d_{_a} in Complex)
#     core type: Lambda
#     parameter: 46
#     body: 26
# 20. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 32
#     end_index: 28
# 21. c_{1}, ..c_{_a}.., c_{j}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 32
#     end_index: 30
# 22. d_{1}, ..d_{_a}.., d_{k}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 32
#     end_index: 33
# 23. a_{_a} in Complex
#     core type: Operation
#     operator: 36
#     operands: 34
# 24. b
#     core type: Variable
#     sub-expressions:
# 25. c_{_a} in Complex
#     core type: Operation
#     operator: 36
#     operands: 35
# 26. d_{_a} in Complex
#     core type: Operation
#     operator: 36
#     operands: 37
# 27. _a -> a_{_a}
#     core type: Lambda
#     parameter: 46
#     body: 38
# 28. i
#     core type: Variable
#     sub-expressions:
# 29. _a -> c_{_a}
#     core type: Lambda
#     parameter: 46
#     body: 39
# 30. j
#     core type: Variable
#     sub-expressions:
# 31. _a -> d_{_a}
#     core type: Lambda
#     parameter: 46
#     body: 40
# 32. 1
#     core type: Literal
#     sub-expressions:
# 33. k
#     core type: Variable
#     sub-expressions:
# 34. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 38, 41
# 35. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 39, 41
# 36. in
#     core type: Literal
#     sub-expressions:
# 37. (d_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 38. a_{_a}
#     core type: IndexedVar
# variable: 42
# index: 46
# 39. c_{_a}
#     core type: IndexedVar
# variable: 43
# index: 46
# 40. d_{_a}
#     core type: IndexedVar
# variable: 44
# index: 46
# 41. Complex
#     core type: Literal
#     sub-expressions:
# 42. a
#     core type: Variable
#     sub-expressions:
# 43. c
#     core type: Variable
#     sub-expressions:
# 44. d
#     core type: Variable
#     sub-expressions:
# 45. (_a)
#     core type: ExprTuple
#     sub-expressions: 46
# 46. _a
#     core type: Variable
#     sub-expressions:
