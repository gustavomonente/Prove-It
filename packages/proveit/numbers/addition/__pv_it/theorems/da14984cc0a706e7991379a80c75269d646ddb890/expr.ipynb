# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a
from proveit.logic import Equals, InSet
from proveit.numbers import Add, Complex, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(a, Conditional(Equals(Add(a, zero), a), InSet(a, Complex))))
# Out:
# expr: (a -> {(a + 0) = a if a in Complex.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \mapsto \left\{\left(a + 0\right) = a \textrm{ if } a \in \mathbb{C}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a -> {(a + 0) = a if a in Complex.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. a -> {(a + 0) = a if a in Complex.
#    core type: Lambda
#    parameter: 13
#    body: 2
# 2. {(a + 0) = a if a in Complex.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (a + 0) = a
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. a in Complex
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (a + 0, a)
#    core type: ExprTuple
#    sub-expressions: 9, 13
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (a, Complex)
#    core type: ExprTuple
#    sub-expressions: 13, 10
# 9. a + 0
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. Complex
#     core type: Literal
#     sub-expressions:
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. a
#     core type: Variable
#     sub-expressions:
# 14. 0
#     core type: Literal
#     sub-expressions:
