# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#left_add_neq">left_add_neq</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.addition import left_add_neq

# %%
# check that the built expression is the same as the stored expression
assert left_add_neq.expr == stored_expr
assert left_add_neq.expr._style_id == stored_expr._style_id
print("Passed sanity check: left_add_neq matches stored_expr")
# Out:
# Passed sanity check: left_add_neq matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(left_add_neq.latex())
# Out:
# \vdash \forall_{a, x, y \in \mathbb{C}~|~x \neq y}~\left(\left(a + x\right) \neq \left(a + y\right)\right)

# %%
left_add_neq.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
left_add_neq.expr_info()
# Out:
# 0. forall_{a, x, y in Complex | x != y} ((a + x) != (a + y))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, x, y) -> {(a + x) != (a + y) if a in Complex ,  x in Complex ,  y in Complex ,  x != y.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, x, y) -> {(a + x) != (a + y) if a in Complex ,  x in Complex ,  y in Complex ,  x != y.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a, x, y)
#    core type: ExprTuple
#    sub-expressions: 26, 28, 29
# 5. {(a + x) != (a + y) if a in Complex ,  x in Complex ,  y in Complex ,  x != y.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (a + x) != (a + y)
#    core type: Operation
#    operator: 24
#    operands: 8
# 7. (a in Complex) and (x in Complex) and (y in Complex) and (x != y)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (a + x, a + y)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
# ...
