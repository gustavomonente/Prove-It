# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import b, i, j
from proveit.core_expr_types import a_1_to_i, c_1_to_j
from proveit.logic import Forall, InSet
from proveit.numbers import Add, Natural, NaturalPos, greater, zero

# %%
# build up the expression from sub-expressions
expr = Forall([i, j], Forall([a_1_to_i, b, c_1_to_j], InSet(Add(a_1_to_i, b, c_1_to_j), NaturalPos), domains = [Natural, Natural, Natural], condition = greater(b, zero)), domains = [Natural, Natural])
# Out:
# expr: forall_{i, j in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j} in Natural | b > 0} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) in NaturalPos)]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{i, j \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{i}, b, c_{1}, \ldots, c_{j} \in \mathbb{N}~|~b > 0}~\left(\left(a_{1} + \ldots + a_{i} + b + c_{1} + \ldots + c_{j}\right) \in \mathbb{N}^+\right)\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{i, j in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j} in Natural | b > 0} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) in NaturalPos)]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((i, j) -> {forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j} in Natural | b > 0} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) in NaturalPos) if i in Natural ,  j in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (i, j) -> {forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j} in Natural | b > 0} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) in NaturalPos) if i in Natural ,  j in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (i, j)
#    core type: ExprTuple
#    sub-expressions: 41, 44
# ...
