# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#add_real_pos_closure">add_real_pos_closure</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.addition import add_real_pos_closure

# %%
# check that the built expression is the same as the stored expression
assert add_real_pos_closure.expr == stored_expr
assert add_real_pos_closure.expr._style_id == stored_expr._style_id
print("Passed sanity check: add_real_pos_closure matches stored_expr")
# Out:
# Passed sanity check: add_real_pos_closure matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(add_real_pos_closure.latex())
# Out:
# \vdash \forall_{i \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{i} \in \mathbb{R}^+}~\left(\left(a_{1} + \ldots + a_{i}\right) \in \mathbb{R}^+\right)\right]

# %%
add_real_pos_closure.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
add_real_pos_closure.expr_info()
# Out:
# 0. forall_{i in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i} in RealPos} ((a_{1} + ..a_{_a}.. + a_{i}) in RealPos)]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (i -> {forall_{a_{1}, ..a_{_a}.., a_{i} in RealPos} ((a_{1} + ..a_{_a}.. + a_{i}) in RealPos) if i in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. i -> {forall_{a_{1}, ..a_{_a}.., a_{i} in RealPos} ((a_{1} + ..a_{_a}.. + a_{i}) in RealPos) if i in Natural.
#    core type: Lambda
#    parameter: 26
#    body: 3
# 3. {forall_{a_{1}, ..a_{_a}.., a_{i} in RealPos} ((a_{1} + ..a_{_a}.. + a_{i}) in RealPos) if i in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{a_{1}, ..a_{_a}.., a_{i} in RealPos} ((a_{1} + ..a_{_a}.. + a_{i}) in RealPos)
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. i in Natural
#    core type: Operation
#    operator: 27
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# ...
