# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import b
from proveit.core_expr_types import a_1_to_i, c_1_to_j
from proveit.logic import Forall, InSet
from proveit.numbers import Add, Natural, NaturalPos, greater, zero

# %%
# build up the expression from sub-expressions
expr = Forall([a_1_to_i, b, c_1_to_j], InSet(Add(a_1_to_i, b, c_1_to_j), NaturalPos), domains = [Natural, Natural, Natural], condition = greater(b, zero))
# Out:
# expr: forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j} in Natural | b > 0} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) in NaturalPos)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a_{1}, \ldots, a_{i}, b, c_{1}, \ldots, c_{j} \in \mathbb{N}~|~b > 0}~\left(\left(a_{1} + \ldots + a_{i} + b + c_{1} + \ldots + c_{j}\right) \in \mathbb{N}^+\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j} in Natural | b > 0} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) in NaturalPos)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}) -> {(a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) in NaturalPos if a_{1} in Natural ,  ..a_{_a} in Natural.. ,  a_{i} in Natural ,  b in Natural ,  c_{1} in Natural ,  ..c_{_a} in Natural.. ,  c_{j} in Natural ,  b > 0.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}) -> {(a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) in NaturalPos if a_{1} in Natural ,  ..a_{_a} in Natural.. ,  a_{i} in Natural ,  b in Natural ,  c_{1} in Natural ,  ..c_{_a} in Natural.. ,  c_{j} in Natural ,  b > 0.
#    core type: Lambda
#    parameters: 17\n   body: 4
# 4. {(a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) in NaturalPos if a_{1} in Natural ,  ..a_{_a} in Natural.. ,  a_{i} in Natural ,  b in Natural ,  c_{1} in Natural ,  ..c_{_a} in Natural.. ,  c_{j} in Natural ,  b > 0.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) in NaturalPos
#    core type: Operation
#    operator: 35
#    operands: 7
# 6. (a_{1} in Natural) and ..(a_{_a} in Natural).. and (a_{i} in Natural) and (b in Natural) and (c_{1} in Natural) and ..(c_{_a} in Natural).. and (c_{j} in Natural) and (b > 0)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a_{1} in Natural, ..a_{_a} in Natural.., a_{i} in Natural, b in Natural, c_{1} in Natural, ..c_{_a} in Natural.., c_{j} in Natural, b > 0)
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14, 15
# 10. a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}
#     core type: Operation
#     operator: 16
#     operands: 17
# 11. NaturalPos
#     core type: Literal
#     sub-expressions:
# 12. (a_{1} in Natural), ..(a_{_a} in Natural).., (a_{i} in Natural)
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 32
#     end_index: 30
# 13. b in Natural
#     core type: Operation
#     operator: 35
#     operands: 19
# 14. (c_{1} in Natural), ..(c_{_a} in Natural).., (c_{j} in Natural)
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 32
#     end_index: 33
# 15. b > 0
#     core type: Operation
#     operator: 21
#     operands: 22
# 16. +
#     core type: Literal
#     sub-expressions:
# 17. (a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j})
#     core type: ExprTuple
#     sub-expressions: 23, 28, 24
# 18. _a -> (a_{_a} in Natural)
#     core type: Lambda
#     parameter: 43
#     body: 25
# 19. (b, Natural)
#     core type: ExprTuple
#     sub-expressions: 28, 39
# 20. _a -> (c_{_a} in Natural)
#     core type: Lambda
#     parameter: 43
#     body: 26
# 21. <
#     core type: Literal
#     sub-expressions:
# 22. (0, b)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 23. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 32
#     end_index: 30
# 24. c_{1}, ..c_{_a}.., c_{j}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 32
#     end_index: 33
# 25. a_{_a} in Natural
#     core type: Operation
#     operator: 35
#     operands: 34
# 26. c_{_a} in Natural
#     core type: Operation
#     operator: 35
#     operands: 36
# 27. 0
#     core type: Literal
#     sub-expressions:
# 28. b
#     core type: Variable
#     sub-expressions:
# 29. _a -> a_{_a}
#     core type: Lambda
#     parameter: 43
#     body: 37
# 30. i
#     core type: Variable
#     sub-expressions:
# 31. _a -> c_{_a}
#     core type: Lambda
#     parameter: 43
#     body: 38
# 32. 1
#     core type: Literal
#     sub-expressions:
# 33. j
#     core type: Variable
#     sub-expressions:
# 34. (a_{_a}, Natural)
#     core type: ExprTuple
#     sub-expressions: 37, 39
# 35. in
#     core type: Literal
#     sub-expressions:
# 36. (c_{_a}, Natural)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 37. a_{_a}
#     core type: IndexedVar
# variable: 40
# index: 43
# 38. c_{_a}
#     core type: IndexedVar
# variable: 41
# index: 43
# 39. Natural
#     core type: Literal
#     sub-expressions:
# 40. a
#     core type: Variable
#     sub-expressions:
# 41. c
#     core type: Variable
#     sub-expressions:
# 42. (_a)
#     core type: ExprTuple
#     sub-expressions: 43
# 43. _a
#     core type: Variable
#     sub-expressions:
