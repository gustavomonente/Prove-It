# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#association">association</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.addition import association

# %%
# check that the built expression is the same as the stored expression
assert association.expr == stored_expr
assert association.expr._style_id == stored_expr._style_id
print("Passed sanity check: association matches stored_expr")
# Out:
# Passed sanity check: association matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(association.latex())
# Out:
# \vdash \forall_{i, j, k \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{i}, b_{1}, \ldots, b_{j}, c_{1}, \ldots, c_{k} \in \mathbb{C}}~\left(\begin{array}{c} \begin{array}{l} \left(a_{1} + \ldots + a_{i} + b_{1} + \ldots + b_{j} + c_{1} + \ldots + c_{k}\right) =  \\ \left(a_{1} + \ldots + a_{i} + \left(b_{1} + \ldots + b_{j}\right) + c_{1} + \ldots + c_{k}\right) \end{array} \end{array}\right)\right]

# %%
association.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
association.expr_info()
# Out:
# 0. forall_{i, j, k in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} + ..a_{_a}.. + a_{i} + b_{1} + ..b_{_a}.. + b_{j} + c_{1} + ..c_{_a}.. + c_{k}) =  \\ (a_{1} + ..a_{_a}.. + a_{i} + (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} + ..c_{_a}.. + c_{k}))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((i, j, k) -> {forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} + ..a_{_a}.. + a_{i} + b_{1} + ..b_{_a}.. + b_{j} + c_{1} + ..c_{_a}.. + c_{k}) =  \\ (a_{1} + ..a_{_a}.. + a_{i} + (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} + ..c_{_a}.. + c_{k})) if i in Natural ,  j in Natural ,  k in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (i, j, k) -> {forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} + ..a_{_a}.. + a_{i} + b_{1} + ..b_{_a}.. + b_{j} + c_{1} + ..c_{_a}.. + c_{k}) =  \\ (a_{1} + ..a_{_a}.. + a_{i} + (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} + ..c_{_a}.. + c_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (i, j, k)
#    core type: ExprTuple
#    sub-expressions: 42, 57, 46
# 4. {forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} + ..a_{_a}.. + a_{i} + b_{1} + ..b_{_a}.. + b_{j} + c_{1} + ..c_{_a}.. + c_{k}) =  \\ (a_{1} + ..a_{_a}.. + a_{i} + (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} + ..c_{_a}.. + c_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} + ..a_{_a}.. + a_{i} + b_{1} + ..b_{_a}.. + b_{j} + c_{1} + ..c_{_a}.. + c_{k}) =  \\ (a_{1} + ..a_{_a}.. + a_{i} + (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} + ..c_{_a}.. + c_{k}))
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. (i in Natural) and (j in Natural) and (k in Natural)
#    core type: Operation
#    operator: 23
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k}) -> {(a_{1} + ..a_{_a}.. + a_{i} + b_{1} + ..b_{_a}.. + b_{j} + c_{1} + ..c_{_a}.. + c_{k}) =  \\ (a_{1} + ..a_{_a}.. + a_{i} + (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} + ..c_{_a}.. + c_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b_{1} in Complex ,  ..b_{_a} in Complex.. ,  b_{j} in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{k} in Complex.)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (i in Natural, j in Natural, k in Natural)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 10. (a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k}) -> {(a_{1} + ..a_{_a}.. + a_{i} + b_{1} + ..b_{_a}.. + b_{j} + c_{1} + ..c_{_a}.. + c_{k}) =  \\ (a_{1} + ..a_{_a}.. + a_{i} + (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} + ..c_{_a}.. + c_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b_{1} in Complex ,  ..b_{_a} in Complex.. ,  b_{j} in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{k} in Complex.
#     core type: Lambda
#     parameters: 30\n    body: 14
# 11. i in Natural
#     core type: Operation
#     operator: 49
#     operands: 15
# 12. j in Natural
#     core type: Operation
#     operator: 49
#     operands: 16
# 13. k in Natural
#     core type: Operation
#     operator: 49
#     operands: 17
# 14. {(a_{1} + ..a_{_a}.. + a_{i} + b_{1} + ..b_{_a}.. + b_{j} + c_{1} + ..c_{_a}.. + c_{k}) =  \\ (a_{1} + ..a_{_a}.. + a_{i} + (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} + ..c_{_a}.. + c_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b_{1} in Complex ,  ..b_{_a} in Complex.. ,  b_{j} in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{k} in Complex.
#     core type: Conditional
#     value: 18
#     condition: 19
# 15. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 42, 20
# 16. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 57, 20
# 17. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 46, 20
# 18. (a_{1} + ..a_{_a}.. + a_{i} + b_{1} + ..b_{_a}.. + b_{j} + c_{1} + ..c_{_a}.. + c_{k}) =  \\ (a_{1} + ..a_{_a}.. + a_{i} + (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} + ..c_{_a}.. + c_{k})
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{i} in Complex) and (b_{1} in Complex) and ..(b_{_a} in Complex).. and (b_{j} in Complex) and (c_{1} in Complex) and ..(c_{_a} in Complex).. and (c_{k} in Complex)
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. Natural
#     core type: Literal
#     sub-expressions:
# 21. =
#     core type: Literal
#     sub-expressions:
# 22. (a_{1} + ..a_{_a}.. + a_{i} + b_{1} + ..b_{_a}.. + b_{j} + c_{1} + ..c_{_a}.. + c_{k}, a_{1} + ..a_{_a}.. + a_{i} + (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} + ..c_{_a}.. + c_{k})
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. and
#     core type: Literal
#     sub-expressions:
# 24. (a_{1} in Complex, ..a_{_a} in Complex.., a_{i} in Complex, b_{1} in Complex, ..b_{_a} in Complex.., b_{j} in Complex, c_{1} in Complex, ..c_{_a} in Complex.., c_{k} in Complex)
#     core type: ExprTuple
#     sub-expressions: 27, 28, 29
# 25. a_{1} + ..a_{_a}.. + a_{i} + b_{1} + ..b_{_a}.. + b_{j} + c_{1} + ..c_{_a}.. + c_{k}
#     core type: Operation
#     operator: 43
#     operands: 30
# 26. a_{1} + ..a_{_a}.. + a_{i} + (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} + ..c_{_a}.. + c_{k}
#     core type: Operation
#     operator: 43
#     operands: 31
# 27. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 56
#     end_index: 42
# 28. (b_{1} in Complex), ..(b_{_a} in Complex).., (b_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 56
#     end_index: 57
# 29. (c_{1} in Complex), ..(c_{_a} in Complex).., (c_{k} in Complex)
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 56
#     end_index: 46
# 30. (a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k})
#     core type: ExprTuple
#     sub-expressions: 35, 51, 37
# 31. (a_{1}, ..a_{_a}.., a_{i}, b_{1} + ..b_{_a}.. + b_{j}, c_{1}, ..c_{_a}.., c_{k})
#     core type: ExprTuple
#     sub-expressions: 35, 36, 37
# 32. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 63
#     body: 38
# 33. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 63
#     body: 39
# 34. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 63
#     body: 40
# 35. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 56
#     end_index: 42
# 36. b_{1} + ..b_{_a}.. + b_{j}
#     core type: Operation
#     operator: 43
#     operands: 44
# 37. c_{1}, ..c_{_a}.., c_{k}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 56
#     end_index: 46
# 38. a_{_a} in Complex
#     core type: Operation
#     operator: 49
#     operands: 47
# 39. b_{_a} in Complex
#     core type: Operation
#     operator: 49
#     operands: 48
# 40. c_{_a} in Complex
#     core type: Operation
#     operator: 49
#     operands: 50
# 41. _a -> a_{_a}
#     core type: Lambda
#     parameter: 63
#     body: 52
# 42. i
#     core type: Variable
#     sub-expressions:
# 43. +
#     core type: Literal
#     sub-expressions:
# 44. (b_{1}, ..b_{_a}.., b_{j})
#     core type: ExprTuple
#     sub-expressions: 51
# 45. _a -> c_{_a}
#     core type: Lambda
#     parameter: 63
#     body: 53
# 46. k
#     core type: Variable
#     sub-expressions:
# 47. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 52, 54
# 48. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 60, 54
# 49. in
#     core type: Literal
#     sub-expressions:
# 50. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 51. b_{1}, ..b_{_a}.., b_{j}
#     core type: ExprRange
#     lambda_map: 55
#     start_index: 56
#     end_index: 57
# 52. a_{_a}
#     core type: IndexedVar
# variable: 58
# index: 63
# 53. c_{_a}
#     core type: IndexedVar
# variable: 59
# index: 63
# 54. Complex
#     core type: Literal
#     sub-expressions:
# 55. _a -> b_{_a}
#     core type: Lambda
#     parameter: 63
#     body: 60
# 56. 1
#     core type: Literal
#     sub-expressions:
# 57. j
#     core type: Variable
#     sub-expressions:
# 58. a
#     core type: Variable
#     sub-expressions:
# 59. c
#     core type: Variable
#     sub-expressions:
# 60. b_{_a}
#     core type: IndexedVar
# variable: 61
# index: 63
# 61. b
#     core type: Variable
#     sub-expressions:
# 62. (_a)
#     core type: ExprTuple
#     sub-expressions: 63
# 63. _a
#     core type: Variable
#     sub-expressions:
