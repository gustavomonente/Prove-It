# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c
from proveit.logic import Equals
from proveit.numbers import Add, Mult, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Mult(three, a)
sub_expr2 = Mult(two, b)
expr = Equals(Add(sub_expr1, sub_expr2, Add(c, c)), Add(sub_expr1, sub_expr2, Mult(two, c)))
# Out:
# expr: ((3 * a) + (2 * b) + (c + c)) = ((3 * a) + (2 * b) + (2 * c))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(3 \cdot a\right) + \left(2 \cdot b\right) + \left(c + c\right)\right) = \left(\left(3 \cdot a\right) + \left(2 \cdot b\right) + \left(2 \cdot c\right)\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((3 * a) + (2 * b) + (c + c)) = ((3 * a) + (2 * b) + (2 * c))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((3 * a) + (2 * b) + (c + c), (3 * a) + (2 * b) + (2 * c))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (3 * a) + (2 * b) + (c + c)
#    core type: Operation
#    operator: 11
#    operands: 5
# 4. (3 * a) + (2 * b) + (2 * c)
#    core type: Operation
#    operator: 11
#    operands: 6
# 5. (3 * a, 2 * b, c + c)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 7
# 6. (3 * a, 2 * b, 2 * c)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 7. c + c
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. 3 * a
#    core type: Operation
#    operator: 15
#    operands: 13
# 9. 2 * b
#    core type: Operation
#    operator: 15
#    operands: 14
# 10. 2 * c
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (c, c)
#     core type: ExprTuple
#     sub-expressions: 21, 21
# 13. (3, a)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 14. (2, b)
#     core type: ExprTuple
#     sub-expressions: 20, 19
# 15. *
#     core type: Literal
#     sub-expressions:
# 16. (2, c)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 17. 3
#     core type: Literal
#     sub-expressions:
# 18. a
#     core type: Variable
#     sub-expressions:
# 19. b
#     core type: Variable
#     sub-expressions:
# 20. 2
#     core type: Literal
#     sub-expressions:
# 21. c
#     core type: Variable
#     sub-expressions:
