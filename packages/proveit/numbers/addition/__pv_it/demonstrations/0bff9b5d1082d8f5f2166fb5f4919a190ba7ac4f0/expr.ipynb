# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, b, c
from proveit.numbers import Add, Mult, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(b, Mult(three, b), Mult(two, b))
expr = ExprTuple(Add(sub_expr1, c, c, two), Add(sub_expr1, Add(c, c), two))
# Out:
# expr: ((b + (3 * b) + (2 * b)) + c + c + 2, (b + (3 * b) + (2 * b)) + (c + c) + 2)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(b + \left(3 \cdot b\right) + \left(2 \cdot b\right)\right) + c + c + 2, \left(b + \left(3 \cdot b\right) + \left(2 \cdot b\right)\right) + \left(c + c\right) + 2\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((b + (3 * b) + (2 * b)) + c + c + 2, (b + (3 * b) + (2 * b)) + (c + c) + 2)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (b + (3 * b) + (2 * b)) + c + c + 2
#    core type: Operation
#    operator: 8
#    operands: 3
# 2. (b + (3 * b) + (2 * b)) + (c + c) + 2
#    core type: Operation
#    operator: 8
#    operands: 4
# 3. (b + (3 * b) + (2 * b), c, c, 2)
#    core type: ExprTuple
#    sub-expressions: 5, 12, 12, 17
# 4. (b + (3 * b) + (2 * b), c + c, 2)
#    core type: ExprTuple
#    sub-expressions: 5, 6, 17
# 5. b + (3 * b) + (2 * b)
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. c + c
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (b, 3 * b, 2 * b)
#    core type: ExprTuple
#    sub-expressions: 18, 10, 11
# 8. +
#    core type: Literal
#    sub-expressions:
# 9. (c, c)
#    core type: ExprTuple
#    sub-expressions: 12, 12
# 10. 3 * b
#     core type: Operation
#     operator: 14
#     operands: 13
# 11. 2 * b
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. c
#     core type: Variable
#     sub-expressions:
# 13. (3, b)
#     core type: ExprTuple
#     sub-expressions: 16, 18
# 14. *
#     core type: Literal
#     sub-expressions:
# 15. (2, b)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. 3
#     core type: Literal
#     sub-expressions:
# 17. 2
#     core type: Literal
#     sub-expressions:
# 18. b
#     core type: Variable
#     sub-expressions:
