# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, b
from proveit.numbers import Add, Mult, Neg, one, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(one)
expr = ExprTuple(Mult(Add(two, three, one, sub_expr1), b), Add(Mult(two, b), Mult(three, b), Mult(one, b), Mult(sub_expr1, b)))
# Out:
# expr: ((2 + 3 + 1 - 1) * b, (2 * b) + (3 * b) + (1 * b) + ((-1) * b))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(2 + 3 + 1 - 1\right) \cdot b, \left(2 \cdot b\right) + \left(3 \cdot b\right) + \left(1 \cdot b\right) + \left(\left(-1\right) \cdot b\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((2 + 3 + 1 - 1) * b, (2 * b) + (3 * b) + (1 * b) + ((-1) * b))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (2 + 3 + 1 - 1) * b
#    core type: Operation
#    operator: 15
#    operands: 3
# 2. (2 * b) + (3 * b) + (1 * b) + ((-1) * b)
#    core type: Operation
#    operator: 10
#    operands: 4
# 3. (2 + 3 + 1 - 1, b)
#    core type: ExprTuple
#    sub-expressions: 5, 20
# 4. (2 * b, 3 * b, 1 * b, (-1) * b)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 9
# 5. 2 + 3 + 1 - 1
#    core type: Operation
#    operator: 10
#    operands: 11
# 6. 2 * b
#    core type: Operation
#    operator: 15
#    operands: 12
# 7. 3 * b
#    core type: Operation
#    operator: 15
#    operands: 13
# 8. 1 * b
#    core type: Operation
#    operator: 15
#    operands: 14
# 9. (-1) * b
#    core type: Operation
#    operator: 15
#    operands: 16
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (2, 3, 1, -1)
#     core type: ExprTuple
#     sub-expressions: 17, 18, 23, 19
# 12. (2, b)
#     core type: ExprTuple
#     sub-expressions: 17, 20
# 13. (3, b)
#     core type: ExprTuple
#     sub-expressions: 18, 20
# 14. (1, b)
#     core type: ExprTuple
#     sub-expressions: 23, 20
# 15. *
#     core type: Literal
#     sub-expressions:
# 16. (-1, b)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. 2
#     core type: Literal
#     sub-expressions:
# 18. 3
#     core type: Literal
#     sub-expressions:
# 19. -1
#     core type: Operation
#     operator: 21
#     operand: 23
# 20. b
#     core type: Variable
#     sub-expressions:
# 21. -
#     core type: Literal
#     sub-expressions:
# 22. (1)
#     core type: ExprTuple
#     sub-expressions: 23
# 23. 1
#     core type: Literal
#     sub-expressions:
