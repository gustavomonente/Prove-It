# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, b
from proveit.numbers import Add, Mult, Neg, one, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(one)
expr = ExprTuple(Add(Mult(b, two), Mult(b, three), Mult(b, one), Mult(b, sub_expr1)), Mult(b, Add(two, three, one, sub_expr1)))
# Out:
# expr: ((b * 2) + (b * 3) + (b * 1) + (b * (-1)), b * (2 + 3 + 1 - 1))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(b \cdot 2\right) + \left(b \cdot 3\right) + \left(b \cdot 1\right) + \left(b \cdot \left(-1\right)\right), b \cdot \left(2 + 3 + 1 - 1\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((b * 2) + (b * 3) + (b * 1) + (b * (-1)), b * (2 + 3 + 1 - 1))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (b * 2) + (b * 3) + (b * 1) + (b * (-1))
#    core type: Operation
#    operator: 15
#    operands: 3
# 2. b * (2 + 3 + 1 - 1)
#    core type: Operation
#    operator: 13
#    operands: 4
# 3. (b * 2, b * 3, b * 1, b * (-1))
#    core type: ExprTuple
#    sub-expressions: 5, 6, 7, 8
# 4. (b, 2 + 3 + 1 - 1)
#    core type: ExprTuple
#    sub-expressions: 17, 9
# 5. b * 2
#    core type: Operation
#    operator: 13
#    operands: 10
# 6. b * 3
#    core type: Operation
#    operator: 13
#    operands: 11
# 7. b * 1
#    core type: Operation
#    operator: 13
#    operands: 12
# 8. b * (-1)
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. 2 + 3 + 1 - 1
#    core type: Operation
#    operator: 15
#    operands: 16
# 10. (b, 2)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 11. (b, 3)
#     core type: ExprTuple
#     sub-expressions: 17, 19
# 12. (b, 1)
#     core type: ExprTuple
#     sub-expressions: 17, 23
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (b, -1)
#     core type: ExprTuple
#     sub-expressions: 17, 20
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (2, 3, 1, -1)
#     core type: ExprTuple
#     sub-expressions: 18, 19, 23, 20
# 17. b
#     core type: Variable
#     sub-expressions:
# 18. 2
#     core type: Literal
#     sub-expressions:
# 19. 3
#     core type: Literal
#     sub-expressions:
# 20. -1
#     core type: Operation
#     operator: 21
#     operand: 23
# 21. -
#     core type: Literal
#     sub-expressions:
# 22. (1)
#     core type: ExprTuple
#     sub-expressions: 23
# 23. 1
#     core type: Literal
#     sub-expressions:
