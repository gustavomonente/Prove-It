# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import b
from proveit.logic import Equals
from proveit.numbers import Add, Mult, Neg, one, three, two

# %%
# build up the expression from sub-expressions
expr = Equals(Add(Mult(two, b), Mult(three, b), b, Neg(b)), Mult(b, Add(two, three, one, Neg(one))))
# Out:
# expr: ((2 * b) + (3 * b) + b - b) = (b * (2 + 3 + 1 - 1))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(2 \cdot b\right) + \left(3 \cdot b\right) + b - b\right) = \left(b \cdot \left(2 + 3 + 1 - 1\right)\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((2 * b) + (3 * b) + b - b) = (b * (2 + 3 + 1 - 1))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((2 * b) + (3 * b) + b - b, b * (2 + 3 + 1 - 1))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (2 * b) + (3 * b) + b - b
#    core type: Operation
#    operator: 15
#    operands: 5
# 4. b * (2 + 3 + 1 - 1)
#    core type: Operation
#    operator: 12
#    operands: 6
# 5. (2 * b, 3 * b, b, -b)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 17, 9
# 6. (b, 2 + 3 + 1 - 1)
#    core type: ExprTuple
#    sub-expressions: 17, 10
# 7. 2 * b
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. 3 * b
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. -b
#    core type: Operation
#    operator: 21
#    operand: 17
# 10. 2 + 3 + 1 - 1
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. (2, b)
#     core type: ExprTuple
#     sub-expressions: 18, 17
# 12. *
#     core type: Literal
#     sub-expressions:
# 13. (3, b)
#     core type: ExprTuple
#     sub-expressions: 19, 17
# 14. (b)
#     core type: ExprTuple
#     sub-expressions: 17
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (2, 3, 1, -1)
#     core type: ExprTuple
#     sub-expressions: 18, 19, 23, 20
# 17. b
#     core type: Variable
#     sub-expressions:
# 18. 2
#     core type: Literal
#     sub-expressions:
# 19. 3
#     core type: Literal
#     sub-expressions:
# 20. -1
#     core type: Operation
#     operator: 21
#     operand: 23
# 21. -
#     core type: Literal
#     sub-expressions:
# 22. (1)
#     core type: ExprTuple
#     sub-expressions: 23
# 23. 1
#     core type: Literal
#     sub-expressions:
