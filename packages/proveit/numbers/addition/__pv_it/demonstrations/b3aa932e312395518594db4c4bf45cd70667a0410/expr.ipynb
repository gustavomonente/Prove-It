# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, b
from proveit.numbers import Add, Mult, Neg, one, three, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(Mult(two, b), Mult(three, b), b, Neg(b)), Mult(Add(two, three, one, Neg(one)), b))
# Out:
# expr: ((2 * b) + (3 * b) + b - b, (2 + 3 + 1 - 1) * b)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(2 \cdot b\right) + \left(3 \cdot b\right) + b - b, \left(2 + 3 + 1 - 1\right) \cdot b\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((2 * b) + (3 * b) + b - b, (2 + 3 + 1 - 1) * b)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (2 * b) + (3 * b) + b - b
#    core type: Operation
#    operator: 13
#    operands: 3
# 2. (2 + 3 + 1 - 1) * b
#    core type: Operation
#    operator: 10
#    operands: 4
# 3. (2 * b, 3 * b, b, -b)
#    core type: ExprTuple
#    sub-expressions: 5, 6, 15, 7
# 4. (2 + 3 + 1 - 1, b)
#    core type: ExprTuple
#    sub-expressions: 8, 15
# 5. 2 * b
#    core type: Operation
#    operator: 10
#    operands: 9
# 6. 3 * b
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. -b
#    core type: Operation
#    operator: 19
#    operand: 15
# 8. 2 + 3 + 1 - 1
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. (2, b)
#    core type: ExprTuple
#    sub-expressions: 16, 15
# 10. *
#     core type: Literal
#     sub-expressions:
# 11. (3, b)
#     core type: ExprTuple
#     sub-expressions: 17, 15
# 12. (b)
#     core type: ExprTuple
#     sub-expressions: 15
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (2, 3, 1, -1)
#     core type: ExprTuple
#     sub-expressions: 16, 17, 21, 18
# 15. b
#     core type: Variable
#     sub-expressions:
# 16. 2
#     core type: Literal
#     sub-expressions:
# 17. 3
#     core type: Literal
#     sub-expressions:
# 18. -1
#     core type: Operation
#     operator: 19
#     operand: 21
# 19. -
#     core type: Literal
#     sub-expressions:
# 20. (1)
#     core type: ExprTuple
#     sub-expressions: 21
# 21. 1
#     core type: Literal
#     sub-expressions:
