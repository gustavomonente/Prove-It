# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c
from proveit.logic import Equals
from proveit.numbers import Add, Mult, one, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(c, c, c)
sub_expr2 = Add(b, b)
sub_expr3 = Add(one, two, three)
expr = Equals(Add(Add(a, a), sub_expr1, sub_expr2, sub_expr3), Add(Mult(two, a), sub_expr1, sub_expr2, sub_expr3))
# Out:
# expr: ((a + a) + (c + c + c) + (b + b) + (1 + 2 + 3)) = ((2 * a) + (c + c + c) + (b + b) + (1 + 2 + 3))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a + a\right) + \left(c + c + c\right) + \left(b + b\right) + \left(1 + 2 + 3\right)\right) = \left(\left(2 \cdot a\right) + \left(c + c + c\right) + \left(b + b\right) + \left(1 + 2 + 3\right)\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a + a) + (c + c + c) + (b + b) + (1 + 2 + 3)) = ((2 * a) + (c + c + c) + (b + b) + (1 + 2 + 3))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((a + a) + (c + c + c) + (b + b) + (1 + 2 + 3), (2 * a) + (c + c + c) + (b + b) + (1 + 2 + 3))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (a + a) + (c + c + c) + (b + b) + (1 + 2 + 3)
#    core type: Operation
#    operator: 17
#    operands: 5
# 4. (2 * a) + (c + c + c) + (b + b) + (1 + 2 + 3)
#    core type: Operation
#    operator: 17
#    operands: 6
# 5. (a + a, c + c + c, b + b, 1 + 2 + 3)
#    core type: ExprTuple
#    sub-expressions: 7, 9, 10, 11
# 6. (2 * a, c + c + c, b + b, 1 + 2 + 3)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 7. a + a
#    core type: Operation
#    operator: 17
#    operands: 12
# 8. 2 * a
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. c + c + c
#    core type: Operation
#    operator: 17
#    operands: 15
# 10. b + b
#     core type: Operation
#     operator: 17
#     operands: 16
# 11. 1 + 2 + 3
#     core type: Operation
#     operator: 17
#     operands: 18
# 12. (a, a)
#     core type: ExprTuple
#     sub-expressions: 19, 19
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (2, a)
#     core type: ExprTuple
#     sub-expressions: 23, 19
# 15. (c, c, c)
#     core type: ExprTuple
#     sub-expressions: 20, 20, 20
# 16. (b, b)
#     core type: ExprTuple
#     sub-expressions: 21, 21
# 17. +
#     core type: Literal
#     sub-expressions:
# 18. (1, 2, 3)
#     core type: ExprTuple
#     sub-expressions: 22, 23, 24
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. c
#     core type: Variable
#     sub-expressions:
# 21. b
#     core type: Variable
#     sub-expressions:
# 22. 1
#     core type: Literal
#     sub-expressions:
# 23. 2
#     core type: Literal
#     sub-expressions:
# 24. 3
#     core type: Literal
#     sub-expressions:
