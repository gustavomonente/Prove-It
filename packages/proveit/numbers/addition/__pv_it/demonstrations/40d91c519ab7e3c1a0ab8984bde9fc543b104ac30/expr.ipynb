# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import b
from proveit.logic import InSet
from proveit.numbers import Add, Complex, Mult, three, two

# %%
# build up the expression from sub-expressions
expr = InSet(Add(b, Mult(three, b), Mult(two, b)), Complex)
# Out:
# expr: (b + (3 * b) + (2 * b)) in Complex

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(b + \left(3 \cdot b\right) + \left(2 \cdot b\right)\right) \in \mathbb{C}

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (b + (3 * b) + (2 * b)) in Complex
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (b + (3 * b) + (2 * b), Complex)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. b + (3 * b) + (2 * b)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. Complex
#    core type: Literal
#    sub-expressions:
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (b, 3 * b, 2 * b)
#    core type: ExprTuple
#    sub-expressions: 14, 7, 8
# 7. 3 * b
#    core type: Operation
#    operator: 10
#    operands: 9
# 8. 2 * b
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (3, b)
#    core type: ExprTuple
#    sub-expressions: 12, 14
# 10. *
#     core type: Literal
#     sub-expressions:
# 11. (2, b)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. 3
#     core type: Literal
#     sub-expressions:
# 13. 2
#     core type: Literal
#     sub-expressions:
# 14. b
#     core type: Variable
#     sub-expressions:
