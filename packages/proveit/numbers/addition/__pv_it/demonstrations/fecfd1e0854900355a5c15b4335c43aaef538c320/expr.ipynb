# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, ExprRange, ExprTuple, b, c, k
from proveit.core_expr_types import Len
from proveit.numbers import one, seven, three

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([b, B, C, c, one, three, A]), Len([ExprRange(k, k, one, seven)]))
# Out:
# expr: (|(b, B, C, c, 1, 3, A)|, |(1, ..k.., 7)|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(b, B, C, c, 1, 3, A\right)|, |\left(1, \ldots, 7\right)|\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|(b, B, C, c, 1, 3, A)|, |(1, ..k.., 7)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(b, B, C, c, 1, 3, A)|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..k.., 7)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((b, B, C, c, 1, 3, A))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..k.., 7))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (b, B, C, c, 1, 3, A)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11, 16, 12, 13
# 7. (1, ..k.., 7)
#    core type: ExprTuple
#    sub-expressions: 14
# 8. b
#    core type: Variable
#    sub-expressions:
# 9. B
#    core type: Variable
#    sub-expressions:
# 10. C
#     core type: Variable
#     sub-expressions:
# 11. c
#     core type: Variable
#     sub-expressions:
# 12. 3
#     core type: Literal
#     sub-expressions:
# 13. A
#     core type: Variable
#     sub-expressions:
# 14. 1, ..k.., 7
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 16
#     end_index: 17
# 15. k -> k
#     core type: Lambda
#     parameter: 18
#     body: 18
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. 7
#     core type: Literal
#     sub-expressions:
# 18. k
#     core type: Variable
#     sub-expressions:
