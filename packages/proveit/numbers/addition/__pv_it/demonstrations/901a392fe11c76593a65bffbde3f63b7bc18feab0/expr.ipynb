# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import b, c
from proveit.logic import Equals
from proveit.numbers import Add, Mult, six, three, two

# %%
# build up the expression from sub-expressions
expr = Equals(Add(two, b, c, Mult(three, b), Mult(two, b), c), Add(Mult(six, b), Mult(two, c), two))
# Out:
# expr: (2 + b + c + (3 * b) + (2 * b) + c) = ((6 * b) + (2 * c) + 2)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(2 + b + c + \left(3 \cdot b\right) + \left(2 \cdot b\right) + c\right) = \left(\left(6 \cdot b\right) + \left(2 \cdot c\right) + 2\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (2 + b + c + (3 * b) + (2 * b) + c) = ((6 * b) + (2 * c) + 2)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (2 + b + c + (3 * b) + (2 * b) + c, (6 * b) + (2 * c) + 2)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 2 + b + c + (3 * b) + (2 * b) + c
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. (6 * b) + (2 * c) + 2
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (2, b, c, 3 * b, 2 * b, c)
#    core type: ExprTuple
#    sub-expressions: 20, 19, 21, 8, 9, 21
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (6 * b, 2 * c, 2)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 20
# 8. 3 * b
#    core type: Operation
#    operator: 15
#    operands: 12
# 9. 2 * b
#    core type: Operation
#    operator: 15
#    operands: 13
# 10. 6 * b
#     core type: Operation
#     operator: 15
#     operands: 14
# 11. 2 * c
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. (3, b)
#     core type: ExprTuple
#     sub-expressions: 17, 19
# 13. (2, b)
#     core type: ExprTuple
#     sub-expressions: 20, 19
# 14. (6, b)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. *
#     core type: Literal
#     sub-expressions:
# 16. (2, c)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 17. 3
#     core type: Literal
#     sub-expressions:
# 18. 6
#     core type: Literal
#     sub-expressions:
# 19. b
#     core type: Variable
#     sub-expressions:
# 20. 2
#     core type: Literal
#     sub-expressions:
# 21. c
#     core type: Variable
#     sub-expressions:
