# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b, c
from proveit.numbers import Add

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(a, a, a, a, a)
expr = ExprTuple(Add(sub_expr1, b, b, b, c, c, c), Add(sub_expr1, Add(b, b, b), c, c, c))
# Out:
# expr: ((a + a + a + a + a) + b + b + b + c + c + c, (a + a + a + a + a) + (b + b + b) + c + c + c)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a + a + a + a + a\right) + b + b + b + c + c + c, \left(a + a + a + a + a\right) + \left(b + b + b\right) + c + c + c\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a + a + a + a + a) + b + b + b + c + c + c, (a + a + a + a + a) + (b + b + b) + c + c + c)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (a + a + a + a + a) + b + b + b + c + c + c
#    core type: Operation
#    operator: 9
#    operands: 3
# 2. (a + a + a + a + a) + (b + b + b) + c + c + c
#    core type: Operation
#    operator: 9
#    operands: 4
# 3. (a + a + a + a + a, b, b, b, c, c, c)
#    core type: ExprTuple
#    sub-expressions: 5, 12, 12, 12, 7, 7, 7
# 4. (a + a + a + a + a, b + b + b, c, c, c)
#    core type: ExprTuple
#    sub-expressions: 5, 6, 7, 7, 7
# 5. a + a + a + a + a
#    core type: Operation
#    operator: 9
#    operands: 8
# 6. b + b + b
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. c
#    core type: Variable
#    sub-expressions:
# 8. (a, a, a, a, a)
#    core type: ExprTuple
#    sub-expressions: 11, 11, 11, 11, 11
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (b, b, b)
#     core type: ExprTuple
#     sub-expressions: 12, 12, 12
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. b
#     core type: Variable
#     sub-expressions:
