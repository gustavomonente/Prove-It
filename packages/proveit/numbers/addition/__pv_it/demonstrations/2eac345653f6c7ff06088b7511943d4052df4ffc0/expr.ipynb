# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, b, c
from proveit.numbers import Add, Mult, one, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Mult(three, b)
sub_expr2 = Mult(two, b)
expr = ExprTuple(Add(Mult(one, two), b, c, sub_expr1, sub_expr2, Mult(one, c)), Add(two, b, c, sub_expr1, sub_expr2, c))
# Out:
# expr: ((1 * 2) + b + c + (3 * b) + (2 * b) + (1 * c), 2 + b + c + (3 * b) + (2 * b) + c)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(1 \cdot 2\right) + b + c + \left(3 \cdot b\right) + \left(2 \cdot b\right) + \left(1 \cdot c\right), 2 + b + c + \left(3 \cdot b\right) + \left(2 \cdot b\right) + c\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((1 * 2) + b + c + (3 * b) + (2 * b) + (1 * c), 2 + b + c + (3 * b) + (2 * b) + c)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (1 * 2) + b + c + (3 * b) + (2 * b) + (1 * c)
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. 2 + b + c + (3 * b) + (2 * b) + c
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (1 * 2, b, c, 3 * b, 2 * b, 1 * c)
#    core type: ExprTuple
#    sub-expressions: 6, 19, 16, 8, 9, 7
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (2, b, c, 3 * b, 2 * b, c)
#    core type: ExprTuple
#    sub-expressions: 18, 19, 16, 8, 9, 16
# 6. 1 * 2
#    core type: Operation
#    operator: 13
#    operands: 10
# 7. 1 * c
#    core type: Operation
#    operator: 13
#    operands: 11
# 8. 3 * b
#    core type: Operation
#    operator: 13
#    operands: 12
# 9. 2 * b
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 15, 18
# 11. (1, c)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 12. (3, b)
#     core type: ExprTuple
#     sub-expressions: 17, 19
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (2, b)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. c
#     core type: Variable
#     sub-expressions:
# 17. 3
#     core type: Literal
#     sub-expressions:
# 18. 2
#     core type: Literal
#     sub-expressions:
# 19. b
#     core type: Variable
#     sub-expressions:
