# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, ExprTuple, a, b, c
from proveit.numbers import Add, Mult, one, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(one, one, three)
expr = ExprTuple(Add(a, Add(A, A), b, B, C, c, sub_expr1), Add(a, Mult(two, A), b, B, C, c, sub_expr1))
# Out:
# expr: (a + (A + A) + b + B + C + c + (1 + 1 + 3), a + (2 * A) + b + B + C + c + (1 + 1 + 3))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a + \left(A + A\right) + b + B + C + c + \left(1 + 1 + 3\right), a + \left(2 \cdot A\right) + b + B + C + c + \left(1 + 1 + 3\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a + (A + A) + b + B + C + c + (1 + 1 + 3), a + (2 * A) + b + B + C + c + (1 + 1 + 3))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. a + (A + A) + b + B + C + c + (1 + 1 + 3)
#    core type: Operation
#    operator: 16
#    operands: 3
# 2. a + (2 * A) + b + B + C + c + (1 + 1 + 3)
#    core type: Operation
#    operator: 16
#    operands: 4
# 3. (a, A + A, b, B, C, c, 1 + 1 + 3)
#    core type: ExprTuple
#    sub-expressions: 6, 5, 8, 9, 10, 11, 12
# 4. (a, 2 * A, b, B, C, c, 1 + 1 + 3)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 9, 10, 11, 12
# 5. A + A
#    core type: Operation
#    operator: 16
#    operands: 13
# 6. a
#    core type: Variable
#    sub-expressions:
# 7. 2 * A
#    core type: Operation
#    operator: 14
#    operands: 15
# 8. b
#    core type: Variable
#    sub-expressions:
# 9. B
#    core type: Variable
#    sub-expressions:
# 10. C
#     core type: Variable
#     sub-expressions:
# 11. c
#     core type: Variable
#     sub-expressions:
# 12. 1 + 1 + 3
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. (A, A)
#     core type: ExprTuple
#     sub-expressions: 19, 19
# 14. *
#     core type: Literal
#     sub-expressions:
# 15. (2, A)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. +
#     core type: Literal
#     sub-expressions:
# 17. (1, 1, 3)
#     core type: ExprTuple
#     sub-expressions: 20, 20, 21
# 18. 2
#     core type: Literal
#     sub-expressions:
# 19. A
#     core type: Variable
#     sub-expressions:
# 20. 1
#     core type: Literal
#     sub-expressions:
# 21. 3
#     core type: Literal
#     sub-expressions:
