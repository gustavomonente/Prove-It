# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#mult_def">mult_def</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.numbers.multiplication import mult_def

# %%
# check that the built expression is the same as the stored expression
assert mult_def.expr == stored_expr
assert mult_def.expr._style_id == stored_expr._style_id
print("Passed sanity check: mult_def matches stored_expr")
# Out:
# Passed sanity check: mult_def matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(mult_def.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}, x \in \mathbb{C}}~\left[\forall_{a_{1}, \ldots, a_{n} \in \left\{x\right\}}~\left(\left(n \cdot x\right) = \left(a_{1} + \ldots + a_{n}\right)\right)\right]

# %%
mult_def.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
mult_def.expr_info()
# Out:
# 0. forall_{n in Natural, x in Complex} [forall_{a_{1}, ..a_{_a}.., a_{n} in {x}} ((n * x) = (a_{1} + ..a_{_a}.. + a_{n}))]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. ((n, x) -> {forall_{a_{1}, ..a_{_a}.., a_{n} in {x}} ((n * x) = (a_{1} + ..a_{_a}.. + a_{n})) if n in Natural ,  x in Complex.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (n, x) -> {forall_{a_{1}, ..a_{_a}.., a_{n} in {x}} ((n * x) = (a_{1} + ..a_{_a}.. + a_{n})) if n in Natural ,  x in Complex.
#    core type: Lambda
#    parameters: 27\n   body: 3
# 3. {forall_{a_{1}, ..a_{_a}.., a_{n} in {x}} ((n * x) = (a_{1} + ..a_{_a}.. + a_{n})) if n in Natural ,  x in Complex.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{a_{1}, ..a_{_a}.., a_{n} in {x}} ((n * x) = (a_{1} + ..a_{_a}.. + a_{n}))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (n in Natural) and (x in Complex)
#    core type: Operation
#    operator: 21
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((a_{1}, ..a_{_a}.., a_{n}) -> {(n * x) = (a_{1} + ..a_{_a}.. + a_{n}) if (a_{1} in {x}) and ..(a_{_a} in {x}).. and (a_{n} in {x}).)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (n in Natural, x in Complex)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. (a_{1}, ..a_{_a}.., a_{n}) -> {(n * x) = (a_{1} + ..a_{_a}.. + a_{n}) if (a_{1} in {x}) and ..(a_{_a} in {x}).. and (a_{n} in {x}).
#    core type: Lambda
#    parameters: 29\n   body: 12
# 10. n in Natural
#     core type: Operation
#     operator: 36
#     operands: 13
# 11. x in Complex
#     core type: Operation
#     operator: 36
#     operands: 14
# 12. {(n * x) = (a_{1} + ..a_{_a}.. + a_{n}) if (a_{1} in {x}) and ..(a_{_a} in {x}).. and (a_{n} in {x}).
#     core type: Conditional
#     value: 15
#     condition: 16
# 13. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 35, 17
# 14. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 45, 18
# 15. (n * x) = (a_{1} + ..a_{_a}.. + a_{n})
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. (a_{1} in {x}) and ..(a_{_a} in {x}).. and (a_{n} in {x})
#     core type: Operation
#     operator: 21
#     operands: 22
# 17. Natural
#     core type: Literal
#     sub-expressions:
# 18. Complex
#     core type: Literal
#     sub-expressions:
# 19. =
#     core type: Literal
#     sub-expressions:
# 20. (n * x, a_{1} + ..a_{_a}.. + a_{n})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. and
#     core type: Literal
#     sub-expressions:
# 22. (a_{1} in {x}, ..a_{_a} in {x}.., a_{n} in {x})
#     core type: ExprTuple
#     sub-expressions: 25
# 23. n * x
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. a_{1} + ..a_{_a}.. + a_{n}
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. (a_{1} in {x}), ..(a_{_a} in {x}).., (a_{n} in {x})
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 34
#     end_index: 35
# 26. *
#     core type: Literal
#     sub-expressions:
# 27. (n, x)
#     core type: ExprTuple
#     sub-expressions: 35, 45
# 28. +
#     core type: Literal
#     sub-expressions:
# 29. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 31
# 30. _a -> (a_{_a} in {x})
#     core type: Lambda
#     parameter: 44
#     body: 32
# 31. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 34
#     end_index: 35
# 32. a_{_a} in {x}
#     core type: Operation
#     operator: 36
#     operands: 37
# 33. _a -> a_{_a}
#     core type: Lambda
#     parameter: 44
#     body: 38
# 34. 1
#     core type: Literal
#     sub-expressions:
# 35. n
#     core type: Variable
#     sub-expressions:
# 36. in
#     core type: Literal
#     sub-expressions:
# 37. (a_{_a}, {x})
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 38. a_{_a}
#     core type: IndexedVar
# variable: 40
# index: 44
# 39. {x}
#     core type: Operation
#     operator: 42
#     operand: 45
# 40. a
#     core type: Variable
#     sub-expressions:
# 41. (_a)
#     core type: ExprTuple
#     sub-expressions: 44
# 42. Set
#     core type: Literal
#     sub-expressions:
# 43. (x)
#     core type: ExprTuple
#     sub-expressions: 45
# 44. _a
#     core type: Variable
#     sub-expressions:
# 45. x
#     core type: Variable
#     sub-expressions:
