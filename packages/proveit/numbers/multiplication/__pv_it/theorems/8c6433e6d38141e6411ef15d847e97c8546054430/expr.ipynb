# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a, b
from proveit.logic import And, InSet
from proveit.numbers import Integer, Mult

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([a, b], Conditional(InSet(Mult(a, b), Integer), And(InSet(a, Integer), InSet(b, Integer)))))
# Out:
# expr: ((a, b) -> {(a * b) in Integer if a in Integer ,  b in Integer.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a, b\right) \mapsto \left\{\left(a \cdot b\right) \in \mathbb{Z} \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a, b) -> {(a * b) in Integer if a in Integer ,  b in Integer.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a, b) -> {(a * b) in Integer if a in Integer ,  b in Integer.
#    core type: Lambda
#    parameters: 12\n   body: 2
# 2. {(a * b) in Integer if a in Integer ,  b in Integer.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (a * b) in Integer
#    core type: Operation
#    operator: 14
#    operands: 5
# 4. (a in Integer) and (b in Integer)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a * b, Integer)
#    core type: ExprTuple
#    sub-expressions: 8, 18
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a in Integer, b in Integer)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. a * b
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. a in Integer
#    core type: Operation
#    operator: 14
#    operands: 13
# 10. b in Integer
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. *
#     core type: Literal
#     sub-expressions:
# 12. (a, b)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 13. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 16, 18
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
# 18. Integer
#     core type: Literal
#     sub-expressions:
