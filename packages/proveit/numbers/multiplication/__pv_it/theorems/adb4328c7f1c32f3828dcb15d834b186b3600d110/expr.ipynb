# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, b, i, j
from proveit.core_expr_types import a_1_to_i, c_1_to_j
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Complex, Mult, Natural, Neg

# %%
# build up the expression from sub-expressions
expr = Lambda([i, j], Conditional(Forall([a_1_to_i, b, c_1_to_j], Equals(Neg(Mult(a_1_to_i, Neg(b), c_1_to_j)), Mult(a_1_to_i, b, c_1_to_j)), domains = [Complex, Complex, Complex]), And(InSet(i, Natural), InSet(j, Natural))))
# Out:
# expr: (i, j) -> {forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j} in Complex} ((-(a_{1} * ..a_{_a}.. * a_{i} * (-b) * c_{1} * ..c_{_a}.. * c_{j})) = (a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j})) if i in Natural ,  j in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(i, j\right) \mapsto \left\{\forall_{a_{1}, \ldots, a_{i}, b, c_{1}, \ldots, c_{j} \in \mathbb{C}}~\left(\left(-\left(a_{1} \cdot \ldots \cdot a_{i} \cdot \left(-b\right) \cdot c_{1} \cdot \ldots \cdot c_{j}\right)\right) = \left(a_{1} \cdot \ldots \cdot a_{i} \cdot b \cdot c_{1} \cdot \ldots \cdot c_{j}\right)\right) \textrm{ if } i \in \mathbb{N} ,  j \in \mathbb{N}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (i, j) -> {forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j} in Complex} ((-(a_{1} * ..a_{_a}.. * a_{i} * (-b) * c_{1} * ..c_{_a}.. * c_{j})) = (a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j})) if i in Natural ,  j in Natural.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (i, j)
#    core type: ExprTuple
#    sub-expressions: 44, 49
# 2. {forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j} in Complex} ((-(a_{1} * ..a_{_a}.. * a_{i} * (-b) * c_{1} * ..c_{_a}.. * c_{j})) = (a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j})) if i in Natural ,  j in Natural.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j} in Complex} ((-(a_{1} * ..a_{_a}.. * a_{i} * (-b) * c_{1} * ..c_{_a}.. * c_{j})) = (a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j}))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. (i in Natural) and (j in Natural)
#    core type: Operation
#    operator: 19
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}) -> {(-(a_{1} * ..a_{_a}.. * a_{i} * (-b) * c_{1} * ..c_{_a}.. * c_{j})) = (a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{j} in Complex.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (i in Natural, j in Natural)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. (a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}) -> {(-(a_{1} * ..a_{_a}.. * a_{i} * (-b) * c_{1} * ..c_{_a}.. * c_{j})) = (a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{j} in Complex.
#    core type: Lambda
#    parameters: 27\n   body: 11
# 9. i in Natural
#    core type: Operation
#    operator: 37
#    operands: 12
# 10. j in Natural
#     core type: Operation
#     operator: 37
#     operands: 13
# 11. {(-(a_{1} * ..a_{_a}.. * a_{i} * (-b) * c_{1} * ..c_{_a}.. * c_{j})) = (a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{j} in Complex.
#     core type: Conditional
#     value: 14
#     condition: 15
# 12. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 44, 16
# 13. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 49, 16
# 14. (-(a_{1} * ..a_{_a}.. * a_{i} * (-b) * c_{1} * ..c_{_a}.. * c_{j})) = (a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j})
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{i} in Complex) and (b in Complex) and (c_{1} in Complex) and ..(c_{_a} in Complex).. and (c_{j} in Complex)
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. Natural
#     core type: Literal
#     sub-expressions:
# 17. =
#     core type: Literal
#     sub-expressions:
# 18. (-(a_{1} * ..a_{_a}.. * a_{i} * (-b) * c_{1} * ..c_{_a}.. * c_{j}), a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j})
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. (a_{1} in Complex, ..a_{_a} in Complex.., a_{i} in Complex, b in Complex, c_{1} in Complex, ..c_{_a} in Complex.., c_{j} in Complex)
#     core type: ExprTuple
#     sub-expressions: 23, 24, 25
# 21. -(a_{1} * ..a_{_a}.. * a_{i} * (-b) * c_{1} * ..c_{_a}.. * c_{j})
#     core type: Operation
#     operator: 45
#     operand: 31
# 22. a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j}
#     core type: Operation
#     operator: 34
#     operands: 27
# 23. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 48
#     end_index: 44
# 24. b in Complex
#     core type: Operation
#     operator: 37
#     operands: 29
# 25. (c_{1} in Complex), ..(c_{_a} in Complex).., (c_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 48
#     end_index: 49
# 26. (a_{1} * ..a_{_a}.. * a_{i} * (-b) * c_{1} * ..c_{_a}.. * c_{j})
#     core type: ExprTuple
#     sub-expressions: 31
# 27. (a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j})
#     core type: ExprTuple
#     sub-expressions: 39, 51, 41
# 28. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 56
#     body: 32
# 29. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 51, 42
# 30. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 56
#     body: 33
# 31. a_{1} * ..a_{_a}.. * a_{i} * (-b) * c_{1} * ..c_{_a}.. * c_{j}
#     core type: Operation
#     operator: 34
#     operands: 35
# 32. a_{_a} in Complex
#     core type: Operation
#     operator: 37
#     operands: 36
# 33. c_{_a} in Complex
#     core type: Operation
#     operator: 37
#     operands: 38
# 34. *
#     core type: Literal
#     sub-expressions:
# 35. (a_{1}, ..a_{_a}.., a_{i}, -b, c_{1}, ..c_{_a}.., c_{j})
#     core type: ExprTuple
#     sub-expressions: 39, 40, 41
# 36. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 50, 42
# 37. in
#     core type: Literal
#     sub-expressions:
# 38. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 52, 42
# 39. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 48
#     end_index: 44
# 40. -b
#     core type: Operation
#     operator: 45
#     operand: 51
# 41. c_{1}, ..c_{_a}.., c_{j}
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 48
#     end_index: 49
# 42. Complex
#     core type: Literal
#     sub-expressions:
# 43. _a -> a_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 50
# 44. i
#     core type: Variable
#     sub-expressions:
# 45. -
#     core type: Literal
#     sub-expressions:
# 46. (b)
#     core type: ExprTuple
#     sub-expressions: 51
# 47. _a -> c_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 52
# 48. 1
#     core type: Literal
#     sub-expressions:
# 49. j
#     core type: Variable
#     sub-expressions:
# 50. a_{_a}
#     core type: IndexedVar
# variable: 53
# index: 56
# 51. b
#     core type: Variable
#     sub-expressions:
# 52. c_{_a}
#     core type: IndexedVar
# variable: 54
# index: 56
# 53. a
#     core type: Variable
#     sub-expressions:
# 54. c
#     core type: Variable
#     sub-expressions:
# 55. (_a)
#     core type: ExprTuple
#     sub-expressions: 56
# 56. _a
#     core type: Variable
#     sub-expressions:
