# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a, x, y
from proveit.logic import And, Equals, InSet
from proveit.numbers import Complex, Mult

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([a, x, y], Conditional(Equals(Mult(a, x), Mult(a, y)), And(InSet(a, Complex), InSet(x, Complex), InSet(y, Complex), Equals(x, y)))))
# Out:
# expr: ((a, x, y) -> {(a * x) = (a * y) if a in Complex ,  x in Complex ,  y in Complex ,  x = y.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a, x, y\right) \mapsto \left\{\left(a \cdot x\right) = \left(a \cdot y\right) \textrm{ if } a \in \mathbb{C} ,  x \in \mathbb{C} ,  y \in \mathbb{C} ,  x = y\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a, x, y) -> {(a * x) = (a * y) if a in Complex ,  x in Complex ,  y in Complex ,  x = y.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a, x, y) -> {(a * x) = (a * y) if a in Complex ,  x in Complex ,  y in Complex ,  x = y.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (a, x, y)
#    core type: ExprTuple
#    sub-expressions: 24, 26, 27
# 3. {(a * x) = (a * y) if a in Complex ,  x in Complex ,  y in Complex ,  x = y.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (a * x) = (a * y)
#    core type: Operation
#    operator: 22
#    operands: 6
# 5. (a in Complex) and (x in Complex) and (y in Complex) and (x = y)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a * x, a * y)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Complex, x in Complex, y in Complex, x = y)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13, 14
# 9. a * x
# ...
