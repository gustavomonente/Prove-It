# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#mult_zero_any">mult_zero_any</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.multiplication import mult_zero_any

# %%
# check that the built expression is the same as the stored expression
assert mult_zero_any.expr == stored_expr
assert mult_zero_any.expr._style_id == stored_expr._style_id
print("Passed sanity check: mult_zero_any matches stored_expr")
# Out:
# Passed sanity check: mult_zero_any matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(mult_zero_any.latex())
# Out:
# \vdash \forall_{i, j \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{i}, b_{1}, \ldots, b_{j} \in \mathbb{C}}~\left(\left(a_{1} \cdot \ldots \cdot a_{i} \cdot 0 \cdot b_{1} \cdot \ldots \cdot b_{j}\right) = 0\right)\right]

# %%
mult_zero_any.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
mult_zero_any.expr_info()
# Out:
# 0. forall_{i, j in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * 0 * b_{1} * ..b_{_a}.. * b_{j}) = 0)]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((i, j) -> {forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * 0 * b_{1} * ..b_{_a}.. * b_{j}) = 0) if i in Natural ,  j in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (i, j) -> {forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * 0 * b_{1} * ..b_{_a}.. * b_{j}) = 0) if i in Natural ,  j in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (i, j)
#    core type: ExprTuple
#    sub-expressions: 37, 40
# 4. {forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * 0 * b_{1} * ..b_{_a}.. * b_{j}) = 0) if i in Natural ,  j in Natural.
#    core type: Conditional
#    value: 5
# ...
