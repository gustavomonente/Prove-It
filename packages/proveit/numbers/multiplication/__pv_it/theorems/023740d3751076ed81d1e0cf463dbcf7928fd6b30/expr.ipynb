# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, i, j
from proveit.core_expr_types import a_1_to_i, b_1_to_j
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Complex, Mult, Natural, one

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([a_1_to_i, b_1_to_j], Equals(Mult(a_1_to_i, one, b_1_to_j), Mult(a_1_to_i, b_1_to_j)), domains = [Complex, Complex]), And(InSet(i, Natural), InSet(j, Natural)))
# Out:
# expr: {forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * 1 * b_{1} * ..b_{_a}.. * b_{j}) = (a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j})) if i in Natural ,  j in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{a_{1}, \ldots, a_{i}, b_{1}, \ldots, b_{j} \in \mathbb{C}}~\left(\left(a_{1} \cdot \ldots \cdot a_{i} \cdot 1 \cdot b_{1} \cdot \ldots \cdot b_{j}\right) = \left(a_{1} \cdot \ldots \cdot a_{i} \cdot b_{1} \cdot \ldots \cdot b_{j}\right)\right) \textrm{ if } i \in \mathbb{N} ,  j \in \mathbb{N}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * 1 * b_{1} * ..b_{_a}.. * b_{j}) = (a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j})) if i in Natural ,  j in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * 1 * b_{1} * ..b_{_a}.. * b_{j}) = (a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j}))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (i in Natural) and (j in Natural)
#    core type: Operation
#    operator: 17
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}) -> {(a_{1} * ..a_{_a}.. * a_{i} * 1 * b_{1} * ..b_{_a}.. * b_{j}) = (a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b_{1} in Complex ,  ..b_{_a} in Complex.. ,  b_{j} in Complex.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (i in Natural, j in Natural)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}) -> {(a_{1} * ..a_{_a}.. * a_{i} * 1 * b_{1} * ..b_{_a}.. * b_{j}) = (a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b_{1} in Complex ,  ..b_{_a} in Complex.. ,  b_{j} in Complex.
#    core type: Lambda
#    parameters: 25\n   body: 9
# 7. i in Natural
#    core type: Operation
#    operator: 38
#    operands: 10
# 8. j in Natural
#    core type: Operation
#    operator: 38
#    operands: 11
# 9. {(a_{1} * ..a_{_a}.. * a_{i} * 1 * b_{1} * ..b_{_a}.. * b_{j}) = (a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b_{1} in Complex ,  ..b_{_a} in Complex.. ,  b_{j} in Complex.
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 33, 14
# 11. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 36, 14
# 12. (a_{1} * ..a_{_a}.. * a_{i} * 1 * b_{1} * ..b_{_a}.. * b_{j}) = (a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j})
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{i} in Complex) and (b_{1} in Complex) and ..(b_{_a} in Complex).. and (b_{j} in Complex)
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. Natural
#     core type: Literal
#     sub-expressions:
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. (a_{1} * ..a_{_a}.. * a_{i} * 1 * b_{1} * ..b_{_a}.. * b_{j}, a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. and
#     core type: Literal
#     sub-expressions:
# 18. (a_{1} in Complex, ..a_{_a} in Complex.., a_{i} in Complex, b_{1} in Complex, ..b_{_a} in Complex.., b_{j} in Complex)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. a_{1} * ..a_{_a}.. * a_{i} * 1 * b_{1} * ..b_{_a}.. * b_{j}
#     core type: Operation
#     operator: 24
#     operands: 23
# 20. a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j}
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 35
#     end_index: 33
# 22. (b_{1} in Complex), ..(b_{_a} in Complex).., (b_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 35
#     end_index: 36
# 23. (a_{1}, ..a_{_a}.., a_{i}, 1, b_{1}, ..b_{_a}.., b_{j})
#     core type: ExprTuple
#     sub-expressions: 28, 35, 29
# 24. *
#     core type: Literal
#     sub-expressions:
# 25. (a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j})
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 26. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 46
#     body: 30
# 27. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 46
#     body: 31
# 28. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 35
#     end_index: 33
# 29. b_{1}, ..b_{_a}.., b_{j}
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 35
#     end_index: 36
# 30. a_{_a} in Complex
#     core type: Operation
#     operator: 38
#     operands: 37
# 31. b_{_a} in Complex
#     core type: Operation
#     operator: 38
#     operands: 39
# 32. _a -> a_{_a}
#     core type: Lambda
#     parameter: 46
#     body: 40
# 33. i
#     core type: Variable
#     sub-expressions:
# 34. _a -> b_{_a}
#     core type: Lambda
#     parameter: 46
#     body: 41
# 35. 1
#     core type: Literal
#     sub-expressions:
# 36. j
#     core type: Variable
#     sub-expressions:
# 37. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 40, 42
# 38. in
#     core type: Literal
#     sub-expressions:
# 39. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 40. a_{_a}
#     core type: IndexedVar
# variable: 43
# index: 46
# 41. b_{_a}
#     core type: IndexedVar
# variable: 44
# index: 46
# 42. Complex
#     core type: Literal
#     sub-expressions:
# 43. a
#     core type: Variable
#     sub-expressions:
# 44. b
#     core type: Variable
#     sub-expressions:
# 45. (_a)
#     core type: ExprTuple
#     sub-expressions: 46
# 46. _a
#     core type: Variable
#     sub-expressions:
