# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable, a, b, c, i, j
from proveit.logic import InSet
from proveit.numbers import Complex, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), Complex), one, i), InSet(b, Complex), ExprRange(sub_expr1, InSet(IndexedVar(c, sub_expr1), Complex), one, j))
# Out:
# expr: (a_{1} in Complex, ..a_{_a} in Complex.., a_{i} in Complex, b in Complex, c_{1} in Complex, ..c_{_a} in Complex.., c_{j} in Complex)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1} \in \mathbb{C}, \ldots, a_{i} \in \mathbb{C}, b \in \mathbb{C}, c_{1} \in \mathbb{C}, \ldots, c_{j} \in \mathbb{C}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1} in Complex, ..a_{_a} in Complex.., a_{i} in Complex, b in Complex, c_{1} in Complex, ..c_{_a} in Complex.., c_{j} in Complex)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{i} in Complex)
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 8
#    end_index: 5
# 2. b in Complex
#    core type: Operation
#    operator: 14
#    operands: 6
# 3. (c_{1} in Complex), ..(c_{_a} in Complex).., (c_{j} in Complex)
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 8
#    end_index: 9
# 4. _a -> (a_{_a} in Complex)
#    core type: Lambda
#    parameter: 22
#    body: 10
# 5. i
#    core type: Variable
#    sub-expressions:
# 6. (b, Complex)
#    core type: ExprTuple
#    sub-expressions: 11, 18
# 7. _a -> (c_{_a} in Complex)
#    core type: Lambda
#    parameter: 22
#    body: 12
# 8. 1
#    core type: Literal
#    sub-expressions:
# 9. j
#    core type: Variable
#    sub-expressions:
# 10. a_{_a} in Complex
#     core type: Operation
#     operator: 14
#     operands: 13
# 11. b
#     core type: Variable
#     sub-expressions:
# 12. c_{_a} in Complex
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 16, 18
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. a_{_a}
#     core type: IndexedVar
# variable: 19
# index: 22
# 17. c_{_a}
#     core type: IndexedVar
# variable: 20
# index: 22
# 18. Complex
#     core type: Literal
#     sub-expressions:
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. c
#     core type: Variable
#     sub-expressions:
# 21. (_a)
#     core type: ExprTuple
#     sub-expressions: 22
# 22. _a
#     core type: Variable
#     sub-expressions:
