# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#left_mult_nonpos_less">left_mult_nonpos_less</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.multiplication import left_mult_nonpos_less

# %%
# check that the built expression is the same as the stored expression
assert left_mult_nonpos_less.expr == stored_expr
assert left_mult_nonpos_less.expr._style_id == stored_expr._style_id
print("Passed sanity check: left_mult_nonpos_less matches stored_expr")
# Out:
# Passed sanity check: left_mult_nonpos_less matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(left_mult_nonpos_less.latex())
# Out:
# \vdash \forall_{a, x, y \in \mathbb{R}~|~x < y, a \leq 0}~\left(\left(a \cdot x\right) \geq \left(a \cdot y\right)\right)

# %%
left_mult_nonpos_less.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
left_mult_nonpos_less.expr_info()
# Out:
# 0. forall_{a, x, y in Real | x < y, a <= 0} ((a * x) >= (a * y))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, x, y) -> {(a * x) >= (a * y) if a in Real ,  x in Real ,  y in Real ,  x < y ,  a <= 0.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, x, y) -> {(a * x) >= (a * y) if a in Real ,  x in Real ,  y in Real ,  x < y ,  a <= 0.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a, x, y)
#    core type: ExprTuple
#    sub-expressions: 32, 30, 31
# 5. {(a * x) >= (a * y) if a in Real ,  x in Real ,  y in Real ,  x < y ,  a <= 0.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (a * x) >= (a * y)
#    core type: Operation
#    operator: 27
#    operands: 8
# 7. (a in Real) and (x in Real) and (y in Real) and (x < y) and (a <= 0)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (a * y, a * x)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# ...
