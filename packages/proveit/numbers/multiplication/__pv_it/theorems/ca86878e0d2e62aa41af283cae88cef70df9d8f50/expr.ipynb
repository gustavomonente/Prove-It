# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.core_expr_types import a_1_to_n
from proveit.logic import Forall, InSet
from proveit.numbers import Mult, Natural

# %%
# build up the expression from sub-expressions
expr = Forall([a_1_to_n], InSet(Mult(a_1_to_n), Natural), domains = [Natural])
# Out:
# expr: forall_{a_{1}, ..a_{_a}.., a_{n} in Natural} ((a_{1} * ..a_{_a}.. * a_{n}) in Natural)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a_{1}, \ldots, a_{n} \in \mathbb{N}}~\left(\left(a_{1} \cdot \ldots \cdot a_{n}\right) \in \mathbb{N}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a_{1}, ..a_{_a}.., a_{n} in Natural} ((a_{1} * ..a_{_a}.. * a_{n}) in Natural)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a_{1}, ..a_{_a}.., a_{n}) -> {(a_{1} * ..a_{_a}.. * a_{n}) in Natural if (a_{1} in Natural) and ..(a_{_a} in Natural).. and (a_{n} in Natural).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a_{1}, ..a_{_a}.., a_{n}) -> {(a_{1} * ..a_{_a}.. * a_{n}) in Natural if (a_{1} in Natural) and ..(a_{_a} in Natural).. and (a_{n} in Natural).
#    core type: Lambda
#    parameters: 13\n   body: 4
# 4. {(a_{1} * ..a_{_a}.. * a_{n}) in Natural if (a_{1} in Natural) and ..(a_{_a} in Natural).. and (a_{n} in Natural).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (a_{1} * ..a_{_a}.. * a_{n}) in Natural
#    core type: Operation
#    operator: 20
#    operands: 7
# 6. (a_{1} in Natural) and ..(a_{_a} in Natural).. and (a_{n} in Natural)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a_{1} * ..a_{_a}.. * a_{n}, Natural)
#    core type: ExprTuple
#    sub-expressions: 10, 23
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a_{1} in Natural, ..a_{_a} in Natural.., a_{n} in Natural)
#    core type: ExprTuple
#    sub-expressions: 11
# 10. a_{1} * ..a_{_a}.. * a_{n}
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (a_{1} in Natural), ..(a_{_a} in Natural).., (a_{n} in Natural)
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 18
#     end_index: 19
# 12. *
#     core type: Literal
#     sub-expressions:
# 13. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 15
# 14. _a -> (a_{_a} in Natural)
#     core type: Lambda
#     parameter: 26
#     body: 16
# 15. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 18
#     end_index: 19
# 16. a_{_a} in Natural
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. _a -> a_{_a}
#     core type: Lambda
#     parameter: 26
#     body: 22
# 18. 1
#     core type: Literal
#     sub-expressions:
# 19. n
#     core type: Variable
#     sub-expressions:
# 20. in
#     core type: Literal
#     sub-expressions:
# 21. (a_{_a}, Natural)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 22. a_{_a}
#     core type: IndexedVar
# variable: 24
# index: 26
# 23. Natural
#     core type: Literal
#     sub-expressions:
# 24. a
#     core type: Variable
#     sub-expressions:
# 25. (_a)
#     core type: ExprTuple
#     sub-expressions: 26
# 26. _a
#     core type: Variable
#     sub-expressions:
