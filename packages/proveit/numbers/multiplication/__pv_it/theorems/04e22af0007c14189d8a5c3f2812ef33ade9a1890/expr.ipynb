# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, x, y
from proveit.logic import And, Equals, InSet
from proveit.numbers import Complex, Mult

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(Mult(x, a), Mult(y, a)), And(InSet(a, Complex), InSet(x, Complex), InSet(y, Complex), Equals(x, y)))
# Out:
# expr: {(x * a) = (y * a) if a in Complex ,  x in Complex ,  y in Complex ,  x = y.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(x \cdot a\right) = \left(y \cdot a\right) \textrm{ if } a \in \mathbb{C} ,  x \in \mathbb{C} ,  y \in \mathbb{C} ,  x = y\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(x * a) = (y * a) if a in Complex ,  x in Complex ,  y in Complex ,  x = y.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (x * a) = (y * a)
#    core type: Operation
#    operator: 19
#    operands: 3
# 2. (a in Complex) and (x in Complex) and (y in Complex) and (x = y)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (x * a, y * a)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (a in Complex, x in Complex, y in Complex, x = y)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 6. x * a
#    core type: Operation
#    operator: 13
#    operands: 12
# 7. y * a
#    core type: Operation
#    operator: 13
#    operands: 14
# 8. a in Complex
#    core type: Operation
#    operator: 17
#    operands: 15
# 9. x in Complex
#    core type: Operation
#    operator: 17
#    operands: 16
# 10. y in Complex
#     core type: Operation
#     operator: 17
#     operands: 18
# 11. x = y
#     core type: Operation
#     operator: 19
#     operands: 20
# 12. (x, a)
#     core type: ExprTuple
#     sub-expressions: 23, 21
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (y, a)
#     core type: ExprTuple
#     sub-expressions: 24, 21
# 15. (a, Complex)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 16. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 23, 22
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (y, Complex)
#     core type: ExprTuple
#     sub-expressions: 24, 22
# 19. =
#     core type: Literal
#     sub-expressions:
# 20. (x, y)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. a
#     core type: Variable
#     sub-expressions:
# 22. Complex
#     core type: Literal
#     sub-expressions:
# 23. x
#     core type: Variable
#     sub-expressions:
# 24. y
#     core type: Variable
#     sub-expressions:
