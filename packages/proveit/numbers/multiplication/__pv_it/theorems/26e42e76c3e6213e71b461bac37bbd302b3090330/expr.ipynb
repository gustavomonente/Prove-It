# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.numbers.Mult.html">Mult</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Function, P, Q
from proveit.core_expr_types import a_1_to_i, b_1_to_j, c_1_to_k
from proveit.numbers import Mult, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [b_1_to_j]
expr = Mult(a_1_to_i, Sum(sub_expr1, Function(P, sub_expr1), condition = Function(Q, sub_expr1)), c_1_to_k)
# Out:
# expr: a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# a_{1} \cdot \ldots \cdot a_{i} \cdot \sum_{b_{1}, \ldots, b_{j}~|~Q(b_{1}, \ldots, b_{j})}~P(b_{1}, \ldots, b_{j}) \cdot c_{1} \cdot \ldots \cdot c_{k}

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. *
#    core type: Literal
#    sub-expressions:
# 2. (a_{1}, ..a_{_a}.., a_{i}, Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}), c_{1}, ..c_{_a}.., c_{k})
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 3. a_{1}, ..a_{_a}.., a_{i}
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 25
#    end_index: 7
# 4. Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j})
#    core type: Operation
#    operator: 8
#    operand: 13
# 5. c_{1}, ..c_{_a}.., c_{k}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 25
#    end_index: 11
# 6. _a -> a_{_a}
#    core type: Lambda
#    parameter: 30
#    body: 12
# 7. i
#    core type: Variable
#    sub-expressions:
# 8. Sum
#    core type: Literal
#    sub-expressions:
# 9. ((b_{1}, ..b_{_a}.., b_{j}) -> {P(b_{1}, ..b_{_a}.., b_{j}) if Q(b_{1}, ..b_{_a}.., b_{j}).)
#    core type: ExprTuple
#    sub-expressions: 13
# 10. _a -> c_{_a}
#     core type: Lambda
#     parameter: 30
#     body: 14
# 11. k
#     core type: Variable
#     sub-expressions:
# 12. a_{_a}
#     core type: IndexedVar
# variable: 15
# index: 30
# 13. (b_{1}, ..b_{_a}.., b_{j}) -> {P(b_{1}, ..b_{_a}.., b_{j}) if Q(b_{1}, ..b_{_a}.., b_{j}).
#     core type: Lambda
#     parameters: 22\n    body: 16
# 14. c_{_a}
#     core type: IndexedVar
# variable: 17
# index: 30
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. {P(b_{1}, ..b_{_a}.., b_{j}) if Q(b_{1}, ..b_{_a}.., b_{j}).
#     core type: Conditional
#     value: 18
#     condition: 19
# 17. c
#     core type: Variable
#     sub-expressions:
# 18. P(b_{1}, ..b_{_a}.., b_{j})
#     core type: Operation
#     operator: 20
#     operands: 22
# 19. Q(b_{1}, ..b_{_a}.., b_{j})
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. P
#     core type: Variable
#     sub-expressions:
# 21. Q
#     core type: Variable
#     sub-expressions:
# 22. (b_{1}, ..b_{_a}.., b_{j})
#     core type: ExprTuple
#     sub-expressions: 23
# 23. b_{1}, ..b_{_a}.., b_{j}
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 25
#     end_index: 26
# 24. _a -> b_{_a}
#     core type: Lambda
#     parameter: 30
#     body: 27
# 25. 1
#     core type: Literal
#     sub-expressions:
# 26. j
#     core type: Variable
#     sub-expressions:
# 27. b_{_a}
#     core type: IndexedVar
# variable: 28
# index: 30
# 28. b
#     core type: Variable
#     sub-expressions:
# 29. (_a)
#     core type: ExprTuple
#     sub-expressions: 30
# 30. _a
#     core type: Variable
#     sub-expressions:
