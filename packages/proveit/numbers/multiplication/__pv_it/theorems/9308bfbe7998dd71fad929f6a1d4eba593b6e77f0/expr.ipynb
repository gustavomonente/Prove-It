# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Function, Lambda, P, Q, i, j, k
from proveit.core_expr_types import a_1_to_i, b_1_to_j, c_1_to_k
from proveit.logic import And, Equals, Forall, Implies, InSet
from proveit.numbers import Complex, Mult, Natural, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [b_1_to_j]
sub_expr2 = Function(P, sub_expr1)
sub_expr3 = Function(Q, sub_expr1)
expr = Lambda([i, j, k], Conditional(Forall([P, Q], Implies(Forall(sub_expr1, InSet(sub_expr2, Complex), condition = sub_expr3), Forall([a_1_to_i, c_1_to_k], Equals(Mult(a_1_to_i, Sum(sub_expr1, sub_expr2, condition = sub_expr3), c_1_to_k), Sum(sub_expr1, Mult(a_1_to_i, sub_expr2, c_1_to_k), condition = sub_expr3)).with_wrapping_at(2), domains = [Complex, Complex]))), And(InSet(i, Natural), InSet(j, Natural), InSet(k, Natural))))
# Out:
# expr: (i, j, k) -> {forall_{P, Q} ([forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex)] => [forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))]) if i in Natural ,  j in Natural ,  k in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(i, j, k\right) \mapsto \left\{\forall_{P, Q}~\left(\left[\forall_{b_{1}, \ldots, b_{j}~|~Q(b_{1}, \ldots, b_{j})}~\left(P(b_{1}, \ldots, b_{j}) \in \mathbb{C}\right)\right] \Rightarrow \left[\forall_{a_{1}, \ldots, a_{i}, c_{1}, \ldots, c_{k} \in \mathbb{C}}~\left(\begin{array}{c} \begin{array}{l} \left(a_{1} \cdot \ldots \cdot a_{i} \cdot \sum_{b_{1}, \ldots, b_{j}~|~Q(b_{1}, \ldots, b_{j})}~P(b_{1}, \ldots, b_{j}) \cdot c_{1} \cdot \ldots \cdot c_{k}\right) =  \\ \sum_{b_{1}, \ldots, b_{j}~|~Q(b_{1}, \ldots, b_{j})}~\left(a_{1} \cdot \ldots \cdot a_{i} \cdot P(b_{1}, \ldots, b_{j}) \cdot c_{1} \cdot \ldots \cdot c_{k}\right) \end{array} \end{array}\right)\right]\right) \textrm{ if } i \in \mathbb{N} ,  j \in \mathbb{N} ,  k \in \mathbb{N}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (i, j, k) -> {forall_{P, Q} ([forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex)] => [forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))]) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (i, j, k)
#    core type: ExprTuple
#    sub-expressions: 67, 78, 71
# 2. {forall_{P, Q} ([forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex)] => [forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))]) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{P, Q} ([forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex)] => [forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))])
#    core type: Operation
#    operator: 22
#    operand: 7
# 4. (i in Natural) and (j in Natural) and (k in Natural)
#    core type: Operation
#    operator: 35
#    operands: 6
# 5. ((P, Q) -> ([forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex)] => [forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))]))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (i in Natural, j in Natural, k in Natural)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 7. (P, Q) -> ([forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex)] => [forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))])
#    core type: Lambda
#    parameters: 11\n   body: 12
# 8. i in Natural
#    core type: Operation
#    operator: 53
#    operands: 13
# 9. j in Natural
#    core type: Operation
#    operator: 53
#    operands: 14
# 10. k in Natural
#     core type: Operation
#     operator: 53
#     operands: 15
# 11. (P, Q)
#     core type: ExprTuple
#     sub-expressions: 68, 65
# 12. [forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex)] => [forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))]
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 67, 18
# 14. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 78, 18
# 15. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 71, 18
# 16. =>
#     core type: Literal
#     sub-expressions:
# 17. (forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex), forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k})))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. Natural
#     core type: Literal
#     sub-expressions:
# 19. forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex)
#     core type: Operation
#     operator: 22
#     operand: 24
# 20. forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))
#     core type: Operation
#     operator: 22
#     operand: 25
# 21. ((b_{1}, ..b_{_a}.., b_{j}) -> {P(b_{1}, ..b_{_a}.., b_{j}) in Complex if Q(b_{1}, ..b_{_a}.., b_{j}).)
#     core type: ExprTuple
#     sub-expressions: 24
# 22. forall
#     core type: Literal
#     sub-expressions:
# 23. ((a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k}) -> {(a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{k} in Complex.)
#     core type: ExprTuple
#     sub-expressions: 25
# 24. (b_{1}, ..b_{_a}.., b_{j}) -> {P(b_{1}, ..b_{_a}.., b_{j}) in Complex if Q(b_{1}, ..b_{_a}.., b_{j}).
#     core type: Lambda
#     parameters: 69\n    body: 26
# 25. (a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k}) -> {(a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{k} in Complex.
#     core type: Lambda
#     parameters: 27\n    body: 28
# 26. {P(b_{1}, ..b_{_a}.., b_{j}) in Complex if Q(b_{1}, ..b_{_a}.., b_{j}).
#     core type: Conditional
#     value: 29
#     condition: 61
# 27. (a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k})
#     core type: ExprTuple
#     sub-expressions: 62, 64
# 28. {(a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{k} in Complex.
#     core type: Conditional
#     value: 30
#     condition: 31
# 29. P(b_{1}, ..b_{_a}.., b_{j}) in Complex
#     core type: Operation
#     operator: 53
#     operands: 32
# 30. (a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k})
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{i} in Complex) and (c_{1} in Complex) and ..(c_{_a} in Complex).. and (c_{k} in Complex)
#     core type: Operation
#     operator: 35
#     operands: 36
# 32. (P(b_{1}, ..b_{_a}.., b_{j}), Complex)
#     core type: ExprTuple
#     sub-expressions: 63, 57
# 33. =
#     core type: Literal
#     sub-expressions:
# 34. (a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}, Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 35. and
#     core type: Literal
#     sub-expressions:
# 36. (a_{1} in Complex, ..a_{_a} in Complex.., a_{i} in Complex, c_{1} in Complex, ..c_{_a} in Complex.., c_{k} in Complex)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 37. a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}
#     core type: Operation
#     operator: 59
#     operands: 41
# 38. Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k})
#     core type: Operation
#     operator: 49
#     operand: 46
# 39. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 77
#     end_index: 67
# 40. (c_{1} in Complex), ..(c_{_a} in Complex).., (c_{k} in Complex)
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 77
#     end_index: 71
# 41. (a_{1}, ..a_{_a}.., a_{i}, Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}), c_{1}, ..c_{_a}.., c_{k})
#     core type: ExprTuple
#     sub-expressions: 62, 45, 64
# 42. ((b_{1}, ..b_{_a}.., b_{j}) -> {a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k} if Q(b_{1}, ..b_{_a}.., b_{j}).)
#     core type: ExprTuple
#     sub-expressions: 46
# 43. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 83
#     body: 47
# 44. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 83
#     body: 48
# 45. Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j})
#     core type: Operation
#     operator: 49
#     operand: 55
# 46. (b_{1}, ..b_{_a}.., b_{j}) -> {a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k} if Q(b_{1}, ..b_{_a}.., b_{j}).
#     core type: Lambda
#     parameters: 69\n    body: 51
# 47. a_{_a} in Complex
#     core type: Operation
#     operator: 53
#     operands: 52
# 48. c_{_a} in Complex
#     core type: Operation
#     operator: 53
#     operands: 54
# 49. Sum
#     core type: Literal
#     sub-expressions:
# 50. ((b_{1}, ..b_{_a}.., b_{j}) -> {P(b_{1}, ..b_{_a}.., b_{j}) if Q(b_{1}, ..b_{_a}.., b_{j}).)
#     core type: ExprTuple
#     sub-expressions: 55
# 51. {a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k} if Q(b_{1}, ..b_{_a}.., b_{j}).
#     core type: Conditional
#     value: 56
#     condition: 61
# 52. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 72, 57
# 53. in
#     core type: Literal
#     sub-expressions:
# 54. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 74, 57
# 55. (b_{1}, ..b_{_a}.., b_{j}) -> {P(b_{1}, ..b_{_a}.., b_{j}) if Q(b_{1}, ..b_{_a}.., b_{j}).
#     core type: Lambda
#     parameters: 69\n    body: 58
# 56. a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}
#     core type: Operation
#     operator: 59
#     operands: 60
# 57. Complex
#     core type: Literal
#     sub-expressions:
# 58. {P(b_{1}, ..b_{_a}.., b_{j}) if Q(b_{1}, ..b_{_a}.., b_{j}).
#     core type: Conditional
#     value: 63
#     condition: 61
# 59. *
#     core type: Literal
#     sub-expressions:
# 60. (a_{1}, ..a_{_a}.., a_{i}, P(b_{1}, ..b_{_a}.., b_{j}), c_{1}, ..c_{_a}.., c_{k})
#     core type: ExprTuple
#     sub-expressions: 62, 63, 64
# 61. Q(b_{1}, ..b_{_a}.., b_{j})
#     core type: Operation
#     operator: 65
#     operands: 69
# 62. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 66
#     start_index: 77
#     end_index: 67
# 63. P(b_{1}, ..b_{_a}.., b_{j})
#     core type: Operation
#     operator: 68
#     operands: 69
# 64. c_{1}, ..c_{_a}.., c_{k}
#     core type: ExprRange
#     lambda_map: 70
#     start_index: 77
#     end_index: 71
# 65. Q
#     core type: Variable
#     sub-expressions:
# 66. _a -> a_{_a}
#     core type: Lambda
#     parameter: 83
#     body: 72
# 67. i
#     core type: Variable
#     sub-expressions:
# 68. P
#     core type: Variable
#     sub-expressions:
# 69. (b_{1}, ..b_{_a}.., b_{j})
#     core type: ExprTuple
#     sub-expressions: 73
# 70. _a -> c_{_a}
#     core type: Lambda
#     parameter: 83
#     body: 74
# 71. k
#     core type: Variable
#     sub-expressions:
# 72. a_{_a}
#     core type: IndexedVar
# variable: 75
# index: 83
# 73. b_{1}, ..b_{_a}.., b_{j}
#     core type: ExprRange
#     lambda_map: 76
#     start_index: 77
#     end_index: 78
# 74. c_{_a}
#     core type: IndexedVar
# variable: 79
# index: 83
# 75. a
#     core type: Variable
#     sub-expressions:
# 76. _a -> b_{_a}
#     core type: Lambda
#     parameter: 83
#     body: 80
# 77. 1
#     core type: Literal
#     sub-expressions:
# 78. j
#     core type: Variable
#     sub-expressions:
# 79. c
#     core type: Variable
#     sub-expressions:
# 80. b_{_a}
#     core type: IndexedVar
# variable: 81
# index: 83
# 81. b
#     core type: Variable
#     sub-expressions:
# 82. (_a)
#     core type: ExprTuple
#     sub-expressions: 83
# 83. _a
#     core type: Variable
#     sub-expressions:
