# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#mult_nat_closure">mult_nat_closure</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.multiplication import mult_nat_closure

# %%
# check that the built expression is the same as the stored expression
assert mult_nat_closure.expr == stored_expr
assert mult_nat_closure.expr._style_id == stored_expr._style_id
print("Passed sanity check: mult_nat_closure matches stored_expr")
# Out:
# Passed sanity check: mult_nat_closure matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(mult_nat_closure.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{n} \in \mathbb{N}}~\left(\left(a_{1} \cdot \ldots \cdot a_{n}\right) \in \mathbb{N}\right)\right]

# %%
mult_nat_closure.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
mult_nat_closure.expr_info()
# Out:
# 0. forall_{n in Natural} [forall_{a_{1}, ..a_{_a}.., a_{n} in Natural} ((a_{1} * ..a_{_a}.. * a_{n}) in Natural)]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (n -> {forall_{a_{1}, ..a_{_a}.., a_{n} in Natural} ((a_{1} * ..a_{_a}.. * a_{n}) in Natural) if n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{a_{1}, ..a_{_a}.., a_{n} in Natural} ((a_{1} * ..a_{_a}.. * a_{n}) in Natural) if n in Natural.
#    core type: Lambda
#    parameter: 25
#    body: 3
# 3. {forall_{a_{1}, ..a_{_a}.., a_{n} in Natural} ((a_{1} * ..a_{_a}.. * a_{n}) in Natural) if n in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{a_{1}, ..a_{_a}.., a_{n} in Natural} ((a_{1} * ..a_{_a}.. * a_{n}) in Natural)
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. n in Natural
#    core type: Operation
#    operator: 26
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((a_{1}, ..a_{_a}.., a_{n}) -> {(a_{1} * ..a_{_a}.. * a_{n}) in Natural if (a_{1} in Natural) and ..(a_{_a} in Natural).. and (a_{n} in Natural).)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (n, Natural)
#    core type: ExprTuple
#    sub-expressions: 25, 29
# 9. (a_{1}, ..a_{_a}.., a_{n}) -> {(a_{1} * ..a_{_a}.. * a_{n}) in Natural if (a_{1} in Natural) and ..(a_{_a} in Natural).. and (a_{n} in Natural).
#    core type: Lambda
#    parameters: 19\n   body: 10
# 10. {(a_{1} * ..a_{_a}.. * a_{n}) in Natural if (a_{1} in Natural) and ..(a_{_a} in Natural).. and (a_{n} in Natural).
#     core type: Conditional
#     value: 11
#     condition: 12
# 11. (a_{1} * ..a_{_a}.. * a_{n}) in Natural
#     core type: Operation
#     operator: 26
#     operands: 13
# 12. (a_{1} in Natural) and ..(a_{_a} in Natural).. and (a_{n} in Natural)
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (a_{1} * ..a_{_a}.. * a_{n}, Natural)
#     core type: ExprTuple
#     sub-expressions: 16, 29
# 14. and
#     core type: Literal
#     sub-expressions:
# 15. (a_{1} in Natural, ..a_{_a} in Natural.., a_{n} in Natural)
#     core type: ExprTuple
#     sub-expressions: 17
# 16. a_{1} * ..a_{_a}.. * a_{n}
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. (a_{1} in Natural), ..(a_{_a} in Natural).., (a_{n} in Natural)
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 24
#     end_index: 25
# 18. *
#     core type: Literal
#     sub-expressions:
# 19. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 21
# 20. _a -> (a_{_a} in Natural)
#     core type: Lambda
#     parameter: 32
#     body: 22
# 21. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 24
#     end_index: 25
# 22. a_{_a} in Natural
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. _a -> a_{_a}
#     core type: Lambda
#     parameter: 32
#     body: 28
# 24. 1
#     core type: Literal
#     sub-expressions:
# 25. n
#     core type: Variable
#     sub-expressions:
# 26. in
#     core type: Literal
#     sub-expressions:
# 27. (a_{_a}, Natural)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 28. a_{_a}
#     core type: IndexedVar
# variable: 30
# index: 32
# 29. Natural
#     core type: Literal
#     sub-expressions:
# 30. a
#     core type: Variable
#     sub-expressions:
# 31. (_a)
#     core type: ExprTuple
#     sub-expressions: 32
# 32. _a
#     core type: Variable
#     sub-expressions:
