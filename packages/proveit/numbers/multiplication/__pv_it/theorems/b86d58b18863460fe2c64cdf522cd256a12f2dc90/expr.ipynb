# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Function, P, Q, i, j, k
from proveit.core_expr_types import a_1_to_i, b_1_to_j, c_1_to_k
from proveit.logic import Equals, Forall, Implies, InSet
from proveit.numbers import Complex, Mult, Natural, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [b_1_to_j]
sub_expr2 = Function(P, sub_expr1)
sub_expr3 = Function(Q, sub_expr1)
expr = Forall([i, j, k], Forall([P, Q], Implies(Forall(sub_expr1, InSet(sub_expr2, Complex), condition = sub_expr3), Forall([a_1_to_i, c_1_to_k], Equals(Mult(a_1_to_i, Sum(sub_expr1, sub_expr2, condition = sub_expr3), c_1_to_k), Sum(sub_expr1, Mult(a_1_to_i, sub_expr2, c_1_to_k), condition = sub_expr3)).with_wrapping_at(2), domains = [Complex, Complex]))), domains = [Natural, Natural, Natural])
# Out:
# expr: forall_{i, j, k in Natural} [forall_{P, Q} ([forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex)] => [forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))])]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{i, j, k \in \mathbb{N}}~\left[\forall_{P, Q}~\left(\left[\forall_{b_{1}, \ldots, b_{j}~|~Q(b_{1}, \ldots, b_{j})}~\left(P(b_{1}, \ldots, b_{j}) \in \mathbb{C}\right)\right] \Rightarrow \left[\forall_{a_{1}, \ldots, a_{i}, c_{1}, \ldots, c_{k} \in \mathbb{C}}~\left(\begin{array}{c} \begin{array}{l} \left(a_{1} \cdot \ldots \cdot a_{i} \cdot \sum_{b_{1}, \ldots, b_{j}~|~Q(b_{1}, \ldots, b_{j})}~P(b_{1}, \ldots, b_{j}) \cdot c_{1} \cdot \ldots \cdot c_{k}\right) =  \\ \sum_{b_{1}, \ldots, b_{j}~|~Q(b_{1}, \ldots, b_{j})}~\left(a_{1} \cdot \ldots \cdot a_{i} \cdot P(b_{1}, \ldots, b_{j}) \cdot c_{1} \cdot \ldots \cdot c_{k}\right) \end{array} \end{array}\right)\right]\right)\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{i, j, k in Natural} [forall_{P, Q} ([forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex)] => [forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))])]
#    core type: Operation
#    operator: 24
#    operand: 2
# 1. ((i, j, k) -> {forall_{P, Q} ([forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex)] => [forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))]) if i in Natural ,  j in Natural ,  k in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (i, j, k) -> {forall_{P, Q} ([forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex)] => [forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))]) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (i, j, k)
#    core type: ExprTuple
#    sub-expressions: 69, 80, 73
# 4. {forall_{P, Q} ([forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex)] => [forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))]) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{P, Q} ([forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex)] => [forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))])
#    core type: Operation
#    operator: 24
#    operand: 9
# 6. (i in Natural) and (j in Natural) and (k in Natural)
#    core type: Operation
#    operator: 37
#    operands: 8
# 7. ((P, Q) -> ([forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex)] => [forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))]))
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (i in Natural, j in Natural, k in Natural)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 9. (P, Q) -> ([forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex)] => [forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))])
#    core type: Lambda
#    parameters: 13\n   body: 14
# 10. i in Natural
#     core type: Operation
#     operator: 55
#     operands: 15
# 11. j in Natural
#     core type: Operation
#     operator: 55
#     operands: 16
# 12. k in Natural
#     core type: Operation
#     operator: 55
#     operands: 17
# 13. (P, Q)
#     core type: ExprTuple
#     sub-expressions: 70, 67
# 14. [forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex)] => [forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))]
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 69, 20
# 16. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 80, 20
# 17. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 73, 20
# 18. =>
#     core type: Literal
#     sub-expressions:
# 19. (forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex), forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k})))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 20. Natural
#     core type: Literal
#     sub-expressions:
# 21. forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex)
#     core type: Operation
#     operator: 24
#     operand: 26
# 22. forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))
#     core type: Operation
#     operator: 24
#     operand: 27
# 23. ((b_{1}, ..b_{_a}.., b_{j}) -> {P(b_{1}, ..b_{_a}.., b_{j}) in Complex if Q(b_{1}, ..b_{_a}.., b_{j}).)
#     core type: ExprTuple
#     sub-expressions: 26
# 24. forall
#     core type: Literal
#     sub-expressions:
# 25. ((a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k}) -> {(a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{k} in Complex.)
#     core type: ExprTuple
#     sub-expressions: 27
# 26. (b_{1}, ..b_{_a}.., b_{j}) -> {P(b_{1}, ..b_{_a}.., b_{j}) in Complex if Q(b_{1}, ..b_{_a}.., b_{j}).
#     core type: Lambda
#     parameters: 71\n    body: 28
# 27. (a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k}) -> {(a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{k} in Complex.
#     core type: Lambda
#     parameters: 29\n    body: 30
# 28. {P(b_{1}, ..b_{_a}.., b_{j}) in Complex if Q(b_{1}, ..b_{_a}.., b_{j}).
#     core type: Conditional
#     value: 31
#     condition: 63
# 29. (a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k})
#     core type: ExprTuple
#     sub-expressions: 64, 66
# 30. {(a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{k} in Complex.
#     core type: Conditional
#     value: 32
#     condition: 33
# 31. P(b_{1}, ..b_{_a}.., b_{j}) in Complex
#     core type: Operation
#     operator: 55
#     operands: 34
# 32. (a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k})
#     core type: Operation
#     operator: 35
#     operands: 36
# 33. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{i} in Complex) and (c_{1} in Complex) and ..(c_{_a} in Complex).. and (c_{k} in Complex)
#     core type: Operation
#     operator: 37
#     operands: 38
# 34. (P(b_{1}, ..b_{_a}.., b_{j}), Complex)
#     core type: ExprTuple
#     sub-expressions: 65, 59
# 35. =
#     core type: Literal
#     sub-expressions:
# 36. (a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}, Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 37. and
#     core type: Literal
#     sub-expressions:
# 38. (a_{1} in Complex, ..a_{_a} in Complex.., a_{i} in Complex, c_{1} in Complex, ..c_{_a} in Complex.., c_{k} in Complex)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 39. a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}
#     core type: Operation
#     operator: 61
#     operands: 43
# 40. Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k})
#     core type: Operation
#     operator: 51
#     operand: 48
# 41. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 79
#     end_index: 69
# 42. (c_{1} in Complex), ..(c_{_a} in Complex).., (c_{k} in Complex)
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 79
#     end_index: 73
# 43. (a_{1}, ..a_{_a}.., a_{i}, Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}), c_{1}, ..c_{_a}.., c_{k})
#     core type: ExprTuple
#     sub-expressions: 64, 47, 66
# 44. ((b_{1}, ..b_{_a}.., b_{j}) -> {a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k} if Q(b_{1}, ..b_{_a}.., b_{j}).)
#     core type: ExprTuple
#     sub-expressions: 48
# 45. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 85
#     body: 49
# 46. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 85
#     body: 50
# 47. Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j})
#     core type: Operation
#     operator: 51
#     operand: 57
# 48. (b_{1}, ..b_{_a}.., b_{j}) -> {a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k} if Q(b_{1}, ..b_{_a}.., b_{j}).
#     core type: Lambda
#     parameters: 71\n    body: 53
# 49. a_{_a} in Complex
#     core type: Operation
#     operator: 55
#     operands: 54
# 50. c_{_a} in Complex
#     core type: Operation
#     operator: 55
#     operands: 56
# 51. Sum
#     core type: Literal
#     sub-expressions:
# 52. ((b_{1}, ..b_{_a}.., b_{j}) -> {P(b_{1}, ..b_{_a}.., b_{j}) if Q(b_{1}, ..b_{_a}.., b_{j}).)
#     core type: ExprTuple
#     sub-expressions: 57
# 53. {a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k} if Q(b_{1}, ..b_{_a}.., b_{j}).
#     core type: Conditional
#     value: 58
#     condition: 63
# 54. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 74, 59
# 55. in
#     core type: Literal
#     sub-expressions:
# 56. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 76, 59
# 57. (b_{1}, ..b_{_a}.., b_{j}) -> {P(b_{1}, ..b_{_a}.., b_{j}) if Q(b_{1}, ..b_{_a}.., b_{j}).
#     core type: Lambda
#     parameters: 71\n    body: 60
# 58. a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}
#     core type: Operation
#     operator: 61
#     operands: 62
# 59. Complex
#     core type: Literal
#     sub-expressions:
# 60. {P(b_{1}, ..b_{_a}.., b_{j}) if Q(b_{1}, ..b_{_a}.., b_{j}).
#     core type: Conditional
#     value: 65
#     condition: 63
# 61. *
#     core type: Literal
#     sub-expressions:
# 62. (a_{1}, ..a_{_a}.., a_{i}, P(b_{1}, ..b_{_a}.., b_{j}), c_{1}, ..c_{_a}.., c_{k})
#     core type: ExprTuple
#     sub-expressions: 64, 65, 66
# 63. Q(b_{1}, ..b_{_a}.., b_{j})
#     core type: Operation
#     operator: 67
#     operands: 71
# 64. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 68
#     start_index: 79
#     end_index: 69
# 65. P(b_{1}, ..b_{_a}.., b_{j})
#     core type: Operation
#     operator: 70
#     operands: 71
# 66. c_{1}, ..c_{_a}.., c_{k}
#     core type: ExprRange
#     lambda_map: 72
#     start_index: 79
#     end_index: 73
# 67. Q
#     core type: Variable
#     sub-expressions:
# 68. _a -> a_{_a}
#     core type: Lambda
#     parameter: 85
#     body: 74
# 69. i
#     core type: Variable
#     sub-expressions:
# 70. P
#     core type: Variable
#     sub-expressions:
# 71. (b_{1}, ..b_{_a}.., b_{j})
#     core type: ExprTuple
#     sub-expressions: 75
# 72. _a -> c_{_a}
#     core type: Lambda
#     parameter: 85
#     body: 76
# 73. k
#     core type: Variable
#     sub-expressions:
# 74. a_{_a}
#     core type: IndexedVar
# variable: 77
# index: 85
# 75. b_{1}, ..b_{_a}.., b_{j}
#     core type: ExprRange
#     lambda_map: 78
#     start_index: 79
#     end_index: 80
# 76. c_{_a}
#     core type: IndexedVar
# variable: 81
# index: 85
# 77. a
#     core type: Variable
#     sub-expressions:
# 78. _a -> b_{_a}
#     core type: Lambda
#     parameter: 85
#     body: 82
# 79. 1
#     core type: Literal
#     sub-expressions:
# 80. j
#     core type: Variable
#     sub-expressions:
# 81. c
#     core type: Variable
#     sub-expressions:
# 82. b_{_a}
#     core type: IndexedVar
# variable: 83
# index: 85
# 83. b
#     core type: Variable
#     sub-expressions:
# 84. (_a)
#     core type: ExprTuple
#     sub-expressions: 85
# 85. _a
#     core type: Variable
#     sub-expressions:
