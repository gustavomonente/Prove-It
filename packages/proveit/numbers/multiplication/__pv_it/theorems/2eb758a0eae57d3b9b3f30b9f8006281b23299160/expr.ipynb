# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, n
from proveit.core_expr_types import a_1_to_n
from proveit.logic import Forall, InSet
from proveit.numbers import Mult, Natural, RealPos

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(n, Conditional(Forall([a_1_to_n], InSet(Mult(a_1_to_n), RealPos), domains = [RealPos]), InSet(n, Natural))))
# Out:
# expr: (n -> {forall_{a_{1}, ..a_{_a}.., a_{n} in RealPos} ((a_{1} * ..a_{_a}.. * a_{n}) in RealPos) if n in Natural.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(n \mapsto \left\{\forall_{a_{1}, \ldots, a_{n} \in \mathbb{R}^+}~\left(\left(a_{1} \cdot \ldots \cdot a_{n}\right) \in \mathbb{R}^+\right) \textrm{ if } n \in \mathbb{N}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (n -> {forall_{a_{1}, ..a_{_a}.., a_{n} in RealPos} ((a_{1} * ..a_{_a}.. * a_{n}) in RealPos) if n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. n -> {forall_{a_{1}, ..a_{_a}.., a_{n} in RealPos} ((a_{1} * ..a_{_a}.. * a_{n}) in RealPos) if n in Natural.
#    core type: Lambda
#    parameter: 25
#    body: 2
# 2. {forall_{a_{1}, ..a_{_a}.., a_{n} in RealPos} ((a_{1} * ..a_{_a}.. * a_{n}) in RealPos) if n in Natural.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1}, ..a_{_a}.., a_{n} in RealPos} ((a_{1} * ..a_{_a}.. * a_{n}) in RealPos)
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. n in Natural
#    core type: Operation
#    operator: 26
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((a_{1}, ..a_{_a}.., a_{n}) -> {(a_{1} * ..a_{_a}.. * a_{n}) in RealPos if (a_{1} in RealPos) and ..(a_{_a} in RealPos).. and (a_{n} in RealPos).)
#    core type: ExprTuple
#    sub-expressions: 8
# ...
