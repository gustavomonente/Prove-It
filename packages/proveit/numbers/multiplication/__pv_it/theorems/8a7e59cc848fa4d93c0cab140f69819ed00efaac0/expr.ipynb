# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Function, P, Q, i, j, k
from proveit.core_expr_types import a_1_to_i, b_1_to_j, c_1_to_k
from proveit.logic import And, Equals, Forall, Implies, InSet
from proveit.numbers import Complex, Mult, Natural, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [b_1_to_j]
sub_expr2 = Function(P, sub_expr1)
sub_expr3 = Function(Q, sub_expr1)
expr = Conditional(Forall([P, Q], Implies(Forall(sub_expr1, InSet(sub_expr2, Complex), condition = sub_expr3), Forall([a_1_to_i, c_1_to_k], Equals(Mult(a_1_to_i, Sum(sub_expr1, sub_expr2, condition = sub_expr3), c_1_to_k), Sum(sub_expr1, Mult(a_1_to_i, sub_expr2, c_1_to_k), condition = sub_expr3)).with_wrapping_at(2), domains = [Complex, Complex]))), And(InSet(i, Natural), InSet(j, Natural), InSet(k, Natural)))
# Out:
# expr: {forall_{P, Q} ([forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex)] => [forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))]) if i in Natural ,  j in Natural ,  k in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{P, Q}~\left(\left[\forall_{b_{1}, \ldots, b_{j}~|~Q(b_{1}, \ldots, b_{j})}~\left(P(b_{1}, \ldots, b_{j}) \in \mathbb{C}\right)\right] \Rightarrow \left[\forall_{a_{1}, \ldots, a_{i}, c_{1}, \ldots, c_{k} \in \mathbb{C}}~\left(\begin{array}{c} \begin{array}{l} \left(a_{1} \cdot \ldots \cdot a_{i} \cdot \sum_{b_{1}, \ldots, b_{j}~|~Q(b_{1}, \ldots, b_{j})}~P(b_{1}, \ldots, b_{j}) \cdot c_{1} \cdot \ldots \cdot c_{k}\right) =  \\ \sum_{b_{1}, \ldots, b_{j}~|~Q(b_{1}, \ldots, b_{j})}~\left(a_{1} \cdot \ldots \cdot a_{i} \cdot P(b_{1}, \ldots, b_{j}) \cdot c_{1} \cdot \ldots \cdot c_{k}\right) \end{array} \end{array}\right)\right]\right) \textrm{ if } i \in \mathbb{N} ,  j \in \mathbb{N} ,  k \in \mathbb{N}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{P, Q} ([forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex)] => [forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))]) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{P, Q} ([forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex)] => [forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))])
#    core type: Operation
#    operator: 20
#    operand: 5
# 2. (i in Natural) and (j in Natural) and (k in Natural)
#    core type: Operation
#    operator: 33
#    operands: 4
# 3. ((P, Q) -> ([forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex)] => [forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))]))
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (i in Natural, j in Natural, k in Natural)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 5. (P, Q) -> ([forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex)] => [forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))])
#    core type: Lambda
#    parameters: 9\n   body: 10
# 6. i in Natural
#    core type: Operation
#    operator: 51
#    operands: 11
# 7. j in Natural
#    core type: Operation
#    operator: 51
#    operands: 12
# 8. k in Natural
#    core type: Operation
#    operator: 51
#    operands: 13
# 9. (P, Q)
#    core type: ExprTuple
#    sub-expressions: 66, 63
# 10. [forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex)] => [forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))]
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 65, 16
# 12. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 76, 16
# 13. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 69, 16
# 14. =>
#     core type: Literal
#     sub-expressions:
# 15. (forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex), forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k})))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. Natural
#     core type: Literal
#     sub-expressions:
# 17. forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex)
#     core type: Operation
#     operator: 20
#     operand: 22
# 18. forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))
#     core type: Operation
#     operator: 20
#     operand: 23
# 19. ((b_{1}, ..b_{_a}.., b_{j}) -> {P(b_{1}, ..b_{_a}.., b_{j}) in Complex if Q(b_{1}, ..b_{_a}.., b_{j}).)
#     core type: ExprTuple
#     sub-expressions: 22
# 20. forall
#     core type: Literal
#     sub-expressions:
# 21. ((a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k}) -> {(a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{k} in Complex.)
#     core type: ExprTuple
#     sub-expressions: 23
# 22. (b_{1}, ..b_{_a}.., b_{j}) -> {P(b_{1}, ..b_{_a}.., b_{j}) in Complex if Q(b_{1}, ..b_{_a}.., b_{j}).
#     core type: Lambda
#     parameters: 67\n    body: 24
# 23. (a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k}) -> {(a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{k} in Complex.
#     core type: Lambda
#     parameters: 25\n    body: 26
# 24. {P(b_{1}, ..b_{_a}.., b_{j}) in Complex if Q(b_{1}, ..b_{_a}.., b_{j}).
#     core type: Conditional
#     value: 27
#     condition: 59
# 25. (a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k})
#     core type: ExprTuple
#     sub-expressions: 60, 62
# 26. {(a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{k} in Complex.
#     core type: Conditional
#     value: 28
#     condition: 29
# 27. P(b_{1}, ..b_{_a}.., b_{j}) in Complex
#     core type: Operation
#     operator: 51
#     operands: 30
# 28. (a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k})
#     core type: Operation
#     operator: 31
#     operands: 32
# 29. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{i} in Complex) and (c_{1} in Complex) and ..(c_{_a} in Complex).. and (c_{k} in Complex)
#     core type: Operation
#     operator: 33
#     operands: 34
# 30. (P(b_{1}, ..b_{_a}.., b_{j}), Complex)
#     core type: ExprTuple
#     sub-expressions: 61, 55
# 31. =
#     core type: Literal
#     sub-expressions:
# 32. (a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}, Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 33. and
#     core type: Literal
#     sub-expressions:
# 34. (a_{1} in Complex, ..a_{_a} in Complex.., a_{i} in Complex, c_{1} in Complex, ..c_{_a} in Complex.., c_{k} in Complex)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 35. a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}
#     core type: Operation
#     operator: 57
#     operands: 39
# 36. Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k})
#     core type: Operation
#     operator: 47
#     operand: 44
# 37. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 75
#     end_index: 65
# 38. (c_{1} in Complex), ..(c_{_a} in Complex).., (c_{k} in Complex)
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 75
#     end_index: 69
# 39. (a_{1}, ..a_{_a}.., a_{i}, Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}), c_{1}, ..c_{_a}.., c_{k})
#     core type: ExprTuple
#     sub-expressions: 60, 43, 62
# 40. ((b_{1}, ..b_{_a}.., b_{j}) -> {a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k} if Q(b_{1}, ..b_{_a}.., b_{j}).)
#     core type: ExprTuple
#     sub-expressions: 44
# 41. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 81
#     body: 45
# 42. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 81
#     body: 46
# 43. Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j})
#     core type: Operation
#     operator: 47
#     operand: 53
# 44. (b_{1}, ..b_{_a}.., b_{j}) -> {a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k} if Q(b_{1}, ..b_{_a}.., b_{j}).
#     core type: Lambda
#     parameters: 67\n    body: 49
# 45. a_{_a} in Complex
#     core type: Operation
#     operator: 51
#     operands: 50
# 46. c_{_a} in Complex
#     core type: Operation
#     operator: 51
#     operands: 52
# 47. Sum
#     core type: Literal
#     sub-expressions:
# 48. ((b_{1}, ..b_{_a}.., b_{j}) -> {P(b_{1}, ..b_{_a}.., b_{j}) if Q(b_{1}, ..b_{_a}.., b_{j}).)
#     core type: ExprTuple
#     sub-expressions: 53
# 49. {a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k} if Q(b_{1}, ..b_{_a}.., b_{j}).
#     core type: Conditional
#     value: 54
#     condition: 59
# 50. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 70, 55
# 51. in
#     core type: Literal
#     sub-expressions:
# 52. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 72, 55
# 53. (b_{1}, ..b_{_a}.., b_{j}) -> {P(b_{1}, ..b_{_a}.., b_{j}) if Q(b_{1}, ..b_{_a}.., b_{j}).
#     core type: Lambda
#     parameters: 67\n    body: 56
# 54. a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}
#     core type: Operation
#     operator: 57
#     operands: 58
# 55. Complex
#     core type: Literal
#     sub-expressions:
# 56. {P(b_{1}, ..b_{_a}.., b_{j}) if Q(b_{1}, ..b_{_a}.., b_{j}).
#     core type: Conditional
#     value: 61
#     condition: 59
# 57. *
#     core type: Literal
#     sub-expressions:
# 58. (a_{1}, ..a_{_a}.., a_{i}, P(b_{1}, ..b_{_a}.., b_{j}), c_{1}, ..c_{_a}.., c_{k})
#     core type: ExprTuple
#     sub-expressions: 60, 61, 62
# 59. Q(b_{1}, ..b_{_a}.., b_{j})
#     core type: Operation
#     operator: 63
#     operands: 67
# 60. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 64
#     start_index: 75
#     end_index: 65
# 61. P(b_{1}, ..b_{_a}.., b_{j})
#     core type: Operation
#     operator: 66
#     operands: 67
# 62. c_{1}, ..c_{_a}.., c_{k}
#     core type: ExprRange
#     lambda_map: 68
#     start_index: 75
#     end_index: 69
# 63. Q
#     core type: Variable
#     sub-expressions:
# 64. _a -> a_{_a}
#     core type: Lambda
#     parameter: 81
#     body: 70
# 65. i
#     core type: Variable
#     sub-expressions:
# 66. P
#     core type: Variable
#     sub-expressions:
# 67. (b_{1}, ..b_{_a}.., b_{j})
#     core type: ExprTuple
#     sub-expressions: 71
# 68. _a -> c_{_a}
#     core type: Lambda
#     parameter: 81
#     body: 72
# 69. k
#     core type: Variable
#     sub-expressions:
# 70. a_{_a}
#     core type: IndexedVar
# variable: 73
# index: 81
# 71. b_{1}, ..b_{_a}.., b_{j}
#     core type: ExprRange
#     lambda_map: 74
#     start_index: 75
#     end_index: 76
# 72. c_{_a}
#     core type: IndexedVar
# variable: 77
# index: 81
# 73. a
#     core type: Variable
#     sub-expressions:
# 74. _a -> b_{_a}
#     core type: Lambda
#     parameter: 81
#     body: 78
# 75. 1
#     core type: Literal
#     sub-expressions:
# 76. j
#     core type: Variable
#     sub-expressions:
# 77. c
#     core type: Variable
#     sub-expressions:
# 78. b_{_a}
#     core type: IndexedVar
# variable: 79
# index: 81
# 79. b
#     core type: Variable
#     sub-expressions:
# 80. (_a)
#     core type: ExprTuple
#     sub-expressions: 81
# 81. _a
#     core type: Variable
#     sub-expressions:
