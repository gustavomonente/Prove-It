# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b
from proveit.logic import And, InSet
from proveit.numbers import Mult, RealPos

# %%
# build up the expression from sub-expressions
expr = Conditional(InSet(Mult(a, b), RealPos), And(InSet(a, RealPos), InSet(b, RealPos)))
# Out:
# expr: {(a * b) in RealPos if a in RealPos ,  b in RealPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a \cdot b\right) \in \mathbb{R}^+ \textrm{ if } a \in \mathbb{R}^+ ,  b \in \mathbb{R}^+\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(a * b) in RealPos if a in RealPos ,  b in RealPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a * b) in RealPos
#    core type: Operation
#    operator: 12
#    operands: 3
# 2. (a in RealPos) and (b in RealPos)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a * b, RealPos)
#    core type: ExprTuple
#    sub-expressions: 6, 16
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (a in RealPos, b in RealPos)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. a * b
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. a in RealPos
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. b in RealPos
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. *
#    core type: Literal
#    sub-expressions:
# 10. (a, b)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 11. (a, RealPos)
#     core type: ExprTuple
#     sub-expressions: 14, 16
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (b, RealPos)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. b
#     core type: Variable
#     sub-expressions:
# 16. RealPos
#     core type: Literal
#     sub-expressions:
