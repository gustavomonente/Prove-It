# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">numbers</a>.<a class="ProveItLink" href="../../theory.ipynb">rounding</a>.<a class="ProveItLink" href="../../theorems.ipynb#real_minus_floor_interval">real_minus_floor_interval</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, x
from proveit.logic import InSet
from proveit.numbers import Real
from proveit.numbers import zero_in_nats
from proveit.numbers.number_sets.real_numbers import int_within_real
from proveit.numbers.rounding import Floor
from proveit.numbers.rounding import floor_is_an_int, real_minus_floor_lower_bound, real_minus_floor_upper_bound

# %%
# %proving real_minus_floor_interval
# Out:
# real_minus_floor_interval: forall_{x in Real} ((x - floor(x)) in [0,1))

# %%
defaults.assumptions = real_minus_floor_interval.conditions
# Out:
# defaults.assumptions: (x in Real)

# %%
interval = real_minus_floor_interval.instance_expr.operands[1]
# Out:
# interval: [0,1)

# %%
x_minus_floor = real_minus_floor_interval.instance_expr.operands[0]
# Out:
# x_minus_floor: x - floor(x)

# %%
floor_is_an_int.instantiate({x:x})
# Out:
# {x in Real} |- floor(x) in Integer

# %%
int_within_real
# Out:
# |- Integer proper_subset Real

# %%
InSet(Floor(x), Real).prove()
# Out:
# {x in Real} |- floor(x) in Real

# %%
InSet(x_minus_floor, Real).prove()
# Out:
# {x in Real} |- (x - floor(x)) in Real

# %%
real_minus_floor_lower_bound
# Out:
# |- forall_{x in Real} ((x - floor(x)) >= 0)

# %%
real_minus_floor_lower_bound.instantiate({x:x})
# Out:
# {x in Real} |- 0 <= (x - floor(x))

# %%
real_minus_floor_upper_bound
# Out:
# |- forall_{x in Real} ((x - floor(x)) < 1)

# %%
real_minus_floor_upper_bound.instantiate({x:x})
# Out:
# {x in Real} |- (x - floor(x)) < 1

# %%
interval.deduce_elem_in_set(x_minus_floor)
# Out:
# {x in Real} |- (x - floor(x)) in [0,1)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{x in Real} ((x - floor(x)) in [0,1))
# 1	instantiation	2, 3, 4, 5, 6, 7	{x in Real} |- (x - floor(x)) in [0,1)
# 	a : 0, b : 1, x : x - floor(x)
# 2	conjecture		|- forall_{a, b, x in Real | a <= x, x < b} (x in [a,b))
# 3	instantiation	21, 19, 8	|- 0 in Real
# 	A : Rational, B : Real, x : 0
# 4	instantiation	21, 19, 9	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 5	instantiation	10, 25, 11	{x in Real} |- (x - floor(x)) in Real
# 	a : x, b : -floor(x)
# 6	instantiation	12, 25	{x in Real} |- 0 <= (x - floor(x))
# 	x : x
# 7	instantiation	13, 25	{x in Real} |- (x - floor(x)) < 1
# 	x : x
# 8	conjecture		|- 0 in Rational
# 9	instantiation	21, 22, 14	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 10	conjecture		|- forall_{a, b in Real} ((a + b) in Real)
# 11	instantiation	15, 16	{x in Real} |- (-floor(x)) in Real
# 	a : floor(x)
# 12	conjecture		|- forall_{x in Real} ((x - floor(x)) >= 0)
# 13	conjecture		|- forall_{x in Real} ((x - floor(x)) < 1)
# 14	instantiation	21, 17, 18	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 15	conjecture		|- forall_{a in Real} ((-a) in Real)
# 16	instantiation	21, 19, 20	{x in Real} |- floor(x) in Real
# 	A : Rational, B : Real, x : floor(x)
# 17	conjecture		|- Natural proper_subset Integer
# 18	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 19	conjecture		|- Rational proper_subset Real
# 20	instantiation	21, 22, 23	{x in Real} |- floor(x) in Rational
# 	A : Integer, B : Rational, x : floor(x)
# 21	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 22	conjecture		|- Integer proper_subset Rational
# 23	instantiation	24, 25	{x in Real} |- floor(x) in Integer
# 	x : x
# 24	axiom		|- forall_{x in Real} (floor(x) in Integer)
# 	proveit.numbers.rounding.floor_is_an_int
# 25	assumption		{x in Real} |- x in Real
