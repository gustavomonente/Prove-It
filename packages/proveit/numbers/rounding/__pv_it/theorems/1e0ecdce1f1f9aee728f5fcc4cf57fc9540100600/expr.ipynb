# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, n, x
from proveit.logic import Equals, InSet
from proveit.numbers import Add, Floor, Integer

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Equals(Floor(Add(x, n)), Add(Floor(x), n)), InSet(n, Integer)))
# Out:
# expr: n -> {floor(x + n) = (floor(x) + n) if n in Integer.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\lfloor x + n\rfloor = \left(\lfloor x\rfloor + n\right) \textrm{ if } n \in \mathbb{Z}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. n -> {floor(x + n) = (floor(x) + n) if n in Integer.
#    core type: Lambda
#    parameter: 19
#    body: 1
# 1. {floor(x + n) = (floor(x) + n) if n in Integer.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. floor(x + n) = (floor(x) + n)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. n in Integer
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (floor(x + n), floor(x) + n)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (n, Integer)
#    core type: ExprTuple
#    sub-expressions: 19, 10
# 8. floor(x + n)
#    core type: Operation
#    operator: 17
#    operand: 13
# 9. floor(x) + n
#    core type: Operation
#    operator: 15
#    operands: 12
# 10. Integer
#     core type: Literal
#     sub-expressions:
# 11. (x + n)
#     core type: ExprTuple
#     sub-expressions: 13
# 12. (floor(x), n)
#     core type: ExprTuple
#     sub-expressions: 14, 19
# 13. x + n
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. floor(x)
#     core type: Operation
#     operator: 17
#     operand: 20
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (x, n)
#     core type: ExprTuple
#     sub-expressions: 20, 19
# 17. floor
#     core type: Literal
#     sub-expressions:
# 18. (x)
#     core type: ExprTuple
#     sub-expressions: 20
# 19. n
#     core type: Variable
#     sub-expressions:
# 20. x
#     core type: Variable
#     sub-expressions:
