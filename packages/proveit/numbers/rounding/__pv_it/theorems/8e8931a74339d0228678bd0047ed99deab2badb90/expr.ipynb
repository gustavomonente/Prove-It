# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, x
from proveit.logic import InSet
from proveit.numbers import Floor, Natural, RealPos

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(x, Conditional(InSet(Floor(x), Natural), InSet(x, RealPos))))
# Out:
# expr: (x -> {floor(x) in Natural if x in RealPos.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \mapsto \left\{\lfloor x\rfloor \in \mathbb{N} \textrm{ if } x \in \mathbb{R}^+\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x -> {floor(x) in Natural if x in RealPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. x -> {floor(x) in Natural if x in RealPos.
#    core type: Lambda
#    parameter: 13
#    body: 2
# 2. {floor(x) in Natural if x in RealPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. floor(x) in Natural
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. x in RealPos
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (floor(x), Natural)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (x, RealPos)
#    core type: ExprTuple
#    sub-expressions: 13, 10
# 8. floor(x)
#    core type: Operation
#    operator: 11
#    operand: 13
# 9. Natural
#    core type: Literal
#    sub-expressions:
# 10. RealPos
#     core type: Literal
#     sub-expressions:
# 11. floor
#     core type: Literal
#     sub-expressions:
# 12. (x)
#     core type: ExprTuple
#     sub-expressions: 13
# 13. x
#     core type: Variable
#     sub-expressions:
