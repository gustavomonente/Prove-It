# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#round_of_round">round_of_round</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.rounding import round_of_round

# %%
# check that the built expression is the same as the stored expression
assert round_of_round.expr == stored_expr
assert round_of_round.expr._style_id == stored_expr._style_id
print("Passed sanity check: round_of_round matches stored_expr")
# Out:
# Passed sanity check: round_of_round matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(round_of_round.latex())
# Out:
# \vdash \forall_{x \in \mathbb{R}}~\left(round(round(x)) = round(x)\right)

# %%
round_of_round.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
round_of_round.expr_info()
# Out:
# 0. forall_{x in Real} (round(round(x)) = round(x))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x -> {round(round(x)) = round(x) if x in Real.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. x -> {round(round(x)) = round(x) if x in Real.
#    core type: Lambda
#    parameter: 17
#    body: 4
# 4. {round(round(x)) = round(x) if x in Real.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. round(round(x)) = round(x)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. x in Real
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (round(round(x)), round(x))
#    core type: ExprTuple
#    sub-expressions: 11, 14
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (x, Real)
#     core type: ExprTuple
#     sub-expressions: 17, 12
# 11. round(round(x))
#     core type: Operation
#     operator: 15
# ...
