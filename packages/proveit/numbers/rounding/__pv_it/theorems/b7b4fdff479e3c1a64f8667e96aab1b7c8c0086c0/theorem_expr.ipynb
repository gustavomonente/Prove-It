# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#floor_of_real_plus_int">floor_of_real_plus_int</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.rounding import floor_of_real_plus_int

# %%
# check that the built expression is the same as the stored expression
assert floor_of_real_plus_int.expr == stored_expr
assert floor_of_real_plus_int.expr._style_id == stored_expr._style_id
print("Passed sanity check: floor_of_real_plus_int matches stored_expr")
# Out:
# Passed sanity check: floor_of_real_plus_int matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(floor_of_real_plus_int.latex())
# Out:
# \vdash \forall_{x \in \mathbb{R}}~\left[\forall_{n \in \mathbb{Z}}~\left(\lfloor x + n\rfloor = \left(\lfloor x\rfloor + n\right)\right)\right]

# %%
floor_of_real_plus_int.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
floor_of_real_plus_int.expr_info()
# Out:
# 0. forall_{x in Real} [forall_{n in Integer} (floor(x + n) = (floor(x) + n))]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (x -> {forall_{n in Integer} (floor(x + n) = (floor(x) + n)) if x in Real.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. x -> {forall_{n in Integer} (floor(x + n) = (floor(x) + n)) if x in Real.
#    core type: Lambda
#    parameter: 30
#    body: 3
# 3. {forall_{n in Integer} (floor(x + n) = (floor(x) + n)) if x in Real.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{n in Integer} (floor(x + n) = (floor(x) + n))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. x in Real
#    core type: Operation
#    operator: 16
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (n -> {floor(x + n) = (floor(x) + n) if n in Integer.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (x, Real)
#    core type: ExprTuple
#    sub-expressions: 30, 10
# ...
