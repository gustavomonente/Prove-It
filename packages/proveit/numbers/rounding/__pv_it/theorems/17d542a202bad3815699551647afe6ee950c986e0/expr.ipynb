# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, x
from proveit.logic import Equals, InSet
from proveit.numbers import Ceil, Floor, Real

# %%
# build up the expression from sub-expressions
sub_expr1 = Floor(x)
expr = Conditional(Equals(Ceil(sub_expr1), sub_expr1), InSet(x, Real))
# Out:
# expr: {ceil(floor(x)) = floor(x) if x in Real.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\lceil \lfloor x\rfloor\rceil = \lfloor x\rfloor \textrm{ if } x \in \mathbb{R}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {ceil(floor(x)) = floor(x) if x in Real.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. ceil(floor(x)) = floor(x)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. x in Real
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (ceil(floor(x)), floor(x))
#    core type: ExprTuple
#    sub-expressions: 7, 11
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (x, Real)
#    core type: ExprTuple
#    sub-expressions: 14, 8
# 7. ceil(floor(x))
#    core type: Operation
#    operator: 9
#    operand: 11
# 8. Real
#    core type: Literal
#    sub-expressions:
# 9. ceil
#    core type: Literal
#    sub-expressions:
# 10. (floor(x))
#     core type: ExprTuple
#     sub-expressions: 11
# 11. floor(x)
#     core type: Operation
#     operator: 12
#     operand: 14
# 12. floor
#     core type: Literal
#     sub-expressions:
# 13. (x)
#     core type: ExprTuple
#     sub-expressions: 14
# 14. x
#     core type: Variable
#     sub-expressions:
