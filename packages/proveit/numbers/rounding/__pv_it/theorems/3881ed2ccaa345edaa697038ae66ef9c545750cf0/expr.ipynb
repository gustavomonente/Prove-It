# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, x
from proveit.logic import InSet
from proveit.numbers import Add, Floor, IntervalCO, Neg, Real, one, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(x, Conditional(InSet(Add(x, Neg(Floor(x))), IntervalCO(zero, one)), InSet(x, Real))))
# Out:
# expr: (x -> {(x - floor(x)) in [0,1) if x in Real.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \mapsto \left\{\left(x - \lfloor x\rfloor\right) \in \left[0,1\right) \textrm{ if } x \in \mathbb{R}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x -> {(x - floor(x)) in [0,1) if x in Real.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. x -> {(x - floor(x)) in [0,1) if x in Real.
#    core type: Lambda
#    parameter: 23
#    body: 2
# 2. {(x - floor(x)) in [0,1) if x in Real.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (x - floor(x)) in [0,1)
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. x in Real
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (x - floor(x), [0,1))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (x, Real)
#    core type: ExprTuple
#    sub-expressions: 23, 10
# 8. x - floor(x)
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. [0,1)
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. Real
#     core type: Literal
#     sub-expressions:
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (x, -floor(x))
#     core type: ExprTuple
#     sub-expressions: 23, 15
# 13. IntervalCO
#     core type: Literal
#     sub-expressions:
# 14. (0, 1)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. -floor(x)
#     core type: Operation
#     operator: 18
#     operand: 20
# 16. 0
#     core type: Literal
#     sub-expressions:
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. -
#     core type: Literal
#     sub-expressions:
# 19. (floor(x))
#     core type: ExprTuple
#     sub-expressions: 20
# 20. floor(x)
#     core type: Operation
#     operator: 21
#     operand: 23
# 21. floor
#     core type: Literal
#     sub-expressions:
# 22. (x)
#     core type: ExprTuple
#     sub-expressions: 23
# 23. x
#     core type: Variable
#     sub-expressions:
