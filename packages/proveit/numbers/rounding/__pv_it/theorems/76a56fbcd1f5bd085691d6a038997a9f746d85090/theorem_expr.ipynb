# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#floor_of_real_is_real">floor_of_real_is_real</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.rounding import floor_of_real_is_real

# %%
# check that the built expression is the same as the stored expression
assert floor_of_real_is_real.expr == stored_expr
assert floor_of_real_is_real.expr._style_id == stored_expr._style_id
print("Passed sanity check: floor_of_real_is_real matches stored_expr")
# Out:
# Passed sanity check: floor_of_real_is_real matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(floor_of_real_is_real.latex())
# Out:
# \vdash \forall_{x \in \mathbb{R}}~\left(\lfloor x\rfloor \in \mathbb{R}\right)

# %%
floor_of_real_is_real.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
floor_of_real_is_real.expr_info()
# Out:
# 0. forall_{x in Real} (floor(x) in Real)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x -> {floor(x) in Real if x in Real.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. x -> {floor(x) in Real if x in Real.
#    core type: Lambda
#    parameter: 14
#    body: 4
# 4. {floor(x) in Real if x in Real.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. floor(x) in Real
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. x in Real
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (floor(x), Real)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (x, Real)
#    core type: ExprTuple
#    sub-expressions: 14, 11
# 10. floor(x)
#     core type: Operation
#     operator: 12
#     operand: 14
# 11. Real
#     core type: Literal
#     sub-expressions:
# 12. floor
#     core type: Literal
# ...
