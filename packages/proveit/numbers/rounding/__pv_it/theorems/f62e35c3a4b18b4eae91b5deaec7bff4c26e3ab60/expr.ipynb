# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, x
from proveit.logic import InSet
from proveit.numbers import Add, Floor, Less, Neg, Real, one

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Conditional(Less(Add(x, Neg(Floor(x))), one), InSet(x, Real)))
# Out:
# expr: x -> {(x - floor(x)) < 1 if x in Real.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# x \mapsto \left\{\left(x - \lfloor x\rfloor\right) < 1 \textrm{ if } x \in \mathbb{R}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. x -> {(x - floor(x)) < 1 if x in Real.
#    core type: Lambda
#    parameter: 19
#    body: 1
# 1. {(x - floor(x)) < 1 if x in Real.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (x - floor(x)) < 1
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. x in Real
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. <
#    core type: Literal
#    sub-expressions:
# 5. (x - floor(x), 1)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (x, Real)
#    core type: ExprTuple
#    sub-expressions: 19, 10
# 8. x - floor(x)
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. Real
#     core type: Literal
#     sub-expressions:
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (x, -floor(x))
#     core type: ExprTuple
#     sub-expressions: 19, 13
# 13. -floor(x)
#     core type: Operation
#     operator: 14
#     operand: 16
# 14. -
#     core type: Literal
#     sub-expressions:
# 15. (floor(x))
#     core type: ExprTuple
#     sub-expressions: 16
# 16. floor(x)
#     core type: Operation
#     operator: 17
#     operand: 19
# 17. floor
#     core type: Literal
#     sub-expressions:
# 18. (x)
#     core type: ExprTuple
#     sub-expressions: 19
# 19. x
#     core type: Variable
#     sub-expressions:
