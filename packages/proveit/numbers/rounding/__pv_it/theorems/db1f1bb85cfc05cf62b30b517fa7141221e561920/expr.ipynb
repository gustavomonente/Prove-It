# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, x
from proveit.logic import InSet
from proveit.numbers import Add, Floor, Neg, Real, greater_eq, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(greater_eq(Add(x, Neg(Floor(x))), zero), InSet(x, Real))
# Out:
# expr: {(x - floor(x)) >= 0 if x in Real.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(x - \lfloor x\rfloor\right) \geq 0 \textrm{ if } x \in \mathbb{R}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(x - floor(x)) >= 0 if x in Real.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (x - floor(x)) >= 0
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. x in Real
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. <=
#    core type: Literal
#    sub-expressions:
# 4. (0, x - floor(x))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (x, Real)
#    core type: ExprTuple
#    sub-expressions: 18, 9
# 7. 0
#    core type: Literal
#    sub-expressions:
# 8. x - floor(x)
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. Real
#    core type: Literal
#    sub-expressions:
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (x, -floor(x))
#     core type: ExprTuple
#     sub-expressions: 18, 12
# 12. -floor(x)
#     core type: Operation
#     operator: 13
#     operand: 15
# 13. -
#     core type: Literal
#     sub-expressions:
# 14. (floor(x))
#     core type: ExprTuple
#     sub-expressions: 15
# 15. floor(x)
#     core type: Operation
#     operator: 16
#     operand: 18
# 16. floor
#     core type: Literal
#     sub-expressions:
# 17. (x)
#     core type: ExprTuple
#     sub-expressions: 18
# 18. x
#     core type: Variable
#     sub-expressions:
