# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, x
from proveit.logic import Equals, InSet
from proveit.numbers import Floor, Integer

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Conditional(Equals(Floor(x), x), InSet(x, Integer)))
# Out:
# expr: x -> {floor(x) = x if x in Integer.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# x \mapsto \left\{\lfloor x\rfloor = x \textrm{ if } x \in \mathbb{Z}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. x -> {floor(x) = x if x in Integer.
#    core type: Lambda
#    parameter: 12
#    body: 1
# 1. {floor(x) = x if x in Integer.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. floor(x) = x
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. x in Integer
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (floor(x), x)
#    core type: ExprTuple
#    sub-expressions: 8, 12
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (x, Integer)
#    core type: ExprTuple
#    sub-expressions: 12, 9
# 8. floor(x)
#    core type: Operation
#    operator: 10
#    operand: 12
# 9. Integer
#    core type: Literal
#    sub-expressions:
# 10. floor
#     core type: Literal
#     sub-expressions:
# 11. (x)
#     core type: ExprTuple
#     sub-expressions: 12
# 12. x
#     core type: Variable
#     sub-expressions:
