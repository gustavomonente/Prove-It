# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import x
from proveit.logic import Forall
from proveit.numbers import Ceil, Floor, LessEq, Real

# %%
# build up the expression from sub-expressions
expr = Forall([x], LessEq(Floor(x), Ceil(x)), domains = [Real])
# Out:
# expr: forall_{x in Real} (floor(x) <= ceil(x))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x \in \mathbb{R}}~\left(\lfloor x\rfloor \leq \lceil x\rceil\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{x in Real} (floor(x) <= ceil(x))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x -> {floor(x) <= ceil(x) if x in Real.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. x -> {floor(x) <= ceil(x) if x in Real.
#    core type: Lambda
#    parameter: 17
#    body: 4
# 4. {floor(x) <= ceil(x) if x in Real.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. floor(x) <= ceil(x)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. x in Real
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. <=
#    core type: Literal
#    sub-expressions:
# 8. (floor(x), ceil(x))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (x, Real)
#     core type: ExprTuple
#     sub-expressions: 17, 13
# 11. floor(x)
#     core type: Operation
#     operator: 14
#     operand: 17
# 12. ceil(x)
#     core type: Operation
#     operator: 15
#     operand: 17
# 13. Real
#     core type: Literal
#     sub-expressions:
# 14. floor
#     core type: Literal
#     sub-expressions:
# 15. ceil
#     core type: Literal
#     sub-expressions:
# 16. (x)
#     core type: ExprTuple
#     sub-expressions: 17
# 17. x
#     core type: Variable
#     sub-expressions:
