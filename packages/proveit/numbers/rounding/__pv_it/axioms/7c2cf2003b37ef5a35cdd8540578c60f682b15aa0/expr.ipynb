# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import x, y
from proveit.logic import Forall
from proveit.numbers import Abs, Add, Integer, LessEq, Neg, Real, Round

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(x)
expr = Forall([x, y], LessEq(Abs(Add(Round(x), sub_expr1)), Abs(Add(y, sub_expr1))), domains = [Real, Integer])
# Out:
# expr: forall_{x in Real, y in Integer} (|round(x) - x| <= |y - x|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x \in \mathbb{R}, y \in \mathbb{Z}}~\left(\left|round(x) - x\right| \leq \left|y - x\right|\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{x in Real, y in Integer} (|round(x) - x| <= |y - x|)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((x, y) -> {|round(x) - x| <= |y - x| if x in Real ,  y in Integer.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (x, y) -> {|round(x) - x| <= |y - x| if x in Real ,  y in Integer.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (x, y)
#    core type: ExprTuple
#    sub-expressions: 35, 30
# 5. {|round(x) - x| <= |y - x| if x in Real ,  y in Integer.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. |round(x) - x| <= |y - x|
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (x in Real) and (y in Integer)
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. <=
#    core type: Literal
#    sub-expressions:
# 9. (|round(x) - x|, |y - x|)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (x in Real, y in Integer)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. |round(x) - x|
#     core type: Operation
#     operator: 17
#     operand: 22
# 13. |y - x|
#     core type: Operation
#     operator: 17
#     operand: 23
# 14. x in Real
#     core type: Operation
#     operator: 20
#     operands: 19
# 15. y in Integer
#     core type: Operation
#     operator: 20
#     operands: 21
# 16. (round(x) - x)
#     core type: ExprTuple
#     sub-expressions: 22
# 17. Abs
#     core type: Literal
#     sub-expressions:
# 18. (y - x)
#     core type: ExprTuple
#     sub-expressions: 23
# 19. (x, Real)
#     core type: ExprTuple
#     sub-expressions: 35, 24
# 20. in
#     core type: Literal
#     sub-expressions:
# 21. (y, Integer)
#     core type: ExprTuple
#     sub-expressions: 30, 25
# 22. round(x) - x
#     core type: Operation
#     operator: 27
#     operands: 26
# 23. y - x
#     core type: Operation
#     operator: 27
#     operands: 28
# 24. Real
#     core type: Literal
#     sub-expressions:
# 25. Integer
#     core type: Literal
#     sub-expressions:
# 26. (round(x), -x)
#     core type: ExprTuple
#     sub-expressions: 29, 31
# 27. +
#     core type: Literal
#     sub-expressions:
# 28. (y, -x)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 29. round(x)
#     core type: Operation
#     operator: 32
#     operand: 35
# 30. y
#     core type: Variable
#     sub-expressions:
# 31. -x
#     core type: Operation
#     operator: 33
#     operand: 35
# 32. round
#     core type: Literal
#     sub-expressions:
# 33. -
#     core type: Literal
#     sub-expressions:
# 34. (x)
#     core type: ExprTuple
#     sub-expressions: 35
# 35. x
#     core type: Variable
#     sub-expressions:
