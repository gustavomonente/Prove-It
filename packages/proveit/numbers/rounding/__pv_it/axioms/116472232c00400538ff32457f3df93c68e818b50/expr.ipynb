# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, x, y
from proveit.logic import And, InSet
from proveit.numbers import Ceil, Integer, LessEq, Real, greater_eq

# %%
# build up the expression from sub-expressions
expr = Lambda([x, y], Conditional(LessEq(Ceil(x), y), And(InSet(x, Real), InSet(y, Integer), greater_eq(y, x))))
# Out:
# expr: (x, y) -> {ceil(x) <= y if x in Real ,  y in Integer ,  y >= x.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x, y\right) \mapsto \left\{\lceil x\rceil \leq y \textrm{ if } x \in \mathbb{R} ,  y \in \mathbb{Z} ,  y \geq x\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x, y) -> {ceil(x) <= y if x in Real ,  y in Integer ,  y >= x.
#    core type: Lambda
#    parameters: 17\n   body: 1
# 1. {ceil(x) <= y if x in Real ,  y in Integer ,  y >= x.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. ceil(x) <= y
#    core type: Operation
#    operator: 16
#    operands: 4
# 3. (x in Real) and (y in Integer) and (y >= x)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (ceil(x), y)
#    core type: ExprTuple
#    sub-expressions: 7, 21
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (x in Real, y in Integer, y >= x)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 7. ceil(x)
#    core type: Operation
#    operator: 11
#    operand: 20
# 8. x in Real
#    core type: Operation
#    operator: 14
#    operands: 13
# 9. y in Integer
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. y >= x
#     core type: Operation
#     operator: 16
#     operands: 17
# 11. ceil
#     core type: Literal
#     sub-expressions:
# 12. (x)
#     core type: ExprTuple
#     sub-expressions: 20
# 13. (x, Real)
#     core type: ExprTuple
#     sub-expressions: 20, 18
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (y, Integer)
#     core type: ExprTuple
#     sub-expressions: 21, 19
# 16. <=
#     core type: Literal
#     sub-expressions:
# 17. (x, y)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. Real
#     core type: Literal
#     sub-expressions:
# 19. Integer
#     core type: Literal
#     sub-expressions:
# 20. x
#     core type: Variable
#     sub-expressions:
# 21. y
#     core type: Variable
#     sub-expressions:
