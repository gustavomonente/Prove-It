# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, x
from proveit.logic import InSet
from proveit.numbers import Integer, Real, Round

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(x, Conditional(InSet(Round(x), Integer), InSet(x, Real))))
# Out:
# expr: (x -> {round(x) in Integer if x in Real.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \mapsto \left\{round(x) \in \mathbb{Z} \textrm{ if } x \in \mathbb{R}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x -> {round(x) in Integer if x in Real.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. x -> {round(x) in Integer if x in Real.
#    core type: Lambda
#    parameter: 13
#    body: 2
# 2. {round(x) in Integer if x in Real.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. round(x) in Integer
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. x in Real
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (round(x), Integer)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (x, Real)
#    core type: ExprTuple
#    sub-expressions: 13, 10
# 8. round(x)
#    core type: Operation
#    operator: 11
#    operand: 13
# 9. Integer
#    core type: Literal
#    sub-expressions:
# 10. Real
#     core type: Literal
#     sub-expressions:
# 11. round
#     core type: Literal
#     sub-expressions:
# 12. (x)
#     core type: ExprTuple
#     sub-expressions: 13
# 13. x
#     core type: Variable
#     sub-expressions:
