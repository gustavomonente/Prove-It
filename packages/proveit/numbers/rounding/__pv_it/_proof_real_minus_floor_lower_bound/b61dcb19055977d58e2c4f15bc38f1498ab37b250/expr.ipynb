# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.numbers.LessEq.html">LessEq</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import x
from proveit.numbers import Add, Floor, Neg, greater_eq

# %%
# build up the expression from sub-expressions
sub_expr1 = Floor(x)
sub_expr2 = Neg(sub_expr1)
expr = greater_eq(Add(x, sub_expr2), Add(sub_expr1, sub_expr2))
# Out:
# expr: (x - floor(x)) >= (floor(x) - floor(x))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x - \lfloor x\rfloor\right) \geq \left(\lfloor x\rfloor - \lfloor x\rfloor\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: reversed
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x - floor(x)) >= (floor(x) - floor(x))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. <=
#    core type: Literal
#    sub-expressions:
# 2. (floor(x) - floor(x), x - floor(x))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. floor(x) - floor(x)
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. x - floor(x)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (floor(x), -floor(x))
#    core type: ExprTuple
#    sub-expressions: 11, 8
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (x, -floor(x))
#    core type: ExprTuple
#    sub-expressions: 14, 8
# 8. -floor(x)
#    core type: Operation
#    operator: 9
#    operand: 11
# 9. -
#    core type: Literal
#    sub-expressions:
# 10. (floor(x))
#     core type: ExprTuple
#     sub-expressions: 11
# 11. floor(x)
#     core type: Operation
#     operator: 12
#     operand: 14
# 12. floor
#     core type: Literal
#     sub-expressions:
# 13. (x)
#     core type: ExprTuple
#     sub-expressions: 14
# 14. x
#     core type: Variable
#     sub-expressions:
