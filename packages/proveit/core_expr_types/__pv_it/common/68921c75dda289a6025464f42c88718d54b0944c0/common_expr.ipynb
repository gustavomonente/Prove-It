# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#f_jp1">f_jp1</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Function.html">Function</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types import f_jp1

# %%
# check that the built expression is the same as the stored expression
assert f_jp1 == stored_expr
assert f_jp1._style_id == stored_expr._style_id
print("Passed sanity check: f_jp1 matches stored_expr")
# Out:
# Passed sanity check: f_jp1 matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(f_jp1.latex())
# Out:
# f(j + 1)

# %%
f_jp1.style_options()
# Out:
# no style options

# %%
# display the expression information
f_jp1.expr_info()
# Out:
# 0. f(j + 1)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. f
#    core type: Variable
#    sub-expressions:
# 2. (j + 1)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. j + 1
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (j, 1)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. j
#    core type: Variable
#    sub-expressions:
# 7. 1
#    core type: Literal
#    sub-expressions:
