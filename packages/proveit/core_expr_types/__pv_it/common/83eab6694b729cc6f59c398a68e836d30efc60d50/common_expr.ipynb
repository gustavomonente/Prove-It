# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#Pk_1_to_n">Pk_1_to_n</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types import Pk_1_to_n

# %%
# check that the built expression is the same as the stored expression
assert Pk_1_to_n == stored_expr
assert Pk_1_to_n._style_id == stored_expr._style_id
print("Passed sanity check: Pk_1_to_n matches stored_expr")
# Out:
# Passed sanity check: Pk_1_to_n matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(Pk_1_to_n.latex())
# Out:
# P(1), \ldots, P(n)

# %%
Pk_1_to_n.style_options()
# Out:
# style name: parameterization
# description: 'implicit' (default for LaTeX formatting) hides the parameter the ExprRange so the parameterization may be ambiguous (e.g., x_{1+1}, ..., x_{n+1}); 'explicit' (default for string formatting) reveals the parameterization (e.g. x_{1+1}, ..x_{k+1}.., x_{n+1}).
# default: None
# current value: None/False
# related methods: ('with_explicit_parameterization', 'with_implicit_parameterization', 'with_default_parameterization_style')

# %%
# display the expression information
Pk_1_to_n.expr_info()
# Out:
# 0. P(1), ..P(k).., P(n)
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. k -> P(k)
#    core type: Lambda
#    parameter: 7
#    body: 4
# 2. 1
#    core type: Literal
#    sub-expressions:
# 3. n
#    core type: Variable
#    sub-expressions:
# 4. P(k)
#    core type: Operation
#    operator: 5
#    operand: 7
# 5. P
#    core type: Variable
#    sub-expressions:
# 6. (k)
#    core type: ExprTuple
#    sub-expressions: 7
# 7. k
#    core type: Variable
#    sub-expressions:
