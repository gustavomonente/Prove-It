# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#merge_back_equiv">merge_back_equiv</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types import merge_back_equiv

# %%
# check that the built expression is the same as the stored expression
assert merge_back_equiv == stored_expr
assert merge_back_equiv._style_id == stored_expr._style_id
print("Passed sanity check: merge_back_equiv matches stored_expr")
# Out:
# Passed sanity check: merge_back_equiv matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(merge_back_equiv.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \left(f(i), \ldots, f(j), f(k)\right) =  \\ \left(f(i), \ldots, f(k)\right) \end{array} \end{array}

# %%
merge_back_equiv.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
merge_back_equiv.expr_info()
# Out:
# 0. (f(i), ..f(a).., f(j), f(k)) =  \\ (f(i), ..f(a).., f(k))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((f(i), ..f(a).., f(j), f(k)), (f(i), ..f(a).., f(k)))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (f(i), ..f(a).., f(j), f(k))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. (f(i), ..f(a).., f(k))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. f(i), ..f(a).., f(j)
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 11
#    end_index: 8
# 6. f(k)
#    core type: Operation
#    operator: 14
#    operand: 12
# 7. f(i), ..f(a).., f(k)
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 11
#    end_index: 12
# 8. j
#    core type: Variable
#    sub-expressions:
# 9. (k)
#    core type: ExprTuple
#    sub-expressions: 12
# 10. a -> f(a)
#     core type: Lambda
#     parameter: 16
#     body: 13
# 11. i
#     core type: Variable
#     sub-expressions:
# ...
