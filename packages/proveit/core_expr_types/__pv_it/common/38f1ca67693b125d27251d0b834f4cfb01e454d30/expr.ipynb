# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, a, fa, i, j, k
from proveit.core_expr_types import Len
from proveit.logic import Equals
from proveit.numbers import Add, Neg, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Equals(Len([ExprRange(sub_expr1, IndexedVar(a, sub_expr1), one, i), ExprRange(a, fa, j, k)]), Add(i, k, Neg(j), one)).with_wrapping_at(2)
# Out:
# expr: |(a_{1}, ..a_{_a}.., a_{i}, f(j), ..f(a).., f(k))| =  \\ (i + k - j + 1)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} |\left(a_{1}, \ldots, a_{i}, f(j), \ldots, f(k)\right)| =  \\ \left(i + k - j + 1\right) \end{array} \end{array}

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |(a_{1}, ..a_{_a}.., a_{i}, f(j), ..f(a).., f(k))| =  \\ (i + k - j + 1)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|(a_{1}, ..a_{_a}.., a_{i}, f(j), ..f(a).., f(k))|, i + k - j + 1)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |(a_{1}, ..a_{_a}.., a_{i}, f(j), ..f(a).., f(k))|
#    core type: Operation
#    operator: 5
#    operand: 9
# 4. i + k - j + 1
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. length
#    core type: Literal
#    sub-expressions:
# 6. ((a_{1}, ..a_{_a}.., a_{i}, f(j), ..f(a).., f(k)))
#    core type: ExprTuple
#    sub-expressions: 9
# 7. +
#    core type: Literal
#    sub-expressions:
# 8. (i, k, -j, 1)
#    core type: ExprTuple
#    sub-expressions: 17, 19, 10, 16
# 9. (a_{1}, ..a_{_a}.., a_{i}, f(j), ..f(a).., f(k))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. -j
#     core type: Operation
#     operator: 13
#     operand: 20
# 11. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 16
#     end_index: 17
# 12. f(j), ..f(a).., f(k)
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 20
#     end_index: 19
# 13. -
#     core type: Literal
#     sub-expressions:
# 14. (j)
#     core type: ExprTuple
#     sub-expressions: 20
# 15. _a -> a_{_a}
#     core type: Lambda
#     parameter: 26
#     body: 21
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. i
#     core type: Variable
#     sub-expressions:
# 18. a -> f(a)
#     core type: Lambda
#     parameter: 27
#     body: 22
# 19. k
#     core type: Variable
#     sub-expressions:
# 20. j
#     core type: Variable
#     sub-expressions:
# 21. a_{_a}
#     core type: IndexedVar
# variable: 27
# index: 26
# 22. f(a)
#     core type: Operation
#     operator: 24
#     operand: 27
# 23. (_a)
#     core type: ExprTuple
#     sub-expressions: 26
# 24. f
#     core type: Variable
#     sub-expressions:
# 25. (a)
#     core type: ExprTuple
#     sub-expressions: 27
# 26. _a
#     core type: Variable
#     sub-expressions:
# 27. a
#     core type: Variable
#     sub-expressions:
