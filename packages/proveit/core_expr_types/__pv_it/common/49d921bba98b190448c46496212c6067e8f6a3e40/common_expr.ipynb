# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#Q__x_1_to_n">Q__x_1_to_n</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Function.html">Function</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types import Q__x_1_to_n

# %%
# check that the built expression is the same as the stored expression
assert Q__x_1_to_n == stored_expr
assert Q__x_1_to_n._style_id == stored_expr._style_id
print("Passed sanity check: Q__x_1_to_n matches stored_expr")
# Out:
# Passed sanity check: Q__x_1_to_n matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(Q__x_1_to_n.latex())
# Out:
# Q(x_{1}, \ldots, x_{n})

# %%
Q__x_1_to_n.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
Q__x_1_to_n.expr_info()
# Out:
# 0. Q(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Q
#    core type: Variable
#    sub-expressions:
# 2. (x_{1}, ..x_{_a}.., x_{n})
#    core type: ExprTuple
#    sub-expressions: 3
# 3. x_{1}, ..x_{_a}.., x_{n}
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 5
#    end_index: 6
# 4. _a -> x_{_a}
#    core type: Lambda
#    parameter: 10
#    body: 7
# 5. 1
#    core type: Literal
#    sub-expressions:
# 6. n
#    core type: Variable
#    sub-expressions:
# 7. x_{_a}
#    core type: IndexedVar
# variable: 8
# index: 10
# 8. x
#    core type: Variable
#    sub-expressions:
# 9. (_a)
#    core type: ExprTuple
#    sub-expressions: 10
# 10. _a
#     core type: Variable
#     sub-expressions:
