# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#f_i_to_j">f_i_to_j</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types import f_i_to_j

# %%
# check that the built expression is the same as the stored expression
assert f_i_to_j == stored_expr
assert f_i_to_j._style_id == stored_expr._style_id
print("Passed sanity check: f_i_to_j matches stored_expr")
# Out:
# Passed sanity check: f_i_to_j matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(f_i_to_j.latex())
# Out:
# f(i), \ldots, f(j)

# %%
f_i_to_j.style_options()
# Out:
# style name: parameterization
# description: 'implicit' (default for LaTeX formatting) hides the parameter the ExprRange so the parameterization may be ambiguous (e.g., x_{1+1}, ..., x_{n+1}); 'explicit' (default for string formatting) reveals the parameterization (e.g. x_{1+1}, ..x_{k+1}.., x_{n+1}).
# default: None
# current value: None/False
# related methods: ('with_explicit_parameterization', 'with_implicit_parameterization', 'with_default_parameterization_style')

# %%
# display the expression information
f_i_to_j.expr_info()
# Out:
# 0. f(i), ..f(a).., f(j)
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. a -> f(a)
#    core type: Lambda
#    parameter: 7
#    body: 4
# 2. i
#    core type: Variable
#    sub-expressions:
# 3. j
#    core type: Variable
#    sub-expressions:
# 4. f(a)
#    core type: Operation
#    operator: 5
#    operand: 7
# 5. f
#    core type: Variable
#    sub-expressions:
# 6. (a)
#    core type: ExprTuple
#    sub-expressions: 7
# 7. a
#    core type: Variable
#    sub-expressions:
