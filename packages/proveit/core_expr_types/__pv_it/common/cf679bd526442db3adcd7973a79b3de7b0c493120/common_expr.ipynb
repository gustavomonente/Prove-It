# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#x_1_to_np1">x_1_to_np1</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types import x_1_to_np1

# %%
# check that the built expression is the same as the stored expression
assert x_1_to_np1 == stored_expr
assert x_1_to_np1._style_id == stored_expr._style_id
print("Passed sanity check: x_1_to_np1 matches stored_expr")
# Out:
# Passed sanity check: x_1_to_np1 matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(x_1_to_np1.latex())
# Out:
# x_{1}, \ldots, x_{n + 1}

# %%
x_1_to_np1.style_options()
# Out:
# style name: parameterization
# description: 'implicit' (default for LaTeX formatting) hides the parameter the ExprRange so the parameterization may be ambiguous (e.g., x_{1+1}, ..., x_{n+1}); 'explicit' (default for string formatting) reveals the parameterization (e.g. x_{1+1}, ..x_{k+1}.., x_{n+1}).
# default: None
# current value: None/False
# related methods: ('with_explicit_parameterization', 'with_implicit_parameterization', 'with_default_parameterization_style')

# %%
# display the expression information
x_1_to_np1.expr_info()
# Out:
# 0. x_{1}, ..x_{_a}.., x_{n + 1}
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 9
#    end_index: 2
# 1. _a -> x_{_a}
#    core type: Lambda
#    parameter: 10
#    body: 3
# 2. n + 1
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. x_{_a}
#    core type: IndexedVar
# variable: 6
# index: 10
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (n, 1)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. x
#    core type: Variable
#    sub-expressions:
# 7. (_a)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. n
#    core type: Variable
#    sub-expressions:
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. _a
#     core type: Variable
#     sub-expressions:
