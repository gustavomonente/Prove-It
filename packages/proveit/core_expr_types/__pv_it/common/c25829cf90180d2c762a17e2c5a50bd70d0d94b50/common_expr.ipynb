# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#c_1_to_n">c_1_to_n</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types import c_1_to_n

# %%
# check that the built expression is the same as the stored expression
assert c_1_to_n == stored_expr
assert c_1_to_n._style_id == stored_expr._style_id
print("Passed sanity check: c_1_to_n matches stored_expr")
# Out:
# Passed sanity check: c_1_to_n matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(c_1_to_n.latex())
# Out:
# c_{1}, \ldots, c_{n}

# %%
c_1_to_n.style_options()
# Out:
# style name: parameterization
# description: 'implicit' (default for LaTeX formatting) hides the parameter the ExprRange so the parameterization may be ambiguous (e.g., x_{1+1}, ..., x_{n+1}); 'explicit' (default for string formatting) reveals the parameterization (e.g. x_{1+1}, ..x_{k+1}.., x_{n+1}).
# default: None
# current value: None/False
# related methods: ('with_explicit_parameterization', 'with_implicit_parameterization', 'with_default_parameterization_style')

# %%
# display the expression information
c_1_to_n.expr_info()
# Out:
# 0. c_{1}, ..c_{_a}.., c_{n}
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. _a -> c_{_a}
#    core type: Lambda
#    parameter: 7
#    body: 4
# 2. 1
#    core type: Literal
#    sub-expressions:
# 3. n
#    core type: Variable
#    sub-expressions:
# 4. c_{_a}
#    core type: IndexedVar
# variable: 5
# index: 7
# 5. c
#    core type: Variable
#    sub-expressions:
# 6. (_a)
#    core type: ExprTuple
#    sub-expressions: 7
# 7. _a
#    core type: Variable
#    sub-expressions:
