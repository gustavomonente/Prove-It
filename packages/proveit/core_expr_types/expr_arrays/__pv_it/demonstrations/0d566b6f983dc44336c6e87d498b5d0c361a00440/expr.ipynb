# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprArray.html">ExprArray</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.expr_arrays</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, D, E, ExprArray, ExprRange, F, IndexedVar, i, j, m
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = [i, j]
expr = ExprArray(ExprRange(i, [IndexedVar(A, sub_expr1), IndexedVar(B, sub_expr1), IndexedVar(C, sub_expr1), IndexedVar(D, sub_expr1), IndexedVar(E, sub_expr1), IndexedVar(F, sub_expr1)], one, m)).with_orientation("vertical").with_implicit_parameterization()
# Out:
# expr: A_{1, j} & \cdots & A_{m, j}  \\
#   B_{1, j} & \cdots & B_{m, j}  \\
#   C_{1, j} & \cdots & C_{m, j}  \\
#   D_{1, j} & \cdots & D_{m, j}  \\
#   E_{1, j} & \cdots & E_{m, j}  \\
#   F_{1, j} & \cdots & F_{m, j}  \\

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array} {ccc}
#  A_{1, j} & \cdots & A_{m, j}  \\
#   B_{1, j} & \cdots & B_{m, j}  \\
#   C_{1, j} & \cdots & C_{m, j}  \\
#   D_{1, j} & \cdots & D_{m, j}  \\
#   E_{1, j} & \cdots & E_{m, j}  \\
#   F_{1, j} & \cdots & F_{m, j}  \\
#   \end{array}

# %%
expr.style_options()
# Out:
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: with_justification
# style name: orientation
# description: to be read from left to right then top to bottom ('horizontal') or to be read top to bottom then left to right ('vertical')
# default: horizontal
# current value: vertical
# related methods: with_orientation
# style name: parameterization
# description: 'implicit' (default for LaTeX formatting) hides the parameter the ExprRange so the parameterization may be ambiguous (e.g., x_{1+1}, ..., x_{n+1}); 'explicit' (default for string formatting) reveals the parameterization (e.g. x_{1+1}, ..x_{k+1}.., x_{n+1}).
# default: None
# current value: implicit
# related methods: ('with_explicit_parameterization', 'with_implicit_parameterization', 'with_default_parameterization_style')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. A_{1, j} & \cdots & A_{m, j}  \\
#   B_{1, j} & \cdots & B_{m, j}  \\
#   C_{1, j} & \cdots & C_{m, j}  \\
#   D_{1, j} & \cdots & D_{m, j}  \\
#   E_{1, j} & \cdots & E_{m, j}  \\
#   F_{1, j} & \cdots & F_{m, j}  \\
#
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (A_{1, j}, B_{1, j}, C_{1, j}, D_{1, j}, E_{1, j}, F_{1, j}), ..(A_{i, j}, B_{i, j}, C_{i, j}, D_{i, j}, E_{i, j}, F_{i, j}).., (A_{m, j}, B_{m, j}, C_{m, j}, D_{m, j}, E_{m, j}, F_{m, j})
#    core type: ExprRange
#    lambda_map: 2
#    start_index: 3
#    end_index: 4
# 2. i -> (A_{i, j}, B_{i, j}, C_{i, j}, D_{i, j}, E_{i, j}, F_{i, j})
#    core type: Lambda
#    parameter: 19
#    body: 5
# 3. 1
#    core type: Literal
#    sub-expressions:
# 4. m
#    core type: Variable
#    sub-expressions:
# 5. (A_{i, j}, B_{i, j}, C_{i, j}, D_{i, j}, E_{i, j}, F_{i, j})
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 9, 10, 11
# 6. A_{i, j}
#    core type: IndexedVar
# variable: 12
# indices: 18
# ...
