# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.expr_arrays</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, ExprRange, ExprTuple, IndexedVar, i, j, n
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(ExprRange(j, IndexedVar(A, [i, j]), one, n).with_explicit_parameterization())
# Out:
# expr: (A_{i, 1}, ..A_{i, j}.., A_{i, n})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{i, 1}, ..A_{i, j}.., A_{i, n}\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A_{i, 1}, ..A_{i, j}.., A_{i, n})
#    core type: ExprTuple
#    sub-expressions: 1
# 1. A_{i, 1}, ..A_{i, j}.., A_{i, n}
#    core type: ExprRange
#    lambda_map: 2
#    start_index: 3
#    end_index: 4
# 2. j -> A_{i, j}
#    core type: Lambda
#    parameter: 9
#    body: 5
# 3. 1
#    core type: Literal
#    sub-expressions:
# 4. n
#    core type: Variable
#    sub-expressions:
# 5. A_{i, j}
#    core type: IndexedVar
# variable: 6
# indices: 7
# 6. A
#    core type: Variable
#    sub-expressions:
# 7. (i, j)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. i
#    core type: Variable
#    sub-expressions:
# 9. j
#    core type: Variable
#    sub-expressions:
