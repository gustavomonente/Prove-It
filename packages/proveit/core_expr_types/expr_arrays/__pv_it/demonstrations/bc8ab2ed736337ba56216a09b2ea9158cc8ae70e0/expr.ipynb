# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.expr_arrays</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, D, E, F, IndexedVar, Lambda, i, j

# %%
# build up the expression from sub-expressions
sub_expr1 = [i, j]
expr = Lambda(i, [IndexedVar(A, sub_expr1), IndexedVar(B, sub_expr1), IndexedVar(C, sub_expr1), IndexedVar(D, sub_expr1), IndexedVar(E, sub_expr1), IndexedVar(F, sub_expr1)])
# Out:
# expr: i -> (A_{i, j}, B_{i, j}, C_{i, j}, D_{i, j}, E_{i, j}, F_{i, j})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# i \mapsto \left(A_{i, j}, B_{i, j}, C_{i, j}, D_{i, j}, E_{i, j}, F_{i, j}\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. i -> (A_{i, j}, B_{i, j}, C_{i, j}, D_{i, j}, E_{i, j}, F_{i, j})
#    core type: Lambda
#    parameter: 15
#    body: 1
# 1. (A_{i, j}, B_{i, j}, C_{i, j}, D_{i, j}, E_{i, j}, F_{i, j})
#    core type: ExprTuple
#    sub-expressions: 2, 3, 4, 5, 6, 7
# 2. A_{i, j}
#    core type: IndexedVar
# variable: 8
# indices: 14
# 3. B_{i, j}
#    core type: IndexedVar
# variable: 9
# indices: 14
# 4. C_{i, j}
#    core type: IndexedVar
# variable: 10
# indices: 14
# 5. D_{i, j}
#    core type: IndexedVar
# variable: 11
# indices: 14
# 6. E_{i, j}
#    core type: IndexedVar
# variable: 12
# indices: 14
# 7. F_{i, j}
#    core type: IndexedVar
# variable: 13
# indices: 14
# 8. A
#    core type: Variable
#    sub-expressions:
# 9. B
#    core type: Variable
#    sub-expressions:
# 10. C
#     core type: Variable
#     sub-expressions:
# 11. D
#     core type: Variable
#     sub-expressions:
# 12. E
#     core type: Variable
#     sub-expressions:
# 13. F
#     core type: Variable
# ...
