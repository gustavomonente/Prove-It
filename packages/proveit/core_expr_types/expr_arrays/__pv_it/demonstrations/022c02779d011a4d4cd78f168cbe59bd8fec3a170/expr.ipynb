# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.expr_arrays</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, ExprRange, IndexedVar, Lambda, i, j, n
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
expr = Lambda(i, [ExprRange(j, IndexedVar(A, [i, j]), one, n).with_explicit_parameterization()])
# Out:
# expr: i -> (A_{i, 1}, ..A_{i, j}.., A_{i, n})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# i \mapsto \left(A_{i, 1}, ..A_{i, j}.., A_{i, n}\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. i -> (A_{i, 1}, ..A_{i, j}.., A_{i, n})
#    core type: Lambda
#    parameter: 9
#    body: 1
# 1. (A_{i, 1}, ..A_{i, j}.., A_{i, n})
#    core type: ExprTuple
#    sub-expressions: 2
# 2. A_{i, 1}, ..A_{i, j}.., A_{i, n}
#    core type: ExprRange
#    lambda_map: 3
#    start_index: 4
#    end_index: 5
# 3. j -> A_{i, j}
#    core type: Lambda
#    parameter: 10
#    body: 6
# 4. 1
#    core type: Literal
#    sub-expressions:
# 5. n
#    core type: Variable
#    sub-expressions:
# 6. A_{i, j}
#    core type: IndexedVar
# variable: 7
# indices: 8
# 7. A
#    core type: Variable
#    sub-expressions:
# 8. (i, j)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. i
#    core type: Variable
#    sub-expressions:
# 10. j
#     core type: Variable
#     sub-expressions:
