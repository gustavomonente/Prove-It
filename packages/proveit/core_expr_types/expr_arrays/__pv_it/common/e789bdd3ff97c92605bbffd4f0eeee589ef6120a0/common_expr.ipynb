# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#A11_to_Amn">A11_to_Amn</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.expr_arrays</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types.expr_arrays import A11_to_Amn

# %%
# check that the built expression is the same as the stored expression
assert A11_to_Amn == stored_expr
assert A11_to_Amn._style_id == stored_expr._style_id
print("Passed sanity check: A11_to_Amn matches stored_expr")
# Out:
# Passed sanity check: A11_to_Amn matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(A11_to_Amn.latex())
# Out:
# A_{1, 1}, \ldots, A_{1, n}, \ldots\ldots, A_{m, 1}, \ldots, A_{m, n}

# %%
A11_to_Amn.style_options()
# Out:
# style name: parameterization
# description: 'implicit' (default for LaTeX formatting) hides the parameter the ExprRange so the parameterization may be ambiguous (e.g., x_{1+1}, ..., x_{n+1}); 'explicit' (default for string formatting) reveals the parameterization (e.g. x_{1+1}, ..x_{k+1}.., x_{n+1}).
# default: None
# current value: None/False
# related methods: ('with_explicit_parameterization', 'with_implicit_parameterization', 'with_default_parameterization_style')

# %%
# display the expression information
A11_to_Amn.expr_info()
# Out:
# 0. A_{1, 1}, ..A_{1, _b}.., A_{1, n}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, n}...., A_{m, 1}, ..A_{m, _b}.., A_{m, n}
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 5
#    end_index: 2
# 1. _a -> A_{_a, 1}, ..A_{_a, _b}.., A_{_a, n}
#    core type: Lambda
#    parameter: 10
#    body: 3
# 2. m
#    core type: Variable
#    sub-expressions:
# 3. A_{_a, 1}, ..A_{_a, _b}.., A_{_a, n}
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 5
#    end_index: 6
# 4. _b -> A_{_a, _b}
#    core type: Lambda
#    parameter: 11
#    body: 7
# 5. 1
#    core type: Literal
#    sub-expressions:
# 6. n
#    core type: Variable
#    sub-expressions:
# 7. A_{_a, _b}
#    core type: IndexedVar
# variable: 8
# indices: 9
# 8. A
#    core type: Variable
#    sub-expressions:
# 9. (_a, _b)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. _a
#     core type: Variable
#     sub-expressions:
# 11. _b
#     core type: Variable
#     sub-expressions:
