# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#lambda_substitution">lambda_substitution</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.lambda_maps</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types.lambda_maps import lambda_substitution

# %%
# check that the built expression is the same as the stored expression
assert lambda_substitution.expr == stored_expr
assert lambda_substitution.expr._style_id == stored_expr._style_id
print("Passed sanity check: lambda_substitution matches stored_expr")
# Out:
# Passed sanity check: lambda_substitution matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(lambda_substitution.latex())
# Out:
# \vdash \forall_{i \in \mathbb{N}^+}~\left[\forall_{f, g}~\left(\begin{array}{c} \begin{array}{l} \left[\forall_{a_{1}, \ldots, a_{i}}~\left(f(a_{1}, \ldots, a_{i}) = g(a_{1}, \ldots, a_{i})\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left[\left(b_{1}, \ldots, b_{i}\right) \mapsto f(b_{1}, \ldots, b_{i})\right] =  \\ \left[\left(c_{1}, \ldots, c_{i}\right) \mapsto g(c_{1}, \ldots, c_{i})\right] \end{array} \end{array}\right) \end{array} \end{array}\right)\right]

# %%
lambda_substitution.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
lambda_substitution.expr_info()
# Out:
# 0. forall_{i in NaturalPos} [forall_{f, g} ([forall_{a_{1}, ..a_{_a}.., a_{i}} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> f(b_{1}, ..b_{_a}.., b_{i})] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> g(c_{1}, ..c_{_a}.., c_{i})]))]
#    core type: Operation
#    operator: 17
#    operand: 2
# 1. (i -> {forall_{f, g} ([forall_{a_{1}, ..a_{_a}.., a_{i}} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> f(b_{1}, ..b_{_a}.., b_{i})] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> g(c_{1}, ..c_{_a}.., c_{i})])) if i in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. i -> {forall_{f, g} ([forall_{a_{1}, ..a_{_a}.., a_{i}} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> f(b_{1}, ..b_{_a}.., b_{i})] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> g(c_{1}, ..c_{_a}.., c_{i})])) if i in NaturalPos.
#    core type: Lambda
#    parameter: 44
#    body: 3
# 3. {forall_{f, g} ([forall_{a_{1}, ..a_{_a}.., a_{i}} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> f(b_{1}, ..b_{_a}.., b_{i})] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> g(c_{1}, ..c_{_a}.., c_{i})])) if i in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{f, g} ([forall_{a_{1}, ..a_{_a}.., a_{i}} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> f(b_{1}, ..b_{_a}.., b_{i})] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> g(c_{1}, ..c_{_a}.., c_{i})]))
#    core type: Operation
#    operator: 17
#    operand: 9
# 5. i in NaturalPos
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. ((f, g) -> ([forall_{a_{1}, ..a_{_a}.., a_{i}} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> f(b_{1}, ..b_{_a}.., b_{i})] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> g(c_{1}, ..c_{_a}.., c_{i})])))
#    core type: ExprTuple
#    sub-expressions: 9
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (i, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 44, 10
# 9. (f, g) -> ([forall_{a_{1}, ..a_{_a}.., a_{i}} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> f(b_{1}, ..b_{_a}.., b_{i})] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> g(c_{1}, ..c_{_a}.., c_{i})]))
#    core type: Lambda
#    parameters: 11\n   body: 12
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. (f, g)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 12. [forall_{a_{1}, ..a_{_a}.., a_{i}} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> f(b_{1}, ..b_{_a}.., b_{i})] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> g(c_{1}, ..c_{_a}.., c_{i})])
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. =>
#     core type: Literal
#     sub-expressions:
# 14. (forall_{a_{1}, ..a_{_a}.., a_{i}} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i})), [(b_{1}, ..b_{_a}.., b_{i}) -> f(b_{1}, ..b_{_a}.., b_{i})] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> g(c_{1}, ..c_{_a}.., c_{i})])
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. forall_{a_{1}, ..a_{_a}.., a_{i}} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))
#     core type: Operation
#     operator: 17
#     operand: 20
# 16. [(b_{1}, ..b_{_a}.., b_{i}) -> f(b_{1}, ..b_{_a}.., b_{i})] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> g(c_{1}, ..c_{_a}.., c_{i})]
#     core type: Operation
#     operator: 26
#     operands: 19
# 17. forall
#     core type: Literal
#     sub-expressions:
# 18. ((a_{1}, ..a_{_a}.., a_{i}) -> (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i})))
#     core type: ExprTuple
#     sub-expressions: 20
# 19. ((b_{1}, ..b_{_a}.., b_{i}) -> f(b_{1}, ..b_{_a}.., b_{i}), (c_{1}, ..c_{_a}.., c_{i}) -> g(c_{1}, ..c_{_a}.., c_{i}))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 20. (a_{1}, ..a_{_a}.., a_{i}) -> (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))
#     core type: Lambda
#     parameters: 36\n    body: 23
# 21. (b_{1}, ..b_{_a}.., b_{i}) -> f(b_{1}, ..b_{_a}.., b_{i})
#     core type: Lambda
#     parameters: 28\n    body: 24
# 22. (c_{1}, ..c_{_a}.., c_{i}) -> g(c_{1}, ..c_{_a}.., c_{i})
#     core type: Lambda
#     parameters: 29\n    body: 25
# 23. f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i})
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. f(b_{1}, ..b_{_a}.., b_{i})
#     core type: Operation
#     operator: 34
#     operands: 28
# 25. g(c_{1}, ..c_{_a}.., c_{i})
#     core type: Operation
#     operator: 35
#     operands: 29
# 26. =
#     core type: Literal
#     sub-expressions:
# 27. (f(a_{1}, ..a_{_a}.., a_{i}), g(a_{1}, ..a_{_a}.., a_{i}))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 28. (b_{1}, ..b_{_a}.., b_{i})
#     core type: ExprTuple
#     sub-expressions: 32
# 29. (c_{1}, ..c_{_a}.., c_{i})
#     core type: ExprTuple
#     sub-expressions: 33
# 30. f(a_{1}, ..a_{_a}.., a_{i})
#     core type: Operation
#     operator: 34
#     operands: 36
# 31. g(a_{1}, ..a_{_a}.., a_{i})
#     core type: Operation
#     operator: 35
#     operands: 36
# 32. b_{1}, ..b_{_a}.., b_{i}
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 43
#     end_index: 44
# 33. c_{1}, ..c_{_a}.., c_{i}
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 43
#     end_index: 44
# 34. f
#     core type: Variable
#     sub-expressions:
# 35. g
#     core type: Variable
#     sub-expressions:
# 36. (a_{1}, ..a_{_a}.., a_{i})
#     core type: ExprTuple
#     sub-expressions: 39
# 37. _a -> b_{_a}
#     core type: Lambda
#     parameter: 50
#     body: 40
# 38. _a -> c_{_a}
#     core type: Lambda
#     parameter: 50
#     body: 41
# 39. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 43
#     end_index: 44
# 40. b_{_a}
#     core type: IndexedVar
# variable: 45
# index: 50
# 41. c_{_a}
#     core type: IndexedVar
# variable: 46
# index: 50
# 42. _a -> a_{_a}
#     core type: Lambda
#     parameter: 50
#     body: 47
# 43. 1
#     core type: Literal
#     sub-expressions:
# 44. i
#     core type: Variable
#     sub-expressions:
# 45. b
#     core type: Variable
#     sub-expressions:
# 46. c
#     core type: Variable
#     sub-expressions:
# 47. a_{_a}
#     core type: IndexedVar
# variable: 48
# index: 50
# 48. a
#     core type: Variable
#     sub-expressions:
# 49. (_a)
#     core type: ExprTuple
#     sub-expressions: 50
# 50. _a
#     core type: Variable
#     sub-expressions:
