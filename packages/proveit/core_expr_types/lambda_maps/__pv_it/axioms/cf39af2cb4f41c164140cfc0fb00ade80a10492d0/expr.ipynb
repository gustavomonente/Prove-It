# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.lambda_maps</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, f, g
from proveit.core_expr_types import a_1_to_i, b_1_to_i, c_1_to_i, f__a_1_to_i, f__b_1_to_i, g__a_1_to_i, g__c_1_to_i
from proveit.logic import Equals, Forall, Implies

# %%
# build up the expression from sub-expressions
expr = Forall([f, g], Implies(Forall([a_1_to_i], Equals(f__a_1_to_i, g__a_1_to_i)), Equals(Lambda([b_1_to_i], f__b_1_to_i), Lambda([c_1_to_i], g__c_1_to_i)).with_wrapping_at(2)).with_wrapping_at(2))
# Out:
# expr: forall_{f, g} ([forall_{a_{1}, ..a_{_a}.., a_{i}} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> f(b_{1}, ..b_{_a}.., b_{i})] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> g(c_{1}, ..c_{_a}.., c_{i})]))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{f, g}~\left(\begin{array}{c} \begin{array}{l} \left[\forall_{a_{1}, \ldots, a_{i}}~\left(f(a_{1}, \ldots, a_{i}) = g(a_{1}, \ldots, a_{i})\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left[\left(b_{1}, \ldots, b_{i}\right) \mapsto f(b_{1}, \ldots, b_{i})\right] =  \\ \left[\left(c_{1}, \ldots, c_{i}\right) \mapsto g(c_{1}, \ldots, c_{i})\right] \end{array} \end{array}\right) \end{array} \end{array}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{f, g} ([forall_{a_{1}, ..a_{_a}.., a_{i}} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> f(b_{1}, ..b_{_a}.., b_{i})] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> g(c_{1}, ..c_{_a}.., c_{i})]))
#    core type: Operation
#    operator: 9
#    operand: 2
# 1. ((f, g) -> ([forall_{a_{1}, ..a_{_a}.., a_{i}} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> f(b_{1}, ..b_{_a}.., b_{i})] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> g(c_{1}, ..c_{_a}.., c_{i})])))
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (f, g) -> ([forall_{a_{1}, ..a_{_a}.., a_{i}} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> f(b_{1}, ..b_{_a}.., b_{i})] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> g(c_{1}, ..c_{_a}.., c_{i})]))
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (f, g)
#    core type: ExprTuple
#    sub-expressions: 26, 27
# 4. [forall_{a_{1}, ..a_{_a}.., a_{i}} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> f(b_{1}, ..b_{_a}.., b_{i})] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> g(c_{1}, ..c_{_a}.., c_{i})])
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =>
#    core type: Literal
#    sub-expressions:
# 6. (forall_{a_{1}, ..a_{_a}.., a_{i}} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i})), [(b_{1}, ..b_{_a}.., b_{i}) -> f(b_{1}, ..b_{_a}.., b_{i})] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> g(c_{1}, ..c_{_a}.., c_{i})])
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. forall_{a_{1}, ..a_{_a}.., a_{i}} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))
#    core type: Operation
#    operator: 9
#    operand: 12
# 8. [(b_{1}, ..b_{_a}.., b_{i}) -> f(b_{1}, ..b_{_a}.., b_{i})] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> g(c_{1}, ..c_{_a}.., c_{i})]
#    core type: Operation
#    operator: 18
#    operands: 11
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. ((a_{1}, ..a_{_a}.., a_{i}) -> (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i})))
#     core type: ExprTuple
#     sub-expressions: 12
# 11. ((b_{1}, ..b_{_a}.., b_{i}) -> f(b_{1}, ..b_{_a}.., b_{i}), (c_{1}, ..c_{_a}.., c_{i}) -> g(c_{1}, ..c_{_a}.., c_{i}))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. (a_{1}, ..a_{_a}.., a_{i}) -> (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))
#     core type: Lambda
#     parameters: 28\n    body: 15
# 13. (b_{1}, ..b_{_a}.., b_{i}) -> f(b_{1}, ..b_{_a}.., b_{i})
#     core type: Lambda
#     parameters: 20\n    body: 16
# 14. (c_{1}, ..c_{_a}.., c_{i}) -> g(c_{1}, ..c_{_a}.., c_{i})
#     core type: Lambda
#     parameters: 21\n    body: 17
# 15. f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i})
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. f(b_{1}, ..b_{_a}.., b_{i})
#     core type: Operation
#     operator: 26
#     operands: 20
# 17. g(c_{1}, ..c_{_a}.., c_{i})
#     core type: Operation
#     operator: 27
#     operands: 21
# 18. =
#     core type: Literal
#     sub-expressions:
# 19. (f(a_{1}, ..a_{_a}.., a_{i}), g(a_{1}, ..a_{_a}.., a_{i}))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. (b_{1}, ..b_{_a}.., b_{i})
#     core type: ExprTuple
#     sub-expressions: 24
# 21. (c_{1}, ..c_{_a}.., c_{i})
#     core type: ExprTuple
#     sub-expressions: 25
# 22. f(a_{1}, ..a_{_a}.., a_{i})
#     core type: Operation
#     operator: 26
#     operands: 28
# 23. g(a_{1}, ..a_{_a}.., a_{i})
#     core type: Operation
#     operator: 27
#     operands: 28
# 24. b_{1}, ..b_{_a}.., b_{i}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 35
#     end_index: 36
# 25. c_{1}, ..c_{_a}.., c_{i}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 35
#     end_index: 36
# 26. f
#     core type: Variable
#     sub-expressions:
# 27. g
#     core type: Variable
#     sub-expressions:
# 28. (a_{1}, ..a_{_a}.., a_{i})
#     core type: ExprTuple
#     sub-expressions: 31
# 29. _a -> b_{_a}
#     core type: Lambda
#     parameter: 42
#     body: 32
# 30. _a -> c_{_a}
#     core type: Lambda
#     parameter: 42
#     body: 33
# 31. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 35
#     end_index: 36
# 32. b_{_a}
#     core type: IndexedVar
# variable: 37
# index: 42
# 33. c_{_a}
#     core type: IndexedVar
# variable: 38
# index: 42
# 34. _a -> a_{_a}
#     core type: Lambda
#     parameter: 42
#     body: 39
# 35. 1
#     core type: Literal
#     sub-expressions:
# 36. i
#     core type: Variable
#     sub-expressions:
# 37. b
#     core type: Variable
#     sub-expressions:
# 38. c
#     core type: Variable
#     sub-expressions:
# 39. a_{_a}
#     core type: IndexedVar
# variable: 40
# index: 42
# 40. a
#     core type: Variable
#     sub-expressions:
# 41. (_a)
#     core type: ExprTuple
#     sub-expressions: 42
# 42. _a
#     core type: Variable
#     sub-expressions:
