# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.lambda_maps</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit.core_expr_types import Q__c_1_to_i, g__c_1_to_i

# %%
# build up the expression from sub-expressions
expr = Conditional(g__c_1_to_i, Q__c_1_to_i)
# Out:
# expr: {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{g(c_{1}, \ldots, c_{i}) \textrm{ if } Q(c_{1}, \ldots, c_{i})\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. g(c_{1}, ..c_{_a}.., c_{i})
#    core type: Operation
#    operator: 3
#    operands: 5
# 2. Q(c_{1}, ..c_{_a}.., c_{i})
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. g
#    core type: Variable
#    sub-expressions:
# 4. Q
#    core type: Variable
#    sub-expressions:
# 5. (c_{1}, ..c_{_a}.., c_{i})
#    core type: ExprTuple
#    sub-expressions: 6
# 6. c_{1}, ..c_{_a}.., c_{i}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 8
#    end_index: 9
# 7. _a -> c_{_a}
#    core type: Lambda
#    parameter: 13
#    body: 10
# 8. 1
#    core type: Literal
#    sub-expressions:
# 9. i
#    core type: Variable
#    sub-expressions:
# 10. c_{_a}
#     core type: IndexedVar
# variable: 11
# index: 13
# 11. c
#     core type: Variable
#     sub-expressions:
# 12. (_a)
#     core type: ExprTuple
#     sub-expressions: 13
# 13. _a
#     core type: Variable
#     sub-expressions:
