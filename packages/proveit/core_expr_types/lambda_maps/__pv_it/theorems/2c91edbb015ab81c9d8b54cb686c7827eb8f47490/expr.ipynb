# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.lambda_maps</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, Q, f, g, i
from proveit.core_expr_types import Q__a_1_to_i, Q__b_1_to_i, Q__c_1_to_i, a_1_to_i, b_1_to_i, c_1_to_i, f__a_1_to_i, f__b_1_to_i, g__a_1_to_i, g__c_1_to_i
from proveit.logic import Equals, Forall, Implies, InSet
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([f, g, Q], Implies(Forall([a_1_to_i], Equals(f__a_1_to_i, g__a_1_to_i), condition = Q__a_1_to_i), Equals(Lambda([b_1_to_i], Conditional(f__b_1_to_i, Q__b_1_to_i)), Lambda([c_1_to_i], Conditional(g__c_1_to_i, Q__c_1_to_i))).with_wrapping_at(2)).with_wrapping_at(2)), InSet(i, NaturalPos))
# Out:
# expr: {forall_{f, g, Q} ([forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).])) if i in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{f, g, Q}~\left(\begin{array}{c} \begin{array}{l} \left[\forall_{a_{1}, \ldots, a_{i}~|~Q(a_{1}, \ldots, a_{i})}~\left(f(a_{1}, \ldots, a_{i}) = g(a_{1}, \ldots, a_{i})\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left[\left(b_{1}, \ldots, b_{i}\right) \mapsto \left\{f(b_{1}, \ldots, b_{i}) \textrm{ if } Q(b_{1}, \ldots, b_{i})\right..\right] =  \\ \left[\left(c_{1}, \ldots, c_{i}\right) \mapsto \left\{g(c_{1}, \ldots, c_{i}) \textrm{ if } Q(c_{1}, \ldots, c_{i})\right..\right] \end{array} \end{array}\right) \end{array} \end{array}\right) \textrm{ if } i \in \mathbb{N}^+\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{f, g, Q} ([forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).])) if i in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{f, g, Q} ([forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).]))
#    core type: Operation
#    operator: 14
#    operand: 6
# 2. i in NaturalPos
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. ((f, g, Q) -> ([forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).])))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (i, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 48, 7
# 6. (f, g, Q) -> ([forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).]))
#    core type: Lambda
#    parameters: 8\n   body: 9
# 7. NaturalPos
#    core type: Literal
#    sub-expressions:
# 8. (f, g, Q)
#    core type: ExprTuple
#    sub-expressions: 38, 39, 32
# 9. [forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).])
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. =>
#     core type: Literal
#     sub-expressions:
# 11. (forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i})), [(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).])
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))
#     core type: Operation
#     operator: 14
#     operand: 17
# 13. [(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).]
#     core type: Operation
#     operator: 29
#     operands: 16
# 14. forall
#     core type: Literal
#     sub-expressions:
# 15. ((a_{1}, ..a_{_a}.., a_{i}) -> {f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}) if Q(a_{1}, ..a_{_a}.., a_{i}).)
#     core type: ExprTuple
#     sub-expressions: 17
# 16. ((b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i})., (c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. (a_{1}, ..a_{_a}.., a_{i}) -> {f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}) if Q(a_{1}, ..a_{_a}.., a_{i}).
#     core type: Lambda
#     parameters: 40\n    body: 20
# 18. (b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).
#     core type: Lambda
#     parameters: 31\n    body: 21
# 19. (c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).
#     core type: Lambda
#     parameters: 33\n    body: 22
# 20. {f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}) if Q(a_{1}, ..a_{_a}.., a_{i}).
#     core type: Conditional
#     value: 23
#     condition: 24
# 21. {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).
#     core type: Conditional
#     value: 25
#     condition: 26
# 22. {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).
#     core type: Conditional
#     value: 27
#     condition: 28
# 23. f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i})
#     core type: Operation
#     operator: 29
#     operands: 30
# 24. Q(a_{1}, ..a_{_a}.., a_{i})
#     core type: Operation
#     operator: 32
#     operands: 40
# 25. f(b_{1}, ..b_{_a}.., b_{i})
#     core type: Operation
#     operator: 38
#     operands: 31
# 26. Q(b_{1}, ..b_{_a}.., b_{i})
#     core type: Operation
#     operator: 32
#     operands: 31
# 27. g(c_{1}, ..c_{_a}.., c_{i})
#     core type: Operation
#     operator: 39
#     operands: 33
# 28. Q(c_{1}, ..c_{_a}.., c_{i})
#     core type: Operation
#     operator: 32
#     operands: 33
# 29. =
#     core type: Literal
#     sub-expressions:
# 30. (f(a_{1}, ..a_{_a}.., a_{i}), g(a_{1}, ..a_{_a}.., a_{i}))
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 31. (b_{1}, ..b_{_a}.., b_{i})
#     core type: ExprTuple
#     sub-expressions: 36
# 32. Q
#     core type: Variable
#     sub-expressions:
# 33. (c_{1}, ..c_{_a}.., c_{i})
#     core type: ExprTuple
#     sub-expressions: 37
# 34. f(a_{1}, ..a_{_a}.., a_{i})
#     core type: Operation
#     operator: 38
#     operands: 40
# 35. g(a_{1}, ..a_{_a}.., a_{i})
#     core type: Operation
#     operator: 39
#     operands: 40
# 36. b_{1}, ..b_{_a}.., b_{i}
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 47
#     end_index: 48
# 37. c_{1}, ..c_{_a}.., c_{i}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 47
#     end_index: 48
# 38. f
#     core type: Variable
#     sub-expressions:
# 39. g
#     core type: Variable
#     sub-expressions:
# 40. (a_{1}, ..a_{_a}.., a_{i})
#     core type: ExprTuple
#     sub-expressions: 43
# 41. _a -> b_{_a}
#     core type: Lambda
#     parameter: 54
#     body: 44
# 42. _a -> c_{_a}
#     core type: Lambda
#     parameter: 54
#     body: 45
# 43. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 47
#     end_index: 48
# 44. b_{_a}
#     core type: IndexedVar
# variable: 49
# index: 54
# 45. c_{_a}
#     core type: IndexedVar
# variable: 50
# index: 54
# 46. _a -> a_{_a}
#     core type: Lambda
#     parameter: 54
#     body: 51
# 47. 1
#     core type: Literal
#     sub-expressions:
# 48. i
#     core type: Variable
#     sub-expressions:
# 49. b
#     core type: Variable
#     sub-expressions:
# 50. c
#     core type: Variable
#     sub-expressions:
# 51. a_{_a}
#     core type: IndexedVar
# variable: 52
# index: 54
# 52. a
#     core type: Variable
#     sub-expressions:
# 53. (_a)
#     core type: ExprTuple
#     sub-expressions: 54
# 54. _a
#     core type: Variable
#     sub-expressions:
