# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.lambda_maps</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, Q, f, g, i
from proveit.core_expr_types import Q__a_1_to_i, Q__b_1_to_i, Q__c_1_to_i, a_1_to_i, b_1_to_i, c_1_to_i, f__a_1_to_i, f__b_1_to_i, g__a_1_to_i, g__c_1_to_i
from proveit.logic import Equals, Forall, Implies
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Forall([i], Forall([f, g, Q], Implies(Forall([a_1_to_i], Equals(f__a_1_to_i, g__a_1_to_i), condition = Q__a_1_to_i), Equals(Lambda([b_1_to_i], Conditional(f__b_1_to_i, Q__b_1_to_i)), Lambda([c_1_to_i], Conditional(g__c_1_to_i, Q__c_1_to_i))).with_wrapping_at(2)).with_wrapping_at(2)), domains = [NaturalPos])
# Out:
# expr: forall_{i in NaturalPos} [forall_{f, g, Q} ([forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).]))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{i \in \mathbb{N}^+}~\left[\forall_{f, g, Q}~\left(\begin{array}{c} \begin{array}{l} \left[\forall_{a_{1}, \ldots, a_{i}~|~Q(a_{1}, \ldots, a_{i})}~\left(f(a_{1}, \ldots, a_{i}) = g(a_{1}, \ldots, a_{i})\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left[\left(b_{1}, \ldots, b_{i}\right) \mapsto \left\{f(b_{1}, \ldots, b_{i}) \textrm{ if } Q(b_{1}, \ldots, b_{i})\right..\right] =  \\ \left[\left(c_{1}, \ldots, c_{i}\right) \mapsto \left\{g(c_{1}, \ldots, c_{i}) \textrm{ if } Q(c_{1}, \ldots, c_{i})\right..\right] \end{array} \end{array}\right) \end{array} \end{array}\right)\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{i in NaturalPos} [forall_{f, g, Q} ([forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).]))]
#    core type: Operation
#    operator: 17
#    operand: 2
# 1. (i -> {forall_{f, g, Q} ([forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).])) if i in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. i -> {forall_{f, g, Q} ([forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).])) if i in NaturalPos.
#    core type: Lambda
#    parameter: 51
#    body: 3
# 3. {forall_{f, g, Q} ([forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).])) if i in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{f, g, Q} ([forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).]))
#    core type: Operation
#    operator: 17
#    operand: 9
# 5. i in NaturalPos
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. ((f, g, Q) -> ([forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).])))
#    core type: ExprTuple
#    sub-expressions: 9
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (i, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 51, 10
# 9. (f, g, Q) -> ([forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).]))
#    core type: Lambda
#    parameters: 11\n   body: 12
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. (f, g, Q)
#     core type: ExprTuple
#     sub-expressions: 41, 42, 35
# 12. [forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).])
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. =>
#     core type: Literal
#     sub-expressions:
# 14. (forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i})), [(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).])
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))
#     core type: Operation
#     operator: 17
#     operand: 20
# 16. [(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).]
#     core type: Operation
#     operator: 32
#     operands: 19
# 17. forall
#     core type: Literal
#     sub-expressions:
# 18. ((a_{1}, ..a_{_a}.., a_{i}) -> {f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}) if Q(a_{1}, ..a_{_a}.., a_{i}).)
#     core type: ExprTuple
#     sub-expressions: 20
# 19. ((b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i})., (c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 20. (a_{1}, ..a_{_a}.., a_{i}) -> {f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}) if Q(a_{1}, ..a_{_a}.., a_{i}).
#     core type: Lambda
#     parameters: 43\n    body: 23
# 21. (b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).
#     core type: Lambda
#     parameters: 34\n    body: 24
# 22. (c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).
#     core type: Lambda
#     parameters: 36\n    body: 25
# 23. {f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}) if Q(a_{1}, ..a_{_a}.., a_{i}).
#     core type: Conditional
#     value: 26
#     condition: 27
# 24. {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).
#     core type: Conditional
#     value: 28
#     condition: 29
# 25. {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).
#     core type: Conditional
#     value: 30
#     condition: 31
# 26. f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i})
#     core type: Operation
#     operator: 32
#     operands: 33
# 27. Q(a_{1}, ..a_{_a}.., a_{i})
#     core type: Operation
#     operator: 35
#     operands: 43
# 28. f(b_{1}, ..b_{_a}.., b_{i})
#     core type: Operation
#     operator: 41
#     operands: 34
# 29. Q(b_{1}, ..b_{_a}.., b_{i})
#     core type: Operation
#     operator: 35
#     operands: 34
# 30. g(c_{1}, ..c_{_a}.., c_{i})
#     core type: Operation
#     operator: 42
#     operands: 36
# 31. Q(c_{1}, ..c_{_a}.., c_{i})
#     core type: Operation
#     operator: 35
#     operands: 36
# 32. =
#     core type: Literal
#     sub-expressions:
# 33. (f(a_{1}, ..a_{_a}.., a_{i}), g(a_{1}, ..a_{_a}.., a_{i}))
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 34. (b_{1}, ..b_{_a}.., b_{i})
#     core type: ExprTuple
#     sub-expressions: 39
# 35. Q
#     core type: Variable
#     sub-expressions:
# 36. (c_{1}, ..c_{_a}.., c_{i})
#     core type: ExprTuple
#     sub-expressions: 40
# 37. f(a_{1}, ..a_{_a}.., a_{i})
#     core type: Operation
#     operator: 41
#     operands: 43
# 38. g(a_{1}, ..a_{_a}.., a_{i})
#     core type: Operation
#     operator: 42
#     operands: 43
# 39. b_{1}, ..b_{_a}.., b_{i}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 50
#     end_index: 51
# 40. c_{1}, ..c_{_a}.., c_{i}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 50
#     end_index: 51
# 41. f
#     core type: Variable
#     sub-expressions:
# 42. g
#     core type: Variable
#     sub-expressions:
# 43. (a_{1}, ..a_{_a}.., a_{i})
#     core type: ExprTuple
#     sub-expressions: 46
# 44. _a -> b_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 47
# 45. _a -> c_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 48
# 46. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 50
#     end_index: 51
# 47. b_{_a}
#     core type: IndexedVar
# variable: 52
# index: 57
# 48. c_{_a}
#     core type: IndexedVar
# variable: 53
# index: 57
# 49. _a -> a_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 54
# 50. 1
#     core type: Literal
#     sub-expressions:
# 51. i
#     core type: Variable
#     sub-expressions:
# 52. b
#     core type: Variable
#     sub-expressions:
# 53. c
#     core type: Variable
#     sub-expressions:
# 54. a_{_a}
#     core type: IndexedVar
# variable: 55
# index: 57
# 55. a
#     core type: Variable
#     sub-expressions:
# 56. (_a)
#     core type: ExprTuple
#     sub-expressions: 57
# 57. _a
#     core type: Variable
#     sub-expressions:
