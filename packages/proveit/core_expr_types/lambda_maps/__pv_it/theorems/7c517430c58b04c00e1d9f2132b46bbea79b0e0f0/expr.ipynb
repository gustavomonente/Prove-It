# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.lambda_maps</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, Q, f, g
from proveit.core_expr_types import Q__a_1_to_i, Q__b_1_to_i, Q__c_1_to_i, a_1_to_i, b_1_to_i, c_1_to_i, f__a_1_to_i, f__b_1_to_i, g__a_1_to_i, g__c_1_to_i
from proveit.logic import Equals, Forall, Implies

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([f, g, Q], Implies(Forall([a_1_to_i], Equals(f__a_1_to_i, g__a_1_to_i), condition = Q__a_1_to_i), Equals(Lambda([b_1_to_i], Conditional(f__b_1_to_i, Q__b_1_to_i)), Lambda([c_1_to_i], Conditional(g__c_1_to_i, Q__c_1_to_i))).with_wrapping_at(2)).with_wrapping_at(2)))
# Out:
# expr: ((f, g, Q) -> ([forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).])))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(f, g, Q\right) \mapsto \left(\begin{array}{c} \begin{array}{l} \left[\forall_{a_{1}, \ldots, a_{i}~|~Q(a_{1}, \ldots, a_{i})}~\left(f(a_{1}, \ldots, a_{i}) = g(a_{1}, \ldots, a_{i})\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left[\left(b_{1}, \ldots, b_{i}\right) \mapsto \left\{f(b_{1}, \ldots, b_{i}) \textrm{ if } Q(b_{1}, \ldots, b_{i})\right..\right] =  \\ \left[\left(c_{1}, \ldots, c_{i}\right) \mapsto \left\{g(c_{1}, \ldots, c_{i}) \textrm{ if } Q(c_{1}, \ldots, c_{i})\right..\right] \end{array} \end{array}\right) \end{array} \end{array}\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((f, g, Q) -> ([forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).])))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (f, g, Q) -> ([forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).]))
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (f, g, Q)
#    core type: ExprTuple
#    sub-expressions: 32, 33, 26
# 3. [forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).])
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =>
#    core type: Literal
#    sub-expressions:
# 5. (forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i})), [(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).])
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))
#    core type: Operation
#    operator: 8
#    operand: 11
# 7. [(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).]
#    core type: Operation
#    operator: 23
#    operands: 10
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. ((a_{1}, ..a_{_a}.., a_{i}) -> {f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}) if Q(a_{1}, ..a_{_a}.., a_{i}).)
#    core type: ExprTuple
#    sub-expressions: 11
# 10. ((b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i})., (c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. (a_{1}, ..a_{_a}.., a_{i}) -> {f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}) if Q(a_{1}, ..a_{_a}.., a_{i}).
#     core type: Lambda
#     parameters: 34\n    body: 14
# 12. (b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).
#     core type: Lambda
#     parameters: 25\n    body: 15
# 13. (c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).
#     core type: Lambda
#     parameters: 27\n    body: 16
# 14. {f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}) if Q(a_{1}, ..a_{_a}.., a_{i}).
#     core type: Conditional
#     value: 17
#     condition: 18
# 15. {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).
#     core type: Conditional
#     value: 19
#     condition: 20
# 16. {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).
#     core type: Conditional
#     value: 21
#     condition: 22
# 17. f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i})
#     core type: Operation
#     operator: 23
#     operands: 24
# 18. Q(a_{1}, ..a_{_a}.., a_{i})
#     core type: Operation
#     operator: 26
#     operands: 34
# 19. f(b_{1}, ..b_{_a}.., b_{i})
#     core type: Operation
#     operator: 32
#     operands: 25
# 20. Q(b_{1}, ..b_{_a}.., b_{i})
#     core type: Operation
#     operator: 26
#     operands: 25
# 21. g(c_{1}, ..c_{_a}.., c_{i})
#     core type: Operation
#     operator: 33
#     operands: 27
# 22. Q(c_{1}, ..c_{_a}.., c_{i})
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. =
#     core type: Literal
#     sub-expressions:
# 24. (f(a_{1}, ..a_{_a}.., a_{i}), g(a_{1}, ..a_{_a}.., a_{i}))
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 25. (b_{1}, ..b_{_a}.., b_{i})
#     core type: ExprTuple
#     sub-expressions: 30
# 26. Q
#     core type: Variable
#     sub-expressions:
# 27. (c_{1}, ..c_{_a}.., c_{i})
#     core type: ExprTuple
#     sub-expressions: 31
# 28. f(a_{1}, ..a_{_a}.., a_{i})
#     core type: Operation
#     operator: 32
#     operands: 34
# 29. g(a_{1}, ..a_{_a}.., a_{i})
#     core type: Operation
#     operator: 33
#     operands: 34
# 30. b_{1}, ..b_{_a}.., b_{i}
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 41
#     end_index: 42
# 31. c_{1}, ..c_{_a}.., c_{i}
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 41
#     end_index: 42
# 32. f
#     core type: Variable
#     sub-expressions:
# 33. g
#     core type: Variable
#     sub-expressions:
# 34. (a_{1}, ..a_{_a}.., a_{i})
#     core type: ExprTuple
#     sub-expressions: 37
# 35. _a -> b_{_a}
#     core type: Lambda
#     parameter: 48
#     body: 38
# 36. _a -> c_{_a}
#     core type: Lambda
#     parameter: 48
#     body: 39
# 37. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 41
#     end_index: 42
# 38. b_{_a}
#     core type: IndexedVar
# variable: 43
# index: 48
# 39. c_{_a}
#     core type: IndexedVar
# variable: 44
# index: 48
# 40. _a -> a_{_a}
#     core type: Lambda
#     parameter: 48
#     body: 45
# 41. 1
#     core type: Literal
#     sub-expressions:
# 42. i
#     core type: Variable
#     sub-expressions:
# 43. b
#     core type: Variable
#     sub-expressions:
# 44. c
#     core type: Variable
#     sub-expressions:
# 45. a_{_a}
#     core type: IndexedVar
# variable: 46
# index: 48
# 46. a
#     core type: Variable
#     sub-expressions:
# 47. (_a)
#     core type: ExprTuple
#     sub-expressions: 48
# 48. _a
#     core type: Variable
#     sub-expressions:
