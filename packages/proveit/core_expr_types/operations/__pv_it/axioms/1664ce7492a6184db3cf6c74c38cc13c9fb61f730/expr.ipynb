# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.operations</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, f
from proveit.core_expr_types import f__x_1_to_n, f__y_1_to_n, x_1_to_n, y_1_to_n
from proveit.logic import Equals

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([f, x_1_to_n, y_1_to_n], Conditional(Equals(f__x_1_to_n, f__y_1_to_n).with_wrapping_at(2), Equals([x_1_to_n], [y_1_to_n]))))
# Out:
# expr: ((f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n}) -> {f(x_{1}, ..x_{_a}.., x_{n}) =  \\ f(y_{1}, ..y_{_a}.., y_{n}) if (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}).)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(f, x_{1}, \ldots, x_{n}, y_{1}, \ldots, y_{n}\right) \mapsto \left\{\begin{array}{c} \begin{array}{l} f(x_{1}, \ldots, x_{n}) =  \\ f(y_{1}, \ldots, y_{n}) \end{array} \end{array} \textrm{ if } \left(x_{1}, \ldots, x_{n}\right) = \left(y_{1}, \ldots, y_{n}\right)\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n}) -> {f(x_{1}, ..x_{_a}.., x_{n}) =  \\ f(y_{1}, ..y_{_a}.., y_{n}) if (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n}) -> {f(x_{1}, ..x_{_a}.., x_{n}) =  \\ f(y_{1}, ..y_{_a}.., y_{n}) if (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}).
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n})
#    core type: ExprTuple
#    sub-expressions: 12, 14, 15
# 3. {f(x_{1}, ..x_{_a}.., x_{n}) =  \\ f(y_{1}, ..y_{_a}.., y_{n}) if (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. f(x_{1}, ..x_{_a}.., x_{n}) =  \\ f(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 7
#    operands: 6
# 5. (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (f(x_{1}, ..x_{_a}.., x_{n}), f(y_{1}, ..y_{_a}.., y_{n}))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. ((x_{1}, ..x_{_a}.., x_{n}), (y_{1}, ..y_{_a}.., y_{n}))
#    core type: ExprTuple
#    sub-expressions: 11, 13
# 9. f(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 12
#    operands: 11
# 10. f(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 14
# 12. f
#     core type: Variable
#     sub-expressions:
# 13. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 15
# 14. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 18
#     end_index: 19
# 15. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 18
#     end_index: 19
# 16. _a -> x_{_a}
#     core type: Lambda
#     parameter: 25
#     body: 20
# 17. _a -> y_{_a}
#     core type: Lambda
#     parameter: 25
#     body: 21
# 18. 1
#     core type: Literal
#     sub-expressions:
# 19. n
#     core type: Variable
#     sub-expressions:
# 20. x_{_a}
#     core type: IndexedVar
# variable: 22
# index: 25
# 21. y_{_a}
#     core type: IndexedVar
# variable: 23
# index: 25
# 22. x
#     core type: Variable
#     sub-expressions:
# 23. y
#     core type: Variable
#     sub-expressions:
# 24. (_a)
#     core type: ExprTuple
#     sub-expressions: 25
# 25. _a
#     core type: Variable
#     sub-expressions:
