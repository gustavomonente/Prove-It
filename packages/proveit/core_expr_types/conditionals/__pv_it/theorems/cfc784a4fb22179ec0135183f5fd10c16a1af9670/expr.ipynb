# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.conditionals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, m
from proveit.core_expr_types import Q_1_to_m
from proveit.logic import And, Equals, Forall, TRUE
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
sub_expr1 = And(Q_1_to_m)
expr = Forall([m], Forall([a, Q_1_to_m], Equals(Conditional(a, And(TRUE, sub_expr1)), Conditional(a, sub_expr1)).with_wrapping_at(1)), domains = [Natural])
# Out:
# expr: forall_{m in Natural} [forall_{a, Q_{1}, ..Q_{_a}.., Q_{m}} ({a if TRUE ,  Q_{1} and ..Q_{_a}.. and Q_{m}. \\  = {a if Q_{1} and ..Q_{_a}.. and Q_{m}.)]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{m \in \mathbb{N}}~\left[\forall_{a, Q_{1}, \ldots, Q_{m}}~\left(\begin{array}{c} \begin{array}{l} \left\{a \textrm{ if } \top ,  Q_{1} \land \ldots \land Q_{m}\right.. \\  = \left\{a \textrm{ if } Q_{1} \land \ldots \land Q_{m}\right.. \end{array} \end{array}\right)\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{m in Natural} [forall_{a, Q_{1}, ..Q_{_a}.., Q_{m}} ({a if TRUE ,  Q_{1} and ..Q_{_a}.. and Q_{m}. \\  = {a if Q_{1} and ..Q_{_a}.. and Q_{m}.)]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (m -> {forall_{a, Q_{1}, ..Q_{_a}.., Q_{m}} ({a if TRUE ,  Q_{1} and ..Q_{_a}.. and Q_{m}. \\  = {a if Q_{1} and ..Q_{_a}.. and Q_{m}.) if m in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. m -> {forall_{a, Q_{1}, ..Q_{_a}.., Q_{m}} ({a if TRUE ,  Q_{1} and ..Q_{_a}.. and Q_{m}. \\  = {a if Q_{1} and ..Q_{_a}.. and Q_{m}.) if m in Natural.
#    core type: Lambda
#    parameter: 28
#    body: 3
# 3. {forall_{a, Q_{1}, ..Q_{_a}.., Q_{m}} ({a if TRUE ,  Q_{1} and ..Q_{_a}.. and Q_{m}. \\  = {a if Q_{1} and ..Q_{_a}.. and Q_{m}.) if m in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{a, Q_{1}, ..Q_{_a}.., Q_{m}} ({a if TRUE ,  Q_{1} and ..Q_{_a}.. and Q_{m}. \\  = {a if Q_{1} and ..Q_{_a}.. and Q_{m}.)
#    core type: Operation
#    operator: 6
#    operand: 10
# 5. m in Natural
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((a, Q_{1}, ..Q_{_a}.., Q_{m}) -> ({a if TRUE ,  Q_{1} and ..Q_{_a}.. and Q_{m}. \\  = {a if Q_{1} and ..Q_{_a}.. and Q_{m}.))
#    core type: ExprTuple
#    sub-expressions: 10
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (m, Natural)
#    core type: ExprTuple
#    sub-expressions: 28, 11
# 10. (a, Q_{1}, ..Q_{_a}.., Q_{m}) -> ({a if TRUE ,  Q_{1} and ..Q_{_a}.. and Q_{m}. \\  = {a if Q_{1} and ..Q_{_a}.. and Q_{m}.)
#     core type: Lambda
#     parameters: 12\n    body: 13
# 11. Natural
#     core type: Literal
#     sub-expressions:
# 12. (a, Q_{1}, ..Q_{_a}.., Q_{m})
#     core type: ExprTuple
#     sub-expressions: 19, 25
# 13. {a if TRUE ,  Q_{1} and ..Q_{_a}.. and Q_{m}. \\  = {a if Q_{1} and ..Q_{_a}.. and Q_{m}.
#     core type: Operation
#     operator: 14
#     operands: 15
# 14. =
#     core type: Literal
#     sub-expressions:
# 15. (a if TRUE ,  Q_{1} and ..Q_{_a}.. and Q_{m}, a if Q_{1} and ..Q_{_a}.. and Q_{m})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. {a if TRUE ,  Q_{1} and ..Q_{_a}.. and Q_{m}.
#     core type: Conditional
#     value: 19
#     condition: 18
# 17. {a if Q_{1} and ..Q_{_a}.. and Q_{m}.
#     core type: Conditional
#     value: 19
#     condition: 22
# 18. TRUE and (Q_{1} and ..Q_{_a}.. and Q_{m})
#     core type: Operation
#     operator: 23
#     operands: 20
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. (TRUE, Q_{1} and ..Q_{_a}.. and Q_{m})
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 21. TRUE
#     core type: Literal
#     sub-expressions:
# 22. Q_{1} and ..Q_{_a}.. and Q_{m}
#     core type: Operation
#     operator: 23
#     operands: 24
# 23. and
#     core type: Literal
#     sub-expressions:
# 24. (Q_{1}, ..Q_{_a}.., Q_{m})
#     core type: ExprTuple
#     sub-expressions: 25
# 25. Q_{1}, ..Q_{_a}.., Q_{m}
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 27
#     end_index: 28
# 26. _a -> Q_{_a}
#     core type: Lambda
#     parameter: 32
#     body: 29
# 27. 1
#     core type: Literal
#     sub-expressions:
# 28. m
#     core type: Variable
#     sub-expressions:
# 29. Q_{_a}
#     core type: IndexedVar
# variable: 30
# index: 32
# 30. Q
#     core type: Variable
#     sub-expressions:
# 31. (_a)
#     core type: ExprTuple
#     sub-expressions: 32
# 32. _a
#     core type: Variable
#     sub-expressions:
