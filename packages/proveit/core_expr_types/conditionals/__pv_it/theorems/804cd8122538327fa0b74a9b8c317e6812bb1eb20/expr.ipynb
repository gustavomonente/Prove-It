# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.conditionals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, R, a
from proveit.core_expr_types import Q_1_to_m
from proveit.logic import And, Equals

# %%
# build up the expression from sub-expressions
expr = Lambda([a, Q_1_to_m, R], Equals(Conditional(a, And(And(Q_1_to_m), R)), Conditional(a, And(Q_1_to_m, R))).with_wrapping_at(1))
# Out:
# expr: (a, Q_{1}, ..Q_{_a}.., Q_{m}, R) -> ({a if Q_{1} and ..Q_{_a}.. and Q_{m} ,  R. \\  = {a if Q_{1} ,  ..Q_{_a}.. ,  Q_{m} ,  R.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, Q_{1}, \ldots, Q_{m}, R\right) \mapsto \left(\begin{array}{c} \begin{array}{l} \left\{a \textrm{ if } Q_{1} \land \ldots \land Q_{m} ,  R\right.. \\  = \left\{a \textrm{ if } Q_{1} ,  \ldots ,  Q_{m} ,  R\right.. \end{array} \end{array}\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, Q_{1}, ..Q_{_a}.., Q_{m}, R) -> ({a if Q_{1} and ..Q_{_a}.. and Q_{m} ,  R. \\  = {a if Q_{1} ,  ..Q_{_a}.. ,  Q_{m} ,  R.)
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a, Q_{1}, ..Q_{_a}.., Q_{m}, R)
#    core type: ExprTuple
#    sub-expressions: 8, 16, 13
# 2. {a if Q_{1} and ..Q_{_a}.. and Q_{m} ,  R. \\  = {a if Q_{1} ,  ..Q_{_a}.. ,  Q_{m} ,  R.
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (a if Q_{1} and ..Q_{_a}.. and Q_{m} ,  R, a if Q_{1} ,  ..Q_{_a}.. ,  Q_{m} ,  R)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. {a if Q_{1} and ..Q_{_a}.. and Q_{m} ,  R.
#    core type: Conditional
#    value: 8
#    condition: 7
# 6. {a if Q_{1} ,  ..Q_{_a}.. ,  Q_{m} ,  R.
#    core type: Conditional
#    value: 8
#    condition: 9
# 7. (Q_{1} and ..Q_{_a}.. and Q_{m}) and R
#    core type: Operation
#    operator: 14
#    operands: 10
# 8. a
#    core type: Variable
#    sub-expressions:
# 9. Q_{1} and ..Q_{_a}.. and Q_{m} and R
#    core type: Operation
#    operator: 14
#    operands: 11
# 10. (Q_{1} and ..Q_{_a}.. and Q_{m}, R)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. (Q_{1}, ..Q_{_a}.., Q_{m}, R)
#     core type: ExprTuple
#     sub-expressions: 16, 13
# 12. Q_{1} and ..Q_{_a}.. and Q_{m}
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. R
#     core type: Variable
#     sub-expressions:
# 14. and
#     core type: Literal
#     sub-expressions:
# 15. (Q_{1}, ..Q_{_a}.., Q_{m})
#     core type: ExprTuple
#     sub-expressions: 16
# 16. Q_{1}, ..Q_{_a}.., Q_{m}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 18
#     end_index: 19
# 17. _a -> Q_{_a}
#     core type: Lambda
#     parameter: 23
#     body: 20
# 18. 1
#     core type: Literal
#     sub-expressions:
# 19. m
#     core type: Variable
#     sub-expressions:
# 20. Q_{_a}
#     core type: IndexedVar
# variable: 21
# index: 23
# 21. Q
#     core type: Variable
#     sub-expressions:
# 22. (_a)
#     core type: ExprTuple
#     sub-expressions: 23
# 23. _a
#     core type: Variable
#     sub-expressions:
