# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.conditionals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, Q, a
from proveit.core_expr_types import R_1_to_n
from proveit.logic import And, Equals

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([a, Q, R_1_to_n], Equals(Conditional(a, And(Q, And(R_1_to_n))), Conditional(a, And(Q, R_1_to_n))).with_wrapping_at(1)))
# Out:
# expr: ((a, Q, R_{1}, ..R_{_a}.., R_{n}) -> ({a if Q ,  R_{1} and ..R_{_a}.. and R_{n}. \\  = {a if Q ,  R_{1} ,  ..R_{_a}.. ,  R_{n}.))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a, Q, R_{1}, \ldots, R_{n}\right) \mapsto \left(\begin{array}{c} \begin{array}{l} \left\{a \textrm{ if } Q ,  R_{1} \land \ldots \land R_{n}\right.. \\  = \left\{a \textrm{ if } Q ,  R_{1} ,  \ldots ,  R_{n}\right.. \end{array} \end{array}\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a, Q, R_{1}, ..R_{_a}.., R_{n}) -> ({a if Q ,  R_{1} and ..R_{_a}.. and R_{n}. \\  = {a if Q ,  R_{1} ,  ..R_{_a}.. ,  R_{n}.))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a, Q, R_{1}, ..R_{_a}.., R_{n}) -> ({a if Q ,  R_{1} and ..R_{_a}.. and R_{n}. \\  = {a if Q ,  R_{1} ,  ..R_{_a}.. ,  R_{n}.)
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (a, Q, R_{1}, ..R_{_a}.., R_{n})
#    core type: ExprTuple
#    sub-expressions: 9, 14, 17
# 3. {a if Q ,  R_{1} and ..R_{_a}.. and R_{n}. \\  = {a if Q ,  R_{1} ,  ..R_{_a}.. ,  R_{n}.
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (a if Q ,  R_{1} and ..R_{_a}.. and R_{n}, a if Q ,  R_{1} ,  ..R_{_a}.. ,  R_{n})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. {a if Q ,  R_{1} and ..R_{_a}.. and R_{n}.
#    core type: Conditional
#    value: 9
#    condition: 8
# 7. {a if Q ,  R_{1} ,  ..R_{_a}.. ,  R_{n}.
#    core type: Conditional
# ...
