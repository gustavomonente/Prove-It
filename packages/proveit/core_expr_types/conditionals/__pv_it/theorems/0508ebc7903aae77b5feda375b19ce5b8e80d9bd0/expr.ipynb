# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.conditionals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a
from proveit.core_expr_types import Q_1_to_m
from proveit.logic import And, Equals, Forall, TRUE

# %%
# build up the expression from sub-expressions
sub_expr1 = And(Q_1_to_m)
expr = Forall([a, Q_1_to_m], Equals(Conditional(a, And(sub_expr1, TRUE)), Conditional(a, sub_expr1)).with_wrapping_at(1))
# Out:
# expr: forall_{a, Q_{1}, ..Q_{_a}.., Q_{m}} ({a if Q_{1} and ..Q_{_a}.. and Q_{m} ,  TRUE. \\  = {a if Q_{1} and ..Q_{_a}.. and Q_{m}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a, Q_{1}, \ldots, Q_{m}}~\left(\begin{array}{c} \begin{array}{l} \left\{a \textrm{ if } Q_{1} \land \ldots \land Q_{m} ,  \top\right.. \\  = \left\{a \textrm{ if } Q_{1} \land \ldots \land Q_{m}\right.. \end{array} \end{array}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a, Q_{1}, ..Q_{_a}.., Q_{m}} ({a if Q_{1} and ..Q_{_a}.. and Q_{m} ,  TRUE. \\  = {a if Q_{1} and ..Q_{_a}.. and Q_{m}.)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, Q_{1}, ..Q_{_a}.., Q_{m}) -> ({a if Q_{1} and ..Q_{_a}.. and Q_{m} ,  TRUE. \\  = {a if Q_{1} and ..Q_{_a}.. and Q_{m}.))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, Q_{1}, ..Q_{_a}.., Q_{m}) -> ({a if Q_{1} and ..Q_{_a}.. and Q_{m} ,  TRUE. \\  = {a if Q_{1} and ..Q_{_a}.. and Q_{m}.)
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a, Q_{1}, ..Q_{_a}.., Q_{m})
#    core type: ExprTuple
#    sub-expressions: 11, 17
# 5. {a if Q_{1} and ..Q_{_a}.. and Q_{m} ,  TRUE. \\  = {a if Q_{1} and ..Q_{_a}.. and Q_{m}.
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (a if Q_{1} and ..Q_{_a}.. and Q_{m} ,  TRUE, a if Q_{1} and ..Q_{_a}.. and Q_{m})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. {a if Q_{1} and ..Q_{_a}.. and Q_{m} ,  TRUE.
#    core type: Conditional
#    value: 11
#    condition: 10
# 9. {a if Q_{1} and ..Q_{_a}.. and Q_{m}.
#    core type: Conditional
#    value: 11
#    condition: 13
# 10. (Q_{1} and ..Q_{_a}.. and Q_{m}) and TRUE
#     core type: Operation
#     operator: 15
#     operands: 12
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. (Q_{1} and ..Q_{_a}.. and Q_{m}, TRUE)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. Q_{1} and ..Q_{_a}.. and Q_{m}
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. TRUE
#     core type: Literal
#     sub-expressions:
# 15. and
#     core type: Literal
#     sub-expressions:
# 16. (Q_{1}, ..Q_{_a}.., Q_{m})
#     core type: ExprTuple
#     sub-expressions: 17
# 17. Q_{1}, ..Q_{_a}.., Q_{m}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 19
#     end_index: 20
# 18. _a -> Q_{_a}
#     core type: Lambda
#     parameter: 24
#     body: 21
# 19. 1
#     core type: Literal
#     sub-expressions:
# 20. m
#     core type: Variable
#     sub-expressions:
# 21. Q_{_a}
#     core type: IndexedVar
# variable: 22
# index: 24
# 22. Q
#     core type: Variable
#     sub-expressions:
# 23. (_a)
#     core type: ExprTuple
#     sub-expressions: 24
# 24. _a
#     core type: Variable
#     sub-expressions:
