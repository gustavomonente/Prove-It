# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable, a, b, k, m
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Add, NaturalPos, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = ExprRange(sub_expr1, IndexedVar(a, sub_expr1), one, m)
sub_expr3 = ExprRange(sub_expr1, IndexedVar(b, sub_expr1), one, m)
sub_expr4 = Equals(IndexedVar(a, k), IndexedVar(b, k))
expr = ExprTuple(InSet(m, NaturalPos), Forall([sub_expr2, sub_expr3], Equals([sub_expr2], [sub_expr3]), condition = ExprRange(k, sub_expr4, one, m)), ExprRange(k, sub_expr4, one, Add(m, one)))
# Out:
# expr: (m in NaturalPos, forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})), a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(m \in \mathbb{N}^+, \forall_{a_{1}, \ldots, a_{m}, b_{1}, \ldots, b_{m}~|~a_{1} = b_{1}, \ldots, a_{m} = b_{m}}~\left(\left(a_{1}, \ldots, a_{m}\right) = \left(b_{1}, \ldots, b_{m}\right)\right), a_{1} = b_{1}, \ldots, a_{m + 1} = b_{m + 1}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (m in NaturalPos, forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})), a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. m in NaturalPos
#    core type: Operation
#    operator: 4
#    operands: 5
# 2. forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))
#    core type: Operation
#    operator: 6
#    operand: 10
# 3. (a_{1} = b_{1}), ..(a_{k} = b_{k}).., (a_{m + 1} = b_{m + 1})
#    core type: ExprRange
#    lambda_map: 25
#    start_index: 28
#    end_index: 8
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (m, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 29, 9
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m}) -> {(a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m}).)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. m + 1
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. (a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m}) -> {(a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m}).
#     core type: Lambda
#     parameters: 13\n    body: 14
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 29, 28
# 13. (a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 14. {(a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m}).
#     core type: Conditional
#     value: 15
#     condition: 16
# 15. (a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})
#     core type: Operation
#     operator: 33
#     operands: 17
# 16. (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m})
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. ((a_{1}, ..a_{_a}.., a_{m}), (b_{1}, ..b_{_a}.., b_{m}))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. and
#     core type: Literal
#     sub-expressions:
# 19. (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})
#     core type: ExprTuple
#     sub-expressions: 22
# 20. (a_{1}, ..a_{_a}.., a_{m})
#     core type: ExprTuple
#     sub-expressions: 23
# 21. (b_{1}, ..b_{_a}.., b_{m})
#     core type: ExprTuple
#     sub-expressions: 24
# 22. (a_{1} = b_{1}), ..(a_{k} = b_{k}).., (a_{m} = b_{m})
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 28
#     end_index: 29
# 23. a_{1}, ..a_{_a}.., a_{m}
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 28
#     end_index: 29
# 24. b_{1}, ..b_{_a}.., b_{m}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 28
#     end_index: 29
# 25. k -> (a_{k} = b_{k})
#     core type: Lambda
#     parameter: 42
#     body: 30
# 26. _a -> a_{_a}
#     core type: Lambda
#     parameter: 38
#     body: 31
# 27. _a -> b_{_a}
#     core type: Lambda
#     parameter: 38
#     body: 32
# 28. 1
#     core type: Literal
#     sub-expressions:
# 29. m
#     core type: Variable
#     sub-expressions:
# 30. a_{k} = b_{k}
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. a_{_a}
#     core type: IndexedVar
# variable: 39
# index: 38
# 32. b_{_a}
#     core type: IndexedVar
# variable: 40
# index: 38
# 33. =
#     core type: Literal
#     sub-expressions:
# 34. (a_{k}, b_{k})
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 35. (_a)
#     core type: ExprTuple
#     sub-expressions: 38
# 36. a_{k}
#     core type: IndexedVar
# variable: 39
# index: 42
# 37. b_{k}
#     core type: IndexedVar
# variable: 40
# index: 42
# 38. _a
#     core type: Variable
#     sub-expressions:
# 39. a
#     core type: Variable
#     sub-expressions:
# 40. b
#     core type: Variable
#     sub-expressions:
# 41. (k)
#     core type: ExprTuple
#     sub-expressions: 42
# 42. k
#     core type: Variable
#     sub-expressions:
