# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable, a, b
from proveit.logic import Equals
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(ExprRange(sub_expr1, Equals(IndexedVar(a, sub_expr1), IndexedVar(b, sub_expr1)), one, one))
# Out:
# expr: (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{1} = b_{1})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1} = b_{1}, \ldots, a_{1} = b_{1}\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{1} = b_{1})
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a_{1} = b_{1}), ..(a_{_a} = b_{_a}).., (a_{1} = b_{1})
#    core type: ExprRange
#    lambda_map: 2
#    start_index: 3
#    end_index: 3
# 2. _a -> (a_{_a} = b_{_a})
#    core type: Lambda
#    parameter: 12
#    body: 4
# 3. 1
#    core type: Literal
#    sub-expressions:
# 4. a_{_a} = b_{_a}
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (a_{_a}, b_{_a})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. a_{_a}
#    core type: IndexedVar
# variable: 9
# index: 12
# 8. b_{_a}
#    core type: IndexedVar
# variable: 10
# index: 12
# 9. a
#    core type: Variable
#    sub-expressions:
# 10. b
#     core type: Variable
#     sub-expressions:
# 11. (_a)
#     core type: ExprTuple
#     sub-expressions: 12
# 12. _a
#     core type: Variable
#     sub-expressions:
