# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable, a, m
from proveit.numbers import Add, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple([ExprRange(sub_expr1, IndexedVar(a, sub_expr1), one, Add(m, one))], Variable("_b", latex_format = r"{_{-}b}"))
# Out:
# expr: ((a_{1}, ..a_{_a}.., a_{m + 1}), _b)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a_{1}, \ldots, a_{m + 1}\right), {_{-}b}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a_{1}, ..a_{_a}.., a_{m + 1}), _b)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (a_{1}, ..a_{_a}.., a_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 3
# 2. _b
#    core type: Variable
#    sub-expressions:
# 3. a_{1}, ..a_{_a}.., a_{m + 1}
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 12
#    end_index: 5
# 4. _a -> a_{_a}
#    core type: Lambda
#    parameter: 13
#    body: 6
# 5. m + 1
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. a_{_a}
#    core type: IndexedVar
# variable: 9
# index: 13
# 7. +
#    core type: Literal
#    sub-expressions:
# 8. (m, 1)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. a
#    core type: Variable
#    sub-expressions:
# 10. (_a)
#     core type: ExprTuple
#     sub-expressions: 13
# 11. m
#     core type: Variable
#     sub-expressions:
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. _a
#     core type: Variable
#     sub-expressions:
