# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Function.html">Function</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, Function, IndexedVar, P, Variable, m
from proveit.numbers import Add, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_b", latex_format = r"{_{-}b}")
expr = Function(P, [ExprRange(sub_expr1, IndexedVar(Variable("_a", latex_format = r"{_{-}a}"), sub_expr1), one, Add(m, one))])
# Out:
# expr: P(_a_{1}, .._a_{_b}.., _a_{m + 1})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# P({_{-}a}_{1}, \ldots, {_{-}a}_{m + 1})

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. P(_a_{1}, .._a_{_b}.., _a_{m + 1})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. P
#    core type: Variable
#    sub-expressions:
# 2. (_a_{1}, .._a_{_b}.., _a_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 3
# 3. _a_{1}, .._a_{_b}.., _a_{m + 1}
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 12
#    end_index: 5
# 4. _b -> _a_{_b}
#    core type: Lambda
#    parameter: 13
#    body: 6
# 5. m + 1
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. _a_{_b}
#    core type: IndexedVar
# variable: 9
# index: 13
# 7. +
#    core type: Literal
#    sub-expressions:
# 8. (m, 1)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. _a
#    core type: Variable
#    sub-expressions:
# 10. (_b)
#     core type: ExprTuple
#     sub-expressions: 13
# 11. m
#     core type: Variable
#     sub-expressions:
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. _b
#     core type: Variable
#     sub-expressions:
