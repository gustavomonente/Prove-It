# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, a, b, k, m, n
from proveit.logic import And, Equals, Forall, Implies
from proveit.numbers import Add, NaturalPos, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [NaturalPos]
sub_expr3 = IndexedVar(a, one)
sub_expr4 = IndexedVar(b, one)
sub_expr5 = IndexedVar(a, sub_expr1)
sub_expr6 = Add(m, one)
sub_expr7 = IndexedVar(b, sub_expr1)
sub_expr8 = ExprRange(sub_expr1, sub_expr5, one, sub_expr6)
sub_expr9 = ExprRange(sub_expr1, sub_expr7, one, sub_expr6)
sub_expr10 = Equals(IndexedVar(a, k), IndexedVar(b, k))
sub_expr11 = ExprRange(sub_expr1, sub_expr5, one, m)
sub_expr12 = ExprRange(sub_expr1, sub_expr7, one, m)
sub_expr13 = ExprRange(sub_expr1, sub_expr5, one, n)
sub_expr14 = ExprRange(sub_expr1, sub_expr7, one, n)
expr = Implies(And(Forall([sub_expr3, sub_expr4], Equals([sub_expr3], [sub_expr4]), condition = Equals(sub_expr3, sub_expr4)), Forall([m], Forall([sub_expr8, sub_expr9], Equals([sub_expr8], [sub_expr9]), condition = ExprRange(k, sub_expr10, one, sub_expr6)), domains = sub_expr2, condition = Forall([sub_expr11, sub_expr12], Equals([sub_expr11], [sub_expr12]), condition = ExprRange(k, sub_expr10, one, m)))), Forall([n], Forall([sub_expr13, sub_expr14], Equals([sub_expr13], [sub_expr14]), condition = ExprRange(k, sub_expr10, one, n)), domains = sub_expr2))
# Out:
# expr: ([forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] and [forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]) => [forall_{n in NaturalPos} [forall_{a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}} ((a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n}))]]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left[\forall_{a_{1}, b_{1}~|~a_{1} = b_{1}}~\left(\left(a_{1}\right) = \left(b_{1}\right)\right)\right] \land \left[\forall_{m \in \mathbb{N}^+~|~\forall_{a_{1}, \ldots, a_{m}, b_{1}, \ldots, b_{m}~|~a_{1} = b_{1}, \ldots, a_{m} = b_{m}}~\left(\left(a_{1}, \ldots, a_{m}\right) = \left(b_{1}, \ldots, b_{m}\right)\right)}~\left[\forall_{a_{1}, \ldots, a_{m + 1}, b_{1}, \ldots, b_{m + 1}~|~a_{1} = b_{1}, \ldots, a_{m + 1} = b_{m + 1}}~\left(\left(a_{1}, \ldots, a_{m + 1}\right) = \left(b_{1}, \ldots, b_{m + 1}\right)\right)\right]\right]\right) \Rightarrow \left[\forall_{n \in \mathbb{N}^+}~\left[\forall_{a_{1}, \ldots, a_{n}, b_{1}, \ldots, b_{n}~|~a_{1} = b_{1}, \ldots, a_{n} = b_{n}}~\left(\left(a_{1}, \ldots, a_{n}\right) = \left(b_{1}, \ldots, b_{n}\right)\right)\right]\right]

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ([forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] and [forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]) => [forall_{n in NaturalPos} [forall_{a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}} ((a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n}))]]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. ([forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] and [forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]], forall_{n in NaturalPos} [forall_{a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}} ((a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n}))])
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. [forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] and [forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]
#    core type: Operation
#    operator: 72
#    operands: 5
# 4. forall_{n in NaturalPos} [forall_{a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}} ((a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n}))]
#    core type: Operation
#    operator: 45
#    operand: 9
# 5. (forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1})), forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))])
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (n -> {forall_{a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}} ((a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n})) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))
#    core type: Operation
#    operator: 45
#    operand: 13
# 8. forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]
#    core type: Operation
#    operator: 45
#    operand: 14
# 9. n -> {forall_{a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}} ((a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n})) if n in NaturalPos.
#    core type: Lambda
#    parameter: 68
#    body: 12
# 10. ((a_{1}, b_{1}) -> {(a_{1}) = (b_{1}) if a_{1} = b_{1}.)
#     core type: ExprTuple
#     sub-expressions: 13
# 11. (m -> {forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1})) if m in NaturalPos ,  forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})).)
#     core type: ExprTuple
#     sub-expressions: 14
# 12. {forall_{a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}} ((a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n})) if n in NaturalPos.
#     core type: Conditional
#     value: 15
#     condition: 16
# 13. (a_{1}, b_{1}) -> {(a_{1}) = (b_{1}) if a_{1} = b_{1}.
#     core type: Lambda
#     parameters: 27\n    body: 17
# 14. m -> {forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1})) if m in NaturalPos ,  forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})).
#     core type: Lambda
#     parameter: 86
#     body: 18
# 15. forall_{a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}} ((a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n}))
#     core type: Operation
#     operator: 45
#     operand: 25
# 16. n in NaturalPos
#     core type: Operation
#     operator: 43
#     operands: 20
# 17. {(a_{1}) = (b_{1}) if a_{1} = b_{1}.
#     core type: Conditional
#     value: 21
#     condition: 22
# 18. {forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1})) if m in NaturalPos ,  forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})).
#     core type: Conditional
#     value: 23
#     condition: 24
# 19. ((a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n}) -> {(a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{n} = b_{n}).)
#     core type: ExprTuple
#     sub-expressions: 25
# 20. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 68, 52
# 21. (a_{1}) = (b_{1})
#     core type: Operation
#     operator: 90
#     operands: 26
# 22. a_{1} = b_{1}
#     core type: Operation
#     operator: 90
#     operands: 27
# 23. forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))
#     core type: Operation
#     operator: 45
#     operand: 34
# 24. (m in NaturalPos) and [forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))]
#     core type: Operation
#     operator: 72
#     operands: 29
# 25. (a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n}) -> {(a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{n} = b_{n}).
#     core type: Lambda
#     parameters: 30\n    body: 31
# 26. ((a_{1}), (b_{1}))
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 27. (a_{1}, b_{1})
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 28. ((a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1}) -> {(a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1}).)
#     core type: ExprTuple
#     sub-expressions: 34
# 29. (m in NaturalPos, forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})))
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 30. (a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n})
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 31. {(a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{n} = b_{n}).
#     core type: Conditional
#     value: 37
#     condition: 38
# 32. (a_{1})
#     core type: ExprTuple
#     sub-expressions: 39
# 33. (b_{1})
#     core type: ExprTuple
#     sub-expressions: 40
# 34. (a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1}) -> {(a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1}).
#     core type: Lambda
#     parameters: 41\n    body: 42
# 35. m in NaturalPos
#     core type: Operation
#     operator: 43
#     operands: 44
# 36. forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))
#     core type: Operation
#     operator: 45
#     operand: 53
# 37. (a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n})
#     core type: Operation
#     operator: 90
#     operands: 47
# 38. (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{n} = b_{n})
#     core type: Operation
#     operator: 72
#     operands: 48
# 39. a_{1}
#     core type: IndexedVar
# variable: 96
# index: 85
# 40. b_{1}
#     core type: IndexedVar
# variable: 97
# index: 85
# 41. (a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 69, 70
# 42. {(a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1}).
#     core type: Conditional
#     value: 50
#     condition: 51
# 43. in
#     core type: Literal
#     sub-expressions:
# 44. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 86, 52
# 45. forall
#     core type: Literal
#     sub-expressions:
# 46. ((a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m}) -> {(a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m}).)
#     core type: ExprTuple
#     sub-expressions: 53
# 47. ((a_{1}, ..a_{_a}.., a_{n}), (b_{1}, ..b_{_a}.., b_{n}))
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 48. (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n})
#     core type: ExprTuple
#     sub-expressions: 56
# 49. (1)
#     core type: ExprTuple
#     sub-expressions: 85
# 50. (a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1})
#     core type: Operation
#     operator: 90
#     operands: 57
# 51. (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1})
#     core type: Operation
#     operator: 72
#     operands: 58
# 52. NaturalPos
#     core type: Literal
#     sub-expressions:
# 53. (a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m}) -> {(a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m}).
#     core type: Lambda
#     parameters: 59\n    body: 60
# 54. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 61
# 55. (b_{1}, ..b_{_a}.., b_{n})
#     core type: ExprTuple
#     sub-expressions: 62
# 56. (a_{1} = b_{1}), ..(a_{k} = b_{k}).., (a_{n} = b_{n})
#     core type: ExprRange
#     lambda_map: 82
#     start_index: 85
#     end_index: 68
# 57. ((a_{1}, ..a_{_a}.., a_{m + 1}), (b_{1}, ..b_{_a}.., b_{m + 1}))
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 58. (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 65
# 59. (a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m})
#     core type: ExprTuple
#     sub-expressions: 80, 81
# 60. {(a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m}).
#     core type: Conditional
#     value: 66
#     condition: 67
# 61. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 83
#     start_index: 85
#     end_index: 68
# 62. b_{1}, ..b_{_a}.., b_{n}
#     core type: ExprRange
#     lambda_map: 84
#     start_index: 85
#     end_index: 68
# 63. (a_{1}, ..a_{_a}.., a_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 69
# 64. (b_{1}, ..b_{_a}.., b_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 70
# 65. (a_{1} = b_{1}), ..(a_{k} = b_{k}).., (a_{m + 1} = b_{m + 1})
#     core type: ExprRange
#     lambda_map: 82
#     start_index: 85
#     end_index: 74
# 66. (a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})
#     core type: Operation
#     operator: 90
#     operands: 71
# 67. (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m})
#     core type: Operation
#     operator: 72
#     operands: 73
# 68. n
#     core type: Variable
#     sub-expressions:
# 69. a_{1}, ..a_{_a}.., a_{m + 1}
#     core type: ExprRange
#     lambda_map: 83
#     start_index: 85
#     end_index: 74
# 70. b_{1}, ..b_{_a}.., b_{m + 1}
#     core type: ExprRange
#     lambda_map: 84
#     start_index: 85
#     end_index: 74
# 71. ((a_{1}, ..a_{_a}.., a_{m}), (b_{1}, ..b_{_a}.., b_{m}))
#     core type: ExprTuple
#     sub-expressions: 75, 76
# 72. and
#     core type: Literal
#     sub-expressions:
# 73. (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})
#     core type: ExprTuple
#     sub-expressions: 77
# 74. m + 1
#     core type: Operation
#     operator: 78
#     operands: 79
# 75. (a_{1}, ..a_{_a}.., a_{m})
#     core type: ExprTuple
#     sub-expressions: 80
# 76. (b_{1}, ..b_{_a}.., b_{m})
#     core type: ExprTuple
#     sub-expressions: 81
# 77. (a_{1} = b_{1}), ..(a_{k} = b_{k}).., (a_{m} = b_{m})
#     core type: ExprRange
#     lambda_map: 82
#     start_index: 85
#     end_index: 86
# 78. +
#     core type: Literal
#     sub-expressions:
# 79. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 86, 85
# 80. a_{1}, ..a_{_a}.., a_{m}
#     core type: ExprRange
#     lambda_map: 83
#     start_index: 85
#     end_index: 86
# 81. b_{1}, ..b_{_a}.., b_{m}
#     core type: ExprRange
#     lambda_map: 84
#     start_index: 85
#     end_index: 86
# 82. k -> (a_{k} = b_{k})
#     core type: Lambda
#     parameter: 99
#     body: 87
# 83. _a -> a_{_a}
#     core type: Lambda
#     parameter: 95
#     body: 88
# 84. _a -> b_{_a}
#     core type: Lambda
#     parameter: 95
#     body: 89
# 85. 1
#     core type: Literal
#     sub-expressions:
# 86. m
#     core type: Variable
#     sub-expressions:
# 87. a_{k} = b_{k}
#     core type: Operation
#     operator: 90
#     operands: 91
# 88. a_{_a}
#     core type: IndexedVar
# variable: 96
# index: 95
# 89. b_{_a}
#     core type: IndexedVar
# variable: 97
# index: 95
# 90. =
#     core type: Literal
#     sub-expressions:
# 91. (a_{k}, b_{k})
#     core type: ExprTuple
#     sub-expressions: 93, 94
# 92. (_a)
#     core type: ExprTuple
#     sub-expressions: 95
# 93. a_{k}
#     core type: IndexedVar
# variable: 96
# index: 99
# 94. b_{k}
#     core type: IndexedVar
# variable: 97
# index: 99
# 95. _a
#     core type: Variable
#     sub-expressions:
# 96. a
#     core type: Variable
#     sub-expressions:
# 97. b
#     core type: Variable
#     sub-expressions:
# 98. (k)
#     core type: ExprTuple
#     sub-expressions: 99
# 99. k
#     core type: Variable
#     sub-expressions:
