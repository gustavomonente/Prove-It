# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Lambda, Variable, a, b, k, m
from proveit.logic import And, Equals
from proveit.numbers import Add, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Add(m, one)
sub_expr3 = ExprRange(sub_expr1, IndexedVar(a, sub_expr1), one, sub_expr2)
expr = Lambda([sub_expr3, ExprRange(sub_expr1, IndexedVar(b, sub_expr1), one, sub_expr2)], Conditional(Equals([sub_expr3], [ExprRange(a, IndexedVar(b, a), one, sub_expr2)]), And(ExprRange(k, Equals(IndexedVar(a, k), IndexedVar(b, k)), one, sub_expr2))))
# Out:
# expr: (a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1}) -> {(a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{a}.., b_{m + 1}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1}).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1}, \ldots, a_{m + 1}, b_{1}, \ldots, b_{m + 1}\right) \mapsto \left\{\left(a_{1}, \ldots, a_{m + 1}\right) = \left(b_{1}, \ldots, b_{m + 1}\right) \textrm{ if } \left(a_{1} = b_{1}\right) \land \ldots \land \left(a_{m + 1} = b_{m + 1}\right)\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1}) -> {(a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{a}.., b_{m + 1}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1}).
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 2. {(a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{a}.., b_{m + 1}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1}).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{a}.., b_{m + 1})
#    core type: Operation
#    operator: 23
#    operands: 5
# 4. (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1})
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. ((a_{1}, ..a_{_a}.., a_{m + 1}), (b_{1}, ..b_{a}.., b_{m + 1}))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 6. and
#    core type: Literal
# ...
