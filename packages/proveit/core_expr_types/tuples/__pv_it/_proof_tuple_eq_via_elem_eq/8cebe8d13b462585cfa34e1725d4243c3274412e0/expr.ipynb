# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.core_expr_types.Len.html">Len</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, a, b, m
from proveit.core_expr_types import Len
from proveit.logic import Equals
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Len([ExprRange(sub_expr1, Equals(IndexedVar(a, sub_expr1), IndexedVar(b, sub_expr1)), one, m)])
# Out:
# expr: |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})|

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(a_{1} = b_{1}, \ldots, a_{m} = b_{m}\right)|

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: function
# current value: function
# related methods: ()

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})|
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. length
#    core type: Literal
#    sub-expressions:
# 2. ((a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})
#    core type: ExprTuple
#    sub-expressions: 4
# 4. (a_{1} = b_{1}), ..(a_{_a} = b_{_a}).., (a_{m} = b_{m})
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 6
#    end_index: 7
# 5. _a -> (a_{_a} = b_{_a})
#    core type: Lambda
#    parameter: 16
#    body: 8
# 6. 1
#    core type: Literal
#    sub-expressions:
# 7. m
#    core type: Variable
#    sub-expressions:
# 8. a_{_a} = b_{_a}
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. =
#    core type: Literal
#    sub-expressions:
# 10. (a_{_a}, b_{_a})
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. a_{_a}
#     core type: IndexedVar
# variable: 13
# index: 16
# 12. b_{_a}
#     core type: IndexedVar
# variable: 14
# index: 16
# 13. a
#     core type: Variable
#     sub-expressions:
# 14. b
#     core type: Variable
#     sub-expressions:
# 15. (_a)
#     core type: ExprTuple
#     sub-expressions: 16
# 16. _a
#     core type: Variable
#     sub-expressions:
