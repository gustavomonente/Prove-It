# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, a, k, x
from proveit.core_expr_types import Len
from proveit.logic import Equals
from proveit.numbers import one, two

# %%
# build up the expression from sub-expressions
expr = Equals(Len([ExprRange(k, ExprRange(x, IndexedVar(a, [k, x]), one, two), one, one)]), Variable("_a", latex_format = r"{_{-}a}"))
# Out:
# expr: |(a_{1, 1}, ..a_{1, x}.., a_{1, 2}, ....a_{k, 1}, ..a_{k, x}.., a_{k, 2}...., a_{1, 1}, ..a_{1, x}.., a_{1, 2})| = _a

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(a_{1, 1}, \ldots, a_{1, 2}, \ldots\ldots, a_{1, 1}, \ldots, a_{1, 2}\right)| = {_{-}a}

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |(a_{1, 1}, ..a_{1, x}.., a_{1, 2}, ....a_{k, 1}, ..a_{k, x}.., a_{k, 2}...., a_{1, 1}, ..a_{1, x}.., a_{1, 2})| = _a
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|(a_{1, 1}, ..a_{1, x}.., a_{1, 2}, ....a_{k, 1}, ..a_{k, x}.., a_{k, 2}...., a_{1, 1}, ..a_{1, x}.., a_{1, 2})|, _a)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |(a_{1, 1}, ..a_{1, x}.., a_{1, 2}, ....a_{k, 1}, ..a_{k, x}.., a_{k, 2}...., a_{1, 1}, ..a_{1, x}.., a_{1, 2})|
#    core type: Operation
#    operator: 5
#    operand: 7
# 4. _a
#    core type: Variable
#    sub-expressions:
# 5. length
#    core type: Literal
#    sub-expressions:
# 6. ((a_{1, 1}, ..a_{1, x}.., a_{1, 2}, ....a_{k, 1}, ..a_{k, x}.., a_{k, 2}...., a_{1, 1}, ..a_{1, x}.., a_{1, 2}))
#    core type: ExprTuple
#    sub-expressions: 7
# 7. (a_{1, 1}, ..a_{1, x}.., a_{1, 2}, ....a_{k, 1}, ..a_{k, x}.., a_{k, 2}...., a_{1, 1}, ..a_{1, x}.., a_{1, 2})
#    core type: ExprTuple
#    sub-expressions: 8
# 8. a_{1, 1}, ..a_{1, x}.., a_{1, 2}, ....a_{k, 1}, ..a_{k, x}.., a_{k, 2}...., a_{1, 1}, ..a_{1, x}.., a_{1, 2}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 12
#    end_index: 12
# 9. k -> a_{k, 1}, ..a_{k, x}.., a_{k, 2}
#    core type: Lambda
#    parameter: 17
#    body: 10
# 10. a_{k, 1}, ..a_{k, x}.., a_{k, 2}
#     core type: ExprRange
#     lambda_map: 11
#     start_index: 12
#     end_index: 13
# 11. x -> a_{k, x}
#     core type: Lambda
#     parameter: 18
#     body: 14
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. 2
#     core type: Literal
#     sub-expressions:
# 14. a_{k, x}
#     core type: IndexedVar
# variable: 15
# indices: 16
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. (k, x)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. k
#     core type: Variable
#     sub-expressions:
# 18. x
#     core type: Variable
#     sub-expressions:
