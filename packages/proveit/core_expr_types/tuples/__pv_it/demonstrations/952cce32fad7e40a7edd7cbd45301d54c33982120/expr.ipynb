# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.core_expr_types.Len.html">Len</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, a, k, n, x
from proveit.core_expr_types import Len
from proveit.numbers import one, zero

# %%
# build up the expression from sub-expressions
expr = Len([ExprRange(k, ExprRange(x, IndexedVar(a, [k, x]), one, zero), one, n)])
# Out:
# expr: |(a_{1, 1}, ..a_{1, x}.., a_{1, 0}, ....a_{k, 1}, ..a_{k, x}.., a_{k, 0}...., a_{n, 1}, ..a_{n, x}.., a_{n, 0})|

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(a_{1, 1}, \ldots, a_{1, 0}, \ldots\ldots, a_{n, 1}, \ldots, a_{n, 0}\right)|

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: function
# current value: function
# related methods: ()

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |(a_{1, 1}, ..a_{1, x}.., a_{1, 0}, ....a_{k, 1}, ..a_{k, x}.., a_{k, 0}...., a_{n, 1}, ..a_{n, x}.., a_{n, 0})|
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. length
#    core type: Literal
#    sub-expressions:
# 2. ((a_{1, 1}, ..a_{1, x}.., a_{1, 0}, ....a_{k, 1}, ..a_{k, x}.., a_{k, 0}...., a_{n, 1}, ..a_{n, x}.., a_{n, 0}))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a_{1, 1}, ..a_{1, x}.., a_{1, 0}, ....a_{k, 1}, ..a_{k, x}.., a_{k, 0}...., a_{n, 1}, ..a_{n, x}.., a_{n, 0})
#    core type: ExprTuple
#    sub-expressions: 4
# 4. a_{1, 1}, ..a_{1, x}.., a_{1, 0}, ....a_{k, 1}, ..a_{k, x}.., a_{k, 0}...., a_{n, 1}, ..a_{n, x}.., a_{n, 0}
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 9
#    end_index: 6
# 5. k -> a_{k, 1}, ..a_{k, x}.., a_{k, 0}
#    core type: Lambda
#    parameter: 14
#    body: 7
# 6. n
#    core type: Variable
#    sub-expressions:
# 7. a_{k, 1}, ..a_{k, x}.., a_{k, 0}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 10
# 8. x -> a_{k, x}
#    core type: Lambda
#    parameter: 15
#    body: 11
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. 0
#     core type: Literal
#     sub-expressions:
# 11. a_{k, x}
#     core type: IndexedVar
# variable: 12
# indices: 13
# 12. a
#     core type: Variable
#     sub-expressions:
# 13. (k, x)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. k
#     core type: Variable
#     sub-expressions:
# 15. x
#     core type: Variable
#     sub-expressions:
