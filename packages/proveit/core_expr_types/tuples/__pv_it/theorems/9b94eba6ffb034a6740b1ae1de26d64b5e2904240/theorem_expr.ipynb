# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#range_from1_len">range_from1_len</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types.tuples import range_from1_len

# %%
# check that the built expression is the same as the stored expression
assert range_from1_len.expr == stored_expr
assert range_from1_len.expr._style_id == stored_expr._style_id
print("Passed sanity check: range_from1_len matches stored_expr")
# Out:
# Passed sanity check: range_from1_len matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(range_from1_len.latex())
# Out:
# \vdash \forall_{i \in \mathbb{N}}~\left[\forall_{f}~\left(|\left(f(1), \ldots, f(i)\right)| = i\right)\right]

# %%
range_from1_len.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
range_from1_len.expr_info()
# Out:
# 0. forall_{i in Natural} [forall_{f} (|(f(1), ..f(a).., f(i))| = i)]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (i -> {forall_{f} (|(f(1), ..f(a).., f(i))| = i) if i in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. i -> {forall_{f} (|(f(1), ..f(a).., f(i))| = i) if i in Natural.
#    core type: Lambda
#    parameter: 22
#    body: 3
# 3. {forall_{f} (|(f(1), ..f(a).., f(i))| = i) if i in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{f} (|(f(1), ..f(a).., f(i))| = i)
#    core type: Operation
#    operator: 6
#    operand: 10
# 5. i in Natural
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (f -> (|(f(1), ..f(a).., f(i))| = i))
#    core type: ExprTuple
#    sub-expressions: 10
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (i, Natural)
#    core type: ExprTuple
#    sub-expressions: 22, 11
# ...
