# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, f, i, j, k
from proveit.core_expr_types import merge_back_equiv
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Natural, Neg, one

# %%
# build up the expression from sub-expressions
expr = Lambda([f, i, j, k], Conditional(merge_back_equiv, And(InSet(Add(k, Neg(i)), Natural), Equals(k, Add(j, one)))))
# Out:
# expr: (f, i, j, k) -> {(f(i), ..f(a).., f(j), f(k)) =  \\ (f(i), ..f(a).., f(k)) if (k - i) in Natural ,  k = (j + 1).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(f, i, j, k\right) \mapsto \left\{\begin{array}{c} \begin{array}{l} \left(f(i), \ldots, f(j), f(k)\right) =  \\ \left(f(i), \ldots, f(k)\right) \end{array} \end{array} \textrm{ if } \left(k - i\right) \in \mathbb{N} ,  k = \left(j + 1\right)\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (f, i, j, k) -> {(f(i), ..f(a).., f(j), f(k)) =  \\ (f(i), ..f(a).., f(k)) if (k - i) in Natural ,  k = (j + 1).
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (f, i, j, k)
#    core type: ExprTuple
#    sub-expressions: 28, 37, 32, 30
# 2. {(f(i), ..f(a).., f(j), f(k)) =  \\ (f(i), ..f(a).., f(k)) if (k - i) in Natural ,  k = (j + 1).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (f(i), ..f(a).., f(j), f(k)) =  \\ (f(i), ..f(a).., f(k))
#    core type: Operation
#    operator: 17
#    operands: 5
# 4. ((k - i) in Natural) and (k = (j + 1))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. ((f(i), ..f(a).., f(j), f(k)), (f(i), ..f(a).., f(k)))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. ((k - i) in Natural, k = (j + 1))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. (f(i), ..f(a).., f(j), f(k))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 9. (f(i), ..f(a).., f(k))
#    core type: ExprTuple
#    sub-expressions: 14
# 10. (k - i) in Natural
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. k = (j + 1)
#     core type: Operation
#     operator: 17
#     operands: 18
# 12. f(i), ..f(a).., f(j)
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 37
#     end_index: 32
# 13. f(k)
#     core type: Operation
#     operator: 28
#     operand: 30
# 14. f(i), ..f(a).., f(k)
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 37
#     end_index: 30
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (k - i, Natural)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 17. =
#     core type: Literal
#     sub-expressions:
# 18. (k, j + 1)
#     core type: ExprTuple
#     sub-expressions: 30, 23
# 19. (k)
#     core type: ExprTuple
#     sub-expressions: 30
# 20. a -> f(a)
#     core type: Lambda
#     parameter: 34
#     body: 24
# 21. k - i
#     core type: Operation
#     operator: 26
#     operands: 25
# 22. Natural
#     core type: Literal
#     sub-expressions:
# 23. j + 1
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. f(a)
#     core type: Operation
#     operator: 28
#     operand: 34
# 25. (k, -i)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 26. +
#     core type: Literal
#     sub-expressions:
# 27. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 28. f
#     core type: Variable
#     sub-expressions:
# 29. (a)
#     core type: ExprTuple
#     sub-expressions: 34
# 30. k
#     core type: Variable
#     sub-expressions:
# 31. -i
#     core type: Operation
#     operator: 35
#     operand: 37
# 32. j
#     core type: Variable
#     sub-expressions:
# 33. 1
#     core type: Literal
#     sub-expressions:
# 34. a
#     core type: Variable
#     sub-expressions:
# 35. -
#     core type: Literal
#     sub-expressions:
# 36. (i)
#     core type: ExprTuple
#     sub-expressions: 37
# 37. i
#     core type: Variable
#     sub-expressions:
