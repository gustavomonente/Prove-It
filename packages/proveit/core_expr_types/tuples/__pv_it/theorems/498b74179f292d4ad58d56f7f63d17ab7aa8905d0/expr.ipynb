# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import i, n
from proveit.core_expr_types import Len, f_1_to_n
from proveit.core_expr_types.tuples import f_1_to_i__1_to_n
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Mult, Natural, NaturalPos

# %%
# build up the expression from sub-expressions
expr = Forall([n], Forall([f_1_to_n, i], Equals(Len([f_1_to_i__1_to_n]), Mult(n, i)).with_wrapping_at(1), condition = InSet(i, Natural)), domains = [NaturalPos])
# Out:
# expr: forall_{n in NaturalPos} [forall_{f_{1}, ..f_{_a}.., f_{n}, i | i in Natural} (|(f_{1}(1), ..f_{1}(x).., f_{1}(i), ....f_{k}(1), ..f_{k}(x).., f_{k}(i)...., f_{n}(1), ..f_{n}(x).., f_{n}(i))| \\  = (n * i))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\forall_{f_{1}, \ldots, f_{n}, i~|~i \in \mathbb{N}}~\left(\begin{array}{c} \begin{array}{l} |\left(f_{1}(1), \ldots, f_{1}(i), \ldots\ldots, f_{n}(1), \ldots, f_{n}(i)\right)| \\  = \left(n \cdot i\right) \end{array} \end{array}\right)\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{f_{1}, ..f_{_a}.., f_{n}, i | i in Natural} (|(f_{1}(1), ..f_{1}(x).., f_{1}(i), ....f_{k}(1), ..f_{k}(x).., f_{k}(i)...., f_{n}(1), ..f_{n}(x).., f_{n}(i))| \\  = (n * i))]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (n -> {forall_{f_{1}, ..f_{_a}.., f_{n}, i | i in Natural} (|(f_{1}(1), ..f_{1}(x).., f_{1}(i), ....f_{k}(1), ..f_{k}(x).., f_{k}(i)...., f_{n}(1), ..f_{n}(x).., f_{n}(i))| \\  = (n * i)) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{f_{1}, ..f_{_a}.., f_{n}, i | i in Natural} (|(f_{1}(1), ..f_{1}(x).., f_{1}(i), ....f_{k}(1), ..f_{k}(x).., f_{k}(i)...., f_{n}(1), ..f_{n}(x).., f_{n}(i))| \\  = (n * i)) if n in NaturalPos.
#    core type: Lambda
#    parameter: 34
#    body: 3
# 3. {forall_{f_{1}, ..f_{_a}.., f_{n}, i | i in Natural} (|(f_{1}(1), ..f_{1}(x).., f_{1}(i), ....f_{k}(1), ..f_{k}(x).., f_{k}(i)...., f_{n}(1), ..f_{n}(x).., f_{n}(i))| \\  = (n * i)) if n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{f_{1}, ..f_{_a}.., f_{n}, i | i in Natural} (|(f_{1}(1), ..f_{1}(x).., f_{1}(i), ....f_{k}(1), ..f_{k}(x).., f_{k}(i)...., f_{n}(1), ..f_{n}(x).., f_{n}(i))| \\  = (n * i))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. n in NaturalPos
#    core type: Operation
#    operator: 19
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((f_{1}, ..f_{_a}.., f_{n}, i) -> {|(f_{1}(1), ..f_{1}(x).., f_{1}(i), ....f_{k}(1), ..f_{k}(x).., f_{k}(i)...., f_{n}(1), ..f_{n}(x).., f_{n}(i))| \\  = (n * i) if i in Natural.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 34, 10
# 9. (f_{1}, ..f_{_a}.., f_{n}, i) -> {|(f_{1}(1), ..f_{1}(x).., f_{1}(i), ....f_{k}(1), ..f_{k}(x).., f_{k}(i)...., f_{n}(1), ..f_{n}(x).., f_{n}(i))| \\  = (n * i) if i in Natural.
#    core type: Lambda
#    parameters: 11\n   body: 12
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. (f_{1}, ..f_{_a}.., f_{n}, i)
#     core type: ExprTuple
#     sub-expressions: 13, 38
# 12. {|(f_{1}(1), ..f_{1}(x).., f_{1}(i), ....f_{k}(1), ..f_{k}(x).., f_{k}(i)...., f_{n}(1), ..f_{n}(x).., f_{n}(i))| \\  = (n * i) if i in Natural.
#     core type: Conditional
#     value: 14
#     condition: 15
# 13. f_{1}, ..f_{_a}.., f_{n}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 37
#     end_index: 34
# 14. |(f_{1}(1), ..f_{1}(x).., f_{1}(i), ....f_{k}(1), ..f_{k}(x).., f_{k}(i)...., f_{n}(1), ..f_{n}(x).., f_{n}(i))| \\  = (n * i)
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. i in Natural
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. _a -> f_{_a}
#     core type: Lambda
#     parameter: 30
#     body: 21
# 17. =
#     core type: Literal
#     sub-expressions:
# 18. (|(f_{1}(1), ..f_{1}(x).., f_{1}(i), ....f_{k}(1), ..f_{k}(x).., f_{k}(i)...., f_{n}(1), ..f_{n}(x).., f_{n}(i))|, n * i)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 38, 24
# 21. f_{_a}
#     core type: IndexedVar
# variable: 42
# index: 30
# 22. |(f_{1}(1), ..f_{1}(x).., f_{1}(i), ....f_{k}(1), ..f_{k}(x).., f_{k}(i)...., f_{n}(1), ..f_{n}(x).., f_{n}(i))|
#     core type: Operation
#     operator: 26
#     operand: 31
# 23. n * i
#     core type: Operation
#     operator: 28
#     operands: 29
# 24. Natural
#     core type: Literal
#     sub-expressions:
# 25. (_a)
#     core type: ExprTuple
#     sub-expressions: 30
# 26. length
#     core type: Literal
#     sub-expressions:
# 27. ((f_{1}(1), ..f_{1}(x).., f_{1}(i), ....f_{k}(1), ..f_{k}(x).., f_{k}(i)...., f_{n}(1), ..f_{n}(x).., f_{n}(i)))
#     core type: ExprTuple
#     sub-expressions: 31
# 28. *
#     core type: Literal
#     sub-expressions:
# 29. (n, i)
#     core type: ExprTuple
#     sub-expressions: 34, 38
# 30. _a
#     core type: Variable
#     sub-expressions:
# 31. (f_{1}(1), ..f_{1}(x).., f_{1}(i), ....f_{k}(1), ..f_{k}(x).., f_{k}(i)...., f_{n}(1), ..f_{n}(x).., f_{n}(i))
#     core type: ExprTuple
#     sub-expressions: 32
# 32. f_{1}(1), ..f_{1}(x).., f_{1}(i), ....f_{k}(1), ..f_{k}(x).., f_{k}(i)...., f_{n}(1), ..f_{n}(x).., f_{n}(i)
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 37
#     end_index: 34
# 33. k -> f_{k}(1), ..f_{k}(x).., f_{k}(i)
#     core type: Lambda
#     parameter: 45
#     body: 35
# 34. n
#     core type: Variable
#     sub-expressions:
# 35. f_{k}(1), ..f_{k}(x).., f_{k}(i)
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 37
#     end_index: 38
# 36. x -> f_{k}(x)
#     core type: Lambda
#     parameter: 44
#     body: 39
# 37. 1
#     core type: Literal
#     sub-expressions:
# 38. i
#     core type: Variable
#     sub-expressions:
# 39. f_{k}(x)
#     core type: Operation
#     operator: 40
#     operand: 44
# 40. f_{k}
#     core type: IndexedVar
# variable: 42
# index: 45
# 41. (x)
#     core type: ExprTuple
#     sub-expressions: 44
# 42. f
#     core type: Variable
#     sub-expressions:
# 43. (k)
#     core type: ExprTuple
#     sub-expressions: 45
# 44. x
#     core type: Variable
#     sub-expressions:
# 45. k
#     core type: Variable
#     sub-expressions:
