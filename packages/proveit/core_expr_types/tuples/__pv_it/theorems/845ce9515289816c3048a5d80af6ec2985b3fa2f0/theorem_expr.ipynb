# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#merge">merge</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types.tuples import merge

# %%
# check that the built expression is the same as the stored expression
assert merge.expr == stored_expr
assert merge.expr._style_id == stored_expr._style_id
print("Passed sanity check: merge matches stored_expr")
# Out:
# Passed sanity check: merge matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(merge.latex())
# Out:
# \vdash \forall_{f, i, j, k, l~|~\left(k - i\right) \in \mathbb{N}, \left(l - j\right) \in \mathbb{N}, k = \left(j + 1\right)}~\left(\begin{array}{c} \begin{array}{l} \left(f(i), \ldots, f(j), f(k), \ldots, f(l)\right) =  \\ \left(f(i), \ldots, f(l)\right) \end{array} \end{array}\right)

# %%
merge.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
merge.expr_info()
# Out:
# 0. forall_{f, i, j, k, l | (k - i) in Natural, (l - j) in Natural, k = (j + 1)} ((f(i), ..f(a).., f(j), f(k), ..f(a).., f(l)) =  \\ (f(i), ..f(a).., f(l)))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((f, i, j, k, l) -> {(f(i), ..f(a).., f(j), f(k), ..f(a).., f(l)) =  \\ (f(i), ..f(a).., f(l)) if (k - i) in Natural ,  (l - j) in Natural ,  k = (j + 1).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (f, i, j, k, l) -> {(f(i), ..f(a).., f(j), f(k), ..f(a).., f(l)) =  \\ (f(i), ..f(a).., f(l)) if (k - i) in Natural ,  (l - j) in Natural ,  k = (j + 1).
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (f, i, j, k, l)
#    core type: ExprTuple
#    sub-expressions: 34, 45, 46, 36, 38
# 5. {(f(i), ..f(a).., f(j), f(k), ..f(a).., f(l)) =  \\ (f(i), ..f(a).., f(l)) if (k - i) in Natural ,  (l - j) in Natural ,  k = (j + 1).
#    core type: Conditional
#    value: 6
#    condition: 7
# ...
