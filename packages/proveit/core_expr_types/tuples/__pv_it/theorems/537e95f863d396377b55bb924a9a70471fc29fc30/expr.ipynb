# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, f, i, j
from proveit.core_expr_types import Len, f_i_to_j, f_jp1, range_i_to_jp1
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Lambda(f, Forall([i, j], Equals(Len([f_i_to_j, f_jp1]), Len([range_i_to_jp1])), condition = InSet(Len([f_i_to_j]), Natural)))
# Out:
# expr: f -> [forall_{i, j | |(f(i), ..f(a).., f(j))| in Natural} (|(f(i), ..f(a).., f(j), f(j + 1))| = |(i, ..k.., j + 1)|)]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# f \mapsto \left[\forall_{i, j~|~|\left(f(i), \ldots, f(j)\right)| \in \mathbb{N}}~\left(|\left(f(i), \ldots, f(j), f(j + 1)\right)| = |\left(i, \ldots, j + 1\right)|\right)\right]

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. f -> [forall_{i, j | |(f(i), ..f(a).., f(j))| in Natural} (|(f(i), ..f(a).., f(j), f(j + 1))| = |(i, ..k.., j + 1)|)]
#    core type: Lambda
#    parameter: 36
#    body: 1
# 1. forall_{i, j | |(f(i), ..f(a).., f(j))| in Natural} (|(f(i), ..f(a).., f(j), f(j + 1))| = |(i, ..k.., j + 1)|)
#    core type: Operation
#    operator: 2
#    operand: 4
# 2. forall
#    core type: Literal
#    sub-expressions:
# 3. ((i, j) -> {|(f(i), ..f(a).., f(j), f(j + 1))| = |(i, ..k.., j + 1)| if |(f(i), ..f(a).., f(j))| in Natural.)
#    core type: ExprTuple
#    sub-expressions: 4
# 4. (i, j) -> {|(f(i), ..f(a).., f(j), f(j + 1))| = |(i, ..k.., j + 1)| if |(f(i), ..f(a).., f(j))| in Natural.
#    core type: Lambda
#    parameters: 5\n   body: 6
# 5. (i, j)
#    core type: ExprTuple
#    sub-expressions: 30, 38
# 6. {|(f(i), ..f(a).., f(j), f(j + 1))| = |(i, ..k.., j + 1)| if |(f(i), ..f(a).., f(j))| in Natural.
#    core type: Conditional
#    value: 7
#    condition: 8
# 7. |(f(i), ..f(a).., f(j), f(j + 1))| = |(i, ..k.., j + 1)|
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. |(f(i), ..f(a).., f(j))| in Natural
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. =
#    core type: Literal
#    sub-expressions:
# 10. (|(f(i), ..f(a).., f(j), f(j + 1))|, |(i, ..k.., j + 1)|)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (|(f(i), ..f(a).., f(j))|, Natural)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. |(f(i), ..f(a).., f(j), f(j + 1))|
#     core type: Operation
#     operator: 19
#     operand: 21
# 14. |(i, ..k.., j + 1)|
#     core type: Operation
#     operator: 19
#     operand: 22
# 15. |(f(i), ..f(a).., f(j))|
#     core type: Operation
#     operator: 19
#     operand: 23
# 16. Natural
#     core type: Literal
#     sub-expressions:
# 17. ((f(i), ..f(a).., f(j), f(j + 1)))
#     core type: ExprTuple
#     sub-expressions: 21
# 18. ((i, ..k.., j + 1))
#     core type: ExprTuple
#     sub-expressions: 22
# 19. length
#     core type: Literal
#     sub-expressions:
# 20. ((f(i), ..f(a).., f(j)))
#     core type: ExprTuple
#     sub-expressions: 23
# 21. (f(i), ..f(a).., f(j), f(j + 1))
#     core type: ExprTuple
#     sub-expressions: 26, 24
# 22. (i, ..k.., j + 1)
#     core type: ExprTuple
#     sub-expressions: 25
# 23. (f(i), ..f(a).., f(j))
#     core type: ExprTuple
#     sub-expressions: 26
# 24. f(j + 1)
#     core type: Operation
#     operator: 36
#     operand: 31
# 25. i, ..k.., (j + 1)
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 30
#     end_index: 31
# 26. f(i), ..f(a).., f(j)
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 30
#     end_index: 38
# 27. (j + 1)
#     core type: ExprTuple
#     sub-expressions: 31
# 28. k -> k
#     core type: Lambda
#     parameter: 32
#     body: 32
# 29. a -> f(a)
#     core type: Lambda
#     parameter: 40
#     body: 33
# 30. i
#     core type: Variable
#     sub-expressions:
# 31. j + 1
#     core type: Operation
#     operator: 34
#     operands: 35
# 32. k
#     core type: Variable
#     sub-expressions:
# 33. f(a)
#     core type: Operation
#     operator: 36
#     operand: 40
# 34. +
#     core type: Literal
#     sub-expressions:
# 35. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 36. f
#     core type: Variable
#     sub-expressions:
# 37. (a)
#     core type: ExprTuple
#     sub-expressions: 40
# 38. j
#     core type: Variable
#     sub-expressions:
# 39. 1
#     core type: Literal
#     sub-expressions:
# 40. a
#     core type: Variable
#     sub-expressions:
