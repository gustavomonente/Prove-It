# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#len_of_ranges_with_repeated_indices">len_of_ranges_with_repeated_indices</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types.tuples import len_of_ranges_with_repeated_indices

# %%
# check that the built expression is the same as the stored expression
assert len_of_ranges_with_repeated_indices.expr == stored_expr
assert len_of_ranges_with_repeated_indices.expr._style_id == stored_expr._style_id
print("Passed sanity check: len_of_ranges_with_repeated_indices matches stored_expr")
# Out:
# Passed sanity check: len_of_ranges_with_repeated_indices matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(len_of_ranges_with_repeated_indices.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{f_{1}, \ldots, f_{n}, i, j~|~\left(j - i + 1\right) \in \mathbb{N}}~\left(\begin{array}{c} \begin{array}{l} |\left(f_{1}(i), \ldots, f_{1}(j), \ldots\ldots, f_{n}(i), \ldots, f_{n}(j)\right)| \\  = \left(n \cdot \left(j - i + 1\right)\right) \end{array} \end{array}\right)\right]

# %%
len_of_ranges_with_repeated_indices.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
len_of_ranges_with_repeated_indices.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{f_{1}, ..f_{_a}.., f_{n}, i, j | (j - i + 1) in Natural} (|(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))| \\  = (n * (j - i + 1)))]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (n -> {forall_{f_{1}, ..f_{_a}.., f_{n}, i, j | (j - i + 1) in Natural} (|(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))| \\  = (n * (j - i + 1))) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{f_{1}, ..f_{_a}.., f_{n}, i, j | (j - i + 1) in Natural} (|(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))| \\  = (n * (j - i + 1))) if n in NaturalPos.
#    core type: Lambda
#    parameter: 37
#    body: 3
# 3. {forall_{f_{1}, ..f_{_a}.., f_{n}, i, j | (j - i + 1) in Natural} (|(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))| \\  = (n * (j - i + 1))) if n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{f_{1}, ..f_{_a}.., f_{n}, i, j | (j - i + 1) in Natural} (|(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))| \\  = (n * (j - i + 1)))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. n in NaturalPos
#    core type: Operation
#    operator: 19
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((f_{1}, ..f_{_a}.., f_{n}, i, j) -> {|(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))| \\  = (n * (j - i + 1)) if (j - i + 1) in Natural.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 37, 10
# 9. (f_{1}, ..f_{_a}.., f_{n}, i, j) -> {|(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))| \\  = (n * (j - i + 1)) if (j - i + 1) in Natural.
#    core type: Lambda
#    parameters: 11\n   body: 12
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. (f_{1}, ..f_{_a}.., f_{n}, i, j)
#     core type: ExprTuple
#     sub-expressions: 13, 45, 44
# 12. {|(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))| \\  = (n * (j - i + 1)) if (j - i + 1) in Natural.
#     core type: Conditional
#     value: 14
#     condition: 15
# 13. f_{1}, ..f_{_a}.., f_{n}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 39
#     end_index: 37
# 14. |(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))| \\  = (n * (j - i + 1))
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. (j - i + 1) in Natural
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. _a -> f_{_a}
#     core type: Lambda
#     parameter: 30
#     body: 21
# 17. =
#     core type: Literal
#     sub-expressions:
# 18. (|(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))|, n * (j - i + 1))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (j - i + 1, Natural)
#     core type: ExprTuple
#     sub-expressions: 32, 24
# 21. f_{_a}
#     core type: IndexedVar
# variable: 49
# index: 30
# 22. |(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))|
#     core type: Operation
#     operator: 26
#     operand: 31
# 23. n * (j - i + 1)
#     core type: Operation
#     operator: 28
#     operands: 29
# 24. Natural
#     core type: Literal
#     sub-expressions:
# 25. (_a)
#     core type: ExprTuple
#     sub-expressions: 30
# 26. length
#     core type: Literal
#     sub-expressions:
# 27. ((f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j)))
#     core type: ExprTuple
#     sub-expressions: 31
# 28. *
#     core type: Literal
#     sub-expressions:
# 29. (n, j - i + 1)
#     core type: ExprTuple
#     sub-expressions: 37, 32
# 30. _a
#     core type: Variable
#     sub-expressions:
# 31. (f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))
#     core type: ExprTuple
#     sub-expressions: 33
# 32. j - i + 1
#     core type: Operation
#     operator: 34
#     operands: 35
# 33. f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j)
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 39
#     end_index: 37
# 34. +
#     core type: Literal
#     sub-expressions:
# 35. (j, -i, 1)
#     core type: ExprTuple
#     sub-expressions: 44, 38, 39
# 36. k -> f_{k}(i), ..f_{k}(x).., f_{k}(j)
#     core type: Lambda
#     parameter: 52
#     body: 40
# 37. n
#     core type: Variable
#     sub-expressions:
# 38. -i
#     core type: Operation
#     operator: 41
#     operand: 45
# 39. 1
#     core type: Literal
#     sub-expressions:
# 40. f_{k}(i), ..f_{k}(x).., f_{k}(j)
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 45
#     end_index: 44
# 41. -
#     core type: Literal
#     sub-expressions:
# 42. (i)
#     core type: ExprTuple
#     sub-expressions: 45
# 43. x -> f_{k}(x)
#     core type: Lambda
#     parameter: 51
#     body: 46
# 44. j
#     core type: Variable
#     sub-expressions:
# 45. i
#     core type: Variable
#     sub-expressions:
# 46. f_{k}(x)
#     core type: Operation
#     operator: 47
#     operand: 51
# 47. f_{k}
#     core type: IndexedVar
# variable: 49
# index: 52
# 48. (x)
#     core type: ExprTuple
#     sub-expressions: 51
# 49. f
#     core type: Variable
#     sub-expressions:
# 50. (k)
#     core type: ExprTuple
#     sub-expressions: 52
# 51. x
#     core type: Variable
#     sub-expressions:
# 52. k
#     core type: Variable
#     sub-expressions:
