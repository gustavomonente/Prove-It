# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda, f
from proveit.core_expr_types import Len, f_1_to_i, range_1_to_i
from proveit.logic import Equals

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(f, Equals(Len([f_1_to_i]), Len([range_1_to_i]))))
# Out:
# expr: (f -> (|(f(1), ..f(a).., f(i))| = |(1, ..k.., i)|))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(f \mapsto \left(|\left(f(1), \ldots, f(i)\right)| = |\left(1, \ldots, i\right)|\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (f -> (|(f(1), ..f(a).., f(i))| = |(1, ..k.., i)|))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. f -> (|(f(1), ..f(a).., f(i))| = |(1, ..k.., i)|)
#    core type: Lambda
#    parameter: 20
#    body: 2
# 2. |(f(1), ..f(a).., f(i))| = |(1, ..k.., i)|
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (|(f(1), ..f(a).., f(i))|, |(1, ..k.., i)|)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. |(f(1), ..f(a).., f(i))|
#    core type: Operation
#    operator: 8
#    operand: 10
# 6. |(1, ..k.., i)|
#    core type: Operation
#    operator: 8
#    operand: 11
# 7. ((f(1), ..f(a).., f(i)))
#    core type: ExprTuple
#    sub-expressions: 10
# 8. length
#    core type: Literal
#    sub-expressions:
# 9. ((1, ..k.., i))
#    core type: ExprTuple
#    sub-expressions: 11
# 10. (f(1), ..f(a).., f(i))
#     core type: ExprTuple
#     sub-expressions: 12
# 11. (1, ..k.., i)
#     core type: ExprTuple
#     sub-expressions: 13
# 12. f(1), ..f(a).., f(i)
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 16
#     end_index: 17
# 13. 1, ..k.., i
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 16
#     end_index: 17
# 14. a -> f(a)
#     core type: Lambda
#     parameter: 22
#     body: 18
# 15. k -> k
#     core type: Lambda
#     parameter: 19
#     body: 19
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. i
#     core type: Variable
#     sub-expressions:
# 18. f(a)
#     core type: Operation
#     operator: 20
#     operand: 22
# 19. k
#     core type: Variable
#     sub-expressions:
# 20. f
#     core type: Variable
#     sub-expressions:
# 21. (a)
#     core type: ExprTuple
#     sub-expressions: 22
# 22. a
#     core type: Variable
#     sub-expressions:
