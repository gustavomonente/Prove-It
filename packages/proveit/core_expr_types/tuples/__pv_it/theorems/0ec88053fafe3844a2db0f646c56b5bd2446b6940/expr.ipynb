# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, f, i, j, k
from proveit.core_expr_types import merge_front_equiv
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Natural, Neg, one

# %%
# build up the expression from sub-expressions
expr = Lambda([f, i, j, k], Conditional(merge_front_equiv, And(InSet(Add(k, Neg(i)), Natural), Equals(j, Add(i, one)))))
# Out:
# expr: (f, i, j, k) -> {(f(i), f(j), ..f(a).., f(k)) =  \\ (f(i), ..f(a).., f(k)) if (k - i) in Natural ,  j = (i + 1).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(f, i, j, k\right) \mapsto \left\{\begin{array}{c} \begin{array}{l} \left(f(i), f(j), \ldots, f(k)\right) =  \\ \left(f(i), \ldots, f(k)\right) \end{array} \end{array} \textrm{ if } \left(k - i\right) \in \mathbb{N} ,  j = \left(i + 1\right)\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (f, i, j, k) -> {(f(i), f(j), ..f(a).., f(k)) =  \\ (f(i), ..f(a).., f(k)) if (k - i) in Natural ,  j = (i + 1).
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (f, i, j, k)
#    core type: ExprTuple
#    sub-expressions: 28, 36, 22, 30
# 2. {(f(i), f(j), ..f(a).., f(k)) =  \\ (f(i), ..f(a).., f(k)) if (k - i) in Natural ,  j = (i + 1).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (f(i), f(j), ..f(a).., f(k)) =  \\ (f(i), ..f(a).., f(k))
#    core type: Operation
#    operator: 17
#    operands: 5
# 4. ((k - i) in Natural) and (j = (i + 1))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. ((f(i), f(j), ..f(a).., f(k)), (f(i), ..f(a).., f(k)))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. ((k - i) in Natural, j = (i + 1))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. (f(i), f(j), ..f(a).., f(k))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 9. (f(i), ..f(a).., f(k))
#    core type: ExprTuple
#    sub-expressions: 14
# 10. (k - i) in Natural
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. j = (i + 1)
#     core type: Operation
#     operator: 17
#     operands: 18
# 12. f(i)
#     core type: Operation
#     operator: 28
#     operand: 36
# 13. f(j), ..f(a).., f(k)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 22
#     end_index: 30
# 14. f(i), ..f(a).., f(k)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 36
#     end_index: 30
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (k - i, Natural)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 17. =
#     core type: Literal
#     sub-expressions:
# 18. (j, i + 1)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 19. a -> f(a)
#     core type: Lambda
#     parameter: 33
#     body: 24
# 20. k - i
#     core type: Operation
#     operator: 26
#     operands: 25
# 21. Natural
#     core type: Literal
#     sub-expressions:
# 22. j
#     core type: Variable
#     sub-expressions:
# 23. i + 1
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. f(a)
#     core type: Operation
#     operator: 28
#     operand: 33
# 25. (k, -i)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 26. +
#     core type: Literal
#     sub-expressions:
# 27. (i, 1)
#     core type: ExprTuple
#     sub-expressions: 36, 32
# 28. f
#     core type: Variable
#     sub-expressions:
# 29. (a)
#     core type: ExprTuple
#     sub-expressions: 33
# 30. k
#     core type: Variable
#     sub-expressions:
# 31. -i
#     core type: Operation
#     operator: 34
#     operand: 36
# 32. 1
#     core type: Literal
#     sub-expressions:
# 33. a
#     core type: Variable
#     sub-expressions:
# 34. -
#     core type: Literal
#     sub-expressions:
# 35. (i)
#     core type: ExprTuple
#     sub-expressions: 36
# 36. i
#     core type: Variable
#     sub-expressions:
