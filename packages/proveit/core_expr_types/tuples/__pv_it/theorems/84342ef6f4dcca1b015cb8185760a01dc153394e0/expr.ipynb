# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, i, j, k
from proveit.core_expr_types import partition_equiv
from proveit.logic import And, InSet
from proveit.numbers import Add, Natural, Neg, one

# %%
# build up the expression from sub-expressions
expr = Conditional(partition_equiv, And(InSet(Add(Add(j, one), Neg(i)), Natural), InSet(Add(k, Neg(j)), Natural)))
# Out:
# expr: {(f(i), ..f(a).., f(k)) =  \\ (f(i), ..f(a).., f(j), f(j + 1), ..f(a).., f(k)) if ((j + 1) - i) in Natural ,  (k - j) in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\begin{array}{c} \begin{array}{l} \left(f(i), \ldots, f(k)\right) =  \\ \left(f(i), \ldots, f(j), f(j + 1), \ldots, f(k)\right) \end{array} \end{array} \textrm{ if } \left(\left(j + 1\right) - i\right) \in \mathbb{N} ,  \left(k - j\right) \in \mathbb{N}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(f(i), ..f(a).., f(k)) =  \\ (f(i), ..f(a).., f(j), f(j + 1), ..f(a).., f(k)) if ((j + 1) - i) in Natural ,  (k - j) in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (f(i), ..f(a).., f(k)) =  \\ (f(i), ..f(a).., f(j), f(j + 1), ..f(a).., f(k))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (((j + 1) - i) in Natural) and ((k - j) in Natural)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. ((f(i), ..f(a).., f(k)), (f(i), ..f(a).., f(j), f(j + 1), ..f(a).., f(k)))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (((j + 1) - i) in Natural, (k - j) in Natural)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. (f(i), ..f(a).., f(k))
#    core type: ExprTuple
#    sub-expressions: 11
# 8. (f(i), ..f(a).., f(j), f(j + 1), ..f(a).., f(k))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 9. ((j + 1) - i) in Natural
#    core type: Operation
#    operator: 15
#    operands: 14
# 10. (k - j) in Natural
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. f(i), ..f(a).., f(k)
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 37
#     end_index: 28
# 12. f(i), ..f(a).., f(j)
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 37
#     end_index: 38
# 13. f(j + 1), ..f(a).., f(k)
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 26
#     end_index: 28
# 14. ((j + 1) - i, Natural)
#     core type: ExprTuple
#     sub-expressions: 18, 20
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (k - j, Natural)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. a -> f(a)
#     core type: Lambda
#     parameter: 30
#     body: 21
# 18. (j + 1) - i
#     core type: Operation
#     operator: 31
#     operands: 22
# 19. k - j
#     core type: Operation
#     operator: 31
#     operands: 23
# 20. Natural
#     core type: Literal
#     sub-expressions:
# 21. f(a)
#     core type: Operation
#     operator: 24
#     operand: 30
# 22. (j + 1, -i)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 23. (k, -j)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 24. f
#     core type: Variable
#     sub-expressions:
# 25. (a)
#     core type: ExprTuple
#     sub-expressions: 30
# 26. j + 1
#     core type: Operation
#     operator: 31
#     operands: 32
# 27. -i
#     core type: Operation
#     operator: 34
#     operand: 37
# 28. k
#     core type: Variable
#     sub-expressions:
# 29. -j
#     core type: Operation
#     operator: 34
#     operand: 38
# 30. a
#     core type: Variable
#     sub-expressions:
# 31. +
#     core type: Literal
#     sub-expressions:
# 32. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 38, 36
# 33. (i)
#     core type: ExprTuple
#     sub-expressions: 37
# 34. -
#     core type: Literal
#     sub-expressions:
# 35. (j)
#     core type: ExprTuple
#     sub-expressions: 38
# 36. 1
#     core type: Literal
#     sub-expressions:
# 37. i
#     core type: Variable
#     sub-expressions:
# 38. j
#     core type: Variable
#     sub-expressions:
