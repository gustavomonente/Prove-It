# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, i
from proveit.core_expr_types import Len, a_1_to_i
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
sub_expr1 = [a_1_to_i]
expr = ExprTuple(Lambda(i, Conditional(Forall(sub_expr1, Equals(Len(sub_expr1), i)), InSet(i, Natural))))
# Out:
# expr: (i -> {forall_{a_{1}, ..a_{_a}.., a_{i}} (|(a_{1}, ..a_{_a}.., a_{i})| = i) if i in Natural.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(i \mapsto \left\{\forall_{a_{1}, \ldots, a_{i}}~\left(|\left(a_{1}, \ldots, a_{i}\right)| = i\right) \textrm{ if } i \in \mathbb{N}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (i -> {forall_{a_{1}, ..a_{_a}.., a_{i}} (|(a_{1}, ..a_{_a}.., a_{i})| = i) if i in Natural.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. i -> {forall_{a_{1}, ..a_{_a}.., a_{i}} (|(a_{1}, ..a_{_a}.., a_{i})| = i) if i in Natural.
#    core type: Lambda
#    parameter: 21
#    body: 2
# 2. {forall_{a_{1}, ..a_{_a}.., a_{i}} (|(a_{1}, ..a_{_a}.., a_{i})| = i) if i in Natural.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1}, ..a_{_a}.., a_{i}} (|(a_{1}, ..a_{_a}.., a_{i})| = i)
#    core type: Operation
#    operator: 5
#    operand: 9
# 4. i in Natural
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((a_{1}, ..a_{_a}.., a_{i}) -> (|(a_{1}, ..a_{_a}.., a_{i})| = i))
#    core type: ExprTuple
#    sub-expressions: 9
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (i, Natural)
#    core type: ExprTuple
#    sub-expressions: 21, 10
# 9. (a_{1}, ..a_{_a}.., a_{i}) -> (|(a_{1}, ..a_{_a}.., a_{i})| = i)
#    core type: Lambda
#    parameters: 17\n   body: 11
# 10. Natural
#     core type: Literal
#     sub-expressions:
# 11. |(a_{1}, ..a_{_a}.., a_{i})| = i
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. =
#     core type: Literal
#     sub-expressions:
# 13. (|(a_{1}, ..a_{_a}.., a_{i})|, i)
#     core type: ExprTuple
#     sub-expressions: 14, 21
# 14. |(a_{1}, ..a_{_a}.., a_{i})|
#     core type: Operation
#     operator: 15
#     operand: 17
# 15. length
#     core type: Literal
#     sub-expressions:
# 16. ((a_{1}, ..a_{_a}.., a_{i}))
#     core type: ExprTuple
#     sub-expressions: 17
# 17. (a_{1}, ..a_{_a}.., a_{i})
#     core type: ExprTuple
#     sub-expressions: 18
# 18. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 20
#     end_index: 21
# 19. _a -> a_{_a}
#     core type: Lambda
#     parameter: 25
#     body: 22
# 20. 1
#     core type: Literal
#     sub-expressions:
# 21. i
#     core type: Variable
#     sub-expressions:
# 22. a_{_a}
#     core type: IndexedVar
# variable: 23
# index: 25
# 23. a
#     core type: Variable
#     sub-expressions:
# 24. (_a)
#     core type: ExprTuple
#     sub-expressions: 25
# 25. _a
#     core type: Variable
#     sub-expressions:
