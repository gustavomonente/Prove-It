# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#merge_back">merge_back</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types.tuples import merge_back

# %%
# check that the built expression is the same as the stored expression
assert merge_back.expr == stored_expr
assert merge_back.expr._style_id == stored_expr._style_id
print("Passed sanity check: merge_back matches stored_expr")
# Out:
# Passed sanity check: merge_back matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(merge_back.latex())
# Out:
# \vdash \forall_{f, i, j, k~|~\left(k - i\right) \in \mathbb{N}, k = \left(j + 1\right)}~\left(\begin{array}{c} \begin{array}{l} \left(f(i), \ldots, f(j), f(k)\right) =  \\ \left(f(i), \ldots, f(k)\right) \end{array} \end{array}\right)

# %%
merge_back.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
merge_back.expr_info()
# Out:
# 0. forall_{f, i, j, k | (k - i) in Natural, k = (j + 1)} ((f(i), ..f(a).., f(j), f(k)) =  \\ (f(i), ..f(a).., f(k)))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((f, i, j, k) -> {(f(i), ..f(a).., f(j), f(k)) =  \\ (f(i), ..f(a).., f(k)) if (k - i) in Natural ,  k = (j + 1).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (f, i, j, k) -> {(f(i), ..f(a).., f(j), f(k)) =  \\ (f(i), ..f(a).., f(k)) if (k - i) in Natural ,  k = (j + 1).
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (f, i, j, k)
#    core type: ExprTuple
#    sub-expressions: 31, 40, 35, 33
# 5. {(f(i), ..f(a).., f(j), f(k)) =  \\ (f(i), ..f(a).., f(k)) if (k - i) in Natural ,  k = (j + 1).
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (f(i), ..f(a).., f(j), f(k)) =  \\ (f(i), ..f(a).., f(k))
#    core type: Operation
#    operator: 20
#    operands: 8
# 7. ((k - i) in Natural) and (k = (j + 1))
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. ((f(i), ..f(a).., f(j), f(k)), (f(i), ..f(a).., f(k)))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. ((k - i) in Natural, k = (j + 1))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. (f(i), ..f(a).., f(j), f(k))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 12. (f(i), ..f(a).., f(k))
#     core type: ExprTuple
#     sub-expressions: 17
# 13. (k - i) in Natural
#     core type: Operation
#     operator: 18
#     operands: 19
# 14. k = (j + 1)
#     core type: Operation
#     operator: 20
#     operands: 21
# 15. f(i), ..f(a).., f(j)
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 40
#     end_index: 35
# 16. f(k)
#     core type: Operation
#     operator: 31
#     operand: 33
# 17. f(i), ..f(a).., f(k)
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 40
#     end_index: 33
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (k - i, Natural)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 20. =
#     core type: Literal
#     sub-expressions:
# 21. (k, j + 1)
#     core type: ExprTuple
#     sub-expressions: 33, 26
# 22. (k)
#     core type: ExprTuple
#     sub-expressions: 33
# 23. a -> f(a)
#     core type: Lambda
#     parameter: 37
#     body: 27
# 24. k - i
#     core type: Operation
#     operator: 29
#     operands: 28
# 25. Natural
#     core type: Literal
#     sub-expressions:
# 26. j + 1
#     core type: Operation
#     operator: 29
#     operands: 30
# 27. f(a)
#     core type: Operation
#     operator: 31
#     operand: 37
# 28. (k, -i)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 29. +
#     core type: Literal
#     sub-expressions:
# 30. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 31. f
#     core type: Variable
#     sub-expressions:
# 32. (a)
#     core type: ExprTuple
#     sub-expressions: 37
# 33. k
#     core type: Variable
#     sub-expressions:
# 34. -i
#     core type: Operation
#     operator: 38
#     operand: 40
# 35. j
#     core type: Variable
#     sub-expressions:
# 36. 1
#     core type: Literal
#     sub-expressions:
# 37. a
#     core type: Variable
#     sub-expressions:
# 38. -
#     core type: Literal
#     sub-expressions:
# 39. (i)
#     core type: ExprTuple
#     sub-expressions: 40
# 40. i
#     core type: Variable
#     sub-expressions:
