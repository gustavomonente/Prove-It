# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#partition_back">partition_back</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types.tuples import partition_back

# %%
# check that the built expression is the same as the stored expression
assert partition_back.expr == stored_expr
assert partition_back.expr._style_id == stored_expr._style_id
print("Passed sanity check: partition_back matches stored_expr")
# Out:
# Passed sanity check: partition_back matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(partition_back.latex())
# Out:
# \vdash \forall_{f, i, j~|~\left(j - i\right) \in \mathbb{N}}~\left(\begin{array}{c} \begin{array}{l} \left(f(i), \ldots, f(j)\right) =  \\ \left(f(i), \ldots, f(j - 1), f(j)\right) \end{array} \end{array}\right)

# %%
partition_back.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
partition_back.expr_info()
# Out:
# 0. forall_{f, i, j | (j - i) in Natural} ((f(i), ..f(a).., f(j)) =  \\ (f(i), ..f(a).., f(j - 1), f(j)))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((f, i, j) -> {(f(i), ..f(a).., f(j)) =  \\ (f(i), ..f(a).., f(j - 1), f(j)) if (j - i) in Natural.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (f, i, j) -> {(f(i), ..f(a).., f(j)) =  \\ (f(i), ..f(a).., f(j - 1), f(j)) if (j - i) in Natural.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (f, i, j)
#    core type: ExprTuple
#    sub-expressions: 28, 32, 30
# 5. {(f(i), ..f(a).., f(j)) =  \\ (f(i), ..f(a).., f(j - 1), f(j)) if (j - i) in Natural.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (f(i), ..f(a).., f(j)) =  \\ (f(i), ..f(a).., f(j - 1), f(j))
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (j - i) in Natural
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. ((f(i), ..f(a).., f(j)), (f(i), ..f(a).., f(j - 1), f(j)))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (j - i, Natural)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. (f(i), ..f(a).., f(j))
#     core type: ExprTuple
#     sub-expressions: 16
# 13. (f(i), ..f(a).., f(j - 1), f(j))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 14. j - i
#     core type: Operation
#     operator: 25
#     operands: 19
# 15. Natural
#     core type: Literal
#     sub-expressions:
# 16. f(i), ..f(a).., f(j)
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 32
#     end_index: 30
# 17. f(i), ..f(a).., f(j - 1)
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 32
#     end_index: 21
# 18. f(j)
#     core type: Operation
#     operator: 28
#     operand: 30
# 19. (j, -i)
#     core type: ExprTuple
#     sub-expressions: 30, 23
# 20. a -> f(a)
#     core type: Lambda
#     parameter: 33
#     body: 24
# 21. j - 1
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. (j)
#     core type: ExprTuple
#     sub-expressions: 30
# 23. -i
#     core type: Operation
#     operator: 34
#     operand: 32
# 24. f(a)
#     core type: Operation
#     operator: 28
#     operand: 33
# 25. +
#     core type: Literal
#     sub-expressions:
# 26. (j, -1)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 27. (i)
#     core type: ExprTuple
#     sub-expressions: 32
# 28. f
#     core type: Variable
#     sub-expressions:
# 29. (a)
#     core type: ExprTuple
#     sub-expressions: 33
# 30. j
#     core type: Variable
#     sub-expressions:
# 31. -1
#     core type: Operation
#     operator: 34
#     operand: 36
# 32. i
#     core type: Variable
#     sub-expressions:
# 33. a
#     core type: Variable
#     sub-expressions:
# 34. -
#     core type: Literal
#     sub-expressions:
# 35. (1)
#     core type: ExprTuple
#     sub-expressions: 36
# 36. 1
#     core type: Literal
#     sub-expressions:
