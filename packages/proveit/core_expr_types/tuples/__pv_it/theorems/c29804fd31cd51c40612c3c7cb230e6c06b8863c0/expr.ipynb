# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, f, i, j, m, n
from proveit.core_expr_types import Len
from proveit.core_expr_types.tuples import general_range_of_ranges
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Add, Natural, one, zero

# %%
# build up the expression from sub-expressions
expr = Lambda([m, n], Conditional(Forall([f, i, j], Equals(Len(general_range_of_ranges), zero).with_wrapping_at(1)), And(InSet(m, Natural), InSet(n, Natural), Equals(Add(n, one), m))))
# Out:
# expr: (m, n) -> {forall_{f, i, j} (|(f(m, i(m)), ..f(m, l).., f(m, j(m)), ....f(k, i(k)), ..f(k, l).., f(k, j(k))...., f(n, i(n)), ..f(n, l).., f(n, j(n)))| \\  = 0) if m in Natural ,  n in Natural ,  (n + 1) = m.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(m, n\right) \mapsto \left\{\forall_{f, i, j}~\left(\begin{array}{c} \begin{array}{l} |\left(f(m, i(m)), \ldots, f(m, j(m)), \ldots\ldots, f(n, i(n)), \ldots, f(n, j(n))\right)| \\  = 0 \end{array} \end{array}\right) \textrm{ if } m \in \mathbb{N} ,  n \in \mathbb{N} ,  \left(n + 1\right) = m\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (m, n) -> {forall_{f, i, j} (|(f(m, i(m)), ..f(m, l).., f(m, j(m)), ....f(k, i(k)), ..f(k, l).., f(k, j(k))...., f(n, i(n)), ..f(n, l).., f(n, j(n)))| \\  = 0) if m in Natural ,  n in Natural ,  (n + 1) = m.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (m, n)
#    core type: ExprTuple
#    sub-expressions: 33, 34
# 2. {forall_{f, i, j} (|(f(m, i(m)), ..f(m, l).., f(m, j(m)), ....f(k, i(k)), ..f(k, l).., f(k, j(k))...., f(n, i(n)), ..f(n, l).., f(n, j(n)))| \\  = 0) if m in Natural ,  n in Natural ,  (n + 1) = m.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{f, i, j} (|(f(m, i(m)), ..f(m, l).., f(m, j(m)), ....f(k, i(k)), ..f(k, l).., f(k, j(k))...., f(n, i(n)), ..f(n, l).., f(n, j(n)))| \\  = 0)
#    core type: Operation
#    operator: 5
#    operand: 9
# 4. (m in Natural) and (n in Natural) and ((n + 1) = m)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((f, i, j) -> (|(f(m, i(m)), ..f(m, l).., f(m, j(m)), ....f(k, i(k)), ..f(k, l).., f(k, j(k))...., f(n, i(n)), ..f(n, l).., f(n, j(n)))| \\  = 0))
#    core type: ExprTuple
#    sub-expressions: 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (m in Natural, n in Natural, (n + 1) = m)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 9. (f, i, j) -> (|(f(m, i(m)), ..f(m, l).., f(m, j(m)), ....f(k, i(k)), ..f(k, l).., f(k, j(k))...., f(n, i(n)), ..f(n, l).., f(n, j(n)))| \\  = 0)
#    core type: Lambda
#    parameters: 13\n   body: 14
# 10. m in Natural
#     core type: Operation
#     operator: 16
#     operands: 15
# 11. n in Natural
#     core type: Operation
#     operator: 16
#     operands: 17
# 12. (n + 1) = m
#     core type: Operation
#     operator: 19
#     operands: 18
# 13. (f, i, j)
#     core type: ExprTuple
#     sub-expressions: 43, 40, 41
# 14. |(f(m, i(m)), ..f(m, l).., f(m, j(m)), ....f(k, i(k)), ..f(k, l).., f(k, j(k))...., f(n, i(n)), ..f(n, l).., f(n, j(n)))| \\  = 0
#     core type: Operation
#     operator: 19
#     operands: 20
# 15. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 33, 21
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 34, 21
# 18. (n + 1, m)
#     core type: ExprTuple
#     sub-expressions: 22, 33
# 19. =
#     core type: Literal
#     sub-expressions:
# 20. (|(f(m, i(m)), ..f(m, l).., f(m, j(m)), ....f(k, i(k)), ..f(k, l).., f(k, j(k))...., f(n, i(n)), ..f(n, l).., f(n, j(n)))|, 0)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. Natural
#     core type: Literal
#     sub-expressions:
# 22. n + 1
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. |(f(m, i(m)), ..f(m, l).., f(m, j(m)), ....f(k, i(k)), ..f(k, l).., f(k, j(k))...., f(n, i(n)), ..f(n, l).., f(n, j(n)))|
#     core type: Operation
#     operator: 27
#     operand: 30
# 24. 0
#     core type: Literal
#     sub-expressions:
# 25. +
#     core type: Literal
#     sub-expressions:
# 26. (n, 1)
#     core type: ExprTuple
#     sub-expressions: 34, 29
# 27. length
#     core type: Literal
#     sub-expressions:
# 28. ((f(m, i(m)), ..f(m, l).., f(m, j(m)), ....f(k, i(k)), ..f(k, l).., f(k, j(k))...., f(n, i(n)), ..f(n, l).., f(n, j(n))))
#     core type: ExprTuple
#     sub-expressions: 30
# 29. 1
#     core type: Literal
#     sub-expressions:
# 30. (f(m, i(m)), ..f(m, l).., f(m, j(m)), ....f(k, i(k)), ..f(k, l).., f(k, j(k))...., f(n, i(n)), ..f(n, l).., f(n, j(n)))
#     core type: ExprTuple
#     sub-expressions: 31
# 31. f(m, i(m)), ..f(m, l).., f(m, j(m)), ....f(k, i(k)), ..f(k, l).., f(k, j(k))...., f(n, i(n)), ..f(n, l).., f(n, j(n))
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 33
#     end_index: 34
# 32. k -> f(k, i(k)), ..f(k, l).., f(k, j(k))
#     core type: Lambda
#     parameter: 45
#     body: 35
# 33. m
#     core type: Variable
#     sub-expressions:
# 34. n
#     core type: Variable
#     sub-expressions:
# 35. f(k, i(k)), ..f(k, l).., f(k, j(k))
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 37
#     end_index: 38
# 36. l -> f(k, l)
#     core type: Lambda
#     parameter: 46
#     body: 39
# 37. i(k)
#     core type: Operation
#     operator: 40
#     operand: 45
# 38. j(k)
#     core type: Operation
#     operator: 41
#     operand: 45
# 39. f(k, l)
#     core type: Operation
#     operator: 43
#     operands: 44
# 40. i
#     core type: Variable
#     sub-expressions:
# 41. j
#     core type: Variable
#     sub-expressions:
# 42. (k)
#     core type: ExprTuple
#     sub-expressions: 45
# 43. f
#     core type: Variable
#     sub-expressions:
# 44. (k, l)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 45. k
#     core type: Variable
#     sub-expressions:
# 46. l
#     core type: Variable
#     sub-expressions:
