# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import i
from proveit.core_expr_types import Len, a_1_to_i
from proveit.logic import Equals, Forall
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
sub_expr1 = [a_1_to_i]
expr = Forall([i], Forall(sub_expr1, Equals(Len(sub_expr1), i)), domains = [Natural])
# Out:
# expr: forall_{i in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}} (|(a_{1}, ..a_{_a}.., a_{i})| = i)]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{i \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{i}}~\left(|\left(a_{1}, \ldots, a_{i}\right)| = i\right)\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{i in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}} (|(a_{1}, ..a_{_a}.., a_{i})| = i)]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (i -> {forall_{a_{1}, ..a_{_a}.., a_{i}} (|(a_{1}, ..a_{_a}.., a_{i})| = i) if i in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. i -> {forall_{a_{1}, ..a_{_a}.., a_{i}} (|(a_{1}, ..a_{_a}.., a_{i})| = i) if i in Natural.
#    core type: Lambda
#    parameter: 22
#    body: 3
# 3. {forall_{a_{1}, ..a_{_a}.., a_{i}} (|(a_{1}, ..a_{_a}.., a_{i})| = i) if i in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{a_{1}, ..a_{_a}.., a_{i}} (|(a_{1}, ..a_{_a}.., a_{i})| = i)
#    core type: Operation
#    operator: 6
#    operand: 10
# 5. i in Natural
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((a_{1}, ..a_{_a}.., a_{i}) -> (|(a_{1}, ..a_{_a}.., a_{i})| = i))
#    core type: ExprTuple
#    sub-expressions: 10
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (i, Natural)
#    core type: ExprTuple
#    sub-expressions: 22, 11
# 10. (a_{1}, ..a_{_a}.., a_{i}) -> (|(a_{1}, ..a_{_a}.., a_{i})| = i)
#     core type: Lambda
#     parameters: 18\n    body: 12
# 11. Natural
#     core type: Literal
#     sub-expressions:
# 12. |(a_{1}, ..a_{_a}.., a_{i})| = i
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. =
#     core type: Literal
#     sub-expressions:
# 14. (|(a_{1}, ..a_{_a}.., a_{i})|, i)
#     core type: ExprTuple
#     sub-expressions: 15, 22
# 15. |(a_{1}, ..a_{_a}.., a_{i})|
#     core type: Operation
#     operator: 16
#     operand: 18
# 16. length
#     core type: Literal
#     sub-expressions:
# 17. ((a_{1}, ..a_{_a}.., a_{i}))
#     core type: ExprTuple
#     sub-expressions: 18
# 18. (a_{1}, ..a_{_a}.., a_{i})
#     core type: ExprTuple
#     sub-expressions: 19
# 19. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 21
#     end_index: 22
# 20. _a -> a_{_a}
#     core type: Lambda
#     parameter: 26
#     body: 23
# 21. 1
#     core type: Literal
#     sub-expressions:
# 22. i
#     core type: Variable
#     sub-expressions:
# 23. a_{_a}
#     core type: IndexedVar
# variable: 24
# index: 26
# 24. a
#     core type: Variable
#     sub-expressions:
# 25. (_a)
#     core type: ExprTuple
#     sub-expressions: 26
# 26. _a
#     core type: Variable
#     sub-expressions:
