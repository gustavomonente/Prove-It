# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#partition">partition</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types.tuples import partition

# %%
# check that the built expression is the same as the stored expression
assert partition.expr == stored_expr
assert partition.expr._style_id == stored_expr._style_id
print("Passed sanity check: partition matches stored_expr")
# Out:
# Passed sanity check: partition matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(partition.latex())
# Out:
# \vdash \forall_{f, i, j, k~|~\left(\left(j + 1\right) - i\right) \in \mathbb{N}, \left(k - j\right) \in \mathbb{N}}~\left(\begin{array}{c} \begin{array}{l} \left(f(i), \ldots, f(k)\right) =  \\ \left(f(i), \ldots, f(j), f(j + 1), \ldots, f(k)\right) \end{array} \end{array}\right)

# %%
partition.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
partition.expr_info()
# Out:
# 0. forall_{f, i, j, k | ((j + 1) - i) in Natural, (k - j) in Natural} ((f(i), ..f(a).., f(k)) =  \\ (f(i), ..f(a).., f(j), f(j + 1), ..f(a).., f(k)))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((f, i, j, k) -> {(f(i), ..f(a).., f(k)) =  \\ (f(i), ..f(a).., f(j), f(j + 1), ..f(a).., f(k)) if ((j + 1) - i) in Natural ,  (k - j) in Natural.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (f, i, j, k) -> {(f(i), ..f(a).., f(k)) =  \\ (f(i), ..f(a).., f(j), f(j + 1), ..f(a).., f(k)) if ((j + 1) - i) in Natural ,  (k - j) in Natural.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (f, i, j, k)
#    core type: ExprTuple
#    sub-expressions: 29, 42, 43, 33
# 5. {(f(i), ..f(a).., f(k)) =  \\ (f(i), ..f(a).., f(j), f(j + 1), ..f(a).., f(k)) if ((j + 1) - i) in Natural ,  (k - j) in Natural.
#    core type: Conditional
#    value: 6
#    condition: 7
# ...
