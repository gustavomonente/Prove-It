# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, ExprTuple, Lambda, a, b, f, fab, i, j, m, n
from proveit.logic import Equals
from proveit.numbers import Add, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([f, i, j, m, n], Conditional(Equals([ExprRange(a, ExprRange(b, fab, i, j), m, n)], []), Equals(Add(n, one), m))))
# Out:
# expr: ((f, i, j, m, n) -> {(f(m, i), ..f(m, b).., f(m, j), ....f(a, i), ..f(a, b).., f(a, j)...., f(n, i), ..f(n, b).., f(n, j)) = () if (n + 1) = m.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(f, i, j, m, n\right) \mapsto \left\{\left(f(m, i), \ldots, f(m, j), \ldots\ldots, f(n, i), \ldots, f(n, j)\right) = () \textrm{ if } \left(n + 1\right) = m\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((f, i, j, m, n) -> {(f(m, i), ..f(m, b).., f(m, j), ....f(a, i), ..f(a, b).., f(a, j)...., f(n, i), ..f(n, b).., f(n, j)) = () if (n + 1) = m.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (f, i, j, m, n) -> {(f(m, i), ..f(m, b).., f(m, j), ....f(a, i), ..f(a, b).., f(a, j)...., f(n, i), ..f(n, b).., f(n, j)) = () if (n + 1) = m.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (f, i, j, m, n)
#    core type: ExprTuple
#    sub-expressions: 24, 21, 22, 16, 17
# 3. {(f(m, i), ..f(m, b).., f(m, j), ....f(a, i), ..f(a, b).., f(a, j)...., f(n, i), ..f(n, b).., f(n, j)) = () if (n + 1) = m.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (f(m, i), ..f(m, b).., f(m, j), ....f(a, i), ..f(a, b).., f(a, j)...., f(n, i), ..f(n, b).., f(n, j)) = ()
#    core type: Operation
#    operator: 7
#    operands: 6
# 5. (n + 1) = m
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. ((f(m, i), ..f(m, b).., f(m, j), ....f(a, i), ..f(a, b).., f(a, j)...., f(n, i), ..f(n, b).., f(n, j)), ())
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (n + 1, m)
#    core type: ExprTuple
#    sub-expressions: 11, 16
# 9. (f(m, i), ..f(m, b).., f(m, j), ....f(a, i), ..f(a, b).., f(a, j)...., f(n, i), ..f(n, b).., f(n, j))
#    core type: ExprTuple
#    sub-expressions: 12
# 10. ()
#     core type: ExprTuple
#     sub-expressions:
# 11. n + 1
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. f(m, i), ..f(m, b).., f(m, j), ....f(a, i), ..f(a, b).., f(a, j)...., f(n, i), ..f(n, b).., f(n, j)
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 16
#     end_index: 17
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (n, 1)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. a -> f(a, i), ..f(a, b).., f(a, j)
#     core type: Lambda
#     parameter: 26
#     body: 19
# 16. m
#     core type: Variable
#     sub-expressions:
# 17. n
#     core type: Variable
#     sub-expressions:
# 18. 1
#     core type: Literal
#     sub-expressions:
# 19. f(a, i), ..f(a, b).., f(a, j)
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 21
#     end_index: 22
# 20. b -> f(a, b)
#     core type: Lambda
#     parameter: 27
#     body: 23
# 21. i
#     core type: Variable
#     sub-expressions:
# 22. j
#     core type: Variable
#     sub-expressions:
# 23. f(a, b)
#     core type: Operation
#     operator: 24
#     operands: 25
# 24. f
#     core type: Variable
#     sub-expressions:
# 25. (a, b)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 26. a
#     core type: Variable
#     sub-expressions:
# 27. b
#     core type: Variable
#     sub-expressions:
