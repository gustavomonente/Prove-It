# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, f, i, j, k, l
from proveit.core_expr_types.tuples import shift_equiv
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Add, Integer, Natural, Neg, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(a)
expr = Forall([f], Forall([a], Forall([i, j, k, l], shift_equiv, conditions = [InSet(Add(Add(j, one), Neg(i)), Natural), Equals(k, Add(i, sub_expr1)), Equals(l, Add(j, sub_expr1))]), domains = [Integer]))
# Out:
# expr: forall_{f} [forall_{a in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), ..f(a).., f(j)) = (f(k + a), ..f(i + a).., f(l + a)))]]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{f}~\left[\forall_{a \in \mathbb{Z}}~\left[\forall_{i, j, k, l~|~\left(\left(j + 1\right) - i\right) \in \mathbb{N}, k = \left(i - a\right), l = \left(j - a\right)}~\left(\left(f(i), \ldots, f(j)\right) = \left(f(k + a), \ldots, f(l + a)\right)\right)\right]\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{f} [forall_{a in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), ..f(a).., f(j)) = (f(k + a), ..f(i + a).., f(l + a)))]]
#    core type: Operation
#    operator: 9
#    operand: 2
# 1. (f -> [forall_{a in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), ..f(a).., f(j)) = (f(k + a), ..f(i + a).., f(l + a)))]])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. f -> [forall_{a in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), ..f(a).., f(j)) = (f(k + a), ..f(i + a).., f(l + a)))]]
#    core type: Lambda
#    parameter: 46
#    body: 3
# 3. forall_{a in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), ..f(a).., f(j)) = (f(k + a), ..f(i + a).., f(l + a)))]
#    core type: Operation
#    operator: 9
#    operand: 5
# 4. (a -> {forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), ..f(a).., f(j)) = (f(k + a), ..f(i + a).., f(l + a))) if a in Integer.)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. a -> {forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), ..f(a).., f(j)) = (f(k + a), ..f(i + a).., f(l + a))) if a in Integer.
#    core type: Lambda
#    parameter: 61
#    body: 6
# 6. {forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), ..f(a).., f(j)) = (f(k + a), ..f(i + a).., f(l + a))) if a in Integer.
#    core type: Conditional
#    value: 7
#    condition: 8
# 7. forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), ..f(a).., f(j)) = (f(k + a), ..f(i + a).., f(l + a)))
#    core type: Operation
#    operator: 9
#    operand: 12
# 8. a in Integer
#    core type: Operation
#    operator: 28
#    operands: 11
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. ((i, j, k, l) -> {(f(i), ..f(a).., f(j)) = (f(k + a), ..f(i + a).., f(l + a)) if ((j + 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 61, 13
# 12. (i, j, k, l) -> {(f(i), ..f(a).., f(j)) = (f(k + a), ..f(i + a).., f(l + a)) if ((j + 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).
#     core type: Lambda
#     parameters: 14\n    body: 15
# 13. Integer
#     core type: Literal
#     sub-expressions:
# 14. (i, j, k, l)
#     core type: ExprTuple
#     sub-expressions: 60, 58, 37, 39
# 15. {(f(i), ..f(a).., f(j)) = (f(k + a), ..f(i + a).., f(l + a)) if ((j + 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).
#     core type: Conditional
#     value: 16
#     condition: 17
# 16. (f(i), ..f(a).., f(j)) = (f(k + a), ..f(i + a).., f(l + a))
#     core type: Operation
#     operator: 31
#     operands: 18
# 17. (((j + 1) - i) in Natural) and (k = (i - a)) and (l = (j - a))
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. ((f(i), ..f(a).., f(j)), (f(k + a), ..f(i + a).., f(l + a)))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. (((j + 1) - i) in Natural, k = (i - a), l = (j - a))
#     core type: ExprTuple
#     sub-expressions: 23, 24, 25
# 21. (f(i), ..f(a).., f(j))
#     core type: ExprTuple
#     sub-expressions: 26
# 22. (f(k + a), ..f(i + a).., f(l + a))
#     core type: ExprTuple
#     sub-expressions: 27
# 23. ((j + 1) - i) in Natural
#     core type: Operation
#     operator: 28
#     operands: 29
# 24. k = (i - a)
#     core type: Operation
#     operator: 31
#     operands: 30
# 25. l = (j - a)
#     core type: Operation
#     operator: 31
#     operands: 32
# 26. f(i), ..f(a).., f(j)
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 60
#     end_index: 58
# 27. f(k + a), ..f(i + a).., f(l + a)
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 37
#     end_index: 39
# 28. in
#     core type: Literal
#     sub-expressions:
# 29. ((j + 1) - i, Natural)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 30. (k, i - a)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 31. =
#     core type: Literal
#     sub-expressions:
# 32. (l, j - a)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 33. a -> f(a)
#     core type: Lambda
#     parameter: 61
#     body: 41
# 34. i -> f(i + a)
#     core type: Lambda
#     parameter: 60
#     body: 42
# 35. (j + 1) - i
#     core type: Operation
#     operator: 56
#     operands: 43
# 36. Natural
#     core type: Literal
#     sub-expressions:
# 37. k
#     core type: Variable
#     sub-expressions:
# 38. i - a
#     core type: Operation
#     operator: 56
#     operands: 44
# 39. l
#     core type: Variable
#     sub-expressions:
# 40. j - a
#     core type: Operation
#     operator: 56
#     operands: 45
# 41. f(a)
#     core type: Operation
#     operator: 46
#     operand: 61
# 42. f(i + a)
#     core type: Operation
#     operator: 46
#     operand: 51
# 43. (j + 1, -i)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 44. (i, -a)
#     core type: ExprTuple
#     sub-expressions: 60, 50
# 45. (j, -a)
#     core type: ExprTuple
#     sub-expressions: 58, 50
# 46. f
#     core type: Variable
#     sub-expressions:
# 47. (i + a)
#     core type: ExprTuple
#     sub-expressions: 51
# 48. j + 1
#     core type: Operation
#     operator: 56
#     operands: 52
# 49. -i
#     core type: Operation
#     operator: 54
#     operand: 60
# 50. -a
#     core type: Operation
#     operator: 54
#     operand: 61
# 51. i + a
#     core type: Operation
#     operator: 56
#     operands: 57
# 52. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 53. (i)
#     core type: ExprTuple
#     sub-expressions: 60
# 54. -
#     core type: Literal
#     sub-expressions:
# 55. (a)
#     core type: ExprTuple
#     sub-expressions: 61
# 56. +
#     core type: Literal
#     sub-expressions:
# 57. (i, a)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 58. j
#     core type: Variable
#     sub-expressions:
# 59. 1
#     core type: Literal
#     sub-expressions:
# 60. i
#     core type: Variable
#     sub-expressions:
# 61. a
#     core type: Variable
#     sub-expressions:
