# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, n
from proveit.core_expr_types import Len, f_1_to_n, i_1_to_n, j_1_to_n
from proveit.core_expr_types.tuples import f_ik_to_jk__1_to_n, range_len_conditions, range_len_sum
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(n, Conditional(Forall([f_1_to_n, i_1_to_n, j_1_to_n], Equals(Len([f_ik_to_jk__1_to_n]), range_len_sum).with_wrapping_at(1), condition = range_len_conditions), InSet(n, NaturalPos))))
# Out:
# expr: (n -> {forall_{f_{1}, ..f_{_a}.., f_{n}, i_{1}, ..i_{_a}.., i_{n}, j_{1}, ..j_{_a}.., j_{n} | (j_{1} - i_{1} + 1) in Natural, ..(j_{k} - i_{k} + 1) in Natural.., (j_{n} - i_{n} + 1) in Natural} (|(f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n}))| \\  = ((j_{1} - i_{1} + 1) + ..(j_{k} - i_{k} + 1).. + (j_{n} - i_{n} + 1))) if n in NaturalPos.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(n \mapsto \left\{\forall_{f_{1}, \ldots, f_{n}, i_{1}, \ldots, i_{n}, j_{1}, \ldots, j_{n}~|~\left(j_{1} - i_{1} + 1\right) \in \mathbb{N}, \ldots, \left(j_{n} - i_{n} + 1\right) \in \mathbb{N}}~\left(\begin{array}{c} \begin{array}{l} |\left(f_{1}(i_{1}), \ldots, f_{1}(j_{1}), \ldots\ldots, f_{n}(i_{n}), \ldots, f_{n}(j_{n})\right)| \\  = \left(\left(j_{1} - i_{1} + 1\right) + \ldots + \left(j_{n} - i_{n} + 1\right)\right) \end{array} \end{array}\right) \textrm{ if } n \in \mathbb{N}^+\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (n -> {forall_{f_{1}, ..f_{_a}.., f_{n}, i_{1}, ..i_{_a}.., i_{n}, j_{1}, ..j_{_a}.., j_{n} | (j_{1} - i_{1} + 1) in Natural, ..(j_{k} - i_{k} + 1) in Natural.., (j_{n} - i_{n} + 1) in Natural} (|(f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n}))| \\  = ((j_{1} - i_{1} + 1) + ..(j_{k} - i_{k} + 1).. + (j_{n} - i_{n} + 1))) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. n -> {forall_{f_{1}, ..f_{_a}.., f_{n}, i_{1}, ..i_{_a}.., i_{n}, j_{1}, ..j_{_a}.., j_{n} | (j_{1} - i_{1} + 1) in Natural, ..(j_{k} - i_{k} + 1) in Natural.., (j_{n} - i_{n} + 1) in Natural} (|(f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n}))| \\  = ((j_{1} - i_{1} + 1) + ..(j_{k} - i_{k} + 1).. + (j_{n} - i_{n} + 1))) if n in NaturalPos.
#    core type: Lambda
#    parameter: 44
#    body: 2
# 2. {forall_{f_{1}, ..f_{_a}.., f_{n}, i_{1}, ..i_{_a}.., i_{n}, j_{1}, ..j_{_a}.., j_{n} | (j_{1} - i_{1} + 1) in Natural, ..(j_{k} - i_{k} + 1) in Natural.., (j_{n} - i_{n} + 1) in Natural} (|(f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n}))| \\  = ((j_{1} - i_{1} + 1) + ..(j_{k} - i_{k} + 1).. + (j_{n} - i_{n} + 1))) if n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{f_{1}, ..f_{_a}.., f_{n}, i_{1}, ..i_{_a}.., i_{n}, j_{1}, ..j_{_a}.., j_{n} | (j_{1} - i_{1} + 1) in Natural, ..(j_{k} - i_{k} + 1) in Natural.., (j_{n} - i_{n} + 1) in Natural} (|(f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n}))| \\  = ((j_{1} - i_{1} + 1) + ..(j_{k} - i_{k} + 1).. + (j_{n} - i_{n} + 1)))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. n in NaturalPos
#    core type: Operation
#    operator: 41
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((f_{1}, ..f_{_a}.., f_{n}, i_{1}, ..i_{_a}.., i_{n}, j_{1}, ..j_{_a}.., j_{n}) -> {|(f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n}))| \\  = ((j_{1} - i_{1} + 1) + ..(j_{k} - i_{k} + 1).. + (j_{n} - i_{n} + 1)) if ((j_{1} - i_{1} + 1) in Natural) and ..((j_{k} - i_{k} + 1) in Natural).. and ((j_{n} - i_{n} + 1) in Natural).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 44, 9
# 8. (f_{1}, ..f_{_a}.., f_{n}, i_{1}, ..i_{_a}.., i_{n}, j_{1}, ..j_{_a}.., j_{n}) -> {|(f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n}))| \\  = ((j_{1} - i_{1} + 1) + ..(j_{k} - i_{k} + 1).. + (j_{n} - i_{n} + 1)) if ((j_{1} - i_{1} + 1) in Natural) and ..((j_{k} - i_{k} + 1) in Natural).. and ((j_{n} - i_{n} + 1) in Natural).
#    core type: Lambda
#    parameters: 10\n   body: 11
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. (f_{1}, ..f_{_a}.., f_{n}, i_{1}, ..i_{_a}.., i_{n}, j_{1}, ..j_{_a}.., j_{n})
#     core type: ExprTuple
#     sub-expressions: 12, 13, 14
# 11. {|(f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n}))| \\  = ((j_{1} - i_{1} + 1) + ..(j_{k} - i_{k} + 1).. + (j_{n} - i_{n} + 1)) if ((j_{1} - i_{1} + 1) in Natural) and ..((j_{k} - i_{k} + 1) in Natural).. and ((j_{n} - i_{n} + 1) in Natural).
#     core type: Conditional
#     value: 15
#     condition: 16
# 12. f_{1}, ..f_{_a}.., f_{n}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 53
#     end_index: 44
# 13. i_{1}, ..i_{_a}.., i_{n}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 53
#     end_index: 44
# 14. j_{1}, ..j_{_a}.., j_{n}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 53
#     end_index: 44
# 15. |(f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n}))| \\  = ((j_{1} - i_{1} + 1) + ..(j_{k} - i_{k} + 1).. + (j_{n} - i_{n} + 1))
#     core type: Operation
#     operator: 20
#     operands: 21
# 16. ((j_{1} - i_{1} + 1) in Natural) and ..((j_{k} - i_{k} + 1) in Natural).. and ((j_{n} - i_{n} + 1) in Natural)
#     core type: Operation
#     operator: 22
#     operands: 23
# 17. _a -> f_{_a}
#     core type: Lambda
#     parameter: 35
#     body: 24
# 18. _a -> i_{_a}
#     core type: Lambda
#     parameter: 35
#     body: 25
# 19. _a -> j_{_a}
#     core type: Lambda
#     parameter: 35
#     body: 26
# 20. =
#     core type: Literal
#     sub-expressions:
# 21. (|(f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n}))|, (j_{1} - i_{1} + 1) + ..(j_{k} - i_{k} + 1).. + (j_{n} - i_{n} + 1))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 22. and
#     core type: Literal
#     sub-expressions:
# 23. ((j_{1} - i_{1} + 1) in Natural, ..(j_{k} - i_{k} + 1) in Natural.., (j_{n} - i_{n} + 1) in Natural)
#     core type: ExprTuple
#     sub-expressions: 29
# 24. f_{_a}
#     core type: IndexedVar
# variable: 61
# index: 35
# 25. i_{_a}
#     core type: IndexedVar
# variable: 63
# index: 35
# 26. j_{_a}
#     core type: IndexedVar
# variable: 55
# index: 35
# 27. |(f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n}))|
#     core type: Operation
#     operator: 31
#     operand: 36
# 28. (j_{1} - i_{1} + 1) + ..(j_{k} - i_{k} + 1).. + (j_{n} - i_{n} + 1)
#     core type: Operation
#     operator: 48
#     operands: 33
# 29. ((j_{1} - i_{1} + 1) in Natural), ..((j_{k} - i_{k} + 1) in Natural).., ((j_{n} - i_{n} + 1) in Natural)
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 53
#     end_index: 44
# 30. (_a)
#     core type: ExprTuple
#     sub-expressions: 35
# 31. length
#     core type: Literal
#     sub-expressions:
# 32. ((f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n})))
#     core type: ExprTuple
#     sub-expressions: 36
# 33. (j_{1} - i_{1} + 1, ..j_{k} - i_{k} + 1.., j_{n} - i_{n} + 1)
#     core type: ExprTuple
#     sub-expressions: 37
# 34. k -> ((j_{k} - i_{k} + 1) in Natural)
#     core type: Lambda
#     parameter: 65
#     body: 38
# 35. _a
#     core type: Variable
#     sub-expressions:
# 36. (f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n}))
#     core type: ExprTuple
#     sub-expressions: 39
# 37. (j_{1} - i_{1} + 1), ..(j_{k} - i_{k} + 1).., (j_{n} - i_{n} + 1)
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 53
#     end_index: 44
# 38. (j_{k} - i_{k} + 1) in Natural
#     core type: Operation
#     operator: 41
#     operands: 42
# 39. f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n})
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 53
#     end_index: 44
# 40. k -> (j_{k} - i_{k} + 1)
#     core type: Lambda
#     parameter: 65
#     body: 45
# 41. in
#     core type: Literal
#     sub-expressions:
# 42. (j_{k} - i_{k} + 1, Natural)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 43. k -> f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})
#     core type: Lambda
#     parameter: 65
#     body: 47
# 44. n
#     core type: Variable
#     sub-expressions:
# 45. j_{k} - i_{k} + 1
#     core type: Operation
#     operator: 48
#     operands: 49
# 46. Natural
#     core type: Literal
#     sub-expressions:
# 47. f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})
#     core type: ExprRange
#     lambda_map: 50
#     start_index: 60
#     end_index: 51
# 48. +
#     core type: Literal
#     sub-expressions:
# 49. (j_{k}, -i_{k}, 1)
#     core type: ExprTuple
#     sub-expressions: 51, 52, 53
# 50. x -> f_{k}(x)
#     core type: Lambda
#     parameter: 62
#     body: 54
# 51. j_{k}
#     core type: IndexedVar
# variable: 55
# index: 65
# 52. -i_{k}
#     core type: Operation
#     operator: 56
#     operand: 60
# 53. 1
#     core type: Literal
#     sub-expressions:
# 54. f_{k}(x)
#     core type: Operation
#     operator: 58
#     operand: 62
# 55. j
#     core type: Variable
#     sub-expressions:
# 56. -
#     core type: Literal
#     sub-expressions:
# 57. (i_{k})
#     core type: ExprTuple
#     sub-expressions: 60
# 58. f_{k}
#     core type: IndexedVar
# variable: 61
# index: 65
# 59. (x)
#     core type: ExprTuple
#     sub-expressions: 62
# 60. i_{k}
#     core type: IndexedVar
# variable: 63
# index: 65
# 61. f
#     core type: Variable
#     sub-expressions:
# 62. x
#     core type: Variable
#     sub-expressions:
# 63. i
#     core type: Variable
#     sub-expressions:
# 64. (k)
#     core type: ExprTuple
#     sub-expressions: 65
# 65. k
#     core type: Variable
#     sub-expressions:
