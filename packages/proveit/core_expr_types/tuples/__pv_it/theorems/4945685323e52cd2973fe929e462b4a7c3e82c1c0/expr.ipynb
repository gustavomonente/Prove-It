# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a, i, j, k, l
from proveit.core_expr_types.tuples import shift_equiv
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Natural, Neg, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(a)
expr = ExprTuple(Lambda([i, j, k, l], Conditional(shift_equiv, And(InSet(Add(Add(j, one), Neg(i)), Natural), Equals(k, Add(i, sub_expr1)), Equals(l, Add(j, sub_expr1))))))
# Out:
# expr: ((i, j, k, l) -> {(f(i), ..f(a).., f(j)) = (f(k + a), ..f(i + a).., f(l + a)) if ((j + 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(i, j, k, l\right) \mapsto \left\{\left(f(i), \ldots, f(j)\right) = \left(f(k + a), \ldots, f(l + a)\right) \textrm{ if } \left(\left(j + 1\right) - i\right) \in \mathbb{N} ,  k = \left(i - a\right) ,  l = \left(j - a\right)\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((i, j, k, l) -> {(f(i), ..f(a).., f(j)) = (f(k + a), ..f(i + a).., f(l + a)) if ((j + 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (i, j, k, l) -> {(f(i), ..f(a).., f(j)) = (f(k + a), ..f(i + a).., f(l + a)) if ((j + 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (i, j, k, l)
#    core type: ExprTuple
#    sub-expressions: 48, 46, 25, 27
# 3. {(f(i), ..f(a).., f(j)) = (f(k + a), ..f(i + a).., f(l + a)) if ((j + 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (f(i), ..f(a).., f(j)) = (f(k + a), ..f(i + a).., f(l + a))
#    core type: Operation
#    operator: 19
#    operands: 6
# 5. (((j + 1) - i) in Natural) and (k = (i - a)) and (l = (j - a))
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. ((f(i), ..f(a).., f(j)), (f(k + a), ..f(i + a).., f(l + a)))
#    core type: ExprTuple
# ...
