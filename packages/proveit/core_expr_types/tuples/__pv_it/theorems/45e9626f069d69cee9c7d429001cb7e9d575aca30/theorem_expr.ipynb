# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#shift_equivalence_both">shift_equivalence_both</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types.tuples import shift_equivalence_both

# %%
# check that the built expression is the same as the stored expression
assert shift_equivalence_both.expr == stored_expr
assert shift_equivalence_both.expr._style_id == stored_expr._style_id
print("Passed sanity check: shift_equivalence_both matches stored_expr")
# Out:
# Passed sanity check: shift_equivalence_both matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(shift_equivalence_both.latex())
# Out:
# \vdash \forall_{f}~\left[\forall_{a, b \in \mathbb{Z}}~\left[\forall_{i, j, k, l~|~\left(\left(j + 1\right) - i\right) \in \mathbb{N}, \left(i + a\right) = \left(k + b\right), \left(j + a\right) = \left(l + b\right)}~\left(\left(f(i + a), \ldots, f(j + a)\right) = \left(f(k + b), \ldots, f(l + b)\right)\right)\right]\right]

# %%
shift_equivalence_both.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
shift_equivalence_both.expr_info()
# Out:
# 0. forall_{f} [forall_{a, b in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b)))]]
#    core type: Operation
#    operator: 10
#    operand: 2
# 1. (f -> [forall_{a, b in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b)))]])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. f -> [forall_{a, b in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b)))]]
#    core type: Lambda
#    parameter: 54
#    body: 3
# 3. forall_{a, b in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b)))]
#    core type: Operation
#    operator: 10
#    operand: 5
# 4. ((a, b) -> {forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b))) if a in Integer ,  b in Integer.)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. (a, b) -> {forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b))) if a in Integer ,  b in Integer.
#    core type: Lambda
#    parameters: 6\n   body: 7
# 6. (a, b)
#    core type: ExprTuple
#    sub-expressions: 70, 72
# 7. {forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b))) if a in Integer ,  b in Integer.
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b)))
#    core type: Operation
#    operator: 10
#    operand: 13
# 9. (a in Integer) and (b in Integer)
#    core type: Operation
#    operator: 24
#    operands: 12
# 10. forall
#     core type: Literal
#     sub-expressions:
# 11. ((i, j, k, l) -> {(f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b)) if ((j + 1) - i) in Natural ,  (i + a) = (k + b) ,  (j + a) = (l + b).)
#     core type: ExprTuple
#     sub-expressions: 13
# 12. (a in Integer, b in Integer)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. (i, j, k, l) -> {(f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b)) if ((j + 1) - i) in Natural ,  (i + a) = (k + b) ,  (j + a) = (l + b).
#     core type: Lambda
#     parameters: 16\n    body: 17
# 14. a in Integer
#     core type: Operation
#     operator: 33
#     operands: 18
# 15. b in Integer
#     core type: Operation
#     operator: 33
#     operands: 19
# 16. (i, j, k, l)
#     core type: ExprTuple
#     sub-expressions: 71, 67, 69, 58
# 17. {(f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b)) if ((j + 1) - i) in Natural ,  (i + a) = (k + b) ,  (j + a) = (l + b).
#     core type: Conditional
#     value: 20
#     condition: 21
# 18. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 70, 22
# 19. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 72, 22
# 20. (f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b))
#     core type: Operation
#     operator: 36
#     operands: 23
# 21. (((j + 1) - i) in Natural) and ((i + a) = (k + b)) and ((j + a) = (l + b))
#     core type: Operation
#     operator: 24
#     operands: 25
# 22. Integer
#     core type: Literal
#     sub-expressions:
# 23. ((f(i + a), ..f(k + a).., f(j + a)), (f(k + b), ..f(i + b).., f(l + b)))
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. and
#     core type: Literal
#     sub-expressions:
# 25. (((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b))
#     core type: ExprTuple
#     sub-expressions: 28, 29, 30
# 26. (f(i + a), ..f(k + a).., f(j + a))
#     core type: ExprTuple
#     sub-expressions: 31
# 27. (f(k + b), ..f(i + b).., f(l + b))
#     core type: ExprTuple
#     sub-expressions: 32
# 28. ((j + 1) - i) in Natural
#     core type: Operation
#     operator: 33
#     operands: 34
# 29. (i + a) = (k + b)
#     core type: Operation
#     operator: 36
#     operands: 35
# 30. (j + a) = (l + b)
#     core type: Operation
#     operator: 36
#     operands: 37
# 31. f(i + a), ..f(k + a).., f(j + a)
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 71
#     end_index: 67
# 32. f(k + b), ..f(i + b).., f(l + b)
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 69
#     end_index: 58
# 33. in
#     core type: Literal
#     sub-expressions:
# 34. ((j + 1) - i, Natural)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 35. (i + a, k + b)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 36. =
#     core type: Literal
#     sub-expressions:
# 37. (j + a, l + b)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 38. k -> f(k + a)
#     core type: Lambda
#     parameter: 69
#     body: 46
# 39. i -> f(i + b)
#     core type: Lambda
#     parameter: 71
#     body: 47
# 40. (j + 1) - i
#     core type: Operation
#     operator: 65
#     operands: 48
# 41. Natural
#     core type: Literal
#     sub-expressions:
# 42. i + a
#     core type: Operation
#     operator: 65
#     operands: 49
# 43. k + b
#     core type: Operation
#     operator: 65
#     operands: 50
# 44. j + a
#     core type: Operation
#     operator: 65
#     operands: 51
# 45. l + b
#     core type: Operation
#     operator: 65
#     operands: 52
# 46. f(k + a)
#     core type: Operation
#     operator: 54
#     operand: 59
# 47. f(i + b)
#     core type: Operation
#     operator: 54
#     operand: 60
# 48. (j + 1, -i)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 49. (i, a)
#     core type: ExprTuple
#     sub-expressions: 71, 70
# 50. (k, b)
#     core type: ExprTuple
#     sub-expressions: 69, 72
# 51. (j, a)
#     core type: ExprTuple
#     sub-expressions: 67, 70
# 52. (l, b)
#     core type: ExprTuple
#     sub-expressions: 58, 72
# 53. (k + a)
#     core type: ExprTuple
#     sub-expressions: 59
# 54. f
#     core type: Variable
#     sub-expressions:
# 55. (i + b)
#     core type: ExprTuple
#     sub-expressions: 60
# 56. j + 1
#     core type: Operation
#     operator: 65
#     operands: 61
# 57. -i
#     core type: Operation
#     operator: 62
#     operand: 71
# 58. l
#     core type: Variable
#     sub-expressions:
# 59. k + a
#     core type: Operation
#     operator: 65
#     operands: 64
# 60. i + b
#     core type: Operation
#     operator: 65
#     operands: 66
# 61. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 62. -
#     core type: Literal
#     sub-expressions:
# 63. (i)
#     core type: ExprTuple
#     sub-expressions: 71
# 64. (k, a)
#     core type: ExprTuple
#     sub-expressions: 69, 70
# 65. +
#     core type: Literal
#     sub-expressions:
# 66. (i, b)
#     core type: ExprTuple
#     sub-expressions: 71, 72
# 67. j
#     core type: Variable
#     sub-expressions:
# 68. 1
#     core type: Literal
#     sub-expressions:
# 69. k
#     core type: Variable
#     sub-expressions:
# 70. a
#     core type: Variable
#     sub-expressions:
# 71. i
#     core type: Variable
#     sub-expressions:
# 72. b
#     core type: Variable
#     sub-expressions:
