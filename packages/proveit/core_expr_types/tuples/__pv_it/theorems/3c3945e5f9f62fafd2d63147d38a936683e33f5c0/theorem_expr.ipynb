# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#merge_series">merge_series</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types.tuples import merge_series

# %%
# check that the built expression is the same as the stored expression
assert merge_series.expr == stored_expr
assert merge_series.expr._style_id == stored_expr._style_id
print("Passed sanity check: merge_series matches stored_expr")
# Out:
# Passed sanity check: merge_series matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(merge_series.latex())
# Out:
# \vdash \forall_{f, i, j~|~\left(j - i\right) \in \mathbb{N}}~\left[\forall_{x_{0}, \ldots, x_{j - i}~|~x_{0} = f(i + 0), \ldots, x_{j - i} = f(i + \left(j - i\right))}~\left(\begin{array}{c} \begin{array}{l} \left(x_{0}, \ldots, x_{j - i}\right) =  \\ \left(f(i), \ldots, f(j)\right) \end{array} \end{array}\right)\right]

# %%
merge_series.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
merge_series.expr_info()
# Out:
# 0. forall_{f, i, j | (j - i) in Natural} [forall_{x_{0}, ..x_{i}.., x_{j - i} | x_{0} = f(i + 0), ..x_{k} = f(i + k).., x_{j - i} = f(i + (j - i))} ((x_{0}, ..x_{i}.., x_{j - i}) =  \\ (f(i), ..f(a).., f(j)))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((f, i, j) -> {forall_{x_{0}, ..x_{i}.., x_{j - i} | x_{0} = f(i + 0), ..x_{k} = f(i + k).., x_{j - i} = f(i + (j - i))} ((x_{0}, ..x_{i}.., x_{j - i}) =  \\ (f(i), ..f(a).., f(j))) if (j - i) in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (f, i, j) -> {forall_{x_{0}, ..x_{i}.., x_{j - i} | x_{0} = f(i + 0), ..x_{k} = f(i + k).., x_{j - i} = f(i + (j - i))} ((x_{0}, ..x_{i}.., x_{j - i}) =  \\ (f(i), ..f(a).., f(j))) if (j - i) in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (f, i, j)
#    core type: ExprTuple
#    sub-expressions: 45, 50, 35
# ...
