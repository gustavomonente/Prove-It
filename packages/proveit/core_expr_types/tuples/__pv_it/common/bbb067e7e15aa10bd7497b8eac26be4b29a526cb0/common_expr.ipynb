# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#f_i_to_j__m_to_n">f_i_to_j__m_to_n</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types.tuples import f_i_to_j__m_to_n

# %%
# check that the built expression is the same as the stored expression
assert f_i_to_j__m_to_n == stored_expr
assert f_i_to_j__m_to_n._style_id == stored_expr._style_id
print("Passed sanity check: f_i_to_j__m_to_n matches stored_expr")
# Out:
# Passed sanity check: f_i_to_j__m_to_n matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(f_i_to_j__m_to_n.latex())
# Out:
# f_{m}(i), \ldots, f_{m}(j), \ldots\ldots, f_{n}(i), \ldots, f_{n}(j)

# %%
f_i_to_j__m_to_n.style_options()
# Out:
# style name: parameterization
# description: 'implicit' (default for LaTeX formatting) hides the parameter the ExprRange so the parameterization may be ambiguous (e.g., x_{1+1}, ..., x_{n+1}); 'explicit' (default for string formatting) reveals the parameterization (e.g. x_{1+1}, ..x_{k+1}.., x_{n+1}).
# default: None
# current value: None/False
# related methods: ('with_explicit_parameterization', 'with_implicit_parameterization', 'with_default_parameterization_style')

# %%
# display the expression information
f_i_to_j__m_to_n.expr_info()
# Out:
# 0. f_{m}(i), ..f_{m}(x).., f_{m}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j)
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. k -> f_{k}(i), ..f_{k}(x).., f_{k}(j)
#    core type: Lambda
#    parameter: 14
#    body: 4
# 2. m
#    core type: Variable
#    sub-expressions:
# 3. n
#    core type: Variable
#    sub-expressions:
# 4. f_{k}(i), ..f_{k}(x).., f_{k}(j)
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 6
#    end_index: 7
# 5. x -> f_{k}(x)
#    core type: Lambda
#    parameter: 13
#    body: 8
# 6. i
#    core type: Variable
#    sub-expressions:
# 7. j
#    core type: Variable
#    sub-expressions:
# 8. f_{k}(x)
#    core type: Operation
#    operator: 9
#    operand: 13
# 9. f_{k}
#    core type: IndexedVar
# variable: 11
# index: 14
# 10. (x)
#     core type: ExprTuple
#     sub-expressions: 13
# 11. f
#     core type: Variable
#     sub-expressions:
# 12. (k)
# ...
