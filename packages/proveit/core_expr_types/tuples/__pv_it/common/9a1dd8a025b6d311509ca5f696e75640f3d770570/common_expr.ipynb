# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#f_1_to_i__1_to_n">f_1_to_i__1_to_n</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types.tuples import f_1_to_i__1_to_n

# %%
# check that the built expression is the same as the stored expression
assert f_1_to_i__1_to_n == stored_expr
assert f_1_to_i__1_to_n._style_id == stored_expr._style_id
print("Passed sanity check: f_1_to_i__1_to_n matches stored_expr")
# Out:
# Passed sanity check: f_1_to_i__1_to_n matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(f_1_to_i__1_to_n.latex())
# Out:
# f_{1}(1), \ldots, f_{1}(i), \ldots\ldots, f_{n}(1), \ldots, f_{n}(i)

# %%
f_1_to_i__1_to_n.style_options()
# Out:
# style name: parameterization
# description: 'implicit' (default for LaTeX formatting) hides the parameter the ExprRange so the parameterization may be ambiguous (e.g., x_{1+1}, ..., x_{n+1}); 'explicit' (default for string formatting) reveals the parameterization (e.g. x_{1+1}, ..x_{k+1}.., x_{n+1}).
# default: None
# current value: None/False
# related methods: ('with_explicit_parameterization', 'with_implicit_parameterization', 'with_default_parameterization_style')

# %%
# display the expression information
f_1_to_i__1_to_n.expr_info()
# Out:
# 0. f_{1}(1), ..f_{1}(x).., f_{1}(i), ....f_{k}(1), ..f_{k}(x).., f_{k}(i)...., f_{n}(1), ..f_{n}(x).., f_{n}(i)
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 5
#    end_index: 2
# 1. k -> f_{k}(1), ..f_{k}(x).., f_{k}(i)
#    core type: Lambda
#    parameter: 13
#    body: 3
# 2. n
#    core type: Variable
#    sub-expressions:
# 3. f_{k}(1), ..f_{k}(x).., f_{k}(i)
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 5
#    end_index: 6
# 4. x -> f_{k}(x)
#    core type: Lambda
#    parameter: 12
#    body: 7
# 5. 1
#    core type: Literal
#    sub-expressions:
# 6. i
#    core type: Variable
#    sub-expressions:
# 7. f_{k}(x)
#    core type: Operation
#    operator: 8
#    operand: 12
# 8. f_{k}
#    core type: IndexedVar
# variable: 10
# index: 13
# 9. (x)
#    core type: ExprTuple
#    sub-expressions: 12
# 10. f
#     core type: Variable
#     sub-expressions:
# 11. (k)
#     core type: ExprTuple
#     sub-expressions: 13
# 12. x
# ...
