# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#range_extension_def">range_extension_def</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types.tuples import range_extension_def

# %%
# check that the built expression is the same as the stored expression
assert range_extension_def.expr == stored_expr
assert range_extension_def.expr._style_id == stored_expr._style_id
print("Passed sanity check: range_extension_def matches stored_expr")
# Out:
# Passed sanity check: range_extension_def matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(range_extension_def.latex())
# Out:
# \vdash \forall_{f, i, j~|~|\left(f(i), \ldots, f(j)\right)| \in \mathbb{N}}~\left(\begin{array}{c} \begin{array}{l} \left(f(i), \ldots, f(j + 1)\right) =  \\ \left(f(i), \ldots, f(j), f(j + 1)\right) \end{array} \end{array}\right)

# %%
range_extension_def.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
range_extension_def.expr_info()
# Out:
# 0. forall_{f, i, j | |(f(i), ..f(a).., f(j))| in Natural} ((f(i), ..f(a).., f(j + 1)) =  \\ (f(i), ..f(a).., f(j), f(j + 1)))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((f, i, j) -> {(f(i), ..f(a).., f(j + 1)) =  \\ (f(i), ..f(a).., f(j), f(j + 1)) if |(f(i), ..f(a).., f(j))| in Natural.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (f, i, j) -> {(f(i), ..f(a).., f(j + 1)) =  \\ (f(i), ..f(a).., f(j), f(j + 1)) if |(f(i), ..f(a).., f(j))| in Natural.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (f, i, j)
#    core type: ExprTuple
#    sub-expressions: 31, 27, 28
# 5. {(f(i), ..f(a).., f(j + 1)) =  \\ (f(i), ..f(a).., f(j), f(j + 1)) if |(f(i), ..f(a).., f(j))| in Natural.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (f(i), ..f(a).., f(j + 1)) =  \\ (f(i), ..f(a).., f(j), f(j + 1))
#    core type: Operation
#    operator: 8
#    operands: 9
# ...
