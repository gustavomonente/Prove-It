# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import b, d, i
from proveit.core_expr_types import a_1_to_i, c_1_to_i
from proveit.logic import And, Equals, Forall
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Forall([i], Forall([a_1_to_i, b, c_1_to_i, d], Equals(Equals([a_1_to_i, b], [c_1_to_i, d]), And(Equals([a_1_to_i], [c_1_to_i]), Equals(b, d))).with_wrapping_at(2)), domains = [Natural])
# Out:
# expr: forall_{i in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{i}, d} (((a_{1}, ..a_{_a}.., a_{i}, b) = (c_{1}, ..c_{_a}.., c_{i}, d)) =  \\ (((a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i})) and (b = d)))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{i \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{i}, b, c_{1}, \ldots, c_{i}, d}~\left(\begin{array}{c} \begin{array}{l} \left(\left(a_{1}, \ldots, a_{i}, b\right) = \left(c_{1}, \ldots, c_{i}, d\right)\right) =  \\ \left(\left(\left(a_{1}, \ldots, a_{i}\right) = \left(c_{1}, \ldots, c_{i}\right)\right) \land \left(b = d\right)\right) \end{array} \end{array}\right)\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{i in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{i}, d} (((a_{1}, ..a_{_a}.., a_{i}, b) = (c_{1}, ..c_{_a}.., c_{i}, d)) =  \\ (((a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i})) and (b = d)))]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (i -> {forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{i}, d} (((a_{1}, ..a_{_a}.., a_{i}, b) = (c_{1}, ..c_{_a}.., c_{i}, d)) =  \\ (((a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i})) and (b = d))) if i in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. i -> {forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{i}, d} (((a_{1}, ..a_{_a}.., a_{i}, b) = (c_{1}, ..c_{_a}.., c_{i}, d)) =  \\ (((a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i})) and (b = d))) if i in Natural.
#    core type: Lambda
#    parameter: 36
#    body: 3
# 3. {forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{i}, d} (((a_{1}, ..a_{_a}.., a_{i}, b) = (c_{1}, ..c_{_a}.., c_{i}, d)) =  \\ (((a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i})) and (b = d))) if i in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{i}, d} (((a_{1}, ..a_{_a}.., a_{i}, b) = (c_{1}, ..c_{_a}.., c_{i}, d)) =  \\ (((a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i})) and (b = d)))
#    core type: Operation
#    operator: 6
#    operand: 10
# 5. i in Natural
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{i}, d) -> (((a_{1}, ..a_{_a}.., a_{i}, b) = (c_{1}, ..c_{_a}.., c_{i}, d)) =  \\ (((a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i})) and (b = d))))
#    core type: ExprTuple
#    sub-expressions: 10
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (i, Natural)
#    core type: ExprTuple
#    sub-expressions: 36, 11
# 10. (a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{i}, d) -> (((a_{1}, ..a_{_a}.., a_{i}, b) = (c_{1}, ..c_{_a}.., c_{i}, d)) =  \\ (((a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i})) and (b = d)))
#     core type: Lambda
#     parameters: 12\n    body: 13
# 11. Natural
#     core type: Literal
#     sub-expressions:
# 12. (a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{i}, d)
#     core type: ExprTuple
#     sub-expressions: 31, 29, 32, 30
# 13. ((a_{1}, ..a_{_a}.., a_{i}, b) = (c_{1}, ..c_{_a}.., c_{i}, d)) =  \\ (((a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i})) and (b = d))
#     core type: Operation
#     operator: 25
#     operands: 14
# 14. ((a_{1}, ..a_{_a}.., a_{i}, b) = (c_{1}, ..c_{_a}.., c_{i}, d), ((a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i})) and (b = d))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. (a_{1}, ..a_{_a}.., a_{i}, b) = (c_{1}, ..c_{_a}.., c_{i}, d)
#     core type: Operation
#     operator: 25
#     operands: 17
# 16. ((a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i})) and (b = d)
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. ((a_{1}, ..a_{_a}.., a_{i}, b), (c_{1}, ..c_{_a}.., c_{i}, d))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. and
#     core type: Literal
#     sub-expressions:
# 19. ((a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i}), b = d)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. (a_{1}, ..a_{_a}.., a_{i}, b)
#     core type: ExprTuple
#     sub-expressions: 31, 29
# 21. (c_{1}, ..c_{_a}.., c_{i}, d)
#     core type: ExprTuple
#     sub-expressions: 32, 30
# 22. (a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i})
#     core type: Operation
#     operator: 25
#     operands: 24
# 23. b = d
#     core type: Operation
#     operator: 25
#     operands: 26
# 24. ((a_{1}, ..a_{_a}.., a_{i}), (c_{1}, ..c_{_a}.., c_{i}))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. =
#     core type: Literal
#     sub-expressions:
# 26. (b, d)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. (a_{1}, ..a_{_a}.., a_{i})
#     core type: ExprTuple
#     sub-expressions: 31
# 28. (c_{1}, ..c_{_a}.., c_{i})
#     core type: ExprTuple
#     sub-expressions: 32
# 29. b
#     core type: Variable
#     sub-expressions:
# 30. d
#     core type: Variable
#     sub-expressions:
# 31. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 35
#     end_index: 36
# 32. c_{1}, ..c_{_a}.., c_{i}
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 35
#     end_index: 36
# 33. _a -> a_{_a}
#     core type: Lambda
#     parameter: 42
#     body: 37
# 34. _a -> c_{_a}
#     core type: Lambda
#     parameter: 42
#     body: 38
# 35. 1
#     core type: Literal
#     sub-expressions:
# 36. i
#     core type: Variable
#     sub-expressions:
# 37. a_{_a}
#     core type: IndexedVar
# variable: 39
# index: 42
# 38. c_{_a}
#     core type: IndexedVar
# variable: 40
# index: 42
# 39. a
#     core type: Variable
#     sub-expressions:
# 40. c
#     core type: Variable
#     sub-expressions:
# 41. (_a)
#     core type: ExprTuple
#     sub-expressions: 42
# 42. _a
#     core type: Variable
#     sub-expressions:
