# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">core_expr_types</a>.<a class="ProveItLink" href="../../theory.ipynb">tuples</a>.<a class="ProveItLink" href="../../theorems.ipynb#tuple_eq_via_elem_eq">tuple_eq_via_elem_eq</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults
from proveit import a, b, c, d, m
from proveit.core_expr_types.tuples  import tuple_eq_def
from proveit.logic import And
from proveit.numbers import Add, zero, one
from proveit.numbers.number_sets.natural_numbers import fold_forall_natural_pos
# Out:
# params operands [x, y] [[not](FALSE), TRUE]
# params operands [x, y] [[not](FALSE), TRUE]
# params operands [x, y] [TRUE, [not](FALSE)]
# params operands [x, y] [TRUE, [not](FALSE)]
# params operands [A] [[not](FALSE)]
# params operands [A] [[not](FALSE)]
# params operands [A] [FALSE]
# params operands [A] [FALSE]
# params operands [x, y] [FALSE, TRUE]
# params operands [x, y] [FALSE, TRUE]
# params operands [x, y] [TRUE, FALSE]
# params operands [x, y] [TRUE, FALSE]
# params operands [A] [TRUE]
# params operands [x] [TRUE]
# params operands [A] [TRUE]
# params operands [A] [TRUE]
# params operands [A] [TRUE]
# params operands [A] [TRUE]
# params operands [A] [TRUE]
# params operands [A] [TRUE]
# params operands [A] [TRUE]
# params operands [x, y] [TRUE, FALSE]
# params operands [x, y] [TRUE, FALSE]
# params operands [A] [TRUE = FALSE]
# params operands [A] [TRUE = FALSE]
# params operands [x, y] [TRUE = FALSE, FALSE]
# params operands [x, y] [TRUE = FALSE, FALSE]
# params operands [x, y] [FALSE, TRUE = FALSE]
# params operands [x, y] [FALSE, TRUE = FALSE]
# params operands [A] [TRUE = FALSE]
# params operands [A] [TRUE = FALSE]
# params operands [A] [[not](TRUE = FALSE)]
# params operands [A] [[not](TRUE = FALSE)]
# params operands [x, y] [[not](TRUE = FALSE), TRUE]
# params operands [x, y] [[not](TRUE = FALSE), TRUE]
# params operands [x, y] [TRUE, [not](TRUE = FALSE)]
# params operands [x, y] [TRUE, [not](TRUE = FALSE)]
# params operands [A] [[not](TRUE = FALSE)]
# params operands [A] [[not](TRUE = FALSE)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](TRUE = FALSE)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](TRUE = FALSE)]
# params operands [A] [TRUE = FALSE]
# params operands [A] [TRUE = FALSE]
# params operands [A] [TRUE = FALSE]
# params operands [A] [TRUE = FALSE]
# params operands [A] [[not](TRUE = FALSE)]
# params operands [A] [[not](TRUE = FALSE)]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](TRUE = FALSE), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](TRUE = FALSE), TRUE]
# params operands [x, y] [TRUE, FALSE]
# params operands [x, y] [TRUE, FALSE]
# params operands [x, y] [FALSE, TRUE]
# params operands [x, y] [FALSE, TRUE]
# params operands [A] [FALSE = TRUE]
# params operands [A] [FALSE = TRUE]
# params operands [x, y] [FALSE = TRUE, FALSE]
# params operands [x, y] [FALSE = TRUE, FALSE]
# params operands [x, y] [FALSE, FALSE = TRUE]
# params operands [x, y] [FALSE, FALSE = TRUE]
# params operands [A] [FALSE = TRUE]
# params operands [A] [FALSE = TRUE]
# params operands [A] [[not](FALSE = TRUE)]
# params operands [A] [[not](FALSE = TRUE)]
# params operands [x, y] [[not](FALSE = TRUE), TRUE]
# params operands [x, y] [[not](FALSE = TRUE), TRUE]
# params operands [x, y] [TRUE, [not](FALSE = TRUE)]
# params operands [x, y] [TRUE, [not](FALSE = TRUE)]
# params operands [A] [[not](FALSE = TRUE)]
# params operands [A] [[not](FALSE = TRUE)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](FALSE = TRUE)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](FALSE = TRUE)]
# params operands [A] [FALSE = TRUE]
# params operands [A] [FALSE = TRUE]
# params operands [A] [FALSE = TRUE]
# params operands [A] [FALSE = TRUE]
# params operands [A] [[not](FALSE = TRUE)]
# params operands [A] [[not](FALSE = TRUE)]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](FALSE = TRUE), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](FALSE = TRUE), TRUE]
# params operands [x, y] [FALSE, TRUE]
# params operands [x, y] [FALSE, TRUE]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](FALSE)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](FALSE)]
# params operands [A] [FALSE]
# params operands [A] [FALSE]
# params operands [A] [FALSE]
# params operands [A] [FALSE]
# params operands [A] [[not](FALSE)]
# params operands [A] [[not](FALSE)]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](FALSE), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](FALSE), TRUE]
# params operands [x, y] [[not](TRUE), FALSE]
# params operands [x, y] [[not](TRUE), FALSE]
# params operands [x, y] [FALSE, [not](TRUE)]
# params operands [x, y] [FALSE, [not](TRUE)]
# params operands [A] [[not](TRUE)]
# params operands [A] [[not](TRUE)]
# params operands [A] [[not](TRUE)]
# params operands [A] [[not](TRUE)]
# params operands [A] [[not](TRUE)]
# params operands [A] [[not](TRUE)]
# params operands [x, y] [[not](TRUE), TRUE]
# params operands [x, y] [[not](TRUE), TRUE]
# params operands [x, y] [TRUE, [not](TRUE)]
# params operands [x, y] [TRUE, [not](TRUE)]
# params operands [x, y] [TRUE, [not](TRUE)]
# params operands [x, y] [TRUE, [not](TRUE)]
# params operands [A] [TRUE = [not](TRUE)]
# params operands [A] [TRUE = [not](TRUE)]
# params operands [x, y] [TRUE = [not](TRUE), FALSE]
# params operands [x, y] [TRUE = [not](TRUE), FALSE]
# params operands [x, y] [FALSE, TRUE = [not](TRUE)]
# params operands [x, y] [FALSE, TRUE = [not](TRUE)]
# params operands [A] [TRUE = [not](TRUE)]
# params operands [A] [TRUE = [not](TRUE)]
# params operands [A] [[not](TRUE = [not](TRUE))]
# params operands [A] [[not](TRUE = [not](TRUE))]
# params operands [x, y] [[not](TRUE = [not](TRUE)), TRUE]
# params operands [x, y] [[not](TRUE = [not](TRUE)), TRUE]
# params operands [x, y] [TRUE, [not](TRUE = [not](TRUE))]
# params operands [x, y] [TRUE, [not](TRUE = [not](TRUE))]
# params operands [A] [[not](TRUE = [not](TRUE))]
# params operands [A] [[not](TRUE = [not](TRUE))]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](TRUE = [not](TRUE))]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](TRUE = [not](TRUE))]
# params operands [A] [TRUE = [not](TRUE)]
# params operands [A] [TRUE = [not](TRUE)]
# params operands [A] [TRUE = [not](TRUE)]
# params operands [A] [TRUE = [not](TRUE)]
# params operands [A] [[not](TRUE = [not](TRUE))]
# params operands [A] [[not](TRUE = [not](TRUE))]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](TRUE = [not](TRUE)), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](TRUE = [not](TRUE)), TRUE]
# params operands [x, y] [TRUE, [not](TRUE)]
# params operands [x, y] [TRUE, [not](TRUE)]
# params operands [x, y] [[not](TRUE), TRUE]
# params operands [x, y] [[not](TRUE), TRUE]
# params operands [A] [[not](TRUE) = TRUE]
# params operands [A] [[not](TRUE) = TRUE]
# params operands [x, y] [[not](TRUE) = TRUE, FALSE]
# params operands [x, y] [[not](TRUE) = TRUE, FALSE]
# params operands [x, y] [FALSE, [not](TRUE) = TRUE]
# params operands [x, y] [FALSE, [not](TRUE) = TRUE]
# params operands [A] [[not](TRUE) = TRUE]
# params operands [A] [[not](TRUE) = TRUE]
# params operands [A] [[not]([not](TRUE) = TRUE)]
# params operands [A] [[not]([not](TRUE) = TRUE)]
# params operands [x, y] [[not]([not](TRUE) = TRUE), TRUE]
# params operands [x, y] [[not]([not](TRUE) = TRUE), TRUE]
# params operands [x, y] [TRUE, [not]([not](TRUE) = TRUE)]
# params operands [x, y] [TRUE, [not]([not](TRUE) = TRUE)]
# params operands [A] [[not]([not](TRUE) = TRUE)]
# params operands [A] [[not]([not](TRUE) = TRUE)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not]([not](TRUE) = TRUE)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not]([not](TRUE) = TRUE)]
# params operands [A] [[not](TRUE) = TRUE]
# params operands [A] [[not](TRUE) = TRUE]
# params operands [A] [[not](TRUE) = TRUE]
# params operands [A] [[not](TRUE) = TRUE]
# params operands [A] [[not]([not](TRUE) = TRUE)]
# params operands [A] [[not]([not](TRUE) = TRUE)]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not]([not](TRUE) = TRUE), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not]([not](TRUE) = TRUE), TRUE]
# params operands [x, y] [[not](TRUE), TRUE]
# params operands [x, y] [[not](TRUE), TRUE]
# params operands [A] [TRUE]
# params operands [A] [TRUE]
# params operands [A] [[not]([not](TRUE))]
# params operands [A] [[not]([not](TRUE))]
# params operands [x, y] [[not]([not](TRUE)), TRUE]
# params operands [x, y] [[not]([not](TRUE)), TRUE]
# params operands [x, y] [TRUE, [not]([not](TRUE))]
# params operands [x, y] [TRUE, [not]([not](TRUE))]
# params operands [A] [[not]([not](TRUE))]
# params operands [A] [[not]([not](TRUE))]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not]([not](TRUE))]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not]([not](TRUE))]
# params operands [A] [[not](TRUE)]
# params operands [A] [[not](TRUE)]
# params operands [A] [TRUE]
# params operands [A] [TRUE]
# params operands [A] [[not](TRUE)]
# params operands [A] [[not](TRUE)]
# params operands [A] [[not]([not](TRUE))]
# params operands [A] [[not]([not](TRUE))]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not]([not](TRUE)), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not]([not](TRUE)), TRUE]
# params operands [A] [FALSE]
# params operands [A] [FALSE]
# params operands [x, y] [BOOLEAN, {TRUE, FALSE}]
# params operands [x, y] [BOOLEAN, {TRUE, FALSE}]
# params operands [x, y] [{TRUE, FALSE}, BOOLEAN]
# params operands [x, y] [{TRUE, FALSE}, BOOLEAN]
# params operands [A] [FALSE]
# params operands [A] [FALSE]
# params operands [A, B] [NaturalPos, Natural]
# params operands [A, B] [NaturalPos, Natural]
# params operands [A, B] [Natural, Integer]
# params operands [A, B] [Natural, Integer]
# params operands [A, B] [NaturalPos, Integer]
# params operands [A, B] [NaturalPos, Integer]
# params operands [A, B] [Natural, Rational]
# params operands [A, B] [Natural, Rational]
# params operands [A, B] [Natural, RationalNonNeg]
# params operands [A, B] [Natural, RationalNonNeg]
# params operands [A, B] [NaturalPos, RationalPos]
# params operands [A, B] [NaturalPos, RationalPos]
# params operands [A, B] [NaturalPos, RationalNonZero]
# params operands [A, B] [NaturalPos, RationalNonZero]
# params operands [A, B] [RationalNonZero, Rational]
# params operands [A, B] [RationalNonZero, Rational]
# params operands [A, B] [RationalPos, Rational]
# params operands [A, B] [RationalPos, Rational]
# params operands [A, B] [RationalNeg, Rational]
# params operands [A, B] [RationalNeg, Rational]
# params operands [A, B] [RationalNonNeg, Rational]
# params operands [A, B] [RationalNonNeg, Rational]
# params operands [A, B] [RationalPos, RationalNonZero]
# params operands [A, B] [RationalPos, RationalNonZero]
# params operands [A, B] [RationalNeg, RationalNonZero]
# params operands [A, B] [RationalNeg, RationalNonZero]
# params operands [A, B] [RationalPos, RationalNonNeg]
# params operands [A, B] [RationalPos, RationalNonNeg]
# params operands [A, B] [RealPos, Real]
# params operands [A, B] [RealPos, Real]
# params operands [A, B] [RealNeg, Real]
# params operands [A, B] [RealNeg, Real]
# params operands [A, B] [RealNonNeg, Real]
# params operands [A, B] [RealNonNeg, Real]
# params operands [A, B] [Rational, Real]
# params operands [A, B] [Rational, Real]
# params operands [A, B] [Integer, Real]
# params operands [A, B] [Integer, Real]
# params operands [A, B] [Natural, Real]
# params operands [A, B] [Natural, Real]
# params operands [A, B] [NaturalPos, Real]
# params operands [A, B] [NaturalPos, Real]
# params operands [A, B] [NaturalPos, RealPos]
# params operands [A, B] [NaturalPos, RealPos]
# params operands [A, B] [Natural, RealNonNeg]
# params operands [A, B] [Natural, RealNonNeg]
# params operands [A, B] [NaturalPos, RealNonNeg]
# params operands [A, B] [NaturalPos, RealNonNeg]
# params operands [A, B] [RealPos, RealNonNeg]
# params operands [A, B] [RealPos, RealNonNeg]
# params operands [A, B] [Rational, Real]
# params operands [A, B, x] [Rational, Real, 0]
# params operands [A, B, x] [Rational, Real, 0]
# params operands [A, B] [Real, Complex]
# params operands [A, B] [Real, Complex]
# params operands [A, B] [Integer, Complex]
# params operands [A, B] [Integer, Complex]
# params operands [A, B] [Natural, Complex]
# params operands [A, B] [Natural, Complex]
# params operands [A, B] [Real, Complex]
# params operands [A, B, x] [Real, Complex, 0]
# params operands [A, B, x] [Real, Complex, 0]
# params operands [n] [0]
# params operands [n] [0]
# params operands [A, B] [Natural, Integer]
# params operands [A, B, x] [Natural, Integer, 0]
# params operands [A, B, x] [Natural, Integer, 0]
# params operands [A, B] [Integer, Rational]
# params operands [A, B] [Integer, Rational]
# params operands [A, B] [Integer, Rational]
# params operands [A, B, x] [Integer, Rational, 0]
# params operands [A, B, x] [Integer, Rational, 0]
# params operands [x, y] [0, 1]
# params operands [x, y] [0, 1]
# params operands [x, y] [1, 2]
# params operands [x, y] [1, 2]
# params operands [x, y] [2, 3]
# params operands [x, y] [2, 3]
# params operands [x, y] [3, 4]
# params operands [x, y] [3, 4]
# params operands [x, y] [4, 5]
# params operands [x, y] [4, 5]
# params operands [x, y] [5, 6]
# params operands [x, y] [5, 6]
# params operands [x, y] [6, 7]
# params operands [x, y] [6, 7]
# params operands [x, y] [7, 8]
# params operands [x, y] [7, 8]
# params operands [x, y] [8, 9]
# params operands [x, y] [8, 9]
# params operands [n] [1]
# params operands [n] [1]
# params operands [A, B] [Natural, Integer]
# params operands [A, B, x] [Natural, Integer, 1]
# params operands [A, B, x] [Natural, Integer, 1]
# params operands [A, B] [Integer, Rational]
# params operands [A, B, x] [Integer, Rational, 1]
# params operands [A, B, x] [Integer, Rational, 1]
# params operands [A, B] [Rational, Real]
# params operands [A, B, x] [Rational, Real, 1]
# params operands [A, B, x] [Rational, Real, 1]
# params operands [A, B] [Real, Complex]
# params operands [A, B, x] [Real, Complex, 1]
# params operands [A, B, x] [Real, Complex, 1]
# params operands [n] [2]
# params operands [n] [2]
# params operands [A, B] [Natural, Integer]
# params operands [A, B, x] [Natural, Integer, 2]
# params operands [A, B, x] [Natural, Integer, 2]
# params operands [A, B] [Integer, Rational]
# params operands [A, B, x] [Integer, Rational, 2]
# params operands [A, B, x] [Integer, Rational, 2]
# params operands [A, B] [Rational, Real]
# params operands [A, B, x] [Rational, Real, 2]
# params operands [A, B, x] [Rational, Real, 2]
# params operands [A, B] [Real, Complex]
# params operands [A, B, x] [Real, Complex, 2]
# params operands [A, B, x] [Real, Complex, 2]
# params operands [n] [3]
# params operands [n] [3]
# params operands [A, B] [Natural, Integer]
# params operands [A, B, x] [Natural, Integer, 3]
# params operands [A, B, x] [Natural, Integer, 3]
# params operands [A, B] [Integer, Rational]
# params operands [A, B, x] [Integer, Rational, 3]
# params operands [A, B, x] [Integer, Rational, 3]
# params operands [A, B] [Rational, Real]
# params operands [A, B, x] [Rational, Real, 3]
# params operands [A, B, x] [Rational, Real, 3]
# params operands [A, B] [Real, Complex]
# params operands [A, B, x] [Real, Complex, 3]
# params operands [A, B, x] [Real, Complex, 3]
# params operands [n] [4]
# params operands [n] [4]
# params operands [A, B] [Natural, Integer]
# params operands [A, B, x] [Natural, Integer, 4]
# params operands [A, B, x] [Natural, Integer, 4]
# params operands [A, B] [Integer, Rational]
# params operands [A, B, x] [Integer, Rational, 4]
# params operands [A, B, x] [Integer, Rational, 4]
# params operands [A, B] [Rational, Real]
# params operands [A, B, x] [Rational, Real, 4]
# params operands [A, B, x] [Rational, Real, 4]
# params operands [A, B] [Real, Complex]
# params operands [A, B, x] [Real, Complex, 4]
# params operands [A, B, x] [Real, Complex, 4]
# params operands [n] [5]
# params operands [n] [5]
# params operands [A, B] [Natural, Integer]
# params operands [A, B, x] [Natural, Integer, 5]
# params operands [A, B, x] [Natural, Integer, 5]
# params operands [A, B] [Integer, Rational]
# params operands [A, B, x] [Integer, Rational, 5]
# params operands [A, B, x] [Integer, Rational, 5]
# params operands [A, B] [Rational, Real]
# params operands [A, B, x] [Rational, Real, 5]
# params operands [A, B, x] [Rational, Real, 5]
# params operands [A, B] [Real, Complex]
# params operands [A, B, x] [Real, Complex, 5]
# params operands [A, B, x] [Real, Complex, 5]
# params operands [n] [6]
# params operands [n] [6]
# params operands [A, B] [Natural, Integer]
# params operands [A, B, x] [Natural, Integer, 6]
# params operands [A, B, x] [Natural, Integer, 6]
# params operands [A, B] [Integer, Rational]
# params operands [A, B, x] [Integer, Rational, 6]
# params operands [A, B, x] [Integer, Rational, 6]
# params operands [A, B] [Rational, Real]
# params operands [A, B, x] [Rational, Real, 6]
# params operands [A, B, x] [Rational, Real, 6]
# params operands [A, B] [Real, Complex]
# params operands [A, B, x] [Real, Complex, 6]
# params operands [A, B, x] [Real, Complex, 6]
# params operands [n] [7]
# params operands [n] [7]
# params operands [A, B] [Natural, Integer]
# params operands [A, B, x] [Natural, Integer, 7]
# params operands [A, B, x] [Natural, Integer, 7]
# params operands [A, B] [Integer, Rational]
# params operands [A, B, x] [Integer, Rational, 7]
# params operands [A, B, x] [Integer, Rational, 7]
# params operands [A, B] [Rational, Real]
# params operands [A, B, x] [Rational, Real, 7]
# params operands [A, B, x] [Rational, Real, 7]
# params operands [A, B] [Real, Complex]
# params operands [A, B, x] [Real, Complex, 7]
# params operands [A, B, x] [Real, Complex, 7]
# params operands [n] [8]
# params operands [n] [8]
# params operands [A, B] [Natural, Integer]
# params operands [A, B, x] [Natural, Integer, 8]
# params operands [A, B, x] [Natural, Integer, 8]
# params operands [A, B] [Integer, Rational]
# params operands [A, B, x] [Integer, Rational, 8]
# params operands [A, B, x] [Integer, Rational, 8]
# params operands [A, B] [Rational, Real]
# params operands [A, B, x] [Rational, Real, 8]
# params operands [A, B, x] [Rational, Real, 8]
# params operands [A, B] [Real, Complex]
# params operands [A, B, x] [Real, Complex, 8]
# params operands [A, B, x] [Real, Complex, 8]
# params operands [n] [9]
# params operands [n] [9]
# params operands [A, B] [Natural, Integer]
# params operands [A, B, x] [Natural, Integer, 9]
# params operands [A, B, x] [Natural, Integer, 9]
# params operands [A, B] [Integer, Rational]
# params operands [A, B, x] [Integer, Rational, 9]
# params operands [A, B, x] [Integer, Rational, 9]
# params operands [A, B] [Rational, Real]
# params operands [A, B, x] [Rational, Real, 9]
# params operands [A, B, x] [Rational, Real, 9]
# params operands [A, B] [Real, Complex]
# params operands [A, B, x] [Real, Complex, 9]
# params operands [A, B, x] [Real, Complex, 9]
# params operands [n] [1]
# params operands [n] [1]
# params operands [A, B] [NaturalPos, Natural]
# params operands [A, B, x] [NaturalPos, Natural, 1]
# params operands [A, B, x] [NaturalPos, Natural, 1]
# params operands [n] [1]
# params operands [n] [1]
# params operands [x, y] [1, 0]
# params operands [x, y] [1, 0]
# params operands [x, y] [0, 1]
# params operands [x, y] [0, 1]
# params operands [x, y] [0, 1]
# params operands [x, y] [0, 1]
# params operands [A] [0 = 1]
# params operands [A] [0 = 1]
# params operands [x, y] [0 = 1, FALSE]
# params operands [x, y] [0 = 1, FALSE]
# params operands [x, y] [FALSE, 0 = 1]
# params operands [x, y] [FALSE, 0 = 1]
# params operands [A] [0 = 1]
# params operands [A] [0 = 1]
# params operands [A] [[not](0 = 1)]
# params operands [A] [[not](0 = 1)]
# params operands [x, y] [[not](0 = 1), TRUE]
# params operands [x, y] [[not](0 = 1), TRUE]
# params operands [x, y] [TRUE, [not](0 = 1)]
# params operands [x, y] [TRUE, [not](0 = 1)]
# params operands [A] [[not](0 = 1)]
# params operands [A] [[not](0 = 1)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](0 = 1)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](0 = 1)]
# params operands [A] [0 = 1]
# params operands [A] [0 = 1]
# params operands [A] [0 = 1]
# params operands [A] [0 = 1]
# params operands [A] [[not](0 = 1)]
# params operands [A] [[not](0 = 1)]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](0 = 1), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](0 = 1), TRUE]
# params operands [x, y] [0, 1]
# params operands [x, y] [0, 1]
# params operands [x, y] [1, 0]
# params operands [x, y] [1, 0]
# params operands [A] [1 = 0]
# params operands [A] [1 = 0]
# params operands [x, y] [1 = 0, FALSE]
# params operands [x, y] [1 = 0, FALSE]
# params operands [x, y] [FALSE, 1 = 0]
# params operands [x, y] [FALSE, 1 = 0]
# params operands [A] [1 = 0]
# params operands [A] [1 = 0]
# params operands [A] [[not](1 = 0)]
# params operands [A] [[not](1 = 0)]
# params operands [x, y] [[not](1 = 0), TRUE]
# params operands [x, y] [[not](1 = 0), TRUE]
# params operands [x, y] [TRUE, [not](1 = 0)]
# params operands [x, y] [TRUE, [not](1 = 0)]
# params operands [A] [[not](1 = 0)]
# params operands [A] [[not](1 = 0)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](1 = 0)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](1 = 0)]
# params operands [A] [1 = 0]
# params operands [A] [1 = 0]
# params operands [A] [1 = 0]
# params operands [A] [1 = 0]
# params operands [A] [[not](1 = 0)]
# params operands [A] [[not](1 = 0)]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](1 = 0), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](1 = 0), TRUE]
# params operands [x, y] [1, 0]
# params operands [x, y] [1, 0]
# params operands [n] [2]
# params operands [n] [2]
# params operands [A, B] [NaturalPos, Natural]
# params operands [A, B, x] [NaturalPos, Natural, 2]
# params operands [A, B, x] [NaturalPos, Natural, 2]
# params operands [n] [2]
# params operands [n] [2]
# params operands [x, y] [2, 0]
# params operands [x, y] [2, 0]
# params operands [x, y] [0, 2]
# params operands [x, y] [0, 2]
# params operands [x, y] [0, 2]
# params operands [x, y] [0, 2]
# params operands [A] [0 = 2]
# params operands [A] [0 = 2]
# params operands [x, y] [0 = 2, FALSE]
# params operands [x, y] [0 = 2, FALSE]
# params operands [x, y] [FALSE, 0 = 2]
# params operands [x, y] [FALSE, 0 = 2]
# params operands [A] [0 = 2]
# params operands [A] [0 = 2]
# params operands [A] [[not](0 = 2)]
# params operands [A] [[not](0 = 2)]
# params operands [x, y] [[not](0 = 2), TRUE]
# params operands [x, y] [[not](0 = 2), TRUE]
# params operands [x, y] [TRUE, [not](0 = 2)]
# params operands [x, y] [TRUE, [not](0 = 2)]
# params operands [A] [[not](0 = 2)]
# params operands [A] [[not](0 = 2)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](0 = 2)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](0 = 2)]
# params operands [A] [0 = 2]
# params operands [A] [0 = 2]
# params operands [A] [0 = 2]
# params operands [A] [0 = 2]
# params operands [A] [[not](0 = 2)]
# params operands [A] [[not](0 = 2)]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](0 = 2), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](0 = 2), TRUE]
# params operands [x, y] [0, 2]
# params operands [x, y] [0, 2]
# params operands [x, y] [2, 0]
# params operands [x, y] [2, 0]
# params operands [A] [2 = 0]
# params operands [A] [2 = 0]
# params operands [x, y] [2 = 0, FALSE]
# params operands [x, y] [2 = 0, FALSE]
# params operands [x, y] [FALSE, 2 = 0]
# params operands [x, y] [FALSE, 2 = 0]
# params operands [A] [2 = 0]
# params operands [A] [2 = 0]
# params operands [A] [[not](2 = 0)]
# params operands [A] [[not](2 = 0)]
# params operands [x, y] [[not](2 = 0), TRUE]
# params operands [x, y] [[not](2 = 0), TRUE]
# params operands [x, y] [TRUE, [not](2 = 0)]
# params operands [x, y] [TRUE, [not](2 = 0)]
# params operands [A] [[not](2 = 0)]
# params operands [A] [[not](2 = 0)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](2 = 0)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](2 = 0)]
# params operands [A] [2 = 0]
# params operands [A] [2 = 0]
# params operands [A] [2 = 0]
# params operands [A] [2 = 0]
# params operands [A] [[not](2 = 0)]
# params operands [A] [[not](2 = 0)]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](2 = 0), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](2 = 0), TRUE]
# params operands [x, y] [2, 0]
# params operands [x, y] [2, 0]
# params operands [n] [3]
# params operands [n] [3]
# params operands [A, B] [NaturalPos, Natural]
# params operands [A, B, x] [NaturalPos, Natural, 3]
# params operands [A, B, x] [NaturalPos, Natural, 3]
# params operands [n] [3]
# params operands [n] [3]
# params operands [x, y] [3, 0]
# params operands [x, y] [3, 0]
# params operands [x, y] [0, 3]
# params operands [x, y] [0, 3]
# params operands [x, y] [0, 3]
# params operands [x, y] [0, 3]
# params operands [A] [0 = 3]
# params operands [A] [0 = 3]
# params operands [x, y] [0 = 3, FALSE]
# params operands [x, y] [0 = 3, FALSE]
# params operands [x, y] [FALSE, 0 = 3]
# params operands [x, y] [FALSE, 0 = 3]
# params operands [A] [0 = 3]
# params operands [A] [0 = 3]
# params operands [A] [[not](0 = 3)]
# params operands [A] [[not](0 = 3)]
# params operands [x, y] [[not](0 = 3), TRUE]
# params operands [x, y] [[not](0 = 3), TRUE]
# params operands [x, y] [TRUE, [not](0 = 3)]
# params operands [x, y] [TRUE, [not](0 = 3)]
# params operands [A] [[not](0 = 3)]
# params operands [A] [[not](0 = 3)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](0 = 3)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](0 = 3)]
# params operands [A] [0 = 3]
# params operands [A] [0 = 3]
# params operands [A] [0 = 3]
# params operands [A] [0 = 3]
# params operands [A] [[not](0 = 3)]
# params operands [A] [[not](0 = 3)]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](0 = 3), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](0 = 3), TRUE]
# params operands [x, y] [0, 3]
# params operands [x, y] [0, 3]
# params operands [x, y] [3, 0]
# params operands [x, y] [3, 0]
# params operands [A] [3 = 0]
# params operands [A] [3 = 0]
# params operands [x, y] [3 = 0, FALSE]
# params operands [x, y] [3 = 0, FALSE]
# params operands [x, y] [FALSE, 3 = 0]
# params operands [x, y] [FALSE, 3 = 0]
# params operands [A] [3 = 0]
# params operands [A] [3 = 0]
# params operands [A] [[not](3 = 0)]
# params operands [A] [[not](3 = 0)]
# params operands [x, y] [[not](3 = 0), TRUE]
# params operands [x, y] [[not](3 = 0), TRUE]
# params operands [x, y] [TRUE, [not](3 = 0)]
# params operands [x, y] [TRUE, [not](3 = 0)]
# params operands [A] [[not](3 = 0)]
# params operands [A] [[not](3 = 0)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](3 = 0)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](3 = 0)]
# params operands [A] [3 = 0]
# params operands [A] [3 = 0]
# params operands [A] [3 = 0]
# params operands [A] [3 = 0]
# params operands [A] [[not](3 = 0)]
# params operands [A] [[not](3 = 0)]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](3 = 0), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](3 = 0), TRUE]
# params operands [x, y] [3, 0]
# params operands [x, y] [3, 0]
# params operands [n] [4]
# params operands [n] [4]
# params operands [A, B] [NaturalPos, Natural]
# params operands [A, B, x] [NaturalPos, Natural, 4]
# params operands [A, B, x] [NaturalPos, Natural, 4]
# params operands [n] [4]
# params operands [n] [4]
# params operands [x, y] [4, 0]
# params operands [x, y] [4, 0]
# params operands [x, y] [0, 4]
# params operands [x, y] [0, 4]
# params operands [x, y] [0, 4]
# params operands [x, y] [0, 4]
# params operands [A] [0 = 4]
# params operands [A] [0 = 4]
# params operands [x, y] [0 = 4, FALSE]
# params operands [x, y] [0 = 4, FALSE]
# params operands [x, y] [FALSE, 0 = 4]
# params operands [x, y] [FALSE, 0 = 4]
# params operands [A] [0 = 4]
# params operands [A] [0 = 4]
# params operands [A] [[not](0 = 4)]
# params operands [A] [[not](0 = 4)]
# params operands [x, y] [[not](0 = 4), TRUE]
# params operands [x, y] [[not](0 = 4), TRUE]
# params operands [x, y] [TRUE, [not](0 = 4)]
# params operands [x, y] [TRUE, [not](0 = 4)]
# params operands [A] [[not](0 = 4)]
# params operands [A] [[not](0 = 4)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](0 = 4)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](0 = 4)]
# params operands [A] [0 = 4]
# params operands [A] [0 = 4]
# params operands [A] [0 = 4]
# params operands [A] [0 = 4]
# params operands [A] [[not](0 = 4)]
# params operands [A] [[not](0 = 4)]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](0 = 4), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](0 = 4), TRUE]
# params operands [x, y] [0, 4]
# params operands [x, y] [0, 4]
# params operands [x, y] [4, 0]
# params operands [x, y] [4, 0]
# params operands [A] [4 = 0]
# params operands [A] [4 = 0]
# params operands [x, y] [4 = 0, FALSE]
# params operands [x, y] [4 = 0, FALSE]
# params operands [x, y] [FALSE, 4 = 0]
# params operands [x, y] [FALSE, 4 = 0]
# params operands [A] [4 = 0]
# params operands [A] [4 = 0]
# params operands [A] [[not](4 = 0)]
# params operands [A] [[not](4 = 0)]
# params operands [x, y] [[not](4 = 0), TRUE]
# params operands [x, y] [[not](4 = 0), TRUE]
# params operands [x, y] [TRUE, [not](4 = 0)]
# params operands [x, y] [TRUE, [not](4 = 0)]
# params operands [A] [[not](4 = 0)]
# params operands [A] [[not](4 = 0)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](4 = 0)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](4 = 0)]
# params operands [A] [4 = 0]
# params operands [A] [4 = 0]
# params operands [A] [4 = 0]
# params operands [A] [4 = 0]
# params operands [A] [[not](4 = 0)]
# params operands [A] [[not](4 = 0)]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](4 = 0), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](4 = 0), TRUE]
# params operands [x, y] [4, 0]
# params operands [x, y] [4, 0]
# params operands [n] [5]
# params operands [n] [5]
# params operands [A, B] [NaturalPos, Natural]
# params operands [A, B, x] [NaturalPos, Natural, 5]
# params operands [A, B, x] [NaturalPos, Natural, 5]
# params operands [n] [5]
# params operands [n] [5]
# params operands [x, y] [5, 0]
# params operands [x, y] [5, 0]
# params operands [x, y] [0, 5]
# params operands [x, y] [0, 5]
# params operands [x, y] [0, 5]
# params operands [x, y] [0, 5]
# params operands [A] [0 = 5]
# params operands [A] [0 = 5]
# params operands [x, y] [0 = 5, FALSE]
# params operands [x, y] [0 = 5, FALSE]
# params operands [x, y] [FALSE, 0 = 5]
# params operands [x, y] [FALSE, 0 = 5]
# params operands [A] [0 = 5]
# params operands [A] [0 = 5]
# params operands [A] [[not](0 = 5)]
# params operands [A] [[not](0 = 5)]
# params operands [x, y] [[not](0 = 5), TRUE]
# params operands [x, y] [[not](0 = 5), TRUE]
# params operands [x, y] [TRUE, [not](0 = 5)]
# params operands [x, y] [TRUE, [not](0 = 5)]
# params operands [A] [[not](0 = 5)]
# params operands [A] [[not](0 = 5)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](0 = 5)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](0 = 5)]
# params operands [A] [0 = 5]
# params operands [A] [0 = 5]
# params operands [A] [0 = 5]
# params operands [A] [0 = 5]
# params operands [A] [[not](0 = 5)]
# params operands [A] [[not](0 = 5)]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](0 = 5), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](0 = 5), TRUE]
# params operands [x, y] [0, 5]
# params operands [x, y] [0, 5]
# params operands [x, y] [5, 0]
# params operands [x, y] [5, 0]
# params operands [A] [5 = 0]
# params operands [A] [5 = 0]
# params operands [x, y] [5 = 0, FALSE]
# params operands [x, y] [5 = 0, FALSE]
# params operands [x, y] [FALSE, 5 = 0]
# params operands [x, y] [FALSE, 5 = 0]
# params operands [A] [5 = 0]
# params operands [A] [5 = 0]
# params operands [A] [[not](5 = 0)]
# params operands [A] [[not](5 = 0)]
# params operands [x, y] [[not](5 = 0), TRUE]
# params operands [x, y] [[not](5 = 0), TRUE]
# params operands [x, y] [TRUE, [not](5 = 0)]
# params operands [x, y] [TRUE, [not](5 = 0)]
# params operands [A] [[not](5 = 0)]
# params operands [A] [[not](5 = 0)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](5 = 0)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](5 = 0)]
# params operands [A] [5 = 0]
# params operands [A] [5 = 0]
# params operands [A] [5 = 0]
# params operands [A] [5 = 0]
# params operands [A] [[not](5 = 0)]
# params operands [A] [[not](5 = 0)]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](5 = 0), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](5 = 0), TRUE]
# params operands [x, y] [5, 0]
# params operands [x, y] [5, 0]
# params operands [n] [6]
# params operands [n] [6]
# params operands [A, B] [NaturalPos, Natural]
# params operands [A, B, x] [NaturalPos, Natural, 6]
# params operands [A, B, x] [NaturalPos, Natural, 6]
# params operands [n] [6]
# params operands [n] [6]
# params operands [x, y] [6, 0]
# params operands [x, y] [6, 0]
# params operands [x, y] [0, 6]
# params operands [x, y] [0, 6]
# params operands [x, y] [0, 6]
# params operands [x, y] [0, 6]
# params operands [A] [0 = 6]
# params operands [A] [0 = 6]
# params operands [x, y] [0 = 6, FALSE]
# params operands [x, y] [0 = 6, FALSE]
# params operands [x, y] [FALSE, 0 = 6]
# params operands [x, y] [FALSE, 0 = 6]
# params operands [A] [0 = 6]
# params operands [A] [0 = 6]
# params operands [A] [[not](0 = 6)]
# params operands [A] [[not](0 = 6)]
# params operands [x, y] [[not](0 = 6), TRUE]
# params operands [x, y] [[not](0 = 6), TRUE]
# params operands [x, y] [TRUE, [not](0 = 6)]
# params operands [x, y] [TRUE, [not](0 = 6)]
# params operands [A] [[not](0 = 6)]
# params operands [A] [[not](0 = 6)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](0 = 6)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](0 = 6)]
# params operands [A] [0 = 6]
# params operands [A] [0 = 6]
# params operands [A] [0 = 6]
# params operands [A] [0 = 6]
# params operands [A] [[not](0 = 6)]
# params operands [A] [[not](0 = 6)]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](0 = 6), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](0 = 6), TRUE]
# params operands [x, y] [0, 6]
# params operands [x, y] [0, 6]
# params operands [x, y] [6, 0]
# params operands [x, y] [6, 0]
# params operands [A] [6 = 0]
# params operands [A] [6 = 0]
# params operands [x, y] [6 = 0, FALSE]
# params operands [x, y] [6 = 0, FALSE]
# params operands [x, y] [FALSE, 6 = 0]
# params operands [x, y] [FALSE, 6 = 0]
# params operands [A] [6 = 0]
# params operands [A] [6 = 0]
# params operands [A] [[not](6 = 0)]
# params operands [A] [[not](6 = 0)]
# params operands [x, y] [[not](6 = 0), TRUE]
# params operands [x, y] [[not](6 = 0), TRUE]
# params operands [x, y] [TRUE, [not](6 = 0)]
# params operands [x, y] [TRUE, [not](6 = 0)]
# params operands [A] [[not](6 = 0)]
# params operands [A] [[not](6 = 0)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](6 = 0)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](6 = 0)]
# params operands [A] [6 = 0]
# params operands [A] [6 = 0]
# params operands [A] [6 = 0]
# params operands [A] [6 = 0]
# params operands [A] [[not](6 = 0)]
# params operands [A] [[not](6 = 0)]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](6 = 0), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](6 = 0), TRUE]
# params operands [x, y] [6, 0]
# params operands [x, y] [6, 0]
# params operands [n] [7]
# params operands [n] [7]
# params operands [A, B] [NaturalPos, Natural]
# params operands [A, B, x] [NaturalPos, Natural, 7]
# params operands [A, B, x] [NaturalPos, Natural, 7]
# params operands [n] [7]
# params operands [n] [7]
# params operands [x, y] [7, 0]
# params operands [x, y] [7, 0]
# params operands [x, y] [0, 7]
# params operands [x, y] [0, 7]
# params operands [x, y] [0, 7]
# params operands [x, y] [0, 7]
# params operands [A] [0 = 7]
# params operands [A] [0 = 7]
# params operands [x, y] [0 = 7, FALSE]
# params operands [x, y] [0 = 7, FALSE]
# params operands [x, y] [FALSE, 0 = 7]
# params operands [x, y] [FALSE, 0 = 7]
# params operands [A] [0 = 7]
# params operands [A] [0 = 7]
# params operands [A] [[not](0 = 7)]
# params operands [A] [[not](0 = 7)]
# params operands [x, y] [[not](0 = 7), TRUE]
# params operands [x, y] [[not](0 = 7), TRUE]
# params operands [x, y] [TRUE, [not](0 = 7)]
# params operands [x, y] [TRUE, [not](0 = 7)]
# params operands [A] [[not](0 = 7)]
# params operands [A] [[not](0 = 7)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](0 = 7)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](0 = 7)]
# params operands [A] [0 = 7]
# params operands [A] [0 = 7]
# params operands [A] [0 = 7]
# params operands [A] [0 = 7]
# params operands [A] [[not](0 = 7)]
# params operands [A] [[not](0 = 7)]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](0 = 7), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](0 = 7), TRUE]
# params operands [x, y] [0, 7]
# params operands [x, y] [0, 7]
# params operands [x, y] [7, 0]
# params operands [x, y] [7, 0]
# params operands [A] [7 = 0]
# params operands [A] [7 = 0]
# params operands [x, y] [7 = 0, FALSE]
# params operands [x, y] [7 = 0, FALSE]
# params operands [x, y] [FALSE, 7 = 0]
# params operands [x, y] [FALSE, 7 = 0]
# params operands [A] [7 = 0]
# params operands [A] [7 = 0]
# params operands [A] [[not](7 = 0)]
# params operands [A] [[not](7 = 0)]
# params operands [x, y] [[not](7 = 0), TRUE]
# params operands [x, y] [[not](7 = 0), TRUE]
# params operands [x, y] [TRUE, [not](7 = 0)]
# params operands [x, y] [TRUE, [not](7 = 0)]
# params operands [A] [[not](7 = 0)]
# params operands [A] [[not](7 = 0)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](7 = 0)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](7 = 0)]
# params operands [A] [7 = 0]
# params operands [A] [7 = 0]
# params operands [A] [7 = 0]
# params operands [A] [7 = 0]
# params operands [A] [[not](7 = 0)]
# params operands [A] [[not](7 = 0)]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](7 = 0), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](7 = 0), TRUE]
# params operands [x, y] [7, 0]
# params operands [x, y] [7, 0]
# params operands [n] [8]
# params operands [n] [8]
# params operands [A, B] [NaturalPos, Natural]
# params operands [A, B, x] [NaturalPos, Natural, 8]
# params operands [A, B, x] [NaturalPos, Natural, 8]
# params operands [n] [8]
# params operands [n] [8]
# params operands [x, y] [8, 0]
# params operands [x, y] [8, 0]
# params operands [x, y] [0, 8]
# params operands [x, y] [0, 8]
# params operands [x, y] [0, 8]
# params operands [x, y] [0, 8]
# params operands [A] [0 = 8]
# params operands [A] [0 = 8]
# params operands [x, y] [0 = 8, FALSE]
# params operands [x, y] [0 = 8, FALSE]
# params operands [x, y] [FALSE, 0 = 8]
# params operands [x, y] [FALSE, 0 = 8]
# params operands [A] [0 = 8]
# params operands [A] [0 = 8]
# params operands [A] [[not](0 = 8)]
# params operands [A] [[not](0 = 8)]
# params operands [x, y] [[not](0 = 8), TRUE]
# params operands [x, y] [[not](0 = 8), TRUE]
# params operands [x, y] [TRUE, [not](0 = 8)]
# params operands [x, y] [TRUE, [not](0 = 8)]
# params operands [A] [[not](0 = 8)]
# params operands [A] [[not](0 = 8)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](0 = 8)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](0 = 8)]
# params operands [A] [0 = 8]
# params operands [A] [0 = 8]
# params operands [A] [0 = 8]
# params operands [A] [0 = 8]
# params operands [A] [[not](0 = 8)]
# params operands [A] [[not](0 = 8)]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](0 = 8), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](0 = 8), TRUE]
# params operands [x, y] [0, 8]
# params operands [x, y] [0, 8]
# params operands [x, y] [8, 0]
# params operands [x, y] [8, 0]
# params operands [A] [8 = 0]
# params operands [A] [8 = 0]
# params operands [x, y] [8 = 0, FALSE]
# params operands [x, y] [8 = 0, FALSE]
# params operands [x, y] [FALSE, 8 = 0]
# params operands [x, y] [FALSE, 8 = 0]
# params operands [A] [8 = 0]
# params operands [A] [8 = 0]
# params operands [A] [[not](8 = 0)]
# params operands [A] [[not](8 = 0)]
# params operands [x, y] [[not](8 = 0), TRUE]
# params operands [x, y] [[not](8 = 0), TRUE]
# params operands [x, y] [TRUE, [not](8 = 0)]
# params operands [x, y] [TRUE, [not](8 = 0)]
# params operands [A] [[not](8 = 0)]
# params operands [A] [[not](8 = 0)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](8 = 0)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](8 = 0)]
# params operands [A] [8 = 0]
# params operands [A] [8 = 0]
# params operands [A] [8 = 0]
# params operands [A] [8 = 0]
# params operands [A] [[not](8 = 0)]
# params operands [A] [[not](8 = 0)]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](8 = 0), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](8 = 0), TRUE]
# params operands [x, y] [8, 0]
# params operands [x, y] [8, 0]
# params operands [n] [9]
# params operands [n] [9]
# params operands [A, B] [NaturalPos, Natural]
# params operands [A, B, x] [NaturalPos, Natural, 9]
# params operands [A, B, x] [NaturalPos, Natural, 9]
# params operands [n] [9]
# params operands [n] [9]
# params operands [x, y] [9, 0]
# params operands [x, y] [9, 0]
# params operands [x, y] [0, 9]
# params operands [x, y] [0, 9]
# params operands [x, y] [0, 9]
# params operands [x, y] [0, 9]
# params operands [A] [0 = 9]
# params operands [A] [0 = 9]
# params operands [x, y] [0 = 9, FALSE]
# params operands [x, y] [0 = 9, FALSE]
# params operands [x, y] [FALSE, 0 = 9]
# params operands [x, y] [FALSE, 0 = 9]
# params operands [A] [0 = 9]
# params operands [A] [0 = 9]
# params operands [A] [[not](0 = 9)]
# params operands [A] [[not](0 = 9)]
# params operands [x, y] [[not](0 = 9), TRUE]
# params operands [x, y] [[not](0 = 9), TRUE]
# params operands [x, y] [TRUE, [not](0 = 9)]
# params operands [x, y] [TRUE, [not](0 = 9)]
# params operands [A] [[not](0 = 9)]
# params operands [A] [[not](0 = 9)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](0 = 9)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](0 = 9)]
# params operands [A] [0 = 9]
# params operands [A] [0 = 9]
# params operands [A] [0 = 9]
# params operands [A] [0 = 9]
# params operands [A] [[not](0 = 9)]
# params operands [A] [[not](0 = 9)]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](0 = 9), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](0 = 9), TRUE]
# params operands [x, y] [0, 9]
# params operands [x, y] [0, 9]
# params operands [x, y] [9, 0]
# params operands [x, y] [9, 0]
# params operands [A] [9 = 0]
# params operands [A] [9 = 0]
# params operands [x, y] [9 = 0, FALSE]
# params operands [x, y] [9 = 0, FALSE]
# params operands [x, y] [FALSE, 9 = 0]
# params operands [x, y] [FALSE, 9 = 0]
# params operands [A] [9 = 0]
# params operands [A] [9 = 0]
# params operands [A] [[not](9 = 0)]
# params operands [A] [[not](9 = 0)]
# params operands [x, y] [[not](9 = 0), TRUE]
# params operands [x, y] [[not](9 = 0), TRUE]
# params operands [x, y] [TRUE, [not](9 = 0)]
# params operands [x, y] [TRUE, [not](9 = 0)]
# params operands [A] [[not](9 = 0)]
# params operands [A] [[not](9 = 0)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](9 = 0)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](9 = 0)]
# params operands [A] [9 = 0]
# params operands [A] [9 = 0]
# params operands [A] [9 = 0]
# params operands [A] [9 = 0]
# params operands [A] [[not](9 = 0)]
# params operands [A] [[not](9 = 0)]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](9 = 0), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](9 = 0), TRUE]
# params operands [x, y] [9, 0]
# params operands [x, y] [9, 0]
# params operands [x, y] [-0, 0]
# params operands [x, y] [-0, 0]
# params operands [x, y] [0, -0]
# params operands [x, y] [0, -0]

# %%
# %proving tuple_eq_via_elem_eq
# Out:
# tuple_eq_via_elem_eq: forall_{i in NaturalPos} [forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{i} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{i} = b_{i}} ((a_{1}, ..a_{_a}.., a_{i}) = (b_{1}, ..b_{_a}.., b_{i}))]

# %% [markdown]
# ### Instantiate the induction theorem for an inductive proof.

# %%
tuple_eq_via_elem_eq.instance_expr
# Out:
# forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{i} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{i} = b_{i}} ((a_{1}, ..a_{_a}.., a_{i}) = (b_{1}, ..b_{_a}.., b_{i}))

# %%
fold_forall_natural_pos
# Out:
# |- forall_{P} ((P(1) and [forall_{m in NaturalPos | P(m)} P(m + 1)]) => [forall_{n in NaturalPos} P(n)])

# %%
from proveit import Function
from proveit import P, i
induction_inst = \
    fold_forall_natural_pos.instantiate({Function(P, i):tuple_eq_via_elem_eq.instance_expr}) \
        .inner_expr().with_wrapping_at(1).inner_expr().antecedent.with_wrapping_at(1)
# Out:
# params operands [P] [i -> [forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{i} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{i} = b_{i}} ((a_{1}, ..a_{_a}.., a_{i}) = (b_{1}, ..b_{_a}.., b_{i}))]]
# params operands [f, i] [_a -> a_{_a}, 1]
# params operands [x, y] [(a_{1}, ..a_{_a}.., a_{1}), (a_{1})]
# params operands [x, y] [(a_{1}, ..a_{_a}.., a_{1}), (a_{1})]
# params operands [x, y] [(a_{1}), (a_{1}, ..a_{_a}.., a_{1})]
# params operands [x, y] [(a_{1}), (a_{1}, ..a_{_a}.., a_{1})]
# params operands [f, i] [_a -> b_{_a}, 1]
# params operands [x, y] [(b_{1}, ..b_{a}.., b_{1}), (b_{1})]
# params operands [x, y] [(b_{1}, ..b_{a}.., b_{1}), (b_{1})]
# params operands [x, y] [(b_{1}), (b_{1}, ..b_{a}.., b_{1})]
# params operands [x, y] [(b_{1}), (b_{1}, ..b_{a}.., b_{1})]
# params operands [f, i] [k -> (a_{k} = b_{k}), 1]
# params operands [x, y] [(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{1} = b_{1}), (a_{1} = b_{1})]
# params operands [x, y] [(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{1} = b_{1}), (a_{1} = b_{1})]
# params operands [x, y] [(a_{1} = b_{1}), (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{1} = b_{1})]
# params operands [x, y] [(a_{1} = b_{1}), (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{1} = b_{1})]
# params operands [A] [a_{1} = b_{1}]
# params operands [x] [a_{1}]
# params operands [x] [b_{1}]
# params operands [x] [a_{1} = b_{1}]
# params operands [x, y] [a_{1}, b_{1}]
# params operands [A] [a_{1} = b_{1}]
# params operands [x, y] [[and](a_{1} = b_{1}), a_{1} = b_{1}]
# params operands [x, y] [[and](a_{1} = b_{1}), a_{1} = b_{1}]
# params operands [x, y] [a_{1} = b_{1}, [and](a_{1} = b_{1})]
# params operands [x, y] [a_{1} = b_{1}, [and](a_{1} = b_{1})]
# params operands [x, y] [a_{1}, b_{1}]
# params operands [x, y] [a_{1}, b_{1}]
# params operands [x, y] [b_{1}, a_{1}]
# params operands [x, y] [b_{1}, a_{1}]
# params operands [f, i] [_a -> a_{_a}, 1]
# params operands [x, y] [(a_{1}, ..a_{_a}.., a_{1}), (a_{1})]
# params operands [x, y] [(a_{1}, ..a_{_a}.., a_{1}), (a_{1})]
# params operands [x, y] [(a_{1}), (a_{1}, ..a_{_a}.., a_{1})]
# params operands [x, y] [(a_{1}), (a_{1}, ..a_{_a}.., a_{1})]
# params operands [f, i] [_a -> b_{_a}, 1]
# params operands [x, y] [(b_{1}, ..b_{a}.., b_{1}), (b_{1})]
# params operands [x, y] [(b_{1}, ..b_{a}.., b_{1}), (b_{1})]
# params operands [x, y] [(b_{1}), (b_{1}, ..b_{a}.., b_{1})]
# params operands [x, y] [(b_{1}), (b_{1}, ..b_{a}.., b_{1})]
# params operands [A] [(a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m})]
# params operands [A] [(a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m})]
# params operands [x, y] [(a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m}), TRUE]
# params operands [x, y] [(a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m}), TRUE]
# params operands [x, y] [TRUE, (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m})]
# params operands [x, y] [TRUE, (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m})]
# params operands [A] [(a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m})]
# params operands [A] [(a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m})]
# params operands [P, x] [_a -> (_a in BOOLEAN), (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m})]
# params operands [P, x] [_a -> (_a in BOOLEAN), (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m})]
# params operands [x, y] [|()|, 0]
# params operands [x, y] [|()|, 0]
# params operands [x, y] [0, |()|]
# params operands [x, y] [0, |()|]
# params operands [x] [0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [m, n] [0, 0]
# params operands [m, n] [0, 0]
# instantiated_params [m, n, A_{1}, ..A_{_a}.., A_{0}]
# params operands [m, n, A_{1}, ..A_{_a}.., A_{0}, B] [0, 0, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [x, y] [|()|, |(1, ..a.., 0)|]
# params operands [x, y] [|()|, |(1, ..a.., 0)|]
# params operands [x, y] [|(1, ..a.., 0)|, |()|]
# params operands [x, y] [|(1, ..a.., 0)|, |()|]
# instantiated_params [m, n, A_{1}, ..A_{_a}.., A_{0}, B, C_{1}, ..C_{_a}.., C_{0}]
# params operands [m, n, A_{1}, ..A_{_a}.., A_{0}, B, C_{1}, ..C_{_a}.., C_{0}] [0, 0, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [A] [(a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [x] [(a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [A] [(a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [x] [[and]((a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}))]
# params operands [A] [(a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [A] [(a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [a] [(a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [x, y] [|((a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}))|, 1]
# params operands [x, y] [|((a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}))|, 1]
# params operands [x, y] [1, |((a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}))|]
# params operands [x, y] [1, |((a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}))|]
# params operands [x] [1]
# params operands [P, x, y] [_a -> (|((a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}))| = _a), 1, 1]
# params operands [P, x, y] [_a -> (|((a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}))| = _a), 1, 1]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m}), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m}), TRUE]
# params operands [A] [(m in NaturalPos) and [forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))]]
# params operands [A] [(m in NaturalPos) and [forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))]]
# params operands [x, y] [(m in NaturalPos) and [forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))], TRUE]
# params operands [x, y] [(m in NaturalPos) and [forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))], TRUE]
# params operands [x, y] [TRUE, (m in NaturalPos) and [forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))]]
# params operands [x, y] [TRUE, (m in NaturalPos) and [forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))]]
# params operands [A] [(m in NaturalPos) and [forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))]]
# params operands [A] [(m in NaturalPos) and [forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))]]
# params operands [P, x] [_a -> (_a in BOOLEAN), (m in NaturalPos) and [forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))]]
# params operands [P, x] [_a -> (_a in BOOLEAN), (m in NaturalPos) and [forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))]]
# params operands [A, B] [m in NaturalPos, forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))]
# params operands [A, B] [m in NaturalPos, forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))]
# params operands [A, B] [m in NaturalPos, forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))]
# params operands [A, B] [m in NaturalPos, forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), (m in NaturalPos) and [forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))], TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), (m in NaturalPos) and [forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))], TRUE]
# params operands [A, B] [m in NaturalPos, forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))]
# params operands [A, B] [m in NaturalPos, forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))]
# params operands [n, n] [m, m]
# params operands [n, n] [m, m]
# params operands [x, A, B] [m, NaturalPos, Natural]
# params operands [x, A, B, x] [m, NaturalPos, Natural, m]
# params operands [x, A, B, x] [m, NaturalPos, Natural, m]
# params operands [n, n] [m, m]
# params operands [n, n] [m, m]
# params operands [x, A, B] [m, Natural, Integer]
# params operands [n, n] [m, m]
# params operands [n, n] [m, m]
# params operands [x, x, y] [m, m, 0]
# params operands [x, x, y] [m, m, 0]
# params operands [y, x, y] [m, 0, m]
# params operands [y, x, y] [m, 0, m]
# params operands [y, x, y] [m, 0, m]
# params operands [y, x, y] [m, 0, m]
# params operands [A] [0 = m]
# params operands [A] [0 = m]
# params operands [x, y] [0 = m, FALSE]
# params operands [x, y] [0 = m, FALSE]
# params operands [x, y] [FALSE, 0 = m]
# params operands [x, y] [FALSE, 0 = m]
# params operands [A] [0 = m]
# params operands [A] [0 = m]
# params operands [A] [[not](0 = m)]
# params operands [A] [[not](0 = m)]
# params operands [x, y] [[not](0 = m), TRUE]
# params operands [x, y] [[not](0 = m), TRUE]
# params operands [x, y] [TRUE, [not](0 = m)]
# params operands [x, y] [TRUE, [not](0 = m)]
# params operands [A] [[not](0 = m)]
# params operands [A] [[not](0 = m)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](0 = m)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](0 = m)]
# params operands [A] [0 = m]
# params operands [A] [0 = m]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](0 = m), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](0 = m), TRUE]
# params operands [y, x, y] [m, 0, m]
# params operands [y, x, y] [m, 0, m]
# params operands [x, x, y] [m, m, 0]
# params operands [x, x, y] [m, m, 0]
# params operands [A] [m = 0]
# params operands [A] [m = 0]
# params operands [x, y] [m = 0, FALSE]
# params operands [x, y] [m = 0, FALSE]
# params operands [x, y] [FALSE, m = 0]
# params operands [x, y] [FALSE, m = 0]
# params operands [A] [m = 0]
# params operands [A] [m = 0]
# params operands [A] [[not](m = 0)]
# params operands [A] [[not](m = 0)]
# params operands [x, y] [[not](m = 0), TRUE]
# params operands [x, y] [[not](m = 0), TRUE]
# params operands [x, y] [TRUE, [not](m = 0)]
# params operands [x, y] [TRUE, [not](m = 0)]
# params operands [A] [[not](m = 0)]
# params operands [A] [[not](m = 0)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](m = 0)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](m = 0)]
# params operands [A] [m = 0]
# params operands [A] [m = 0]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](m = 0), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](m = 0), TRUE]
# params operands [x, x, y] [m, m, 0]
# params operands [x, x, y] [m, m, 0]
# params operands [A, B] [m in NaturalPos, forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))]
# params operands [A, B] [m in NaturalPos, forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))]
# params operands [A, B] [m in NaturalPos, forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))]
# params operands [A, B] [m in NaturalPos, forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))]
# params operands [n, n] [m, m]
# params operands [n, n] [m, m]
# params operands [x, A, B] [m, NaturalPos, Natural]
# params operands [x, A, B, x] [m, NaturalPos, Natural, m]
# params operands [x, A, B, x] [m, NaturalPos, Natural, m]
# params operands [n, n] [m, m]
# params operands [n, n] [m, m]
# params operands [x, A, B] [m, Natural, Integer]
# params operands [n, n] [m, m]
# params operands [n, n] [m, m]
# params operands [x, x, y] [m, m, 0]
# params operands [x, x, y] [m, m, 0]
# params operands [y, x, y] [m, 0, m]
# params operands [y, x, y] [m, 0, m]
# params operands [y, x, y] [m, 0, m]
# params operands [y, x, y] [m, 0, m]
# params operands [A] [0 = m]
# params operands [A] [0 = m]
# params operands [x, y] [0 = m, FALSE]
# params operands [x, y] [0 = m, FALSE]
# params operands [x, y] [FALSE, 0 = m]
# params operands [x, y] [FALSE, 0 = m]
# params operands [A] [0 = m]
# params operands [A] [0 = m]
# params operands [y, x, y] [m, 0, m]
# params operands [y, x, y] [m, 0, m]
# params operands [x, x, y] [m, m, 0]
# params operands [x, x, y] [m, m, 0]
# params operands [A] [m = 0]
# params operands [A] [m = 0]
# params operands [x, y] [m = 0, FALSE]
# params operands [x, y] [m = 0, FALSE]
# params operands [x, y] [FALSE, m = 0]
# params operands [x, y] [FALSE, m = 0]
# params operands [A] [m = 0]
# params operands [A] [m = 0]
# params operands [x, x, y] [m, m, 0]
# params operands [x, x, y] [m, m, 0]
# params operands [A, B] [m in NaturalPos, forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))]
# params operands [A, B] [m in NaturalPos, forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))]
# params operands [A] [(a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1})]
# params operands [A] [(a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1})]
# params operands [x, y] [(a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1}), TRUE]
# params operands [x, y] [(a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1}), TRUE]
# params operands [x, y] [TRUE, (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1})]
# params operands [x, y] [TRUE, (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1})]
# params operands [A] [(a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1})]
# params operands [A] [(a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1})]
# params operands [P, x] [_a -> (_a in BOOLEAN), (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1})]
# params operands [P, x] [_a -> (_a in BOOLEAN), (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1})]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [m, n] [0, 0]
# params operands [m, n] [0, 0]
# instantiated_params [m, n, A_{1}, ..A_{_a}.., A_{0}]
# params operands [m, n, A_{1}, ..A_{_a}.., A_{0}, B] [0, 0, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# instantiated_params [m, n, A_{1}, ..A_{_a}.., A_{0}, B, C_{1}, ..C_{_a}.., C_{0}]
# params operands [m, n, A_{1}, ..A_{_a}.., A_{0}, B, C_{1}, ..C_{_a}.., C_{0}] [0, 0, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [A] [(a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [x] [(a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [A] [(a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [x] [[and]((a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}))]
# params operands [A] [(a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [A] [(a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [a] [(a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [x, y] [|((a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}))|, 1]
# params operands [x, y] [|((a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}))|, 1]
# params operands [x, y] [1, |((a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}))|]
# params operands [x, y] [1, |((a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}))|]
# params operands [P, x, y] [_a -> (|((a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}))| = _a), 1, 1]
# params operands [P, x, y] [_a -> (|((a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}))| = _a), 1, 1]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1}), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1}), TRUE]
# params operands [n, n] [n, n]
# params operands [n, n] [n, n]
# params operands [x, A, B] [n, NaturalPos, Natural]
# params operands [x, A, B, x] [n, NaturalPos, Natural, n]
# params operands [x, A, B, x] [n, NaturalPos, Natural, n]
# params operands [n, n] [n, n]
# params operands [n, n] [n, n]
# params operands [x, A, B] [n, Natural, Integer]
# params operands [n, n] [n, n]
# params operands [n, n] [n, n]
# params operands [x, x, y] [n, n, 0]
# params operands [x, x, y] [n, n, 0]
# params operands [y, x, y] [n, 0, n]
# params operands [y, x, y] [n, 0, n]
# params operands [y, x, y] [n, 0, n]
# params operands [y, x, y] [n, 0, n]
# params operands [A] [0 = n]
# params operands [A] [0 = n]
# params operands [x, y] [0 = n, FALSE]
# params operands [x, y] [0 = n, FALSE]
# params operands [x, y] [FALSE, 0 = n]
# params operands [x, y] [FALSE, 0 = n]
# params operands [A] [0 = n]
# params operands [A] [0 = n]
# params operands [A] [[not](0 = n)]
# params operands [A] [[not](0 = n)]
# params operands [x, y] [[not](0 = n), TRUE]
# params operands [x, y] [[not](0 = n), TRUE]
# params operands [x, y] [TRUE, [not](0 = n)]
# params operands [x, y] [TRUE, [not](0 = n)]
# params operands [A] [[not](0 = n)]
# params operands [A] [[not](0 = n)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](0 = n)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](0 = n)]
# params operands [A] [0 = n]
# params operands [A] [0 = n]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](0 = n), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](0 = n), TRUE]
# params operands [y, x, y] [n, 0, n]
# params operands [y, x, y] [n, 0, n]
# params operands [x, x, y] [n, n, 0]
# params operands [x, x, y] [n, n, 0]
# params operands [A] [n = 0]
# params operands [A] [n = 0]
# params operands [x, y] [n = 0, FALSE]
# params operands [x, y] [n = 0, FALSE]
# params operands [x, y] [FALSE, n = 0]
# params operands [x, y] [FALSE, n = 0]
# params operands [A] [n = 0]
# params operands [A] [n = 0]
# params operands [A] [[not](n = 0)]
# params operands [A] [[not](n = 0)]
# params operands [x, y] [[not](n = 0), TRUE]
# params operands [x, y] [[not](n = 0), TRUE]
# params operands [x, y] [TRUE, [not](n = 0)]
# params operands [x, y] [TRUE, [not](n = 0)]
# params operands [A] [[not](n = 0)]
# params operands [A] [[not](n = 0)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](n = 0)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](n = 0)]
# params operands [A] [n = 0]
# params operands [A] [n = 0]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](n = 0), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](n = 0), TRUE]
# params operands [x, x, y] [n, n, 0]
# params operands [x, x, y] [n, n, 0]
# params operands [n, n] [n, n]
# params operands [n, n] [n, n]
# params operands [x, A, B] [n, NaturalPos, Natural]
# params operands [x, A, B, x] [n, NaturalPos, Natural, n]
# params operands [x, A, B, x] [n, NaturalPos, Natural, n]
# params operands [n, n] [n, n]
# params operands [n, n] [n, n]
# params operands [x, A, B] [n, Natural, Integer]
# params operands [n, n] [n, n]
# params operands [n, n] [n, n]
# params operands [x, x, y] [n, n, 0]
# params operands [x, x, y] [n, n, 0]
# params operands [y, x, y] [n, 0, n]
# params operands [y, x, y] [n, 0, n]
# params operands [y, x, y] [n, 0, n]
# params operands [y, x, y] [n, 0, n]
# params operands [A] [0 = n]
# params operands [A] [0 = n]
# params operands [x, y] [0 = n, FALSE]
# params operands [x, y] [0 = n, FALSE]
# params operands [x, y] [FALSE, 0 = n]
# params operands [x, y] [FALSE, 0 = n]
# params operands [A] [0 = n]
# params operands [A] [0 = n]
# params operands [y, x, y] [n, 0, n]
# params operands [y, x, y] [n, 0, n]
# params operands [x, x, y] [n, n, 0]
# params operands [x, x, y] [n, n, 0]
# params operands [A] [n = 0]
# params operands [A] [n = 0]
# params operands [x, y] [n = 0, FALSE]
# params operands [x, y] [n = 0, FALSE]
# params operands [x, y] [FALSE, n = 0]
# params operands [x, y] [FALSE, n = 0]
# params operands [A] [n = 0]
# params operands [A] [n = 0]
# params operands [x, x, y] [n, n, 0]
# params operands [x, x, y] [n, n, 0]
# params operands [A] [(a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{n} = b_{n})]
# params operands [A] [(a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{n} = b_{n})]
# params operands [x, y] [(a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{n} = b_{n}), TRUE]
# params operands [x, y] [(a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{n} = b_{n}), TRUE]
# params operands [x, y] [TRUE, (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{n} = b_{n})]
# params operands [x, y] [TRUE, (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{n} = b_{n})]
# params operands [A] [(a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{n} = b_{n})]
# params operands [A] [(a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{n} = b_{n})]
# params operands [P, x] [_a -> (_a in BOOLEAN), (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{n} = b_{n})]
# params operands [P, x] [_a -> (_a in BOOLEAN), (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{n} = b_{n})]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [m, n] [0, 0]
# params operands [m, n] [0, 0]
# instantiated_params [m, n, A_{1}, ..A_{_a}.., A_{0}]
# params operands [m, n, A_{1}, ..A_{_a}.., A_{0}, B] [0, 0, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n})]
# instantiated_params [m, n, A_{1}, ..A_{_a}.., A_{0}, B, C_{1}, ..C_{_a}.., C_{0}]
# params operands [m, n, A_{1}, ..A_{_a}.., A_{0}, B, C_{1}, ..C_{_a}.., C_{0}] [0, 0, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n})]
# params operands [A] [(a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n})]
# params operands [x] [(a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n})]
# params operands [A] [(a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n})]
# params operands [x] [[and]((a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}))]
# params operands [A] [(a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n})]
# params operands [A] [(a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n})]
# params operands [a] [(a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n})]
# params operands [x, y] [|((a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}))|, 1]
# params operands [x, y] [|((a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}))|, 1]
# params operands [x, y] [1, |((a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}))|]
# params operands [x, y] [1, |((a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}))|]
# params operands [P, x, y] [_a -> (|((a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}))| = _a), 1, 1]
# params operands [P, x, y] [_a -> (|((a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}))| = _a), 1, 1]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{n} = b_{n}), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{n} = b_{n}), TRUE]
# induction_inst: |- ([forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] \\  and [forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]) \\  => [forall_{n in NaturalPos} [forall_{a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}} ((a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n}))]]

# %% [markdown]
# ### First prove the base case of the induction.

# %%
induction_base = induction_inst.antecedent.operands[0]
# Out:
# induction_base: forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))

# %%
a1, b1 = induction_base.instance_params
# Out:
# a1: a_{1}
# b1: b_{1}

# %%
tuple_eq_def
# Out:
# |- forall_{i in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{i}, d} (((a_{1}, ..a_{_a}.., a_{i}, b) = (c_{1}, ..c_{_a}.., c_{i}, d)) =  \\ (((a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i})) and (b = d)))]

# %%
tuple_eq_base = tuple_eq_def.instantiate({i:zero})
# Out:
# params operands [i] [0]
# params operands [i] [0]
# params operands [x, y] [0 + 1, 1]
# params operands [x, y] [0 + 1, 1]
# params operands [x, y] [1, 0 + 1]
# params operands [x, y] [1, 0 + 1]
# params operands [f, x, y] [_a -> _a, 0 + 1, 1]
# params operands [f, x, y] [_a -> _a, 0 + 1, 1]
# params operands [f, i, j] [_a -> a_{_a}, 1, 0]
# params operands [f, i, j] [_a -> a_{_a}, 1, 0]
# params operands [x, y] [(a_{1}, ..a_{_a}.., a_{0}), ()]
# params operands [x, y] [(a_{1}, ..a_{_a}.., a_{0}), ()]
# params operands [x, y] [(), (a_{1}, ..a_{_a}.., a_{0})]
# params operands [x, y] [(), (a_{1}, ..a_{_a}.., a_{0})]
# params operands [f, i, j] [_a -> c_{_a}, 1, 0]
# params operands [f, i, j] [_a -> c_{_a}, 1, 0]
# params operands [x, y] [(c_{1}, ..c_{a}.., c_{0}), ()]
# params operands [x, y] [(c_{1}, ..c_{a}.., c_{0}), ()]
# params operands [x, y] [(), (c_{1}, ..c_{a}.., c_{0})]
# params operands [x, y] [(), (c_{1}, ..c_{a}.., c_{0})]
# params operands [f, i, j] [_a -> a_{_a}, 1, 0]
# params operands [f, i, j] [_a -> a_{_a}, 1, 0]
# params operands [f, i, j] [_a -> c_{_a}, 1, 0]
# params operands [f, i, j] [_a -> c_{_a}, 1, 0]
# params operands [f, i, j] [_a -> a_{_a}, 1, 0]
# params operands [f, i, j] [_a -> a_{_a}, 1, 0]
# params operands [f, i, j] [_a -> c_{_a}, 1, 0]
# params operands [f, i, j] [_a -> c_{_a}, 1, 0]
# tuple_eq_base: |- forall_{b, d} (((b) = (d)) =  \\ ((() = ()) and (b = d)))

# %%
tuple_eq_base_inst = tuple_eq_base.instantiate({b:a1, d:b1})
# Out:
# params operands [b, d] [a_{1}, b_{1}]
# params operands [x, y] [(a_{1}) = (b_{1}), (() = ()) and (a_{1} = b_{1})]
# params operands [x, y] [(a_{1}) = (b_{1}), (() = ()) and (a_{1} = b_{1})]
# params operands [x, y] [(() = ()) and (a_{1} = b_{1}), (a_{1}) = (b_{1})]
# params operands [x, y] [(() = ()) and (a_{1} = b_{1}), (a_{1}) = (b_{1})]
# tuple_eq_base_inst: |- ((a_{1}) = (b_{1})) = ((() = ()) and (a_{1} = b_{1}))

# %%
tuple_eq_base_inst.rhs.prove(assumptions=induction_base.conditions)
# Out:
# params operands [A] [TRUE and TRUE]
# params operands [A] [TRUE and TRUE]
# params operands [x, y] [TRUE and TRUE, TRUE]
# params operands [x, y] [TRUE and TRUE, TRUE]
# params operands [x, y] [TRUE, TRUE and TRUE]
# params operands [x, y] [TRUE, TRUE and TRUE]
# params operands [A] [TRUE and TRUE]
# params operands [A] [TRUE and TRUE]
# params operands [P, x] [_a -> (_a in BOOLEAN), TRUE and TRUE]
# params operands [P, x] [_a -> (_a in BOOLEAN), TRUE and TRUE]
# params operands [A, B] [TRUE, TRUE]
# params operands [A, B] [TRUE, TRUE]
# params operands [A, B] [TRUE, TRUE]
# params operands [A, B] [TRUE, TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), TRUE and TRUE, TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), TRUE and TRUE, TRUE]
# params operands [A, B] [TRUE, TRUE]
# params operands [A, B] [TRUE, TRUE]
# params operands [A, B] [TRUE, TRUE]
# params operands [A, B] [TRUE, TRUE]
# params operands [A, B] [() = (), a_{1} = b_{1}]
# params operands [x] [()]
# params operands [A, B] [() = (), a_{1} = b_{1}]
# params operands [A] [(() = ()) and (a_{1} = b_{1})]
# params operands [A] [(() = ()) and (a_{1} = b_{1})]
# params operands [x, y] [(() = ()) and (a_{1} = b_{1}), TRUE]
# params operands [x, y] [(() = ()) and (a_{1} = b_{1}), TRUE]
# params operands [x, y] [TRUE, (() = ()) and (a_{1} = b_{1})]
# params operands [x, y] [TRUE, (() = ()) and (a_{1} = b_{1})]
# params operands [A] [(() = ()) and (a_{1} = b_{1})]
# params operands [A] [(() = ()) and (a_{1} = b_{1})]
# params operands [P, x] [_a -> (_a in BOOLEAN), (() = ()) and (a_{1} = b_{1})]
# params operands [P, x] [_a -> (_a in BOOLEAN), (() = ()) and (a_{1} = b_{1})]
# params operands [A, B] [() = (), a_{1} = b_{1}]
# params operands [A, B] [() = (), a_{1} = b_{1}]
# params operands [A, B] [() = (), a_{1} = b_{1}]
# params operands [A, B] [() = (), a_{1} = b_{1}]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), (() = ()) and (a_{1} = b_{1}), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), (() = ()) and (a_{1} = b_{1}), TRUE]
# params operands [A, B] [() = (), a_{1} = b_{1}]
# params operands [A, B] [() = (), a_{1} = b_{1}]
# params operands [A, B] [() = (), a_{1} = b_{1}]
# params operands [A, B] [() = (), a_{1} = b_{1}]
# {a_{1} = b_{1}} |- (() = ()) and (a_{1} = b_{1})

# %%
tuple_eq_base_inst.derive_left_via_equality(assumptions=induction_base.conditions)
# Out:
# params operands [P, Q] [(a_{1}) = (b_{1}), (() = ()) and (a_{1} = b_{1})]
# params operands [P, Q] [(a_{1}) = (b_{1}), (() = ()) and (a_{1} = b_{1})]
# params operands [x, y] [(a_{1}), (b_{1})]
# params operands [x, y] [(a_{1}), (b_{1})]
# params operands [x, y] [(b_{1}), (a_{1})]
# params operands [x, y] [(b_{1}), (a_{1})]
# {a_{1} = b_{1}} |- (a_{1}) = (b_{1})

# %%
induction_base.prove()
# Out:
# |- forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))

# %% [markdown]
# ### Now prove the induction step assuming the induction hypothesis

# %%
induction_step = induction_inst.antecedent.operands[1]
# Out:
# induction_step: forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]

# %%
eq_conds = induction_step.instance_expr.explicit_conditions()[0]
# Out:
# eq_conds: (a_{1} = b_{1}), ..(a_{k} = b_{k}).., (a_{m + 1} = b_{m + 1})

# %%
defaults.assumptions = (induction_step.conditions + [eq_conds])
# Out:
# params operands [n, n] [m, m]
# params operands [n, n] [m, m]
# params operands [x, A, B] [m, NaturalPos, Natural]
# params operands [x, A, B, x] [m, NaturalPos, Natural, m]
# params operands [x, A, B, x] [m, NaturalPos, Natural, m]
# params operands [n, n] [m, m]
# params operands [n, n] [m, m]
# params operands [x, A, B] [m, Natural, Integer]
# params operands [n, n] [m, m]
# params operands [n, n] [m, m]
# params operands [x, x, y] [m, m, 0]
# params operands [x, x, y] [m, m, 0]
# params operands [y, x, y] [m, 0, m]
# params operands [y, x, y] [m, 0, m]
# params operands [y, x, y] [m, 0, m]
# params operands [y, x, y] [m, 0, m]
# params operands [A] [0 = m]
# params operands [A] [0 = m]
# params operands [x, y] [0 = m, FALSE]
# params operands [x, y] [0 = m, FALSE]
# params operands [x, y] [FALSE, 0 = m]
# params operands [x, y] [FALSE, 0 = m]
# params operands [A] [0 = m]
# params operands [A] [0 = m]
# params operands [A] [[not](0 = m)]
# params operands [A] [[not](0 = m)]
# params operands [x, y] [[not](0 = m), TRUE]
# params operands [x, y] [[not](0 = m), TRUE]
# params operands [x, y] [TRUE, [not](0 = m)]
# params operands [x, y] [TRUE, [not](0 = m)]
# params operands [A] [[not](0 = m)]
# params operands [A] [[not](0 = m)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](0 = m)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](0 = m)]
# params operands [A] [0 = m]
# params operands [A] [0 = m]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](0 = m), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](0 = m), TRUE]
# params operands [y, x, y] [m, 0, m]
# params operands [y, x, y] [m, 0, m]
# params operands [x, x, y] [m, m, 0]
# params operands [x, x, y] [m, m, 0]
# params operands [A] [m = 0]
# params operands [A] [m = 0]
# params operands [x, y] [m = 0, FALSE]
# params operands [x, y] [m = 0, FALSE]
# params operands [x, y] [FALSE, m = 0]
# params operands [x, y] [FALSE, m = 0]
# params operands [A] [m = 0]
# params operands [A] [m = 0]
# params operands [A] [[not](m = 0)]
# params operands [A] [[not](m = 0)]
# params operands [x, y] [[not](m = 0), TRUE]
# params operands [x, y] [[not](m = 0), TRUE]
# params operands [x, y] [TRUE, [not](m = 0)]
# params operands [x, y] [TRUE, [not](m = 0)]
# params operands [A] [[not](m = 0)]
# params operands [A] [[not](m = 0)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](m = 0)]
# params operands [P, x] [_a -> (_a in BOOLEAN), [not](m = 0)]
# params operands [A] [m = 0]
# params operands [A] [m = 0]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](m = 0), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [not](m = 0), TRUE]
# params operands [x, x, y] [m, m, 0]
# params operands [x, x, y] [m, m, 0]
# params operands [A] [(a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1})]
# params operands [A] [(a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1})]
# params operands [x, y] [(a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1}), TRUE]
# params operands [x, y] [(a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1}), TRUE]
# params operands [x, y] [TRUE, (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1})]
# params operands [x, y] [TRUE, (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1})]
# params operands [A] [(a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1})]
# params operands [A] [(a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1})]
# params operands [P, x] [_a -> (_a in BOOLEAN), (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1})]
# params operands [P, x] [_a -> (_a in BOOLEAN), (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1})]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [m, n] [0, 0]
# params operands [m, n] [0, 0]
# instantiated_params [m, n, A_{1}, ..A_{_a}.., A_{0}]
# params operands [m, n, A_{1}, ..A_{_a}.., A_{0}, B] [0, 0, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# instantiated_params [m, n, A_{1}, ..A_{_a}.., A_{0}, B, C_{1}, ..C_{_a}.., C_{0}]
# params operands [m, n, A_{1}, ..A_{_a}.., A_{0}, B, C_{1}, ..C_{_a}.., C_{0}] [0, 0, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [A] [(a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [A] [(a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [f, x, y] [_a -> _a, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [a] [(a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})]
# params operands [x, y] [|((a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}))|, 1]
# params operands [x, y] [|((a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}))|, 1]
# params operands [x, y] [1, |((a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}))|]
# params operands [x, y] [1, |((a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}))|]
# params operands [P, x, y] [_a -> (|((a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}))| = _a), 1, 1]
# params operands [P, x, y] [_a -> (|((a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}))| = _a), 1, 1]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1}), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1}), TRUE]
# defaults.assumptions: (m in NaturalPos, forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})), a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})

# %%
induction_hyp = induction_step.conditions[1]
# Out:
# induction_hyp: forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))

# %% [markdown]
# ***Splitting apart the conjunction of equality conditions is an important step***

# %%
eq_cond_partition = eq_conds.partition(m)
# Out:
# params operands [j, f, i, j] [m, k -> (a_{k} = b_{k}), 1, m]
# params operands [x] [|(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})|]
# params operands [i, i] [m, m]
# params operands [i, i, f] [m, m, _a -> (a_{_a} = b_{_a})]
# params operands [y, x, y] [m, |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})|, m]
# params operands [y, x, y] [m, |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})|, m]
# params operands [x, x, y] [m, m, |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})|]
# params operands [x, x, y] [m, m, |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})|]
# params operands [x, x] [m, m]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, P, x, y] [m, m, _b -> (|(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})| = _b), m, m]
# params operands [x, y, P, x, y] [m, m, _b -> (|(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})| = _b), m, m]
# params operands [z, x, y, z] [m, |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})|, |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})|, m]
# params operands [z, x, y, z] [m, |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})|, |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})|, m]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [y, z, x, y, z] [m, m, |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})|, m, m]
# params operands [y, z, x, y, z] [m, m, |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})|, m, m]
# params operands [y, P, x, y] [m, _a -> (_a in Natural), |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})|, m]
# params operands [y, P, x, y] [m, _a -> (_a in Natural), |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})|, m]
# params operands [n] [|(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})|]
# params operands [n] [|(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})|]
# params operands [A, B] [Natural, Integer]
# params operands [j, f, i, j] [m, k -> (a_{k} = b_{k}), 1, m]
# params operands [x, y] [(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}, a_{m + 1} = b_{m + 1})]
# params operands [x, y] [(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}, a_{m + 1} = b_{m + 1})]
# params operands [x, y] [(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}, a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m + 1} = b_{m + 1})]
# params operands [x, y] [(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}, a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m + 1} = b_{m + 1})]
# eq_cond_partition: {m in NaturalPos} |- (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m + 1} = b_{m + 1}) = (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}, a_{m + 1} = b_{m + 1})

# %%
eq_conds_conjunction = And(eq_conds).prove()
# Out:
# eq_conds_conjunction: {a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1})

# %%
eq_conds_conjunction_partition = eq_cond_partition.sub_right_side_into(eq_conds_conjunction)
# Out:
# params operands [i] [m + 1]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x] [m + 1]
# params operands [x, y, z] [m + 1, m + 1, m + 1]
# params operands [x, y, z] [m + 1, m + 1, m + 1]
# params operands [x, y, z] [m + 1, m + 1, m + 1]
# params operands [x, y, z] [m + 1, m + 1, m + 1]
# params operands [x, y, z] [m + 1, m + 1, m + 1]
# params operands [x, y, z] [m + 1, m + 1, m + 1]
# params operands [a, a, b] [m, m, 1]
# params operands [a, a, b] [m, m, 1]
# params operands [n] [m + 1]
# params operands [n] [m + 1]
# params operands [A, B] [Natural, Integer]
# params operands [i, f] [m + 1, _a -> (a_{_a} = b_{_a})]
# params operands [x, y] [|(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m + 1} = b_{m + 1})|, m + 1]
# params operands [x, y] [|(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m + 1} = b_{m + 1})|, m + 1]
# params operands [x, y] [m + 1, |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m + 1} = b_{m + 1})|]
# params operands [x, y] [m + 1, |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m + 1} = b_{m + 1})|]
# params operands [f, x, y] [_a -> _a, m + 1, m + 1]
# params operands [f, x, y] [_a -> _a, m + 1, m + 1]
# params operands [P, x, y] [_b -> (|(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m + 1} = b_{m + 1})| = _b), m + 1, m + 1]
# params operands [P, x, y] [_b -> (|(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m + 1} = b_{m + 1})| = _b), m + 1, m + 1]
# params operands [n] [m + 1]
# params operands [n, P] [m + 1, (_a_{1}, .._a_{_b}.., _a_{m + 1}) -> (_a_{1} and .._a_{_b}.. and _a_{m + 1})]
# instantiated_params [n, P, x_{1}, ..x_{_a}.., x_{m + 1}]
# params operands [n, P, x_{1}, ..x_{_a}.., x_{m + 1}] [m + 1, (_a_{1}, .._a_{_b}.., _a_{m + 1}) -> (_a_{1} and .._a_{_b}.. and _a_{m + 1}), (a_{1} = b_{1}), ..(a_{_a} = b_{_a}).., (a_{m + 1} = b_{m + 1})]
# params operands [i] [m + 1]
# params operands [i, f] [m + 1, _a -> (a_{_a} = b_{_a})]
# params operands [x, y] [|(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m + 1} = b_{m + 1})|, |(1, ..k.., m + 1)|]
# params operands [x, y] [|(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m + 1} = b_{m + 1})|, |(1, ..k.., m + 1)|]
# params operands [x, y] [|(1, ..k.., m + 1)|, |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m + 1} = b_{m + 1})|]
# params operands [x, y] [|(1, ..k.., m + 1)|, |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m + 1} = b_{m + 1})|]
# instantiated_params [n, P, x_{1}, ..x_{_a}.., x_{m + 1}, y_{1}, ..y_{_a}.., y_{m + 1}]
# params operands [n, P, x_{1}, ..x_{_a}.., x_{m + 1}, y_{1}, ..y_{_a}.., y_{m + 1}] [m + 1, (_a_{1}, .._a_{_b}.., _a_{m + 1}) -> (_a_{1} and .._a_{_b}.. and _a_{m + 1}), (a_{1} = b_{1}), ..(a_{_a} = b_{_a}).., (a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}), ..(a_{_a} = b_{_a}).., (a_{m} = b_{m}), a_{m + 1} = b_{m + 1}]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [i] [m + 1]
# params operands [i, f] [m + 1, _a -> _a]
# params operands [n, n] [m, m]
# params operands [n, n] [m, m]
# params operands [x, A, B] [m, NaturalPos, Natural]
# params operands [x, A, B, x] [m, NaturalPos, Natural, m]
# params operands [x, A, B, x] [m, NaturalPos, Natural, m]
# params operands [n, n] [m, m]
# params operands [n, n] [m, m]
# params operands [x, A, B] [m, Natural, Integer]
# params operands [n, n] [m, m]
# params operands [n, n] [m, m]
# params operands [x, x, y] [m, m, 0]
# params operands [x, x, y] [m, m, 0]
# params operands [y, x, y] [m, 0, m]
# params operands [y, x, y] [m, 0, m]
# params operands [y, x, y] [m, 0, m]
# params operands [y, x, y] [m, 0, m]
# params operands [A] [0 = m]
# params operands [A] [0 = m]
# params operands [x, y] [0 = m, FALSE]
# params operands [x, y] [0 = m, FALSE]
# params operands [x, y] [FALSE, 0 = m]
# params operands [x, y] [FALSE, 0 = m]
# params operands [A] [0 = m]
# params operands [A] [0 = m]
# params operands [y, x, y] [m, 0, m]
# params operands [y, x, y] [m, 0, m]
# params operands [x, x, y] [m, m, 0]
# params operands [x, x, y] [m, m, 0]
# params operands [A] [m = 0]
# params operands [A] [m = 0]
# params operands [x, y] [m = 0, FALSE]
# params operands [x, y] [m = 0, FALSE]
# params operands [x, y] [FALSE, m = 0]
# params operands [x, y] [FALSE, m = 0]
# params operands [A] [m = 0]
# params operands [A] [m = 0]
# params operands [x, x, y] [m, m, 0]
# params operands [x, x, y] [m, m, 0]
# params operands [x, y] [|(1, ..a.., m + 1)|, m + 1]
# params operands [x, y] [|(1, ..a.., m + 1)|, m + 1]
# params operands [x, y] [m + 1, |(1, ..a.., m + 1)|]
# params operands [x, y] [m + 1, |(1, ..a.., m + 1)|]
# params operands [f, x, y] [_a -> _a, m + 1, m + 1]
# params operands [f, x, y] [_a -> _a, m + 1, m + 1]
# params operands [P, x, y] [_a -> (|(1, ..a.., m + 1)| = _a), m + 1, m + 1]
# params operands [P, x, y] [_a -> (|(1, ..a.., m + 1)| = _a), m + 1, m + 1]
# params operands [i, f, b, i] [m, _a -> (a_{_a} = b_{_a}), a_{m + 1} = b_{m + 1}, m]
# params operands [i, f, b, i] [m, _a -> (a_{_a} = b_{_a}), a_{m + 1} = b_{m + 1}, m]
# params operands [x, y] [|(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}, a_{m + 1} = b_{m + 1})|, |(1, ..k.., m + 1)|]
# params operands [x, y] [|(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}, a_{m + 1} = b_{m + 1})|, |(1, ..k.., m + 1)|]
# params operands [x, y] [|(1, ..k.., m + 1)|, |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}, a_{m + 1} = b_{m + 1})|]
# params operands [x, y] [|(1, ..k.., m + 1)|, |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}, a_{m + 1} = b_{m + 1})|]
# params operands [n, P, x_{1}, ..x_{_a}.., x_{m + 1}, y_{1}, ..y_{_a}.., y_{m + 1}] [m + 1, (_a_{1}, .._a_{_b}.., _a_{m + 1}) -> (_a_{1} and .._a_{_b}.. and _a_{m + 1}), (a_{1} = b_{1}), ..(a_{_a} = b_{_a}).., (a_{m + 1} = b_{m + 1}), (a_{1} = b_{1}), ..(a_{_a} = b_{_a}).., (a_{m} = b_{m}), a_{m + 1} = b_{m + 1}]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [i] [m + 1]
# params operands [i, f] [m + 1, _a -> _a]
# params operands [f, x, y] [_a -> _a, m + 1, m + 1]
# params operands [f, x, y] [_a -> _a, m + 1, m + 1]
# params operands [P, x, y] [_a -> (|(1, ..a.., m + 1)| = _a), m + 1, m + 1]
# params operands [P, x, y] [_a -> (|(1, ..a.., m + 1)| = _a), m + 1, m + 1]
# params operands [A] [(a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m}) and (a_{m + 1} = b_{m + 1})]
# params operands [A] [(a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m}) and (a_{m + 1} = b_{m + 1})]
# params operands [x, y] [(a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m}) and (a_{m + 1} = b_{m + 1}), TRUE]
# params operands [x, y] [(a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m}) and (a_{m + 1} = b_{m + 1}), TRUE]
# params operands [x, y] [TRUE, (a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m}) and (a_{m + 1} = b_{m + 1})]
# params operands [x, y] [TRUE, (a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m}) and (a_{m + 1} = b_{m + 1})]
# params operands [A] [(a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m}) and (a_{m + 1} = b_{m + 1})]
# params operands [A] [(a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m}) and (a_{m + 1} = b_{m + 1})]
# params operands [P, x] [_a -> (_a in BOOLEAN), (a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m}) and (a_{m + 1} = b_{m + 1})]
# params operands [P, x] [_a -> (_a in BOOLEAN), (a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m}) and (a_{m + 1} = b_{m + 1})]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [a] [a_{m + 1} = b_{m + 1}]
# params operands [x, y] [|(a_{m + 1} = b_{m + 1})|, 1]
# params operands [x, y] [|(a_{m + 1} = b_{m + 1})|, 1]
# params operands [x, y] [1, |(a_{m + 1} = b_{m + 1})|]
# params operands [x, y] [1, |(a_{m + 1} = b_{m + 1})|]
# params operands [P, x, y] [_a -> (|(a_{m + 1} = b_{m + 1})| = _a), 1, 1]
# params operands [P, x, y] [_a -> (|(a_{m + 1} = b_{m + 1})| = _a), 1, 1]
# params operands [m, n] [0, 1]
# params operands [m, n] [0, 1]
# instantiated_params [m, n, A_{1}, ..A_{_a}.., A_{0}]
# params operands [m, n, A_{1}, ..A_{_a}.., A_{0}, B] [0, 1, (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})]
# instantiated_params [m, n, A_{1}, ..A_{_a}.., A_{0}, B, C_{1}, ..C_{_a}.., C_{1}]
# params operands [m, n, A_{1}, ..A_{_a}.., A_{0}, B, C_{1}, ..C_{_a}.., C_{1}] [0, 1, (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}), a_{m + 1} = b_{m + 1}]
# params operands [a] [a_{m + 1} = b_{m + 1}]
# params operands [x, y] [|(a_{m + 1} = b_{m + 1})|, |(1, ..k.., 1)|]
# params operands [x, y] [|(a_{m + 1} = b_{m + 1})|, |(1, ..k.., 1)|]
# params operands [x, y] [|(1, ..k.., 1)|, |(a_{m + 1} = b_{m + 1})|]
# params operands [x, y] [|(1, ..k.., 1)|, |(a_{m + 1} = b_{m + 1})|]
# params operands [f, x, y] [_b -> _b, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [f, x, y] [_b -> _b, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [f, x, y] [_a -> _a, m + 1, m + 1]
# params operands [f, x, y] [_a -> _a, m + 1, m + 1]
# params operands [x] [a_{m + 1}]
# params operands [f, x, y] [_a -> _a, m + 1, m + 1]
# params operands [f, x, y] [_a -> _a, m + 1, m + 1]
# params operands [x] [b_{m + 1}]
# params operands [x] [a_{m + 1} = b_{m + 1}]
# params operands [x] [(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}) and (a_{m + 1} = b_{m + 1})]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), (a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m}) and (a_{m + 1} = b_{m + 1}), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), (a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m}) and (a_{m + 1} = b_{m + 1}), TRUE]
# params operands [i, i] [m, m]
# params operands [i, i, f] [m, m, _a -> (a_{_a} = b_{_a})]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, P, x, y] [m, m, _b -> (|(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})| = _b), m, m]
# params operands [x, y, P, x, y] [m, m, _b -> (|(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})| = _b), m, m]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [m, m, n] [m, m, 0]
# params operands [m, m, n] [m, m, 0]
# instantiated_params [m, m, n, A_{1}, ..A_{_a}.., A_{m}]
# params operands [m, m, n, A_{1}, ..A_{_a}.., A_{m}, B] [m, m, 0, (a_{1} = b_{1}), ..(a_{_a} = b_{_a}).., (a_{m} = b_{m}), a_{m + 1} = b_{m + 1}]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [i, i] [m, m]
# params operands [i, i, f] [m, m, _a -> _a]
# params operands [y, x, y] [m, |(1, ..a.., m)|, m]
# params operands [y, x, y] [m, |(1, ..a.., m)|, m]
# params operands [x, x, y] [m, m, |(1, ..a.., m)|]
# params operands [x, x, y] [m, m, |(1, ..a.., m)|]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, P, x, y] [m, m, _a -> (|(1, ..a.., m)| = _a), m, m]
# params operands [x, y, P, x, y] [m, m, _a -> (|(1, ..a.., m)| = _a), m, m]
# params operands [i, i] [m, m]
# params operands [i, i, f] [m, m, _a -> (a_{_a} = b_{_a})]
# params operands [x, y] [|(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})|, |(1, ..k.., m)|]
# params operands [x, y] [|(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})|, |(1, ..k.., m)|]
# params operands [x, y] [|(1, ..k.., m)|, |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})|]
# params operands [x, y] [|(1, ..k.., m)|, |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})|]
# instantiated_params [m, m, n, A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{0}]
# params operands [m, m, n, A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{0}] [m, m, 0, (a_{1} = b_{1}), ..(a_{_a} = b_{_a}).., (a_{m} = b_{m}), a_{m + 1} = b_{m + 1}]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [i, i] [m, m]
# params operands [i, i, f] [m, m, _a -> _a]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, P, x, y] [m, m, _a -> (|(1, ..a.., m)| = _a), m, m]
# params operands [x, y, P, x, y] [m, m, _a -> (|(1, ..a.., m)| = _a), m, m]
# params operands [f, i, j] [_a -> C_{_a}, 1, 0]
# params operands [f, i, j] [_a -> C_{_a}, 1, 0]
# params operands [x, y] [(C_{1}, ..C_{a}.., C_{0}), ()]
# params operands [x, y] [(C_{1}, ..C_{a}.., C_{0}), ()]
# params operands [x, y] [(), (C_{1}, ..C_{a}.., C_{0})]
# params operands [x, y] [(), (C_{1}, ..C_{a}.., C_{0})]
# params operands [f, i, j] [_a -> C_{_a}, 1, 0]
# params operands [f, i, j] [_a -> C_{_a}, 1, 0]
# params operands [m, m, n, A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{0}] [m, m, 0, (a_{1} = b_{1}), ..(a_{_a} = b_{_a}).., (a_{m} = b_{m}), a_{m + 1} = b_{m + 1}]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [i, i] [m, m]
# params operands [i, i, f] [m, m, _a -> _a]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, P, x, y] [m, m, _a -> (|(1, ..a.., m)| = _a), m, m]
# params operands [x, y, P, x, y] [m, m, _a -> (|(1, ..a.., m)| = _a), m, m]
# params operands [x, y] [a_{m + 1}, b_{m + 1}]
# params operands [x, y] [a_{m + 1}, b_{m + 1}]
# params operands [x, y] [b_{m + 1}, a_{m + 1}]
# params operands [x, y] [b_{m + 1}, a_{m + 1}]
# eq_conds_conjunction_partition: {m in NaturalPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- (a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m}) and (a_{m + 1} = b_{m + 1})

# %%
eq_conds_conjunction_partition.derive_some(0)
# Out:
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [i, i] [m, m]
# params operands [i, i, f] [m, m, _a -> (a_{_a} = b_{_a})]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, P, x, y] [m, m, _b -> (|(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})| = _b), m, m]
# params operands [x, y, P, x, y] [m, m, _b -> (|(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})| = _b), m, m]
# params operands [a] [a_{m + 1} = b_{m + 1}]
# params operands [P, x, y] [_a -> (|(a_{m + 1} = b_{m + 1})| = _a), 1, 1]
# params operands [P, x, y] [_a -> (|(a_{m + 1} = b_{m + 1})| = _a), 1, 1]
# params operands [m, l, m, n] [m, 0, m, 1]
# params operands [m, l, m, n] [m, 0, m, 1]
# instantiated_params [m, l, m, n, A_{1}, ..A_{_a}.., A_{0}]
# params operands [m, l, m, n, A_{1}, ..A_{_a}.., A_{0}] [m, 0, m, 1]
# instantiated_params [m, l, m, n, A_{1}, ..A_{_a}.., A_{0}, B_{1}, ..B_{_a}.., B_{m}]
# params operands [m, l, m, n, A_{1}, ..A_{_a}.., A_{0}, B_{1}, ..B_{_a}.., B_{m}] [m, 0, m, 1, (a_{1} = b_{1}), ..(a_{_a} = b_{_a}).., (a_{m} = b_{m})]
# instantiated_params [m, l, m, n, A_{1}, ..A_{_a}.., A_{0}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{1}]
# params operands [m, l, m, n, A_{1}, ..A_{_a}.., A_{0}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{1}] [m, 0, m, 1, (a_{1} = b_{1}), ..(a_{_a} = b_{_a}).., (a_{m} = b_{m}), a_{m + 1} = b_{m + 1}]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [i, i] [m, m]
# params operands [i, i, f] [m, m, _a -> _a]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, P, x, y] [m, m, _a -> (|(1, ..a.., m)| = _a), m, m]
# params operands [x, y, P, x, y] [m, m, _a -> (|(1, ..a.., m)| = _a), m, m]
# params operands [f, i, j] [_a -> A_{_a}, 1, 0]
# params operands [f, i, j] [_a -> A_{_a}, 1, 0]
# params operands [x, y] [(A_{1}, ..A_{a}.., A_{0}), ()]
# params operands [x, y] [(A_{1}, ..A_{a}.., A_{0}), ()]
# params operands [x, y] [(), (A_{1}, ..A_{a}.., A_{0})]
# params operands [x, y] [(), (A_{1}, ..A_{a}.., A_{0})]
# params operands [f, i] [_a -> C_{_a}, 1]
# params operands [x, y] [(C_{1}, ..C_{a}.., C_{1}), (C_{1})]
# params operands [x, y] [(C_{1}, ..C_{a}.., C_{1}), (C_{1})]
# params operands [x, y] [(C_{1}), (C_{1}, ..C_{a}.., C_{1})]
# params operands [x, y] [(C_{1}), (C_{1}, ..C_{a}.., C_{1})]
# params operands [f, i] [_a -> C_{_a}, 1]
# params operands [f, i, j] [_a -> A_{_a}, 1, 0]
# params operands [f, i, j] [_a -> A_{_a}, 1, 0]
# params operands [m, l, m, n, A_{1}, ..A_{_a}.., A_{0}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{1}] [m, 0, m, 1, (a_{1} = b_{1}), ..(a_{_a} = b_{_a}).., (a_{m} = b_{m}), a_{m + 1} = b_{m + 1}]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [i, i] [m, m]
# params operands [i, i, f] [m, m, _a -> _a]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, P, x, y] [m, m, _a -> (|(1, ..a.., m)| = _a), m, m]
# params operands [x, y, P, x, y] [m, m, _a -> (|(1, ..a.., m)| = _a), m, m]
# params operands [A] [(a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m})]
# params operands [A] [(a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m})]
# params operands [x, y] [(a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m}), TRUE]
# params operands [x, y] [(a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m}), TRUE]
# params operands [x, y] [TRUE, (a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m})]
# params operands [x, y] [TRUE, (a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m})]
# params operands [A] [(a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m})]
# params operands [A] [(a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m})]
# params operands [P, x] [_a -> (_a in BOOLEAN), (a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m})]
# params operands [P, x] [_a -> (_a in BOOLEAN), (a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m})]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [m, n] [0, 0]
# params operands [m, n] [0, 0]
# instantiated_params [m, n, A_{1}, ..A_{_a}.., A_{0}]
# params operands [m, n, A_{1}, ..A_{_a}.., A_{0}, B] [0, 0, (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})]
# instantiated_params [m, n, A_{1}, ..A_{_a}.., A_{0}, B, C_{1}, ..C_{_a}.., C_{0}]
# params operands [m, n, A_{1}, ..A_{_a}.., A_{0}, B, C_{1}, ..C_{_a}.., C_{0}] [0, 0, (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})]
# params operands [A] [(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})]
# params operands [f, x, y] [_b -> _b, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [f, x, y] [_b -> _b, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [f, x, y] [_b -> _b, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [f, x, y] [_b -> _b, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [A] [(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})]
# params operands [f, x, y] [_b -> _b, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [f, x, y] [_b -> _b, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [f, x, y] [_b -> _b, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [f, x, y] [_b -> _b, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [f, x, y] [_b -> _b, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [f, x, y] [_b -> _b, (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}), (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})]
# params operands [a] [(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})]
# params operands [x, y] [|((a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}))|, 1]
# params operands [x, y] [|((a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}))|, 1]
# params operands [x, y] [1, |((a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}))|]
# params operands [x, y] [1, |((a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}))|]
# params operands [P, x, y] [_b -> (|((a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}))| = _b), 1, 1]
# params operands [P, x, y] [_b -> (|((a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}))| = _b), 1, 1]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), (a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m}), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), (a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m}), TRUE]
# {m in NaturalPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- (a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m})

# %% [markdown]
# ***Now we can instantiate the induction hypothesis***

# %%
induction_hyp.instantiate()
# Out:
# params operands [n, n] [m, m]
# params operands [n, n] [m, m]
# params operands [x, A, B] [m, NaturalPos, Natural]
# params operands [x, A, B, x] [m, NaturalPos, Natural, m]
# params operands [x, A, B, x] [m, NaturalPos, Natural, m]
# params operands [n, n] [m, m]
# params operands [n, n] [m, m]
# params operands [x, A, B] [m, Natural, Integer]
# params operands [n, n] [m, m]
# params operands [n, n] [m, m]
# params operands [x, x, y] [m, m, 0]
# params operands [x, x, y] [m, m, 0]
# params operands [y, x, y] [m, 0, m]
# params operands [y, x, y] [m, 0, m]
# params operands [y, x, y] [m, 0, m]
# params operands [y, x, y] [m, 0, m]
# params operands [A] [0 = m]
# params operands [A] [0 = m]
# params operands [x, y] [0 = m, FALSE]
# params operands [x, y] [0 = m, FALSE]
# params operands [x, y] [FALSE, 0 = m]
# params operands [x, y] [FALSE, 0 = m]
# params operands [A] [0 = m]
# params operands [A] [0 = m]
# params operands [y, x, y] [m, 0, m]
# params operands [y, x, y] [m, 0, m]
# params operands [x, x, y] [m, m, 0]
# params operands [x, x, y] [m, m, 0]
# params operands [A] [m = 0]
# params operands [A] [m = 0]
# params operands [x, y] [m = 0, FALSE]
# params operands [x, y] [m = 0, FALSE]
# params operands [x, y] [FALSE, m = 0]
# params operands [x, y] [FALSE, m = 0]
# params operands [A] [m = 0]
# params operands [A] [m = 0]
# params operands [x, x, y] [m, m, 0]
# params operands [x, x, y] [m, m, 0]
# params operands [b] [b]
# instantiated_params [a, b, a_{1}, ..a_{_a}.., a_{m}]
# params operands [a] [a]
# instantiated_params [a, b, a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m}]
# params operands [a, b] [a, b]
# params operands [a, b] [a, b]
# params operands [x, y] [(a_{1}, ..a_{_a}.., a_{m}), (b_{1}, ..b_{_a}.., b_{m})]
# params operands [x, y] [(a_{1}, ..a_{_a}.., a_{m}), (b_{1}, ..b_{_a}.., b_{m})]
# params operands [x, y] [(b_{1}, ..b_{_a}.., b_{m}), (a_{1}, ..a_{_a}.., a_{m})]
# params operands [x, y] [(b_{1}, ..b_{_a}.., b_{m}), (a_{1}, ..a_{_a}.., a_{m})]
# {forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})), m in NaturalPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- (a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})

# %% [markdown]
# ***And now we will be able to prove the induction step by invoking the `tuple_eq_def` axiom***

# %%
last_eq = eq_conds_conjunction_partition.derive_any(1)
# Out:
# params operands [i, i] [m, m]
# params operands [i, i, f] [m, m, _a -> (a_{_a} = b_{_a})]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, P, x, y] [m, m, _b -> (|(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})| = _b), m, m]
# params operands [x, y, P, x, y] [m, m, _b -> (|(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})| = _b), m, m]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [m, m, n] [m, m, 0]
# params operands [m, m, n] [m, m, 0]
# instantiated_params [m, m, n, A_{1}, ..A_{_a}.., A_{m}]
# params operands [m, m, n, A_{1}, ..A_{_a}.., A_{m}, B] [m, m, 0, (a_{1} = b_{1}), ..(a_{_a} = b_{_a}).., (a_{m} = b_{m}), a_{m + 1} = b_{m + 1}]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [i, i] [m, m]
# params operands [i, i, f] [m, m, _a -> _a]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, P, x, y] [m, m, _a -> (|(1, ..a.., m)| = _a), m, m]
# params operands [x, y, P, x, y] [m, m, _a -> (|(1, ..a.., m)| = _a), m, m]
# instantiated_params [m, m, n, A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{0}]
# params operands [m, m, n, A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{0}] [m, m, 0, (a_{1} = b_{1}), ..(a_{_a} = b_{_a}).., (a_{m} = b_{m}), a_{m + 1} = b_{m + 1}]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [i, i] [m, m]
# params operands [i, i, f] [m, m, _a -> _a]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, P, x, y] [m, m, _a -> (|(1, ..a.., m)| = _a), m, m]
# params operands [x, y, P, x, y] [m, m, _a -> (|(1, ..a.., m)| = _a), m, m]
# params operands [f, i, j] [_a -> C_{_a}, 1, 0]
# params operands [f, i, j] [_a -> C_{_a}, 1, 0]
# params operands [f, i, j] [_a -> C_{_a}, 1, 0]
# params operands [f, i, j] [_a -> C_{_a}, 1, 0]
# params operands [m, m, n, A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{0}] [m, m, 0, (a_{1} = b_{1}), ..(a_{_a} = b_{_a}).., (a_{m} = b_{m}), a_{m + 1} = b_{m + 1}]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [P, x, y] [_a -> (|()| = _a), 0, 0]
# params operands [i, i] [m, m]
# params operands [i, i, f] [m, m, _a -> _a]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, P, x, y] [m, m, _a -> (|(1, ..a.., m)| = _a), m, m]
# params operands [x, y, P, x, y] [m, m, _a -> (|(1, ..a.., m)| = _a), m, m]
# last_eq: {m in NaturalPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- a_{m + 1} = b_{m + 1}

# %%
a_mp1, b_mp1 = last_eq.operands
# Out:
# a_mp1: a_{m + 1}
# b_mp1: b_{m + 1}

# %%
tuple_eq_def
# Out:
# |- forall_{i in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{i}, d} (((a_{1}, ..a_{_a}.., a_{i}, b) = (c_{1}, ..c_{_a}.., c_{i}, d)) =  \\ (((a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i})) and (b = d)))]

# %%
tuple_eq_def_inst = tuple_eq_def.instantiate({i:m, c:b, b:a_mp1, d:b_mp1})
# Out:
# params operands [i, c, a, i] [m, b, a, m]
# params operands [i, c, i] [m, b, m]
# instantiated_params [i, c, a, i, a_{1}, ..a_{_a}.., a_{m}]
# params operands [i, a, i, b] [m, a, m, a_{m + 1}]
# instantiated_params [i, c, a, i, a_{1}, ..a_{_a}.., a_{m}, b, c_{1}, ..c_{_a}.., c_{m}]
# params operands [i, c, a, i, b, d] [m, b, a, m, a_{m + 1}, b_{m + 1}]
# params operands [x, y] [(a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1}), ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})) and (a_{m + 1} = b_{m + 1})]
# params operands [x, y] [(a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1}), ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})) and (a_{m + 1} = b_{m + 1})]
# params operands [x, y] [((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})) and (a_{m + 1} = b_{m + 1}), (a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1})]
# params operands [x, y] [((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})) and (a_{m + 1} = b_{m + 1}), (a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1})]
# tuple_eq_def_inst: {m in NaturalPos} |- ((a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1})) = (((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})) and (a_{m + 1} = b_{m + 1}))

# %%
tuple_eq_def_inst.rhs.prove()
# Out:
# params operands [A, B] [(a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}), a_{m + 1} = b_{m + 1}]
# params operands [A, B] [(a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}), a_{m + 1} = b_{m + 1}]
# params operands [A] [((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})) and (a_{m + 1} = b_{m + 1})]
# params operands [A] [((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})) and (a_{m + 1} = b_{m + 1})]
# params operands [x, y] [((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})) and (a_{m + 1} = b_{m + 1}), TRUE]
# params operands [x, y] [((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})) and (a_{m + 1} = b_{m + 1}), TRUE]
# params operands [x, y] [TRUE, ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})) and (a_{m + 1} = b_{m + 1})]
# params operands [x, y] [TRUE, ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})) and (a_{m + 1} = b_{m + 1})]
# params operands [A] [((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})) and (a_{m + 1} = b_{m + 1})]
# params operands [A] [((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})) and (a_{m + 1} = b_{m + 1})]
# params operands [P, x] [_a -> (_a in BOOLEAN), ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})) and (a_{m + 1} = b_{m + 1})]
# params operands [P, x] [_a -> (_a in BOOLEAN), ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})) and (a_{m + 1} = b_{m + 1})]
# params operands [A, B] [(a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}), a_{m + 1} = b_{m + 1}]
# params operands [A, B] [(a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}), a_{m + 1} = b_{m + 1}]
# params operands [A, B] [(a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}), a_{m + 1} = b_{m + 1}]
# params operands [A, B] [(a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}), a_{m + 1} = b_{m + 1}]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})) and (a_{m + 1} = b_{m + 1}), TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})) and (a_{m + 1} = b_{m + 1}), TRUE]
# params operands [A, B] [(a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}), a_{m + 1} = b_{m + 1}]
# params operands [A, B] [(a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}), a_{m + 1} = b_{m + 1}]
# params operands [A, B] [(a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}), a_{m + 1} = b_{m + 1}]
# params operands [A, B] [(a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}), a_{m + 1} = b_{m + 1}]
# {forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})), m in NaturalPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})) and (a_{m + 1} = b_{m + 1})

# %%
tuple_eq_split_both = tuple_eq_def_inst.derive_left_via_equality()
# Out:
# params operands [P, Q] [(a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1}), ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})) and (a_{m + 1} = b_{m + 1})]
# params operands [P, Q] [(a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1}), ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})) and (a_{m + 1} = b_{m + 1})]
# params operands [x, y] [(a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}), (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1})]
# params operands [x, y] [(a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}), (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1})]
# params operands [x, y] [(b_{1}, ..b_{_a}.., b_{m}, b_{m + 1}), (a_{1}, ..a_{_a}.., a_{m}, a_{m + 1})]
# params operands [x, y] [(b_{1}, ..b_{_a}.., b_{m}, b_{m + 1}), (a_{1}, ..a_{_a}.., a_{m}, a_{m + 1})]
# tuple_eq_split_both: {forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})), m in NaturalPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- (a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1})

# %%
tuple_eq_split_right = tuple_eq_split_both.inner_expr().lhs.merge()
# Out:
# params operands [x] [(a_{1}, ..a_{_a}.., a_{m}, a_{m + 1})]
# params operands [j, f, i, j] [m, _a -> a_{_a}, 1, m]
# params operands [x] [|(a_{1}, ..a_{_a}.., a_{m})|]
# params operands [i, i] [m, m]
# params operands [i, i, f] [m, m, _a -> a_{_a}]
# params operands [y, x, y] [m, |(a_{1}, ..a_{_a}.., a_{m})|, m]
# params operands [y, x, y] [m, |(a_{1}, ..a_{_a}.., a_{m})|, m]
# params operands [x, x, y] [m, m, |(a_{1}, ..a_{_a}.., a_{m})|]
# params operands [x, x, y] [m, m, |(a_{1}, ..a_{_a}.., a_{m})|]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, P, x, y] [m, m, _b -> (|(a_{1}, ..a_{_a}.., a_{m})| = _b), m, m]
# params operands [x, y, P, x, y] [m, m, _b -> (|(a_{1}, ..a_{_a}.., a_{m})| = _b), m, m]
# params operands [z, x, y, z] [m, |(a_{1}, ..a_{_a}.., a_{m})|, |(a_{1}, ..a_{_a}.., a_{m})|, m]
# params operands [z, x, y, z] [m, |(a_{1}, ..a_{_a}.., a_{m})|, |(a_{1}, ..a_{_a}.., a_{m})|, m]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [y, z, x, y, z] [m, m, |(a_{1}, ..a_{_a}.., a_{m})|, m, m]
# params operands [y, z, x, y, z] [m, m, |(a_{1}, ..a_{_a}.., a_{m})|, m, m]
# params operands [y, P, x, y] [m, _a -> (_a in Natural), |(a_{1}, ..a_{_a}.., a_{m})|, m]
# params operands [y, P, x, y] [m, _a -> (_a in Natural), |(a_{1}, ..a_{_a}.., a_{m})|, m]
# params operands [n] [|(a_{1}, ..a_{_a}.., a_{m})|]
# params operands [n] [|(a_{1}, ..a_{_a}.., a_{m})|]
# params operands [A, B] [Natural, Integer]
# params operands [j, f, i, j] [m, _a -> a_{_a}, 1, m]
# params operands [x, y] [(a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}), (a_{1}, ..a_{_a}.., a_{m + 1})]
# params operands [x, y] [(a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}), (a_{1}, ..a_{_a}.., a_{m + 1})]
# params operands [x, y] [(a_{1}, ..a_{_a}.., a_{m + 1}), (a_{1}, ..a_{_a}.., a_{m}, a_{m + 1})]
# params operands [x, y] [(a_{1}, ..a_{_a}.., a_{m + 1}), (a_{1}, ..a_{_a}.., a_{m}, a_{m + 1})]
# params operands [x, y, z] [(a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}), (a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}), (a_{1}, ..a_{_a}.., a_{m + 1})]
# params operands [x, y, z] [(a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}), (a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}), (a_{1}, ..a_{_a}.., a_{m + 1})]
# params operands [P, x, y] [_b -> (_b = (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1})), (a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}), (a_{1}, ..a_{_a}.., a_{m + 1})]
# params operands [P, x, y] [_b -> (_b = (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1})), (a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}), (a_{1}, ..a_{_a}.., a_{m + 1})]
# params operands [x, y] [(a_{1}, ..a_{_a}.., a_{m + 1}), (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1})]
# params operands [x, y] [(a_{1}, ..a_{_a}.., a_{m + 1}), (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1})]
# params operands [x, y] [(b_{1}, ..b_{_a}.., b_{m}, b_{m + 1}), (a_{1}, ..a_{_a}.., a_{m + 1})]
# params operands [x, y] [(b_{1}, ..b_{_a}.., b_{m}, b_{m + 1}), (a_{1}, ..a_{_a}.., a_{m + 1})]
# tuple_eq_split_right: {forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})), m in NaturalPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- (a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1})

# %%
tuple_eq = tuple_eq_split_right.inner_expr().rhs.merge()
# Out:
# params operands [x] [(b_{1}, ..b_{_a}.., b_{m}, b_{m + 1})]
# params operands [j, f, i, j] [m, _a -> b_{_a}, 1, m]
# params operands [x] [|(b_{1}, ..b_{a}.., b_{m})|]
# params operands [i, i] [m, m]
# params operands [i, i, f] [m, m, a -> b_{a}]
# params operands [y, x, y] [m, |(b_{1}, ..b_{a}.., b_{m})|, m]
# params operands [y, x, y] [m, |(b_{1}, ..b_{a}.., b_{m})|, m]
# params operands [x, x, y] [m, m, |(b_{1}, ..b_{a}.., b_{m})|]
# params operands [x, x, y] [m, m, |(b_{1}, ..b_{a}.., b_{m})|]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, P, x, y] [m, m, _a -> (|(b_{1}, ..b_{a}.., b_{m})| = _a), m, m]
# params operands [x, y, P, x, y] [m, m, _a -> (|(b_{1}, ..b_{a}.., b_{m})| = _a), m, m]
# params operands [z, x, y, z] [m, |(b_{1}, ..b_{a}.., b_{m})|, |(b_{1}, ..b_{a}.., b_{m})|, m]
# params operands [z, x, y, z] [m, |(b_{1}, ..b_{a}.., b_{m})|, |(b_{1}, ..b_{a}.., b_{m})|, m]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [x, y, f, x, y] [m, m, _a -> _a, m, m]
# params operands [y, z, x, y, z] [m, m, |(b_{1}, ..b_{a}.., b_{m})|, m, m]
# params operands [y, z, x, y, z] [m, m, |(b_{1}, ..b_{a}.., b_{m})|, m, m]
# params operands [y, P, x, y] [m, _a -> (_a in Natural), |(b_{1}, ..b_{a}.., b_{m})|, m]
# params operands [y, P, x, y] [m, _a -> (_a in Natural), |(b_{1}, ..b_{a}.., b_{m})|, m]
# params operands [n] [|(b_{1}, ..b_{a}.., b_{m})|]
# params operands [n] [|(b_{1}, ..b_{a}.., b_{m})|]
# params operands [A, B] [Natural, Integer]
# params operands [j, f, i, j] [m, _a -> b_{_a}, 1, m]
# params operands [x, y] [(b_{1}, ..b_{a}.., b_{m}, b_{m + 1}), (b_{1}, ..b_{a}.., b_{m + 1})]
# params operands [x, y] [(b_{1}, ..b_{a}.., b_{m}, b_{m + 1}), (b_{1}, ..b_{a}.., b_{m + 1})]
# params operands [x, y] [(b_{1}, ..b_{a}.., b_{m + 1}), (b_{1}, ..b_{a}.., b_{m}, b_{m + 1})]
# params operands [x, y] [(b_{1}, ..b_{a}.., b_{m + 1}), (b_{1}, ..b_{a}.., b_{m}, b_{m + 1})]
# params operands [x, y, z] [(b_{1}, ..b_{_a}.., b_{m}, b_{m + 1}), (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1}), (b_{1}, ..b_{a}.., b_{m + 1})]
# params operands [x, y, z] [(b_{1}, ..b_{_a}.., b_{m}, b_{m + 1}), (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1}), (b_{1}, ..b_{a}.., b_{m + 1})]
# params operands [P, x, y] [_b -> ((a_{1}, ..a_{_a}.., a_{m + 1}) = _b), (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1}), (b_{1}, ..b_{a}.., b_{m + 1})]
# params operands [P, x, y] [_b -> ((a_{1}, ..a_{_a}.., a_{m + 1}) = _b), (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1}), (b_{1}, ..b_{a}.., b_{m + 1})]
# params operands [x, y] [(a_{1}, ..a_{_a}.., a_{m + 1}), (b_{1}, ..b_{a}.., b_{m + 1})]
# params operands [x, y] [(a_{1}, ..a_{_a}.., a_{m + 1}), (b_{1}, ..b_{a}.., b_{m + 1})]
# params operands [x, y] [(b_{1}, ..b_{a}.., b_{m + 1}), (a_{1}, ..a_{_a}.., a_{m + 1})]
# params operands [x, y] [(b_{1}, ..b_{a}.., b_{m + 1}), (a_{1}, ..a_{_a}.., a_{m + 1})]
# tuple_eq: {forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})), m in NaturalPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- (a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{a}.., b_{m + 1})

# %%
induction_step.prove()
# Out:
# |- forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{a}.., b_{m + 1}))]

# %% [markdown]
# ### With the base case and the induction step proven, the induction proof is easily finished.

# %%
induction_inst.derive_consequent()
# Out:
# params operands [A, B] [forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1})), forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]
# params operands [A, B] [forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1})), forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]
# params operands [A] [[forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] and [forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]]
# params operands [A] [[forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] and [forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]]
# params operands [x, y] [[forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] and [forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]], TRUE]
# params operands [x, y] [[forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] and [forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]], TRUE]
# params operands [x, y] [TRUE, [forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] and [forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]]
# params operands [x, y] [TRUE, [forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] and [forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]]
# params operands [A] [[forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] and [forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]]
# params operands [A] [[forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] and [forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]]
# params operands [P, x] [_a -> (_a in BOOLEAN), [forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] and [forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]]
# params operands [P, x] [_a -> (_a in BOOLEAN), [forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] and [forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]]
# params operands [A, B] [forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1})), forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]
# params operands [A, B] [forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1})), forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]
# params operands [A, B] [forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1})), forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]
# params operands [A, B] [forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1})), forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] and [forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]], TRUE]
# params operands [P, x, y] [_a -> (_a in BOOLEAN), [forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] and [forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]], TRUE]
# params operands [A, B] [forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1})), forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]
# params operands [A, B] [forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1})), forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]
# params operands [A, B] [forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1})), forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]
# params operands [A, B] [forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1})), forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]
# tuple_eq_via_elem_eq has been proven.  Now simply execute "%qed".
# |- forall_{n in NaturalPos} [forall_{a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}} ((a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n}))]

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{n in NaturalPos} [forall_{a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}} ((a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n}))]
# 1	instantiation	3, 4, 5, 6, 7*	|- ([forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] \\  and [forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]) \\  => [forall_{n in NaturalPos} [forall_{a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}} ((a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n}))]]
# 	P(i) : forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{i} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{i} = b_{i}} ((a_{1}, ..a_{_a}.., a_{i}) = (b_{1}, ..b_{_a}.., b_{i}))
# 2	instantiation	38, 8, 9	|- [forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] \\  and [forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]
# 	A : forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1})), B : forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]
# 3	conjecture		|- forall_{P} ((P(1) and [forall_{m in NaturalPos | P(m)} P(m + 1)]) => [forall_{n in NaturalPos} P(n)])
# 4	instantiation	10	|- (a_{1}, ..a_{_a}.., a_{1}) = (a_{1})
# 	f(_a) : a_{_a}, i : 1
# 5	instantiation	10	|- (b_{1}, ..b_{a}.., b_{1}) = (b_{1})
# 	f(_a) : b_{_a}, i : 1
# 6	instantiation	10	|- (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{1} = b_{1}) = (a_{1} = b_{1})
# 	f(k) : a_{k} = b_{k}, i : 1
# 7	instantiation	11, 12	|- [and](a_{1} = b_{1}) = (a_{1} = b_{1})
# 	A : a_{1} = b_{1}
# 8	generalizaton	13	|- forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))
# 9	generalizaton	14	|- forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{a}.., b_{m + 1}))]
# 10	conjecture		|- forall_{f, i} ((f(i), ..f(a).., f(i)) = (f(i)))
# 11	conjecture		|- forall_{A in BOOLEAN} ([and](A) = A)
# 12	instantiation	15	|- (a_{1} = b_{1}) in BOOLEAN
# 	x : a_{1}, y : b_{1}
# 13	instantiation	30, 16, 17	{a_{1} = b_{1}} |- (a_{1}) = (b_{1})
# 	P : (a_{1}) = (b_{1}), Q : (() = ()) and (a_{1} = b_{1})
# 14	instantiation	23, 18, 19	{forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})), m in NaturalPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- (a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{a}.., b_{m + 1})
# 	P(_b) : (a_{1}, ..a_{_a}.., a_{m + 1}) = _b, x : (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1}), y : (b_{1}, ..b_{a}.., b_{m + 1})
# 15	axiom		|- forall_{x, y} ((x = y) in BOOLEAN)
# 	proveit.logic.equality.equality_in_bool
# 16	instantiation	38, 20, 21	{a_{1} = b_{1}} |- (() = ()) and (a_{1} = b_{1})
# 	A : () = (), B : a_{1} = b_{1}
# 17	instantiation	22	|- ((a_{1}) = (b_{1})) = ((() = ()) and (a_{1} = b_{1}))
# 	b : a_{1}, d : b_{1}
# 18	instantiation	23, 24, 25	{forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})), m in NaturalPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- (a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1})
# 	P(_b) : _b = (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1}), x : (a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}), y : (a_{1}, ..a_{_a}.., a_{m + 1})
# 19	instantiation	33, 26	{m in NaturalPos} |- (b_{1}, ..b_{a}.., b_{m}, b_{m + 1}) = (b_{1}, ..b_{a}.., b_{m + 1})
# 	f(_a) : b_{_a}, i : 1, j : m
# 20	instantiation	27	|- () = ()
# 	x : ()
# 21	assumption		{a_{1} = b_{1}} |- a_{1} = b_{1}
# 22	instantiation	41, 47, 28, 29	|- forall_{b, d} (((b) = (d)) =  \\ ((() = ()) and (b = d)))
# 	i : 0
# 23	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 24	instantiation	30, 31, 32	{forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})), m in NaturalPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- (a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1})
# 	P : (a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1}), Q : ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})) and (a_{m + 1} = b_{m + 1})
# 25	instantiation	33, 34	{m in NaturalPos} |- (a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}) = (a_{1}, ..a_{_a}.., a_{m + 1})
# 	f(_a) : a_{_a}, i : 1, j : m
# 26	instantiation	65, 68, 35	{m in NaturalPos} |- |(b_{1}, ..b_{a}.., b_{m})| in Natural
# 	P(_a) : _a in Natural, x : |(b_{1}, ..b_{a}.., b_{m})|, y : m
# 27	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equals_reflexivity
# 28	instantiation	36, 37	|- (a_{1}, ..a_{_a}.., a_{0}) = ()
# 	f(_a) : a_{_a}, i : 1, j : 0
# 29	instantiation	36, 37	|- (c_{1}, ..c_{a}.., c_{0}) = ()
# 	f(_a) : c_{_a}, i : 1, j : 0
# 30	theorem		|- forall_{P, Q | Q, P = Q} P
# 	proveit.logic.equality.lhs_via_equality
# 31	instantiation	38, 39, 40	{forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})), m in NaturalPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})) and (a_{m + 1} = b_{m + 1})
# 	A : (a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}), B : a_{m + 1} = b_{m + 1}
# 32	instantiation	41, 68	{m in NaturalPos} |- ((a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1})) = (((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})) and (a_{m + 1} = b_{m + 1}))
# 	i : m, a : a, b : a_{m + 1}, c : b, d : b_{m + 1}
# 33	conjecture		|- forall_{f, i, j | |(f(i), ..f(a).., f(j))| in Natural} ((f(i), ..f(a).., f(j), f(j + 1)) = (f(i), ..f(a).., f(j + 1)))
# 34	instantiation	65, 68, 42	{m in NaturalPos} |- |(a_{1}, ..a_{_a}.., a_{m})| in Natural
# 	P(_a) : _a in Natural, x : |(a_{1}, ..a_{_a}.., a_{m})|, y : m
# 35	instantiation	67, 68	{m in NaturalPos} |- |(b_{1}, ..b_{a}.., b_{m})| = m
# 	i : m, f(a) : b_{a}
# 36	axiom		|- forall_{f, i, j | (j + 1) = i} ((f(i), ..f(a).., f(j)) = ())
# 	proveit.core_expr_types.tuples.empty_range_def
# 37	conjecture		|- (0 + 1) = 1
# 38	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 39	instantiation	43, 44	{forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})), m in NaturalPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- (a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})
# 	a : a, b : b
# 40	instantiation	45, 68, 47, 49, 48, 51	{m in NaturalPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- a_{m + 1} = b_{m + 1}
# 	m : m, n : 0, A : (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}), B : a_{m + 1} = b_{m + 1}, C : ()
# 41	axiom		|- forall_{i in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{i}, d} (((a_{1}, ..a_{_a}.., a_{i}, b) = (c_{1}, ..c_{_a}.., c_{i}, d)) =  \\ (((a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i})) and (b = d)))]
# 	proveit.core_expr_types.tuples.tuple_eq_def
# 42	instantiation	67, 68	{m in NaturalPos} |- |(a_{1}, ..a_{_a}.., a_{m})| = m
# 	i : m, f(_a) : a_{_a}
# 43	assumption		{forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} |- forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))
# 44	instantiation	46, 47, 68, 64, 48, 49, 50, 51	{m in NaturalPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- (a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m})
# 	l : 0, m : m, n : 1, A : (), B : (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}), C : (a_{m + 1} = b_{m + 1})
# 45	conjecture		|- forall_{m, n in Natural} [forall_{A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n} | A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n}} B]
# 46	conjecture		|- forall_{l, m, n in Natural} [forall_{A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n} | A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n}} (B_{1} and ..B_{_a}.. and B_{m})]
# 47	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 48	conjecture		|- |()| = |(1, ..a.., 0)|
# 49	instantiation	58, 68	{m in NaturalPos} |- |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})| = |(1, ..k.., m)|
# 	i : m, f(_a) : a_{_a} = b_{_a}
# 50	instantiation	52	|- |(a_{m + 1} = b_{m + 1})| = |(1, ..k.., 1)|
# 	a : a_{m + 1} = b_{m + 1}
# 51	instantiation	53, 59, 54, 55, 56, 57	{m in NaturalPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- (a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m}) and (a_{m + 1} = b_{m + 1})
# 	n : m + 1, P(_a_{1}, .._a_{_b}.., _a_{m + 1}) : _a_{1} and .._a_{_b}.. and _a_{m + 1}, x : (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m + 1} = b_{m + 1}), y : (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}, a_{m + 1} = b_{m + 1})
# 52	conjecture		|- forall_{a} (|(a)| = |(1, ..k.., 1)|)
# 53	theorem		|- forall_{n in Natural} [forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(x_{1}, ..x_{_a}.., x_{n}), (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})]
# 	proveit.logic.equality.sub_in_right_operands
# 54	instantiation	58, 59	{m in NaturalPos} |- |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m + 1} = b_{m + 1})| = |(1, ..k.., m + 1)|
# 	i : m + 1, f(_a) : a_{_a} = b_{_a}
# 55	instantiation	60, 68	{m in NaturalPos} |- |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}, a_{m + 1} = b_{m + 1})| = |(1, ..k.., m + 1)|
# 	f(_a) : a_{_a} = b_{_a}, b : a_{m + 1} = b_{m + 1}, i : m
# 56	assumption		{a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1})
# 57	instantiation	61, 62	{m in NaturalPos} |- (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m + 1} = b_{m + 1}) = (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}, a_{m + 1} = b_{m + 1})
# 	f(k) : a_{k} = b_{k}, i : 1, j : m
# 58	conjecture		|- forall_{i in Natural} [forall_{f} (|(f(1), ..f(a).., f(i))| = |(1, ..k.., i)|)]
# 59	instantiation	63, 68, 64	{m in NaturalPos} |- (m + 1) in Natural
# 	a : m, b : 1
# 60	conjecture		|- forall_{f, b} [forall_{i in Natural} (|(f(1), ..f(a).., f(i), b)| = |(1, ..k.., i + 1)|)]
# 61	axiom		|- forall_{f, i, j | |(f(i), ..f(a).., f(j))| in Natural} ((f(i), ..f(a).., f(j + 1)) =  \\ (f(i), ..f(a).., f(j), f(j + 1)))
# 	proveit.core_expr_types.tuples.range_extension_def
# 62	instantiation	65, 68, 66	{m in NaturalPos} |- |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})| in Natural
# 	P(_a) : _a in Natural, x : |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})|, y : m
# 63	conjecture		|- forall_{a, b in Natural} ((a + b) in Natural)
# 64	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 65	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 66	instantiation	67, 68	{m in NaturalPos} |- |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})| = m
# 	i : m, f(_a) : a_{_a} = b_{_a}
# 67	conjecture		|- forall_{i in Natural} [forall_{f} (|(f(1), ..f(a).., f(i))| = i)]
# 68	instantiation	69, 70, 71	{m in NaturalPos} |- m in Natural
# 	A : NaturalPos, B : Natural, x : m
# 69	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 70	conjecture		|- NaturalPos proper_subset Natural
# 71	assumption		{m in NaturalPos} |- m in NaturalPos
