# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#Am">Am</a> of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.Function.html">Function</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit import Am

# %%
# check that the built expression is the same as the stored expression
assert Am == stored_expr
assert Am._style_id == stored_expr._style_id
print("Passed sanity check: Am matches stored_expr")
# Out:
# Passed sanity check: Am matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(Am.latex())
# Out:
# A(m)

# %%
Am.style_options()
# Out:
# no style options

# %%
# display the expression information
Am.expr_info()
# Out:
# 0. A(m)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. A
#    core type: Variable
#    sub-expressions:
# 2. (m)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. m
#    core type: Variable
#    sub-expressions:
