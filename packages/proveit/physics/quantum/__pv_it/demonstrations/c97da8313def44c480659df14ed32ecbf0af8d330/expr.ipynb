# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprTuple
from proveit.logic import Set
from proveit.numbers import one
from proveit.physics.quantum import SPACE, X, Z
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one)
sub_expr2 = MultiQubitGate(Z, sub_expr1)
sub_expr3 = MultiQubitGate(SPACE, sub_expr1)
expr = ExprTuple(ExprArray([sub_expr2, sub_expr3, MultiQubitGate(X, sub_expr1), sub_expr3, sub_expr2]))
# Out:
# expr: ((MultiQubitGate(Z, {1}) & MultiQubitGate(SPACE, {1}) & MultiQubitGate(X, {1}) & MultiQubitGate(SPACE, {1}) & MultiQubitGate(Z, {1})))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\begin{array} {ccccc}
#  \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{Z{\Big \{} \left\{1\right\}}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & SPACE
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{X{\Big \{} \left\{1\right\}}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & SPACE
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{Z{\Big \{} \left\{1\right\}}
# } \hspace{2em} \end{array}
# \right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((MultiQubitGate(Z, {1}) & MultiQubitGate(SPACE, {1}) & MultiQubitGate(X, {1}) & MultiQubitGate(SPACE, {1}) & MultiQubitGate(Z, {1})))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. MultiQubitGate(Z, {1}) & MultiQubitGate(SPACE, {1}) & MultiQubitGate(X, {1}) & MultiQubitGate(SPACE, {1}) & MultiQubitGate(Z, {1})
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (MultiQubitGate(Z, {1}), MultiQubitGate(SPACE, {1}), MultiQubitGate(X, {1}), MultiQubitGate(SPACE, {1}), MultiQubitGate(Z, {1}))
#    core type: ExprTuple
#    sub-expressions: 5, 4, 3, 4, 5
# 3. MultiQubitGate(X, {1})
#    core type: Operation
#    operator: 8
#    operands: 6
# 4. MultiQubitGate(SPACE, {1})
#    core type: Operation
#    operator: 8
#    operands: 7
# 5. MultiQubitGate(Z, {1})
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. (X, {1})
#    core type: ExprTuple
#    sub-expressions: 10, 13
# 7. (SPACE, {1})
#    core type: ExprTuple
#    sub-expressions: 11, 13
# ...
