# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.physics.quantum.circuit.Circuit.html">Circuit</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray
from proveit.logic import Set
from proveit.numbers import four, one, three, two, zero
from proveit.physics.quantum import CLASSICAL_CONTROL, Input, Output, SPACE, X, ket0, ket1
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Input(zero)
sub_expr2 = Set(one, two)
sub_expr3 = Set(three, four)
expr = Circuit(ExprArray([sub_expr1, MultiQubitGate(CLASSICAL_CONTROL, sub_expr2), SPACE], [Input(ket0), MultiQubitGate(X, sub_expr2).with_styles(representation='implicit'), Output(ket0)], [sub_expr1, MultiQubitGate(CLASSICAL_CONTROL, sub_expr3), SPACE], [Input(ket1), MultiQubitGate(X, sub_expr3), Output(ket1)]))
# Out:
# expr:  Input(0)  & MultiQubitGate(CLASSICAL\_CONTROL, {1, 2})  & SPACE   \\
#    Input(|0〉)  & MultiQubitGate(X, {1, 2})  & Output(|0〉)   \\
#    Input(0)  & MultiQubitGate(CLASSICAL\_CONTROL, {3, 4})  & SPACE   \\
#    Input(|1〉)  & MultiQubitGate(X, {3, 4})  & Output(|1〉)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{0} & \control \cw \cwx[1]   \\
#   & \lstick{\lvert 0 \rangle} & \targ & \rstick{\lvert 0 \rangle} \qw   \\
#   & \lstick{0} & \control \cw \cwx[1]   \\
#   & \lstick{\lvert 1 \rangle} & \gate{X} & \rstick{\lvert 1 \rangle} \qw
# } \hspace{2em}

# %%
expr.style_options()
# Out:
# style name: spacing
# description: change the spacing of a circuit using the format '@C=1em @R=.7em' where C is the column spacing and R is the row spacing
# default: @C=1em @R=.7em
# current value: @C=1em @R=.7em
# related methods: ()
# style name: orientation
# description: to be read from left to right then top to bottom ('horizontal') or to be read top to bottom then left to right ('vertical')
# default: horizontal
# current value: horizontal
# related methods: with_orientation

# %%
# display the expression information
expr.expr_info()
# Out:
# 0.  Input(0)  & MultiQubitGate(CLASSICAL\_CONTROL, {1, 2})  & SPACE   \\
#    Input(|0〉)  & MultiQubitGate(X, {1, 2})  & Output(|0〉)   \\
#    Input(0)  & MultiQubitGate(CLASSICAL\_CONTROL, {3, 4})  & SPACE   \\
#    Input(|1〉)  & MultiQubitGate(X, {3, 4})  & Output(|1〉)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. CIRCUIT
#    core type: Literal
#    sub-expressions:
# 2. ((Input(0) & MultiQubitGate(CLASSICAL\_CONTROL, {1, 2}) & SPACE  \\
#   Input(|0〉) & MultiQubitGate(X, {1, 2}) & Output(|0〉)  \\
#   Input(0) & MultiQubitGate(CLASSICAL\_CONTROL, {3, 4}) & SPACE  \\
#   Input(|1〉) & MultiQubitGate(X, {3, 4}) & Output(|1〉)))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. Input(0) & MultiQubitGate(CLASSICAL\_CONTROL, {1, 2}) & SPACE  \\
#   Input(|0〉) & MultiQubitGate(X, {1, 2}) & Output(|0〉)  \\
#   Input(0) & MultiQubitGate(CLASSICAL\_CONTROL, {3, 4}) & SPACE  \\
#   Input(|1〉) & MultiQubitGate(X, {3, 4}) & Output(|1〉)
#    core type: ExprTuple
# ...
