# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.physics.quantum import Gate, I, Input, Output, ket0

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Input(ket0), Gate(I), Output(ket0))
# Out:
# expr: (Input(|0〉), Gate(I), Output(|0〉))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{I}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Input(|0〉), Gate(I), Output(|0〉))
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. Input(|0〉)
#    core type: Operation
#    operator: 4
#    operand: 10
# 2. Gate(I)
#    core type: Operation
#    operator: 5
#    operand: 9
# 3. Output(|0〉)
#    core type: Operation
#    operator: 7
#    operand: 10
# 4. INPUT
#    core type: Literal
#    sub-expressions:
# 5. GATE
#    core type: Literal
#    sub-expressions:
# 6. (--)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. OUTPUT
#    core type: Literal
#    sub-expressions:
# 8. (|0〉)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. --
#    core type: Literal
#    sub-expressions:
# 10. |0〉
#     core type: Operation
#     operator: 11
#     operand: 13
# 11. KET
#     core type: Literal
#     sub-expressions:
# 12. (0)
#     core type: ExprTuple
#     sub-expressions: 13
# 13. 0
#     core type: Literal
#     sub-expressions:
