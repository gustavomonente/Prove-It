# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.logic import Set
from proveit.numbers import five, six
from proveit.physics.quantum import Gate, H, Input, Output, Z, ket0, ket1
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Gate(H)
expr = ExprTuple(Input(ket0), sub_expr1, MultiQubitGate(Z, Set(five, six)), sub_expr1, Output(ket1))
# Out:
# expr: (Input(|0〉), Gate(H), MultiQubitGate(Z, {5, 6}), Gate(H), Output(|1〉))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{H}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & Z
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{H}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 1 \rangle} \qw
# } \hspace{2em}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Input(|0〉), Gate(H), MultiQubitGate(Z, {5, 6}), Gate(H), Output(|1〉))
#    core type: ExprTuple
#    sub-expressions: 1, 3, 2, 3, 4
# 1. Input(|0〉)
#    core type: Operation
#    operator: 5
#    operand: 13
# 2. MultiQubitGate(Z, {5, 6})
#    core type: Operation
#    operator: 7
#    operands: 8
# 3. Gate(H)
#    core type: Operation
#    operator: 9
#    operand: 16
# 4. Output(|1〉)
#    core type: Operation
#    operator: 11
#    operand: 17
# 5. INPUT
#    core type: Literal
#    sub-expressions:
# 6. (|0〉)
#    core type: ExprTuple
#    sub-expressions: 13
# 7. MULTI_QUBIT_GATE
#    core type: Literal
#    sub-expressions:
# 8. (Z, {5, 6})
#    core type: ExprTuple
#    sub-expressions: 14, 15
# 9. GATE
#    core type: Literal
#    sub-expressions:
# 10. (H)
#     core type: ExprTuple
#     sub-expressions: 16
# 11. OUTPUT
#     core type: Literal
#     sub-expressions:
# 12. (|1〉)
#     core type: ExprTuple
#     sub-expressions: 17
# 13. |0〉
#     core type: Operation
#     operator: 21
#     operand: 23
# 14. Z
#     core type: Literal
#     sub-expressions:
# 15. {5, 6}
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. H
#     core type: Literal
#     sub-expressions:
# 17. |1〉
#     core type: Operation
#     operator: 21
#     operand: 26
# 18. (0)
#     core type: ExprTuple
#     sub-expressions: 23
# 19. Set
#     core type: Literal
#     sub-expressions:
# 20. (5, 6)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 21. KET
#     core type: Literal
#     sub-expressions:
# 22. (1)
#     core type: ExprTuple
#     sub-expressions: 26
# 23. 0
#     core type: Literal
#     sub-expressions:
# 24. 5
#     core type: Literal
#     sub-expressions:
# 25. 6
#     core type: Literal
#     sub-expressions:
# 26. 1
#     core type: Literal
#     sub-expressions:
