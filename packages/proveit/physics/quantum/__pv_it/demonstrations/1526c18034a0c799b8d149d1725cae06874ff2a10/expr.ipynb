# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprRange, ExprTuple, h, i, j, m
from proveit.core_expr_types.expr_arrays import Bij, Qij
from proveit.numbers import one
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
expr = ExprTuple(ExprArray(ExprRange(i, [ExprRange(j, MultiQubitGate(Bij, Qij), one, h)], one, m)))
# Out:
# expr: ((MultiQubitGate(B_{1, 1}, Q_{1, 1}) & ..MultiQubitGate(B_{1, j}, Q_{1, j}).. & MultiQubitGate(B_{1, h}, Q_{1, h})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(B_{i, 1}, Q_{i, 1}) & ..MultiQubitGate(B_{i, j}, Q_{i, j}).. & MultiQubitGate(B_{i, h}, Q_{i, h})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(B_{m, 1}, Q_{m, 1}) & ..MultiQubitGate(B_{m, j}, Q_{m, j}).. & MultiQubitGate(B_{m, h}, Q_{m, h})))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\begin{array} {ccc}
#  \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{1, 1}{\Big \{} Q_{1, 1}}
# } \hspace{2em} & \cdots & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{1, h}{\Big \{} Q_{1, h}}
# } \hspace{2em}  \\
#   \vdots & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{i, j}{\Big \{} Q_{i, j}}
# } \hspace{2em} & \vdots  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{m, 1}{\Big \{} Q_{m, 1}}
# } \hspace{2em} & \cdots & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{m, h}{\Big \{} Q_{m, h}}
# } \hspace{2em} \end{array}
# \right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((MultiQubitGate(B_{1, 1}, Q_{1, 1}) & ..MultiQubitGate(B_{1, j}, Q_{1, j}).. & MultiQubitGate(B_{1, h}, Q_{1, h})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(B_{i, 1}, Q_{i, 1}) & ..MultiQubitGate(B_{i, j}, Q_{i, j}).. & MultiQubitGate(B_{i, h}, Q_{i, h})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(B_{m, 1}, Q_{m, 1}) & ..MultiQubitGate(B_{m, j}, Q_{m, j}).. & MultiQubitGate(B_{m, h}, Q_{m, h})))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. MultiQubitGate(B_{1, 1}, Q_{1, 1}) & ..MultiQubitGate(B_{1, j}, Q_{1, j}).. & MultiQubitGate(B_{1, h}, Q_{1, h})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(B_{i, 1}, Q_{i, 1}) & ..MultiQubitGate(B_{i, j}, Q_{i, j}).. & MultiQubitGate(B_{i, h}, Q_{i, h})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(B_{m, 1}, Q_{m, 1}) & ..MultiQubitGate(B_{m, j}, Q_{m, j}).. & MultiQubitGate(B_{m, h}, Q_{m, h})
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (MultiQubitGate(B_{1, 1}, Q_{1, 1}), ..MultiQubitGate(B_{1, j}, Q_{1, j}).., MultiQubitGate(B_{1, h}, Q_{1, h})), ..(MultiQubitGate(B_{i, 1}, Q_{i, 1}), ..MultiQubitGate(B_{i, j}, Q_{i, j}).., MultiQubitGate(B_{i, h}, Q_{i, h})).., (MultiQubitGate(B_{m, 1}, Q_{m, 1}), ..MultiQubitGate(B_{m, j}, Q_{m, j}).., MultiQubitGate(B_{m, h}, Q_{m, h}))
#    core type: ExprRange
#    lambda_map: 3
#    start_index: 8
#    end_index: 4
# 3. i -> (MultiQubitGate(B_{i, 1}, Q_{i, 1}), ..MultiQubitGate(B_{i, j}, Q_{i, j}).., MultiQubitGate(B_{i, h}, Q_{i, h}))
#    core type: Lambda
#    parameter: 18
#    body: 5
# 4. m
#    core type: Variable
#    sub-expressions:
# 5. (MultiQubitGate(B_{i, 1}, Q_{i, 1}), ..MultiQubitGate(B_{i, j}, Q_{i, j}).., MultiQubitGate(B_{i, h}, Q_{i, h}))
#    core type: ExprTuple
#    sub-expressions: 6
# 6. MultiQubitGate(B_{i, 1}, Q_{i, 1}), ..MultiQubitGate(B_{i, j}, Q_{i, j}).., MultiQubitGate(B_{i, h}, Q_{i, h})
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 8
#    end_index: 9
# 7. j -> MultiQubitGate(B_{i, j}, Q_{i, j})
#    core type: Lambda
#    parameter: 19
#    body: 10
# 8. 1
#    core type: Literal
#    sub-expressions:
# 9. h
#    core type: Variable
#    sub-expressions:
# 10. MultiQubitGate(B_{i, j}, Q_{i, j})
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 12. (B_{i, j}, Q_{i, j})
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. B_{i, j}
#     core type: IndexedVar
# variable: 15
# indices: 17
# 14. Q_{i, j}
#     core type: IndexedVar
# variable: 16
# indices: 17
# 15. B
#     core type: Variable
#     sub-expressions:
# 16. Q
#     core type: Variable
#     sub-expressions:
# 17. (i, j)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. i
#     core type: Variable
#     sub-expressions:
# 19. j
#     core type: Variable
#     sub-expressions:
