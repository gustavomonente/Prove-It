# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprTuple
from proveit.logic import Set
from proveit.numbers import four, one, three, two
from proveit.physics.quantum import CONTROL, Input, Output, X, ket0, ket1
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = Set(three, four)
sub_expr3 = Input(ket0)
sub_expr4 = Output(ket0)
expr = ExprTuple(ExprArray([sub_expr3, MultiQubitGate(CONTROL, sub_expr1), sub_expr4], [sub_expr3, MultiQubitGate(X, sub_expr1).with_styles(representation='implicit'), sub_expr4], [sub_expr3, MultiQubitGate(CONTROL, sub_expr2), sub_expr4], [Input(ket1), MultiQubitGate(X, sub_expr2), Output(ket1)]))
# Out:
# expr: ((Input(|0〉) & MultiQubitGate(CONTROL, {1, 2}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(X, {1, 2}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(CONTROL, {3, 4}) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(X, {3, 4}) & Output(|1〉)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\begin{array} {ccc}
#  \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \targ
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 1 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & X
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# ...

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((Input(|0〉) & MultiQubitGate(CONTROL, {1, 2}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(X, {1, 2}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(CONTROL, {3, 4}) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(X, {3, 4}) & Output(|1〉)))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. Input(|0〉) & MultiQubitGate(CONTROL, {1, 2}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(X, {1, 2}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(CONTROL, {3, 4}) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(X, {3, 4}) & Output(|1〉)
#    core type: ExprTuple
#    sub-expressions: 2, 3, 4, 5
# 2. (Input(|0〉), MultiQubitGate(CONTROL, {1, 2}), Output(|0〉))
#    core type: ExprTuple
#    sub-expressions: 8, 6, 10
# 3. (Input(|0〉), MultiQubitGate(X, {1, 2}), Output(|0〉))
#    core type: ExprTuple
#    sub-expressions: 8, 7, 10
# 4. (Input(|0〉), MultiQubitGate(CONTROL, {3, 4}), Output(|0〉))
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# ...
