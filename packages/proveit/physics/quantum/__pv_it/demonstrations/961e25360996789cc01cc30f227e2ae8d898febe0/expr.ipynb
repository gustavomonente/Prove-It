# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprTuple
from proveit.logic import Set
from proveit.numbers import eight, five, four, one, seven, six, three, two
from proveit.physics.quantum import CONTROL, Gate, H, I, Input, Output, X, ket0, ket1
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Gate(I)
sub_expr2 = Set(one, two)
sub_expr3 = Gate(H)
sub_expr4 = Set(three, four)
sub_expr5 = Set(five, six)
sub_expr6 = Set(seven, eight)
sub_expr7 = Input(ket0)
sub_expr8 = Output(ket0)
sub_expr9 = Output(ket1)
sub_expr10 = Input(ket1)
expr = ExprTuple(ExprArray([sub_expr7, sub_expr1, MultiQubitGate(X, sub_expr2).with_styles(representation='implicit'), sub_expr1, sub_expr8], [sub_expr7, sub_expr3, MultiQubitGate(CONTROL, sub_expr2), sub_expr3, sub_expr8], [sub_expr7, sub_expr1, MultiQubitGate(X, sub_expr4), sub_expr1, sub_expr9], [sub_expr10, sub_expr3, MultiQubitGate(CONTROL, sub_expr4), sub_expr3, sub_expr9], [sub_expr10, sub_expr1, MultiQubitGate(X, sub_expr5), sub_expr1, sub_expr9], [sub_expr7, sub_expr3, MultiQubitGate(CONTROL, sub_expr5), sub_expr3, sub_expr8], [sub_expr10, sub_expr1, MultiQubitGate(X, sub_expr6), sub_expr1, sub_expr8], [sub_expr10, sub_expr3, MultiQubitGate(CONTROL, sub_expr6), sub_expr3, sub_expr9]))
# Out:
# expr: ((Input(|0〉) & Gate(I) & MultiQubitGate(X, {1, 2}) & Gate(I) & Output(|0〉)  \\
#   Input(|0〉) & Gate(H) & MultiQubitGate(CONTROL, {1, 2}) & Gate(H) & Output(|0〉)  \\
#   Input(|0〉) & Gate(I) & MultiQubitGate(X, {3, 4}) & Gate(I) & Output(|1〉)  \\
#   Input(|1〉) & Gate(H) & MultiQubitGate(CONTROL, {3, 4}) & Gate(H) & Output(|1〉)  \\
#   Input(|1〉) & Gate(I) & MultiQubitGate(X, {5, 6}) & Gate(I) & Output(|1〉)  \\
#   Input(|0〉) & Gate(H) & MultiQubitGate(CONTROL, {5, 6}) & Gate(H) & Output(|0〉)  \\
#   Input(|1〉) & Gate(I) & MultiQubitGate(X, {7, 8}) & Gate(I) & Output(|0〉)  \\
#   Input(|1〉) & Gate(H) & MultiQubitGate(CONTROL, {7, 8}) & Gate(H) & Output(|1〉)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\begin{array} {ccccc}
#  \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{I}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \targ
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{I}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{H}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{H}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{I}
# ...

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((Input(|0〉) & Gate(I) & MultiQubitGate(X, {1, 2}) & Gate(I) & Output(|0〉)  \\
#   Input(|0〉) & Gate(H) & MultiQubitGate(CONTROL, {1, 2}) & Gate(H) & Output(|0〉)  \\
#   Input(|0〉) & Gate(I) & MultiQubitGate(X, {3, 4}) & Gate(I) & Output(|1〉)  \\
#   Input(|1〉) & Gate(H) & MultiQubitGate(CONTROL, {3, 4}) & Gate(H) & Output(|1〉)  \\
#   Input(|1〉) & Gate(I) & MultiQubitGate(X, {5, 6}) & Gate(I) & Output(|1〉)  \\
#   Input(|0〉) & Gate(H) & MultiQubitGate(CONTROL, {5, 6}) & Gate(H) & Output(|0〉)  \\
#   Input(|1〉) & Gate(I) & MultiQubitGate(X, {7, 8}) & Gate(I) & Output(|0〉)  \\
#   Input(|1〉) & Gate(H) & MultiQubitGate(CONTROL, {7, 8}) & Gate(H) & Output(|1〉)))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. Input(|0〉) & Gate(I) & MultiQubitGate(X, {1, 2}) & Gate(I) & Output(|0〉)  \\
#   Input(|0〉) & Gate(H) & MultiQubitGate(CONTROL, {1, 2}) & Gate(H) & Output(|0〉)  \\
#   Input(|0〉) & Gate(I) & MultiQubitGate(X, {3, 4}) & Gate(I) & Output(|1〉)  \\
# ...
