# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.logic import Set
from proveit.numbers import four, three
from proveit.physics.quantum import CONTROL, Gate, H, Input, Output, ket1
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Gate(H)
expr = ExprTuple(Input(ket1), sub_expr1, MultiQubitGate(CONTROL, Set(three, four)), sub_expr1, Output(ket1))
# Out:
# expr: (Input(|1〉), Gate(H), MultiQubitGate(CONTROL, {3, 4}), Gate(H), Output(|1〉))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 1 \rangle}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{H}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{H}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 1 \rangle} \qw
# } \hspace{2em}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Input(|1〉), Gate(H), MultiQubitGate(CONTROL, {3, 4}), Gate(H), Output(|1〉))
#    core type: ExprTuple
#    sub-expressions: 1, 3, 2, 3, 4
# 1. Input(|1〉)
#    core type: Operation
#    operator: 5
#    operand: 15
# 2. MultiQubitGate(CONTROL, {3, 4})
#    core type: Operation
#    operator: 6
#    operands: 7
# 3. Gate(H)
#    core type: Operation
#    operator: 8
#    operand: 14
# 4. Output(|1〉)
#    core type: Operation
#    operator: 10
#    operand: 15
# 5. INPUT
#    core type: Literal
#    sub-expressions:
# 6. MULTI_QUBIT_GATE
#    core type: Literal
#    sub-expressions:
# 7. (CONTROL, {3, 4})
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 8. GATE
#    core type: Literal
#    sub-expressions:
# 9. (H)
#    core type: ExprTuple
#    sub-expressions: 14
# 10. OUTPUT
#     core type: Literal
#     sub-expressions:
# 11. (|1〉)
#     core type: ExprTuple
#     sub-expressions: 15
# 12. CONTROL
#     core type: Literal
#     sub-expressions:
# 13. {3, 4}
# ...
