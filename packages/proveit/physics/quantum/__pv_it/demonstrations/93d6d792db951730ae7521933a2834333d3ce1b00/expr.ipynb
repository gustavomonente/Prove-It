# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprTuple
from proveit.logic import Set
from proveit.numbers import eight, five, four, one, seven, six, three, two
from proveit.physics.quantum import CONTROL, Input, Output, Z, ket0, ket1
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = Set(three, four)
sub_expr3 = Set(five, six)
sub_expr4 = Set(seven, eight)
sub_expr5 = Input(ket0)
sub_expr6 = MultiQubitGate(CONTROL, sub_expr1)
sub_expr7 = Output(ket0)
sub_expr8 = MultiQubitGate(Z, sub_expr1)
sub_expr9 = MultiQubitGate(CONTROL, sub_expr2)
sub_expr10 = Input(ket1)
sub_expr11 = MultiQubitGate(Z, sub_expr2)
sub_expr12 = Output(ket1)
sub_expr13 = MultiQubitGate(CONTROL, sub_expr3)
sub_expr14 = MultiQubitGate(Z, sub_expr3)
sub_expr15 = MultiQubitGate(CONTROL, sub_expr4)
sub_expr16 = MultiQubitGate(Z, sub_expr4)
expr = ExprTuple(ExprArray([sub_expr5, sub_expr6, sub_expr6, sub_expr7], [sub_expr5, sub_expr8, sub_expr8, sub_expr7], [sub_expr5, sub_expr9, sub_expr9, sub_expr7], [sub_expr10, sub_expr11, sub_expr11, sub_expr12], [sub_expr10, sub_expr13, sub_expr13, sub_expr12], [sub_expr5, sub_expr14, sub_expr14, sub_expr7], [sub_expr10, sub_expr15, sub_expr15, sub_expr12], [sub_expr10, sub_expr16, sub_expr16, sub_expr12]))
# Out:
# expr: ((Input(|0〉) & MultiQubitGate(CONTROL, {1, 2}) & MultiQubitGate(CONTROL, {1, 2}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(Z, {1, 2}) & MultiQubitGate(Z, {1, 2}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(CONTROL, {3, 4}) & MultiQubitGate(CONTROL, {3, 4}) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(Z, {3, 4}) & MultiQubitGate(Z, {3, 4}) & Output(|1〉)  \\
#   Input(|1〉) & MultiQubitGate(CONTROL, {5, 6}) & MultiQubitGate(CONTROL, {5, 6}) & Output(|1〉)  \\
#   Input(|0〉) & MultiQubitGate(Z, {5, 6}) & MultiQubitGate(Z, {5, 6}) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(CONTROL, {7, 8}) & MultiQubitGate(CONTROL, {7, 8}) & Output(|1〉)  \\
#   Input(|1〉) & MultiQubitGate(Z, {7, 8}) & MultiQubitGate(Z, {7, 8}) & Output(|1〉)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\begin{array} {cccc}
#  \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & Z
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & Z
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 0 \rangle} \qw
# ...

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((Input(|0〉) & MultiQubitGate(CONTROL, {1, 2}) & MultiQubitGate(CONTROL, {1, 2}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(Z, {1, 2}) & MultiQubitGate(Z, {1, 2}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(CONTROL, {3, 4}) & MultiQubitGate(CONTROL, {3, 4}) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(Z, {3, 4}) & MultiQubitGate(Z, {3, 4}) & Output(|1〉)  \\
#   Input(|1〉) & MultiQubitGate(CONTROL, {5, 6}) & MultiQubitGate(CONTROL, {5, 6}) & Output(|1〉)  \\
#   Input(|0〉) & MultiQubitGate(Z, {5, 6}) & MultiQubitGate(Z, {5, 6}) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(CONTROL, {7, 8}) & MultiQubitGate(CONTROL, {7, 8}) & Output(|1〉)  \\
#   Input(|1〉) & MultiQubitGate(Z, {7, 8}) & MultiQubitGate(Z, {7, 8}) & Output(|1〉)))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. Input(|0〉) & MultiQubitGate(CONTROL, {1, 2}) & MultiQubitGate(CONTROL, {1, 2}) & Output(|0〉)  \\
# ...
