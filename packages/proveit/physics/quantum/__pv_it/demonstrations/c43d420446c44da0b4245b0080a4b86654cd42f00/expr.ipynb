# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, ExprRange, ExprTuple, IndexedVar, P, Q, R, Variable, g, h, k, m
from proveit.core_expr_types.expr_arrays import D11_to_Dmn, S11_to_Smn
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Variable("_b", latex_format = r"{_{-}b}")
sub_expr3 = [sub_expr1, sub_expr2]
expr = ExprTuple(ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(A, sub_expr3), one, g), one, m), ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(B, sub_expr3), one, h), one, m), ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(C, sub_expr3), one, k), one, m), D11_to_Dmn, ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(P, sub_expr3), one, g), one, m), ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(Q, sub_expr3), one, h), one, m), ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(R, sub_expr3), one, k), one, m), S11_to_Smn)
# Out:
# expr: (A_{1, 1}, ..A_{1, _b}.., A_{1, g}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, g}...., A_{m, 1}, ..A_{m, _b}.., A_{m, g}, B_{1, 1}, ..B_{1, _b}.., B_{1, h}, ....B_{_a, 1}, ..B_{_a, _b}.., B_{_a, h}...., B_{m, 1}, ..B_{m, _b}.., B_{m, h}, C_{1, 1}, ..C_{1, _b}.., C_{1, k}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, k}...., C_{m, 1}, ..C_{m, _b}.., C_{m, k}, D_{1, 1}, ..D_{1, _b}.., D_{1, n}, ....D_{_a, 1}, ..D_{_a, _b}.., D_{_a, n}...., D_{m, 1}, ..D_{m, _b}.., D_{m, n}, P_{1, 1}, ..P_{1, _b}.., P_{1, g}, ....P_{_a, 1}, ..P_{_a, _b}.., P_{_a, g}...., P_{m, 1}, ..P_{m, _b}.., P_{m, g}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, S_{1, 1}, ..S_{1, _b}.., S_{1, n}, ....S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}...., S_{m, 1}, ..S_{m, _b}.., S_{m, n})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{1, 1}, \ldots, A_{1, g}, \ldots\ldots, A_{m, 1}, \ldots, A_{m, g}, B_{1, 1}, \ldots, B_{1, h}, \ldots\ldots, B_{m, 1}, \ldots, B_{m, h}, C_{1, 1}, \ldots, C_{1, k}, \ldots\ldots, C_{m, 1}, \ldots, C_{m, k}, D_{1, 1}, \ldots, D_{1, n}, \ldots\ldots, D_{m, 1}, \ldots, D_{m, n}, P_{1, 1}, \ldots, P_{1, g}, \ldots\ldots, P_{m, 1}, \ldots, P_{m, g}, Q_{1, 1}, \ldots, Q_{1, h}, \ldots\ldots, Q_{m, 1}, \ldots, Q_{m, h}, R_{1, 1}, \ldots, R_{1, k}, \ldots\ldots, R_{m, 1}, \ldots, R_{m, k}, S_{1, 1}, \ldots, S_{1, n}, \ldots\ldots, S_{m, 1}, \ldots, S_{m, n}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A_{1, 1}, ..A_{1, _b}.., A_{1, g}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, g}...., A_{m, 1}, ..A_{m, _b}.., A_{m, g}, B_{1, 1}, ..B_{1, _b}.., B_{1, h}, ....B_{_a, 1}, ..B_{_a, _b}.., B_{_a, h}...., B_{m, 1}, ..B_{m, _b}.., B_{m, h}, C_{1, 1}, ..C_{1, _b}.., C_{1, k}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, k}...., C_{m, 1}, ..C_{m, _b}.., C_{m, k}, D_{1, 1}, ..D_{1, _b}.., D_{1, n}, ....D_{_a, 1}, ..D_{_a, _b}.., D_{_a, n}...., D_{m, 1}, ..D_{m, _b}.., D_{m, n}, P_{1, 1}, ..P_{1, _b}.., P_{1, g}, ....P_{_a, 1}, ..P_{_a, _b}.., P_{_a, g}...., P_{m, 1}, ..P_{m, _b}.., P_{m, g}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, S_{1, 1}, ..S_{1, _b}.., S_{1, n}, ....S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}...., S_{m, 1}, ..S_{m, _b}.., S_{m, n})
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4, 5, 6, 7, 8
# 1. A_{1, 1}, ..A_{1, _b}.., A_{1, g}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, g}...., A_{m, 1}, ..A_{m, _b}.., A_{m, g}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 37
#    end_index: 17
# 2. B_{1, 1}, ..B_{1, _b}.., B_{1, h}, ....B_{_a, 1}, ..B_{_a, _b}.., B_{_a, h}...., B_{m, 1}, ..B_{m, _b}.., B_{m, h}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 37
#    end_index: 17
# 3. C_{1, 1}, ..C_{1, _b}.., C_{1, k}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, k}...., C_{m, 1}, ..C_{m, _b}.., C_{m, k}
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 37
#    end_index: 17
# 4. D_{1, 1}, ..D_{1, _b}.., D_{1, n}, ....D_{_a, 1}, ..D_{_a, _b}.., D_{_a, n}...., D_{m, 1}, ..D_{m, _b}.., D_{m, n}
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 37
#    end_index: 17
# 5. P_{1, 1}, ..P_{1, _b}.., P_{1, g}, ....P_{_a, 1}, ..P_{_a, _b}.., P_{_a, g}...., P_{m, 1}, ..P_{m, _b}.., P_{m, g}
#    core type: ExprRange
#    lambda_map: 13
#    start_index: 37
#    end_index: 17
# 6. Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}
#    core type: ExprRange
#    lambda_map: 14
#    start_index: 37
#    end_index: 17
# 7. R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}
#    core type: ExprRange
#    lambda_map: 15
#    start_index: 37
#    end_index: 17
# 8. S_{1, 1}, ..S_{1, _b}.., S_{1, n}, ....S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}...., S_{m, 1}, ..S_{m, _b}.., S_{m, n}
#    core type: ExprRange
#    lambda_map: 16
#    start_index: 37
#    end_index: 17
# 9. _a -> A_{_a, 1}, ..A_{_a, _b}.., A_{_a, g}
#    core type: Lambda
#    parameter: 56
#    body: 18
# 10. _a -> B_{_a, 1}, ..B_{_a, _b}.., B_{_a, h}
#     core type: Lambda
#     parameter: 56
#     body: 19
# 11. _a -> C_{_a, 1}, ..C_{_a, _b}.., C_{_a, k}
#     core type: Lambda
#     parameter: 56
#     body: 20
# 12. _a -> D_{_a, 1}, ..D_{_a, _b}.., D_{_a, n}
#     core type: Lambda
#     parameter: 56
#     body: 21
# 13. _a -> P_{_a, 1}, ..P_{_a, _b}.., P_{_a, g}
#     core type: Lambda
#     parameter: 56
#     body: 22
# 14. _a -> Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}
#     core type: Lambda
#     parameter: 56
#     body: 23
# 15. _a -> R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}
#     core type: Lambda
#     parameter: 56
#     body: 24
# 16. _a -> S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}
#     core type: Lambda
#     parameter: 56
#     body: 25
# 17. m
#     core type: Variable
#     sub-expressions:
# 18. A_{_a, 1}, ..A_{_a, _b}.., A_{_a, g}
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 37
#     end_index: 31
# 19. B_{_a, 1}, ..B_{_a, _b}.., B_{_a, h}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 37
#     end_index: 33
# 20. C_{_a, 1}, ..C_{_a, _b}.., C_{_a, k}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 37
#     end_index: 35
# 21. D_{_a, 1}, ..D_{_a, _b}.., D_{_a, n}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 37
#     end_index: 38
# 22. P_{_a, 1}, ..P_{_a, _b}.., P_{_a, g}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 37
#     end_index: 31
# 23. Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 37
#     end_index: 33
# 24. R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 37
#     end_index: 35
# 25. S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 37
#     end_index: 38
# 26. _b -> A_{_a, _b}
#     core type: Lambda
#     parameter: 57
#     body: 39
# 27. _b -> B_{_a, _b}
#     core type: Lambda
#     parameter: 57
#     body: 40
# 28. _b -> C_{_a, _b}
#     core type: Lambda
#     parameter: 57
#     body: 41
# 29. _b -> D_{_a, _b}
#     core type: Lambda
#     parameter: 57
#     body: 42
# 30. _b -> P_{_a, _b}
#     core type: Lambda
#     parameter: 57
#     body: 43
# 31. g
#     core type: Variable
#     sub-expressions:
# 32. _b -> Q_{_a, _b}
#     core type: Lambda
#     parameter: 57
#     body: 44
# 33. h
#     core type: Variable
#     sub-expressions:
# 34. _b -> R_{_a, _b}
#     core type: Lambda
#     parameter: 57
#     body: 45
# 35. k
#     core type: Variable
#     sub-expressions:
# 36. _b -> S_{_a, _b}
#     core type: Lambda
#     parameter: 57
#     body: 46
# 37. 1
#     core type: Literal
#     sub-expressions:
# 38. n
#     core type: Variable
#     sub-expressions:
# 39. A_{_a, _b}
#     core type: IndexedVar
# variable: 47
# indices: 55
# 40. B_{_a, _b}
#     core type: IndexedVar
# variable: 48
# indices: 55
# 41. C_{_a, _b}
#     core type: IndexedVar
# variable: 49
# indices: 55
# 42. D_{_a, _b}
#     core type: IndexedVar
# variable: 50
# indices: 55
# 43. P_{_a, _b}
#     core type: IndexedVar
# variable: 51
# indices: 55
# 44. Q_{_a, _b}
#     core type: IndexedVar
# variable: 52
# indices: 55
# 45. R_{_a, _b}
#     core type: IndexedVar
# variable: 53
# indices: 55
# 46. S_{_a, _b}
#     core type: IndexedVar
# variable: 54
# indices: 55
# 47. A
#     core type: Variable
#     sub-expressions:
# 48. B
#     core type: Variable
#     sub-expressions:
# 49. C
#     core type: Variable
#     sub-expressions:
# 50. D
#     core type: Variable
#     sub-expressions:
# 51. P
#     core type: Variable
#     sub-expressions:
# 52. Q
#     core type: Variable
#     sub-expressions:
# 53. R
#     core type: Variable
#     sub-expressions:
# 54. S
#     core type: Variable
#     sub-expressions:
# 55. (_a, _b)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 56. _a
#     core type: Variable
#     sub-expressions:
# 57. _b
#     core type: Variable
#     sub-expressions:
