# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, k, x
from proveit.core_expr_types import Len
from proveit.numbers import Mult, one, three

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([ExprRange(k, ExprRange(x, [k, x], one, three), one, one)]), Mult(one, three))
# Out:
# expr: (|((1, 1), ..(1, x).., (1, 3), ....(k, 1), ..(k, x).., (k, 3)...., (1, 1), ..(1, x).., (1, 3))|, 1 * 3)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(\left(1, 1\right), \ldots, \left(1, 3\right), \ldots\ldots, \left(1, 1\right), \ldots, \left(1, 3\right)\right)|, 1 \cdot 3\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|((1, 1), ..(1, x).., (1, 3), ....(k, 1), ..(k, x).., (k, 3)...., (1, 1), ..(1, x).., (1, 3))|, 1 * 3)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |((1, 1), ..(1, x).., (1, 3), ....(k, 1), ..(k, x).., (k, 3)...., (1, 1), ..(1, x).., (1, 3))|
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. 1 * 3
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. length
#    core type: Literal
#    sub-expressions:
# 4. (((1, 1), ..(1, x).., (1, 3), ....(k, 1), ..(k, x).., (k, 3)...., (1, 1), ..(1, x).., (1, 3)))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. *
#    core type: Literal
#    sub-expressions:
# 6. (1, 3)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 7. ((1, 1), ..(1, x).., (1, 3), ....(k, 1), ..(k, x).., (k, 3)...., (1, 1), ..(1, x).., (1, 3))
#    core type: ExprTuple
#    sub-expressions: 8
# 8. (1, 1), ..(1, x).., (1, 3), ....(k, 1), ..(k, x).., (k, 3)...., (1, 1), ..(1, x).., (1, 3)
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 12
#    end_index: 12
# 9. k -> (k, 1), ..(k, x).., (k, 3)
#    core type: Lambda
#    parameter: 15
#    body: 10
# 10. (k, 1), ..(k, x).., (k, 3)
#     core type: ExprRange
#     lambda_map: 11
#     start_index: 12
#     end_index: 13
# 11. x -> (k, x)
#     core type: Lambda
#     parameter: 16
#     body: 14
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. 3
#     core type: Literal
#     sub-expressions:
# 14. (k, x)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. k
#     core type: Variable
#     sub-expressions:
# 16. x
#     core type: Variable
#     sub-expressions:
