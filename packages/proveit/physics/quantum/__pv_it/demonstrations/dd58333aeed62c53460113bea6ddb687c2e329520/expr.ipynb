# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.physics.quantum.circuit.Circuit.html">Circuit</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray
from proveit.logic import Set
from proveit.numbers import eight, five, four, one, seven, six, three, two
from proveit.physics.quantum import CONTROL, Gate, H, Input, Output, Z, ket0, ket1
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Gate(H)
sub_expr2 = Set(one, two)
sub_expr3 = Set(three, four)
sub_expr4 = Set(five, six)
sub_expr5 = Set(seven, eight)
sub_expr6 = Input(ket0)
sub_expr7 = Output(ket0)
sub_expr8 = Input(ket1)
sub_expr9 = Output(ket1)
expr = Circuit(ExprArray([sub_expr6, sub_expr1, MultiQubitGate(CONTROL, sub_expr2), sub_expr1, sub_expr7], [sub_expr6, sub_expr1, MultiQubitGate(Z, sub_expr2), sub_expr1, sub_expr7], [sub_expr6, sub_expr1, MultiQubitGate(CONTROL, sub_expr3), sub_expr1, sub_expr7], [sub_expr8, sub_expr1, MultiQubitGate(Z, sub_expr3), sub_expr1, sub_expr9], [sub_expr8, sub_expr1, MultiQubitGate(CONTROL, sub_expr4), sub_expr1, sub_expr9], [sub_expr6, sub_expr1, MultiQubitGate(Z, sub_expr4), sub_expr1, sub_expr9], [sub_expr8, sub_expr1, MultiQubitGate(CONTROL, sub_expr5), sub_expr1, sub_expr9], [sub_expr8, sub_expr1, MultiQubitGate(Z, sub_expr5), sub_expr1, sub_expr7]))
# Out:
# expr:  Input(|0〉)  & Gate(H)  & MultiQubitGate(CONTROL, {1, 2})  & Gate(H)  & Output(|0〉)   \\
#    Input(|0〉)  & Gate(H)  & MultiQubitGate(Z, {1, 2})  & Gate(H)  & Output(|0〉)   \\
#    Input(|0〉)  & Gate(H)  & MultiQubitGate(CONTROL, {3, 4})  & Gate(H)  & Output(|0〉)   \\
#    Input(|1〉)  & Gate(H)  & MultiQubitGate(Z, {3, 4})  & Gate(H)  & Output(|1〉)   \\
#    Input(|1〉)  & Gate(H)  & MultiQubitGate(CONTROL, {5, 6})  & Gate(H)  & Output(|1〉)   \\
#    Input(|0〉)  & Gate(H)  & MultiQubitGate(Z, {5, 6})  & Gate(H)  & Output(|1〉)   \\
#    Input(|1〉)  & Gate(H)  & MultiQubitGate(CONTROL, {7, 8})  & Gate(H)  & Output(|1〉)   \\
#    Input(|1〉)  & Gate(H)  & MultiQubitGate(Z, {7, 8})  & Gate(H)  & Output(|0〉)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle} & \gate{H} & \control \qw \qwx[1] & \gate{H} & \rstick{\lvert 0 \rangle} \qw   \\
#   & \lstick{\lvert 0 \rangle} & \gate{H} & \gate{Z} & \gate{H} & \rstick{\lvert 0 \rangle} \qw   \\
#   & \lstick{\lvert 0 \rangle} & \gate{H} & \control \qw \qwx[1] & \gate{H} & \rstick{\lvert 0 \rangle} \qw   \\
#   & \lstick{\lvert 1 \rangle} & \gate{H} & \gate{Z} & \gate{H} & \rstick{\lvert 1 \rangle} \qw   \\
#   & \lstick{\lvert 1 \rangle} & \gate{H} & \control \qw \qwx[1] & \gate{H} & \rstick{\lvert 1 \rangle} \qw   \\
#   & \lstick{\lvert 0 \rangle} & \gate{H} & \gate{Z} & \gate{H} & \rstick{\lvert 1 \rangle} \qw   \\
#   & \lstick{\lvert 1 \rangle} & \gate{H} & \control \qw \qwx[1] & \gate{H} & \rstick{\lvert 1 \rangle} \qw   \\
#   & \lstick{\lvert 1 \rangle} & \gate{H} & \gate{Z} & \gate{H} & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em}

# %%
expr.style_options()
# Out:
# style name: spacing
# description: change the spacing of a circuit using the format '@C=1em @R=.7em' where C is the column spacing and R is the row spacing
# default: @C=1em @R=.7em
# current value: @C=1em @R=.7em
# related methods: ()
# style name: orientation
# description: to be read from left to right then top to bottom ('horizontal') or to be read top to bottom then left to right ('vertical')
# default: horizontal
# current value: horizontal
# related methods: with_orientation

# %%
# display the expression information
expr.expr_info()
# Out:
# 0.  Input(|0〉)  & Gate(H)  & MultiQubitGate(CONTROL, {1, 2})  & Gate(H)  & Output(|0〉)   \\
#    Input(|0〉)  & Gate(H)  & MultiQubitGate(Z, {1, 2})  & Gate(H)  & Output(|0〉)   \\
#    Input(|0〉)  & Gate(H)  & MultiQubitGate(CONTROL, {3, 4})  & Gate(H)  & Output(|0〉)   \\
#    Input(|1〉)  & Gate(H)  & MultiQubitGate(Z, {3, 4})  & Gate(H)  & Output(|1〉)   \\
#    Input(|1〉)  & Gate(H)  & MultiQubitGate(CONTROL, {5, 6})  & Gate(H)  & Output(|1〉)   \\
#    Input(|0〉)  & Gate(H)  & MultiQubitGate(Z, {5, 6})  & Gate(H)  & Output(|1〉)   \\
#    Input(|1〉)  & Gate(H)  & MultiQubitGate(CONTROL, {7, 8})  & Gate(H)  & Output(|1〉)   \\
#    Input(|1〉)  & Gate(H)  & MultiQubitGate(Z, {7, 8})  & Gate(H)  & Output(|0〉)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. CIRCUIT
#    core type: Literal
#    sub-expressions:
# 2. ((Input(|0〉) & Gate(H) & MultiQubitGate(CONTROL, {1, 2}) & Gate(H) & Output(|0〉)  \\
# ...
