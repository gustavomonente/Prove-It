# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprTuple, Literal
from proveit.logic import Set
from proveit.numbers import one, three, two
from proveit.physics.quantum import CLASSICAL_CONTROL, CONTROL, Gate, H, I, Input, MEAS, Output, SPACE, X, Z, ket0, ket_psi
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = Gate(H)
sub_expr3 = Set(one, three)
sub_expr4 = Set(two, three)
sub_expr5 = Input(ket0)
sub_expr6 = MultiQubitGate(X, sub_expr4).with_styles(representation='implicit')
expr = ExprTuple(ExprArray([Input(ket_psi), I, I, MultiQubitGate(CONTROL, sub_expr1), sub_expr2, MEAS, MultiQubitGate(CLASSICAL_CONTROL, sub_expr3), SPACE], [sub_expr5, I, sub_expr6, MultiQubitGate(X, sub_expr1).with_styles(representation='implicit'), I, MultiQubitGate(Literal("MEAS", theory = "proveit.physics.quantum"), sub_expr4), SPACE, SPACE], [sub_expr5, sub_expr2, MultiQubitGate(CONTROL, sub_expr4), I, I, sub_expr6, MultiQubitGate(Z, sub_expr3), Output(ket_psi)]))
# Out:
# expr: ((Input(|psi〉) & -- & -- & MultiQubitGate(CONTROL, {1, 2}) & Gate(H) & Gate(MES) & MultiQubitGate(CLASSICAL\_CONTROL, {1, 3}) & SPACE  \\
#   Input(|0〉) & -- & MultiQubitGate(X, {2, 3}) & MultiQubitGate(X, {1, 2}) & -- & MultiQubitGate(MEAS, {2, 3}) & SPACE & SPACE  \\
#   Input(|0〉) & Gate(H) & MultiQubitGate(CONTROL, {2, 3}) & -- & -- & MultiQubitGate(X, {2, 3}) & MultiQubitGate(Z, {1, 3}) & Output(|psi〉)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\begin{array} {cccccccc}
#  \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert \psi \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \qw
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \qw
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{H}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \meter
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \cw
# } \hspace{2em} & SPACE  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \qw
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \targ
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \targ
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \qw
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & MEAS
# } \hspace{2em} & SPACE & SPACE  \\
# ...

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((Input(|psi〉) & -- & -- & MultiQubitGate(CONTROL, {1, 2}) & Gate(H) & Gate(MES) & MultiQubitGate(CLASSICAL\_CONTROL, {1, 3}) & SPACE  \\
#   Input(|0〉) & -- & MultiQubitGate(X, {2, 3}) & MultiQubitGate(X, {1, 2}) & -- & MultiQubitGate(MEAS, {2, 3}) & SPACE & SPACE  \\
#   Input(|0〉) & Gate(H) & MultiQubitGate(CONTROL, {2, 3}) & -- & -- & MultiQubitGate(X, {2, 3}) & MultiQubitGate(Z, {1, 3}) & Output(|psi〉)))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. Input(|psi〉) & -- & -- & MultiQubitGate(CONTROL, {1, 2}) & Gate(H) & Gate(MES) & MultiQubitGate(CLASSICAL\_CONTROL, {1, 3}) & SPACE  \\
#   Input(|0〉) & -- & MultiQubitGate(X, {2, 3}) & MultiQubitGate(X, {1, 2}) & -- & MultiQubitGate(MEAS, {2, 3}) & SPACE & SPACE  \\
#   Input(|0〉) & Gate(H) & MultiQubitGate(CONTROL, {2, 3}) & -- & -- & MultiQubitGate(X, {2, 3}) & MultiQubitGate(Z, {1, 3}) & Output(|psi〉)
#    core type: ExprTuple
#    sub-expressions: 2, 3, 4
# ...
