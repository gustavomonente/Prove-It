# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprTuple
from proveit.logic import Set
from proveit.numbers import four, one, seven, six, three, two
from proveit.physics.quantum import CONTROL, Gate, I, Input, Output, X, Z, ket0, ket1
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two, three, four, six, seven)
sub_expr2 = Input(ket0)
sub_expr3 = Output(ket0)
sub_expr4 = MultiQubitGate(Z, sub_expr1)
sub_expr5 = Input(ket1)
sub_expr6 = Output(ket1)
sub_expr7 = [sub_expr2, MultiQubitGate(CONTROL, sub_expr1), sub_expr3]
sub_expr8 = [sub_expr5, MultiQubitGate(X, sub_expr1), sub_expr6]
expr = ExprTuple(ExprArray(sub_expr7, sub_expr7, [sub_expr2, sub_expr4, sub_expr3], sub_expr8, [sub_expr2, Gate(I), sub_expr3], sub_expr8, [sub_expr5, sub_expr4, sub_expr6]))
# Out:
# expr: ((Input(|0〉) & MultiQubitGate(CONTROL, {1, 2, 3, 4, 6, 7}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(CONTROL, {1, 2, 3, 4, 6, 7}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(Z, {1, 2, 3, 4, 6, 7}) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(X, {1, 2, 3, 4, 6, 7}) & Output(|1〉)  \\
#   Input(|0〉) & Gate(I) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(X, {1, 2, 3, 4, 6, 7}) & Output(|1〉)  \\
#   Input(|1〉) & MultiQubitGate(Z, {1, 2, 3, 4, 6, 7}) & Output(|1〉)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\begin{array} {ccc}
#  \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & Z
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 1 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & X
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 1 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{I}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 1 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & X
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 1 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 1 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & Z
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 1 \rangle} \qw
# } \hspace{2em} \end{array}
# \right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((Input(|0〉) & MultiQubitGate(CONTROL, {1, 2, 3, 4, 6, 7}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(CONTROL, {1, 2, 3, 4, 6, 7}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(Z, {1, 2, 3, 4, 6, 7}) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(X, {1, 2, 3, 4, 6, 7}) & Output(|1〉)  \\
#   Input(|0〉) & Gate(I) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(X, {1, 2, 3, 4, 6, 7}) & Output(|1〉)  \\
#   Input(|1〉) & MultiQubitGate(Z, {1, 2, 3, 4, 6, 7}) & Output(|1〉)))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. Input(|0〉) & MultiQubitGate(CONTROL, {1, 2, 3, 4, 6, 7}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(CONTROL, {1, 2, 3, 4, 6, 7}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(Z, {1, 2, 3, 4, 6, 7}) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(X, {1, 2, 3, 4, 6, 7}) & Output(|1〉)  \\
#   Input(|0〉) & Gate(I) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(X, {1, 2, 3, 4, 6, 7}) & Output(|1〉)  \\
#   Input(|1〉) & MultiQubitGate(Z, {1, 2, 3, 4, 6, 7}) & Output(|1〉)
#    core type: ExprTuple
#    sub-expressions: 2, 2, 3, 5, 4, 5, 6
# 2. (Input(|0〉), MultiQubitGate(CONTROL, {1, 2, 3, 4, 6, 7}), Output(|0〉))
#    core type: ExprTuple
#    sub-expressions: 8, 7, 10
# 3. (Input(|0〉), MultiQubitGate(Z, {1, 2, 3, 4, 6, 7}), Output(|0〉))
#    core type: ExprTuple
#    sub-expressions: 8, 13, 10
# 4. (Input(|0〉), Gate(I), Output(|0〉))
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 5. (Input(|1〉), MultiQubitGate(X, {1, 2, 3, 4, 6, 7}), Output(|1〉))
#    core type: ExprTuple
#    sub-expressions: 12, 11, 14
# 6. (Input(|1〉), MultiQubitGate(Z, {1, 2, 3, 4, 6, 7}), Output(|1〉))
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14
# 7. MultiQubitGate(CONTROL, {1, 2, 3, 4, 6, 7})
#    core type: Operation
#    operator: 21
#    operands: 15
# 8. Input(|0〉)
#    core type: Operation
#    operator: 20
#    operand: 27
# 9. Gate(I)
#    core type: Operation
#    operator: 16
#    operand: 26
# 10. Output(|0〉)
#     core type: Operation
#     operator: 23
#     operand: 27
# 11. MultiQubitGate(X, {1, 2, 3, 4, 6, 7})
#     core type: Operation
#     operator: 21
#     operands: 19
# 12. Input(|1〉)
#     core type: Operation
#     operator: 20
#     operand: 31
# 13. MultiQubitGate(Z, {1, 2, 3, 4, 6, 7})
#     core type: Operation
#     operator: 21
#     operands: 22
# 14. Output(|1〉)
#     core type: Operation
#     operator: 23
#     operand: 31
# 15. (CONTROL, {1, 2, 3, 4, 6, 7})
#     core type: ExprTuple
#     sub-expressions: 25, 30
# 16. GATE
#     core type: Literal
#     sub-expressions:
# 17. (--)
#     core type: ExprTuple
#     sub-expressions: 26
# 18. (|0〉)
#     core type: ExprTuple
#     sub-expressions: 27
# 19. (X, {1, 2, 3, 4, 6, 7})
#     core type: ExprTuple
#     sub-expressions: 28, 30
# 20. INPUT
#     core type: Literal
#     sub-expressions:
# 21. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 22. (Z, {1, 2, 3, 4, 6, 7})
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 23. OUTPUT
#     core type: Literal
#     sub-expressions:
# 24. (|1〉)
#     core type: ExprTuple
#     sub-expressions: 31
# 25. CONTROL
#     core type: Literal
#     sub-expressions:
# 26. --
#     core type: Literal
#     sub-expressions:
# 27. |0〉
#     core type: Operation
#     operator: 35
#     operand: 37
# 28. X
#     core type: Literal
#     sub-expressions:
# 29. Z
#     core type: Literal
#     sub-expressions:
# 30. {1, 2, 3, 4, 6, 7}
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. |1〉
#     core type: Operation
#     operator: 35
#     operand: 43
# 32. (0)
#     core type: ExprTuple
#     sub-expressions: 37
# 33. Set
#     core type: Literal
#     sub-expressions:
# 34. (1, 2, 3, 4, 6, 7)
#     core type: ExprTuple
#     sub-expressions: 43, 38, 39, 40, 41, 42
# 35. KET
#     core type: Literal
#     sub-expressions:
# 36. (1)
#     core type: ExprTuple
#     sub-expressions: 43
# 37. 0
#     core type: Literal
#     sub-expressions:
# 38. 2
#     core type: Literal
#     sub-expressions:
# 39. 3
#     core type: Literal
#     sub-expressions:
# 40. 4
#     core type: Literal
#     sub-expressions:
# 41. 6
#     core type: Literal
#     sub-expressions:
# 42. 7
#     core type: Literal
#     sub-expressions:
# 43. 1
#     core type: Literal
#     sub-expressions:
