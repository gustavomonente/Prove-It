# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import C, ExprTuple, IndexedVar, Q, i
from proveit.numbers import one
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = [i, one]
expr = ExprTuple(MultiQubitGate(IndexedVar(C, sub_expr1), IndexedVar(Q, sub_expr1)))
# Out:
# expr: (MultiQubitGate(C_{i, 1}, Q_{i, 1}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{C_{i, 1}{\Big \{} Q_{i, 1}}
# } \hspace{2em}\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (MultiQubitGate(C_{i, 1}, Q_{i, 1}))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. MultiQubitGate(C_{i, 1}, Q_{i, 1})
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. MULTI_QUBIT_GATE
#    core type: Literal
#    sub-expressions:
# 3. (C_{i, 1}, Q_{i, 1})
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. C_{i, 1}
#    core type: IndexedVar
# variable: 6
# indices: 8
# 5. Q_{i, 1}
#    core type: IndexedVar
# variable: 7
# indices: 8
# 6. C
#    core type: Variable
#    sub-expressions:
# 7. Q
#    core type: Variable
#    sub-expressions:
# 8. (i, 1)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. i
#    core type: Variable
#    sub-expressions:
# 10. 1
#     core type: Literal
#     sub-expressions:
