# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprTuple
from proveit.logic import Set
from proveit.numbers import four, one, three, two
from proveit.physics.quantum import CLASSICAL_CONTROL, Input, Output, SPACE, X, ket0, ket1
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Input(one)
sub_expr2 = Set(one, two)
sub_expr3 = Set(three, four)
expr = ExprTuple(ExprArray([sub_expr1, MultiQubitGate(CLASSICAL_CONTROL, sub_expr2), SPACE], [Input(ket0), MultiQubitGate(X, sub_expr2).with_styles(representation='implicit'), Output(ket1)], [sub_expr1, MultiQubitGate(CLASSICAL_CONTROL, sub_expr3), SPACE], [Input(ket1), MultiQubitGate(X, sub_expr3), Output(ket0)]))
# Out:
# expr: ((Input(1) & MultiQubitGate(CLASSICAL\_CONTROL, {1, 2}) & SPACE  \\
#   Input(|0〉) & MultiQubitGate(X, {1, 2}) & Output(|1〉)  \\
#   Input(1) & MultiQubitGate(CLASSICAL\_CONTROL, {3, 4}) & SPACE  \\
#   Input(|1〉) & MultiQubitGate(X, {3, 4}) & Output(|0〉)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\begin{array} {ccc}
#  \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{1}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \cw
# } \hspace{2em} & SPACE  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \targ
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 1 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{1}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \cw
# } \hspace{2em} & SPACE  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 1 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & X
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em} \end{array}
# \right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((Input(1) & MultiQubitGate(CLASSICAL\_CONTROL, {1, 2}) & SPACE  \\
#   Input(|0〉) & MultiQubitGate(X, {1, 2}) & Output(|1〉)  \\
#   Input(1) & MultiQubitGate(CLASSICAL\_CONTROL, {3, 4}) & SPACE  \\
#   Input(|1〉) & MultiQubitGate(X, {3, 4}) & Output(|0〉)))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. Input(1) & MultiQubitGate(CLASSICAL\_CONTROL, {1, 2}) & SPACE  \\
#   Input(|0〉) & MultiQubitGate(X, {1, 2}) & Output(|1〉)  \\
#   Input(1) & MultiQubitGate(CLASSICAL\_CONTROL, {3, 4}) & SPACE  \\
#   Input(|1〉) & MultiQubitGate(X, {3, 4}) & Output(|0〉)
#    core type: ExprTuple
#    sub-expressions: 2, 3, 4, 5
# 2. (Input(1), MultiQubitGate(CLASSICAL\_CONTROL, {1, 2}), SPACE)
#    core type: ExprTuple
#    sub-expressions: 10, 6, 12
# 3. (Input(|0〉), MultiQubitGate(X, {1, 2}), Output(|1〉))
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 4. (Input(1), MultiQubitGate(CLASSICAL\_CONTROL, {3, 4}), SPACE)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# ...
