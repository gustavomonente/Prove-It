# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprArray.html">ExprArray</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray
from proveit.logic import Set
from proveit.numbers import Neg, eight, five, four, one, seven, six, three, two
from proveit.physics.quantum import CONTROL, Input, Output, Z, ket0, ket1
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = Set(three, four)
sub_expr3 = Set(five, six)
sub_expr4 = Set(seven, eight)
sub_expr5 = Input(ket0)
sub_expr6 = Output(ket0)
sub_expr7 = Input(ket1)
sub_expr8 = Output(ket1)
expr = ExprArray([sub_expr5, MultiQubitGate(Z, sub_expr1), sub_expr6], [sub_expr5, MultiQubitGate(CONTROL, sub_expr1), sub_expr6], [sub_expr5, MultiQubitGate(Z, sub_expr2), sub_expr6], [sub_expr7, MultiQubitGate(CONTROL, sub_expr2), sub_expr8], [sub_expr7, MultiQubitGate(Z, sub_expr3), sub_expr8], [sub_expr5, MultiQubitGate(CONTROL, sub_expr3), sub_expr6], [sub_expr7, MultiQubitGate(Z, sub_expr4), Output(Neg(ket1))], [sub_expr7, MultiQubitGate(CONTROL, sub_expr4), sub_expr8])
# Out:
# expr: Input(|0〉) & MultiQubitGate(Z, {1, 2}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(CONTROL, {1, 2}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(Z, {3, 4}) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(CONTROL, {3, 4}) & Output(|1〉)  \\
#   Input(|1〉) & MultiQubitGate(Z, {5, 6}) & Output(|1〉)  \\
#   Input(|0〉) & MultiQubitGate(CONTROL, {5, 6}) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(Z, {7, 8}) & Output(-|1〉)  \\
#   Input(|1〉) & MultiQubitGate(CONTROL, {7, 8}) & Output(|1〉)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array} {ccc}
#  \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & Z
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & Z
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 1 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 1 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 1 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & Z
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 1 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 1 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & Z
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{-\lvert 1 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 1 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 1 \rangle} \qw
# } \hspace{2em} \end{array}

# %%
expr.style_options()
# Out:
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: with_justification
# style name: orientation
# description: to be read from left to right then top to bottom ('horizontal') or to be read top to bottom then left to right ('vertical')
# default: horizontal
# current value: horizontal
# related methods: with_orientation
# style name: parameterization
# description: 'implicit' (default for LaTeX formatting) hides the parameter the ExprRange so the parameterization may be ambiguous (e.g., x_{1+1}, ..., x_{n+1}); 'explicit' (default for string formatting) reveals the parameterization (e.g. x_{1+1}, ..x_{k+1}.., x_{n+1}).
# default: None
# current value: None/False
# related methods: ('with_explicit_parameterization', 'with_implicit_parameterization', 'with_default_parameterization_style')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. Input(|0〉) & MultiQubitGate(Z, {1, 2}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(CONTROL, {1, 2}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(Z, {3, 4}) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(CONTROL, {3, 4}) & Output(|1〉)  \\
#   Input(|1〉) & MultiQubitGate(Z, {5, 6}) & Output(|1〉)  \\
#   Input(|0〉) & MultiQubitGate(CONTROL, {5, 6}) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(Z, {7, 8}) & Output(-|1〉)  \\
#   Input(|1〉) & MultiQubitGate(CONTROL, {7, 8}) & Output(|1〉)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4, 5, 6, 7, 8
# 1. (Input(|0〉), MultiQubitGate(Z, {1, 2}), Output(|0〉))
#    core type: ExprTuple
#    sub-expressions: 14, 9, 16
# 2. (Input(|0〉), MultiQubitGate(CONTROL, {1, 2}), Output(|0〉))
#    core type: ExprTuple
#    sub-expressions: 14, 10, 16
# 3. (Input(|0〉), MultiQubitGate(Z, {3, 4}), Output(|0〉))
#    core type: ExprTuple
#    sub-expressions: 14, 11, 16
# 4. (Input(|1〉), MultiQubitGate(CONTROL, {3, 4}), Output(|1〉))
#    core type: ExprTuple
#    sub-expressions: 19, 12, 21
# 5. (Input(|1〉), MultiQubitGate(Z, {5, 6}), Output(|1〉))
#    core type: ExprTuple
#    sub-expressions: 19, 13, 21
# 6. (Input(|0〉), MultiQubitGate(CONTROL, {5, 6}), Output(|0〉))
#    core type: ExprTuple
#    sub-expressions: 14, 15, 16
# 7. (Input(|1〉), MultiQubitGate(Z, {7, 8}), Output(-|1〉))
#    core type: ExprTuple
#    sub-expressions: 19, 17, 18
# 8. (Input(|1〉), MultiQubitGate(CONTROL, {7, 8}), Output(|1〉))
#    core type: ExprTuple
#    sub-expressions: 19, 20, 21
# 9. MultiQubitGate(Z, {1, 2})
#    core type: Operation
#    operator: 32
#    operands: 22
# 10. MultiQubitGate(CONTROL, {1, 2})
#     core type: Operation
#     operator: 32
#     operands: 23
# 11. MultiQubitGate(Z, {3, 4})
#     core type: Operation
#     operator: 32
#     operands: 24
# 12. MultiQubitGate(CONTROL, {3, 4})
#     core type: Operation
#     operator: 32
#     operands: 25
# 13. MultiQubitGate(Z, {5, 6})
#     core type: Operation
#     operator: 32
#     operands: 26
# 14. Input(|0〉)
#     core type: Operation
#     operator: 31
#     operand: 38
# 15. MultiQubitGate(CONTROL, {5, 6})
#     core type: Operation
#     operator: 32
#     operands: 27
# 16. Output(|0〉)
#     core type: Operation
#     operator: 34
#     operand: 38
# 17. MultiQubitGate(Z, {7, 8})
#     core type: Operation
#     operator: 32
#     operands: 29
# 18. Output(-|1〉)
#     core type: Operation
#     operator: 34
#     operand: 40
# 19. Input(|1〉)
#     core type: Operation
#     operator: 31
#     operand: 57
# 20. MultiQubitGate(CONTROL, {7, 8})
#     core type: Operation
#     operator: 32
#     operands: 33
# 21. Output(|1〉)
#     core type: Operation
#     operator: 34
#     operand: 57
# 22. (Z, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 39, 35
# 23. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 41, 35
# 24. (Z, {3, 4})
#     core type: ExprTuple
#     sub-expressions: 39, 36
# 25. (CONTROL, {3, 4})
#     core type: ExprTuple
#     sub-expressions: 41, 36
# 26. (Z, {5, 6})
#     core type: ExprTuple
#     sub-expressions: 39, 37
# 27. (CONTROL, {5, 6})
#     core type: ExprTuple
#     sub-expressions: 41, 37
# 28. (|0〉)
#     core type: ExprTuple
#     sub-expressions: 38
# 29. (Z, {7, 8})
#     core type: ExprTuple
#     sub-expressions: 39, 42
# 30. (-|1〉)
#     core type: ExprTuple
#     sub-expressions: 40
# 31. INPUT
#     core type: Literal
#     sub-expressions:
# 32. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 33. (CONTROL, {7, 8})
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 34. OUTPUT
#     core type: Literal
#     sub-expressions:
# 35. {1, 2}
#     core type: Operation
#     operator: 49
#     operands: 43
# 36. {3, 4}
#     core type: Operation
#     operator: 49
#     operands: 44
# 37. {5, 6}
#     core type: Operation
#     operator: 49
#     operands: 45
# 38. |0〉
#     core type: Operation
#     operator: 60
#     operand: 56
# 39. Z
#     core type: Literal
#     sub-expressions:
# 40. -|1〉
#     core type: Operation
#     operator: 47
#     operand: 57
# 41. CONTROL
#     core type: Literal
#     sub-expressions:
# 42. {7, 8}
#     core type: Operation
#     operator: 49
#     operands: 50
# 43. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 62, 51
# 44. (3, 4)
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 45. (5, 6)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 46. (0)
#     core type: ExprTuple
#     sub-expressions: 56
# 47. -
#     core type: Literal
#     sub-expressions:
# 48. (|1〉)
#     core type: ExprTuple
#     sub-expressions: 57
# 49. Set
#     core type: Literal
#     sub-expressions:
# 50. (7, 8)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 51. 2
#     core type: Literal
#     sub-expressions:
# 52. 3
#     core type: Literal
#     sub-expressions:
# 53. 4
#     core type: Literal
#     sub-expressions:
# 54. 5
#     core type: Literal
#     sub-expressions:
# 55. 6
#     core type: Literal
#     sub-expressions:
# 56. 0
#     core type: Literal
#     sub-expressions:
# 57. |1〉
#     core type: Operation
#     operator: 60
#     operand: 62
# 58. 7
#     core type: Literal
#     sub-expressions:
# 59. 8
#     core type: Literal
#     sub-expressions:
# 60. KET
#     core type: Literal
#     sub-expressions:
# 61. (1)
#     core type: ExprTuple
#     sub-expressions: 62
# 62. 1
#     core type: Literal
#     sub-expressions:
