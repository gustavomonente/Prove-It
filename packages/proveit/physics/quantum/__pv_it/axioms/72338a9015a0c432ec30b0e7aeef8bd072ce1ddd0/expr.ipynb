# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, k, n
from proveit.linalg import TensorProd
from proveit.logic import Equals, InSet
from proveit.numbers import Add, Exp, Interval, Neg, one, two, zero
from proveit.physics.quantum import RegisterKet, ket0

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(k, Conditional(Equals(RegisterKet(k, Add(n, one)), TensorProd(RegisterKet(k, n), ket0)), InSet(k, Interval(zero, Add(Exp(two, n), Neg(one)))))))
# Out:
# expr: (k -> {|k〉_{n + 1} = (|k〉_{n} otimes |0〉) if k in {0...2^{n} - 1}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(k \mapsto \left\{\lvert k \rangle_{n + 1} = \left(\lvert k \rangle_{n} {\otimes} \lvert 0 \rangle\right) \textrm{ if } k \in \{0 \ldots 2^{n} - 1\}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (k -> {|k〉_{n + 1} = (|k〉_{n} otimes |0〉) if k in {0...2^{n} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. k -> {|k〉_{n + 1} = (|k〉_{n} otimes |0〉) if k in {0...2^{n} - 1}.
#    core type: Lambda
#    parameter: 28
#    body: 2
# 2. {|k〉_{n + 1} = (|k〉_{n} otimes |0〉) if k in {0...2^{n} - 1}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. |k〉_{n + 1} = (|k〉_{n} otimes |0〉)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. k in {0...2^{n} - 1}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (|k〉_{n + 1}, |k〉_{n} otimes |0〉)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (k, {0...2^{n} - 1})
#    core type: ExprTuple
#    sub-expressions: 28, 11
# 9. |k〉_{n + 1}
#    core type: Operation
#    operator: 22
#    operands: 12
# 10. |k〉_{n} otimes |0〉
#     core type: Operation
#     operator: 13
# ...
