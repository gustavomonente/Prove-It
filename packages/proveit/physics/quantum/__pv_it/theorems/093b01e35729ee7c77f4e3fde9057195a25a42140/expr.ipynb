# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Psi, k, m, n
from proveit.linalg import TensorExp
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Add, Exp, Interval, Neg, Sum, one, two, zero
from proveit.physics.quantum import Ket, Meas, QubitSpace
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
sub_expr1 = Ket(Psi)
expr = Forall([Psi, m], Equals(Sum([k], Prob(Equals(m, k), m), domains = [Interval(zero, Add(Exp(two, n), Neg(one)))]), one), conditions = [InSet(sub_expr1, TensorExp([QubitSpace], n)), Equals(m, Meas(sub_expr1))])
# Out:
# expr: forall_{Psi, m | |Psi〉 in (Complex^{2})^{otimes n}, m = MEAS(|Psi〉)} ((Sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]) = 1)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{\Psi, m~|~\lvert \Psi \rangle \in \left(\mathbb{C}^{2}\right)^{\otimes n}, m = \mathcal{M}(\lvert \Psi \rangle)}~\left(\left(\sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]\right) = 1\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{Psi, m | |Psi〉 in (Complex^{2})^{otimes n}, m = MEAS(|Psi〉)} ((Sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]) = 1)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((Psi, m) -> {(Sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]) = 1 if |Psi〉 in (Complex^{2})^{otimes n} ,  m = MEAS(|Psi〉).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (Psi, m) -> {(Sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]) = 1 if |Psi〉 in (Complex^{2})^{otimes n} ,  m = MEAS(|Psi〉).
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (Psi, m)
#    core type: ExprTuple
#    sub-expressions: 40, 46
# 5. {(Sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]) = 1 if |Psi〉 in (Complex^{2})^{otimes n} ,  m = MEAS(|Psi〉).
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (Sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]) = 1
#    core type: Operation
#    operator: 41
#    operands: 8
# 7. (|Psi〉 in (Complex^{2})^{otimes n}) and (m = MEAS(|Psi〉))
# ...
