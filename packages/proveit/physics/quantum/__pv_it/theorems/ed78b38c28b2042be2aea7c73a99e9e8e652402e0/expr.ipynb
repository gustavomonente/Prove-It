# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B, D, ExprArray, ExprRange, ExprTuple, F, G, IndexedVar, j, k, m, n
from proveit.logic import Set
from proveit.numbers import Add, one, two
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(Add(m, one), Add(m, k, two))
expr = ExprTuple(Circuit(ExprArray([ExprRange(j, MultiQubitGate(IndexedVar(B, j), sub_expr1), one, n)], [ExprRange(j, MultiQubitGate(IndexedVar(D, j), sub_expr1), one, n)])), Circuit(ExprArray([ExprRange(j, MultiQubitGate(IndexedVar(F, j), sub_expr1), one, n)], [ExprRange(j, MultiQubitGate(IndexedVar(G, j), sub_expr1), one, n)])))
# Out:
# expr: ( MultiQubitGate(B_{1}, {m + 1, m + k + 2})  & ..MultiQubitGate(B_{j}, {m + 1, m + k + 2})..  & MultiQubitGate(B_{n}, {m + 1, m + k + 2})   \\
#    MultiQubitGate(D_{1}, {m + 1, m + k + 2})  & ..MultiQubitGate(D_{j}, {m + 1, m + k + 2})..  & MultiQubitGate(D_{n}, {m + 1, m + k + 2}),  MultiQubitGate(F_{1}, {m + 1, m + k + 2})  & ..MultiQubitGate(F_{j}, {m + 1, m + k + 2})..  & MultiQubitGate(F_{n}, {m + 1, m + k + 2})   \\
#    MultiQubitGate(G_{1}, {m + 1, m + k + 2})  & ..MultiQubitGate(G_{j}, {m + 1, m + k + 2})..  & MultiQubitGate(G_{n}, {m + 1, m + k + 2}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{1}{\Big \{} \left\{m + 1, m + k + 2\right\}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{B_{n}{\Big \{} \left\{m + 1, m + k + 2\right\}} \qwx[1]   \\
#   & \gate{D_{1}{\Big \{} \left\{m + 1, m + k + 2\right\}} & \gate{\cdots} & \gate{D_{n}{\Big \{} \left\{m + 1, m + k + 2\right\}}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{F_{1}{\Big \{} \left\{m + 1, m + k + 2\right\}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{F_{n}{\Big \{} \left\{m + 1, m + k + 2\right\}} \qwx[1]   \\
#   & \gate{G_{1}{\Big \{} \left\{m + 1, m + k + 2\right\}} & \gate{\cdots} & \gate{G_{n}{\Big \{} \left\{m + 1, m + k + 2\right\}}
# } \hspace{2em}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ( MultiQubitGate(B_{1}, {m + 1, m + k + 2})  & ..MultiQubitGate(B_{j}, {m + 1, m + k + 2})..  & MultiQubitGate(B_{n}, {m + 1, m + k + 2})   \\
#    MultiQubitGate(D_{1}, {m + 1, m + k + 2})  & ..MultiQubitGate(D_{j}, {m + 1, m + k + 2})..  & MultiQubitGate(D_{n}, {m + 1, m + k + 2}),  MultiQubitGate(F_{1}, {m + 1, m + k + 2})  & ..MultiQubitGate(F_{j}, {m + 1, m + k + 2})..  & MultiQubitGate(F_{n}, {m + 1, m + k + 2})   \\
#    MultiQubitGate(G_{1}, {m + 1, m + k + 2})  & ..MultiQubitGate(G_{j}, {m + 1, m + k + 2})..  & MultiQubitGate(G_{n}, {m + 1, m + k + 2}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1.  MultiQubitGate(B_{1}, {m + 1, m + k + 2})  & ..MultiQubitGate(B_{j}, {m + 1, m + k + 2})..  & MultiQubitGate(B_{n}, {m + 1, m + k + 2})   \\
#    MultiQubitGate(D_{1}, {m + 1, m + k + 2})  & ..MultiQubitGate(D_{j}, {m + 1, m + k + 2})..  & MultiQubitGate(D_{n}, {m + 1, m + k + 2})
#    core type: Operation
#    operator: 4
#    operand: 6
# ...
