# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, ExprTuple, IndexedVar, Lambda, Variable, n, x
from proveit.core_expr_types import x_1_to_n
from proveit.logic import And, InSet
from proveit.numbers import Add, one
from proveit.physics.quantum import QubitSpace

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(Lambda([x_1_to_n], Conditional(InSet(Add(x_1_to_n), QubitSpace), And(ExprRange(sub_expr1, InSet(IndexedVar(x, sub_expr1), QubitSpace), one, n)))))
# Out:
# expr: ((x_{1}, ..x_{_a}.., x_{n}) -> {(x_{1} + ..x_{_a}.. + x_{n}) in Complex^{2} if (x_{1} in Complex^{2}) and ..(x_{_a} in Complex^{2}).. and (x_{n} in Complex^{2}).)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(x_{1}, \ldots, x_{n}\right) \mapsto \left\{\left(x_{1} + \ldots + x_{n}\right) \in \mathbb{C}^{2} \textrm{ if } \left(x_{1} \in \mathbb{C}^{2}\right) \land \ldots \land \left(x_{n} \in \mathbb{C}^{2}\right)\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((x_{1}, ..x_{_a}.., x_{n}) -> {(x_{1} + ..x_{_a}.. + x_{n}) in Complex^{2} if (x_{1} in Complex^{2}) and ..(x_{_a} in Complex^{2}).. and (x_{n} in Complex^{2}).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (x_{1}, ..x_{_a}.., x_{n}) -> {(x_{1} + ..x_{_a}.. + x_{n}) in Complex^{2} if (x_{1} in Complex^{2}) and ..(x_{_a} in Complex^{2}).. and (x_{n} in Complex^{2}).
#    core type: Lambda
#    parameters: 11\n   body: 2
# 2. {(x_{1} + ..x_{_a}.. + x_{n}) in Complex^{2} if (x_{1} in Complex^{2}) and ..(x_{_a} in Complex^{2}).. and (x_{n} in Complex^{2}).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (x_{1} + ..x_{_a}.. + x_{n}) in Complex^{2}
#    core type: Operation
#    operator: 18
#    operands: 5
# 4. (x_{1} in Complex^{2}) and ..(x_{_a} in Complex^{2}).. and (x_{n} in Complex^{2})
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (x_{1} + ..x_{_a}.. + x_{n}, Complex^{2})
#    core type: ExprTuple
#    sub-expressions: 8, 21
# ...
