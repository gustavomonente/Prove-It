# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, U, x
from proveit.linalg import MatrixProd, SU
from proveit.logic import InSet
from proveit.numbers import two
from proveit.physics.quantum import QubitSpace

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(U, Conditional(InSet(MatrixProd(U, x), QubitSpace), InSet(U, SU(two)))))
# Out:
# expr: (U -> {(U . x) in Complex^{2} if U in SU(2).)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(U \mapsto \left\{\left(U \thinspace x\right) \in \mathbb{C}^{2} \textrm{ if } U \in SU(2)\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (U -> {(U . x) in Complex^{2} if U in SU(2).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. U -> {(U . x) in Complex^{2} if U in SU(2).
#    core type: Lambda
#    parameter: 17
#    body: 2
# 2. {(U . x) in Complex^{2} if U in SU(2).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (U . x) in Complex^{2}
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. U in SU(2)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (U . x, Complex^{2})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (U, SU(2))
#    core type: ExprTuple
#    sub-expressions: 17, 10
# 8. U . x
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. Complex^{2}
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. SU(2)
#     core type: Operation
#     operator: 15
#     operand: 20
# 11. .
#     core type: Literal
#     sub-expressions:
# 12. (U, x)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 13. Exp
#     core type: Literal
#     sub-expressions:
# 14. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 15. SU
#     core type: Literal
#     sub-expressions:
# 16. (2)
#     core type: ExprTuple
#     sub-expressions: 20
# 17. U
#     core type: Variable
#     sub-expressions:
# 18. x
#     core type: Variable
#     sub-expressions:
# 19. Complex
#     core type: Literal
#     sub-expressions:
# 20. 2
#     core type: Literal
#     sub-expressions:
