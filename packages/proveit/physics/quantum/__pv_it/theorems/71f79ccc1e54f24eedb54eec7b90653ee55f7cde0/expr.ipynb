# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.physics.quantum.circuit.MultiQubitGate.html">MultiQubitGate</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import G, IndexedVar, j, k, m
from proveit.logic import Set
from proveit.numbers import Add, one, two
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
expr = MultiQubitGate(IndexedVar(G, j), Set(Add(m, one), Add(m, k, two)))
# Out:
# expr: MultiQubitGate(G_{j}, {m + 1, m + k + 2})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{G_{j}{\Big \{} \left\{m + 1, m + k + 2\right\}}
# } \hspace{2em}

# %%
expr.style_options()
# Out:
# style name: representation
# description: 'implicit' representation displays X gates as a target, while 'explicit' representation always displays the type of gate in a box. Ex. |X|
# default: explicit
# current value: explicit
# related methods: ()

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. MultiQubitGate(G_{j}, {m + 1, m + k + 2})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. MULTI_QUBIT_GATE
#    core type: Literal
#    sub-expressions:
# 2. (G_{j}, {m + 1, m + k + 2})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. G_{j}
#    core type: IndexedVar
# variable: 5
# index: 9
# 4. {m + 1, m + k + 2}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. G
#    core type: Variable
#    sub-expressions:
# 6. (j)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. Set
#    core type: Literal
#    sub-expressions:
# 8. (m + 1, m + k + 2)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. j
#    core type: Variable
#    sub-expressions:
# 10. m + 1
#     core type: Operation
#     operator: 13
#     operands: 12
# 11. m + k + 2
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 16, 15
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (m, k, 2)
#     core type: ExprTuple
#     sub-expressions: 16, 17, 18
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. m
#     core type: Variable
#     sub-expressions:
# 17. k
#     core type: Variable
#     sub-expressions:
# 18. 2
#     core type: Literal
#     sub-expressions:
