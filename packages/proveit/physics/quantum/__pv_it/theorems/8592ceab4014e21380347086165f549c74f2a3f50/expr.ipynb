# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import G, IndexedVar, Lambda, j, k, m
from proveit.logic import Set
from proveit.numbers import Add, one, two
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
expr = Lambda(j, MultiQubitGate(IndexedVar(G, j), Set(Add(m, one), Add(m, k, two))))
# Out:
# expr: j -> MultiQubitGate(G_{j}, {m + 1, m + k + 2})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# j \mapsto \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{G_{j}{\Big \{} \left\{m + 1, m + k + 2\right\}}
# } \hspace{2em}

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. j -> MultiQubitGate(G_{j}, {m + 1, m + k + 2})
#    core type: Lambda
#    parameter: 10
#    body: 1
# 1. MultiQubitGate(G_{j}, {m + 1, m + k + 2})
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. MULTI_QUBIT_GATE
#    core type: Literal
#    sub-expressions:
# 3. (G_{j}, {m + 1, m + k + 2})
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. G_{j}
#    core type: IndexedVar
# variable: 6
# index: 10
# 5. {m + 1, m + k + 2}
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. G
#    core type: Variable
#    sub-expressions:
# 7. (j)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. Set
#    core type: Literal
#    sub-expressions:
# 9. (m + 1, m + k + 2)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. j
#     core type: Variable
#     sub-expressions:
# 11. m + 1
#     core type: Operation
#     operator: 14
#     operands: 13
# 12. m + k + 2
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 17, 16
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (m, k, 2)
#     core type: ExprTuple
#     sub-expressions: 17, 18, 19
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. m
#     core type: Variable
#     sub-expressions:
# 18. k
#     core type: Variable
#     sub-expressions:
# 19. 2
#     core type: Literal
#     sub-expressions:
