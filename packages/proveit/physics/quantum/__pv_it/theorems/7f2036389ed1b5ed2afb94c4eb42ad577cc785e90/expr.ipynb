# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B, D, ExprArray, ExprRange, F, G, IndexedVar, h, i, j, k, m, n
from proveit.core_expr_types.expr_arrays import Aij, Cij, Eij, Qij, Rij, Sij
from proveit.logic import Implies, Set
from proveit.numbers import Add, one, two
from proveit.physics.quantum.circuit import Circuit, CircuitEquiv, MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(Add(m, one), Add(m, k, two))
sub_expr2 = [ExprRange(j, MultiQubitGate(IndexedVar(B, j), sub_expr1), one, n)]
sub_expr3 = [ExprRange(j, MultiQubitGate(IndexedVar(D, j), sub_expr1), one, n)]
sub_expr4 = [ExprRange(j, MultiQubitGate(IndexedVar(F, j), sub_expr1), one, n)]
sub_expr5 = [ExprRange(j, MultiQubitGate(IndexedVar(G, j), sub_expr1), one, n)]
sub_expr6 = ExprRange(i, [ExprRange(j, MultiQubitGate(Aij, Sij), one, n)], one, m)
sub_expr7 = ExprRange(i, [ExprRange(j, MultiQubitGate(Cij, Rij), one, n)], one, k)
sub_expr8 = ExprRange(i, [ExprRange(j, MultiQubitGate(Eij, Qij), one, n)], one, h)
expr = Implies(CircuitEquiv(Circuit(ExprArray(sub_expr2, sub_expr3)), Circuit(ExprArray(sub_expr4, sub_expr5))), CircuitEquiv(Circuit(ExprArray(sub_expr6, sub_expr2, sub_expr7, sub_expr3, sub_expr8)), Circuit(ExprArray(sub_expr6, sub_expr4, sub_expr7, sub_expr5, sub_expr8)))).with_wrapping_at(2)
# Out:
# expr: ( MultiQubitGate(B_{1}, {m + 1, m + k + 2})  & ..MultiQubitGate(B_{j}, {m + 1, m + k + 2})..  & MultiQubitGate(B_{n}, {m + 1, m + k + 2})   \\
#    MultiQubitGate(D_{1}, {m + 1, m + k + 2})  & ..MultiQubitGate(D_{j}, {m + 1, m + k + 2})..  & MultiQubitGate(D_{n}, {m + 1, m + k + 2}) equiv  MultiQubitGate(F_{1}, {m + 1, m + k + 2})  & ..MultiQubitGate(F_{j}, {m + 1, m + k + 2})..  & MultiQubitGate(F_{n}, {m + 1, m + k + 2})   \\
#    MultiQubitGate(G_{1}, {m + 1, m + k + 2})  & ..MultiQubitGate(G_{j}, {m + 1, m + k + 2})..  & MultiQubitGate(G_{n}, {m + 1, m + k + 2})) =>  \\ ( MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
# ...

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{1}{\Big \{} \left\{m + 1, m + k + 2\right\}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{B_{n}{\Big \{} \left\{m + 1, m + k + 2\right\}} \qwx[1]   \\
#   & \gate{D_{1}{\Big \{} \left\{m + 1, m + k + 2\right\}} & \gate{\cdots} & \gate{D_{n}{\Big \{} \left\{m + 1, m + k + 2\right\}}
# } \hspace{2em} \cong \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{F_{1}{\Big \{} \left\{m + 1, m + k + 2\right\}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{F_{n}{\Big \{} \left\{m + 1, m + k + 2\right\}} \qwx[1]   \\
#   & \gate{G_{1}{\Big \{} \left\{m + 1, m + k + 2\right\}} & \gate{\cdots} & \gate{G_{n}{\Big \{} \left\{m + 1, m + k + 2\right\}}
# } \hspace{2em}\right) \Rightarrow  \\ \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1, 1}{\Big \{} S_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{1, n}{\Big \{} S_{1, n}} \qwx[1]   \\
# ...

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ( MultiQubitGate(B_{1}, {m + 1, m + k + 2})  & ..MultiQubitGate(B_{j}, {m + 1, m + k + 2})..  & MultiQubitGate(B_{n}, {m + 1, m + k + 2})   \\
#    MultiQubitGate(D_{1}, {m + 1, m + k + 2})  & ..MultiQubitGate(D_{j}, {m + 1, m + k + 2})..  & MultiQubitGate(D_{n}, {m + 1, m + k + 2}) equiv  MultiQubitGate(F_{1}, {m + 1, m + k + 2})  & ..MultiQubitGate(F_{j}, {m + 1, m + k + 2})..  & MultiQubitGate(F_{n}, {m + 1, m + k + 2})   \\
#    MultiQubitGate(G_{1}, {m + 1, m + k + 2})  & ..MultiQubitGate(G_{j}, {m + 1, m + k + 2})..  & MultiQubitGate(G_{n}, {m + 1, m + k + 2})) =>  \\ ( MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
# ...
