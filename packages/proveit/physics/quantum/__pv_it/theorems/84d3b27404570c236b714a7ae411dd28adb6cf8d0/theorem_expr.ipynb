# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#register_qubit_all_probs">register_qubit_all_probs</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum import register_qubit_all_probs

# %%
# check that the built expression is the same as the stored expression
assert register_qubit_all_probs.expr == stored_expr
assert register_qubit_all_probs.expr._style_id == stored_expr._style_id
print("Passed sanity check: register_qubit_all_probs matches stored_expr")
# Out:
# Passed sanity check: register_qubit_all_probs matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(register_qubit_all_probs.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{\Psi, m~|~\lvert \Psi \rangle \in \left(\mathbb{C}^{2}\right)^{\otimes n}, m = \mathcal{M}(\lvert \Psi \rangle)}~\left(\left(\sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]\right) = 1\right)\right]

# %%
register_qubit_all_probs.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
register_qubit_all_probs.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{Psi, m | |Psi〉 in (Complex^{2})^{otimes n}, m = MEAS(|Psi〉)} ((Sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]) = 1)]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (n -> {forall_{Psi, m | |Psi〉 in (Complex^{2})^{otimes n}, m = MEAS(|Psi〉)} ((Sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]) = 1) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{Psi, m | |Psi〉 in (Complex^{2})^{otimes n}, m = MEAS(|Psi〉)} ((Sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]) = 1) if n in NaturalPos.
#    core type: Lambda
#    parameter: 66
#    body: 3
# 3. {forall_{Psi, m | |Psi〉 in (Complex^{2})^{otimes n}, m = MEAS(|Psi〉)} ((Sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]) = 1) if n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{Psi, m | |Psi〉 in (Complex^{2})^{otimes n}, m = MEAS(|Psi〉)} ((Sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]) = 1)
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. n in NaturalPos
# ...
