# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprRange, ExprTuple, F, G, IndexedVar, h, i, j, k, m, n
from proveit.core_expr_types.expr_arrays import Aij, Cij, Eij, Qij, Rij, Sij
from proveit.logic import Set
from proveit.numbers import Add, one, two
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(Add(m, one), Add(m, k, two))
expr = ExprTuple(ExprArray(ExprRange(i, [ExprRange(j, MultiQubitGate(Aij, Sij), one, n)], one, m), [ExprRange(j, MultiQubitGate(IndexedVar(F, j), sub_expr1), one, n)], ExprRange(i, [ExprRange(j, MultiQubitGate(Cij, Rij), one, n)], one, k), [ExprRange(j, MultiQubitGate(IndexedVar(G, j), sub_expr1), one, n)], ExprRange(i, [ExprRange(j, MultiQubitGate(Eij, Qij), one, n)], one, h)))
# Out:
# expr: ((MultiQubitGate(A_{1, 1}, S_{1, 1}) & ..MultiQubitGate(A_{1, j}, S_{1, j}).. & MultiQubitGate(A_{1, n}, S_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(A_{i, 1}, S_{i, 1}) & ..MultiQubitGate(A_{i, j}, S_{i, j}).. & MultiQubitGate(A_{i, n}, S_{i, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(A_{m, 1}, S_{m, 1}) & ..MultiQubitGate(A_{m, j}, S_{m, j}).. & MultiQubitGate(A_{m, n}, S_{m, n})  \\
#   MultiQubitGate(F_{1}, {m + 1, m + k + 2}) & ..MultiQubitGate(F_{j}, {m + 1, m + k + 2}).. & MultiQubitGate(F_{n}, {m + 1, m + k + 2})  \\
#   MultiQubitGate(C_{1, 1}, R_{1, 1}) & ..MultiQubitGate(C_{1, j}, R_{1, j}).. & MultiQubitGate(C_{1, n}, R_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(C_{i, 1}, R_{i, 1}) & ..MultiQubitGate(C_{i, j}, R_{i, j}).. & MultiQubitGate(C_{i, n}, R_{i, n})  \\
#   \colon & \colon & \colon  \\
# ...

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\begin{array} {ccc}
#  \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1, 1}{\Big \{} S_{1, 1}}
# } \hspace{2em} & \cdots & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1, n}{\Big \{} S_{1, n}}
# } \hspace{2em}  \\
#   \vdots & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{i, j}{\Big \{} S_{i, j}}
# } \hspace{2em} & \vdots  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{m, 1}{\Big \{} S_{m, 1}}
# } \hspace{2em} & \cdots & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{m, n}{\Big \{} S_{m, n}}
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{F_{1}{\Big \{} \left\{m + 1, m + k + 2\right\}}
# } \hspace{2em} & \cdots & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{F_{n}{\Big \{} \left\{m + 1, m + k + 2\right\}}
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{C_{1, 1}{\Big \{} R_{1, 1}}
# } \hspace{2em} & \cdots & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{C_{1, n}{\Big \{} R_{1, n}}
# ...

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((MultiQubitGate(A_{1, 1}, S_{1, 1}) & ..MultiQubitGate(A_{1, j}, S_{1, j}).. & MultiQubitGate(A_{1, n}, S_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(A_{i, 1}, S_{i, 1}) & ..MultiQubitGate(A_{i, j}, S_{i, j}).. & MultiQubitGate(A_{i, n}, S_{i, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(A_{m, 1}, S_{m, 1}) & ..MultiQubitGate(A_{m, j}, S_{m, j}).. & MultiQubitGate(A_{m, n}, S_{m, n})  \\
#   MultiQubitGate(F_{1}, {m + 1, m + k + 2}) & ..MultiQubitGate(F_{j}, {m + 1, m + k + 2}).. & MultiQubitGate(F_{n}, {m + 1, m + k + 2})  \\
#   MultiQubitGate(C_{1, 1}, R_{1, 1}) & ..MultiQubitGate(C_{1, j}, R_{1, j}).. & MultiQubitGate(C_{1, n}, R_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(C_{i, 1}, R_{i, 1}) & ..MultiQubitGate(C_{i, j}, R_{i, j}).. & MultiQubitGate(C_{i, n}, R_{i, n})  \\
#   \colon & \colon & \colon  \\
# ...
