# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, alpha, x
from proveit.linalg import ScalarProd
from proveit.logic import Forall, InSet
from proveit.numbers import Complex
from proveit.physics.quantum import QubitSpace

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(x, Conditional(Forall([alpha], InSet(ScalarProd(alpha, x), QubitSpace), domains = [Complex]), InSet(x, QubitSpace))))
# Out:
# expr: (x -> {forall_{alpha in Complex} ((alpha * x) in Complex^{2}) if x in Complex^{2}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \mapsto \left\{\forall_{\alpha \in \mathbb{C}}~\left(\left(\alpha \thinspace x\right) \in \mathbb{C}^{2}\right) \textrm{ if } x \in \mathbb{C}^{2}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x -> {forall_{alpha in Complex} ((alpha * x) in Complex^{2}) if x in Complex^{2}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. x -> {forall_{alpha in Complex} ((alpha * x) in Complex^{2}) if x in Complex^{2}.
#    core type: Lambda
#    parameter: 22
#    body: 2
# 2. {forall_{alpha in Complex} ((alpha * x) in Complex^{2}) if x in Complex^{2}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{alpha in Complex} ((alpha * x) in Complex^{2})
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. x in Complex^{2}
#    core type: Operation
#    operator: 13
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (alpha -> {(alpha * x) in Complex^{2} if alpha in Complex.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (x, Complex^{2})
#    core type: ExprTuple
#    sub-expressions: 22, 16
# 8. alpha -> {(alpha * x) in Complex^{2} if alpha in Complex.
#    core type: Lambda
#    parameter: 21
#    body: 9
# ...
