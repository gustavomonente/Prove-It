# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import D, IndexedVar, Lambda, S, i
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
expr = Lambda(i, [MultiQubitGate(IndexedVar(D, i), IndexedVar(S, i))])
# Out:
# expr: i -> (MultiQubitGate(D_{i}, S_{i}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# i \mapsto \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{D_{i}{\Big \{} S_{i}}
# } \hspace{2em}\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. i -> (MultiQubitGate(D_{i}, S_{i}))
#    core type: Lambda
#    parameter: 10
#    body: 1
# 1. (MultiQubitGate(D_{i}, S_{i}))
#    core type: ExprTuple
#    sub-expressions: 2
# 2. MultiQubitGate(D_{i}, S_{i})
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. MULTI_QUBIT_GATE
#    core type: Literal
#    sub-expressions:
# 4. (D_{i}, S_{i})
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. D_{i}
#    core type: IndexedVar
# variable: 7
# index: 10
# 6. S_{i}
#    core type: IndexedVar
# variable: 8
# index: 10
# 7. D
#    core type: Variable
#    sub-expressions:
# 8. S
#    core type: Variable
#    sub-expressions:
# 9. (i)
#    core type: ExprTuple
#    sub-expressions: 10
# 10. i
#     core type: Variable
#     sub-expressions:
