# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, ExprArray, ExprRange, ExprTuple, IndexedVar, Lambda, P, Q, R, Variable, g, h, i, j, k, m, n
from proveit.core_expr_types.expr_arrays import Aij, Bij, Cij, D11_to_Dmn, Dij, Pij, Qij, Rij, S11_to_Smn, Sij
from proveit.logic import And, Implies
from proveit.numbers import one
from proveit.physics.quantum.circuit import Circuit, CircuitEquiv, MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Variable("_b", latex_format = r"{_{-}b}")
sub_expr3 = [sub_expr1, sub_expr2]
sub_expr4 = ExprRange(j, MultiQubitGate(Bij, Qij), one, h)
sub_expr5 = ExprRange(j, MultiQubitGate(Dij, Sij), one, n)
sub_expr6 = ExprRange(j, MultiQubitGate(Aij, Pij), one, g)
sub_expr7 = ExprRange(j, MultiQubitGate(Cij, Rij), one, k)
expr = ExprTuple(Lambda([ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(A, sub_expr3), one, g), one, m), ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(B, sub_expr3), one, h), one, m), ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(C, sub_expr3), one, k), one, m), D11_to_Dmn, ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(P, sub_expr3), one, g), one, m), ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(Q, sub_expr3), one, h), one, m), ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(R, sub_expr3), one, k), one, m), S11_to_Smn], Implies(And(CircuitEquiv(Circuit(ExprArray(ExprRange(i, [sub_expr4], one, m))), Circuit(ExprArray(ExprRange(i, [sub_expr5], one, m)))), Circuit(ExprArray(ExprRange(i, [sub_expr6, sub_expr4, sub_expr7], one, m)))), Circuit(ExprArray(ExprRange(i, [sub_expr6, sub_expr5, sub_expr7], one, m)))).with_wrapping_at(2)))
# Out:
# expr: ((A_{1, 1}, ..A_{1, _b}.., A_{1, g}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, g}...., A_{m, 1}, ..A_{m, _b}.., A_{m, g}, B_{1, 1}, ..B_{1, _b}.., B_{1, h}, ....B_{_a, 1}, ..B_{_a, _b}.., B_{_a, h}...., B_{m, 1}, ..B_{m, _b}.., B_{m, h}, C_{1, 1}, ..C_{1, _b}.., C_{1, k}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, k}...., C_{m, 1}, ..C_{m, _b}.., C_{m, k}, D_{1, 1}, ..D_{1, _b}.., D_{1, n}, ....D_{_a, 1}, ..D_{_a, _b}.., D_{_a, n}...., D_{m, 1}, ..D_{m, _b}.., D_{m, n}, P_{1, 1}, ..P_{1, _b}.., P_{1, g}, ....P_{_a, 1}, ..P_{_a, _b}.., P_{_a, g}...., P_{m, 1}, ..P_{m, _b}.., P_{m, g}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, S_{1, 1}, ..S_{1, _b}.., S_{1, n}, ....S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}...., S_{m, 1}, ..S_{m, _b}.., S_{m, n}) -> ((( MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(
# ...

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(A_{1, 1}, \ldots, A_{1, g}, \ldots\ldots, A_{m, 1}, \ldots, A_{m, g}, B_{1, 1}, \ldots, B_{1, h}, \ldots\ldots, B_{m, 1}, \ldots, B_{m, h}, C_{1, 1}, \ldots, C_{1, k}, \ldots\ldots, C_{m, 1}, \ldots, C_{m, k}, D_{1, 1}, \ldots, D_{1, n}, \ldots\ldots, D_{m, 1}, \ldots, D_{m, n}, P_{1, 1}, \ldots, P_{1, g}, \ldots\ldots, P_{m, 1}, \ldots, P_{m, g}, Q_{1, 1}, \ldots, Q_{1, h}, \ldots\ldots, Q_{m, 1}, \ldots, Q_{m, h}, R_{1, 1}, \ldots, R_{1, k}, \ldots\ldots, R_{m, 1}, \ldots, R_{m, k}, S_{1, 1}, \ldots, S_{1, n}, \ldots\ldots, S_{m, 1}, \ldots, S_{m, n}\right) \mapsto \left(\begin{array}{c} \begin{array}{l} \left(\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{1, 1}{\Big \{} Q_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{B_{1, h}{\Big \{} Q_{1, h}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{B_{i, j}{\Big \{} Q_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{B_{m, 1}{\Big \{} Q_{m, 1}} & \gate{\cdots} & \gate{B_{m, h}{\Big \{} Q_{m, h}}
# ...

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((A_{1, 1}, ..A_{1, _b}.., A_{1, g}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, g}...., A_{m, 1}, ..A_{m, _b}.., A_{m, g}, B_{1, 1}, ..B_{1, _b}.., B_{1, h}, ....B_{_a, 1}, ..B_{_a, _b}.., B_{_a, h}...., B_{m, 1}, ..B_{m, _b}.., B_{m, h}, C_{1, 1}, ..C_{1, _b}.., C_{1, k}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, k}...., C_{m, 1}, ..C_{m, _b}.., C_{m, k}, D_{1, 1}, ..D_{1, _b}.., D_{1, n}, ....D_{_a, 1}, ..D_{_a, _b}.., D_{_a, n}...., D_{m, 1}, ..D_{m, _b}.., D_{m, n}, P_{1, 1}, ..P_{1, _b}.., P_{1, g}, ....P_{_a, 1}, ..P_{_a, _b}.., P_{_a, g}...., P_{m, 1}, ..P_{m, _b}.., P_{m, g}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, S_{1, 1}, ..S_{1, _b}.., S_{1, n}, ....S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}...., S_{m, 1}, ..S_{m, _b}.., S_{m, n}) -> ((( MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{
# ...
