# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import D, ExprRange, IndexedVar, S, i, m
from proveit.numbers import one
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
expr = ExprRange(i, [MultiQubitGate(IndexedVar(D, i), IndexedVar(S, i))], one, m)
# Out:
# expr: (MultiQubitGate(D_{1}, S_{1})), ..(MultiQubitGate(D_{i}, S_{i})).., (MultiQubitGate(D_{m}, S_{m}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{D_{1}{\Big \{} S_{1}}
# } \hspace{2em}\right), \ldots, \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{D_{m}{\Big \{} S_{m}}
# } \hspace{2em}\right)

# %%
expr.style_options()
# Out:
# style name: parameterization
# description: 'implicit' (default for LaTeX formatting) hides the parameter the ExprRange so the parameterization may be ambiguous (e.g., x_{1+1}, ..., x_{n+1}); 'explicit' (default for string formatting) reveals the parameterization (e.g. x_{1+1}, ..x_{k+1}.., x_{n+1}).
# default: None
# current value: None/False
# related methods: ('with_explicit_parameterization', 'with_implicit_parameterization', 'with_default_parameterization_style')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (MultiQubitGate(D_{1}, S_{1})), ..(MultiQubitGate(D_{i}, S_{i})).., (MultiQubitGate(D_{m}, S_{m}))
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. i -> (MultiQubitGate(D_{i}, S_{i}))
#    core type: Lambda
#    parameter: 13
#    body: 4
# 2. 1
#    core type: Literal
#    sub-expressions:
# 3. m
#    core type: Variable
#    sub-expressions:
# 4. (MultiQubitGate(D_{i}, S_{i}))
#    core type: ExprTuple
#    sub-expressions: 5
# 5. MultiQubitGate(D_{i}, S_{i})
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. MULTI_QUBIT_GATE
#    core type: Literal
#    sub-expressions:
# 7. (D_{i}, S_{i})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. D_{i}
#    core type: IndexedVar
# variable: 10
# index: 13
# 9. S_{i}
#    core type: IndexedVar
# variable: 11
# index: 13
# 10. D
#     core type: Variable
#     sub-expressions:
# 11. S
#     core type: Variable
#     sub-expressions:
# 12. (i)
#     core type: ExprTuple
#     sub-expressions: 13
# 13. i
#     core type: Variable
#     sub-expressions:
