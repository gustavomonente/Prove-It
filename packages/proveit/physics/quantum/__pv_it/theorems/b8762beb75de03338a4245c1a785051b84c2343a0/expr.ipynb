# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, h, i, j, k, m, n
from proveit.core_expr_types.expr_arrays import Aij, Bij, Cij, Qij, Rij, Sij
from proveit.numbers import one
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
expr = ExprRange(i, [ExprRange(j, MultiQubitGate(Aij, Rij), one, k), ExprRange(j, MultiQubitGate(Bij, Sij), one, n), ExprRange(j, MultiQubitGate(Cij, Qij), one, h)], one, m)
# Out:
# expr: (MultiQubitGate(A_{1, 1}, R_{1, 1}), ..MultiQubitGate(A_{1, j}, R_{1, j}).., MultiQubitGate(A_{1, k}, R_{1, k}), MultiQubitGate(B_{1, 1}, S_{1, 1}), ..MultiQubitGate(B_{1, j}, S_{1, j}).., MultiQubitGate(B_{1, n}, S_{1, n}), MultiQubitGate(C_{1, 1}, Q_{1, 1}), ..MultiQubitGate(C_{1, j}, Q_{1, j}).., MultiQubitGate(C_{1, h}, Q_{1, h})), ..(MultiQubitGate(A_{i, 1}, R_{i, 1}), ..MultiQubitGate(A_{i, j}, R_{i, j}).., MultiQubitGate(A_{i, k}, R_{i, k}), MultiQubitGate(B_{i, 1}, S_{i, 1}), ..MultiQubitGate(B_{i, j}, S_{i, j}).., MultiQubitGate(B_{i, n}, S_{i, n}), MultiQubitGate(C_{i, 1}, Q_{i, 1}), ..MultiQubitGate(C_{i, j}, Q_{i, j}).., MultiQubitGate(C_{i, h}, Q_{i, h})).., (MultiQubitGate(A_{m, 1}, R_{m, 1}), ..MultiQubitGate(A_{m, j}, R_{m, j}).., MultiQubitGate(A_{m, k}, R_{m, k}), MultiQubitGate(B_{m, 1}, S_{m, 1}), ..MultiQubitGate(B_{m, j}, S_{m, j}).., MultiQubitGate(B_{m, n}, S_{m, n}), MultiQubitGate(C_{m, 1}, Q_{m, 1}), ..MultiQubitGate(C_{m, j}, Q_{m, j}).., MultiQubitG
# ...

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1, 1}{\Big \{} R_{1, 1}}
# } \hspace{2em}, \ldots, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1, k}{\Big \{} R_{1, k}}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{1, 1}{\Big \{} S_{1, 1}}
# } \hspace{2em}, \ldots, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{1, n}{\Big \{} S_{1, n}}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{C_{1, 1}{\Big \{} Q_{1, 1}}
# } \hspace{2em}, \ldots, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{C_{1, h}{\Big \{} Q_{1, h}}
# } \hspace{2em}\right), \ldots, \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{m, 1}{\Big \{} R_{m, 1}}
# } \hspace{2em}, \ldots, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{m, k}{\Big \{} R_{m, k}}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{m, 1}{\Big \{} S_{m, 1}}
# } \hspace{2em}, \ldots, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{m, n}{\Big \{} S_{m, n}}
# ...

# %%
expr.style_options()
# Out:
# style name: parameterization
# description: 'implicit' (default for LaTeX formatting) hides the parameter the ExprRange so the parameterization may be ambiguous (e.g., x_{1+1}, ..., x_{n+1}); 'explicit' (default for string formatting) reveals the parameterization (e.g. x_{1+1}, ..x_{k+1}.., x_{n+1}).
# default: None
# current value: None/False
# related methods: ('with_explicit_parameterization', 'with_implicit_parameterization', 'with_default_parameterization_style')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (MultiQubitGate(A_{1, 1}, R_{1, 1}), ..MultiQubitGate(A_{1, j}, R_{1, j}).., MultiQubitGate(A_{1, k}, R_{1, k}), MultiQubitGate(B_{1, 1}, S_{1, 1}), ..MultiQubitGate(B_{1, j}, S_{1, j}).., MultiQubitGate(B_{1, n}, S_{1, n}), MultiQubitGate(C_{1, 1}, Q_{1, 1}), ..MultiQubitGate(C_{1, j}, Q_{1, j}).., MultiQubitGate(C_{1, h}, Q_{1, h})), ..(MultiQubitGate(A_{i, 1}, R_{i, 1}), ..MultiQubitGate(A_{i, j}, R_{i, j}).., MultiQubitGate(A_{i, k}, R_{i, k}), MultiQubitGate(B_{i, 1}, S_{i, 1}), ..MultiQubitGate(B_{i, j}, S_{i, j}).., MultiQubitGate(B_{i, n}, S_{i, n}), MultiQubitGate(C_{i, 1}, Q_{i, 1}), ..MultiQubitGate(C_{i, j}, Q_{i, j}).., MultiQubitGate(C_{i, h}, Q_{i, h})).., (MultiQubitGate(A_{m, 1}, R_{m, 1}), ..MultiQubitGate(A_{m, j}, R_{m, j}).., MultiQubitGate(A_{m, k}, R_{m, k}), MultiQubitGate(B_{m, 1}, S_{m, 1}), ..MultiQubitGate(B_{m, j}, S_{m, j}).., MultiQubitGate(B_{m, n}, S_{m, n}), MultiQubitGate(C_{m, 1}, Q_{m, 1}), ..MultiQubitGate(C_{m, j}, Q_{m, j}).., MultiQubitGate
# ...
