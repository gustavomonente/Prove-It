# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, ExprRange, IndexedVar, Lambda, Variable, g
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Variable("_b", latex_format = r"{_{-}b}")
expr = Lambda(sub_expr1, ExprRange(sub_expr2, IndexedVar(A, [sub_expr1, sub_expr2]), one, g))
# Out:
# expr: _a -> A_{_a, 1}, ..A_{_a, _b}.., A_{_a, g}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# {_{-}a} \mapsto A_{{_{-}a}, 1}, \ldots, A_{{_{-}a}, g}

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. _a -> A_{_a, 1}, ..A_{_a, _b}.., A_{_a, g}
#    core type: Lambda
#    parameter: 8
#    body: 1
# 1. A_{_a, 1}, ..A_{_a, _b}.., A_{_a, g}
#    core type: ExprRange
#    lambda_map: 2
#    start_index: 3
#    end_index: 4
# 2. _b -> A_{_a, _b}
#    core type: Lambda
#    parameter: 9
#    body: 5
# 3. 1
#    core type: Literal
#    sub-expressions:
# 4. g
#    core type: Variable
#    sub-expressions:
# 5. A_{_a, _b}
#    core type: IndexedVar
# variable: 6
# indices: 7
# 6. A
#    core type: Variable
#    sub-expressions:
# 7. (_a, _b)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. _a
#    core type: Variable
#    sub-expressions:
# 9. _b
#    core type: Variable
#    sub-expressions:
