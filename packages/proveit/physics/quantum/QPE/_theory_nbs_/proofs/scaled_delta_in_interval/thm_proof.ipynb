# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#scaled_delta_in_interval">scaled_delta_in_interval</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import a, b, c, x, defaults, ExprTuple
from proveit.logic import Equals, InSet, NotEquals
from proveit.numbers import Add, frac, Mult, Neg
from proveit.numbers import zero, Complex, Real
from proveit.numbers.rounding import real_minus_floor_interval
from proveit.physics.quantum.QPE import best_def, b_, delta_def, delta_is_real, two_pow_t, phase_
from proveit.physics.quantum.QPE import best_is_int, phase_in_interval, phase_is_real, two_pow_t_is_nat_pos

# %%
# %proving scaled_delta_in_interval
# Out:
# scaled_delta_in_interval: (2^{t} * delta) in [0,1)

# %% [markdown]
# The proof utilizes the chain of equalities $2^t\cdot \delta = 2^t \left(\varphi - \frac{b}{2^t}\right) = 2^t \left(\varphi - \frac{\lfloor\varphi\cdot 2^t\rfloor}{2^t}\right) = \varphi \cdot 2^t - \lfloor\varphi\cdot 2^t\rfloor$, then calls upon a theorem for the value of an expression of the form $x - \lfloor x \rfloor$.

# %%
scaled_delta = scaled_delta_in_interval.operands[0]
# Out:
# scaled_delta: 2^{t} * delta

# %%
delta_def
# Out:
# |- delta = (phase - (b / 2^{t}))

# %%
eq_01 = delta_def.substitution(scaled_delta)
# Out:
# eq_01: |- (2^{t} * delta) = (2^{t} * (phase - (b / 2^{t})))

# %%
scaled_delta_expanded_dist = eq_01.rhs.distribution(1)
# Out:
# scaled_delta_expanded_dist: |- (2^{t} * (phase - (b / 2^{t}))) = ((2^{t} * phase) + (2^{t} * (-(b / 2^{t}))))

# %%
simplification_01 = scaled_delta_expanded_dist.operands[1].operands[1].simplification()
# Out:
# simplification_01: |- (2^{t} * (-(b / 2^{t}))) = (-b)

# %%
simplification_02 = simplification_01.substitution(scaled_delta_expanded_dist.rhs)
# Out:
# simplification_02: |- ((2^{t} * phase) + (2^{t} * (-(b / 2^{t})))) = ((2^{t} * phase) - b)

# %%
best_def
# Out:
# |- b = floor(phase * 2^{t})

# %%
floor_expr_commuted = best_def.rhs.operands[0].commutation().substitution(best_def.rhs)
# Out:
# floor_expr_commuted: |- floor(phase * 2^{t}) = floor(2^{t} * phase)

# %%
best_def_commuted = best_def.apply_transitivity(floor_expr_commuted)
# Out:
# best_def_commuted: |- b = floor(2^{t} * phase)

# %%
simplification_03 = best_def_commuted.substitution(simplification_02.rhs)
# Out:
# simplification_03: |- ((2^{t} * phase) - b) = ((2^{t} * phase) - floor(2^{t} * phase))

# %%
eq_02 = Equals.apply_transitivities([eq_01, scaled_delta_expanded_dist, simplification_02, simplification_03])
# Out:
# eq_02: |- (2^{t} * delta) = ((2^{t} * phase) - floor(2^{t} * phase))

# %% [markdown]
# $(2^t\cdot\delta)$ has now been expressed in the form $x - \lfloor x \rfloor$, and we have a theorem for the value of such an expression:

# %%
real_minus_floor_interval
# Out:
# |- forall_{x in Real} ((x - floor(x)) in [0,1))

# %% [markdown]
# We need to show that our eventual argument $x = 2^t\cdot\delta$ is Real, then instantiate our theorem:

# %%
phase_is_real
# Out:
# |- phase in Real

# %%
InSet(Mult(two_pow_t, phase_), Real).prove()
# Out:
# |- (2^{t} * phase) in Real

# %%
interval_claim = real_minus_floor_interval.instantiate({x:Mult(two_pow_t, phase_)})
# Out:
# interval_claim: |- ((2^{t} * phase) - floor(2^{t} * phase)) in [0,1)

# %%
eq_02.sub_left_side_into(interval_claim)
# Out:
# scaled_delta_in_interval has been proven.  Now simply execute "%qed".
# |- (2^{t} * delta) in [0,1)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	instantiation	1, 2, 3	|- (2^{t} * delta) in [0,1)
# 	P(_a) : _a in [0,1), x : 2^{t} * delta, y : (2^{t} * phase) - floor(2^{t} * phase)
# 1	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 2	instantiation	4, 5	|- ((2^{t} * phase) - floor(2^{t} * phase)) in [0,1)
# 	x : 2^{t} * phase
# 3	instantiation	56, 6, 7	|- (2^{t} * delta) = ((2^{t} * phase) - floor(2^{t} * phase))
# 	x : 2^{t} * delta, y : (2^{t} * phase) - b, z : (2^{t} * phase) - floor(2^{t} * phase)
# 4	conjecture		|- forall_{x in Real} ((x - floor(x)) in [0,1))
# 5	instantiation	8, 73, 39	|- (2^{t} * phase) in Real
# 	a : 2^{t}, b : phase
# 6	instantiation	56, 9, 10	|- (2^{t} * delta) = ((2^{t} * phase) - b)
# 	x : 2^{t} * delta, y : (2^{t} * phase) + (2^{t} * (-(b / 2^{t}))), z : (2^{t} * phase) - b
# 7	instantiation	62, 11	|- ((2^{t} * phase) - b) = ((2^{t} * phase) - floor(2^{t} * phase))
# 	f(_a) : (2^{t} * phase) - _a, x : b, y : floor(2^{t} * phase)
# 8	conjecture		|- forall_{a, b in Real} ((a * b) in Real)
# 9	instantiation	56, 12, 13	|- (2^{t} * delta) = ((2^{t} * phase) + (2^{t} * (-(b / 2^{t}))))
# 	x : 2^{t} * delta, y : 2^{t} * (phase - (b / 2^{t})), z : (2^{t} * phase) + (2^{t} * (-(b / 2^{t})))
# 10	instantiation	62, 14	|- ((2^{t} * phase) + (2^{t} * (-(b / 2^{t})))) = ((2^{t} * phase) - b)
# 	f(_a) : (2^{t} * phase) + _a, x : 2^{t} * (-(b / 2^{t})), y : -b
# 11	instantiation	56, 15, 16	|- b = floor(2^{t} * phase)
# 	x : b, y : floor(phase * 2^{t}), z : floor(2^{t} * phase)
# 12	instantiation	62, 17	|- (2^{t} * delta) = (2^{t} * (phase - (b / 2^{t})))
# 	f(_a) : 2^{t} * _a, x : delta, y : phase - (b / 2^{t})
# 13	instantiation	18, 78, 19, 20, 21, 22, 23, 69, 35, 24	|- (2^{t} * (phase - (b / 2^{t}))) = ((2^{t} * phase) + (2^{t} * (-(b / 2^{t}))))
# 	i : 1, j : 2, k : 0, a : (2^{t}), b : (phase, -(b / 2^{t})), c : ()
# 14	instantiation	56, 25, 26	|- (2^{t} * (-(b / 2^{t}))) = (-b)
# 	x : 2^{t} * (-(b / 2^{t})), y : -(2^{t} * (b / 2^{t})), z : -b
# 15	axiom		|- b = floor(phase * 2^{t})
# 	proveit.physics.quantum.QPE.best_def
# 16	instantiation	62, 27	|- floor(phase * 2^{t}) = floor(2^{t} * phase)
# 	f(_a) : floor(_a), x : phase * 2^{t}, y : 2^{t} * phase
# 17	axiom		|- delta = (phase - (b / 2^{t}))
# 	proveit.physics.quantum.QPE.delta_def
# 18	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * (b_{1} + ..b_{_a}.. + b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ ((a_{1} * ..a_{_a}.. * a_{i} * b_{1} * c_{1} * ..c_{_a}.. * c_{k}) + ..(a_{1} * ..a_{_a}.. * a_{i} * b_{n} * c_{1} * ..c_{_a}.. * c_{k}).. + (a_{1} * ..a_{_a}.. * a_{i} * b_{j} * c_{1} * ..c_{_a}.. * c_{k})))]
# 19	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 20	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 21	instantiation	28	|- |(2^{t})| = |(1, ..k.., 1)|
# 	a : 2^{t}
# 22	instantiation	29	|- |(phase, -(b / 2^{t}))| = |(1, ..k.., 2)|
# 	a : phase, b : -(b / 2^{t})
# 23	conjecture		|- |()| = |(1, ..a.., 0)|
# 24	instantiation	30, 32	|- (-(b / 2^{t})) in Complex
# 	a : b / 2^{t}
# 25	instantiation	31, 69, 32	|- (2^{t} * (-(b / 2^{t}))) = (-(2^{t} * (b / 2^{t})))
# 	x : 2^{t}, y : b / 2^{t}
# 26	instantiation	62, 33	|- (-(2^{t} * (b / 2^{t}))) = (-b)
# 	f(_a) : -_a, x : 2^{t} * (b / 2^{t}), y : b
# 27	instantiation	34, 35, 69	|- (phase * 2^{t}) = (2^{t} * phase)
# 	a : phase, b : 2^{t}
# 28	conjecture		|- forall_{a} (|(a)| = |(1, ..k.., 1)|)
# 29	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..k.., 2)|)
# 30	conjecture		|- forall_{a in Complex} ((-a) in Complex)
# 31	conjecture		|- forall_{x, y in Complex} ((x * (-y)) = (-(x * y)))
# 32	instantiation	36, 61, 69, 46	|- (b / 2^{t}) in Complex
# 	a : b, b : 2^{t}
# 33	instantiation	40, 37, 38	|- (2^{t} * (b / 2^{t})) = b
# 	P(_a) : (2^{t} * (b / 2^{t})) = _a, x : (1 / 1) * (b / 1), y : b
# 34	conjecture		|- forall_{a, b in Complex} ((a * b) = (b * a))
# 35	instantiation	83, 72, 39	|- phase in Complex
# 	A : Real, B : Complex, x : phase
# 36	conjecture		|- forall_{a, b in Complex | b != 0} ((a / b) in Complex)
# 37	instantiation	40, 41, 42	|- (2^{t} * (b / 2^{t})) = ((1 / 1) * (b / 1))
# 	P(_a) : _a = ((1 / 1) * (b / 1)), x : ((1 * 2^{t}) / 1) * (b / (2^{t} * 1)), y : 2^{t} * (b / 2^{t})
# 38	instantiation	56, 43, 44	|- ((1 / 1) * (b / 1)) = b
# 	x : (1 / 1) * (b / 1), y : 1 * b, z : b
# 39	conjecture		|- phase in Real
# 40	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 41	instantiation	45, 60, 69, 61, 46	|- (((1 * 2^{t}) / 1) * (b / (2^{t} * 1))) = ((1 / 1) * (b / 1))
# 	a : 1, b : 2^{t}, c : 1, d : b, e : 1
# 42	instantiation	56, 47, 48	|- (((1 * 2^{t}) / 1) * (b / (2^{t} * 1))) = (2^{t} * (b / 2^{t}))
# 	x : ((1 * 2^{t}) / 1) * (b / (2^{t} * 1)), y : 2^{t} * (b / (2^{t} * 1)), z : 2^{t} * (b / 2^{t})
# 43	instantiation	56, 49, 50	|- ((1 / 1) * (b / 1)) = (1 * b)
# 	x : (1 / 1) * (b / 1), y : 1 * (b / 1), z : 1 * b
# 44	instantiation	68, 61	|- (1 * b) = b
# 	x : b
# 45	conjecture		|- forall_{a, b, c, d, e in Complex | b != 0} ((((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e)))
# 46	instantiation	51, 85	|- 2^{t} != 0
# 	n : 2^{t}
# 47	instantiation	62, 52	|- (((1 * 2^{t}) / 1) * (b / (2^{t} * 1))) = (2^{t} * (b / (2^{t} * 1)))
# 	f(_a) : _a * (b / (2^{t} * 1)), x : (1 * 2^{t}) / 1, y : 2^{t}
# 48	instantiation	62, 53	|- (2^{t} * (b / (2^{t} * 1))) = (2^{t} * (b / 2^{t}))
# 	f(_a) : 2^{t} * _a, x : b / (2^{t} * 1), y : b / 2^{t}
# 49	instantiation	62, 54	|- ((1 / 1) * (b / 1)) = (1 * (b / 1))
# 	f(_a) : _a * (b / 1), x : 1 / 1, y : 1
# 50	instantiation	62, 55	|- (1 * (b / 1)) = (1 * b)
# 	f(_a) : 1 * _a, x : b / 1, y : b
# 51	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 52	instantiation	56, 57, 58	|- ((1 * 2^{t}) / 1) = 2^{t}
# 	x : (1 * 2^{t}) / 1, y : 2^{t} / 1, z : 2^{t}
# 53	instantiation	62, 59	|- (b / (2^{t} * 1)) = (b / 2^{t})
# 	f(_a) : b / _a, x : 2^{t} * 1, y : 2^{t}
# 54	instantiation	64, 60	|- (1 / 1) = 1
# 	x : 1
# 55	instantiation	64, 61	|- (b / 1) = b
# 	x : b
# 56	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 57	instantiation	62, 63	|- ((1 * 2^{t}) / 1) = (2^{t} / 1)
# 	f(_a) : _a / 1, x : 1 * 2^{t}, y : 2^{t}
# 58	instantiation	64, 69	|- (2^{t} / 1) = 2^{t}
# 	x : 2^{t}
# 59	instantiation	65, 69	|- (2^{t} * 1) = 2^{t}
# 	x : 2^{t}
# 60	instantiation	83, 72, 66	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 61	instantiation	83, 72, 67	|- b in Complex
# 	A : Real, B : Complex, x : b
# 62	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 63	instantiation	68, 69	|- (1 * 2^{t}) = 2^{t}
# 	x : 2^{t}
# 64	conjecture		|- forall_{x in Complex} ((x / 1) = x)
# 65	conjecture		|- forall_{x in Complex} ((x * 1) = x)
# 66	instantiation	83, 76, 70	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 67	instantiation	83, 76, 71	|- b in Real
# 	A : Rational, B : Real, x : b
# 68	conjecture		|- forall_{x in Complex} ((1 * x) = x)
# 69	instantiation	83, 72, 73	|- 2^{t} in Complex
# 	A : Real, B : Complex, x : 2^{t}
# 70	instantiation	83, 79, 74	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 71	instantiation	83, 79, 75	|- b in Rational
# 	A : Integer, B : Rational, x : b
# 72	conjecture		|- Real proper_subset Complex
# 73	instantiation	83, 76, 77	|- 2^{t} in Real
# 	A : Rational, B : Real, x : 2^{t}
# 74	instantiation	83, 81, 78	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 75	conjecture		|- b in Integer
# 76	conjecture		|- Rational proper_subset Real
# 77	instantiation	83, 79, 80	|- 2^{t} in Rational
# 	A : Integer, B : Rational, x : 2^{t}
# 78	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 79	conjecture		|- Integer proper_subset Rational
# 80	instantiation	83, 81, 82	|- 2^{t} in Integer
# 	A : Natural, B : Integer, x : 2^{t}
# 81	conjecture		|- Natural proper_subset Integer
# 82	instantiation	83, 84, 85	|- 2^{t} in Natural
# 	A : NaturalPos, B : Natural, x : 2^{t}
# 83	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 84	conjecture		|- NaturalPos proper_subset Natural
# 85	conjecture		|- 2^{t} in NaturalPos
