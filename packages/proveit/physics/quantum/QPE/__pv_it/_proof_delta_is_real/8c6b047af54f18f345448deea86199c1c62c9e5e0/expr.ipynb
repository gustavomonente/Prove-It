# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.numbers import Add, Neg, Real, frac
from proveit.physics.quantum.QPE import b_, phase_, two_pow_t

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(phase_, Neg(frac(b_, two_pow_t))), Real)
# Out:
# expr: (phase - (b / 2^{t}), Real)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\varphi - \frac{b}{2^{t}}, \mathbb{R}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (phase - (b / 2^{t}), Real)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. phase - (b / 2^{t})
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. Real
#    core type: Literal
#    sub-expressions:
# 3. +
#    core type: Literal
#    sub-expressions:
# 4. (phase, -(b / 2^{t}))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. phase
#    core type: Literal
#    sub-expressions:
# 6. -(b / 2^{t})
#    core type: Operation
#    operator: 7
#    operand: 9
# 7. -
#    core type: Literal
#    sub-expressions:
# 8. (b / 2^{t})
#    core type: ExprTuple
#    sub-expressions: 9
# 9. b / 2^{t}
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. /
#     core type: Literal
#     sub-expressions:
# 11. (b, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. b
#     core type: Literal
#     sub-expressions:
# 13. 2^{t}
#     core type: Operation
#     operator: 14
#     operands: 15
# 14. Exp
#     core type: Literal
#     sub-expressions:
# 15. (2, t)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. 2
#     core type: Literal
#     sub-expressions:
# 17. t
#     core type: Literal
#     sub-expressions:
