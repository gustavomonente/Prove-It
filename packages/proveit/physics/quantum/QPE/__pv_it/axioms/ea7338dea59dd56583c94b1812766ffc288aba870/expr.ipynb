# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprArray, ExprTuple, Lambda, k
from proveit.logic import InSet, Set
from proveit.numbers import NaturalPos, one, three, two
from proveit.physics.quantum import CONTROL, Hgate, Input, Ket, Output, SPACE, ket0
from proveit.physics.quantum.QPE import U_pow_two_pow_k, psi_k, psi_next, u_
from proveit.physics.quantum.circuit import Circuit, IdentityOp, MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(two, three)
sub_expr2 = Ket(u_)
sub_expr3 = MultiQubitGate(IdentityOp(), Set(one, two))
expr = ExprTuple(Lambda(k, Conditional(Circuit(ExprArray([Input(Ket(psi_k)), IdentityOp(), IdentityOp(), sub_expr3, SPACE, SPACE], [Input(ket0), Hgate, MultiQubitGate(CONTROL, sub_expr1), sub_expr3, IdentityOp(), Output(Ket(psi_next))], [Input(sub_expr2), IdentityOp(), MultiQubitGate(U_pow_two_pow_k, sub_expr1), Output(sub_expr2), SPACE, SPACE])), InSet(k, NaturalPos))))
# Out:
# expr: (k -> { Input(|psi_{k}〉)  & --  & --  & MultiQubitGate(I, {1, 2})  & SPACE  & SPACE   \\
#    Input(|0〉)  & Gate(H)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(I, {1, 2})  & --  & Output(|psi_{k + 1}〉)   \\
#    Input(|u〉)  & --  & MultiQubitGate(U^{2^{k}}, {2, 3})  & Output(|u〉)  & SPACE  & SPACE if k in NaturalPos.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(k \mapsto \left\{\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert \psi_{k} \rangle} & \qw & \qw & \multigate{1}{I}   \\
#   & \lstick{\lvert 0 \rangle} & \gate{H} & \control \qw \qwx[1] & \ghost{I} & \qw & \rstick{\lvert \psi_{k + 1} \rangle} \qw   \\
#   & \lstick{\lvert u \rangle} & \qw & \gate{U^{2^{k}}} & \rstick{\lvert u \rangle} \qw
# } \hspace{2em} \textrm{ if } k \in \mathbb{N}^+\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (k -> { Input(|psi_{k}〉)  & --  & --  & MultiQubitGate(I, {1, 2})  & SPACE  & SPACE   \\
#    Input(|0〉)  & Gate(H)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(I, {1, 2})  & --  & Output(|psi_{k + 1}〉)   \\
#    Input(|u〉)  & --  & MultiQubitGate(U^{2^{k}}, {2, 3})  & Output(|u〉)  & SPACE  & SPACE if k in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. k -> { Input(|psi_{k}〉)  & --  & --  & MultiQubitGate(I, {1, 2})  & SPACE  & SPACE   \\
#    Input(|0〉)  & Gate(H)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(I, {1, 2})  & --  & Output(|psi_{k + 1}〉)   \\
#    Input(|u〉)  & --  & MultiQubitGate(U^{2^{k}}, {2, 3})  & Output(|u〉)  & SPACE  & SPACE if k in NaturalPos.
#    core type: Lambda
#    parameter: 72
#    body: 2
# 2. { Input(|psi_{k}〉)  & --  & --  & MultiQubitGate(I, {1, 2})  & SPACE  & SPACE   \\
#    Input(|0〉)  & Gate(H)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(I, {1, 2})  & --  & Output(|psi_{k + 1}〉)   \\
#    Input(|u〉)  & --  & MultiQubitGate(U^{2^{k}}, {2, 3})  & Output(|u〉)  & SPACE  & SPACE if k in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3.  Input(|psi_{k}〉)  & --  & --  & MultiQubitGate(I, {1, 2})  & SPACE  & SPACE   \\
#    Input(|0〉)  & Gate(H)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(I, {1, 2})  & --  & Output(|psi_{k + 1}〉)   \\
#    Input(|u〉)  & --  & MultiQubitGate(U^{2^{k}}, {2, 3})  & Output(|u〉)  & SPACE  & SPACE
#    core type: Operation
#    operator: 5
#    operand: 9
# 4. k in NaturalPos
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. CIRCUIT
#    core type: Literal
#    sub-expressions:
# 6. ((Input(|psi_{k}〉) & -- & -- & MultiQubitGate(I, {1, 2}) & SPACE & SPACE  \\
#   Input(|0〉) & Gate(H) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(I, {1, 2}) & -- & Output(|psi_{k + 1}〉)  \\
#   Input(|u〉) & -- & MultiQubitGate(U^{2^{k}}, {2, 3}) & Output(|u〉) & SPACE & SPACE))
#    core type: ExprTuple
#    sub-expressions: 9
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (k, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 72, 10
# 9. Input(|psi_{k}〉) & -- & -- & MultiQubitGate(I, {1, 2}) & SPACE & SPACE  \\
#   Input(|0〉) & Gate(H) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(I, {1, 2}) & -- & Output(|psi_{k + 1}〉)  \\
#   Input(|u〉) & -- & MultiQubitGate(U^{2^{k}}, {2, 3}) & Output(|u〉) & SPACE & SPACE
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. (Input(|psi_{k}〉), --, --, MultiQubitGate(I, {1, 2}), SPACE, SPACE)
#     core type: ExprTuple
#     sub-expressions: 14, 40, 40, 18, 23, 23
# 12. (Input(|0〉), Gate(H), MultiQubitGate(CONTROL, {2, 3}), MultiQubitGate(I, {1, 2}), --, Output(|psi_{k + 1}〉))
#     core type: ExprTuple
#     sub-expressions: 15, 16, 17, 18, 40, 19
# 13. (Input(|u〉), --, MultiQubitGate(U^{2^{k}}, {2, 3}), Output(|u〉), SPACE, SPACE)
#     core type: ExprTuple
#     sub-expressions: 20, 40, 21, 22, 23, 23
# 14. Input(|psi_{k}〉)
#     core type: Operation
#     operator: 31
#     operand: 36
# 15. Input(|0〉)
#     core type: Operation
#     operator: 31
#     operand: 37
# 16. Gate(H)
#     core type: Operation
#     operator: 26
#     operand: 38
# 17. MultiQubitGate(CONTROL, {2, 3})
#     core type: Operation
#     operator: 32
#     operands: 28
# 18. MultiQubitGate(I, {1, 2})
#     core type: Operation
#     operator: 32
#     operands: 29
# 19. Output(|psi_{k + 1}〉)
#     core type: Operation
#     operator: 34
#     operand: 42
# 20. Input(|u〉)
#     core type: Operation
#     operator: 31
#     operand: 45
# 21. MultiQubitGate(U^{2^{k}}, {2, 3})
#     core type: Operation
#     operator: 32
#     operands: 33
# 22. Output(|u〉)
#     core type: Operation
#     operator: 34
#     operand: 45
# 23. SPACE
#     core type: Literal
#     sub-expressions:
# 24. (|psi_{k}〉)
#     core type: ExprTuple
#     sub-expressions: 36
# 25. (|0〉)
#     core type: ExprTuple
#     sub-expressions: 37
# 26. GATE
#     core type: Literal
#     sub-expressions:
# 27. (H)
#     core type: ExprTuple
#     sub-expressions: 38
# 28. (CONTROL, {2, 3})
#     core type: ExprTuple
#     sub-expressions: 39, 44
# 29. (--, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 30. (|psi_{k + 1}〉)
#     core type: ExprTuple
#     sub-expressions: 42
# 31. INPUT
#     core type: Literal
#     sub-expressions:
# 32. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 33. (U^{2^{k}}, {2, 3})
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 34. OUTPUT
#     core type: Literal
#     sub-expressions:
# 35. (|u〉)
#     core type: ExprTuple
#     sub-expressions: 45
# 36. |psi_{k}〉
#     core type: Operation
#     operator: 53
#     operand: 55
# 37. |0〉
#     core type: Operation
#     operator: 53
#     operand: 56
# 38. H
#     core type: Literal
#     sub-expressions:
# 39. CONTROL
#     core type: Literal
#     sub-expressions:
# 40. --
#     core type: Literal
#     sub-expressions:
# 41. {1, 2}
#     core type: Operation
#     operator: 51
#     operands: 48
# 42. |psi_{k + 1}〉
#     core type: Operation
#     operator: 53
#     operand: 57
# 43. U^{2^{k}}
#     core type: Operation
#     operator: 65
#     operands: 50
# 44. {2, 3}
#     core type: Operation
#     operator: 51
#     operands: 52
# 45. |u〉
#     core type: Operation
#     operator: 53
#     operand: 61
# 46. (psi_{k})
#     core type: ExprTuple
#     sub-expressions: 55
# 47. (0)
#     core type: ExprTuple
#     sub-expressions: 56
# 48. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 73, 69
# 49. (psi_{k + 1})
#     core type: ExprTuple
#     sub-expressions: 57
# 50. (U, 2^{k})
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 51. Set
#     core type: Literal
#     sub-expressions:
# 52. (2, 3)
#     core type: ExprTuple
#     sub-expressions: 69, 60
# 53. KET
#     core type: Literal
#     sub-expressions:
# 54. (u)
#     core type: ExprTuple
#     sub-expressions: 61
# 55. psi_{k}
#     core type: Operation
#     operator: 63
#     operands: 62
# 56. 0
#     core type: Literal
#     sub-expressions:
# 57. psi_{k + 1}
#     core type: Operation
#     operator: 63
#     operands: 64
# 58. U
#     core type: Literal
#     sub-expressions:
# 59. 2^{k}
#     core type: Operation
#     operator: 65
#     operands: 66
# 60. 3
#     core type: Literal
#     sub-expressions:
# 61. u
#     core type: Literal
#     sub-expressions:
# 62. (psi, k)
#     core type: ExprTuple
#     sub-expressions: 67, 72
# 63. SUB_INDEXED
#     core type: Literal
#     sub-expressions:
# 64. (psi, k + 1)
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 65. Exp
#     core type: Literal
#     sub-expressions:
# 66. (2, k)
#     core type: ExprTuple
#     sub-expressions: 69, 72
# 67. psi
#     core type: Literal
#     sub-expressions:
# 68. k + 1
#     core type: Operation
#     operator: 70
#     operands: 71
# 69. 2
#     core type: Literal
#     sub-expressions:
# 70. +
#     core type: Literal
#     sub-expressions:
# 71. (k, 1)
#     core type: ExprTuple
#     sub-expressions: 72, 73
# 72. k
#     core type: Variable
#     sub-expressions:
# 73. 1
#     core type: Literal
#     sub-expressions:
