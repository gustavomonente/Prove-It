# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#mid_q_p_e">mid_q_p_e</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.QPE import mid_q_p_e

# %%
# check that the built expression is the same as the stored expression
assert mid_q_p_e.expr == stored_expr
assert mid_q_p_e.expr._style_id == stored_expr._style_id
print("Passed sanity check: mid_q_p_e matches stored_expr")
# Out:
# Passed sanity check: mid_q_p_e matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(mid_q_p_e.latex())
# Out:
# \vdash \forall_{k \in \mathbb{N}^+}~\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert \psi_{k} \rangle} & \qw & \qw & \multigate{1}{I}   \\
#   & \lstick{\lvert 0 \rangle} & \gate{H} & \control \qw \qwx[1] & \ghost{I} & \qw & \rstick{\lvert \psi_{k + 1} \rangle} \qw   \\
#   & \lstick{\lvert u \rangle} & \qw & \gate{U^{2^{k}}} & \rstick{\lvert u \rangle} \qw
# } \hspace{2em}

# %%
mid_q_p_e.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
mid_q_p_e.expr_info()
# Out:
# 0. forall_{k in NaturalPos}  Input(|psi_{k}〉)  & --  & --  & MultiQubitGate(I, {1, 2})  & SPACE  & SPACE   \\
#    Input(|0〉)  & Gate(H)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(I, {1, 2})  & --  & Output(|psi_{k + 1}〉)   \\
#    Input(|u〉)  & --  & MultiQubitGate(U^{2^{k}}, {2, 3})  & Output(|u〉)  & SPACE  & SPACE
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (k -> { Input(|psi_{k}〉)  & --  & --  & MultiQubitGate(I, {1, 2})  & SPACE  & SPACE   \\
#    Input(|0〉)  & Gate(H)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(I, {1, 2})  & --  & Output(|psi_{k + 1}〉)   \\
#    Input(|u〉)  & --  & MultiQubitGate(U^{2^{k}}, {2, 3})  & Output(|u〉)  & SPACE  & SPACE if k in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. k -> { Input(|psi_{k}〉)  & --  & --  & MultiQubitGate(I, {1, 2})  & SPACE  & SPACE   \\
# ...
