# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, l
from proveit.linalg import MatrixProd
from proveit.logic import Equals, InSet
from proveit.numbers import Integer
from proveit.physics.quantum import Ket, RegisterBra
from proveit.physics.quantum.QPE import ModAdd, Psi_, alpha_l, b_, t_

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(l, Conditional(Equals(alpha_l, MatrixProd(RegisterBra(ModAdd(b_, l), t_), Ket(Psi_))), InSet(l, Integer))))
# Out:
# expr: (l -> {alpha_{l} = {t}_〈b MOD_ADD l|Psi〉 if l in Integer.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(l \mapsto \left\{\alpha_{l} = {_{t}}\langle b \oplus l \rvert\Psi \rangle \textrm{ if } l \in \mathbb{Z}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (l -> {alpha_{l} = {t}_〈b MOD_ADD l|Psi〉 if l in Integer.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. l -> {alpha_{l} = {t}_〈b MOD_ADD l|Psi〉 if l in Integer.
#    core type: Lambda
#    parameter: 29
#    body: 2
# 2. {alpha_{l} = {t}_〈b MOD_ADD l|Psi〉 if l in Integer.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. alpha_{l} = {t}_〈b MOD_ADD l|Psi〉
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. l in Integer
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (alpha_{l}, {t}_〈b MOD_ADD l|Psi〉)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (l, Integer)
#    core type: ExprTuple
#    sub-expressions: 29, 11
# 9. alpha_{l}
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. {t}_〈b MOD_ADD l| . |Psi〉
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. Integer
#     core type: Literal
#     sub-expressions:
# 12. SUB_INDEXED
#     core type: Literal
#     sub-expressions:
# 13. (alpha, l)
#     core type: ExprTuple
#     sub-expressions: 16, 29
# 14. .
#     core type: Literal
#     sub-expressions:
# 15. ({t}_〈b MOD_ADD l|, |Psi〉)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. alpha
#     core type: Literal
#     sub-expressions:
# 17. {t}_〈b MOD_ADD l|
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. |Psi〉
#     core type: Operation
#     operator: 21
#     operand: 25
# 19. REGISTER_BRA
#     core type: Literal
#     sub-expressions:
# 20. (b MOD_ADD l, t)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. KET
#     core type: Literal
#     sub-expressions:
# 22. (Psi)
#     core type: ExprTuple
#     sub-expressions: 25
# 23. b MOD_ADD l
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. t
#     core type: Literal
#     sub-expressions:
# 25. Psi
#     core type: Literal
#     sub-expressions:
# 26. MOD_ADD
#     core type: Literal
#     sub-expressions:
# 27. (b, l)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 28. b
#     core type: Literal
#     sub-expressions:
# 29. l
#     core type: Variable
#     sub-expressions:
