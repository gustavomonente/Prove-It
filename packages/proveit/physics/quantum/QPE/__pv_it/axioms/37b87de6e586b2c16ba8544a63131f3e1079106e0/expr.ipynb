# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprArray, k
from proveit.logic import InSet, Set
from proveit.numbers import NaturalPos, one, three, two
from proveit.physics.quantum import CONTROL, Hgate, Input, Ket, Output, SPACE, ket0
from proveit.physics.quantum.QPE import U_pow_two_pow_k, psi_k, psi_next, u_
from proveit.physics.quantum.circuit import Circuit, IdentityOp, MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(two, three)
sub_expr2 = Ket(u_)
sub_expr3 = MultiQubitGate(IdentityOp(), Set(one, two))
expr = Conditional(Circuit(ExprArray([Input(Ket(psi_k)), IdentityOp(), IdentityOp(), sub_expr3, SPACE, SPACE], [Input(ket0), Hgate, MultiQubitGate(CONTROL, sub_expr1), sub_expr3, IdentityOp(), Output(Ket(psi_next))], [Input(sub_expr2), IdentityOp(), MultiQubitGate(U_pow_two_pow_k, sub_expr1), Output(sub_expr2), SPACE, SPACE])), InSet(k, NaturalPos))
# Out:
# expr: { Input(|psi_{k}〉)  & --  & --  & MultiQubitGate(I, {1, 2})  & SPACE  & SPACE   \\
#    Input(|0〉)  & Gate(H)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(I, {1, 2})  & --  & Output(|psi_{k + 1}〉)   \\
#    Input(|u〉)  & --  & MultiQubitGate(U^{2^{k}}, {2, 3})  & Output(|u〉)  & SPACE  & SPACE if k in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert \psi_{k} \rangle} & \qw & \qw & \multigate{1}{I}   \\
#   & \lstick{\lvert 0 \rangle} & \gate{H} & \control \qw \qwx[1] & \ghost{I} & \qw & \rstick{\lvert \psi_{k + 1} \rangle} \qw   \\
#   & \lstick{\lvert u \rangle} & \qw & \gate{U^{2^{k}}} & \rstick{\lvert u \rangle} \qw
# } \hspace{2em} \textrm{ if } k \in \mathbb{N}^+\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. { Input(|psi_{k}〉)  & --  & --  & MultiQubitGate(I, {1, 2})  & SPACE  & SPACE   \\
#    Input(|0〉)  & Gate(H)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(I, {1, 2})  & --  & Output(|psi_{k + 1}〉)   \\
#    Input(|u〉)  & --  & MultiQubitGate(U^{2^{k}}, {2, 3})  & Output(|u〉)  & SPACE  & SPACE if k in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1.  Input(|psi_{k}〉)  & --  & --  & MultiQubitGate(I, {1, 2})  & SPACE  & SPACE   \\
#    Input(|0〉)  & Gate(H)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(I, {1, 2})  & --  & Output(|psi_{k + 1}〉)   \\
#    Input(|u〉)  & --  & MultiQubitGate(U^{2^{k}}, {2, 3})  & Output(|u〉)  & SPACE  & SPACE
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. k in NaturalPos
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. CIRCUIT
#    core type: Literal
#    sub-expressions:
# 4. ((Input(|psi_{k}〉) & -- & -- & MultiQubitGate(I, {1, 2}) & SPACE & SPACE  \\
#   Input(|0〉) & Gate(H) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(I, {1, 2}) & -- & Output(|psi_{k + 1}〉)  \\
#   Input(|u〉) & -- & MultiQubitGate(U^{2^{k}}, {2, 3}) & Output(|u〉) & SPACE & SPACE))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (k, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 70, 8
# 7. Input(|psi_{k}〉) & -- & -- & MultiQubitGate(I, {1, 2}) & SPACE & SPACE  \\
#   Input(|0〉) & Gate(H) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(I, {1, 2}) & -- & Output(|psi_{k + 1}〉)  \\
#   Input(|u〉) & -- & MultiQubitGate(U^{2^{k}}, {2, 3}) & Output(|u〉) & SPACE & SPACE
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 8. NaturalPos
#    core type: Literal
#    sub-expressions:
# 9. (Input(|psi_{k}〉), --, --, MultiQubitGate(I, {1, 2}), SPACE, SPACE)
#    core type: ExprTuple
#    sub-expressions: 12, 38, 38, 16, 21, 21
# 10. (Input(|0〉), Gate(H), MultiQubitGate(CONTROL, {2, 3}), MultiQubitGate(I, {1, 2}), --, Output(|psi_{k + 1}〉))
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15, 16, 38, 17
# 11. (Input(|u〉), --, MultiQubitGate(U^{2^{k}}, {2, 3}), Output(|u〉), SPACE, SPACE)
#     core type: ExprTuple
#     sub-expressions: 18, 38, 19, 20, 21, 21
# 12. Input(|psi_{k}〉)
#     core type: Operation
#     operator: 29
#     operand: 34
# 13. Input(|0〉)
#     core type: Operation
#     operator: 29
#     operand: 35
# 14. Gate(H)
#     core type: Operation
#     operator: 24
#     operand: 36
# 15. MultiQubitGate(CONTROL, {2, 3})
#     core type: Operation
#     operator: 30
#     operands: 26
# 16. MultiQubitGate(I, {1, 2})
#     core type: Operation
#     operator: 30
#     operands: 27
# 17. Output(|psi_{k + 1}〉)
#     core type: Operation
#     operator: 32
#     operand: 40
# 18. Input(|u〉)
#     core type: Operation
#     operator: 29
#     operand: 43
# 19. MultiQubitGate(U^{2^{k}}, {2, 3})
#     core type: Operation
#     operator: 30
#     operands: 31
# 20. Output(|u〉)
#     core type: Operation
#     operator: 32
#     operand: 43
# 21. SPACE
#     core type: Literal
#     sub-expressions:
# 22. (|psi_{k}〉)
#     core type: ExprTuple
#     sub-expressions: 34
# 23. (|0〉)
#     core type: ExprTuple
#     sub-expressions: 35
# 24. GATE
#     core type: Literal
#     sub-expressions:
# 25. (H)
#     core type: ExprTuple
#     sub-expressions: 36
# 26. (CONTROL, {2, 3})
#     core type: ExprTuple
#     sub-expressions: 37, 42
# 27. (--, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 28. (|psi_{k + 1}〉)
#     core type: ExprTuple
#     sub-expressions: 40
# 29. INPUT
#     core type: Literal
#     sub-expressions:
# 30. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 31. (U^{2^{k}}, {2, 3})
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 32. OUTPUT
#     core type: Literal
#     sub-expressions:
# 33. (|u〉)
#     core type: ExprTuple
#     sub-expressions: 43
# 34. |psi_{k}〉
#     core type: Operation
#     operator: 51
#     operand: 53
# 35. |0〉
#     core type: Operation
#     operator: 51
#     operand: 54
# 36. H
#     core type: Literal
#     sub-expressions:
# 37. CONTROL
#     core type: Literal
#     sub-expressions:
# 38. --
#     core type: Literal
#     sub-expressions:
# 39. {1, 2}
#     core type: Operation
#     operator: 49
#     operands: 46
# 40. |psi_{k + 1}〉
#     core type: Operation
#     operator: 51
#     operand: 55
# 41. U^{2^{k}}
#     core type: Operation
#     operator: 63
#     operands: 48
# 42. {2, 3}
#     core type: Operation
#     operator: 49
#     operands: 50
# 43. |u〉
#     core type: Operation
#     operator: 51
#     operand: 59
# 44. (psi_{k})
#     core type: ExprTuple
#     sub-expressions: 53
# 45. (0)
#     core type: ExprTuple
#     sub-expressions: 54
# 46. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 71, 67
# 47. (psi_{k + 1})
#     core type: ExprTuple
#     sub-expressions: 55
# 48. (U, 2^{k})
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 49. Set
#     core type: Literal
#     sub-expressions:
# 50. (2, 3)
#     core type: ExprTuple
#     sub-expressions: 67, 58
# 51. KET
#     core type: Literal
#     sub-expressions:
# 52. (u)
#     core type: ExprTuple
#     sub-expressions: 59
# 53. psi_{k}
#     core type: Operation
#     operator: 61
#     operands: 60
# 54. 0
#     core type: Literal
#     sub-expressions:
# 55. psi_{k + 1}
#     core type: Operation
#     operator: 61
#     operands: 62
# 56. U
#     core type: Literal
#     sub-expressions:
# 57. 2^{k}
#     core type: Operation
#     operator: 63
#     operands: 64
# 58. 3
#     core type: Literal
#     sub-expressions:
# 59. u
#     core type: Literal
#     sub-expressions:
# 60. (psi, k)
#     core type: ExprTuple
#     sub-expressions: 65, 70
# 61. SUB_INDEXED
#     core type: Literal
#     sub-expressions:
# 62. (psi, k + 1)
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 63. Exp
#     core type: Literal
#     sub-expressions:
# 64. (2, k)
#     core type: ExprTuple
#     sub-expressions: 67, 70
# 65. psi
#     core type: Literal
#     sub-expressions:
# 66. k + 1
#     core type: Operation
#     operator: 68
#     operands: 69
# 67. 2
#     core type: Literal
#     sub-expressions:
# 68. +
#     core type: Literal
#     sub-expressions:
# 69. (k, 1)
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 70. k
#     core type: Variable
#     sub-expressions:
# 71. 1
#     core type: Literal
#     sub-expressions:
