# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.physics.quantum.circuit.Circuit.html">Circuit</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray
from proveit.logic import Set
from proveit.numbers import one, three, two
from proveit.physics.quantum import CONTROL, Hgate, Input, Ket, Output, SPACE, ket0
from proveit.physics.quantum.QPE import U_pow_two_pow_k, psi_k, psi_next, u_
from proveit.physics.quantum.circuit import Circuit, IdentityOp, MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(two, three)
sub_expr2 = Ket(u_)
sub_expr3 = MultiQubitGate(IdentityOp(), Set(one, two))
expr = Circuit(ExprArray([Input(Ket(psi_k)), IdentityOp(), IdentityOp(), sub_expr3, SPACE, SPACE], [Input(ket0), Hgate, MultiQubitGate(CONTROL, sub_expr1), sub_expr3, IdentityOp(), Output(Ket(psi_next))], [Input(sub_expr2), IdentityOp(), MultiQubitGate(U_pow_two_pow_k, sub_expr1), Output(sub_expr2), SPACE, SPACE]))
# Out:
# expr:  Input(|psi_{k}〉)  & --  & --  & MultiQubitGate(I, {1, 2})  & SPACE  & SPACE   \\
#    Input(|0〉)  & Gate(H)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(I, {1, 2})  & --  & Output(|psi_{k + 1}〉)   \\
#    Input(|u〉)  & --  & MultiQubitGate(U^{2^{k}}, {2, 3})  & Output(|u〉)  & SPACE  & SPACE

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert \psi_{k} \rangle} & \qw & \qw & \multigate{1}{I}   \\
#   & \lstick{\lvert 0 \rangle} & \gate{H} & \control \qw \qwx[1] & \ghost{I} & \qw & \rstick{\lvert \psi_{k + 1} \rangle} \qw   \\
#   & \lstick{\lvert u \rangle} & \qw & \gate{U^{2^{k}}} & \rstick{\lvert u \rangle} \qw
# } \hspace{2em}

# %%
expr.style_options()
# Out:
# style name: spacing
# description: change the spacing of a circuit using the format '@C=1em @R=.7em' where C is the column spacing and R is the row spacing
# default: @C=1em @R=.7em
# current value: @C=1em @R=.7em
# related methods: ()
# style name: orientation
# description: to be read from left to right then top to bottom ('horizontal') or to be read top to bottom then left to right ('vertical')
# default: horizontal
# current value: horizontal
# related methods: with_orientation

# %%
# display the expression information
expr.expr_info()
# Out:
# 0.  Input(|psi_{k}〉)  & --  & --  & MultiQubitGate(I, {1, 2})  & SPACE  & SPACE   \\
#    Input(|0〉)  & Gate(H)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(I, {1, 2})  & --  & Output(|psi_{k + 1}〉)   \\
#    Input(|u〉)  & --  & MultiQubitGate(U^{2^{k}}, {2, 3})  & Output(|u〉)  & SPACE  & SPACE
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. CIRCUIT
#    core type: Literal
#    sub-expressions:
# 2. ((Input(|psi_{k}〉) & -- & -- & MultiQubitGate(I, {1, 2}) & SPACE & SPACE  \\
#   Input(|0〉) & Gate(H) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(I, {1, 2}) & -- & Output(|psi_{k + 1}〉)  \\
#   Input(|u〉) & -- & MultiQubitGate(U^{2^{k}}, {2, 3}) & Output(|u〉) & SPACE & SPACE))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. Input(|psi_{k}〉) & -- & -- & MultiQubitGate(I, {1, 2}) & SPACE & SPACE  \\
#   Input(|0〉) & Gate(H) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(I, {1, 2}) & -- & Output(|psi_{k + 1}〉)  \\
#   Input(|u〉) & -- & MultiQubitGate(U^{2^{k}}, {2, 3}) & Output(|u〉) & SPACE & SPACE
#    core type: ExprTuple
#    sub-expressions: 4, 5, 6
# 4. (Input(|psi_{k}〉), --, --, MultiQubitGate(I, {1, 2}), SPACE, SPACE)
#    core type: ExprTuple
#    sub-expressions: 7, 33, 33, 11, 16, 16
# 5. (Input(|0〉), Gate(H), MultiQubitGate(CONTROL, {2, 3}), MultiQubitGate(I, {1, 2}), --, Output(|psi_{k + 1}〉))
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11, 33, 12
# 6. (Input(|u〉), --, MultiQubitGate(U^{2^{k}}, {2, 3}), Output(|u〉), SPACE, SPACE)
#    core type: ExprTuple
#    sub-expressions: 13, 33, 14, 15, 16, 16
# 7. Input(|psi_{k}〉)
#    core type: Operation
#    operator: 24
#    operand: 29
# 8. Input(|0〉)
#    core type: Operation
#    operator: 24
#    operand: 30
# 9. Gate(H)
#    core type: Operation
#    operator: 19
#    operand: 31
# 10. MultiQubitGate(CONTROL, {2, 3})
#     core type: Operation
#     operator: 25
#     operands: 21
# 11. MultiQubitGate(I, {1, 2})
#     core type: Operation
#     operator: 25
#     operands: 22
# 12. Output(|psi_{k + 1}〉)
#     core type: Operation
#     operator: 27
#     operand: 35
# 13. Input(|u〉)
#     core type: Operation
#     operator: 24
#     operand: 38
# 14. MultiQubitGate(U^{2^{k}}, {2, 3})
#     core type: Operation
#     operator: 25
#     operands: 26
# 15. Output(|u〉)
#     core type: Operation
#     operator: 27
#     operand: 38
# 16. SPACE
#     core type: Literal
#     sub-expressions:
# 17. (|psi_{k}〉)
#     core type: ExprTuple
#     sub-expressions: 29
# 18. (|0〉)
#     core type: ExprTuple
#     sub-expressions: 30
# 19. GATE
#     core type: Literal
#     sub-expressions:
# 20. (H)
#     core type: ExprTuple
#     sub-expressions: 31
# 21. (CONTROL, {2, 3})
#     core type: ExprTuple
#     sub-expressions: 32, 37
# 22. (--, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 23. (|psi_{k + 1}〉)
#     core type: ExprTuple
#     sub-expressions: 35
# 24. INPUT
#     core type: Literal
#     sub-expressions:
# 25. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 26. (U^{2^{k}}, {2, 3})
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 27. OUTPUT
#     core type: Literal
#     sub-expressions:
# 28. (|u〉)
#     core type: ExprTuple
#     sub-expressions: 38
# 29. |psi_{k}〉
#     core type: Operation
#     operator: 46
#     operand: 48
# 30. |0〉
#     core type: Operation
#     operator: 46
#     operand: 49
# 31. H
#     core type: Literal
#     sub-expressions:
# 32. CONTROL
#     core type: Literal
#     sub-expressions:
# 33. --
#     core type: Literal
#     sub-expressions:
# 34. {1, 2}
#     core type: Operation
#     operator: 44
#     operands: 41
# 35. |psi_{k + 1}〉
#     core type: Operation
#     operator: 46
#     operand: 50
# 36. U^{2^{k}}
#     core type: Operation
#     operator: 58
#     operands: 43
# 37. {2, 3}
#     core type: Operation
#     operator: 44
#     operands: 45
# 38. |u〉
#     core type: Operation
#     operator: 46
#     operand: 54
# 39. (psi_{k})
#     core type: ExprTuple
#     sub-expressions: 48
# 40. (0)
#     core type: ExprTuple
#     sub-expressions: 49
# 41. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 66, 62
# 42. (psi_{k + 1})
#     core type: ExprTuple
#     sub-expressions: 50
# 43. (U, 2^{k})
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 44. Set
#     core type: Literal
#     sub-expressions:
# 45. (2, 3)
#     core type: ExprTuple
#     sub-expressions: 62, 53
# 46. KET
#     core type: Literal
#     sub-expressions:
# 47. (u)
#     core type: ExprTuple
#     sub-expressions: 54
# 48. psi_{k}
#     core type: Operation
#     operator: 56
#     operands: 55
# 49. 0
#     core type: Literal
#     sub-expressions:
# 50. psi_{k + 1}
#     core type: Operation
#     operator: 56
#     operands: 57
# 51. U
#     core type: Literal
#     sub-expressions:
# 52. 2^{k}
#     core type: Operation
#     operator: 58
#     operands: 59
# 53. 3
#     core type: Literal
#     sub-expressions:
# 54. u
#     core type: Literal
#     sub-expressions:
# 55. (psi, k)
#     core type: ExprTuple
#     sub-expressions: 60, 65
# 56. SUB_INDEXED
#     core type: Literal
#     sub-expressions:
# 57. (psi, k + 1)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 58. Exp
#     core type: Literal
#     sub-expressions:
# 59. (2, k)
#     core type: ExprTuple
#     sub-expressions: 62, 65
# 60. psi
#     core type: Literal
#     sub-expressions:
# 61. k + 1
#     core type: Operation
#     operator: 63
#     operands: 64
# 62. 2
#     core type: Literal
#     sub-expressions:
# 63. +
#     core type: Literal
#     sub-expressions:
# 64. (k, 1)
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 65. k
#     core type: Variable
#     sub-expressions:
# 66. 1
#     core type: Literal
#     sub-expressions:
