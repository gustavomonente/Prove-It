# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#psi_kets_in_q_reg_space">psi_kets_in_q_reg_space</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.QPE import psi_kets_in_q_reg_space

# %%
# check that the built expression is the same as the stored expression
assert psi_kets_in_q_reg_space.expr == stored_expr
assert psi_kets_in_q_reg_space.expr._style_id == stored_expr._style_id
print("Passed sanity check: psi_kets_in_q_reg_space matches stored_expr")
# Out:
# Passed sanity check: psi_kets_in_q_reg_space matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(psi_kets_in_q_reg_space.latex())
# Out:
# \vdash \forall_{k \in \mathbb{N}^+}~\left(\lvert \psi_{k} \rangle \in \left(\mathbb{C}^{2}\right)^{\otimes k}\right)

# %%
psi_kets_in_q_reg_space.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
psi_kets_in_q_reg_space.expr_info()
# Out:
# 0. forall_{k in NaturalPos} (|psi_{k}〉 in (Complex^{2})^{otimes k})
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (k -> {|psi_{k}〉 in (Complex^{2})^{otimes k} if k in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. k -> {|psi_{k}〉 in (Complex^{2})^{otimes k} if k in NaturalPos.
#    core type: Lambda
#    parameter: 23
#    body: 4
# 4. {|psi_{k}〉 in (Complex^{2})^{otimes k} if k in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. |psi_{k}〉 in (Complex^{2})^{otimes k}
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. k in NaturalPos
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (|psi_{k}〉, (Complex^{2})^{otimes k})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (k, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 23, 12
# 10. |psi_{k}〉
# ...
