# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#eigen_uu">eigen_uu</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.QPE import eigen_uu

# %%
# check that the built expression is the same as the stored expression
assert eigen_uu.expr == stored_expr
assert eigen_uu.expr._style_id == stored_expr._style_id
print("Passed sanity check: eigen_uu matches stored_expr")
# Out:
# Passed sanity check: eigen_uu matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(eigen_uu.latex())
# Out:
# \vdash \left(U \thinspace \lvert u \rangle\right) = \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi} \thinspace \lvert u \rangle\right)

# %%
eigen_uu.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
eigen_uu.expr_info()
# Out:
# 0. (U . |u〉) = (e^{2 * pi * i * phase} * |u〉)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (U . |u〉, e^{2 * pi * i * phase} * |u〉)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. U . |u〉
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. e^{2 * pi * i * phase} * |u〉
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. .
#    core type: Literal
#    sub-expressions:
# 6. (U, |u〉)
#    core type: ExprTuple
#    sub-expressions: 9, 11
# 7. *
#    core type: Literal
#    sub-expressions:
# 8. (e^{2 * pi * i * phase}, |u〉)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. U
#    core type: Literal
#    sub-expressions:
# 10. e^{2 * pi * i * phase}
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. |u〉
#     core type: Operation
#     operator: 14
#     operand: 18
# 12. Exp
#     core type: Literal
#     sub-expressions:
# 13. (e, 2 * pi * i * phase)
# ...
