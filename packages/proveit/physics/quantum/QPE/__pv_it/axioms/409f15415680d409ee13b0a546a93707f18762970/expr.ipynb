# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprArray, Lambda, k
from proveit.logic import InSet, Set
from proveit.numbers import NaturalPos, one, three, two
from proveit.physics.quantum import CONTROL, Hgate, Input, Ket, Output, SPACE, ket0
from proveit.physics.quantum.QPE import U_pow_two_pow_k, psi_k, psi_next, u_
from proveit.physics.quantum.circuit import Circuit, IdentityOp, MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(two, three)
sub_expr2 = Ket(u_)
sub_expr3 = MultiQubitGate(IdentityOp(), Set(one, two))
expr = Lambda(k, Conditional(Circuit(ExprArray([Input(Ket(psi_k)), IdentityOp(), IdentityOp(), sub_expr3, SPACE, SPACE], [Input(ket0), Hgate, MultiQubitGate(CONTROL, sub_expr1), sub_expr3, IdentityOp(), Output(Ket(psi_next))], [Input(sub_expr2), IdentityOp(), MultiQubitGate(U_pow_two_pow_k, sub_expr1), Output(sub_expr2), SPACE, SPACE])), InSet(k, NaturalPos)))
# Out:
# expr: k -> { Input(|psi_{k}〉)  & --  & --  & MultiQubitGate(I, {1, 2})  & SPACE  & SPACE   \\
#    Input(|0〉)  & Gate(H)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(I, {1, 2})  & --  & Output(|psi_{k + 1}〉)   \\
#    Input(|u〉)  & --  & MultiQubitGate(U^{2^{k}}, {2, 3})  & Output(|u〉)  & SPACE  & SPACE if k in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# k \mapsto \left\{\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert \psi_{k} \rangle} & \qw & \qw & \multigate{1}{I}   \\
#   & \lstick{\lvert 0 \rangle} & \gate{H} & \control \qw \qwx[1] & \ghost{I} & \qw & \rstick{\lvert \psi_{k + 1} \rangle} \qw   \\
#   & \lstick{\lvert u \rangle} & \qw & \gate{U^{2^{k}}} & \rstick{\lvert u \rangle} \qw
# } \hspace{2em} \textrm{ if } k \in \mathbb{N}^+\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. k -> { Input(|psi_{k}〉)  & --  & --  & MultiQubitGate(I, {1, 2})  & SPACE  & SPACE   \\
#    Input(|0〉)  & Gate(H)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(I, {1, 2})  & --  & Output(|psi_{k + 1}〉)   \\
#    Input(|u〉)  & --  & MultiQubitGate(U^{2^{k}}, {2, 3})  & Output(|u〉)  & SPACE  & SPACE if k in NaturalPos.
#    core type: Lambda
#    parameter: 71
#    body: 1
# 1. { Input(|psi_{k}〉)  & --  & --  & MultiQubitGate(I, {1, 2})  & SPACE  & SPACE   \\
#    Input(|0〉)  & Gate(H)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(I, {1, 2})  & --  & Output(|psi_{k + 1}〉)   \\
#    Input(|u〉)  & --  & MultiQubitGate(U^{2^{k}}, {2, 3})  & Output(|u〉)  & SPACE  & SPACE if k in NaturalPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2.  Input(|psi_{k}〉)  & --  & --  & MultiQubitGate(I, {1, 2})  & SPACE  & SPACE   \\
#    Input(|0〉)  & Gate(H)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(I, {1, 2})  & --  & Output(|psi_{k + 1}〉)   \\
#    Input(|u〉)  & --  & MultiQubitGate(U^{2^{k}}, {2, 3})  & Output(|u〉)  & SPACE  & SPACE
#    core type: Operation
#    operator: 4
#    operand: 8
# 3. k in NaturalPos
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. CIRCUIT
#    core type: Literal
#    sub-expressions:
# 5. ((Input(|psi_{k}〉) & -- & -- & MultiQubitGate(I, {1, 2}) & SPACE & SPACE  \\
#   Input(|0〉) & Gate(H) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(I, {1, 2}) & -- & Output(|psi_{k + 1}〉)  \\
#   Input(|u〉) & -- & MultiQubitGate(U^{2^{k}}, {2, 3}) & Output(|u〉) & SPACE & SPACE))
#    core type: ExprTuple
#    sub-expressions: 8
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (k, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 71, 9
# 8. Input(|psi_{k}〉) & -- & -- & MultiQubitGate(I, {1, 2}) & SPACE & SPACE  \\
#   Input(|0〉) & Gate(H) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(I, {1, 2}) & -- & Output(|psi_{k + 1}〉)  \\
#   Input(|u〉) & -- & MultiQubitGate(U^{2^{k}}, {2, 3}) & Output(|u〉) & SPACE & SPACE
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. (Input(|psi_{k}〉), --, --, MultiQubitGate(I, {1, 2}), SPACE, SPACE)
#     core type: ExprTuple
#     sub-expressions: 13, 39, 39, 17, 22, 22
# 11. (Input(|0〉), Gate(H), MultiQubitGate(CONTROL, {2, 3}), MultiQubitGate(I, {1, 2}), --, Output(|psi_{k + 1}〉))
#     core type: ExprTuple
#     sub-expressions: 14, 15, 16, 17, 39, 18
# 12. (Input(|u〉), --, MultiQubitGate(U^{2^{k}}, {2, 3}), Output(|u〉), SPACE, SPACE)
#     core type: ExprTuple
#     sub-expressions: 19, 39, 20, 21, 22, 22
# 13. Input(|psi_{k}〉)
#     core type: Operation
#     operator: 30
#     operand: 35
# 14. Input(|0〉)
#     core type: Operation
#     operator: 30
#     operand: 36
# 15. Gate(H)
#     core type: Operation
#     operator: 25
#     operand: 37
# 16. MultiQubitGate(CONTROL, {2, 3})
#     core type: Operation
#     operator: 31
#     operands: 27
# 17. MultiQubitGate(I, {1, 2})
#     core type: Operation
#     operator: 31
#     operands: 28
# 18. Output(|psi_{k + 1}〉)
#     core type: Operation
#     operator: 33
#     operand: 41
# 19. Input(|u〉)
#     core type: Operation
#     operator: 30
#     operand: 44
# 20. MultiQubitGate(U^{2^{k}}, {2, 3})
#     core type: Operation
#     operator: 31
#     operands: 32
# 21. Output(|u〉)
#     core type: Operation
#     operator: 33
#     operand: 44
# 22. SPACE
#     core type: Literal
#     sub-expressions:
# 23. (|psi_{k}〉)
#     core type: ExprTuple
#     sub-expressions: 35
# 24. (|0〉)
#     core type: ExprTuple
#     sub-expressions: 36
# 25. GATE
#     core type: Literal
#     sub-expressions:
# 26. (H)
#     core type: ExprTuple
#     sub-expressions: 37
# 27. (CONTROL, {2, 3})
#     core type: ExprTuple
#     sub-expressions: 38, 43
# 28. (--, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 29. (|psi_{k + 1}〉)
#     core type: ExprTuple
#     sub-expressions: 41
# 30. INPUT
#     core type: Literal
#     sub-expressions:
# 31. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 32. (U^{2^{k}}, {2, 3})
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 33. OUTPUT
#     core type: Literal
#     sub-expressions:
# 34. (|u〉)
#     core type: ExprTuple
#     sub-expressions: 44
# 35. |psi_{k}〉
#     core type: Operation
#     operator: 52
#     operand: 54
# 36. |0〉
#     core type: Operation
#     operator: 52
#     operand: 55
# 37. H
#     core type: Literal
#     sub-expressions:
# 38. CONTROL
#     core type: Literal
#     sub-expressions:
# 39. --
#     core type: Literal
#     sub-expressions:
# 40. {1, 2}
#     core type: Operation
#     operator: 50
#     operands: 47
# 41. |psi_{k + 1}〉
#     core type: Operation
#     operator: 52
#     operand: 56
# 42. U^{2^{k}}
#     core type: Operation
#     operator: 64
#     operands: 49
# 43. {2, 3}
#     core type: Operation
#     operator: 50
#     operands: 51
# 44. |u〉
#     core type: Operation
#     operator: 52
#     operand: 60
# 45. (psi_{k})
#     core type: ExprTuple
#     sub-expressions: 54
# 46. (0)
#     core type: ExprTuple
#     sub-expressions: 55
# 47. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 72, 68
# 48. (psi_{k + 1})
#     core type: ExprTuple
#     sub-expressions: 56
# 49. (U, 2^{k})
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 50. Set
#     core type: Literal
#     sub-expressions:
# 51. (2, 3)
#     core type: ExprTuple
#     sub-expressions: 68, 59
# 52. KET
#     core type: Literal
#     sub-expressions:
# 53. (u)
#     core type: ExprTuple
#     sub-expressions: 60
# 54. psi_{k}
#     core type: Operation
#     operator: 62
#     operands: 61
# 55. 0
#     core type: Literal
#     sub-expressions:
# 56. psi_{k + 1}
#     core type: Operation
#     operator: 62
#     operands: 63
# 57. U
#     core type: Literal
#     sub-expressions:
# 58. 2^{k}
#     core type: Operation
#     operator: 64
#     operands: 65
# 59. 3
#     core type: Literal
#     sub-expressions:
# 60. u
#     core type: Literal
#     sub-expressions:
# 61. (psi, k)
#     core type: ExprTuple
#     sub-expressions: 66, 71
# 62. SUB_INDEXED
#     core type: Literal
#     sub-expressions:
# 63. (psi, k + 1)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 64. Exp
#     core type: Literal
#     sub-expressions:
# 65. (2, k)
#     core type: ExprTuple
#     sub-expressions: 68, 71
# 66. psi
#     core type: Literal
#     sub-expressions:
# 67. k + 1
#     core type: Operation
#     operator: 69
#     operands: 70
# 68. 2
#     core type: Literal
#     sub-expressions:
# 69. +
#     core type: Literal
#     sub-expressions:
# 70. (k, 1)
#     core type: ExprTuple
#     sub-expressions: 71, 72
# 71. k
#     core type: Variable
#     sub-expressions:
# 72. 1
#     core type: Literal
#     sub-expressions:
