# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.numbers import Mult, Neg, frac
from proveit.physics.quantum.QPE import b_, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = frac(b_, two_pow_t)
expr = ExprTuple(Mult(two_pow_t, Neg(sub_expr1)), Neg(Mult(two_pow_t, sub_expr1)))
# Out:
# expr: (2^{t} * (-(b / 2^{t})), -(2^{t} * (b / 2^{t})))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(2^{t} \cdot \left(-\frac{b}{2^{t}}\right), -\left(2^{t} \cdot \frac{b}{2^{t}}\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (2^{t} * (-(b / 2^{t})), -(2^{t} * (b / 2^{t})))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 2^{t} * (-(b / 2^{t}))
#    core type: Operation
#    operator: 9
#    operands: 3
# 2. -(2^{t} * (b / 2^{t}))
#    core type: Operation
#    operator: 7
#    operand: 6
# 3. (2^{t}, -(b / 2^{t}))
#    core type: ExprTuple
#    sub-expressions: 15, 5
# 4. (2^{t} * (b / 2^{t}))
#    core type: ExprTuple
#    sub-expressions: 6
# 5. -(b / 2^{t})
#    core type: Operation
#    operator: 7
#    operand: 11
# 6. 2^{t} * (b / 2^{t})
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. -
#    core type: Literal
#    sub-expressions:
# 8. (b / 2^{t})
#    core type: ExprTuple
#    sub-expressions: 11
# 9. *
#    core type: Literal
#    sub-expressions:
# 10. (2^{t}, b / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 15, 11
# 11. b / 2^{t}
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. /
#     core type: Literal
#     sub-expressions:
# 13. (b, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. b
#     core type: Literal
#     sub-expressions:
# 15. 2^{t}
#     core type: Operation
#     operator: 16
#     operands: 17
# 16. Exp
#     core type: Literal
#     sub-expressions:
# 17. (2, t)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. 2
#     core type: Literal
#     sub-expressions:
# 19. t
#     core type: Literal
#     sub-expressions:
