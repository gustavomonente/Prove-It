# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.logic import Forall, InSet
from proveit.numbers import Add, IntervalCO, Neg, frac, one, two
from proveit.physics.quantum.QPE import delta_, full_domain, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = frac(one, two)
expr = Forall([l], InSet(Add(delta_, Neg(frac(l, two_pow_t))), IntervalCO(Neg(sub_expr1), sub_expr1)), domains = [full_domain])
# Out:
# expr: forall_{l in {-2^{t - 1} + 1...2^{t - 1}}} ((delta - (l / 2^{t})) in [-(1 / 2),1 / 2))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{l \in \{-2^{t - 1} + 1 \ldots 2^{t - 1}\}}~\left(\left(\delta - \frac{l}{2^{t}}\right) \in \left[-\frac{1}{2},\frac{1}{2}\right)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{l in {-2^{t - 1} + 1...2^{t - 1}}} ((delta - (l / 2^{t})) in [-(1 / 2),1 / 2))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (l -> {(delta - (l / 2^{t})) in [-(1 / 2),1 / 2) if l in {-2^{t - 1} + 1...2^{t - 1}}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. l -> {(delta - (l / 2^{t})) in [-(1 / 2),1 / 2) if l in {-2^{t - 1} + 1...2^{t - 1}}.
#    core type: Lambda
#    parameter: 32
#    body: 4
# 4. {(delta - (l / 2^{t})) in [-(1 / 2),1 / 2) if l in {-2^{t - 1} + 1...2^{t - 1}}.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (delta - (l / 2^{t})) in [-(1 / 2),1 / 2)
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. l in {-2^{t - 1} + 1...2^{t - 1}}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (delta - (l / 2^{t}), [-(1 / 2),1 / 2))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (l, {-2^{t - 1} + 1...2^{t - 1}})
#    core type: ExprTuple
#    sub-expressions: 32, 12
# 10. delta - (l / 2^{t})
#     core type: Operation
#     operator: 40
#     operands: 13
# 11. [-(1 / 2),1 / 2)
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. {-2^{t - 1} + 1...2^{t - 1}}
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. (delta, -(l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 14. IntervalCO
#     core type: Literal
#     sub-expressions:
# 15. (-(1 / 2), 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 20, 26
# 16. Interval
#     core type: Literal
#     sub-expressions:
# 17. (-2^{t - 1} + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 21, 34
# 18. delta
#     core type: Literal
#     sub-expressions:
# 19. -(l / 2^{t})
#     core type: Operation
#     operator: 44
#     operand: 25
# 20. -(1 / 2)
#     core type: Operation
#     operator: 44
#     operand: 26
# 21. -2^{t - 1} + 1
#     core type: Operation
#     operator: 40
#     operands: 24
# 22. (l / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 25
# 23. (1 / 2)
#     core type: ExprTuple
#     sub-expressions: 26
# 24. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 27, 46
# 25. l / 2^{t}
#     core type: Operation
#     operator: 29
#     operands: 28
# 26. 1 / 2
#     core type: Operation
#     operator: 29
#     operands: 30
# 27. -2^{t - 1}
#     core type: Operation
#     operator: 44
#     operand: 34
# 28. (l, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 29. /
#     core type: Literal
#     sub-expressions:
# 30. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 46, 38
# 31. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 34
# 32. l
#     core type: Variable
#     sub-expressions:
# 33. 2^{t}
#     core type: Operation
#     operator: 36
#     operands: 35
# 34. 2^{t - 1}
#     core type: Operation
#     operator: 36
#     operands: 37
# 35. (2, t)
#     core type: ExprTuple
#     sub-expressions: 38, 42
# 36. Exp
#     core type: Literal
#     sub-expressions:
# 37. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 38. 2
#     core type: Literal
#     sub-expressions:
# 39. t - 1
#     core type: Operation
#     operator: 40
#     operands: 41
# 40. +
#     core type: Literal
#     sub-expressions:
# 41. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 42. t
#     core type: Literal
#     sub-expressions:
# 43. -1
#     core type: Operation
#     operator: 44
#     operand: 46
# 44. -
#     core type: Literal
#     sub-expressions:
# 45. (1)
#     core type: ExprTuple
#     sub-expressions: 46
# 46. 1
#     core type: Literal
#     sub-expressions:
