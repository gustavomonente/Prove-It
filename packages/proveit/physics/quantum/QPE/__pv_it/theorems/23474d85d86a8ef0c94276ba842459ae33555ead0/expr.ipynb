# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, eps
from proveit.logic import InSet, SubsetEq
from proveit.numbers import NaturalPos
from proveit.physics.quantum.QPE import full_domain, pos_domain

# %%
# build up the expression from sub-expressions
expr = Lambda(eps, Conditional(SubsetEq(pos_domain, full_domain), InSet(eps, NaturalPos)))
# Out:
# expr: eps -> {{eps + 1...2^{t - 1}} subset_eq {-2^{t - 1} + 1...2^{t - 1}} if eps in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \varepsilon \mapsto \left\{\{\varepsilon + 1 \ldots 2^{t - 1}\} \subseteq \{-2^{t - 1} + 1 \ldots 2^{t - 1}\} \textrm{ if } \varepsilon \in \mathbb{N}^+\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. eps -> {{eps + 1...2^{t - 1}} subset_eq {-2^{t - 1} + 1...2^{t - 1}} if eps in NaturalPos.
#    core type: Lambda
#    parameter: 18
#    body: 1
# 1. {{eps + 1...2^{t - 1}} subset_eq {-2^{t - 1} + 1...2^{t - 1}} if eps in NaturalPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. {eps + 1...2^{t - 1}} subset_eq {-2^{t - 1} + 1...2^{t - 1}}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. eps in NaturalPos
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. subset_eq
#    core type: Literal
#    sub-expressions:
# 5. ({eps + 1...2^{t - 1}}, {-2^{t - 1} + 1...2^{t - 1}})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (eps, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 18, 10
# 8. {eps + 1...2^{t - 1}}
#    core type: Operation
#    operator: 12
#    operands: 11
# 9. {-2^{t - 1} + 1...2^{t - 1}}
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. (eps + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 14, 21
# 12. Interval
#     core type: Literal
#     sub-expressions:
# 13. (-2^{t - 1} + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 15, 21
# 14. eps + 1
#     core type: Operation
#     operator: 26
#     operands: 16
# 15. -2^{t - 1} + 1
#     core type: Operation
#     operator: 26
#     operands: 17
# 16. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 18, 32
# 17. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 19, 32
# 18. eps
#     core type: Variable
#     sub-expressions:
# 19. -2^{t - 1}
#     core type: Operation
#     operator: 30
#     operand: 21
# 20. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 21
# 21. 2^{t - 1}
#     core type: Operation
#     operator: 22
#     operands: 23
# 22. Exp
#     core type: Literal
#     sub-expressions:
# 23. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. 2
#     core type: Literal
#     sub-expressions:
# 25. t - 1
#     core type: Operation
#     operator: 26
#     operands: 27
# 26. +
#     core type: Literal
#     sub-expressions:
# 27. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 28. t
#     core type: Literal
#     sub-expressions:
# 29. -1
#     core type: Operation
#     operator: 30
#     operand: 32
# 30. -
#     core type: Literal
#     sub-expressions:
# 31. (1)
#     core type: ExprTuple
#     sub-expressions: 32
# 32. 1
#     core type: Literal
#     sub-expressions:
