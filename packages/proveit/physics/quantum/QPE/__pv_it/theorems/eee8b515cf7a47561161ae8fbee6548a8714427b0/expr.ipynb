# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, eps, l
from proveit.numbers import Add, Sum
from proveit.physics.quantum.QPE import Pfail, alpha_l_sqrd, neg_domain, pos_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
expr = ExprTuple(Pfail(eps), Add(Sum(sub_expr1, alpha_l_sqrd, domains = [neg_domain]), Sum(sub_expr1, alpha_l_sqrd, domains = [pos_domain])))
# Out:
# expr: (Pfail(eps), (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(P_{\rm fail}(\varepsilon), \left(\sum_{l=-2^{t - 1} + 1}^{-\left(\varepsilon + 1\right)} \left|\alpha_{l}\right|^{2}\right) + \left(\sum_{l=\varepsilon + 1}^{2^{t - 1}} \left|\alpha_{l}\right|^{2}\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Pfail(eps), (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Pfail(eps)
#    core type: Operation
#    operator: 3
#    operand: 44
# 2. (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2})
#    core type: Operation
#    operator: 49
#    operands: 5
# 3. Pfail
#    core type: Literal
#    sub-expressions:
# 4. (eps)
#    core type: ExprTuple
#    sub-expressions: 44
# 5. (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}, Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}
#    core type: Operation
#    operator: 9
#    operand: 11
# 7. Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2}
#    core type: Operation
#    operator: 9
#    operand: 12
# 8. (l -> {|alpha_{l}|^{2} if l in {-2^{t - 1} + 1...-(eps + 1)}.)
# ...
