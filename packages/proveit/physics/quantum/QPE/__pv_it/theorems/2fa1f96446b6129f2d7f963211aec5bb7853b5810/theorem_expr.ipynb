# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#pos_domain_within_integer">pos_domain_within_integer</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.QPE import pos_domain_within_integer

# %%
# check that the built expression is the same as the stored expression
assert pos_domain_within_integer.expr == stored_expr
assert pos_domain_within_integer.expr._style_id == stored_expr._style_id
print("Passed sanity check: pos_domain_within_integer matches stored_expr")
# Out:
# Passed sanity check: pos_domain_within_integer matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(pos_domain_within_integer.latex())
# Out:
# \vdash \forall_{\varepsilon \in \{1 \ldots 2^{t - 1} - 2\}}~\left(\{\varepsilon + 1 \ldots 2^{t - 1}\} \subseteq \mathbb{Z}\right)

# %%
pos_domain_within_integer.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
pos_domain_within_integer.expr_info()
# Out:
# 0. forall_{eps in {1...2^{t - 1} - 2}} ({eps + 1...2^{t - 1}} subset_eq Integer)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (eps -> {{eps + 1...2^{t - 1}} subset_eq Integer if eps in {1...2^{t - 1} - 2}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. eps -> {{eps + 1...2^{t - 1}} subset_eq Integer if eps in {1...2^{t - 1} - 2}.
#    core type: Lambda
#    parameter: 21
#    body: 4
# 4. {{eps + 1...2^{t - 1}} subset_eq Integer if eps in {1...2^{t - 1} - 2}.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. {eps + 1...2^{t - 1}} subset_eq Integer
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. eps in {1...2^{t - 1} - 2}
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. subset_eq
#    core type: Literal
#    sub-expressions:
# 8. ({eps + 1...2^{t - 1}}, Integer)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. in
#    core type: Literal
# ...
