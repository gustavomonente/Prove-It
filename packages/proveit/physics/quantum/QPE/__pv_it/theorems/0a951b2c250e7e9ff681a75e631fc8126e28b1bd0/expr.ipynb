# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, eps
from proveit.logic import InSet, SubsetEq
from proveit.physics.quantum.QPE import eps_domain, full_domain_sans_zero, pos_domain

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(eps, Conditional(SubsetEq(pos_domain, full_domain_sans_zero), InSet(eps, eps_domain))))
# Out:
# expr: (eps -> {{eps + 1...2^{t - 1}} subset_eq ({-2^{t - 1} + 1...2^{t - 1}} - {0}) if eps in {1...2^{t - 1} - 2}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\varepsilon \mapsto \left\{\{\varepsilon + 1 \ldots 2^{t - 1}\} \subseteq \left(\{-2^{t - 1} + 1 \ldots 2^{t - 1}\} - \left\{0\right\}\right) \textrm{ if } \varepsilon \in \{1 \ldots 2^{t - 1} - 2\}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (eps -> {{eps + 1...2^{t - 1}} subset_eq ({-2^{t - 1} + 1...2^{t - 1}} - {0}) if eps in {1...2^{t - 1} - 2}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. eps -> {{eps + 1...2^{t - 1}} subset_eq ({-2^{t - 1} + 1...2^{t - 1}} - {0}) if eps in {1...2^{t - 1} - 2}.
#    core type: Lambda
#    parameter: 26
#    body: 2
# 2. {{eps + 1...2^{t - 1}} subset_eq ({-2^{t - 1} + 1...2^{t - 1}} - {0}) if eps in {1...2^{t - 1} - 2}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. {eps + 1...2^{t - 1}} subset_eq ({-2^{t - 1} + 1...2^{t - 1}} - {0})
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. eps in {1...2^{t - 1} - 2}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. subset_eq
#    core type: Literal
#    sub-expressions:
# 6. ({eps + 1...2^{t - 1}}, {-2^{t - 1} + 1...2^{t - 1}} - {0})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (eps, {1...2^{t - 1} - 2})
#    core type: ExprTuple
#    sub-expressions: 26, 11
# 9. {eps + 1...2^{t - 1}}
#    core type: Operation
#    operator: 21
#    operands: 12
# 10. {-2^{t - 1} + 1...2^{t - 1}} - {0}
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. {1...2^{t - 1} - 2}
#     core type: Operation
#     operator: 21
#     operands: 15
# 12. (eps + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 16, 34
# 13. -
#     core type: Literal
#     sub-expressions:
# 14. ({-2^{t - 1} + 1...2^{t - 1}}, {0})
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. (1, 2^{t - 1} - 2)
#     core type: ExprTuple
#     sub-expressions: 45, 19
# 16. eps + 1
#     core type: Operation
#     operator: 39
#     operands: 20
# 17. {-2^{t - 1} + 1...2^{t - 1}}
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. {0}
#     core type: Operation
#     operator: 23
#     operand: 28
# 19. 2^{t - 1} - 2
#     core type: Operation
#     operator: 39
#     operands: 25
# 20. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 26, 45
# 21. Interval
#     core type: Literal
#     sub-expressions:
# 22. (-2^{t - 1} + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 27, 34
# 23. Set
#     core type: Literal
#     sub-expressions:
# 24. (0)
#     core type: ExprTuple
#     sub-expressions: 28
# 25. (2^{t - 1}, -2)
#     core type: ExprTuple
#     sub-expressions: 34, 29
# 26. eps
#     core type: Variable
#     sub-expressions:
# 27. -2^{t - 1} + 1
#     core type: Operation
#     operator: 39
#     operands: 30
# 28. 0
#     core type: Literal
#     sub-expressions:
# 29. -2
#     core type: Operation
#     operator: 43
#     operand: 37
# 30. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 32, 45
# 31. (2)
#     core type: ExprTuple
#     sub-expressions: 37
# 32. -2^{t - 1}
#     core type: Operation
#     operator: 43
#     operand: 34
# 33. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 34
# 34. 2^{t - 1}
#     core type: Operation
#     operator: 35
#     operands: 36
# 35. Exp
#     core type: Literal
#     sub-expressions:
# 36. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 37. 2
#     core type: Literal
#     sub-expressions:
# 38. t - 1
#     core type: Operation
#     operator: 39
#     operands: 40
# 39. +
#     core type: Literal
#     sub-expressions:
# 40. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 41. t
#     core type: Literal
#     sub-expressions:
# 42. -1
#     core type: Operation
#     operator: 43
#     operand: 45
# 43. -
#     core type: Literal
#     sub-expressions:
# 44. (1)
#     core type: ExprTuple
#     sub-expressions: 45
# 45. 1
#     core type: Literal
#     sub-expressions:
