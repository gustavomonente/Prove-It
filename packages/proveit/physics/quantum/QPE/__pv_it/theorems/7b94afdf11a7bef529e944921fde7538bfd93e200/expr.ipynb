# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.physics.quantum.QPE import full_domain_sans_zero, pos_domain

# %%
# build up the expression from sub-expressions
expr = ExprTuple(pos_domain, full_domain_sans_zero)
# Out:
# expr: ({eps + 1...2^{t - 1}}, {-2^{t - 1} + 1...2^{t - 1}} - {0})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\{\varepsilon + 1 \ldots 2^{t - 1}\}, \{-2^{t - 1} + 1 \ldots 2^{t - 1}\} - \left\{0\right\}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ({eps + 1...2^{t - 1}}, {-2^{t - 1} + 1...2^{t - 1}} - {0})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. {eps + 1...2^{t - 1}}
#    core type: Operation
#    operator: 10
#    operands: 3
# 2. {-2^{t - 1} + 1...2^{t - 1}} - {0}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (eps + 1, 2^{t - 1})
#    core type: ExprTuple
#    sub-expressions: 6, 20
# 4. -
#    core type: Literal
#    sub-expressions:
# 5. ({-2^{t - 1} + 1...2^{t - 1}}, {0})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. eps + 1
#    core type: Operation
#    operator: 25
#    operands: 9
# 7. {-2^{t - 1} + 1...2^{t - 1}}
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. {0}
#    core type: Operation
#    operator: 12
#    operand: 16
# 9. (eps, 1)
#    core type: ExprTuple
#    sub-expressions: 14, 31
# 10. Interval
#     core type: Literal
#     sub-expressions:
# 11. (-2^{t - 1} + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 15, 20
# 12. Set
#     core type: Literal
#     sub-expressions:
# 13. (0)
#     core type: ExprTuple
#     sub-expressions: 16
# 14. eps
#     core type: Variable
#     sub-expressions:
# 15. -2^{t - 1} + 1
#     core type: Operation
#     operator: 25
#     operands: 17
# 16. 0
#     core type: Literal
#     sub-expressions:
# 17. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 18, 31
# 18. -2^{t - 1}
#     core type: Operation
#     operator: 29
#     operand: 20
# 19. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 20
# 20. 2^{t - 1}
#     core type: Operation
#     operator: 21
#     operands: 22
# 21. Exp
#     core type: Literal
#     sub-expressions:
# 22. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 23. 2
#     core type: Literal
#     sub-expressions:
# 24. t - 1
#     core type: Operation
#     operator: 25
#     operands: 26
# 25. +
#     core type: Literal
#     sub-expressions:
# 26. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 27. t
#     core type: Literal
#     sub-expressions:
# 28. -1
#     core type: Operation
#     operator: 29
#     operand: 31
# 29. -
#     core type: Literal
#     sub-expressions:
# 30. (1)
#     core type: ExprTuple
#     sub-expressions: 31
# 31. 1
#     core type: Literal
#     sub-expressions:
