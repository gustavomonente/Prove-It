# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, l
from proveit.logic import InSet
from proveit.numbers import frac, one
from proveit.physics.quantum.QPE import diff_l_scaled_delta, pos_domain

# %%
# build up the expression from sub-expressions
expr = Conditional(frac(one, diff_l_scaled_delta), InSet(l, pos_domain))
# Out:
# expr: {1 / (l - (2^{t} * delta)) if l in {eps + 1...2^{t - 1}}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\frac{1}{l - \left(2^{t} \cdot \delta\right)} \textrm{ if } l \in \{\varepsilon + 1 \ldots 2^{t - 1}\}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {1 / (l - (2^{t} * delta)) if l in {eps + 1...2^{t - 1}}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. 1 / (l - (2^{t} * delta))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. l in {eps + 1...2^{t - 1}}
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. /
#    core type: Literal
#    sub-expressions:
# 4. (1, l - (2^{t} * delta))
#    core type: ExprTuple
#    sub-expressions: 35, 7
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (l, {eps + 1...2^{t - 1}})
#    core type: ExprTuple
#    sub-expressions: 12, 8
# 7. l - (2^{t} * delta)
#    core type: Operation
#    operator: 24
#    operands: 9
# 8. {eps + 1...2^{t - 1}}
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (l, -(2^{t} * delta))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. Interval
#     core type: Literal
#     sub-expressions:
# 11. (eps + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. l
#     core type: Variable
#     sub-expressions:
# 13. -(2^{t} * delta)
#     core type: Operation
#     operator: 31
#     operand: 19
# 14. eps + 1
#     core type: Operation
#     operator: 24
#     operands: 17
# 15. 2^{t - 1}
#     core type: Operation
#     operator: 29
#     operands: 18
# 16. (2^{t} * delta)
#     core type: ExprTuple
#     sub-expressions: 19
# 17. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 20, 35
# 18. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 33, 21
# 19. 2^{t} * delta
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. eps
#     core type: Variable
#     sub-expressions:
# 21. t - 1
#     core type: Operation
#     operator: 24
#     operands: 25
# 22. *
#     core type: Literal
#     sub-expressions:
# 23. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. +
#     core type: Literal
#     sub-expressions:
# 25. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 34, 28
# 26. 2^{t}
#     core type: Operation
#     operator: 29
#     operands: 30
# 27. delta
#     core type: Literal
#     sub-expressions:
# 28. -1
#     core type: Operation
#     operator: 31
#     operand: 35
# 29. Exp
#     core type: Literal
#     sub-expressions:
# 30. (2, t)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 31. -
#     core type: Literal
#     sub-expressions:
# 32. (1)
#     core type: ExprTuple
#     sub-expressions: 35
# 33. 2
#     core type: Literal
#     sub-expressions:
# 34. t
#     core type: Literal
#     sub-expressions:
# 35. 1
#     core type: Literal
#     sub-expressions:
