# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, eps, l
from proveit.logic import InSet
from proveit.numbers import Add, LessEq, Sum
from proveit.physics.quantum.QPE import Pfail, alpha_l_sqrd, eps_domain, neg_domain, pos_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
expr = ExprTuple(Lambda(eps, Conditional(LessEq(Pfail(eps), Add(Sum(sub_expr1, alpha_l_sqrd, domains = [neg_domain]), Sum(sub_expr1, alpha_l_sqrd, domains = [pos_domain]))), InSet(eps, eps_domain))))
# Out:
# expr: (eps -> {Pfail(eps) <= ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2})) if eps in {1...2^{t - 1} - 2}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\varepsilon \mapsto \left\{P_{\rm fail}(\varepsilon) \leq \left(\left(\sum_{l=-2^{t - 1} + 1}^{-\left(\varepsilon + 1\right)} \left|\alpha_{l}\right|^{2}\right) + \left(\sum_{l=\varepsilon + 1}^{2^{t - 1}} \left|\alpha_{l}\right|^{2}\right)\right) \textrm{ if } \varepsilon \in \{1 \ldots 2^{t - 1} - 2\}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (eps -> {Pfail(eps) <= ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2})) if eps in {1...2^{t - 1} - 2}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. eps -> {Pfail(eps) <= ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2})) if eps in {1...2^{t - 1} - 2}.
#    core type: Lambda
#    parameter: 57
#    body: 2
# 2. {Pfail(eps) <= ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2})) if eps in {1...2^{t - 1} - 2}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. Pfail(eps) <= ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2}))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. eps in {1...2^{t - 1} - 2}
#    core type: Operation
#    operator: 33
#    operands: 7
# 5. <=
#    core type: Literal
#    sub-expressions:
# ...
