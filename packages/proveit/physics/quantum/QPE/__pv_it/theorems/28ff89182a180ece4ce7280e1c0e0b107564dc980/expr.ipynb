# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, eps
from proveit.logic import InSet, SubsetEq
from proveit.numbers import Integer
from proveit.physics.quantum.QPE import eps_domain, neg_domain

# %%
# build up the expression from sub-expressions
expr = Conditional(SubsetEq(neg_domain, Integer), InSet(eps, eps_domain))
# Out:
# expr: {{-2^{t - 1} + 1...-(eps + 1)} subset_eq Integer if eps in {1...2^{t - 1} - 2}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\{-2^{t - 1} + 1 \ldots -\left(\varepsilon + 1\right)\} \subseteq \mathbb{Z} \textrm{ if } \varepsilon \in \{1 \ldots 2^{t - 1} - 2\}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {{-2^{t - 1} + 1...-(eps + 1)} subset_eq Integer if eps in {1...2^{t - 1} - 2}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. {-2^{t - 1} + 1...-(eps + 1)} subset_eq Integer
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. eps in {1...2^{t - 1} - 2}
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. subset_eq
#    core type: Literal
#    sub-expressions:
# 4. ({-2^{t - 1} + 1...-(eps + 1)}, Integer)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (eps, {1...2^{t - 1} - 2})
#    core type: ExprTuple
#    sub-expressions: 26, 9
# 7. {-2^{t - 1} + 1...-(eps + 1)}
#    core type: Operation
#    operator: 11
#    operands: 10
# 8. Integer
#    core type: Literal
#    sub-expressions:
# 9. {1...2^{t - 1} - 2}
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (-2^{t - 1} + 1, -(eps + 1))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. Interval
#     core type: Literal
#     sub-expressions:
# 12. (1, 2^{t - 1} - 2)
#     core type: ExprTuple
#     sub-expressions: 37, 15
# 13. -2^{t - 1} + 1
#     core type: Operation
#     operator: 31
#     operands: 16
# 14. -(eps + 1)
#     core type: Operation
#     operator: 35
#     operand: 20
# 15. 2^{t - 1} - 2
#     core type: Operation
#     operator: 31
#     operands: 18
# 16. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 19, 37
# 17. (eps + 1)
#     core type: ExprTuple
#     sub-expressions: 20
# 18. (2^{t - 1}, -2)
#     core type: ExprTuple
#     sub-expressions: 25, 21
# 19. -2^{t - 1}
#     core type: Operation
#     operator: 35
#     operand: 25
# 20. eps + 1
#     core type: Operation
#     operator: 31
#     operands: 23
# 21. -2
#     core type: Operation
#     operator: 35
#     operand: 29
# 22. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 25
# 23. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 26, 37
# 24. (2)
#     core type: ExprTuple
#     sub-expressions: 29
# 25. 2^{t - 1}
#     core type: Operation
#     operator: 27
#     operands: 28
# 26. eps
#     core type: Variable
#     sub-expressions:
# 27. Exp
#     core type: Literal
#     sub-expressions:
# 28. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 29. 2
#     core type: Literal
#     sub-expressions:
# 30. t - 1
#     core type: Operation
#     operator: 31
#     operands: 32
# 31. +
#     core type: Literal
#     sub-expressions:
# 32. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 33. t
#     core type: Literal
#     sub-expressions:
# 34. -1
#     core type: Operation
#     operator: 35
#     operand: 37
# 35. -
#     core type: Literal
#     sub-expressions:
# 36. (1)
#     core type: ExprTuple
#     sub-expressions: 37
# 37. 1
#     core type: Literal
#     sub-expressions:
