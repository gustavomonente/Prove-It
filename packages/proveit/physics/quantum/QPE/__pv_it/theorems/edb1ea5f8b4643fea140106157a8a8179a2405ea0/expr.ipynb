# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import eps, l
from proveit.logic import Forall
from proveit.numbers import Add, LessEq, Mult, Sum, four, frac, one
from proveit.physics.quantum.QPE import Pfail, diff_l_scaled_delta, eps_domain, neg_domain, pos_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = frac(one, diff_l_scaled_delta)
expr = Forall([eps], LessEq(Pfail(eps), Mult(frac(one, four), Add(Sum(sub_expr1, sub_expr2, domains = [neg_domain]), Sum(sub_expr1, sub_expr2, domains = [pos_domain])))), domains = [eps_domain])
# Out:
# expr: forall_{eps in {1...2^{t - 1} - 2}} (Pfail(eps) <= ((1 / 4) * ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta)))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta)))))))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{\varepsilon \in \{1 \ldots 2^{t - 1} - 2\}}~\left(P_{\rm fail}(\varepsilon) \leq \left(\frac{1}{4} \cdot \left(\left(\sum_{l=-2^{t - 1} + 1}^{-\left(\varepsilon + 1\right)} \frac{1}{l - \left(2^{t} \cdot \delta\right)}\right) + \left(\sum_{l=\varepsilon + 1}^{2^{t - 1}} \frac{1}{l - \left(2^{t} \cdot \delta\right)}\right)\right)\right)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{eps in {1...2^{t - 1} - 2}} (Pfail(eps) <= ((1 / 4) * ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta)))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta)))))))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (eps -> {Pfail(eps) <= ((1 / 4) * ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta)))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta)))))) if eps in {1...2^{t - 1} - 2}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. eps -> {Pfail(eps) <= ((1 / 4) * ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta)))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta)))))) if eps in {1...2^{t - 1} - 2}.
#    core type: Lambda
#    parameter: 65
#    body: 4
# 4. {Pfail(eps) <= ((1 / 4) * ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta)))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta)))))) if eps in {1...2^{t - 1} - 2}.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. Pfail(eps) <= ((1 / 4) * ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta)))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))))))
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. eps in {1...2^{t - 1} - 2}
#    core type: Operation
#    operator: 41
#    operands: 9
# 7. <=
#    core type: Literal
#    sub-expressions:
# 8. (Pfail(eps), (1 / 4) * ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta)))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))))))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. (eps, {1...2^{t - 1} - 2})
#    core type: ExprTuple
#    sub-expressions: 65, 12
# 10. Pfail(eps)
#     core type: Operation
#     operator: 13
#     operand: 65
# 11. (1 / 4) * ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta)))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta)))))
#     core type: Operation
#     operator: 62
#     operands: 15
# 12. {1...2^{t - 1} - 2}
#     core type: Operation
#     operator: 48
#     operands: 16
# 13. Pfail
#     core type: Literal
#     sub-expressions:
# 14. (eps)
#     core type: ExprTuple
#     sub-expressions: 65
# 15. (1 / 4, (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta)))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta)))))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. (1, 2^{t - 1} - 2)
#     core type: ExprTuple
#     sub-expressions: 79, 19
# 17. 1 / 4
#     core type: Operation
#     operator: 39
#     operands: 20
# 18. (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta)))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))))
#     core type: Operation
#     operator: 73
#     operands: 21
# 19. 2^{t - 1} - 2
#     core type: Operation
#     operator: 73
#     operands: 22
# 20. (1, 4)
#     core type: ExprTuple
#     sub-expressions: 79, 23
# 21. (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} 1 / (l - (2^{t} * delta)), Sum_{l=eps + 1}^{2^{t - 1}} 1 / (l - (2^{t} * delta)))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. (2^{t - 1}, -2)
#     core type: ExprTuple
#     sub-expressions: 64, 26
# 23. 4
#     core type: Literal
#     sub-expressions:
# 24. Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} 1 / (l - (2^{t} * delta))
#     core type: Operation
#     operator: 28
#     operand: 31
# 25. Sum_{l=eps + 1}^{2^{t - 1}} 1 / (l - (2^{t} * delta))
#     core type: Operation
#     operator: 28
#     operand: 32
# 26. -2
#     core type: Operation
#     operator: 77
#     operand: 72
# 27. (l -> {1 / (l - (2^{t} * delta)) if l in {-2^{t - 1} + 1...-(eps + 1)}.)
#     core type: ExprTuple
#     sub-expressions: 31
# 28. Sum
#     core type: Literal
#     sub-expressions:
# 29. (l -> {1 / (l - (2^{t} * delta)) if l in {eps + 1...2^{t - 1}}.)
#     core type: ExprTuple
#     sub-expressions: 32
# 30. (2)
#     core type: ExprTuple
#     sub-expressions: 72
# 31. l -> {1 / (l - (2^{t} * delta)) if l in {-2^{t - 1} + 1...-(eps + 1)}.
#     core type: Lambda
#     parameter: 52
#     body: 33
# 32. l -> {1 / (l - (2^{t} * delta)) if l in {eps + 1...2^{t - 1}}.
#     core type: Lambda
#     parameter: 52
#     body: 34
# 33. {1 / (l - (2^{t} * delta)) if l in {-2^{t - 1} + 1...-(eps + 1)}.
#     core type: Conditional
#     value: 36
#     condition: 35
# 34. {1 / (l - (2^{t} * delta)) if l in {eps + 1...2^{t - 1}}.
#     core type: Conditional
#     value: 36
#     condition: 37
# 35. l in {-2^{t - 1} + 1...-(eps + 1)}
#     core type: Operation
#     operator: 41
#     operands: 38
# 36. 1 / (l - (2^{t} * delta))
#     core type: Operation
#     operator: 39
#     operands: 40
# 37. l in {eps + 1...2^{t - 1}}
#     core type: Operation
#     operator: 41
#     operands: 42
# 38. (l, {-2^{t - 1} + 1...-(eps + 1)})
#     core type: ExprTuple
#     sub-expressions: 52, 43
# 39. /
#     core type: Literal
#     sub-expressions:
# 40. (1, l - (2^{t} * delta))
#     core type: ExprTuple
#     sub-expressions: 79, 44
# 41. in
#     core type: Literal
#     sub-expressions:
# 42. (l, {eps + 1...2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 52, 45
# 43. {-2^{t - 1} + 1...-(eps + 1)}
#     core type: Operation
#     operator: 48
#     operands: 46
# 44. l - (2^{t} * delta)
#     core type: Operation
#     operator: 73
#     operands: 47
# 45. {eps + 1...2^{t - 1}}
#     core type: Operation
#     operator: 48
#     operands: 49
# 46. (-2^{t - 1} + 1, -(eps + 1))
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 47. (l, -(2^{t} * delta))
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 48. Interval
#     core type: Literal
#     sub-expressions:
# 49. (eps + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 58, 64
# 50. -2^{t - 1} + 1
#     core type: Operation
#     operator: 73
#     operands: 54
# 51. -(eps + 1)
#     core type: Operation
#     operator: 77
#     operand: 58
# 52. l
#     core type: Variable
#     sub-expressions:
# 53. -(2^{t} * delta)
#     core type: Operation
#     operator: 77
#     operand: 59
# 54. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 57, 79
# 55. (eps + 1)
#     core type: ExprTuple
#     sub-expressions: 58
# 56. (2^{t} * delta)
#     core type: ExprTuple
#     sub-expressions: 59
# 57. -2^{t - 1}
#     core type: Operation
#     operator: 77
#     operand: 64
# 58. eps + 1
#     core type: Operation
#     operator: 73
#     operands: 61
# 59. 2^{t} * delta
#     core type: Operation
#     operator: 62
#     operands: 63
# 60. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 64
# 61. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 65, 79
# 62. *
#     core type: Literal
#     sub-expressions:
# 63. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 64. 2^{t - 1}
#     core type: Operation
#     operator: 69
#     operands: 68
# 65. eps
#     core type: Variable
#     sub-expressions:
# 66. 2^{t}
#     core type: Operation
#     operator: 69
#     operands: 70
# 67. delta
#     core type: Literal
#     sub-expressions:
# 68. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 72, 71
# 69. Exp
#     core type: Literal
#     sub-expressions:
# 70. (2, t)
#     core type: ExprTuple
#     sub-expressions: 72, 75
# 71. t - 1
#     core type: Operation
#     operator: 73
#     operands: 74
# 72. 2
#     core type: Literal
#     sub-expressions:
# 73. +
#     core type: Literal
#     sub-expressions:
# 74. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 75, 76
# 75. t
#     core type: Literal
#     sub-expressions:
# 76. -1
#     core type: Operation
#     operator: 77
#     operand: 79
# 77. -
#     core type: Literal
#     sub-expressions:
# 78. (1)
#     core type: ExprTuple
#     sub-expressions: 79
# 79. 1
#     core type: Literal
#     sub-expressions:
