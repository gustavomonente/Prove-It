# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#neg_domain_in_full_domain_sans_zero">neg_domain_in_full_domain_sans_zero</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.QPE import neg_domain_in_full_domain_sans_zero

# %%
# check that the built expression is the same as the stored expression
assert neg_domain_in_full_domain_sans_zero.expr == stored_expr
assert neg_domain_in_full_domain_sans_zero.expr._style_id == stored_expr._style_id
print("Passed sanity check: neg_domain_in_full_domain_sans_zero matches stored_expr")
# Out:
# Passed sanity check: neg_domain_in_full_domain_sans_zero matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(neg_domain_in_full_domain_sans_zero.latex())
# Out:
# \vdash \forall_{\varepsilon \in \{1 \ldots 2^{t - 1} - 2\}}~\left(\{-2^{t - 1} + 1 \ldots -\left(\varepsilon + 1\right)\} \subseteq \left(\{-2^{t - 1} + 1 \ldots 2^{t - 1}\} - \left\{0\right\}\right)\right)

# %%
neg_domain_in_full_domain_sans_zero.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
neg_domain_in_full_domain_sans_zero.expr_info()
# Out:
# 0. forall_{eps in {1...2^{t - 1} - 2}} ({-2^{t - 1} + 1...-(eps + 1)} subset_eq ({-2^{t - 1} + 1...2^{t - 1}} - {0}))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (eps -> {{-2^{t - 1} + 1...-(eps + 1)} subset_eq ({-2^{t - 1} + 1...2^{t - 1}} - {0}) if eps in {1...2^{t - 1} - 2}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. eps -> {{-2^{t - 1} + 1...-(eps + 1)} subset_eq ({-2^{t - 1} + 1...2^{t - 1}} - {0}) if eps in {1...2^{t - 1} - 2}.
#    core type: Lambda
#    parameter: 35
#    body: 4
# 4. {{-2^{t - 1} + 1...-(eps + 1)} subset_eq ({-2^{t - 1} + 1...2^{t - 1}} - {0}) if eps in {1...2^{t - 1} - 2}.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. {-2^{t - 1} + 1...-(eps + 1)} subset_eq ({-2^{t - 1} + 1...2^{t - 1}} - {0})
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. eps in {1...2^{t - 1} - 2}
#    core type: Operation
#    operator: 9
#    operands: 10
# ...
