# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, l
from proveit.logic import InSet
from proveit.physics.quantum.QPE import alpha_l_sqrd, neg_domain

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(l, Conditional(alpha_l_sqrd, InSet(l, neg_domain))))
# Out:
# expr: (l -> {|alpha_{l}|^{2} if l in {-2^{t - 1} + 1...-(eps + 1)}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(l \mapsto \left\{\left|\alpha_{l}\right|^{2} \textrm{ if } l \in \{-2^{t - 1} + 1 \ldots -\left(\varepsilon + 1\right)\}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (l -> {|alpha_{l}|^{2} if l in {-2^{t - 1} + 1...-(eps + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. l -> {|alpha_{l}|^{2} if l in {-2^{t - 1} + 1...-(eps + 1)}.
#    core type: Lambda
#    parameter: 22
#    body: 2
# 2. {|alpha_{l}|^{2} if l in {-2^{t - 1} + 1...-(eps + 1)}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. |alpha_{l}|^{2}
#    core type: Operation
#    operator: 29
#    operands: 5
# 4. l in {-2^{t - 1} + 1...-(eps + 1)}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (|alpha_{l}|, 2)
#    core type: ExprTuple
#    sub-expressions: 8, 31
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (l, {-2^{t - 1} + 1...-(eps + 1)})
#    core type: ExprTuple
#    sub-expressions: 22, 9
# 8. |alpha_{l}|
#    core type: Operation
#    operator: 10
#    operand: 14
# 9. {-2^{t - 1} + 1...-(eps + 1)}
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. Abs
#     core type: Literal
#     sub-expressions:
# 11. (alpha_{l})
#     core type: ExprTuple
#     sub-expressions: 14
# 12. Interval
#     core type: Literal
#     sub-expressions:
# 13. (-2^{t - 1} + 1, -(eps + 1))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. alpha_{l}
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. -2^{t - 1} + 1
#     core type: Operation
#     operator: 33
#     operands: 19
# 16. -(eps + 1)
#     core type: Operation
#     operator: 37
#     operand: 24
# 17. SUB_INDEXED
#     core type: Literal
#     sub-expressions:
# 18. (alpha, l)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 23, 39
# 20. (eps + 1)
#     core type: ExprTuple
#     sub-expressions: 24
# 21. alpha
#     core type: Literal
#     sub-expressions:
# 22. l
#     core type: Variable
#     sub-expressions:
# 23. -2^{t - 1}
#     core type: Operation
#     operator: 37
#     operand: 27
# 24. eps + 1
#     core type: Operation
#     operator: 33
#     operands: 26
# 25. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 27
# 26. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 28, 39
# 27. 2^{t - 1}
#     core type: Operation
#     operator: 29
#     operands: 30
# 28. eps
#     core type: Variable
#     sub-expressions:
# 29. Exp
#     core type: Literal
#     sub-expressions:
# 30. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 31. 2
#     core type: Literal
#     sub-expressions:
# 32. t - 1
#     core type: Operation
#     operator: 33
#     operands: 34
# 33. +
#     core type: Literal
#     sub-expressions:
# 34. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 35. t
#     core type: Literal
#     sub-expressions:
# 36. -1
#     core type: Operation
#     operator: 37
#     operand: 39
# 37. -
#     core type: Literal
#     sub-expressions:
# 38. (1)
#     core type: ExprTuple
#     sub-expressions: 39
# 39. 1
#     core type: Literal
#     sub-expressions:
