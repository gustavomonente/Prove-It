# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, l
from proveit.logic import InSet
from proveit.numbers import frac, one
from proveit.physics.quantum.QPE import diff_l_scaled_delta, pos_domain

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(l, Conditional(frac(one, diff_l_scaled_delta), InSet(l, pos_domain))))
# Out:
# expr: (l -> {1 / (l - (2^{t} * delta)) if l in {eps + 1...2^{t - 1}}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(l \mapsto \left\{\frac{1}{l - \left(2^{t} \cdot \delta\right)} \textrm{ if } l \in \{\varepsilon + 1 \ldots 2^{t - 1}\}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (l -> {1 / (l - (2^{t} * delta)) if l in {eps + 1...2^{t - 1}}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. l -> {1 / (l - (2^{t} * delta)) if l in {eps + 1...2^{t - 1}}.
#    core type: Lambda
#    parameter: 14
#    body: 2
# 2. {1 / (l - (2^{t} * delta)) if l in {eps + 1...2^{t - 1}}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. 1 / (l - (2^{t} * delta))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. l in {eps + 1...2^{t - 1}}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. /
#    core type: Literal
#    sub-expressions:
# 6. (1, l - (2^{t} * delta))
#    core type: ExprTuple
#    sub-expressions: 37, 9
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (l, {eps + 1...2^{t - 1}})
#    core type: ExprTuple
#    sub-expressions: 14, 10
# 9. l - (2^{t} * delta)
#    core type: Operation
#    operator: 26
#    operands: 11
# 10. {eps + 1...2^{t - 1}}
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (l, -(2^{t} * delta))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. Interval
#     core type: Literal
#     sub-expressions:
# 13. (eps + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. l
#     core type: Variable
#     sub-expressions:
# 15. -(2^{t} * delta)
#     core type: Operation
#     operator: 33
#     operand: 21
# 16. eps + 1
#     core type: Operation
#     operator: 26
#     operands: 19
# 17. 2^{t - 1}
#     core type: Operation
#     operator: 31
#     operands: 20
# 18. (2^{t} * delta)
#     core type: ExprTuple
#     sub-expressions: 21
# 19. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 22, 37
# 20. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 35, 23
# 21. 2^{t} * delta
#     core type: Operation
#     operator: 24
#     operands: 25
# 22. eps
#     core type: Variable
#     sub-expressions:
# 23. t - 1
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. *
#     core type: Literal
#     sub-expressions:
# 25. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 26. +
#     core type: Literal
#     sub-expressions:
# 27. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 36, 30
# 28. 2^{t}
#     core type: Operation
#     operator: 31
#     operands: 32
# 29. delta
#     core type: Literal
#     sub-expressions:
# 30. -1
#     core type: Operation
#     operator: 33
#     operand: 37
# 31. Exp
#     core type: Literal
#     sub-expressions:
# 32. (2, t)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 33. -
#     core type: Literal
#     sub-expressions:
# 34. (1)
#     core type: ExprTuple
#     sub-expressions: 37
# 35. 2
#     core type: Literal
#     sub-expressions:
# 36. t
#     core type: Literal
#     sub-expressions:
# 37. 1
#     core type: Literal
#     sub-expressions:
