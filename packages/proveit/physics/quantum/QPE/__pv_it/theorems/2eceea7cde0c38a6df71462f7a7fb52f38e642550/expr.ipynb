# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Exp, Integer, Mult, e, frac, i, pi, two
from proveit.physics.quantum.QPE import ModAdd, two_pow_t

# %%
# build up the expression from sub-expressions
expr = Forall([a, b], Equals(Exp(e, frac(Mult(two, pi, i, ModAdd(a, b)), two_pow_t)), Exp(e, frac(Mult(two, pi, i, Add(a, b)), two_pow_t))), domains = [Integer, Integer])
# Out:
# expr: forall_{a, b in Integer} (e^{(2 * pi * i * (a MOD_ADD b)) / 2^{t}} = e^{(2 * pi * i * (a + b)) / 2^{t}})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a, b \in \mathbb{Z}}~\left(\mathsf{e}^{\frac{2 \cdot \pi \cdot \mathsf{i} \cdot \left(a \oplus b\right)}{2^{t}}} = \mathsf{e}^{\frac{2 \cdot \pi \cdot \mathsf{i} \cdot \left(a + b\right)}{2^{t}}}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a, b in Integer} (e^{(2 * pi * i * (a MOD_ADD b)) / 2^{t}} = e^{(2 * pi * i * (a + b)) / 2^{t}})
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b) -> {e^{(2 * pi * i * (a MOD_ADD b)) / 2^{t}} = e^{(2 * pi * i * (a + b)) / 2^{t}} if a in Integer ,  b in Integer.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b) -> {e^{(2 * pi * i * (a MOD_ADD b)) / 2^{t}} = e^{(2 * pi * i * (a + b)) / 2^{t}} if a in Integer ,  b in Integer.
#    core type: Lambda
#    parameters: 43\n   body: 4
# 4. {e^{(2 * pi * i * (a MOD_ADD b)) / 2^{t}} = e^{(2 * pi * i * (a + b)) / 2^{t}} if a in Integer ,  b in Integer.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. e^{(2 * pi * i * (a MOD_ADD b)) / 2^{t}} = e^{(2 * pi * i * (a + b)) / 2^{t}}
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a in Integer) and (b in Integer)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (e^{(2 * pi * i * (a MOD_ADD b)) / 2^{t}}, e^{(2 * pi * i * (a + b)) / 2^{t}})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (a in Integer, b in Integer)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. e^{(2 * pi * i * (a MOD_ADD b)) / 2^{t}}
#     core type: Operation
#     operator: 33
#     operands: 15
# 12. e^{(2 * pi * i * (a + b)) / 2^{t}}
#     core type: Operation
#     operator: 33
#     operands: 16
# 13. a in Integer
#     core type: Operation
#     operator: 18
#     operands: 17
# 14. b in Integer
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. (e, (2 * pi * i * (a MOD_ADD b)) / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 21, 20
# 16. (e, (2 * pi * i * (a + b)) / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 17. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 44, 23
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 45, 23
# 20. (2 * pi * i * (a MOD_ADD b)) / 2^{t}
#     core type: Operation
#     operator: 25
#     operands: 24
# 21. e
#     core type: Literal
#     sub-expressions:
# 22. (2 * pi * i * (a + b)) / 2^{t}
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. Integer
#     core type: Literal
#     sub-expressions:
# 24. (2 * pi * i * (a MOD_ADD b), 2^{t})
#     core type: ExprTuple
#     sub-expressions: 27, 29
# 25. /
#     core type: Literal
#     sub-expressions:
# 26. (2 * pi * i * (a + b), 2^{t})
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 27. 2 * pi * i * (a MOD_ADD b)
#     core type: Operation
#     operator: 31
#     operands: 30
# 28. 2 * pi * i * (a + b)
#     core type: Operation
#     operator: 31
#     operands: 32
# 29. 2^{t}
#     core type: Operation
#     operator: 33
#     operands: 34
# 30. (2, pi, i, a MOD_ADD b)
#     core type: ExprTuple
#     sub-expressions: 39, 36, 37, 35
# 31. *
#     core type: Literal
#     sub-expressions:
# 32. (2, pi, i, a + b)
#     core type: ExprTuple
#     sub-expressions: 39, 36, 37, 38
# 33. Exp
#     core type: Literal
#     sub-expressions:
# 34. (2, t)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 35. a MOD_ADD b
#     core type: Operation
#     operator: 41
#     operands: 43
# 36. pi
#     core type: Literal
#     sub-expressions:
# 37. i
#     core type: Literal
#     sub-expressions:
# 38. a + b
#     core type: Operation
#     operator: 42
#     operands: 43
# 39. 2
#     core type: Literal
#     sub-expressions:
# 40. t
#     core type: Literal
#     sub-expressions:
# 41. MOD_ADD
#     core type: Literal
#     sub-expressions:
# 42. +
#     core type: Literal
#     sub-expressions:
# 43. (a, b)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 44. a
#     core type: Variable
#     sub-expressions:
# 45. b
#     core type: Variable
#     sub-expressions:
