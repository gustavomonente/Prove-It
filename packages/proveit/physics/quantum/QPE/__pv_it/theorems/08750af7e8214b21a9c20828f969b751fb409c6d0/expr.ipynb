# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, l
from proveit.numbers import Sum, frac, one
from proveit.physics.quantum.QPE import diff_l_scaled_delta, neg_domain, pos_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = frac(one, diff_l_scaled_delta)
expr = ExprTuple(Sum(sub_expr1, sub_expr2, domains = [neg_domain]), Sum(sub_expr1, sub_expr2, domains = [pos_domain]))
# Out:
# expr: (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} 1 / (l - (2^{t} * delta)), Sum_{l=eps + 1}^{2^{t - 1}} 1 / (l - (2^{t} * delta)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{l=-2^{t - 1} + 1}^{-\left(\varepsilon + 1\right)} \frac{1}{l - \left(2^{t} \cdot \delta\right)}, \sum_{l=\varepsilon + 1}^{2^{t - 1}} \frac{1}{l - \left(2^{t} \cdot \delta\right)}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} 1 / (l - (2^{t} * delta)), Sum_{l=eps + 1}^{2^{t - 1}} 1 / (l - (2^{t} * delta)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} 1 / (l - (2^{t} * delta))
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. Sum_{l=eps + 1}^{2^{t - 1}} 1 / (l - (2^{t} * delta))
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. (l -> {1 / (l - (2^{t} * delta)) if l in {-2^{t - 1} + 1...-(eps + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. Sum
#    core type: Literal
#    sub-expressions:
# 5. (l -> {1 / (l - (2^{t} * delta)) if l in {eps + 1...2^{t - 1}}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. l -> {1 / (l - (2^{t} * delta)) if l in {-2^{t - 1} + 1...-(eps + 1)}.
#    core type: Lambda
#    parameter: 27
#    body: 8
# 7. l -> {1 / (l - (2^{t} * delta)) if l in {eps + 1...2^{t - 1}}.
#    core type: Lambda
#    parameter: 27
#    body: 9
# 8. {1 / (l - (2^{t} * delta)) if l in {-2^{t - 1} + 1...-(eps + 1)}.
#    core type: Conditional
#    value: 11
#    condition: 10
# 9. {1 / (l - (2^{t} * delta)) if l in {eps + 1...2^{t - 1}}.
#    core type: Conditional
#    value: 11
#    condition: 12
# 10. l in {-2^{t - 1} + 1...-(eps + 1)}
#     core type: Operation
#     operator: 16
#     operands: 13
# 11. 1 / (l - (2^{t} * delta))
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. l in {eps + 1...2^{t - 1}}
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. (l, {-2^{t - 1} + 1...-(eps + 1)})
#     core type: ExprTuple
#     sub-expressions: 27, 18
# 14. /
#     core type: Literal
#     sub-expressions:
# 15. (1, l - (2^{t} * delta))
#     core type: ExprTuple
#     sub-expressions: 54, 19
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (l, {eps + 1...2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 27, 20
# 18. {-2^{t - 1} + 1...-(eps + 1)}
#     core type: Operation
#     operator: 23
#     operands: 21
# 19. l - (2^{t} * delta)
#     core type: Operation
#     operator: 48
#     operands: 22
# 20. {eps + 1...2^{t - 1}}
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. (-2^{t - 1} + 1, -(eps + 1))
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 22. (l, -(2^{t} * delta))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 23. Interval
#     core type: Literal
#     sub-expressions:
# 24. (eps + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 33, 39
# 25. -2^{t - 1} + 1
#     core type: Operation
#     operator: 48
#     operands: 29
# 26. -(eps + 1)
#     core type: Operation
#     operator: 52
#     operand: 33
# 27. l
#     core type: Variable
#     sub-expressions:
# 28. -(2^{t} * delta)
#     core type: Operation
#     operator: 52
#     operand: 34
# 29. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 32, 54
# 30. (eps + 1)
#     core type: ExprTuple
#     sub-expressions: 33
# 31. (2^{t} * delta)
#     core type: ExprTuple
#     sub-expressions: 34
# 32. -2^{t - 1}
#     core type: Operation
#     operator: 52
#     operand: 39
# 33. eps + 1
#     core type: Operation
#     operator: 48
#     operands: 36
# 34. 2^{t} * delta
#     core type: Operation
#     operator: 37
#     operands: 38
# 35. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 39
# 36. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 40, 54
# 37. *
#     core type: Literal
#     sub-expressions:
# 38. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 39. 2^{t - 1}
#     core type: Operation
#     operator: 44
#     operands: 43
# 40. eps
#     core type: Variable
#     sub-expressions:
# 41. 2^{t}
#     core type: Operation
#     operator: 44
#     operands: 45
# 42. delta
#     core type: Literal
#     sub-expressions:
# 43. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 47, 46
# 44. Exp
#     core type: Literal
#     sub-expressions:
# 45. (2, t)
#     core type: ExprTuple
#     sub-expressions: 47, 50
# 46. t - 1
#     core type: Operation
#     operator: 48
#     operands: 49
# 47. 2
#     core type: Literal
#     sub-expressions:
# 48. +
#     core type: Literal
#     sub-expressions:
# 49. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 50. t
#     core type: Literal
#     sub-expressions:
# 51. -1
#     core type: Operation
#     operator: 52
#     operand: 54
# 52. -
#     core type: Literal
#     sub-expressions:
# 53. (1)
#     core type: ExprTuple
#     sub-expressions: 54
# 54. 1
#     core type: Literal
#     sub-expressions:
