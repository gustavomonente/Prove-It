# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import eps
from proveit.logic import Forall, SubsetEq
from proveit.numbers import NaturalPos
from proveit.physics.quantum.QPE import full_domain, neg_domain

# %%
# build up the expression from sub-expressions
expr = Forall([eps], SubsetEq(neg_domain, full_domain), domains = [NaturalPos])
# Out:
# expr: forall_{eps in NaturalPos} ({-2^{t - 1} + 1...-(eps + 1)} subset_eq {-2^{t - 1} + 1...2^{t - 1}})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{\varepsilon \in \mathbb{N}^+}~\left(\{-2^{t - 1} + 1 \ldots -\left(\varepsilon + 1\right)\} \subseteq \{-2^{t - 1} + 1 \ldots 2^{t - 1}\}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{eps in NaturalPos} ({-2^{t - 1} + 1...-(eps + 1)} subset_eq {-2^{t - 1} + 1...2^{t - 1}})
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (eps -> {{-2^{t - 1} + 1...-(eps + 1)} subset_eq {-2^{t - 1} + 1...2^{t - 1}} if eps in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. eps -> {{-2^{t - 1} + 1...-(eps + 1)} subset_eq {-2^{t - 1} + 1...2^{t - 1}} if eps in NaturalPos.
#    core type: Lambda
#    parameter: 25
#    body: 4
# 4. {{-2^{t - 1} + 1...-(eps + 1)} subset_eq {-2^{t - 1} + 1...2^{t - 1}} if eps in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. {-2^{t - 1} + 1...-(eps + 1)} subset_eq {-2^{t - 1} + 1...2^{t - 1}}
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. eps in NaturalPos
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. subset_eq
#    core type: Literal
#    sub-expressions:
# 8. ({-2^{t - 1} + 1...-(eps + 1)}, {-2^{t - 1} + 1...2^{t - 1}})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (eps, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 25, 13
# 11. {-2^{t - 1} + 1...-(eps + 1)}
#     core type: Operation
#     operator: 15
#     operands: 14
# 12. {-2^{t - 1} + 1...2^{t - 1}}
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. NaturalPos
#     core type: Literal
#     sub-expressions:
# 14. (-2^{t - 1} + 1, -(eps + 1))
#     core type: ExprTuple
#     sub-expressions: 18, 17
# 15. Interval
#     core type: Literal
#     sub-expressions:
# 16. (-2^{t - 1} + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 18, 26
# 17. -(eps + 1)
#     core type: Operation
#     operator: 35
#     operand: 21
# 18. -2^{t - 1} + 1
#     core type: Operation
#     operator: 31
#     operands: 20
# 19. (eps + 1)
#     core type: ExprTuple
#     sub-expressions: 21
# 20. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 22, 37
# 21. eps + 1
#     core type: Operation
#     operator: 31
#     operands: 23
# 22. -2^{t - 1}
#     core type: Operation
#     operator: 35
#     operand: 26
# 23. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 25, 37
# 24. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 26
# 25. eps
#     core type: Variable
#     sub-expressions:
# 26. 2^{t - 1}
#     core type: Operation
#     operator: 27
#     operands: 28
# 27. Exp
#     core type: Literal
#     sub-expressions:
# 28. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 29. 2
#     core type: Literal
#     sub-expressions:
# 30. t - 1
#     core type: Operation
#     operator: 31
#     operands: 32
# 31. +
#     core type: Literal
#     sub-expressions:
# 32. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 33. t
#     core type: Literal
#     sub-expressions:
# 34. -1
#     core type: Operation
#     operator: 35
#     operand: 37
# 35. -
#     core type: Literal
#     sub-expressions:
# 36. (1)
#     core type: ExprTuple
#     sub-expressions: 37
# 37. 1
#     core type: Literal
#     sub-expressions:
