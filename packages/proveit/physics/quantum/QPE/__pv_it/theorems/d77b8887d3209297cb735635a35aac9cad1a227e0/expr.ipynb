# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, eps
from proveit.logic import InSet
from proveit.numbers import NaturalPos, Real
from proveit.physics.quantum.QPE import Psuccess

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(eps, Conditional(InSet(Psuccess(eps), Real), InSet(eps, NaturalPos))))
# Out:
# expr: (eps -> {Psuccess(eps) in Real if eps in NaturalPos.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\varepsilon \mapsto \left\{P_{\rm success}(\varepsilon) \in \mathbb{R} \textrm{ if } \varepsilon \in \mathbb{N}^+\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (eps -> {Psuccess(eps) in Real if eps in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. eps -> {Psuccess(eps) in Real if eps in NaturalPos.
#    core type: Lambda
#    parameter: 13
#    body: 2
# 2. {Psuccess(eps) in Real if eps in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. Psuccess(eps) in Real
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. eps in NaturalPos
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (Psuccess(eps), Real)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (eps, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 13, 10
# 8. Psuccess(eps)
#    core type: Operation
#    operator: 11
#    operand: 13
# 9. Real
#    core type: Literal
#    sub-expressions:
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. Psuccess
#     core type: Literal
#     sub-expressions:
# 12. (eps)
#     core type: ExprTuple
#     sub-expressions: 13
# 13. eps
#     core type: Variable
#     sub-expressions:
