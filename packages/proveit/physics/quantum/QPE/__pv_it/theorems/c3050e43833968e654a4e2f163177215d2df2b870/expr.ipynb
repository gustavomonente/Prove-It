# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, l
from proveit.logic import InSet
from proveit.numbers import Integer, Real, frac, one
from proveit.physics.quantum.QPE import diff_l_scaled_delta

# %%
# build up the expression from sub-expressions
expr = Conditional(InSet(frac(one, diff_l_scaled_delta), Real), InSet(l, Integer))
# Out:
# expr: {(1 / (l - (2^{t} * delta))) in Real if l in Integer.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\frac{1}{l - \left(2^{t} \cdot \delta\right)} \in \mathbb{R} \textrm{ if } l \in \mathbb{Z}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(1 / (l - (2^{t} * delta))) in Real if l in Integer.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (1 / (l - (2^{t} * delta))) in Real
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. l in Integer
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (1 / (l - (2^{t} * delta)), Real)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (l, Integer)
#    core type: ExprTuple
#    sub-expressions: 15, 8
# 6. 1 / (l - (2^{t} * delta))
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. Real
#    core type: Literal
#    sub-expressions:
# 8. Integer
#    core type: Literal
#    sub-expressions:
# 9. /
#    core type: Literal
#    sub-expressions:
# 10. (1, l - (2^{t} * delta))
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. 1
#     core type: Literal
#     sub-expressions:
# 12. l - (2^{t} * delta)
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (l, -(2^{t} * delta))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. l
#     core type: Variable
#     sub-expressions:
# 16. -(2^{t} * delta)
#     core type: Operation
#     operator: 17
#     operand: 19
# 17. -
#     core type: Literal
#     sub-expressions:
# 18. (2^{t} * delta)
#     core type: ExprTuple
#     sub-expressions: 19
# 19. 2^{t} * delta
#     core type: Operation
#     operator: 20
#     operands: 21
# 20. *
#     core type: Literal
#     sub-expressions:
# 21. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 22. 2^{t}
#     core type: Operation
#     operator: 24
#     operands: 25
# 23. delta
#     core type: Literal
#     sub-expressions:
# 24. Exp
#     core type: Literal
#     sub-expressions:
# 25. (2, t)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 26. 2
#     core type: Literal
#     sub-expressions:
# 27. t
#     core type: Literal
#     sub-expressions:
