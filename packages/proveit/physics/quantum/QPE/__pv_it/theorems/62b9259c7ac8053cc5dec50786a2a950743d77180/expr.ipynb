# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, eps
from proveit.logic import InSet, SubsetEq
from proveit.physics.quantum.QPE import eps_domain, full_domain_sans_zero, pos_domain

# %%
# build up the expression from sub-expressions
expr = Lambda(eps, Conditional(SubsetEq(pos_domain, full_domain_sans_zero), InSet(eps, eps_domain)))
# Out:
# expr: eps -> {{eps + 1...2^{t - 1}} subset_eq ({-2^{t - 1} + 1...2^{t - 1}} - {0}) if eps in {1...2^{t - 1} - 2}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \varepsilon \mapsto \left\{\{\varepsilon + 1 \ldots 2^{t - 1}\} \subseteq \left(\{-2^{t - 1} + 1 \ldots 2^{t - 1}\} - \left\{0\right\}\right) \textrm{ if } \varepsilon \in \{1 \ldots 2^{t - 1} - 2\}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. eps -> {{eps + 1...2^{t - 1}} subset_eq ({-2^{t - 1} + 1...2^{t - 1}} - {0}) if eps in {1...2^{t - 1} - 2}.
#    core type: Lambda
#    parameter: 25
#    body: 1
# 1. {{eps + 1...2^{t - 1}} subset_eq ({-2^{t - 1} + 1...2^{t - 1}} - {0}) if eps in {1...2^{t - 1} - 2}.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. {eps + 1...2^{t - 1}} subset_eq ({-2^{t - 1} + 1...2^{t - 1}} - {0})
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. eps in {1...2^{t - 1} - 2}
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. subset_eq
#    core type: Literal
#    sub-expressions:
# 5. ({eps + 1...2^{t - 1}}, {-2^{t - 1} + 1...2^{t - 1}} - {0})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (eps, {1...2^{t - 1} - 2})
#    core type: ExprTuple
#    sub-expressions: 25, 10
# 8. {eps + 1...2^{t - 1}}
#    core type: Operation
#    operator: 20
#    operands: 11
# ...
