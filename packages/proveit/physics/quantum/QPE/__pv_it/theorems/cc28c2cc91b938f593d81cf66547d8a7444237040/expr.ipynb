# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b
from proveit.numbers import Mult, e, frac, i, pi, two
from proveit.physics.quantum.QPE import ModAdd, two_pow_t

# %%
# build up the expression from sub-expressions
expr = ExprTuple(e, frac(Mult(two, pi, i, ModAdd(a, b)), two_pow_t))
# Out:
# expr: (e, (2 * pi * i * (a MOD_ADD b)) / 2^{t})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\mathsf{e}, \frac{2 \cdot \pi \cdot \mathsf{i} \cdot \left(a \oplus b\right)}{2^{t}}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (e, (2 * pi * i * (a MOD_ADD b)) / 2^{t})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. e
#    core type: Literal
#    sub-expressions:
# 2. (2 * pi * i * (a MOD_ADD b)) / 2^{t}
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. /
#    core type: Literal
#    sub-expressions:
# 4. (2 * pi * i * (a MOD_ADD b), 2^{t})
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. 2 * pi * i * (a MOD_ADD b)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. 2^{t}
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. *
#    core type: Literal
#    sub-expressions:
# 8. (2, pi, i, a MOD_ADD b)
#    core type: ExprTuple
#    sub-expressions: 14, 11, 12, 13
# 9. Exp
#    core type: Literal
#    sub-expressions:
# 10. (2, t)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 11. pi
#     core type: Literal
#     sub-expressions:
# 12. i
#     core type: Literal
#     sub-expressions:
# 13. a MOD_ADD b
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. 2
#     core type: Literal
#     sub-expressions:
# 15. t
#     core type: Literal
#     sub-expressions:
# 16. MOD_ADD
#     core type: Literal
#     sub-expressions:
# 17. (a, b)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. a
#     core type: Variable
#     sub-expressions:
# 19. b
#     core type: Variable
#     sub-expressions:
