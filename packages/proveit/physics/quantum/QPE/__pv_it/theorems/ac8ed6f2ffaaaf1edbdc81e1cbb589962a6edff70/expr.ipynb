# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, l
from proveit.logic import InSet
from proveit.numbers import Integer, RealNonNeg
from proveit.physics.quantum.QPE import abs_alpha_l

# %%
# build up the expression from sub-expressions
expr = Conditional(InSet(abs_alpha_l, RealNonNeg), InSet(l, Integer))
# Out:
# expr: {|alpha_{l}| in RealNonNeg if l in Integer.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left|\alpha_{l}\right| \in \mathbb{R}^{\ge 0} \textrm{ if } l \in \mathbb{Z}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {|alpha_{l}| in RealNonNeg if l in Integer.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. |alpha_{l}| in RealNonNeg
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. l in Integer
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (|alpha_{l}|, RealNonNeg)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (l, Integer)
#    core type: ExprTuple
#    sub-expressions: 15, 8
# 6. |alpha_{l}|
#    core type: Operation
#    operator: 9
#    operand: 11
# 7. RealNonNeg
#    core type: Literal
#    sub-expressions:
# 8. Integer
#    core type: Literal
#    sub-expressions:
# 9. Abs
#    core type: Literal
#    sub-expressions:
# 10. (alpha_{l})
#     core type: ExprTuple
#     sub-expressions: 11
# 11. alpha_{l}
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. SUB_INDEXED
#     core type: Literal
#     sub-expressions:
# 13. (alpha, l)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. alpha
#     core type: Literal
#     sub-expressions:
# 15. l
#     core type: Variable
#     sub-expressions:
