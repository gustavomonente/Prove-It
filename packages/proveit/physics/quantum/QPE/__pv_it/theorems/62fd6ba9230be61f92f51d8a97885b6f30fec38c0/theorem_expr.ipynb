# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#alpha_l_eval">alpha_l_eval</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.QPE import alpha_l_eval

# %%
# check that the built expression is the same as the stored expression
assert alpha_l_eval.expr == stored_expr
assert alpha_l_eval.expr._style_id == stored_expr._style_id
print("Passed sanity check: alpha_l_eval matches stored_expr")
# Out:
# Passed sanity check: alpha_l_eval matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(alpha_l_eval.latex())
# Out:
# \vdash \forall_{l \in \mathbb{Z}}~\left(\alpha_{l} = \left(\frac{1}{2^{t}} \cdot \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{\frac{-\left(2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot \left(b \oplus l\right)\right)}{2^{t}}} \cdot \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k}\right)\right)\right)\right)

# %%
alpha_l_eval.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
alpha_l_eval.expr_info()
# Out:
# 0. forall_{l in Integer} (alpha_{l} = ((1 / 2^{t}) * (Sum_{k=0}^{2^{t} - 1} (e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k}))))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (l -> {alpha_{l} = ((1 / 2^{t}) * (Sum_{k=0}^{2^{t} - 1} (e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k}))) if l in Integer.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. l -> {alpha_{l} = ((1 / 2^{t}) * (Sum_{k=0}^{2^{t} - 1} (e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k}))) if l in Integer.
#    core type: Lambda
#    parameter: 68
#    body: 4
# 4. {alpha_{l} = ((1 / 2^{t}) * (Sum_{k=0}^{2^{t} - 1} (e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k}))) if l in Integer.
#    core type: Conditional
#    value: 5
#    condition: 6
# ...
