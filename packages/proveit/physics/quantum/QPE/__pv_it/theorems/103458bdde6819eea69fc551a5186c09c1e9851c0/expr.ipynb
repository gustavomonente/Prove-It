# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, l
from proveit.numbers import Abs, Add, Exp, Mult, Neg, e, frac, i, one, pi, two
from proveit.physics.quantum.QPE import abs_alpha_l, delta_, two_pow_t

# %%
# build up the expression from sub-expressions
expr = ExprTuple(abs_alpha_l, frac(Abs(Add(one, Neg(Exp(e, Mult(two, pi, i, Add(Mult(two_pow_t, delta_), Neg(l))))))), Mult(two_pow_t, Abs(Add(one, Neg(Exp(e, Mult(two, pi, i, Add(delta_, Neg(frac(l, two_pow_t)))))))))))
# Out:
# expr: (|alpha_{l}|, |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * |1 - e^{2 * pi * i * (delta - (l / 2^{t}))}|))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left|\alpha_{l}\right|, \frac{\left|1 - \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\left(2^{t} \cdot \delta\right) - l\right)}\right|}{2^{t} \cdot \left|1 - \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\delta - \frac{l}{2^{t}}\right)}\right|}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|alpha_{l}|, |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * |1 - e^{2 * pi * i * (delta - (l / 2^{t}))}|))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |alpha_{l}|
#    core type: Operation
#    operator: 16
#    operand: 5
# 2. |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * |1 - e^{2 * pi * i * (delta - (l / 2^{t}))}|)
#    core type: Operation
#    operator: 51
#    operands: 4
# 3. (alpha_{l})
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}|, 2^{t} * |1 - e^{2 * pi * i * (delta - (l / 2^{t}))}|)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. alpha_{l}
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}|
#    core type: Operation
#    operator: 16
#    operand: 13
# 7. 2^{t} * |1 - e^{2 * pi * i * (delta - (l / 2^{t}))}|
#    core type: Operation
#    operator: 41
#    operands: 11
# 8. SUB_INDEXED
#    core type: Literal
# ...
