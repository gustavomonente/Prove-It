# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#two_pow_t_minus_one_is_nat_pos">two_pow_t_minus_one_is_nat_pos</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.QPE import two_pow_t_minus_one_is_nat_pos

# %%
# check that the built expression is the same as the stored expression
assert two_pow_t_minus_one_is_nat_pos.expr == stored_expr
assert two_pow_t_minus_one_is_nat_pos.expr._style_id == stored_expr._style_id
print("Passed sanity check: two_pow_t_minus_one_is_nat_pos matches stored_expr")
# Out:
# Passed sanity check: two_pow_t_minus_one_is_nat_pos matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(two_pow_t_minus_one_is_nat_pos.latex())
# Out:
# \vdash 2^{t - 1} \in \mathbb{N}^+

# %%
two_pow_t_minus_one_is_nat_pos.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
two_pow_t_minus_one_is_nat_pos.expr_info()
# Out:
# 0. 2^{t - 1} in NaturalPos
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (2^{t - 1}, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 2^{t - 1}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. NaturalPos
#    core type: Literal
#    sub-expressions:
# 5. Exp
#    core type: Literal
#    sub-expressions:
# 6. (2, t - 1)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. 2
#    core type: Literal
#    sub-expressions:
# 8. t - 1
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. t
#     core type: Literal
#     sub-expressions:
# 12. -1
#     core type: Operation
#     operator: 13
#     operand: 15
# 13. -
#     core type: Literal
#     sub-expressions:
# 14. (1)
#     core type: ExprTuple
#     sub-expressions: 15
# 15. 1
# ...
