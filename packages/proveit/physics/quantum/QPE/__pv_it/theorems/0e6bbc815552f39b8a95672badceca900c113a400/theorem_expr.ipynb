# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#scaled_delta_diff_in_interval">scaled_delta_diff_in_interval</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.QPE import scaled_delta_diff_in_interval

# %%
# check that the built expression is the same as the stored expression
assert scaled_delta_diff_in_interval.expr == stored_expr
assert scaled_delta_diff_in_interval.expr._style_id == stored_expr._style_id
print("Passed sanity check: scaled_delta_diff_in_interval matches stored_expr")
# Out:
# Passed sanity check: scaled_delta_diff_in_interval matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(scaled_delta_diff_in_interval.latex())
# Out:
# \vdash \forall_{l \in \{-2^{t - 1} + 1 \ldots 2^{t - 1}\}}~\left(\left(2 \cdot \pi \cdot \left(\delta - \frac{l}{2^{t}}\right)\right) \in \left[-\pi,\pi\right]\right)

# %%
scaled_delta_diff_in_interval.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
scaled_delta_diff_in_interval.expr_info()
# Out:
# 0. forall_{l in {-2^{t - 1} + 1...2^{t - 1}}} ((2 * pi * (delta - (l / 2^{t}))) in [-pi,pi])
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (l -> {(2 * pi * (delta - (l / 2^{t}))) in [-pi,pi] if l in {-2^{t - 1} + 1...2^{t - 1}}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. l -> {(2 * pi * (delta - (l / 2^{t}))) in [-pi,pi] if l in {-2^{t - 1} + 1...2^{t - 1}}.
#    core type: Lambda
#    parameter: 36
#    body: 4
# 4. {(2 * pi * (delta - (l / 2^{t}))) in [-pi,pi] if l in {-2^{t - 1} + 1...2^{t - 1}}.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (2 * pi * (delta - (l / 2^{t}))) in [-pi,pi]
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. l in {-2^{t - 1} + 1...2^{t - 1}}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (2 * pi * (delta - (l / 2^{t})), [-pi,pi])
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
# ...
