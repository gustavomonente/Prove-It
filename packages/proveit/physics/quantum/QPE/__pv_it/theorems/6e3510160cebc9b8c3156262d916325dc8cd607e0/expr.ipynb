# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.numbers.Sum.html">Sum</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.numbers import Sum, frac, one
from proveit.physics.quantum.QPE import diff_l_scaled_delta, neg_domain

# %%
# build up the expression from sub-expressions
expr = Sum([l], frac(one, diff_l_scaled_delta), domains = [neg_domain])
# Out:
# expr: Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} 1 / (l - (2^{t} * delta))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \sum_{l=-2^{t - 1} + 1}^{-\left(\varepsilon + 1\right)} \frac{1}{l - \left(2^{t} \cdot \delta\right)}

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} 1 / (l - (2^{t} * delta))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. Sum
#    core type: Literal
#    sub-expressions:
# 2. (l -> {1 / (l - (2^{t} * delta)) if l in {-2^{t - 1} + 1...-(eps + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. l -> {1 / (l - (2^{t} * delta)) if l in {-2^{t - 1} + 1...-(eps + 1)}.
#    core type: Lambda
#    parameter: 16
#    body: 4
# 4. {1 / (l - (2^{t} * delta)) if l in {-2^{t - 1} + 1...-(eps + 1)}.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. 1 / (l - (2^{t} * delta))
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. l in {-2^{t - 1} + 1...-(eps + 1)}
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. /
#    core type: Literal
#    sub-expressions:
# 8. (1, l - (2^{t} * delta))
#    core type: ExprTuple
#    sub-expressions: 45, 11
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (l, {-2^{t - 1} + 1...-(eps + 1)})
#     core type: ExprTuple
#     sub-expressions: 16, 12
# 11. l - (2^{t} * delta)
#     core type: Operation
#     operator: 39
#     operands: 13
# 12. {-2^{t - 1} + 1...-(eps + 1)}
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (l, -(2^{t} * delta))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. Interval
#     core type: Literal
#     sub-expressions:
# 15. (-2^{t - 1} + 1, -(eps + 1))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. l
#     core type: Variable
#     sub-expressions:
# 17. -(2^{t} * delta)
#     core type: Operation
#     operator: 43
#     operand: 23
# 18. -2^{t - 1} + 1
#     core type: Operation
#     operator: 39
#     operands: 21
# 19. -(eps + 1)
#     core type: Operation
#     operator: 43
#     operand: 25
# 20. (2^{t} * delta)
#     core type: ExprTuple
#     sub-expressions: 23
# 21. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 24, 45
# 22. (eps + 1)
#     core type: ExprTuple
#     sub-expressions: 25
# 23. 2^{t} * delta
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. -2^{t - 1}
#     core type: Operation
#     operator: 43
#     operand: 32
# 25. eps + 1
#     core type: Operation
#     operator: 39
#     operands: 29
# 26. *
#     core type: Literal
#     sub-expressions:
# 27. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 28. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 32
# 29. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 33, 45
# 30. 2^{t}
#     core type: Operation
#     operator: 35
#     operands: 34
# 31. delta
#     core type: Literal
#     sub-expressions:
# 32. 2^{t - 1}
#     core type: Operation
#     operator: 35
#     operands: 36
# 33. eps
#     core type: Variable
#     sub-expressions:
# 34. (2, t)
#     core type: ExprTuple
#     sub-expressions: 37, 41
# 35. Exp
#     core type: Literal
#     sub-expressions:
# 36. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 37. 2
#     core type: Literal
#     sub-expressions:
# 38. t - 1
#     core type: Operation
#     operator: 39
#     operands: 40
# 39. +
#     core type: Literal
#     sub-expressions:
# 40. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 41. t
#     core type: Literal
#     sub-expressions:
# 42. -1
#     core type: Operation
#     operator: 43
#     operand: 45
# 43. -
#     core type: Literal
#     sub-expressions:
# 44. (1)
#     core type: ExprTuple
#     sub-expressions: 45
# 45. 1
#     core type: Literal
#     sub-expressions:
