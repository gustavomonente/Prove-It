# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.numbers.Mult.html">Mult</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, l
from proveit.numbers import Exp, Mult, Neg, e, frac, i, pi, two
from proveit.physics.quantum.QPE import ModAdd, b_, phase_, two_pow_t

# %%
# build up the expression from sub-expressions
expr = Mult(Exp(e, frac(Neg(Mult(two, pi, i, k, ModAdd(b_, l))), two_pow_t)), Exp(e, Mult(two, pi, i, phase_, k)))
# Out:
# expr: e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \mathsf{e}^{\frac{-\left(2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot \left(b \oplus l\right)\right)}{2^{t}}} \cdot \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k}

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k}
#    core type: Operation
#    operator: 21
#    operands: 1
# 1. (e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}}, e^{2 * pi * i * phase * k})
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}}
#    core type: Operation
#    operator: 17
#    operands: 4
# 3. e^{2 * pi * i * phase * k}
#    core type: Operation
#    operator: 17
#    operands: 5
# 4. (e, (-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t})
#    core type: ExprTuple
#    sub-expressions: 7, 6
# 5. (e, 2 * pi * i * phase * k)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. e
#    core type: Literal
#    sub-expressions:
# 8. 2 * pi * i * phase * k
#    core type: Operation
#    operator: 21
#    operands: 11
# 9. /
#    core type: Literal
#    sub-expressions:
# 10. (-(2 * pi * i * k * (b MOD_ADD l)), 2^{t})
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 23, 24, 25, 14, 26
# 12. -(2 * pi * i * k * (b MOD_ADD l))
#     core type: Operation
#     operator: 15
#     operand: 19
# 13. 2^{t}
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. phase
#     core type: Literal
#     sub-expressions:
# 15. -
#     core type: Literal
#     sub-expressions:
# 16. (2 * pi * i * k * (b MOD_ADD l))
#     core type: ExprTuple
#     sub-expressions: 19
# 17. Exp
#     core type: Literal
#     sub-expressions:
# 18. (2, t)
#     core type: ExprTuple
#     sub-expressions: 23, 20
# 19. 2 * pi * i * k * (b MOD_ADD l)
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. t
#     core type: Literal
#     sub-expressions:
# 21. *
#     core type: Literal
#     sub-expressions:
# 22. (2, pi, i, k, b MOD_ADD l)
#     core type: ExprTuple
#     sub-expressions: 23, 24, 25, 26, 27
# 23. 2
#     core type: Literal
#     sub-expressions:
# 24. pi
#     core type: Literal
#     sub-expressions:
# 25. i
#     core type: Literal
#     sub-expressions:
# 26. k
#     core type: Variable
#     sub-expressions:
# 27. b MOD_ADD l
#     core type: Operation
#     operator: 28
#     operands: 29
# 28. MOD_ADD
#     core type: Literal
#     sub-expressions:
# 29. (b, l)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 30. b
#     core type: Literal
#     sub-expressions:
# 31. l
#     core type: Variable
#     sub-expressions:
