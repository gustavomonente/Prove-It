# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, eps, l
from proveit.logic import InSet
from proveit.numbers import Add, LessEq, Mult, Sum, four, frac, one
from proveit.physics.quantum.QPE import Pfail, diff_l_scaled_delta, eps_domain, neg_domain, pos_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = frac(one, diff_l_scaled_delta)
expr = Conditional(LessEq(Pfail(eps), Mult(frac(one, four), Add(Sum(sub_expr1, sub_expr2, domains = [neg_domain]), Sum(sub_expr1, sub_expr2, domains = [pos_domain])))), InSet(eps, eps_domain))
# Out:
# expr: {Pfail(eps) <= ((1 / 4) * ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta)))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta)))))) if eps in {1...2^{t - 1} - 2}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{P_{\rm fail}(\varepsilon) \leq \left(\frac{1}{4} \cdot \left(\left(\sum_{l=-2^{t - 1} + 1}^{-\left(\varepsilon + 1\right)} \frac{1}{l - \left(2^{t} \cdot \delta\right)}\right) + \left(\sum_{l=\varepsilon + 1}^{2^{t - 1}} \frac{1}{l - \left(2^{t} \cdot \delta\right)}\right)\right)\right) \textrm{ if } \varepsilon \in \{1 \ldots 2^{t - 1} - 2\}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {Pfail(eps) <= ((1 / 4) * ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta)))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta)))))) if eps in {1...2^{t - 1} - 2}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. Pfail(eps) <= ((1 / 4) * ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta)))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))))))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. eps in {1...2^{t - 1} - 2}
#    core type: Operation
#    operator: 37
#    operands: 5
# 3. <=
#    core type: Literal
#    sub-expressions:
# 4. (Pfail(eps), (1 / 4) * ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta)))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))))))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (eps, {1...2^{t - 1} - 2})
#    core type: ExprTuple
#    sub-expressions: 61, 8
# 6. Pfail(eps)
#    core type: Operation
#    operator: 9
#    operand: 61
# ...
