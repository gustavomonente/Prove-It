# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#eps_domain">eps_domain</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.numbers.Interval.html">Interval</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.QPE import eps_domain

# %%
# check that the built expression is the same as the stored expression
assert eps_domain == stored_expr
assert eps_domain._style_id == stored_expr._style_id
print("Passed sanity check: eps_domain matches stored_expr")
# Out:
# Passed sanity check: eps_domain matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(eps_domain.latex())
# Out:
# \{1 \ldots 2^{t - 1} - 2\}

# %%
eps_domain.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
eps_domain.expr_info()
# Out:
# 0. {1...2^{t - 1} - 2}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Interval
#    core type: Literal
#    sub-expressions:
# 2. (1, 2^{t - 1} - 2)
#    core type: ExprTuple
#    sub-expressions: 18, 3
# 3. 2^{t - 1} - 2
#    core type: Operation
#    operator: 12
#    operands: 4
# 4. (2^{t - 1}, -2)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. 2^{t - 1}
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. -2
#    core type: Operation
#    operator: 16
#    operand: 11
# 7. Exp
#    core type: Literal
#    sub-expressions:
# 8. (2, t - 1)
#    core type: ExprTuple
#    sub-expressions: 11, 10
# 9. (2)
#    core type: ExprTuple
#    sub-expressions: 11
# 10. t - 1
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. 2
#     core type: Literal
#     sub-expressions:
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. t
#     core type: Literal
# ...
