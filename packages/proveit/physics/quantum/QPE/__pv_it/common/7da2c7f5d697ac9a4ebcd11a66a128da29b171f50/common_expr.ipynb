# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#abs_a">abs_a</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.numbers.Abs.html">Abs</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.QPE import abs_a

# %%
# check that the built expression is the same as the stored expression
assert abs_a == stored_expr
assert abs_a._style_id == stored_expr._style_id
print("Passed sanity check: abs_a matches stored_expr")
# Out:
# Passed sanity check: abs_a matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(abs_a.latex())
# Out:
# \left|a\right|

# %%
abs_a.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: function
# current value: function
# related methods: ()

# %%
# display the expression information
abs_a.expr_info()
# Out:
# 0. |a|
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. Abs
#    core type: Literal
#    sub-expressions:
# 2. (a)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. a
#    core type: Variable
#    sub-expressions:
