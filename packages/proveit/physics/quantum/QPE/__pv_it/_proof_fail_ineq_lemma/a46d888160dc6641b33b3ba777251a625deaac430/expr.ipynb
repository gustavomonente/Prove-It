# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, k, y
from proveit.logic import Forall
from proveit.numbers import Abs, Add, Exp, LessEq, Mult, Neg, four, frac, one, two
from proveit.physics.quantum.QPE import SubIndexed, alpha_, delta_, full_domain_sans_zero, pos_domain, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(Mult(two_pow_t, delta_))
expr = ExprTuple(Forall([k], LessEq(Exp(Abs(SubIndexed(alpha_, k)), two), frac(one, Mult(four, Exp(Add(k, sub_expr1), two)))), domains = [full_domain_sans_zero]), Forall([y], LessEq(Exp(Abs(SubIndexed(alpha_, y)), two), frac(one, Mult(four, Exp(Add(y, sub_expr1), two)))), domains = [pos_domain]))
# Out:
# expr: (forall_{k in {-2^{t - 1} + 1...2^{t - 1}} - {0}} (|alpha_{k}|^{2} <= (1 / (4 * (k - (2^{t} * delta))^{2}))), forall_{y in {eps + 1...2^{t - 1}}} (|alpha_{y}|^{2} <= (1 / (4 * (y - (2^{t} * delta))^{2}))))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\forall_{k \in \{-2^{t - 1} + 1 \ldots 2^{t - 1}\} - \left\{0\right\}}~\left(\left|\alpha_{k}\right|^{2} \leq \frac{1}{4 \cdot \left(k - \left(2^{t} \cdot \delta\right)\right)^{2}}\right), \forall_{y \in \{\varepsilon + 1 \ldots 2^{t - 1}\}}~\left(\left|\alpha_{y}\right|^{2} \leq \frac{1}{4 \cdot \left(y - \left(2^{t} \cdot \delta\right)\right)^{2}}\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (forall_{k in {-2^{t - 1} + 1...2^{t - 1}} - {0}} (|alpha_{k}|^{2} <= (1 / (4 * (k - (2^{t} * delta))^{2}))), forall_{y in {eps + 1...2^{t - 1}}} (|alpha_{y}|^{2} <= (1 / (4 * (y - (2^{t} * delta))^{2}))))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{k in {-2^{t - 1} + 1...2^{t - 1}} - {0}} (|alpha_{k}|^{2} <= (1 / (4 * (k - (2^{t} * delta))^{2})))
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. forall_{y in {eps + 1...2^{t - 1}}} (|alpha_{y}|^{2} <= (1 / (4 * (y - (2^{t} * delta))^{2})))
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. (k -> {|alpha_{k}|^{2} <= (1 / (4 * (k - (2^{t} * delta))^{2})) if k in ({-2^{t - 1} + 1...2^{t - 1}} - {0}).)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (y -> {|alpha_{y}|^{2} <= (1 / (4 * (y - (2^{t} * delta))^{2})) if y in {eps + 1...2^{t - 1}}.)
#    core type: ExprTuple
#    sub-expressions: 7
# ...
