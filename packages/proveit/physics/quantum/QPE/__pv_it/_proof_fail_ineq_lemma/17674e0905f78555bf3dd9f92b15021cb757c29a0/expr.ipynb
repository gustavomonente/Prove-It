# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, k
from proveit.logic import InSet
from proveit.numbers import Abs, Add, Exp, LessEq, Mult, Neg, four, frac, one, two
from proveit.physics.quantum.QPE import SubIndexed, alpha_, delta_, full_domain_sans_zero, two_pow_t

# %%
# build up the expression from sub-expressions
expr = Lambda(k, Conditional(LessEq(Exp(Abs(SubIndexed(alpha_, k)), two), frac(one, Mult(four, Exp(Add(k, Neg(Mult(two_pow_t, delta_))), two)))), InSet(k, full_domain_sans_zero)))
# Out:
# expr: k -> {|alpha_{k}|^{2} <= (1 / (4 * (k - (2^{t} * delta))^{2})) if k in ({-2^{t - 1} + 1...2^{t - 1}} - {0}).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# k \mapsto \left\{\left|\alpha_{k}\right|^{2} \leq \frac{1}{4 \cdot \left(k - \left(2^{t} \cdot \delta\right)\right)^{2}} \textrm{ if } k \in \left(\{-2^{t - 1} + 1 \ldots 2^{t - 1}\} - \left\{0\right\}\right)\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. k -> {|alpha_{k}|^{2} <= (1 / (4 * (k - (2^{t} * delta))^{2})) if k in ({-2^{t - 1} + 1...2^{t - 1}} - {0}).
#    core type: Lambda
#    parameter: 41
#    body: 1
# 1. {|alpha_{k}|^{2} <= (1 / (4 * (k - (2^{t} * delta))^{2})) if k in ({-2^{t - 1} + 1...2^{t - 1}} - {0}).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. |alpha_{k}|^{2} <= (1 / (4 * (k - (2^{t} * delta))^{2}))
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. k in ({-2^{t - 1} + 1...2^{t - 1}} - {0})
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. <=
#    core type: Literal
#    sub-expressions:
# 5. (|alpha_{k}|^{2}, 1 / (4 * (k - (2^{t} * delta))^{2}))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (k, {-2^{t - 1} + 1...2^{t - 1}} - {0})
#    core type: ExprTuple
#    sub-expressions: 41, 10
# 8. |alpha_{k}|^{2}
#    core type: Operation
#    operator: 55
#    operands: 11
# ...
