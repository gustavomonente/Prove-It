# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, y
from proveit.logic import InSet
from proveit.numbers import Abs, Add, Exp, LessEq, Mult, Neg, four, frac, one, two
from proveit.physics.quantum.QPE import SubIndexed, alpha_, delta_, pos_domain, two_pow_t

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(y, Conditional(LessEq(Exp(Abs(SubIndexed(alpha_, y)), two), frac(one, Mult(four, Exp(Add(y, Neg(Mult(two_pow_t, delta_))), two)))), InSet(y, pos_domain))))
# Out:
# expr: (y -> {|alpha_{y}|^{2} <= (1 / (4 * (y - (2^{t} * delta))^{2})) if y in {eps + 1...2^{t - 1}}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(y \mapsto \left\{\left|\alpha_{y}\right|^{2} \leq \frac{1}{4 \cdot \left(y - \left(2^{t} \cdot \delta\right)\right)^{2}} \textrm{ if } y \in \{\varepsilon + 1 \ldots 2^{t - 1}\}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (y -> {|alpha_{y}|^{2} <= (1 / (4 * (y - (2^{t} * delta))^{2})) if y in {eps + 1...2^{t - 1}}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. y -> {|alpha_{y}|^{2} <= (1 / (4 * (y - (2^{t} * delta))^{2})) if y in {eps + 1...2^{t - 1}}.
#    core type: Lambda
#    parameter: 41
#    body: 2
# 2. {|alpha_{y}|^{2} <= (1 / (4 * (y - (2^{t} * delta))^{2})) if y in {eps + 1...2^{t - 1}}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. |alpha_{y}|^{2} <= (1 / (4 * (y - (2^{t} * delta))^{2}))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. y in {eps + 1...2^{t - 1}}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. <=
#    core type: Literal
#    sub-expressions:
# 6. (|alpha_{y}|^{2}, 1 / (4 * (y - (2^{t} * delta))^{2}))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (y, {eps + 1...2^{t - 1}})
#    core type: ExprTuple
#    sub-expressions: 41, 11
# ...
