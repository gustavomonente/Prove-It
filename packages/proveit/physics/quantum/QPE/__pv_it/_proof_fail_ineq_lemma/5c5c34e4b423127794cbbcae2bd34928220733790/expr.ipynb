# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k
from proveit.logic import Forall
from proveit.numbers import Abs, Add, Exp, LessEq, Mult, Neg, four, frac, one, two
from proveit.physics.quantum.QPE import SubIndexed, alpha_, delta_, neg_domain, two_pow_t

# %%
# build up the expression from sub-expressions
expr = Forall([k], LessEq(Exp(Abs(SubIndexed(alpha_, k)), two), frac(one, Mult(four, Exp(Add(k, Neg(Mult(two_pow_t, delta_))), two)))), domains = [neg_domain])
# Out:
# expr: forall_{k in {-2^{t - 1} + 1...-(eps + 1)}} (|alpha_{k}|^{2} <= (1 / (4 * (k - (2^{t} * delta))^{2})))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{k \in \{-2^{t - 1} + 1 \ldots -\left(\varepsilon + 1\right)\}}~\left(\left|\alpha_{k}\right|^{2} \leq \frac{1}{4 \cdot \left(k - \left(2^{t} \cdot \delta\right)\right)^{2}}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{k in {-2^{t - 1} + 1...-(eps + 1)}} (|alpha_{k}|^{2} <= (1 / (4 * (k - (2^{t} * delta))^{2})))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (k -> {|alpha_{k}|^{2} <= (1 / (4 * (k - (2^{t} * delta))^{2})) if k in {-2^{t - 1} + 1...-(eps + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. k -> {|alpha_{k}|^{2} <= (1 / (4 * (k - (2^{t} * delta))^{2})) if k in {-2^{t - 1} + 1...-(eps + 1)}.
#    core type: Lambda
#    parameter: 44
#    body: 4
# 4. {|alpha_{k}|^{2} <= (1 / (4 * (k - (2^{t} * delta))^{2})) if k in {-2^{t - 1} + 1...-(eps + 1)}.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. |alpha_{k}|^{2} <= (1 / (4 * (k - (2^{t} * delta))^{2}))
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. k in {-2^{t - 1} + 1...-(eps + 1)}
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. <=
#    core type: Literal
#    sub-expressions:
# ...
