# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, y
from proveit.logic import InSet
from proveit.numbers import Abs, Add, Exp, LessEq, Mult, Neg, four, frac, one, two
from proveit.physics.quantum.QPE import SubIndexed, alpha_, delta_, neg_domain, two_pow_t

# %%
# build up the expression from sub-expressions
expr = Conditional(LessEq(Exp(Abs(SubIndexed(alpha_, y)), two), frac(one, Mult(four, Exp(Add(y, Neg(Mult(two_pow_t, delta_))), two)))), InSet(y, neg_domain))
# Out:
# expr: {|alpha_{y}|^{2} <= (1 / (4 * (y - (2^{t} * delta))^{2})) if y in {-2^{t - 1} + 1...-(eps + 1)}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left|\alpha_{y}\right|^{2} \leq \frac{1}{4 \cdot \left(y - \left(2^{t} \cdot \delta\right)\right)^{2}} \textrm{ if } y \in \{-2^{t - 1} + 1 \ldots -\left(\varepsilon + 1\right)\}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {|alpha_{y}|^{2} <= (1 / (4 * (y - (2^{t} * delta))^{2})) if y in {-2^{t - 1} + 1...-(eps + 1)}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. |alpha_{y}|^{2} <= (1 / (4 * (y - (2^{t} * delta))^{2}))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. y in {-2^{t - 1} + 1...-(eps + 1)}
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. <=
#    core type: Literal
#    sub-expressions:
# 4. (|alpha_{y}|^{2}, 1 / (4 * (y - (2^{t} * delta))^{2}))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (y, {-2^{t - 1} + 1...-(eps + 1)})
#    core type: ExprTuple
#    sub-expressions: 40, 9
# 7. |alpha_{y}|^{2}
#    core type: Operation
#    operator: 55
#    operands: 10
# 8. 1 / (4 * (y - (2^{t} * delta))^{2})
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. {-2^{t - 1} + 1...-(eps + 1)}
#    core type: Operation
#    operator: 13
#    operands: 14
# ...
