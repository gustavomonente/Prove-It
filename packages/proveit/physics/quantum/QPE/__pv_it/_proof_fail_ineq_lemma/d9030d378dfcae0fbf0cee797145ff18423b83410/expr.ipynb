# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, l
from proveit.numbers import Exp, Mult, Sum, four, frac, one, two
from proveit.physics.quantum.QPE import alpha_l_sqrd, diff_l_scaled_delta, pos_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = [pos_domain]
expr = ExprTuple(Sum(sub_expr1, alpha_l_sqrd, domains = sub_expr2), Sum(sub_expr1, frac(one, Mult(four, Exp(diff_l_scaled_delta, two))), domains = sub_expr2))
# Out:
# expr: (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2}, Sum_{l=eps + 1}^{2^{t - 1}} 1 / (4 * (l - (2^{t} * delta))^{2}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{l=\varepsilon + 1}^{2^{t - 1}} \left|\alpha_{l}\right|^{2}, \sum_{l=\varepsilon + 1}^{2^{t - 1}} \frac{1}{4 \cdot \left(l - \left(2^{t} \cdot \delta\right)\right)^{2}}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2}, Sum_{l=eps + 1}^{2^{t - 1}} 1 / (4 * (l - (2^{t} * delta))^{2}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2}
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. Sum_{l=eps + 1}^{2^{t - 1}} 1 / (4 * (l - (2^{t} * delta))^{2})
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. (l -> {|alpha_{l}|^{2} if l in {eps + 1...2^{t - 1}}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. Sum
#    core type: Literal
#    sub-expressions:
# 5. (l -> {1 / (4 * (l - (2^{t} * delta))^{2}) if l in {eps + 1...2^{t - 1}}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. l -> {|alpha_{l}|^{2} if l in {eps + 1...2^{t - 1}}.
#    core type: Lambda
#    parameter: 43
#    body: 8
# 7. l -> {1 / (4 * (l - (2^{t} * delta))^{2}) if l in {eps + 1...2^{t - 1}}.
#    core type: Lambda
#    parameter: 43
#    body: 9
# 8. {|alpha_{l}|^{2} if l in {eps + 1...2^{t - 1}}.
# ...
