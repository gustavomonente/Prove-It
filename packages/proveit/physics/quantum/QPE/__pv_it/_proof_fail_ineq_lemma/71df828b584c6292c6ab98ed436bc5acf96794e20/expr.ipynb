# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, y
from proveit.logic import Forall, Implies
from proveit.numbers import Abs, Add, Exp, LessEq, Mult, Neg, four, frac, one, two
from proveit.physics.quantum.QPE import SubIndexed, alpha_, delta_, full_domain_sans_zero, neg_domain, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(Mult(two_pow_t, delta_))
expr = Implies(Forall([k], LessEq(Exp(Abs(SubIndexed(alpha_, k)), two), frac(one, Mult(four, Exp(Add(k, sub_expr1), two)))), domains = [full_domain_sans_zero]), Forall([y], LessEq(Exp(Abs(SubIndexed(alpha_, y)), two), frac(one, Mult(four, Exp(Add(y, sub_expr1), two)))), domains = [neg_domain]))
# Out:
# expr: [forall_{k in {-2^{t - 1} + 1...2^{t - 1}} - {0}} (|alpha_{k}|^{2} <= (1 / (4 * (k - (2^{t} * delta))^{2})))] => [forall_{y in {-2^{t - 1} + 1...-(eps + 1)}} (|alpha_{y}|^{2} <= (1 / (4 * (y - (2^{t} * delta))^{2})))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left[\forall_{k \in \{-2^{t - 1} + 1 \ldots 2^{t - 1}\} - \left\{0\right\}}~\left(\left|\alpha_{k}\right|^{2} \leq \frac{1}{4 \cdot \left(k - \left(2^{t} \cdot \delta\right)\right)^{2}}\right)\right] \Rightarrow \left[\forall_{y \in \{-2^{t - 1} + 1 \ldots -\left(\varepsilon + 1\right)\}}~\left(\left|\alpha_{y}\right|^{2} \leq \frac{1}{4 \cdot \left(y - \left(2^{t} \cdot \delta\right)\right)^{2}}\right)\right]

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. [forall_{k in {-2^{t - 1} + 1...2^{t - 1}} - {0}} (|alpha_{k}|^{2} <= (1 / (4 * (k - (2^{t} * delta))^{2})))] => [forall_{y in {-2^{t - 1} + 1...-(eps + 1)}} (|alpha_{y}|^{2} <= (1 / (4 * (y - (2^{t} * delta))^{2})))]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{k in {-2^{t - 1} + 1...2^{t - 1}} - {0}} (|alpha_{k}|^{2} <= (1 / (4 * (k - (2^{t} * delta))^{2}))), forall_{y in {-2^{t - 1} + 1...-(eps + 1)}} (|alpha_{y}|^{2} <= (1 / (4 * (y - (2^{t} * delta))^{2}))))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{k in {-2^{t - 1} + 1...2^{t - 1}} - {0}} (|alpha_{k}|^{2} <= (1 / (4 * (k - (2^{t} * delta))^{2})))
#    core type: Operation
#    operator: 6
#    operand: 8
# 4. forall_{y in {-2^{t - 1} + 1...-(eps + 1)}} (|alpha_{y}|^{2} <= (1 / (4 * (y - (2^{t} * delta))^{2})))
#    core type: Operation
#    operator: 6
#    operand: 9
# ...
