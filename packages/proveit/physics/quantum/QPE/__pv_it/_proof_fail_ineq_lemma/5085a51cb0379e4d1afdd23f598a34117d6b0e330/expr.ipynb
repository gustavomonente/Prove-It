# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, y
from proveit.numbers import Add, Exp, Mult, Neg, four, two
from proveit.physics.quantum.QPE import delta_, two_pow_t

# %%
# build up the expression from sub-expressions
expr = ExprTuple(four, Exp(Add(y, Neg(Mult(two_pow_t, delta_))), two))
# Out:
# expr: (4, (y - (2^{t} * delta))^{2})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(4, \left(y - \left(2^{t} \cdot \delta\right)\right)^{2}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (4, (y - (2^{t} * delta))^{2})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 4
#    core type: Literal
#    sub-expressions:
# 2. (y - (2^{t} * delta))^{2}
#    core type: Operation
#    operator: 16
#    operands: 3
# 3. (y - (2^{t} * delta), 2)
#    core type: ExprTuple
#    sub-expressions: 4, 18
# 4. y - (2^{t} * delta)
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (y, -(2^{t} * delta))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. y
#    core type: Variable
#    sub-expressions:
# 8. -(2^{t} * delta)
#    core type: Operation
#    operator: 9
#    operand: 11
# 9. -
#    core type: Literal
#    sub-expressions:
# 10. (2^{t} * delta)
#     core type: ExprTuple
#     sub-expressions: 11
# 11. 2^{t} * delta
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. *
#     core type: Literal
#     sub-expressions:
# 13. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. 2^{t}
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. delta
#     core type: Literal
#     sub-expressions:
# 16. Exp
#     core type: Literal
#     sub-expressions:
# 17. (2, t)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. 2
#     core type: Literal
#     sub-expressions:
# 19. t
#     core type: Literal
#     sub-expressions:
