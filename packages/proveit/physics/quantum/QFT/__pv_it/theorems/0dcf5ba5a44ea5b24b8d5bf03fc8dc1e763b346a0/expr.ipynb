# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QFT</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, k, l, n
from proveit.linalg import MatrixProd
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Exp, Interval, Mult, Neg, e, frac, i, one, pi, sqrt, two, zero
from proveit.physics.quantum import RegisterBra, RegisterKet
from proveit.physics.quantum.QFT import InverseFourierTransform

# %%
# build up the expression from sub-expressions
sub_expr1 = Exp(two, n)
sub_expr2 = Interval(zero, Add(sub_expr1, Neg(one)))
expr = Lambda([k, l], Conditional(Equals(MatrixProd(RegisterBra(l, n), InverseFourierTransform(n), RegisterKet(k, n)), Mult(frac(one, sqrt(sub_expr1)), Exp(e, frac(Neg(Mult(two, pi, i, k, l)), sub_expr1)))), And(InSet(k, sub_expr2), InSet(l, sub_expr2))))
# Out:
# expr: (k, l) -> {({n}_〈l| . FT^{dag}(n) . |k〉_{n}) = ((1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}}) if k in {0...2^{n} - 1} ,  l in {0...2^{n} - 1}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(k, l\right) \mapsto \left\{\left({_{n}}\langle l \rvert \thinspace {\mathrm {FT}}^{\dag}(n) \thinspace \lvert k \rangle_{n}\right) = \left(\frac{1}{\sqrt{(2^{n})}} \cdot \mathsf{e}^{\frac{-\left(2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot l\right)}{2^{n}}}\right) \textrm{ if } k \in \{0 \ldots 2^{n} - 1\} ,  l \in \{0 \ldots 2^{n} - 1\}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (k, l) -> {({n}_〈l| . FT^{dag}(n) . |k〉_{n}) = ((1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}}) if k in {0...2^{n} - 1} ,  l in {0...2^{n} - 1}.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (k, l)
#    core type: ExprTuple
#    sub-expressions: 63, 64
# 2. {({n}_〈l| . FT^{dag}(n) . |k〉_{n}) = ((1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}}) if k in {0...2^{n} - 1} ,  l in {0...2^{n} - 1}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. ({n}_〈l| . FT^{dag}(n) . |k〉_{n}) = ((1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}})
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (k in {0...2^{n} - 1}) and (l in {0...2^{n} - 1})
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. ({n}_〈l| . FT^{dag}(n) . |k〉_{n}, (1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (k in {0...2^{n} - 1}, l in {0...2^{n} - 1})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. {n}_〈l| . FT^{dag}(n) . |k〉_{n}
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. (1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}}
#     core type: Operation
#     operator: 58
#     operands: 15
# 11. k in {0...2^{n} - 1}
#     core type: Operation
#     operator: 17
#     operands: 16
# 12. l in {0...2^{n} - 1}
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. .
#     core type: Literal
#     sub-expressions:
# 14. ({n}_〈l|, FT^{dag}(n), |k〉_{n})
#     core type: ExprTuple
#     sub-expressions: 19, 20, 21
# 15. (1 / sqrt((2^{n})), e^{(-(2 * pi * i * k * l)) / 2^{n}})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 16. (k, {0...2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 63, 24
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (l, {0...2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 64, 24
# 19. {n}_〈l|
#     core type: Operation
#     operator: 25
#     operands: 26
# 20. FT^{dag}(n)
#     core type: Operation
#     operator: 27
#     operand: 56
# 21. |k〉_{n}
#     core type: Operation
#     operator: 29
#     operands: 30
# 22. 1 / sqrt((2^{n}))
#     core type: Operation
#     operator: 48
#     operands: 31
# 23. e^{(-(2 * pi * i * k * l)) / 2^{n}}
#     core type: Operation
#     operator: 51
#     operands: 32
# 24. {0...2^{n} - 1}
#     core type: Operation
#     operator: 33
#     operands: 34
# 25. REGISTER_BRA
#     core type: Literal
#     sub-expressions:
# 26. (l, n)
#     core type: ExprTuple
#     sub-expressions: 64, 56
# 27. FT^{dag}
#     core type: Literal
#     sub-expressions:
# 28. (n)
#     core type: ExprTuple
#     sub-expressions: 56
# 29. REGISTER_KET
#     core type: Literal
#     sub-expressions:
# 30. (k, n)
#     core type: ExprTuple
#     sub-expressions: 63, 56
# 31. (1, sqrt((2^{n})))
#     core type: ExprTuple
#     sub-expressions: 57, 35
# 32. (e, (-(2 * pi * i * k * l)) / 2^{n})
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 33. Interval
#     core type: Literal
#     sub-expressions:
# 34. (0, 2^{n} - 1)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 35. sqrt((2^{n}))
#     core type: Operation
#     operator: 51
#     operands: 40
# 36. e
#     core type: Literal
#     sub-expressions:
# 37. (-(2 * pi * i * k * l)) / 2^{n}
#     core type: Operation
#     operator: 48
#     operands: 41
# 38. 0
#     core type: Literal
#     sub-expressions:
# 39. 2^{n} - 1
#     core type: Operation
#     operator: 42
#     operands: 43
# 40. (2^{n}, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 46, 44
# 41. (-(2 * pi * i * k * l), 2^{n})
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 42. +
#     core type: Literal
#     sub-expressions:
# 43. (2^{n}, -1)
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 44. 1 / 2
#     core type: Operation
#     operator: 48
#     operands: 49
# 45. -(2 * pi * i * k * l)
#     core type: Operation
#     operator: 53
#     operand: 55
# 46. 2^{n}
#     core type: Operation
#     operator: 51
#     operands: 52
# 47. -1
#     core type: Operation
#     operator: 53
#     operand: 57
# 48. /
#     core type: Literal
#     sub-expressions:
# 49. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 57, 60
# 50. (2 * pi * i * k * l)
#     core type: ExprTuple
#     sub-expressions: 55
# 51. Exp
#     core type: Literal
#     sub-expressions:
# 52. (2, n)
#     core type: ExprTuple
#     sub-expressions: 60, 56
# 53. -
#     core type: Literal
#     sub-expressions:
# 54. (1)
#     core type: ExprTuple
#     sub-expressions: 57
# 55. 2 * pi * i * k * l
#     core type: Operation
#     operator: 58
#     operands: 59
# 56. n
#     core type: Variable
#     sub-expressions:
# 57. 1
#     core type: Literal
#     sub-expressions:
# 58. *
#     core type: Literal
#     sub-expressions:
# 59. (2, pi, i, k, l)
#     core type: ExprTuple
#     sub-expressions: 60, 61, 62, 63, 64
# 60. 2
#     core type: Literal
#     sub-expressions:
# 61. pi
#     core type: Literal
#     sub-expressions:
# 62. i
#     core type: Literal
#     sub-expressions:
# 63. k
#     core type: Variable
#     sub-expressions:
# 64. l
#     core type: Variable
#     sub-expressions:
