# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#inv_f_ton_matrix_elem">inv_f_ton_matrix_elem</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QFT</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.QFT import inv_f_ton_matrix_elem

# %%
# check that the built expression is the same as the stored expression
assert inv_f_ton_matrix_elem.expr == stored_expr
assert inv_f_ton_matrix_elem.expr._style_id == stored_expr._style_id
print("Passed sanity check: inv_f_ton_matrix_elem matches stored_expr")
# Out:
# Passed sanity check: inv_f_ton_matrix_elem matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(inv_f_ton_matrix_elem.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{k, l \in \{0 \ldots 2^{n} - 1\}}~\left(\left({_{n}}\langle l \rvert \thinspace {\mathrm {FT}}^{\dag}(n) \thinspace \lvert k \rangle_{n}\right) = \left(\frac{1}{\sqrt{(2^{n})}} \cdot \mathsf{e}^{\frac{-\left(2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot l\right)}{2^{n}}}\right)\right)\right]

# %%
inv_f_ton_matrix_elem.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
inv_f_ton_matrix_elem.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{k, l in {0...2^{n} - 1}} (({n}_〈l| . FT^{dag}(n) . |k〉_{n}) = ((1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}}))]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (n -> {forall_{k, l in {0...2^{n} - 1}} (({n}_〈l| . FT^{dag}(n) . |k〉_{n}) = ((1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}})) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{k, l in {0...2^{n} - 1}} (({n}_〈l| . FT^{dag}(n) . |k〉_{n}) = ((1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}})) if n in NaturalPos.
#    core type: Lambda
#    parameter: 66
#    body: 3
# 3. {forall_{k, l in {0...2^{n} - 1}} (({n}_〈l| . FT^{dag}(n) . |k〉_{n}) = ((1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}})) if n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# ...
