# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theorems.ipynb#double_space_equiv">double_space_equiv</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving double_space_equiv
# Out:
# double_space_equiv: forall_{h, k, m, n in NaturalPos} [forall_{A_{1, 1}, ..A_{1, _b}.., A_{1, n}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, n}...., A_{m, 1}, ..A_{m, _b}.., A_{m, n}, B_{1}, ..B_{_a}.., B_{n}, C_{1, 1}, ..C_{1, _b}.., C_{1, n}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, n}...., C_{k, 1}, ..C_{k, _b}.., C_{k, n}, D_{1}, ..D_{_a}.., D_{n}, E_{1, 1}, ..E_{1, _b}.., E_{1, n}, ....E_{_a, 1}, ..E_{_a, _b}.., E_{_a, n}...., E_{h, 1}, ..E_{h, _b}.., E_{h, n}, F_{1}, ..F_{_a}.., F_{n}, G_{1}, ..G_{_a}.., G_{n}, S_{1, 1}, ..S_{1, _b}.., S_{1, n}, ....S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}...., S_{m, 1}, ..S_{m, _b}.., S_{m, n}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, n}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, n}...., Q_{h, 1}, ..Q_{h, _b}.., Q_{h, n}, R_{1, 1}, ..R_{1, _b}.., R_{1, n}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, n}...., R_{k, 1}, ..R_{k, _b}.., R_{k, n}} (( MultiQubitGate(B_{1}, {m + 1, m + k + 2})  & ..MultiQubitGate(B_{j}, {m + 1, m + k + 2})..  & MultiQubitGate(B_{n}, {m + 1, m + k + 
# ...
